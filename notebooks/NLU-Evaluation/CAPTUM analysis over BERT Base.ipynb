# %% [markdown]
# ## Captum - Axiomatic Attribution for Deep Networks
# https://arxiv.org/pdf/1703.01365
#
# https://www.kaggle.com/rhtsingh/interpreting-text-models-with-bert-on-tpu

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import os
import sys
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from tqdm.notebook import tqdm_notebook
import torch
import torch.nn as nn
from nlpClassifiers.data.dataset  import NLPDataset
from transformers import BertTokenizer, BertForSequenceClassification
from captum.attr import visualization as viz
from captum.attr import LayerIntegratedGradients
# Out:
# /usr/local/lib/python3.6/dist-packages/gensim/similarities/__init__.py:15: UserWarning: The gensim.similarities.levenshtein submodule is disabled, because the optional Levenshtein package <https://pypi.org/project/python-Levenshtein/> is unavailable. Install Levenhstein (e.g. `pip install python-Levenshtein`) to suppress this warning.
#   warnings.warn(msg)

# %%
model_base = 'bert-base-cased'
model_path ='../../models/agent-benchmark/bert-base-portuguese-tapt-classifier/base-dataset-agent-benchmark-agent-benchmark-100-epochs-early-stop-reset-3-bert-base-cased'
device = torch.device("cuda:2" if torch.cuda.is_available() else "cpu")

# load model
model = BertForSequenceClassification.from_pretrained(model_path, output_attentions = False,
        output_hidden_states = False, num_labels=64)
model.to(device)
model.eval()
model.zero_grad()

# load tokenizer
tokenizer = BertTokenizer.from_pretrained(model_base)

# %%
device
# Out:
# device(type='cuda', index=2)

# %%
ref_token_id = tokenizer.pad_token_id # A token used for generating token reference
sep_token_id = tokenizer.sep_token_id # A token used as a separator between question and text and it is also added to the end of the text.
cls_token_id = tokenizer.cls_token_id # A token used for prepending to the concatenated question-text word sequence

# %%
def construct_input_ref_pair(text, ref_token_id, sep_token_id, cls_token_id):

    text_ids = tokenizer.encode(text, add_special_tokens=False)
    # construct input token ids
    input_ids = [cls_token_id] + text_ids + [sep_token_id]
    # construct reference token ids 
    ref_input_ids = [cls_token_id] + [ref_token_id] * len(text_ids) + [sep_token_id]

    return torch.tensor([input_ids], device=device), torch.tensor([ref_input_ids], device=device), len(text_ids)

def construct_input_ref_token_type_pair(input_ids, sep_ind=0):
    seq_len = input_ids.size(1)
    token_type_ids = torch.tensor([[0 if i <= sep_ind else 1 for i in range(seq_len)]], device=device)
    ref_token_type_ids = torch.zeros_like(token_type_ids, device=device)# * -1
    return token_type_ids, ref_token_type_ids

def construct_input_ref_pos_id_pair(input_ids):
    seq_length = input_ids.size(1)
    position_ids = torch.arange(seq_length, dtype=torch.long, device=device)
    # we could potentially also use random permutation with `torch.randperm(seq_length, device=device)`
    ref_position_ids = torch.zeros(seq_length, dtype=torch.long, device=device)

    position_ids = position_ids.unsqueeze(0).expand_as(input_ids)
    ref_position_ids = ref_position_ids.unsqueeze(0).expand_as(input_ids)
    return position_ids, ref_position_ids
    
def construct_attention_mask(input_ids):
    return torch.ones_like(input_ids)

# %%
def predict(inputs, token_type_ids, attention_mask):
    return model(inputs, attention_mask, token_type_ids)[0]

def custom_forward(inputs, token_type_ids, attention_mask, label):
    preds = predict(inputs, token_type_ids, attention_mask)
    return torch.softmax(preds, dim = 1)[:, label]

def save_act(module, inp, out):
    return saved_act

hook = model.bert.embeddings.register_forward_hook(save_act)
hook.remove()

# %%
#Creates a list of tokens and attributions so we can plot the average attributions distribution for all tokens
def add_token_to_dict(token, attrib_score):
    if token != "[CLS]" and token != "[SEP]":
        try:
            if token not in attrib_tokens:
                attrib_tokens[token] = np.empty([0], dtype = float)
        except ValueError as error:
            print(error, token, attrib_tokens)
        attrib_tokens[token] = np.append(attrib_tokens[token], attrib_score)

# %%
def process(text, label):
    input_ids, ref_input_ids, sep_id = construct_input_ref_pair(text, ref_token_id, sep_token_id, cls_token_id)
    token_type_ids, ref_token_type_ids = construct_input_ref_token_type_pair(input_ids, sep_id)
    position_ids, ref_position_ids = construct_input_ref_pos_id_pair(input_ids)
    attention_mask = construct_attention_mask(input_ids)

    indices = input_ids[0].detach().tolist()
    all_tokens = tokenizer.convert_ids_to_tokens(indices)

    lig = LayerIntegratedGradients(custom_forward, model.bert.embeddings)
    
    attributions_main, delta_main = lig.attribute(inputs=input_ids,
                                                  baselines=ref_input_ids,
                                                  n_steps = 150,
                                                  additional_forward_args=(token_type_ids, attention_mask, label),
                                                  return_convergence_delta=True)
    
    score = predict(input_ids, token_type_ids, attention_mask)
    attributions_main = attributions_main.cpu()
    delta_main = delta_main.cpu()
    score = score.cpu()
    prd_label = torch.argmax(torch.softmax(score, dim = 1)[0])
    
    #inv_label = 101
    #if(prd_label == inv_label or label == inv_label):
    r_df = add_attributions_to_visualizer(attributions_main, delta_main, text, score, label, all_tokens)
    return r_df
    
def add_attributions_to_visualizer(attributions, delta, text, score, label, all_tokens):
    attributions = attributions.sum(dim=-1).squeeze(0)
    attributions = attributions / torch.norm(attributions)
    attributions = attributions.cpu()
    pred_class = torch.argmax(torch.softmax(score, dim = 1)[0])
    pred_score = torch.softmax(score, dim = 1)[0][pred_class]
    
    if(label == pred_class):
        l = 'Correct'
    else:
        l = 'Incorrect'
        
    ix = 0

    for token in all_tokens:
        add_token_to_dict(token,attributions[ix])
        ix+=1
    
    df = pd.DataFrame({"result":l, "score":pred_score.item(), "attribution_score":attributions.sum().item()}, index=[0])
    score_vis.append(
        viz.VisualizationDataRecord(
            attributions,
            pred_score,
            pred_class,
            label,
            label,
            attributions.sum(),
            all_tokens,
            delta
        )
    )
    return df,attributions,all_tokens

# %%
def read_data(filename):
    data = pd.read_csv(filename, sep=";", names =['utterance','label'], header=None, dtype={'utterance':str, 'label': str} )
    return data

# %%
DATA_PATH = '../../data/agent-benchmark'
TRAIN_DATASET  = os.path.join(DATA_PATH, 'train.csv')
TEST_DATASET  = os.path.join(DATA_PATH, 'test.csv')

# %%
test_dataset = read_data(TEST_DATASET).dropna()

# %%
train_corpus = NLPDataset('agent-benchmark', "train", 82, model_base)
test_corpus = NLPDataset('agent-benchmark', "test", 82, model_base)
labels_dict = train_corpus.labels_dict

# %%
train_dataset = read_data(TRAIN_DATASET).dropna()

# %%
pd.set_option('display.max_rows', None)
train_dataset[train_dataset['label']=='calendar_notification']
# Out:
#                                                utterance  \
# 0                      where is my meeting today located
# 197                                     upcoming meeting
# 531                                           click save
# 602    please set a notification on twenty third octo...
# 753                         remind me of mondays meeting
# 761      remind me of my meeting on wednesday at nine am
# 1002                 tell me when the event is happening
# 1102    set a notification about my meeting next tuesday
# 1179   send me an alert and hour before my next appoi...
# 1283       remind me when the concert tickets go on sale
# 1356   there are many important event in this month n...
# 1402   create a notification reminder for meeting tom...
# 1409   remind me about my next meeting with joe one h...
# 1653       set reminder for meeting at three pm tomorrow
# 1851                        send an alert before meeting
# 1863   set a reminder alert for saturday nine am towa...
# 2013                                     repeat birthday
# 2067                      when will i meet with joe next
# 2182   send me a notification an hour before my next ...
# 2335                    alert me when registration opens
# 2379              set an alarm for next tuesdays meeting
# 2520   give me a reminder notification on tomorrow's ...
# 2585                                 what are the events
# 2693          set reminder for meeting tuesday with bill
# 2934   please set an alarm for tomorrows meeting at s...
# 2965   add reminder today evening to collect the parc...
# 2968   i have a sales meeting this thursday at seven ...
# 3054                       latest reminder about meeting
# 3198                                           set alarm
# 3237                          whats on my calendar today
# 3358         make an alarm for fridays meeting at ten am
# 3364                     notify me when i have a meeting
# 3397   remind me a week before my credit card payment...
# 3464                      when is my dentist appointment
# 3621   give me a three day notification before my che...
# 4065   please tell me about a hour before thursday ab...
# 4144                    when is my next meeting with joe
# 4156         tell me when my next doctors appointment is
# 4442                       family bonding before meeting
# 4496   add a notification reminder and calendar event...
# 4518   remind me on fifth april there is a meeting wi...
# 4754   remind me of the meeting on one divided by twe...
# 4857                          what are my calender event
# 4862                               set this before event
# 4956   remind me of my twelve oclock meeting by one t...
# 4982                        tell me when i have an event
# 5050   please remind me at five pm today that i have ...
# 5077   notify me on march eleventh the day of my appo...
# 5104              set notification for meeting with boss
# 5112                                add a note to attend
# 5431   i am going to sally's birthday on saturday at ...
# 5606              notifiy me two hours before my meeting
# 5963                          remind me about my meeting
# 6003            tell me when i need to leave the airport
# 6125           remind me about my anniversary in advance
# 6128                                    meeting reminder
# 6223                    tell me when my moms birthday is
# 6526   set a notification for eleven march that an in...
# 6725   i have a meeting set a reminder for four divid...
# 6809   set a notification for my twelve pm meeting fi...
# 6867                 notify me of the meeting on tuesday
# 6930   remind me about my meeting with joe at ten on ...
# 6951        please put me your input to know my schedule
# 6992                      notify all birthdays next week
# 7138   set reminder for meeting with john on wednesda...
# 7154   remind me of my dentist appointment the night ...
# 7199                                        repeat alarm
# 7282   set a reminder to notify me one hour before lu...
# 7293             can you notify the event in my calendar
# 7312               notify me about all meetings tomorrow
# 7488                notify me one hour before my meeting
# 7933         please remind about the tomorrow's schedule
# 8022   remind me of the meeting with my teacher today...
# 8088   set a notification for sixth march that there ...
# 8556    create event with alarm for meeting in two hours
# 8702          remind me of my meeting tomorrow at ten am
# 8704                                   open my reminders
# 8831   remind me to pay the electricity bill on this ...
# 9171   remind yourself to remind me about needed to b...
# 9332   pleas set a reminder for a meeting i have on t...
# 9361                     attend party before the meeting
# 9429   set an alarm at ten am tomorrow and label it a...
# 9435   will set alarm clock one hour before my next d...
# 9712                   alert me at the time of the event
# 9847   remind me about the office meeting tomorrow at...
# 10431                                     set a reminder
# 10594                      create a reminder for meeting
# 10647                         notify me when my rent due
# 10662                    alert me when my anniversary is
# 10697  notify me an hour before my two pm appointment...
# 11168                        upcoming events in calendar
# 11434            when is my husband's birthday this year
# 11670            set a reminder to attend pta on tuesday
# 11698                set a reminder for my meeting today
# 11827          new notification for meeting in two hours
# 11932  remind me of the seven am sales meeting this t...
# 12263  i have a nine am meeting on wednesday send me ...
# 12294              remind me of the event in my calendar
# 12446                 set notification before this event
# 12455               please let me know about my birthday
# 12533  set reminder for date night with husband next ...
# 12542                            set meeting at seven pm
# 13013  notify me about the evening meeting five minut...
# 13045                  remind me about meeting next week
# 13056                                meeting this monday
# 13108  i've got an important meeting this sunday noon...
# 13201  save event for five pm to six pm on march eigh...
# 13412                   what is on my calendar for today
# 13523  would you please notify me about the event in ...
# 13629  notify me about any festival occurring next month
# 13646                which day this week do i have plans
# 13796      please let me know about a meeting after days
# 13828  can you remind my next meeting with my boss on...
# 13981                                     check calendar
# 14371  add sally's birthday to calander for saturday ...
# 14417       please alert me a day before jeff's birthday
# 14456             what are my plans for the month of may
# 14508  remind me that i have a meeting with cassy for...
# 14536  can i know what i have to do the next saturday...
# 14537                     write down meeting at seven pm
# 14756  can you remind me to go to dentist appointment...
# 14814                 remind me at the time of the event
# 14848             note down important event in this week
# 14965  set a notification for fifth march that i have...
# 15009                 what are the events coming up soon
# 15089             tell me when this meeting is coming up
# 15104  make a note to pay the electricity bill and re...
# 15138                    give me my to do list for today
# 15149  give me a reminder twenty four hours before my...
# 15300                                           calendar
# 15391        can you remind me about my meeting tomorrow
# 15522                    set up notification for meeting
# 15548                    any events in my calender today
# 15624             remind me to go to my meeting tomorrow
# 15662  search my calendar for my next event and notif...
# 15734            what events are in my clender for today
# 15786  remind me thirty minutes early that i have a t...
# 15791  remind me two hours before six pm that i have ...
# 15955                      whats going on in my calendar
# 16126                      make an alert for my birthday
# 16306  remind me of my twelve oclock meeting by one t...
# 16319  let me know when a next event if occurring fro...
# 16599      thirty minute reminder on meeting for tuesday
# 16623  set a two day notification before maria's birt...
# 16636               notify me when this meeting is close
# 16682                                     any meeting on
# 16979  please sound an alarm three hours before a sch...
# 17048  don't let me forget rover's vet appointment on...
# 17061         notify me in fifteen before meeting starts
# 17093  please remind me one hour before the meeting i...
# 17256  set phone to vibrate for a reminder five minut...
# 17396          send me a reminder for my meeting tonight
# 17410  remind me of my sister's birthday party tomorr...
# 17500                            set an alarm for two pm
# 17529                       what do i have planned today
# 17625     ess week ki sabhi important event ko note karo
# 17636  can you remind me to order the turkey three we...
# 17732         please make me uted about today's scenario
# 17765  please give me notice when i need to leave for...
# 17813  give me the list of all events coming up in th...
# 17980  notify me the day before the horse race at san...
# 18183             please let me know about my aniversary
#
#                        label
# 0      calendar_notification
# 197    calendar_notification
# 531    calendar_notification
# 602    calendar_notification
# 753    calendar_notification
# 761    calendar_notification
# 1002   calendar_notification
# 1102   calendar_notification
# 1179   calendar_notification
# 1283   calendar_notification
# 1356   calendar_notification
# 1402   calendar_notification
# 1409   calendar_notification
# 1653   calendar_notification
# 1851   calendar_notification
# 1863   calendar_notification
# 2013   calendar_notification
# 2067   calendar_notification
# 2182   calendar_notification
# 2335   calendar_notification
# 2379   calendar_notification
# 2520   calendar_notification
# 2585   calendar_notification
# 2693   calendar_notification
# 2934   calendar_notification
# 2965   calendar_notification
# 2968   calendar_notification
# 3054   calendar_notification
# 3198   calendar_notification
# 3237   calendar_notification
# 3358   calendar_notification
# 3364   calendar_notification
# 3397   calendar_notification
# 3464   calendar_notification
# 3621   calendar_notification
# 4065   calendar_notification
# 4144   calendar_notification
# 4156   calendar_notification
# 4442   calendar_notification
# 4496   calendar_notification
# 4518   calendar_notification
# 4754   calendar_notification
# 4857   calendar_notification
# 4862   calendar_notification
# 4956   calendar_notification
# 4982   calendar_notification
# 5050   calendar_notification
# 5077   calendar_notification
# 5104   calendar_notification
# 5112   calendar_notification
# 5431   calendar_notification
# 5606   calendar_notification
# 5963   calendar_notification
# 6003   calendar_notification
# 6125   calendar_notification
# 6128   calendar_notification
# 6223   calendar_notification
# 6526   calendar_notification
# 6725   calendar_notification
# 6809   calendar_notification
# 6867   calendar_notification
# 6930   calendar_notification
# 6951   calendar_notification
# 6992   calendar_notification
# 7138   calendar_notification
# 7154   calendar_notification
# 7199   calendar_notification
# 7282   calendar_notification
# 7293   calendar_notification
# 7312   calendar_notification
# 7488   calendar_notification
# 7933   calendar_notification
# 8022   calendar_notification
# 8088   calendar_notification
# 8556   calendar_notification
# 8702   calendar_notification
# 8704   calendar_notification
# 8831   calendar_notification
# 9171   calendar_notification
# 9332   calendar_notification
# 9361   calendar_notification
# 9429   calendar_notification
# 9435   calendar_notification
# 9712   calendar_notification
# 9847   calendar_notification
# 10431  calendar_notification
# 10594  calendar_notification
# 10647  calendar_notification
# 10662  calendar_notification
# 10697  calendar_notification
# 11168  calendar_notification
# 11434  calendar_notification
# 11670  calendar_notification
# 11698  calendar_notification
# 11827  calendar_notification
# 11932  calendar_notification
# 12263  calendar_notification
# 12294  calendar_notification
# 12446  calendar_notification
# 12455  calendar_notification
# 12533  calendar_notification
# 12542  calendar_notification
# 13013  calendar_notification
# 13045  calendar_notification
# 13056  calendar_notification
# 13108  calendar_notification
# 13201  calendar_notification
# 13412  calendar_notification
# 13523  calendar_notification
# 13629  calendar_notification
# 13646  calendar_notification
# 13796  calendar_notification
# 13828  calendar_notification
# 13981  calendar_notification
# 14371  calendar_notification
# 14417  calendar_notification
# 14456  calendar_notification
# 14508  calendar_notification
# 14536  calendar_notification
# 14537  calendar_notification
# 14756  calendar_notification
# 14814  calendar_notification
# 14848  calendar_notification
# 14965  calendar_notification
# 15009  calendar_notification
# 15089  calendar_notification
# 15104  calendar_notification
# 15138  calendar_notification
# 15149  calendar_notification
# 15300  calendar_notification
# 15391  calendar_notification
# 15522  calendar_notification
# 15548  calendar_notification
# 15624  calendar_notification
# 15662  calendar_notification
# 15734  calendar_notification
# 15786  calendar_notification
# 15791  calendar_notification
# 15955  calendar_notification
# 16126  calendar_notification
# 16306  calendar_notification
# 16319  calendar_notification
# 16599  calendar_notification
# 16623  calendar_notification
# 16636  calendar_notification
# 16682  calendar_notification
# 16979  calendar_notification
# 17048  calendar_notification
# 17061  calendar_notification
# 17093  calendar_notification
# 17256  calendar_notification
# 17396  calendar_notification
# 17410  calendar_notification
# 17500  calendar_notification
# 17529  calendar_notification
# 17625  calendar_notification
# 17636  calendar_notification
# 17732  calendar_notification
# 17765  calendar_notification
# 17813  calendar_notification
# 17980  calendar_notification
# 18183  calendar_notification

# %% [markdown]
# ## Analysis over 3 classes:
#     115 - Sintomas.Genérico.Promessa de oferta
#     108 - Sintomas.Qualificado.Cliente está longe
#     116 - Sintomas.Qualificado.Ausência sinal geral

# %%
score_vis = []
attrib_tokens = {}
results_df = pd.DataFrame() 
for step,row in tqdm_notebook(test_corpus.df.iterrows(), total=test_corpus.df.shape[0]):
 #   if step == 500:
 #       break
    text = row['utterance']
    label = train_corpus.labels_dict.get(row['label'])
    if label == 38:
     #if label == 15:
        df,attributions,all_tokens = process(text, label)
        results_df = results_df.append(df, ignore_index=True)
# Out:
# HBox(children=(FloatProgress(value=0.0, max=5116.0), HTML(value='')))

# %%
tokens_list = []
attrib_list =np.empty([len(attrib_tokens)], dtype = float)
i = 0
for k in attrib_tokens:
    # v is the list of grades for student k
    tokens_list.append(k)
    attrib_list[i]=sum(attrib_tokens[k])/ float(len(attrib_tokens[k]))
    i+=1
    
    
n = 20  #how many highest and lowest importances we want to plot
sorted_imp_idx = attrib_list.argsort()
lowest_imp_idx = sorted_imp_idx[:n]
highest_imp_idx = sorted_imp_idx[-n:]
imp_idx = np.concatenate((lowest_imp_idx, highest_imp_idx), axis=None)
attrib_list = attrib_list[imp_idx]
tokens_list = np.array(tokens_list)[imp_idx.astype(int)]

# %%
def getcolor(result):
    if result:
        return 'g'
    else:
        return 'r'

# %%
title="Average Feature Importances"
axis_title="Features"
x_pos = (np.arange(len(tokens_list)))
plt.figure(figsize=(16,9))
plt.bar(x_pos, attrib_list, align='center',color=list(map(getcolor, (attrib_list > 0.))))
plt.xticks(x_pos, list(tokens_list), wrap=True,rotation='vertical',ha='right')
#plt.margins(0.1)
#plt.subplots_adjust(bottom=0.15)
plt.xlabel(axis_title)
plt.title(title)
# Out:
# Text(0.5, 1.0, 'Average Feature Importances')

# %%
import matplotlib.pyplot as plt

# %%
attributions
# Out:
# tensor([ 0.0000, -0.0183,  0.9417, -0.0954,  0.3167,  0.0286,  0.0508,  0.0000],
#        dtype=torch.float64)

# %%
results_df[results_df['result']=='Correct']['attribution_score'].mean()
# Out:
# 1.6158006012404162

# %%
results_df[results_df['result']=='Incorrect']['attribution_score'].mean()
# Out:
# 0.53057375797617

# %%
groups = results_df.groupby("result")
for name, group in groups:
    plt.plot(group["score"],  marker="o", linestyle="", label=name)
plt.legend()
plt.suptitle('Sintomas.Genérico.Promessa de oferta', fontsize=16)
# Out:
# Text(0.5, 0.98, 'Sintomas.Genérico.Promessa de oferta')

# %%
groups = results_df.groupby("result")
for name, group in groups:
    plt.plot(group["attribution_score"],  marker="o", linestyle="", label=name)
plt.legend()
plt.suptitle('Sintomas.Genérico.Promessa de oferta', fontsize=16)
# Out:
# Text(0.5, 0.98, 'Sintomas.Genérico.Promessa de oferta')

# %%
x = viz.visualize_text(score_vis)
# Out:
# <table width: 100%><div style="border-top: 1px solid; margin-top: 5px;             padding-top: 5px; display: inline-block"><b>Legend: </b><span style="display: inline-block; width: 10px; height: 10px;                 border: 1px solid; background-color:                 hsl(0, 75%, 60%)"></span> Negative  <span style="display: inline-block; width: 10px; height: 10px;                 border: 1px solid; background-color:                 hsl(0, 75%, 100%)"></span> Neutral  <span style="display: inline-block; width: 10px; height: 10px;                 border: 1px solid; background-color:                 hsl(120, 75%, 50%)"></span> Positive  </div><tr><th>True Label</th><th>Predicted Label</th><th>Attribution Label</th><th>Attribution Score</th><th>Word Importance</th><tr><td><text style="padding-right:2em"><b>18</b></text></td><td><text style="padding-right:2em"><b>18 (0.81)</b></text></td><td><text style="padding-right:2em"><b>18</b></text></td><td><text style="padding-right:2em"><b>1.33</b></text></td><td><mark style="background-color: hsl(0, 75%, 100%); opacity:1.0;                     line-height:1.75"><font color="black"> [CLS]                    </font></mark><mark style="background-color: hsl(120, 75%, 65%); opacity:1.0;                     line-height:1.75"><font color="black"> where                    </font></mark><mark style="background-color: hsl(120, 75%, 77%); opacity:1.0;                     line-height:1.75"><font color="black"> can                    </font></mark><mark style="background-color: hsl(0, 75%, 100%); opacity:1.0;                     line-height:1.75"><font color="black"> i                    </font></mark><mark style="background-color: hsl(0, 75%, 96%); opacity:1.0;                     line-height:1.75"><font color="black"> go                    </font></mark><mark style="background-color: hsl(120, 75%, 77%); opacity:1.0;                     line-height:1.75"><font color="black"> shopping                    </font></mark><mark style="background-color: hsl(0, 75%, 92%); opacity:1.0;                     line-height:1.75"><font color="black"> here                    </font></mark><mark style="background-color: hsl(0, 75%, 100%); opacity:1.0;                     line-height:1.75"><font color="black"> [SEP]                    </font></mark></td><tr><tr><td><text style="padding-right:2em"><b>18</b></text></td><td><text style="padding-right:2em"><b>18 (0.99)</b></text></td><td><text style="padding-right:2em"><b>18</b></text></td><td><text style="padding-right:2em"><b>1.41</b></text></td><td><mark style="background-color: hsl(0, 75%, 100%); opacity:1.0;                     line-height:1.75"><font color="black"> [CLS]                    </font></mark><mark style="background-color: hsl(120, 75%, 98%); opacity:1.0;                     line-height:1.75"><font color="black"> hey                    </font></mark><mark style="background-color: hsl(120, 75%, 99%); opacity:1.0;                     line-height:1.75"><font color="black"> sir                    </font></mark><mark style="background-color: hsl(120, 75%, 95%); opacity:1.0;                     line-height:1.75"><font color="black"> ##i                    </font></mark><mark style="background-color: hsl(0, 75%, 98%); opacity:1.0;                     line-height:1.75"><font color="black"> give                    </font></mark><mark style="background-color: hsl(0, 75%, 100%); opacity:1.0;                     line-height:1.75"><font color="black"> me                    </font></mark><mark style="background-color: hsl(0, 75%, 97%); opacity:1.0;                     line-height:1.75"><font color="black"> a                    </font></mark><mark style="background-color: hsl(0, 75%, 97%); opacity:1.0;                     line-height:1.75"><font color="black"> list                    </font></mark><mark style="background-color: hsl(120, 75%, 93%); opacity:1.0;                     line-height:1.75"><font color="black"> of                    </font></mark><mark style=" ...

# %%
score_vis = []
results_df = pd.DataFrame() 
for step,row in tqdm_notebook(test_corpus.df.iterrows(), total=test_corpus.df.shape[0]):
#    if step == 50:
#        break
    text = row['utterance']
    label = train_corpus.labels_dict.get(row['label'])
    if label == 18:
        df = process(text, label)
        results_df = results_df.append(df, ignore_index=True)
# Out:
# HBox(children=(FloatProgress(value=0.0, max=5116.0), HTML(value='')))

# %%
groups = results_df.groupby("result")
for name, group in groups:
    plt.plot(group["attribution_score"],  marker="o", linestyle="", label=name)
plt.legend()
plt.suptitle('Sintomas.Qualificado.Cliente está longe', fontsize=16)
# Out:
# Text(0.5, 0.98, 'Sintomas.Qualificado.Cliente está longe')

# %%
viz.visualize_text(score_vis)
# Out:
# <table width: 100%><div style="border-top: 1px solid; margin-top: 5px;             padding-top: 5px; display: inline-block"><b>Legend: </b><span style="display: inline-block; width: 10px; height: 10px;                 border: 1px solid; background-color:                 hsl(0, 75%, 60%)"></span> Negative  <span style="display: inline-block; width: 10px; height: 10px;                 border: 1px solid; background-color:                 hsl(0, 75%, 100%)"></span> Neutral  <span style="display: inline-block; width: 10px; height: 10px;                 border: 1px solid; background-color:                 hsl(120, 75%, 50%)"></span> Positive  </div><tr><th>True Label</th><th>Predicted Label</th><th>Attribution Label</th><th>Attribution Score</th><th>Word Importance</th><tr><td><text style="padding-right:2em"><b>18</b></text></td><td><text style="padding-right:2em"><b>18 (0.81)</b></text></td><td><text style="padding-right:2em"><b>where can i go shopping here</b></text></td><td><text style="padding-right:2em"><b>1.33</b></text></td><td><mark style="background-color: hsl(0, 75%, 100%); opacity:1.0;                     line-height:1.75"><font color="black"> [CLS]                    </font></mark><mark style="background-color: hsl(120, 75%, 65%); opacity:1.0;                     line-height:1.75"><font color="black"> where                    </font></mark><mark style="background-color: hsl(120, 75%, 77%); opacity:1.0;                     line-height:1.75"><font color="black"> can                    </font></mark><mark style="background-color: hsl(0, 75%, 100%); opacity:1.0;                     line-height:1.75"><font color="black"> i                    </font></mark><mark style="background-color: hsl(0, 75%, 96%); opacity:1.0;                     line-height:1.75"><font color="black"> go                    </font></mark><mark style="background-color: hsl(120, 75%, 77%); opacity:1.0;                     line-height:1.75"><font color="black"> shopping                    </font></mark><mark style="background-color: hsl(0, 75%, 92%); opacity:1.0;                     line-height:1.75"><font color="black"> here                    </font></mark><mark style="background-color: hsl(0, 75%, 100%); opacity:1.0;                     line-height:1.75"><font color="black"> [SEP]                    </font></mark></td><tr><tr><td><text style="padding-right:2em"><b>18</b></text></td><td><text style="padding-right:2em"><b>18 (0.99)</b></text></td><td><text style="padding-right:2em"><b>hey siri give me a list of nearby shops</b></text></td><td><text style="padding-right:2em"><b>1.41</b></text></td><td><mark style="background-color: hsl(0, 75%, 100%); opacity:1.0;                     line-height:1.75"><font color="black"> [CLS]                    </font></mark><mark style="background-color: hsl(120, 75%, 98%); opacity:1.0;                     line-height:1.75"><font color="black"> hey                    </font></mark><mark style="background-color: hsl(120, 75%, 99%); opacity:1.0;                     line-height:1.75"><font color="black"> sir                    </font></mark><mark style="background-color: hsl(120, 75%, 95%); opacity:1.0;                     line-height:1.75"><font color="black"> ##i                    </font></mark><mark style="background-color: hsl(0, 75%, 98%); opacity:1.0;                     line-height:1.75"><font color="black"> give                    </font></mark><mark style="background-color: hsl(0, 75%, 100%); opacity:1.0;                     line-height:1.75"><font color="black"> me                    </font></mark><mark style="background-color: hsl(0, 75%, 97%); opacity:1.0;                     line-height:1.75"><font color="black"> a                    </font></mark><mark style="background-color: hsl(0, 75%, 97%); opacity:1.0;                     line-height:1.75"><font color="black"> list                    </font></mark><mark style="background-color: hsl(120, 75%, 93%); opacity:1.0;                     line-height:1.75"><font c ...
# <table width: 100%><div style="border-top: 1px solid; margin-top: 5px;             padding-top: 5px; display: inline-block"><b>Legend: </b><span style="display: inline-block; width: 10px; height: 10px;                 border: 1px solid; background-color:                 hsl(0, 75%, 60%)"></span> Negative  <span style="display: inline-block; width: 10px; height: 10px;                 border: 1px solid; background-color:                 hsl(0, 75%, 100%)"></span> Neutral  <span style="display: inline-block; width: 10px; height: 10px;                 border: 1px solid; background-color:                 hsl(120, 75%, 50%)"></span> Positive  </div><tr><th>True Label</th><th>Predicted Label</th><th>Attribution Label</th><th>Attribution Score</th><th>Word Importance</th><tr><td><text style="padding-right:2em"><b>18</b></text></td><td><text style="padding-right:2em"><b>18 (0.81)</b></text></td><td><text style="padding-right:2em"><b>where can i go shopping here</b></text></td><td><text style="padding-right:2em"><b>1.33</b></text></td><td><mark style="background-color: hsl(0, 75%, 100%); opacity:1.0;                     line-height:1.75"><font color="black"> [CLS]                    </font></mark><mark style="background-color: hsl(120, 75%, 65%); opacity:1.0;                     line-height:1.75"><font color="black"> where                    </font></mark><mark style="background-color: hsl(120, 75%, 77%); opacity:1.0;                     line-height:1.75"><font color="black"> can                    </font></mark><mark style="background-color: hsl(0, 75%, 100%); opacity:1.0;                     line-height:1.75"><font color="black"> i                    </font></mark><mark style="background-color: hsl(0, 75%, 96%); opacity:1.0;                     line-height:1.75"><font color="black"> go                    </font></mark><mark style="background-color: hsl(120, 75%, 77%); opacity:1.0;                     line-height:1.75"><font color="black"> shopping                    </font></mark><mark style="background-color: hsl(0, 75%, 92%); opacity:1.0;                     line-height:1.75"><font color="black"> here                    </font></mark><mark style="background-color: hsl(0, 75%, 100%); opacity:1.0;                     line-height:1.75"><font color="black"> [SEP]                    </font></mark></td><tr><tr><td><text style="padding-right:2em"><b>18</b></text></td><td><text style="padding-right:2em"><b>18 (0.99)</b></text></td><td><text style="padding-right:2em"><b>hey siri give me a list of nearby shops</b></text></td><td><text style="padding-right:2em"><b>1.41</b></text></td><td><mark style="background-color: hsl(0, 75%, 100%); opacity:1.0;                     line-height:1.75"><font color="black"> [CLS]                    </font></mark><mark style="background-color: hsl(120, 75%, 98%); opacity:1.0;                     line-height:1.75"><font color="black"> hey                    </font></mark><mark style="background-color: hsl(120, 75%, 99%); opacity:1.0;                     line-height:1.75"><font color="black"> sir                    </font></mark><mark style="background-color: hsl(120, 75%, 95%); opacity:1.0;                     line-height:1.75"><font color="black"> ##i                    </font></mark><mark style="background-color: hsl(0, 75%, 98%); opacity:1.0;                     line-height:1.75"><font color="black"> give                    </font></mark><mark style="background-color: hsl(0, 75%, 100%); opacity:1.0;                     line-height:1.75"><font color="black"> me                    </font></mark><mark style="background-color: hsl(0, 75%, 97%); opacity:1.0;                     line-height:1.75"><font color="black"> a                    </font></mark><mark style="background-color: hsl(0, 75%, 97%); opacity:1.0;                     line-height:1.75"><font color="black"> list                    </font></mark><mark style="background-color: hsl(120, 75%, 93%); opacity:1.0;                     line-height:1.75"><font c ...

# %%
score_vis = []
results_df = pd.DataFrame() 
for step,row in tqdm_notebook(test_corpus.df.iterrows(), total=test_corpus.df.shape[0]):
#    if step == 50:
#        break
    text = row['utterance']
    label = train_corpus.labels_dict.get(row['label'])
    if label == 116:
        df = process(text, label)
        results_df = results_df.append(df, ignore_index=True)
# Out:
# HBox(children=(FloatProgress(value=0.0, max=133986.0), HTML(value='')))

# %%
groups = results_df.groupby("result")
for name, group in groups:
    plt.plot(group["attribution_score"],  marker="o", linestyle="", label=name)
plt.legend()
plt.suptitle('Sintomas.Qualificado.Ausência sinal geral', fontsize=16)
# Out:
# Text(0.5, 0.98, 'Sintomas.Qualificado.Ausência sinal geral')

# %%
viz.visualize_text(score_vis)
# Out:
# <table width: 100%><div style="border-top: 1px solid; margin-top: 5px;             padding-top: 5px; display: inline-block"><b>Legend: </b><span style="display: inline-block; width: 10px; height: 10px;                 border: 1px solid; background-color:                 hsl(0, 75%, 60%)"></span> Negative  <span style="display: inline-block; width: 10px; height: 10px;                 border: 1px solid; background-color:                 hsl(0, 75%, 100%)"></span> Neutral  <span style="display: inline-block; width: 10px; height: 10px;                 border: 1px solid; background-color:                 hsl(120, 75%, 50%)"></span> Positive  </div><tr><th>True Label</th><th>Predicted Label</th><th>Attribution Label</th><th>Attribution Score</th><th>Word Importance</th><tr><td><text style="padding-right:2em"><b>116</b></text></td><td><text style="padding-right:2em"><b>116 (1.00)</b></text></td><td><text style="padding-right:2em"><b>ausencia de sinal em alguns pontos da tv</b></text></td><td><text style="padding-right:2em"><b>2.45</b></text></td><td><mark style="background-color: hsl(0, 75%, 100%); opacity:1.0;                     line-height:1.75"><font color="black"> [CLS]                    </font></mark><mark style="background-color: hsl(120, 75%, 91%); opacity:1.0;                     line-height:1.75"><font color="black"> ause                    </font></mark><mark style="background-color: hsl(120, 75%, 94%); opacity:1.0;                     line-height:1.75"><font color="black"> ##ncia                    </font></mark><mark style="background-color: hsl(120, 75%, 98%); opacity:1.0;                     line-height:1.75"><font color="black"> de                    </font></mark><mark style="background-color: hsl(120, 75%, 92%); opacity:1.0;                     line-height:1.75"><font color="black"> sinal                    </font></mark><mark style="background-color: hsl(120, 75%, 70%); opacity:1.0;                     line-height:1.75"><font color="black"> em                    </font></mark><mark style="background-color: hsl(120, 75%, 83%); opacity:1.0;                     line-height:1.75"><font color="black"> alguns                    </font></mark><mark style="background-color: hsl(120, 75%, 71%); opacity:1.0;                     line-height:1.75"><font color="black"> pontos                    </font></mark><mark style="background-color: hsl(120, 75%, 88%); opacity:1.0;                     line-height:1.75"><font color="black"> da                    </font></mark><mark style="background-color: hsl(120, 75%, 95%); opacity:1.0;                     line-height:1.75"><font color="black"> t                    </font></mark><mark style="background-color: hsl(120, 75%, 99%); opacity:1.0;                     line-height:1.75"><font color="black"> ##v                    </font></mark><mark style="background-color: hsl(0, 75%, 100%); opacity:1.0;                     line-height:1.75"><font color="black"> [SEP]                    </font></mark></td><tr><tr><td><text style="padding-right:2em"><b>116</b></text></td><td><text style="padding-right:2em"><b>116 (1.00)</b></text></td><td><text style="padding-right:2em"><b>ausencia de sinal em dois pontos</b></text></td><td><text style="padding-right:2em"><b>1.63</b></text></td><td><mark style="background-color: hsl(0, 75%, 100%); opacity:1.0;                     line-height:1.75"><font color="black"> [CLS]                    </font></mark><mark style="background-color: hsl(120, 75%, 98%); opacity:1.0;                     line-height:1.75"><font color="black"> ause                    </font></mark><mark style="background-color: hsl(120, 75%, 95%); opacity:1.0;                     line-height:1.75"><font color="black"> ##ncia                    </font></mark><mark style="background-color: hsl(0, 75%, 99%); opacity:1.0;                     line-height:1.75"><font color="black"> de                    </font></mark><mark style="background-color: hsl(0, 75%, 100%); opacity:1.0;                     l ...

# %%
Sintomas.Genérico.Promessa de oferta
Sintomas.Qualificado.Cliente está longe
Sintomas.Qualificado.Ausência sinal geral
# Out:
#   File "<ipython-input-22-eb244cb87906>", line 1
#     Sintomas.Genérico.Promessa de oferta
#                                 ^
# SyntaxError: invalid syntax

# %%
print(list(labels_dict.keys())[list(labels_dict.values()).index(116)])

# %%
print(labels_dict.get('Sintomas.Qualificado.Recarga'))
