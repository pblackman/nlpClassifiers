# %%
# %load_ext autoreload
# %autoreload 2

from os.path import join
import os
import pandas as pd
import torch
import numpy as np
import torch.nn as nn
import torch.nn.functional as F
from torch.optim.lr_scheduler import ReduceLROnPlateau
from torch.nn.init import kaiming_uniform_
from torch.optim import SGD
from torch.utils.data import DataLoader, SequentialSampler, RandomSampler
from torch.optim import Adam
from torch.autograd import Variable
from nlpClassifiers.data.dataset  import NLPDataset, Vocabulary
from sklearn.metrics import roc_curve, auc, classification_report
from scipy.special import expit
import gensim
import shutil
from pathlib import Path
import random

# %%
ROOT = '../../'
PATH_TO_VIRTUAL_OPERATOR_DATA = join(ROOT, "data/virtual-operator")
PATH_TO_AGENT_BENCHMARK_DATA = join(ROOT, "data/agent-benchmark")
PATH_TO_ML_PT_DATA = join(ROOT, "data/mercado-livre-pt-only")

PATH_TO_VIRTUAL_OPERATOR_MODELS = join(ROOT, "models/virtual-operator")
PATH_TO_AGENT_BENCHMARK_MODELS = join(ROOT, "models/agent-benchmark")
PATH_TO_ML_PT_MODELS = join(ROOT, "models/mercado-livre-pt-only")
#EMBEDDINGS_FILE = '../../data/agent-benchmark/vocab/word2vec-model-agent-benchmark.bin'
EMBEDDING_DIM = 300
MAX_WORDS = 30000
dataset = 'virtual-operator'

sentence_max_len = 82
batch_size = 512
biLSTM = True
epochs=30
stopwords_lang = None
gpu=1
lr=1e-3
clipping_value=0.25
save_name='bilstm-pytorch-jointly-trained-embeddings'
patience=5

# %%
BASE_PATH_TO_MODELS = {"virtual-operator": PATH_TO_VIRTUAL_OPERATOR_MODELS, "agent-benchmark": PATH_TO_AGENT_BENCHMARK_MODELS, "mercado-livre-pt": PATH_TO_ML_PT_MODELS}
FULL_PATH_TO_MODELS = join(BASE_PATH_TO_MODELS[dataset], "bilstm-classifier")

# %%
def _init_fn(worker_id):
    np.random.seed(seed)

# %%
def read_data(dataset, subset):
    BASE_PATH_TO_DATASET = {"virtual-operator": PATH_TO_VIRTUAL_OPERATOR_DATA, "agent-benchmark": PATH_TO_AGENT_BENCHMARK_DATA, "mercado-livre-pt": PATH_TO_ML_PT_DATA}
    BASE_PATH_TO_DATASET = {"train": join(BASE_PATH_TO_DATASET[dataset], "train.csv"), "val": join(BASE_PATH_TO_DATASET[dataset], "val.csv"), "test": join(BASE_PATH_TO_DATASET[dataset], "test.csv")}
    FULL_PATH_TO_DATASET = BASE_PATH_TO_DATASET[subset]
    
    if dataset == "mercado-livre-pt":
        sep=","
    else:
        sep=";"
    data = pd.read_csv(FULL_PATH_TO_DATASET, sep=sep, names =['utterance','label'], header=None, dtype={'utterance':str, 'label': str} )
    return data

# %%
train_df = read_data(dataset, "train")
val_df = read_data(dataset, "val")

# %%
voc = Vocabulary('CNN', stopwords_lang)
voc.build_vocab(train_df['utterance'].tolist() +  val_df['utterance'].tolist(), MAX_WORDS)
#embedding_weights = voc.load_embeddings(EMBEDDINGS_FILE, EMBEDDING_DIM)
if voc.num_words < MAX_WORDS or MAX_WORDS == 0:
    MAX_WORDS = voc.num_words

# %%
train_corpus = NLPDataset(dataset, "train", sentence_max_len, vocab= voc)
labels_dict = train_corpus.labels_dict
val_corpus = NLPDataset(dataset, "val", sentence_max_len, labels_dict = labels_dict, vocab= voc)

# %%
train_dataloader = DataLoader(
            train_corpus,
            sampler = RandomSampler(train_corpus),
            batch_size = batch_size,
            pin_memory=True,
            #shuffle=True,
            worker_init_fn=_init_fn,
            num_workers=0
)

validation_dataloader = DataLoader(
            val_corpus,
            sampler = RandomSampler(val_corpus),
            batch_size = batch_size,
            pin_memory=True,
            #shuffle=True,
            worker_init_fn=_init_fn,
            num_workers=0
)

# %%
#del model
torch.cuda.empty_cache()

# %%
def seed_everything(seed=10):
    random.seed(seed)
    os.environ['PYTHONHASHSEED'] = str(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    torch.backends.cudnn.deterministic = True

# %%
seed_everything()

# %%
device = torch.device(f"cuda:{gpu}")

# %%
class LSTMNet(nn.Module):
    def __init__(self, device, num_classes, num_features, criterion, embedding_dim, bidirectional, embedding_weights=None):
        super(LSTMNet, self).__init__()
        self.criterion = criterion
        self.embedding_dim = embedding_dim
        self.lstm_units = embedding_dim
        self.lstm_act = nn.Tanh()
        self.num_directions = 2 if bidirectional else 1
        self.device = device
        self.n_layers = 1
        self.embedding = nn.Embedding(num_features, embedding_dim, padding_idx = 0)
        
        if(embedding_weights is not None):
            print("Embedding layer weights won't be updated.")
            self.embedding.load_state_dict({'weight': embedding_weights})
            #self.embedding.from_pretrained(embedding_weights, freeze=True)
            self.embedding.weight.requires_grad = False
        else:
            self.embedding.weight.data = torch.zeros(self.embedding.weight.data.size())
            self.embedding.weight.requires_grad = True
        
        self.lstm = nn.LSTM(embedding_dim, self.lstm_units, num_layers=self.n_layers, bidirectional=bidirectional, batch_first=True)

        self.dropout = nn.Dropout(0.2)       
        self.linear = nn.Linear(self.num_directions * self.lstm_units, num_classes)   
        self.init_weights()
        
    def forward(self, x, y):

        # lstm step => then ONLY take the sequence's final timetep to pass into the linear/dense layer
        # Note: lstm_out contains outputs for every step of the sequence we are looping over (for BPTT)
        # but we just need the output of the last step of the sequence, aka lstm_out[-1]
        #print("x input:", x.size())
        #set_trace()
        x = self.embedding(x)
        #print("embeddings:", x.size())
        x_, (h_n, c_n) = self.lstm(x)
        h = x_[:,-0,:]
        #h = self.lstm_act(h)
        '''        
        if self.num_directions == 2:
            h = torch.cat((h_n[-2, :, :], h_n[-1, :, :]), dim=1)
        else:
            h = h_n[-1, :, :]
        '''
        #print("h before activation:", h.size())
        #print("h after activation:", h.size())
        output = self.dropout(h)
        output = self.linear(output)
        #print("output after linear:", output.size())
        loss = self.criterion(output.squeeze(), y)
        #print("loss:", loss.size())
        return loss,output
    
    def init_weights(self):  
        nn.init.xavier_normal_(self.lstm.weight_hh_l0)
        nn.init.xavier_normal_(self.lstm.weight_ih_l0)
        nn.init.xavier_normal_(self.linear.weight.data)
       
        for name, param in self.lstm.named_parameters():
            if 'bias' in name:
                nn.init.constant_(param, 0.0)
            elif 'weight_ih' in name:
                nn.init.kaiming_normal_(param)
            elif 'weight_hh' in name:
                nn.init.orthogonal_(param)

# %%
criterion = torch.nn.CrossEntropyLoss()
model = LSTMNet(device, train_corpus.num_labels, MAX_WORDS, criterion, EMBEDDING_DIM, biLSTM)

# %%
model = model.to(device)
optimizer = Adam(model.parameters(),lr, betas=(0.7, 0.999))

# %%
def get_accuracy_from_logits(logits, labels):
    acc = (labels.cpu() == logits.cpu().argmax(-1)).float().detach().numpy()
    return float(100 * acc.sum() / len(acc))

# %%
scheduler = ReduceLROnPlateau(optimizer, mode='min', patience=3,verbose=True, factor=0.1)

best_epoch = -1
last_saved_model = ""
training_stats = []
global_step = 0
best_val_acc = float("-inf")
best_model_wts = None
best_curr_val = 0

for epoch_i in range(0, epochs):
    print("")
    print('======== Epoch {:} / {:} ========'.format(epoch_i + 1, epochs))
    print('Training...')
    total_train_loss = 0
    model.train()
    for step, batch in enumerate(train_dataloader):
         # Progress update every 40 batches.
        if step % 40 == 0 and not step == 0:
            print('  Batch {:>5,}  of  {:>5,}.    .'.format(step, len(train_dataloader)))
        b_input_ids = batch[0]
        b_labels = batch[1].clone().detach().to(device)
        b_input_ids = b_input_ids.clone().detach().to(device).long()
        loss, logits= model(b_input_ids, b_labels)
        step_loss = loss.item()
        model.zero_grad()
        loss.backward()
        torch.nn.utils.clip_grad_norm_(model.parameters(), clipping_value)
        optimizer.step()
        

        if step % 40 == 0 and not step == 0:
            print("  step loss: {0:.2f}".format(step_loss))
        total_train_loss += step_loss
        global_step += 1
    avg_train_loss = total_train_loss / len(train_dataloader)
    # Measure how long this epoch took.
    print("")
    print("  Average training loss: {0:.2f}".format(avg_train_loss))

    print("")
    print("Running Validation...")
    model.eval()

    # Tracking variables
    total_eval_accuracy = 0.0
    total_eval_loss = 0
    nb_eval_steps = 0
    for step, batch in enumerate(validation_dataloader):
        b_input_ids = batch[0]
        b_input_ids = b_input_ids.clone().detach().to(device).long()
        b_labels = batch[1].to(device)
        with torch.no_grad():
            # Forward pass, calculate logit predictions.
            loss, logits = model(b_input_ids, b_labels)
        total_eval_loss += loss
        batch_acc = get_accuracy_from_logits(logits, b_labels)
        print("Batch accuracy: {0:.2f}".format(batch_acc))
        total_eval_accuracy += batch_acc
    
    # Calculate the average loss over all of the batches.
    avg_val_accuracy = total_eval_accuracy / len(validation_dataloader)
    print("  Accuracy: {0:.2f}".format(avg_val_accuracy))
    
    if avg_val_accuracy > best_val_acc:
        print(f"New best model, saving it!")
        if avg_val_accuracy > best_curr_val:
            best_curr_val = avg_val_accuracy
        if last_saved_model:
            shutil.rmtree(last_saved_model)
        model_path = Path(
            FULL_PATH_TO_MODELS,
            f"base-dataset-{dataset}-{save_name}"
        )
        last_saved_model = model_path
        model_path.mkdir(parents=True, exist_ok=True)
        best_val_acc = avg_val_accuracy
        torch.save(model, join(model_path, "best-model.pth"))
        best_epoch = epoch_i
        n_epochs_no_improvement = 0
    elif avg_val_accuracy > best_curr_val:
        best_curr_val = avg_val_accuracy
        n_epochs_no_improvement = 0
    else:
        n_epochs_no_improvement += 1
        print(f"The model does not improve for {n_epochs_no_improvement} epochs!")

    if n_epochs_no_improvement > patience:
        print(f"====>Stopping training, the model did not improve for {n_epochs_no_improvement}\n====>Best epoch: {best_epoch + 1}.")
        break
    scheduler.step(total_eval_loss)
print("")
print("Training complete!")
# Out:
# ======== Epoch 1 / 30 ========
# Training...
#   Batch    40  of    943.    .
#   step loss: 2.91
#   Batch    80  of    943.    .
#   step loss: 2.29
#   Batch   120  of    943.    .
#   step loss: 1.77
#   Batch   160  of    943.    .
#   step loss: 1.38
#   Batch   200  of    943.    .
#   step loss: 1.12
#   Batch   240  of    943.    .
#   step loss: 1.01
#   Batch   280  of    943.    .
#   step loss: 0.98
#   Batch   320  of    943.    .
#   step loss: 0.74
#   Batch   360  of    943.    .
#   step loss: 0.72
#   Batch   400  of    943.    .
#   step loss: 0.68
#   Batch   440  of    943.    .
#   step loss: 0.61
#   Batch   480  of    943.    .
#   step loss: 0.54
#   Batch   520  of    943.    .
#   step loss: 0.58
#   Batch   560  of    943.    .
#   step loss: 0.52
#   Batch   600  of    943.    .
#   step loss: 0.53
#   Batch   640  of    943.    .
#   step loss: 0.56
#   Batch   680  of    943.    .
#   step loss: 0.56
#   Batch   720  of    943.    .
#   step loss: 0.44
#   Batch   760  of    943.    .
#   step loss: 0.44
#   Batch   800  of    943.    .
#   step loss: 0.42
#   Batch   840  of    943.    .
#   step loss: 0.46
#   Batch   880  of    943.    .
#   step loss: 0.37
#   Batch   920  of    943.    .
#   step loss: 0.44
#
#   Average training loss: 0.95
#
# Running Validation...
# Batch accuracy: 89.06
# Batch accuracy: 90.62
# Batch accuracy: 90.04
# Batch accuracy: 88.67
# Batch accuracy: 87.70
# Batch accuracy: 86.91
# Batch accuracy: 87.50
# Batch accuracy: 88.48
# Batch accuracy: 91.02
# Batch accuracy: 89.26
# Batch accuracy: 86.91
# Batch accuracy: 91.02
# Batch accuracy: 91.41
# Batch accuracy: 89.65
# Batch accuracy: 85.94
# Batch accuracy: 89.84
# Batch accuracy: 90.62
# Batch accuracy: 86.72
# Batch accuracy: 86.72
# Batch accuracy: 87.11
# Batch accuracy: 88.67
# Batch accuracy: 87.89
# Batch accuracy: 89.06
# Batch accuracy: 89.84
# Batch accuracy: 90.04
# Batch accuracy: 92.19
# Batch accuracy: 90.23
# Batch accuracy: 89.06
# Batch accuracy: 88.48
# Batch accuracy: 88.28
# Batch accuracy: 88.48
# Batch accuracy: 89.45
# Batch accuracy: 88.09
# Batch accuracy: 89.84
# Batch accuracy: 90.82
# Batch accuracy: 92.77
# Batch accuracy: 90.43
# Batch accuracy: 90.04
# Batch accuracy: 88.28
# Batch accuracy: 89.84
# Batch accuracy: 89.26
# Batch accuracy: 89.06
# Batch accuracy: 89.65
# Batch accuracy: 89.65
# Batch accuracy: 88.09
# Batch accuracy: 89.65
# Batch accuracy: 90.62
# Batch accuracy: 88.09
# Batch accuracy: 90.43
# Batch accuracy: 89.45
# Batch accuracy: 89.06
# Batch accuracy: 90.23
# Batch accuracy: 89.45
# Batch accuracy: 90.23
# Batch accuracy: 88.87
# Batch accuracy: 89.45
# Batch accuracy: 89.06
# Batch accuracy: 88.09
# Batch accuracy: 87.50
# Batch accuracy: 89.26
# Batch accuracy: 88.48
# Batch accuracy: 89.26
# Batch accuracy: 88.67
# Batch accuracy: 90.82
# Batch accuracy: 86.91
# Batch accuracy: 89.65
# Batch accuracy: 88.87
# Batch accuracy: 91.80
# Batch accuracy: 89.45
# Batch accuracy: 88.67
# Batch accuracy: 90.04
# Batch accuracy: 89.84
# Batch accuracy: 89.26
# Batch accuracy: 91.02
# Batch accuracy: 90.62
# Batch accuracy: 89.84
# Batch accuracy: 89.26
# Batch accuracy: 89.06
# Batch accuracy: 86.33
# Batch accuracy: 89.84
# Batch accuracy: 89.65
# Batch accuracy: 91.80
# Batch accuracy: 86.91
# Batch accuracy: 90.04
# Batch accuracy: 88.87
# Batch accuracy: 89.84
# Batch accuracy: 87.50
# Batch accuracy: 89.45
# Batch accuracy: 87.11
# Batch accuracy: 89.06
# Batch accuracy: 90.04
# Batch accuracy: 88.67
# Batch accuracy: 88.67
# Batch accuracy: 90.04
# Batch accuracy: 89.26
# Batch accuracy: 88.09
# Batch accuracy: 87.50
# Batch accuracy: 90.62
# Batch accuracy: 92.19
# Batch accuracy: 90.43
# Batch accuracy: 88.87
# Batch accuracy: 87.50
# Batch accuracy: 90.43
# Batch accuracy: 90.23
# Batch accuracy: 89.05
#   Accuracy: 89.25
# New best model, saving it!
#
# ======== Epoch 2 / 30 ========
# Training...
#   Batch    40  of    943.    .
#   step loss: 0.37
#   Batch    80  of    943.    .
#   step loss: 0.29
#   Batch   120  of    943.    .
#   step loss: 0.35
#   Batch   160  of    943.    .
#   step loss: 0.39
#   Batch   200  of    943.    .
#   step loss: 0.35
#   Batch   240  of    943.    .
#   step loss: 0.26
#   Batch   280  of    943.    .
#   step loss: 0.33
#   Batch   320  of    943.    .
#   step loss: 0.32
#   Batch   360  of    943.    .
#   step loss: 0.34
#   Batch   400  of    943.    .
#   step loss: 0.34
#   Batch   440  of    943.    .
#   step loss: 0.32
#   Batch   480  of    943.    .
#   step loss: 0.34
#   Batch   520  of    943.    .
#   step loss: 0.24
#   Batch   560  of    943.    .
#   step loss: 0.38
#   Batch   600  of    943.    .
#   step loss: 0.30
#   Batch   640  of    943.    .
#   step loss: 0.27
#   Batch   680  of    943.    .
#   step loss: 0.25
#   Batch   720  of    943.    .
#   step loss: 0.24
#   Batch   760  of    943.    .
#   step loss: 0.32
#   Batch   800  of    943.    .
#   step loss: 0.32
#   Batch   840  of    943.    .
#   step loss: 0.22
#   Batch   880  of    943.    .
#   step loss: 0.28
#   Batch   920  of    943.    .
#   step loss: 0.22
#
#   Average training loss: 0.32
#
# Running Validation...
# Batch accuracy: 91.60
# Batch accuracy: 91.99
# Batch accuracy: 91.02
# Batch accuracy: 91.60
# Batch accuracy: 91.41
# Batch accuracy: 91.21
# Batch accuracy: 90.43
# Batch accuracy: 92.58
# Batch accuracy: 94.34
# Batch accuracy: 90.23
# Batch accuracy: 91.21
# Batch accuracy: 91.21
# Batch accuracy: 91.02
# Batch accuracy: 88.67
# Batch accuracy: 89.06
# Batch accuracy: 91.41
# Batch accuracy: 91.80
# Batch accuracy: 90.82
# Batch accuracy: 91.21
# Batch accuracy: 90.04
# Batch accuracy: 91.80
# Batch accuracy: 89.65
# Batch accuracy: 93.95
# Batch accuracy: 90.04
# Batch accuracy: 91.41
# Batch accuracy: 91.60
# Batch accuracy: 91.41
# Batch accuracy: 91.80
# Batch accuracy: 92.77
# Batch accuracy: 91.80
# Batch accuracy: 91.41
# Batch accuracy: 90.23
# Batch accuracy: 92.77
# Batch accuracy: 91.21
# Batch accuracy: 91.02
# Batch accuracy: 92.77
# Batch accuracy: 91.21
# Batch accuracy: 91.02
# Batch accuracy: 94.34
# Batch accuracy: 93.55
# Batch accuracy: 91.41
# Batch accuracy: 93.75
# Batch accuracy: 92.77
# Batch accuracy: 90.62
# Batch accuracy: 89.65
# Batch accuracy: 91.80
# Batch accuracy: 92.38
# Batch accuracy: 91.99
# Batch accuracy: 90.43
# Batch accuracy: 92.19
# Batch accuracy: 89.65
# Batch accuracy: 92.77
# Batch accuracy: 91.99
# Batch accuracy: 92.58
# Batch accuracy: 92.38
# Batch accuracy: 91.80
# Batch accuracy: 92.97
# Batch accuracy: 90.04
# Batch accuracy: 92.77
# Batch accuracy: 91.80
# Batch accuracy: 95.12
# Batch accuracy: 91.02
# Batch accuracy: 90.62
# Batch accuracy: 93.16
# Batch accuracy: 93.16
# Batch accuracy: 91.99
# Batch accuracy: 92.58
# Batch accuracy: 91.41
# Batch accuracy: 91.41
# Batch accuracy: 91.41
# Batch accuracy: 91.80
# Batch accuracy: 91.80
# Batch accuracy: 92.38
# Batch accuracy: 91.02
# Batch accuracy: 91.99
# Batch accuracy: 90.43
# Batch accuracy: 92.19
# Batch accuracy: 92.19
# Batch accuracy: 91.41
# Batch accuracy: 91.02
# Batch accuracy: 90.82
# Batch accuracy: 90.04
# Batch accuracy: 90.62
# Batch accuracy: 92.38
# Batch accuracy: 91.41
# Batch accuracy: 91.80
# Batch accuracy: 90.04
# Batch accuracy: 91.99
# Batch accuracy: 90.62
# Batch accuracy: 91.41
# Batch accuracy: 93.55
# Batch accuracy: 91.02
# Batch accuracy: 92.97
# Batch accuracy: 91.21
# Batch accuracy: 93.16
# Batch accuracy: 91.80
# Batch accuracy: 92.77
# Batch accuracy: 92.38
# Batch accuracy: 91.60
# Batch accuracy: 90.82
# Batch accuracy: 91.41
# Batch accuracy: 91.02
# Batch accuracy: 93.95
# Batch accuracy: 92.38
# Batch accuracy: 91.93
#   Accuracy: 91.67
# New best model, saving it!
#
# ======== Epoch 3 / 30 ========
# Training...
#   Batch    40  of    943.    .
#   step loss: 0.23
#   Batch    80  of    943.    .
#   step loss: 0.21
#   Batch   120  of    943.    .
#   step loss: 0.26
#   Batch   160  of    943.    .
#   step loss: 0.29
#   Batch   200  of    943.    .
#   step loss: 0.31
#   Batch   240  of    943.    .
#   step loss: 0.22
#   Batch   280  of    943.    .
#   step loss: 0.26
#   Batch   320  of    943.    .
#   step loss: 0.20
#   Batch   360  of    943.    .
#   step loss: 0.30
#   Batch   400  of    943.    .
#   step loss: 0.26
#   Batch   440  of    943.    .
#   step loss: 0.28
#   Batch   480  of    943.    .
#   step loss: 0.18
#   Batch   520  of    943.    .
#   step loss: 0.22
#   Batch   560  of    943.    .
#   step loss: 0.23
#   Batch   600  of    943.    .
#   step loss: 0.21
#   Batch   640  of    943.    .
#   step loss: 0.19
#   Batch   680  of    943.    .
#   step loss: 0.18
#   Batch   720  of    943.    .
#   step loss: 0.17
#   Batch   760  of    943.    .
#   step loss: 0.24
#   Batch   800  of    943.    .
#   step loss: 0.19
#   Batch   840  of    943.    .
#   step loss: 0.25
#   Batch   880  of    943.    .
#   step loss: 0.24
#   Batch   920  of    943.    .
#   step loss: 0.17
#
#   Average training loss: 0.23
#
# Running Validation...
# Batch accuracy: 93.55
# Batch accuracy: 92.38
# Batch accuracy: 93.36
# Batch accuracy: 91.60
# Batch accuracy: 91.80
# Batch accuracy: 93.16
# Batch accuracy: 92.38
# Batch accuracy: 91.80
# Batch accuracy: 91.60
# Batch accuracy: 91.99
# Batch accuracy: 92.58
# Batch accuracy: 92.97
# Batch accuracy: 91.60
# Batch accuracy: 93.16
# Batch accuracy: 93.75
# Batch accuracy: 92.77
# Batch accuracy: 92.38
# Batch accuracy: 91.41
# Batch accuracy: 93.36
# Batch accuracy: 93.16
# Batch accuracy: 93.36
# Batch accuracy: 93.36
# Batch accuracy: 92.77
# Batch accuracy: 94.34
# Batch accuracy: 93.95
# Batch accuracy: 91.80
# Batch accuracy: 90.23
# Batch accuracy: 92.58
# Batch accuracy: 93.55
# Batch accuracy: 92.97
# Batch accuracy: 93.95
# Batch accuracy: 93.75
# Batch accuracy: 93.55
# Batch accuracy: 91.21
# Batch accuracy: 91.99
# Batch accuracy: 92.58
# Batch accuracy: 94.14
# Batch accuracy: 92.77
# Batch accuracy: 93.95
# Batch accuracy: 93.55
# Batch accuracy: 93.55
# Batch accuracy: 92.58
# Batch accuracy: 92.19
# Batch accuracy: 94.34
# Batch accuracy: 94.53
# Batch accuracy: 93.55
# Batch accuracy: 93.36
# Batch accuracy: 91.02
# Batch accuracy: 94.73
# Batch accuracy: 90.82
# Batch accuracy: 91.99
# Batch accuracy: 92.58
# Batch accuracy: 93.95
# Batch accuracy: 92.77
# Batch accuracy: 93.95
# Batch accuracy: 92.97
# Batch accuracy: 93.75
# Batch accuracy: 91.41
# Batch accuracy: 93.55
# Batch accuracy: 92.97
# Batch accuracy: 91.60
# Batch accuracy: 94.73
# Batch accuracy: 91.41
# Batch accuracy: 91.80
# Batch accuracy: 92.58
# Batch accuracy: 93.16
# Batch accuracy: 92.58
# Batch accuracy: 91.60
# Batch accuracy: 94.14
# Batch accuracy: 90.23
# Batch accuracy: 93.55
# Batch accuracy: 91.99
# Batch accuracy: 90.43
# Batch accuracy: 93.36
# Batch accuracy: 93.16
# Batch accuracy: 90.43
# Batch accuracy: 93.75
# Batch accuracy: 93.75
# Batch accuracy: 92.58
# Batch accuracy: 90.82
# Batch accuracy: 91.80
# Batch accuracy: 91.80
# Batch accuracy: 93.55
# Batch accuracy: 93.75
# Batch accuracy: 90.23
# Batch accuracy: 92.38
# Batch accuracy: 92.97
# Batch accuracy: 92.97
# Batch accuracy: 93.55
# Batch accuracy: 93.55
# Batch accuracy: 93.55
# Batch accuracy: 93.36
# Batch accuracy: 92.58
# Batch accuracy: 93.16
# Batch accuracy: 91.99
# Batch accuracy: 93.95
# Batch accuracy: 91.99
# Batch accuracy: 93.16
# Batch accuracy: 92.97
# Batch accuracy: 91.21
# Batch accuracy: 91.21
# Batch accuracy: 92.77
# Batch accuracy: 91.41
# Batch accuracy: 93.75
# Batch accuracy: 91.93
#   Accuracy: 92.71
# New best model, saving it!
#
# ======== Epoch 4 / 30 ========
# Training...
#   Batch    40  of    943.    .
#   step loss: 0.14
#   Batch    80  of    943.    .
#   step loss: 0.16
#   Batch   120  of    943.    .
#   step loss: 0.16
#   Batch   160  of    943.    .
#   step loss: 0.25
#   Batch   200  of    943.    .
#   step loss: 0.18
#   Batch   240  of    943.    .
#   step loss: 0.19
#   Batch   280  of    943.    .
#   step loss: 0.21
#   Batch   320  of    943.    .
#   step loss: 0.18
#   Batch   360  of    943.    .
#   step loss: 0.13
#   Batch   400  of    943.    .
#   step loss: 0.14
#   Batch   440  of    943.    .
#   step loss: 0.22
#   Batch   480  of    943.    .
#   step loss: 0.14
#   Batch   520  of    943.    .
#   step loss: 0.19
#   Batch   560  of    943.    .
#   step loss: 0.20
#   Batch   600  of    943.    .
#   step loss: 0.18
#   Batch   640  of    943.    .
#   step loss: 0.17
#   Batch   680  of    943.    .
#   step loss: 0.13
#   Batch   720  of    943.    .
#   step loss: 0.14
#   Batch   760  of    943.    .
#   step loss: 0.15
#   Batch   800  of    943.    .
#   step loss: 0.21
#   Batch   840  of    943.    .
#   step loss: 0.15
#   Batch   880  of    943.    .
#   step loss: 0.13
#   Batch   920  of    943.    .
#   step loss: 0.23
#
#   Average training loss: 0.18
#
# Running Validation...
# Batch accuracy: 95.31
# Batch accuracy: 91.02
# Batch accuracy: 94.53
# Batch accuracy: 93.75
# Batch accuracy: 93.55
# Batch accuracy: 95.90
# Batch accuracy: 92.97
# Batch accuracy: 92.19
# Batch accuracy: 93.16
# Batch accuracy: 93.36
# Batch accuracy: 92.97
# Batch accuracy: 93.16
# Batch accuracy: 93.16
# Batch accuracy: 92.58
# Batch accuracy: 93.95
# Batch accuracy: 91.99
# Batch accuracy: 91.21
# Batch accuracy: 94.73
# Batch accuracy: 93.16
# Batch accuracy: 92.97
# Batch accuracy: 91.02
# Batch accuracy: 92.19
# Batch accuracy: 94.53
# Batch accuracy: 91.21
# Batch accuracy: 92.58
# Batch accuracy: 91.41
# Batch accuracy: 93.95
# Batch accuracy: 92.38
# Batch accuracy: 94.34
# Batch accuracy: 94.53
# Batch accuracy: 94.14
# Batch accuracy: 92.38
# Batch accuracy: 92.19
# Batch accuracy: 94.34
# Batch accuracy: 94.34
# Batch accuracy: 92.77
# Batch accuracy: 95.12
# Batch accuracy: 92.19
# Batch accuracy: 93.36
# Batch accuracy: 95.31
# Batch accuracy: 94.53
# Batch accuracy: 92.77
# Batch accuracy: 92.19
# Batch accuracy: 92.58
# Batch accuracy: 92.97
# Batch accuracy: 94.34
# Batch accuracy: 91.21
# Batch accuracy: 92.19
# Batch accuracy: 94.14
# Batch accuracy: 93.55
# Batch accuracy: 92.97
# Batch accuracy: 93.75
# Batch accuracy: 93.75
# Batch accuracy: 93.36
# Batch accuracy: 94.73
# Batch accuracy: 93.55
# Batch accuracy: 92.77
# Batch accuracy: 95.12
# Batch accuracy: 93.75
# Batch accuracy: 90.82
# Batch accuracy: 94.53
# Batch accuracy: 92.38
# Batch accuracy: 94.92
# Batch accuracy: 92.77
# Batch accuracy: 93.55
# Batch accuracy: 92.77
# Batch accuracy: 94.14
# Batch accuracy: 91.99
# Batch accuracy: 91.80
# Batch accuracy: 92.38
# Batch accuracy: 94.73
# Batch accuracy: 94.92
# Batch accuracy: 93.75
# Batch accuracy: 91.41
# Batch accuracy: 94.34
# Batch accuracy: 92.97
# Batch accuracy: 93.16
# Batch accuracy: 93.55
# Batch accuracy: 93.16
# Batch accuracy: 93.16
# Batch accuracy: 94.14
# Batch accuracy: 93.36
# Batch accuracy: 92.38
# Batch accuracy: 91.99
# Batch accuracy: 94.34
# Batch accuracy: 93.36
# Batch accuracy: 93.36
# Batch accuracy: 93.55
# Batch accuracy: 93.55
# Batch accuracy: 94.34
# Batch accuracy: 93.75
# Batch accuracy: 93.36
# Batch accuracy: 92.38
# Batch accuracy: 92.58
# Batch accuracy: 95.12
# Batch accuracy: 92.19
# Batch accuracy: 92.38
# Batch accuracy: 93.55
# Batch accuracy: 94.14
# Batch accuracy: 93.75
# Batch accuracy: 92.77
# Batch accuracy: 92.77
# Batch accuracy: 94.14
# Batch accuracy: 93.16
# Batch accuracy: 92.51
#   Accuracy: 93.28
# New best model, saving it!
#
# ======== Epoch 5 / 30 ========
# Training...
#   Batch    40  of    943.    .
#   step loss: 0.15
#   Batch    80  of    943.    .
#   step loss: 0.15
#   Batch   120  of    943.    .
#   step loss: 0.12
#   Batch   160  of    943.    .
#   step loss: 0.14
#   Batch   200  of    943.    .
#   step loss: 0.14
#   Batch   240  of    943.    .
#   step loss: 0.12
#   Batch   280  of    943.    .
#   step loss: 0.07
#   Batch   320  of    943.    .
#   step loss: 0.15
#   Batch   360  of    943.    .
#   step loss: 0.08
#   Batch   400  of    943.    .
#   step loss: 0.19
#   Batch   440  of    943.    .
#   step loss: 0.15
#   Batch   480  of    943.    .
#   step loss: 0.15
#   Batch   520  of    943.    .
#   step loss: 0.12
#   Batch   560  of    943.    .
#   step loss: 0.18
#   Batch   600  of    943.    .
#   step loss: 0.21
#   Batch   640  of    943.    .
#   step loss: 0.11
#   Batch   680  of    943.    .
#   step loss: 0.13
#   Batch   720  of    943.    .
#   step loss: 0.10
#   Batch   760  of    943.    .
#   step loss: 0.18
#   Batch   800  of    943.    .
#   step loss: 0.18
#   Batch   840  of    943.    .
#   step loss: 0.11
#   Batch   880  of    943.    .
#   step loss: 0.14
#   Batch   920  of    943.    .
#   step loss: 0.17
#
#   Average training loss: 0.14
#
# Running Validation...
# Batch accuracy: 93.95
# Batch accuracy: 92.58
# Batch accuracy: 94.92
# Batch accuracy: 94.73
# Batch accuracy: 93.75
# Batch accuracy: 92.77
# Batch accuracy: 93.75
# Batch accuracy: 92.97
# Batch accuracy: 92.77
# Batch accuracy: 91.21
# Batch accuracy: 92.38
# Batch accuracy: 94.53
# Batch accuracy: 94.14
# Batch accuracy: 93.36
# Batch accuracy: 93.75
# Batch accuracy: 94.34
# Batch accuracy: 94.73
# Batch accuracy: 94.53
# Batch accuracy: 95.12
# Batch accuracy: 91.60
# Batch accuracy: 91.99
# Batch accuracy: 92.97
# Batch accuracy: 92.97
# Batch accuracy: 93.36
# Batch accuracy: 93.16
# Batch accuracy: 95.12
# Batch accuracy: 92.19
# Batch accuracy: 93.95
# Batch accuracy: 92.58
# Batch accuracy: 92.97
# Batch accuracy: 92.58
# Batch accuracy: 93.36
# Batch accuracy: 93.95
# Batch accuracy: 92.58
# Batch accuracy: 92.19
# Batch accuracy: 91.80
# Batch accuracy: 94.14
# Batch accuracy: 94.34
# Batch accuracy: 92.77
# Batch accuracy: 94.14
# Batch accuracy: 92.77
# Batch accuracy: 94.73
# Batch accuracy: 93.75
# Batch accuracy: 92.77
# Batch accuracy: 93.36
# Batch accuracy: 95.90
# Batch accuracy: 92.97
# Batch accuracy: 91.41
# Batch accuracy: 93.75
# Batch accuracy: 94.14
# Batch accuracy: 93.95
# Batch accuracy: 93.95
# Batch accuracy: 92.38
# Batch accuracy: 93.36
# Batch accuracy: 93.36
# Batch accuracy: 92.97
# Batch accuracy: 92.58
# Batch accuracy: 93.75
# Batch accuracy: 94.14
# Batch accuracy: 92.19
# Batch accuracy: 92.58
# Batch accuracy: 91.80
# Batch accuracy: 92.97
# Batch accuracy: 93.95
# Batch accuracy: 94.34
# Batch accuracy: 93.75
# Batch accuracy: 91.41
# Batch accuracy: 94.53
# Batch accuracy: 92.58
# Batch accuracy: 93.75
# Batch accuracy: 92.58
# Batch accuracy: 92.38
# Batch accuracy: 92.97
# Batch accuracy: 91.02
# Batch accuracy: 93.55
# Batch accuracy: 92.19
# Batch accuracy: 93.95
# Batch accuracy: 93.36
# Batch accuracy: 95.31
# Batch accuracy: 94.14
# Batch accuracy: 91.80
# Batch accuracy: 93.75
# Batch accuracy: 94.53
# Batch accuracy: 91.21
# Batch accuracy: 94.92
# Batch accuracy: 93.55
# Batch accuracy: 91.41
# Batch accuracy: 93.55
# Batch accuracy: 93.16
# Batch accuracy: 94.14
# Batch accuracy: 94.34
# Batch accuracy: 94.34
# Batch accuracy: 94.53
# Batch accuracy: 91.41
# Batch accuracy: 91.02
# Batch accuracy: 92.58
# Batch accuracy: 93.95
# Batch accuracy: 94.14
# Batch accuracy: 94.14
# Batch accuracy: 91.02
# Batch accuracy: 94.73
# Batch accuracy: 93.75
# Batch accuracy: 92.97
# Batch accuracy: 92.77
# Batch accuracy: 95.97
#   Accuracy: 93.33
# New best model, saving it!
#
# ======== Epoch 6 / 30 ========
# Training...
#   Batch    40  of    943.    .
#   step loss: 0.12
#   Batch    80  of    943.    .
#   step loss: 0.09
#   Batch   120  of    943.    .
#   step loss: 0.11
#   Batch   160  of    943.    .
#   step loss: 0.11
#   Batch   200  of    943.    .
#   step loss: 0.07
#   Batch   240  of    943.    .
#   step loss: 0.12
#   Batch   280  of    943.    .
#   step loss: 0.12
#   Batch   320  of    943.    .
#   step loss: 0.15
#   Batch   360  of    943.    .
#   step loss: 0.16
#   Batch   400  of    943.    .
#   step loss: 0.12
#   Batch   440  of    943.    .
#   step loss: 0.11
#   Batch   480  of    943.    .
#   step loss: 0.14
#   Batch   520  of    943.    .
#   step loss: 0.10
#   Batch   560  of    943.    .
#   step loss: 0.13
#   Batch   600  of    943.    .
#   step loss: 0.11
#   Batch   640  of    943.    .
#   step loss: 0.16
#   Batch   680  of    943.    .
#   step loss: 0.14
#   Batch   720  of    943.    .
#   step loss: 0.11
#   Batch   760  of    943.    .
#   step loss: 0.10
#   Batch   800  of    943.    .
#   step loss: 0.12
#   Batch   840  of    943.    .
#   step loss: 0.10
#   Batch   880  of    943.    .
#   step loss: 0.10
#   Batch   920  of    943.    .
#   step loss: 0.11
#
#   Average training loss: 0.11
#
# Running Validation...
# Batch accuracy: 95.51
# Batch accuracy: 93.75
# Batch accuracy: 93.55
# Batch accuracy: 93.16
# Batch accuracy: 94.92
# Batch accuracy: 93.55
# Batch accuracy: 93.95
# Batch accuracy: 95.12
# Batch accuracy: 94.34
# Batch accuracy: 94.73
# Batch accuracy: 93.36
# Batch accuracy: 92.97
# Batch accuracy: 92.58
# Batch accuracy: 94.34
# Batch accuracy: 92.77
# Batch accuracy: 91.02
# Batch accuracy: 92.58
# Batch accuracy: 95.12
# Batch accuracy: 95.51
# Batch accuracy: 93.36
# Batch accuracy: 96.09
# Batch accuracy: 93.75
# Batch accuracy: 94.14
# Batch accuracy: 93.36
# Batch accuracy: 92.77
# Batch accuracy: 92.77
# Batch accuracy: 94.92
# Batch accuracy: 91.41
# Batch accuracy: 93.95
# Batch accuracy: 93.75
# Batch accuracy: 93.16
# Batch accuracy: 90.62
# Batch accuracy: 93.36
# Batch accuracy: 94.34
# Batch accuracy: 93.75
# Batch accuracy: 94.34
# Batch accuracy: 92.58
# Batch accuracy: 94.73
# Batch accuracy: 94.14
# Batch accuracy: 94.14
# Batch accuracy: 94.14
# Batch accuracy: 91.80
# Batch accuracy: 93.55
# Batch accuracy: 92.97
# Batch accuracy: 94.92
# Batch accuracy: 92.38
# Batch accuracy: 92.38
# Batch accuracy: 93.36
# Batch accuracy: 92.58
# Batch accuracy: 94.73
# Batch accuracy: 91.80
# Batch accuracy: 93.55
# Batch accuracy: 93.55
# Batch accuracy: 92.77
# Batch accuracy: 92.38
# Batch accuracy: 92.97
# Batch accuracy: 93.95
# Batch accuracy: 93.36
# Batch accuracy: 92.38
# Batch accuracy: 94.34
# Batch accuracy: 94.73
# Batch accuracy: 92.58
# Batch accuracy: 92.38
# Batch accuracy: 93.16
# Batch accuracy: 93.36
# Batch accuracy: 93.75
# Batch accuracy: 93.95
# Batch accuracy: 93.95
# Batch accuracy: 94.92
# Batch accuracy: 92.97
# Batch accuracy: 95.31
# Batch accuracy: 94.92
# Batch accuracy: 94.14
# Batch accuracy: 92.38
# Batch accuracy: 93.55
# Batch accuracy: 94.53
# Batch accuracy: 92.38
# Batch accuracy: 94.34
# Batch accuracy: 93.16
# Batch accuracy: 93.55
# Batch accuracy: 94.92
# Batch accuracy: 94.34
# Batch accuracy: 93.16
# Batch accuracy: 93.95
# Batch accuracy: 92.97
# Batch accuracy: 93.95
# Batch accuracy: 94.14
# Batch accuracy: 93.95
# Batch accuracy: 94.73
# Batch accuracy: 92.19
# Batch accuracy: 92.77
# Batch accuracy: 92.19
# Batch accuracy: 94.14
# Batch accuracy: 93.16
# Batch accuracy: 95.12
# Batch accuracy: 93.75
# Batch accuracy: 93.95
# Batch accuracy: 93.36
# Batch accuracy: 95.51
# Batch accuracy: 91.99
# Batch accuracy: 93.16
# Batch accuracy: 93.95
# Batch accuracy: 93.55
# Batch accuracy: 93.75
# Batch accuracy: 89.91
#   Accuracy: 93.57
# New best model, saving it!
#
# ======== Epoch 7 / 30 ========
# Training...
#   Batch    40  of    943.    .
#   step loss: 0.11
#   Batch    80  of    943.    .
#   step loss: 0.07
#   Batch   120  of    943.    .
#   step loss: 0.12
#   Batch   160  of    943.    .
#   step loss: 0.13
#   Batch   200  of    943.    .
#   step loss: 0.09
#   Batch   240  of    943.    .
#   step loss: 0.07
#   Batch   280  of    943.    .
#   step loss: 0.10
#   Batch   320  of    943.    .
#   step loss: 0.09
#   Batch   360  of    943.    .
#   step loss: 0.11
#   Batch   400  of    943.    .
#   step loss: 0.07
#   Batch   440  of    943.    .
#   step loss: 0.08
#   Batch   480  of    943.    .
#   step loss: 0.06
#   Batch   520  of    943.    .
#   step loss: 0.08
#   Batch   560  of    943.    .
#   step loss: 0.81
#   Batch   600  of    943.    .
#   step loss: 0.12
#   Batch   640  of    943.    .
#   step loss: 0.08
#   Batch   680  of    943.    .
#   step loss: 0.08
#   Batch   720  of    943.    .
#   step loss: 0.09
#   Batch   760  of    943.    .
#   step loss: 0.09
#   Batch   800  of    943.    .
#   step loss: 0.15
#   Batch   840  of    943.    .
#   step loss: 0.11
#   Batch   880  of    943.    .
#   step loss: 0.09
#   Batch   920  of    943.    .
#   step loss: 0.14
#
#   Average training loss: 0.09
#
# Running Validation...
# Batch accuracy: 93.95
# Batch accuracy: 94.73
# Batch accuracy: 94.73
# Batch accuracy: 93.95
# Batch accuracy: 93.36
# Batch accuracy: 94.92
# Batch accuracy: 95.51
# Batch accuracy: 94.34
# Batch accuracy: 93.16
# Batch accuracy: 90.82
# Batch accuracy: 94.53
# Batch accuracy: 93.95
# Batch accuracy: 94.14
# Batch accuracy: 94.34
# Batch accuracy: 93.55
# Batch accuracy: 93.36
# Batch accuracy: 92.19
# Batch accuracy: 92.38
# Batch accuracy: 91.60
# Batch accuracy: 94.92
# Batch accuracy: 95.31
# Batch accuracy: 95.70
# Batch accuracy: 94.73
# Batch accuracy: 93.36
# Batch accuracy: 94.73
# Batch accuracy: 92.58
# Batch accuracy: 93.36
# Batch accuracy: 92.77
# Batch accuracy: 91.99
# Batch accuracy: 93.16
# Batch accuracy: 94.14
# Batch accuracy: 93.36
# Batch accuracy: 91.02
# Batch accuracy: 92.58
# Batch accuracy: 93.55
# Batch accuracy: 94.73
# Batch accuracy: 94.34
# Batch accuracy: 92.77
# Batch accuracy: 93.36
# Batch accuracy: 91.02
# Batch accuracy: 95.51
# Batch accuracy: 93.16
# Batch accuracy: 92.58
# Batch accuracy: 90.23
# Batch accuracy: 94.53
# Batch accuracy: 93.55
# Batch accuracy: 92.97
# Batch accuracy: 94.34
# Batch accuracy: 92.97
# Batch accuracy: 92.97
# Batch accuracy: 94.14
# Batch accuracy: 93.75
# Batch accuracy: 93.75
# Batch accuracy: 90.82
# Batch accuracy: 92.38
# Batch accuracy: 93.75
# Batch accuracy: 92.58
# Batch accuracy: 95.31
# Batch accuracy: 94.92
# Batch accuracy: 93.95
# Batch accuracy: 94.14
# Batch accuracy: 92.77
# Batch accuracy: 94.73
# Batch accuracy: 93.75
# Batch accuracy: 94.14
# Batch accuracy: 93.75
# Batch accuracy: 95.12
# Batch accuracy: 93.95
# Batch accuracy: 95.51
# Batch accuracy: 94.34
# Batch accuracy: 93.36
# Batch accuracy: 94.73
# Batch accuracy: 93.95
# Batch accuracy: 95.12
# Batch accuracy: 95.51
# Batch accuracy: 94.92
# Batch accuracy: 95.12
# Batch accuracy: 94.92
# Batch accuracy: 93.16
# Batch accuracy: 94.34
# Batch accuracy: 93.75
# Batch accuracy: 94.53
# Batch accuracy: 93.75
# Batch accuracy: 94.53
# Batch accuracy: 93.16
# Batch accuracy: 93.16
# Batch accuracy: 94.34
# Batch accuracy: 93.16
# Batch accuracy: 94.34
# Batch accuracy: 94.53
# Batch accuracy: 94.53
# Batch accuracy: 92.38
# Batch accuracy: 91.60
# Batch accuracy: 92.77
# Batch accuracy: 92.58
# Batch accuracy: 92.58
# Batch accuracy: 93.75
# Batch accuracy: 94.34
# Batch accuracy: 95.31
# Batch accuracy: 94.53
# Batch accuracy: 93.36
# Batch accuracy: 94.34
# Batch accuracy: 92.58
# Batch accuracy: 91.80
# Batch accuracy: 95.39
#   Accuracy: 93.71
# New best model, saving it!
#
# ======== Epoch 8 / 30 ========
# Training...
#   Batch    40  of    943.    .
#   step loss: 0.05
#   Batch    80  of    943.    .
#   step loss: 0.04
#   Batch   120  of    943.    .
#   step loss: 0.07
#   Batch   160  of    943.    .
#   step loss: 0.05
#   Batch   200  of    943.    .
#   step loss: 0.06
#   Batch   240  of    943.    .
#   step loss: 0.04
#   Batch   280  of    943.    .
#   step loss: 0.05
#   Batch   320  of    943.    .
#   step loss: 0.09
#   Batch   360  of    943.    .
#   step loss: 0.06
#   Batch   400  of    943.    .
#   step loss: 0.06
#   Batch   440  of    943.    .
#   step loss: 0.07
#   Batch   480  of    943.    .
#   step loss: 0.06
#   Batch   520  of    943.    .
#   step loss: 0.08
#   Batch   560  of    943.    .
#   step loss: 0.06
#   Batch   600  of    943.    .
#   step loss: 0.09
#   Batch   640  of    943.    .
#   step loss: 0.07
#   Batch   680  of    943.    .
#   step loss: 0.05
#   Batch   720  of    943.    .
#   step loss: 0.11
#   Batch   760  of    943.    .
#   step loss: 0.08
#   Batch   800  of    943.    .
#   step loss: 0.09
#   Batch   840  of    943.    .
#   step loss: 0.12
#   Batch   880  of    943.    .
#   step loss: 0.10
#   Batch   920  of    943.    .
#   step loss: 0.07
#
#   Average training loss: 0.07
#
# Running Validation...
# Batch accuracy: 94.73
# Batch accuracy: 91.02
# Batch accuracy: 94.34
# Batch accuracy: 94.34
# Batch accuracy: 93.36
# Batch accuracy: 93.55
# Batch accuracy: 94.53
# Batch accuracy: 94.34
# Batch accuracy: 93.75
# Batch accuracy: 93.36
# Batch accuracy: 94.34
# Batch accuracy: 93.95
# Batch accuracy: 94.14
# Batch accuracy: 94.92
# Batch accuracy: 93.36
# Batch accuracy: 93.55
# Batch accuracy: 94.92
# Batch accuracy: 93.55
# Batch accuracy: 93.55
# Batch accuracy: 94.14
# Batch accuracy: 93.75
# Batch accuracy: 94.14
# Batch accuracy: 95.12
# Batch accuracy: 94.34
# Batch accuracy: 95.12
# Batch accuracy: 91.99
# Batch accuracy: 93.75
# Batch accuracy: 93.95
# Batch accuracy: 93.75
# Batch accuracy: 92.97
# Batch accuracy: 92.38
# Batch accuracy: 93.95
# Batch accuracy: 93.95
# Batch accuracy: 94.73
# Batch accuracy: 93.36
# Batch accuracy: 91.80
# Batch accuracy: 93.95
# Batch accuracy: 91.99
# Batch accuracy: 95.70
# Batch accuracy: 94.53
# Batch accuracy: 92.77
# Batch accuracy: 92.97
# Batch accuracy: 93.95
# Batch accuracy: 92.19
# Batch accuracy: 95.31
# Batch accuracy: 93.75
# Batch accuracy: 95.31
# Batch accuracy: 93.55
# Batch accuracy: 95.70
# Batch accuracy: 93.95
# Batch accuracy: 92.77
# Batch accuracy: 93.75
# Batch accuracy: 95.12
# Batch accuracy: 94.53
# Batch accuracy: 93.36
# Batch accuracy: 94.92
# Batch accuracy: 93.75
# Batch accuracy: 93.75
# Batch accuracy: 92.97
# Batch accuracy: 94.14
# Batch accuracy: 93.75
# Batch accuracy: 93.16
# Batch accuracy: 94.53
# Batch accuracy: 94.34
# Batch accuracy: 91.41
# Batch accuracy: 94.73
# Batch accuracy: 94.53
# Batch accuracy: 92.97
# Batch accuracy: 94.73
# Batch accuracy: 93.55
# Batch accuracy: 94.92
# Batch accuracy: 94.14
# Batch accuracy: 93.16
# Batch accuracy: 92.58
# Batch accuracy: 95.90
# Batch accuracy: 93.16
# Batch accuracy: 93.55
# Batch accuracy: 94.73
# Batch accuracy: 94.92
# Batch accuracy: 92.19
# Batch accuracy: 92.58
# Batch accuracy: 93.55
# Batch accuracy: 92.38
# Batch accuracy: 94.92
# Batch accuracy: 93.16
# Batch accuracy: 93.36
# Batch accuracy: 93.95
# Batch accuracy: 93.16
# Batch accuracy: 95.51
# Batch accuracy: 93.95
# Batch accuracy: 94.14
# Batch accuracy: 92.38
# Batch accuracy: 92.97
# Batch accuracy: 93.95
# Batch accuracy: 93.55
# Batch accuracy: 94.14
# Batch accuracy: 93.75
# Batch accuracy: 94.73
# Batch accuracy: 92.38
# Batch accuracy: 93.36
# Batch accuracy: 94.34
# Batch accuracy: 94.14
# Batch accuracy: 94.34
# Batch accuracy: 92.38
# Batch accuracy: 92.51
#   Accuracy: 93.79
# New best model, saving it!
#
# ======== Epoch 9 / 30 ========
# Training...
#   Batch    40  of    943.    .
#   step loss: 0.06
#   Batch    80  of    943.    .
#   step loss: 0.04
#   Batch   120  of    943.    .
#   step loss: 0.04
#   Batch   160  of    943.    .
#   step loss: 0.04
#   Batch   200  of    943.    .
#   step loss: 0.07
#   Batch   240  of    943.    .
#   step loss: 0.08
#   Batch   280  of    943.    .
#   step loss: 0.04
#   Batch   320  of    943.    .
#   step loss: 0.05
#   Batch   360  of    943.    .
#   step loss: 0.04
#   Batch   400  of    943.    .
#   step loss: 0.05
#   Batch   440  of    943.    .
#   step loss: 0.05
#   Batch   480  of    943.    .
#   step loss: 0.07
#   Batch   520  of    943.    .
#   step loss: 0.06
#   Batch   560  of    943.    .
#   step loss: 0.08
#   Batch   600  of    943.    .
#   step loss: 0.08
#   Batch   640  of    943.    .
#   step loss: 0.04
#   Batch   680  of    943.    .
#   step loss: 0.10
#   Batch   720  of    943.    .
#   step loss: 0.04
#   Batch   760  of    943.    .
#   step loss: 0.06
#   Batch   800  of    943.    .
#   step loss: 0.07
#   Batch   840  of    943.    .
#   step loss: 0.06
#   Batch   880  of    943.    .
#   step loss: 0.07
#   Batch   920  of    943.    .
#   step loss: 0.03
#
#   Average training loss: 0.06
#
# Running Validation...
# Batch accuracy: 94.92
# Batch accuracy: 94.73
# Batch accuracy: 94.53
# Batch accuracy: 92.38
# Batch accuracy: 94.34
# Batch accuracy: 93.36
# Batch accuracy: 94.34
# Batch accuracy: 91.99
# Batch accuracy: 93.36
# Batch accuracy: 93.95
# Batch accuracy: 92.77
# Batch accuracy: 95.70
# Batch accuracy: 95.12
# Batch accuracy: 94.53
# Batch accuracy: 91.41
# Batch accuracy: 92.19
# Batch accuracy: 92.77
# Batch accuracy: 93.55
# Batch accuracy: 94.53
# Batch accuracy: 95.70
# Batch accuracy: 94.14
# Batch accuracy: 93.95
# Batch accuracy: 93.95
# Batch accuracy: 93.75
# Batch accuracy: 92.19
# Batch accuracy: 92.77
# Batch accuracy: 93.95
# Batch accuracy: 93.55
# Batch accuracy: 92.19
# Batch accuracy: 94.92
# Batch accuracy: 95.31
# Batch accuracy: 94.14
# Batch accuracy: 92.77
# Batch accuracy: 94.53
# Batch accuracy: 95.90
# Batch accuracy: 92.77
# Batch accuracy: 93.95
# Batch accuracy: 91.80
# Batch accuracy: 93.55
# Batch accuracy: 92.19
# Batch accuracy: 93.55
# Batch accuracy: 94.92
# Batch accuracy: 92.77
# Batch accuracy: 95.31
# Batch accuracy: 93.55
# Batch accuracy: 93.75
# Batch accuracy: 92.58
# Batch accuracy: 96.29
# Batch accuracy: 95.12
# Batch accuracy: 93.55
# Batch accuracy: 93.36
# Batch accuracy: 93.16
# Batch accuracy: 94.14
# Batch accuracy: 92.97
# Batch accuracy: 93.36
# Batch accuracy: 92.77
# Batch accuracy: 93.95
# Batch accuracy: 95.51
# Batch accuracy: 94.92
# Batch accuracy: 93.75
# Batch accuracy: 93.16
# Batch accuracy: 93.95
# Batch accuracy: 92.97
# Batch accuracy: 92.58
# Batch accuracy: 94.34
# Batch accuracy: 94.34
# Batch accuracy: 94.92
# Batch accuracy: 93.75
# Batch accuracy: 95.12
# Batch accuracy: 92.97
# Batch accuracy: 93.75
# Batch accuracy: 91.02
# Batch accuracy: 91.80
# Batch accuracy: 95.70
# Batch accuracy: 94.14
# Batch accuracy: 95.51
# Batch accuracy: 93.95
# Batch accuracy: 93.16
# Batch accuracy: 92.77
# Batch accuracy: 93.16
# Batch accuracy: 91.99
# Batch accuracy: 94.14
# Batch accuracy: 93.95
# Batch accuracy: 94.34
# Batch accuracy: 91.80
# Batch accuracy: 94.53
# Batch accuracy: 93.95
# Batch accuracy: 95.90
# Batch accuracy: 93.16
# Batch accuracy: 93.16
# Batch accuracy: 94.14
# Batch accuracy: 95.12
# Batch accuracy: 94.92
# Batch accuracy: 93.16
# Batch accuracy: 92.77
# Batch accuracy: 94.14
# Batch accuracy: 94.14
# Batch accuracy: 93.16
# Batch accuracy: 91.99
# Batch accuracy: 92.58
# Batch accuracy: 94.34
# Batch accuracy: 93.75
# Batch accuracy: 95.70
# Batch accuracy: 93.55
# Batch accuracy: 94.24
#   Accuracy: 93.77
# The model does not improve for 1 epochs!
#
# ======== Epoch 10 / 30 ========
# Training...
#   Batch    40  of    943.    .
#   step loss: 0.05
#   Batch    80  of    943.    .
#   step loss: 0.04
#   Batch   120  of    943.    .
#   step loss: 0.06
#   Batch   160  of    943.    .
#   step loss: 0.09
#   Batch   200  of    943.    .
#   step loss: 0.05
#   Batch   240  of    943.    .
#   step loss: 0.04
#   Batch   280  of    943.    .
#   step loss: 0.05
#   Batch   320  of    943.    .
#   step loss: 0.07
#   Batch   360  of    943.    .
#   step loss: 0.08
#   Batch   400  of    943.    .
#   step loss: 0.02
#   Batch   440  of    943.    .
#   step loss: 0.06
#   Batch   480  of    943.    .
#   step loss: 0.05
#   Batch   520  of    943.    .
#   step loss: 0.05
#   Batch   560  of    943.    .
#   step loss: 0.03
#   Batch   600  of    943.    .
#   step loss: 0.03
#   Batch   640  of    943.    .
#   step loss: 0.06
#   Batch   680  of    943.    .
#   step loss: 0.04
#   Batch   720  of    943.    .
#   step loss: 0.06
#   Batch   760  of    943.    .
#   step loss: 0.07
#   Batch   800  of    943.    .
#   step loss: 0.02
#   Batch   840  of    943.    .
#   step loss: 0.05
#   Batch   880  of    943.    .
#   step loss: 0.08
#   Batch   920  of    943.    .
#   step loss: 0.07
#
#   Average training loss: 0.05
#
# Running Validation...
# Batch accuracy: 93.75
# Batch accuracy: 91.21
# Batch accuracy: 93.36
# Batch accuracy: 93.55
# Batch accuracy: 93.55
# Batch accuracy: 94.53
# Batch accuracy: 94.73
# Batch accuracy: 94.53
# Batch accuracy: 93.55
# Batch accuracy: 94.73
# Batch accuracy: 94.34
# Batch accuracy: 94.34
# Batch accuracy: 94.73
# Batch accuracy: 94.14
# Batch accuracy: 94.34
# Batch accuracy: 92.97
# Batch accuracy: 94.34
# Batch accuracy: 93.55
# Batch accuracy: 94.53
# Batch accuracy: 90.82
# Batch accuracy: 94.73
# Batch accuracy: 92.77
# Batch accuracy: 95.51
# Batch accuracy: 94.53
# Batch accuracy: 95.12
# Batch accuracy: 92.77
# Batch accuracy: 94.53
# Batch accuracy: 93.16
# Batch accuracy: 95.12
# Batch accuracy: 94.14
# Batch accuracy: 94.53
# Batch accuracy: 94.34
# Batch accuracy: 94.92
# Batch accuracy: 93.75
# Batch accuracy: 92.77
# Batch accuracy: 93.55
# Batch accuracy: 92.58
# Batch accuracy: 93.95
# Batch accuracy: 93.55
# Batch accuracy: 93.16
# Batch accuracy: 94.92
# Batch accuracy: 90.82
# Batch accuracy: 95.70
# Batch accuracy: 93.55
# Batch accuracy: 94.92
# Batch accuracy: 92.97
# Batch accuracy: 92.97
# Batch accuracy: 90.23
# Batch accuracy: 94.34
# Batch accuracy: 95.31
# Batch accuracy: 92.58
# Batch accuracy: 93.55
# Batch accuracy: 94.34
# Batch accuracy: 94.53
# Batch accuracy: 94.73
# Batch accuracy: 94.14
# Batch accuracy: 95.51
# Batch accuracy: 94.92
# Batch accuracy: 92.38
# Batch accuracy: 94.34
# Batch accuracy: 92.19
# Batch accuracy: 93.36
# Batch accuracy: 94.14
# Batch accuracy: 95.12
# Batch accuracy: 93.55
# Batch accuracy: 95.70
# Batch accuracy: 96.48
# Batch accuracy: 93.55
# Batch accuracy: 93.95
# Batch accuracy: 94.73
# Batch accuracy: 94.92
# Batch accuracy: 93.55
# Batch accuracy: 90.23
# Batch accuracy: 95.90
# Batch accuracy: 94.92
# Batch accuracy: 92.97
# Batch accuracy: 95.51
# Batch accuracy: 94.34
# Batch accuracy: 93.55
# Batch accuracy: 92.97
# Batch accuracy: 93.16
# Batch accuracy: 93.55
# Batch accuracy: 94.53
# Batch accuracy: 93.95
# Batch accuracy: 92.58
# Batch accuracy: 93.36
# Batch accuracy: 93.16
# Batch accuracy: 93.16
# Batch accuracy: 93.36
# Batch accuracy: 94.53
# Batch accuracy: 93.36
# Batch accuracy: 94.73
# Batch accuracy: 92.38
# Batch accuracy: 93.95
# Batch accuracy: 95.12
# Batch accuracy: 93.75
# Batch accuracy: 93.95
# Batch accuracy: 93.36
# Batch accuracy: 92.58
# Batch accuracy: 95.90
# Batch accuracy: 94.73
# Batch accuracy: 93.36
# Batch accuracy: 95.12
# Batch accuracy: 94.34
# Batch accuracy: 92.80
#   Accuracy: 93.89
# New best model, saving it!
# Epoch    10: reducing learning rate of group 0 to 1.0000e-04.
#
# ======== Epoch 11 / 30 ========
# Training...
#   Batch    40  of    943.    .
#   step loss: 0.02
#   Batch    80  of    943.    .
#   step loss: 0.02
#   Batch   120  of    943.    .
#   step loss: 0.02
#   Batch   160  of    943.    .
#   step loss: 0.02
#   Batch   200  of    943.    .
#   step loss: 0.03
#   Batch   240  of    943.    .
#   step loss: 0.02
#   Batch   280  of    943.    .
#   step loss: 0.02
#   Batch   320  of    943.    .
#   step loss: 0.03
#   Batch   360  of    943.    .
#   step loss: 0.02
#   Batch   400  of    943.    .
#   step loss: 0.01
#   Batch   440  of    943.    .
#   step loss: 0.02
#   Batch   480  of    943.    .
#   step loss: 0.04
#   Batch   520  of    943.    .
#   step loss: 0.03
#   Batch   560  of    943.    .
#   step loss: 0.03
#   Batch   600  of    943.    .
#   step loss: 0.03
#   Batch   640  of    943.    .
#   step loss: 0.02
#   Batch   680  of    943.    .
#   step loss: 0.02
#   Batch   720  of    943.    .
#   step loss: 0.03
#   Batch   760  of    943.    .
#   step loss: 0.02
#   Batch   800  of    943.    .
#   step loss: 0.04
#   Batch   840  of    943.    .
#   step loss: 0.02
#   Batch   880  of    943.    .
#   step loss: 0.02
#   Batch   920  of    943.    .
#   step loss: 0.02
#
#   Average training loss: 0.03
#
# Running Validation...
# Batch accuracy: 95.12
# Batch accuracy: 93.55
# Batch accuracy: 94.53
# Batch accuracy: 96.68
# Batch accuracy: 92.97
# Batch accuracy: 94.34
# Batch accuracy: 94.73
# Batch accuracy: 93.55
# Batch accuracy: 95.90
# Batch accuracy: 94.14
# Batch accuracy: 94.53
# Batch accuracy: 95.12
# Batch accuracy: 94.14
# Batch accuracy: 92.97
# Batch accuracy: 93.36
# Batch accuracy: 94.34
# Batch accuracy: 92.97
# Batch accuracy: 93.55
# Batch accuracy: 91.99
# Batch accuracy: 94.92
# Batch accuracy: 92.77
# Batch accuracy: 94.73
# Batch accuracy: 93.75
# Batch accuracy: 93.16
# Batch accuracy: 94.53
# Batch accuracy: 94.34
# Batch accuracy: 96.29
# Batch accuracy: 95.90
# Batch accuracy: 93.16
# Batch accuracy: 94.92
# Batch accuracy: 94.92
# Batch accuracy: 94.14
# Batch accuracy: 93.95
# Batch accuracy: 94.14
# Batch accuracy: 94.53
# Batch accuracy: 94.73
# Batch accuracy: 94.73
# Batch accuracy: 94.14
# Batch accuracy: 95.12
# Batch accuracy: 95.12
# Batch accuracy: 95.90
# Batch accuracy: 94.34
# Batch accuracy: 96.29
# Batch accuracy: 94.34
# Batch accuracy: 95.12
# Batch accuracy: 93.55
# Batch accuracy: 93.75
# Batch accuracy: 94.34
# Batch accuracy: 94.92
# Batch accuracy: 92.38
# Batch accuracy: 93.16
# Batch accuracy: 95.70
# Batch accuracy: 93.55
# Batch accuracy: 92.58
# Batch accuracy: 93.55
# Batch accuracy: 93.16
# Batch accuracy: 93.36
# Batch accuracy: 95.12
# Batch accuracy: 95.70
# Batch accuracy: 94.14
# Batch accuracy: 94.92
# Batch accuracy: 94.34
# Batch accuracy: 94.53
# Batch accuracy: 94.14
# Batch accuracy: 93.75
# Batch accuracy: 93.16
# Batch accuracy: 93.36
# Batch accuracy: 92.97
# Batch accuracy: 94.92
# Batch accuracy: 93.55
# Batch accuracy: 94.73
# Batch accuracy: 93.55
# Batch accuracy: 94.73
# Batch accuracy: 93.55
# Batch accuracy: 93.36
# Batch accuracy: 93.75
# Batch accuracy: 92.58
# Batch accuracy: 95.31
# Batch accuracy: 94.73
# Batch accuracy: 95.12
# Batch accuracy: 94.53
# Batch accuracy: 92.97
# Batch accuracy: 94.34
# Batch accuracy: 93.75
# Batch accuracy: 94.14
# Batch accuracy: 93.75
# Batch accuracy: 96.09
# Batch accuracy: 94.92
# Batch accuracy: 94.14
# Batch accuracy: 93.55
# Batch accuracy: 94.73
# Batch accuracy: 93.36
# Batch accuracy: 92.97
# Batch accuracy: 93.55
# Batch accuracy: 94.14
# Batch accuracy: 91.41
# Batch accuracy: 92.77
# Batch accuracy: 94.53
# Batch accuracy: 93.16
# Batch accuracy: 91.99
# Batch accuracy: 92.19
# Batch accuracy: 95.31
# Batch accuracy: 93.55
# Batch accuracy: 94.53
# Batch accuracy: 94.52
#   Accuracy: 94.13
# New best model, saving it!
#
# ======== Epoch 12 / 30 ========
# Training...
#   Batch    40  of    943.    .
#   step loss: 0.02
#   Batch    80  of    943.    .
#   step loss: 0.02
#   Batch   120  of    943.    .
#   step loss: 0.01
#   Batch   160  of    943.    .
#   step loss: 0.03
#   Batch   200  of    943.    .
#   step loss: 0.02
#   Batch   240  of    943.    .
#   step loss: 0.02
#   Batch   280  of    943.    .
#   step loss: 0.01
#   Batch   320  of    943.    .
#   step loss: 0.01
#   Batch   360  of    943.    .
#   step loss: 0.02
#   Batch   400  of    943.    .
#   step loss: 0.02
#   Batch   440  of    943.    .
#   step loss: 0.02
#   Batch   480  of    943.    .
#   step loss: 0.01
#   Batch   520  of    943.    .
#   step loss: 0.02
#   Batch   560  of    943.    .
#   step loss: 0.02
#   Batch   600  of    943.    .
#   step loss: 0.02
#   Batch   640  of    943.    .
#   step loss: 0.02
#   Batch   680  of    943.    .
#   step loss: 0.01
#   Batch   720  of    943.    .
#   step loss: 0.02
#   Batch   760  of    943.    .
#   step loss: 0.02
#   Batch   800  of    943.    .
#   step loss: 0.02
#   Batch   840  of    943.    .
#   step loss: 0.01
#   Batch   880  of    943.    .
#   step loss: 0.02
#   Batch   920  of    943.    .
#   step loss: 0.01
#
#   Average training loss: 0.02
#
# Running Validation...
# Batch accuracy: 93.16
# Batch accuracy: 92.77
# Batch accuracy: 94.92
# Batch accuracy: 92.97
# Batch accuracy: 95.70
# Batch accuracy: 94.14
# Batch accuracy: 94.14
# Batch accuracy: 93.95
# Batch accuracy: 94.92
# Batch accuracy: 94.34
# Batch accuracy: 95.12
# Batch accuracy: 96.29
# Batch accuracy: 92.58
# Batch accuracy: 94.73
# Batch accuracy: 93.75
# Batch accuracy: 93.75
# Batch accuracy: 93.55
# Batch accuracy: 95.12
# Batch accuracy: 93.16
# Batch accuracy: 94.34
# Batch accuracy: 94.53
# Batch accuracy: 93.36
# Batch accuracy: 92.77
# Batch accuracy: 93.16
# Batch accuracy: 94.73
# Batch accuracy: 95.70
# Batch accuracy: 96.29
# Batch accuracy: 94.14
# Batch accuracy: 95.31
# Batch accuracy: 95.31
# Batch accuracy: 92.38
# Batch accuracy: 95.70
# Batch accuracy: 94.53
# Batch accuracy: 94.34
# Batch accuracy: 93.16
# Batch accuracy: 94.53
# Batch accuracy: 92.97
# Batch accuracy: 94.73
# Batch accuracy: 95.31
# Batch accuracy: 94.34
# Batch accuracy: 96.09
# Batch accuracy: 94.34
# Batch accuracy: 93.95
# Batch accuracy: 94.14
# Batch accuracy: 94.34
# Batch accuracy: 94.92
# Batch accuracy: 93.55
# Batch accuracy: 93.55
# Batch accuracy: 94.53
# Batch accuracy: 90.82
# Batch accuracy: 95.12
# Batch accuracy: 93.95
# Batch accuracy: 92.19
# Batch accuracy: 93.55
# Batch accuracy: 95.51
# Batch accuracy: 92.38
# Batch accuracy: 92.97
# Batch accuracy: 94.92
# Batch accuracy: 95.51
# Batch accuracy: 91.21
# Batch accuracy: 94.14
# Batch accuracy: 93.16
# Batch accuracy: 94.14
# Batch accuracy: 94.73
# Batch accuracy: 95.12
# Batch accuracy: 95.12
# Batch accuracy: 93.95
# Batch accuracy: 94.14
# Batch accuracy: 92.38
# Batch accuracy: 95.31
# Batch accuracy: 95.12
# Batch accuracy: 96.09
# Batch accuracy: 93.55
# Batch accuracy: 93.55
# Batch accuracy: 96.09
# Batch accuracy: 92.38
# Batch accuracy: 94.53
# Batch accuracy: 92.77
# Batch accuracy: 95.51
# Batch accuracy: 94.14
# Batch accuracy: 92.77
# Batch accuracy: 93.16
# Batch accuracy: 94.14
# Batch accuracy: 93.95
# Batch accuracy: 95.51
# Batch accuracy: 93.55
# Batch accuracy: 95.12
# Batch accuracy: 94.34
# Batch accuracy: 93.16
# Batch accuracy: 94.34
# Batch accuracy: 93.75
# Batch accuracy: 93.16
# Batch accuracy: 91.99
# Batch accuracy: 92.38
# Batch accuracy: 94.34
# Batch accuracy: 93.55
# Batch accuracy: 93.95
# Batch accuracy: 95.12
# Batch accuracy: 94.73
# Batch accuracy: 95.31
# Batch accuracy: 93.75
# Batch accuracy: 94.53
# Batch accuracy: 94.53
# Batch accuracy: 95.51
# Batch accuracy: 94.52
#   Accuracy: 94.15
# New best model, saving it!
#
# ======== Epoch 13 / 30 ========
# Training...
#   Batch    40  of    943.    .
#   step loss: 0.02
#   Batch    80  of    943.    .
#   step loss: 0.01
#   Batch   120  of    943.    .
#   step loss: 0.02
#   Batch   160  of    943.    .
#   step loss: 0.02
#   Batch   200  of    943.    .
#   step loss: 0.02
#   Batch   240  of    943.    .
#   step loss: 0.02
#   Batch   280  of    943.    .
#   step loss: 0.03
#   Batch   320  of    943.    .
#   step loss: 0.01
#   Batch   360  of    943.    .
#   step loss: 0.03
#   Batch   400  of    943.    .
#   step loss: 0.01
#   Batch   440  of    943.    .
#   step loss: 0.02
#   Batch   480  of    943.    .
#   step loss: 0.03
#   Batch   520  of    943.    .
#   step loss: 0.01
#   Batch   560  of    943.    .
#   step loss: 0.01
#   Batch   600  of    943.    .
#   step loss: 0.01
#   Batch   640  of    943.    .
#   step loss: 0.02
#   Batch   680  of    943.    .
#   step loss: 0.01
#   Batch   720  of    943.    .
#   step loss: 0.02
#   Batch   760  of    943.    .
#   step loss: 0.02
#   Batch   800  of    943.    .
#   step loss: 0.02
#   Batch   840  of    943.    .
#   step loss: 0.02
#   Batch   880  of    943.    .
#   step loss: 0.01
#   Batch   920  of    943.    .
#   step loss: 0.01
#
#   Average training loss: 0.02
#
# Running Validation...
# Batch accuracy: 94.92
# Batch accuracy: 94.92
# Batch accuracy: 92.58
# Batch accuracy: 95.70
# Batch accuracy: 92.77
# Batch accuracy: 92.77
# Batch accuracy: 92.97
# Batch accuracy: 95.12
# Batch accuracy: 94.14
# Batch accuracy: 93.55
# Batch accuracy: 94.92
# Batch accuracy: 95.51
# Batch accuracy: 94.73
# Batch accuracy: 95.31
# Batch accuracy: 94.92
# Batch accuracy: 95.51
# Batch accuracy: 95.51
# Batch accuracy: 94.92
# Batch accuracy: 94.34
# Batch accuracy: 93.75
# Batch accuracy: 94.34
# Batch accuracy: 95.90
# Batch accuracy: 94.14
# Batch accuracy: 94.73
# Batch accuracy: 94.92
# Batch accuracy: 94.53
# Batch accuracy: 93.95
# Batch accuracy: 94.14
# Batch accuracy: 94.14
# Batch accuracy: 95.12
# Batch accuracy: 93.16
# Batch accuracy: 92.38
# Batch accuracy: 92.58
# Batch accuracy: 95.12
# Batch accuracy: 95.12
# Batch accuracy: 94.53
# Batch accuracy: 94.14
# Batch accuracy: 93.36
# Batch accuracy: 94.73
# Batch accuracy: 93.75
# Batch accuracy: 94.34
# Batch accuracy: 95.12
# Batch accuracy: 93.75
# Batch accuracy: 92.19
# Batch accuracy: 94.14
# Batch accuracy: 94.34
# Batch accuracy: 96.09
# Batch accuracy: 94.92
# Batch accuracy: 93.75
# Batch accuracy: 93.36
# Batch accuracy: 94.92
# Batch accuracy: 93.95
# Batch accuracy: 96.09
# Batch accuracy: 94.73
# Batch accuracy: 94.34
# Batch accuracy: 93.55
# Batch accuracy: 93.16
# Batch accuracy: 93.95
# Batch accuracy: 93.75
# Batch accuracy: 94.53
# Batch accuracy: 94.14
# Batch accuracy: 94.92
# Batch accuracy: 93.36
# Batch accuracy: 93.95
# Batch accuracy: 93.55
# Batch accuracy: 95.31
# Batch accuracy: 94.14
# Batch accuracy: 94.14
# Batch accuracy: 93.16
# Batch accuracy: 95.70
# Batch accuracy: 94.53
# Batch accuracy: 94.53
# Batch accuracy: 93.95
# Batch accuracy: 93.16
# Batch accuracy: 94.73
# Batch accuracy: 94.14
# Batch accuracy: 93.16
# Batch accuracy: 94.92
# Batch accuracy: 93.16
# Batch accuracy: 92.19
# Batch accuracy: 94.34
# Batch accuracy: 94.73
# Batch accuracy: 94.73
# Batch accuracy: 95.90
# Batch accuracy: 93.55
# Batch accuracy: 94.92
# Batch accuracy: 93.95
# Batch accuracy: 94.14
# Batch accuracy: 93.75
# Batch accuracy: 93.95
# Batch accuracy: 94.34
# Batch accuracy: 94.14
# Batch accuracy: 94.92
# Batch accuracy: 95.12
# Batch accuracy: 92.97
# Batch accuracy: 93.16
# Batch accuracy: 94.34
# Batch accuracy: 93.75
# Batch accuracy: 94.92
# Batch accuracy: 94.73
# Batch accuracy: 94.53
# Batch accuracy: 91.80
# Batch accuracy: 95.51
# Batch accuracy: 92.58
# Batch accuracy: 92.51
#   Accuracy: 94.22
# New best model, saving it!
#
# ======== Epoch 14 / 30 ========
# Training...
#   Batch    40  of    943.    .
#   step loss: 0.01
#   Batch    80  of    943.    .
#   step loss: 0.01
#   Batch   120  of    943.    .
#   step loss: 0.01
#   Batch   160  of    943.    .
#   step loss: 0.01
#   Batch   200  of    943.    .
#   step loss: 0.02
#   Batch   240  of    943.    .
#   step loss: 0.01
#   Batch   280  of    943.    .
#   step loss: 0.01
#   Batch   320  of    943.    .
#   step loss: 0.02
#   Batch   360  of    943.    .
#   step loss: 0.01
#   Batch   400  of    943.    .
#   step loss: 0.02
#   Batch   440  of    943.    .
#   step loss: 0.01
#   Batch   480  of    943.    .
#   step loss: 0.01
#   Batch   520  of    943.    .
#   step loss: 0.01
#   Batch   560  of    943.    .
#   step loss: 0.02
#   Batch   600  of    943.    .
#   step loss: 0.01
#   Batch   640  of    943.    .
#   step loss: 0.01
#   Batch   680  of    943.    .
#   step loss: 0.02
#   Batch   720  of    943.    .
#   step loss: 0.02
#   Batch   760  of    943.    .
#   step loss: 0.01
#   Batch   800  of    943.    .
#   step loss: 0.01
#   Batch   840  of    943.    .
#   step loss: 0.01
#   Batch   880  of    943.    .
#   step loss: 0.02
#   Batch   920  of    943.    .
#   step loss: 0.02
#
#   Average training loss: 0.01
#
# Running Validation...
# Batch accuracy: 93.16
# Batch accuracy: 95.12
# Batch accuracy: 95.12
# Batch accuracy: 93.95
# Batch accuracy: 93.36
# Batch accuracy: 93.36
# Batch accuracy: 94.34
# ...
# Batch accuracy: 95.90
# Batch accuracy: 94.92
# Batch accuracy: 92.38
# Batch accuracy: 95.51
# Batch accuracy: 95.31
# Batch accuracy: 95.90
# Batch accuracy: 93.55
# Batch accuracy: 92.97
# Batch accuracy: 95.90
# Batch accuracy: 96.48
# Batch accuracy: 93.16
# Batch accuracy: 93.55
# Batch accuracy: 93.36
# Batch accuracy: 93.55
# Batch accuracy: 94.92
# Batch accuracy: 93.36
# Batch accuracy: 94.34
# Batch accuracy: 92.97
# Batch accuracy: 93.75
# Batch accuracy: 95.51
# Batch accuracy: 92.97
# Batch accuracy: 94.73
# Batch accuracy: 94.34
# Batch accuracy: 93.55
# Batch accuracy: 93.75
# Batch accuracy: 94.34
# Batch accuracy: 92.58
# Batch accuracy: 95.31
# Batch accuracy: 95.51
# Batch accuracy: 91.99
# Batch accuracy: 94.14
# Batch accuracy: 94.92
# Batch accuracy: 94.34
# Batch accuracy: 94.14
# Batch accuracy: 93.75
# Batch accuracy: 91.60
# Batch accuracy: 94.14
# Batch accuracy: 92.58
# Batch accuracy: 93.95
# Batch accuracy: 93.36
# Batch accuracy: 94.73
# Batch accuracy: 91.21
# Batch accuracy: 95.12
# Batch accuracy: 94.73
# Batch accuracy: 93.55
# Batch accuracy: 94.92
# Batch accuracy: 94.73
# Batch accuracy: 95.31
# Batch accuracy: 96.29
# Batch accuracy: 95.31
# Batch accuracy: 92.38
# Batch accuracy: 93.36
# Batch accuracy: 94.53
# Batch accuracy: 94.34
# Batch accuracy: 93.36
# Batch accuracy: 92.97
# Batch accuracy: 94.14
# Batch accuracy: 95.51
# Batch accuracy: 93.55
# Batch accuracy: 95.70
# Batch accuracy: 92.38
# Batch accuracy: 95.31
# Batch accuracy: 94.81
#   Accuracy: 94.24
# The model does not improve for 2 epochs!
#
# ======== Epoch 22 / 30 ========
# Training...
#   Batch    40  of    943.    .
#   step loss: 0.01
#   Batch    80  of    943.    .
#   step loss: 0.00
#   Batch   120  of    943.    .
#   step loss: 0.01
#   Batch   160  of    943.    .
#   step loss: 0.02
#   Batch   200  of    943.    .
#   step loss: 0.01
#   Batch   240  of    943.    .
#   step loss: 0.01
#   Batch   280  of    943.    .
#   step loss: 0.02
#   Batch   320  of    943.    .
#   step loss: 0.01
#   Batch   360  of    943.    .
#   step loss: 0.01
#   Batch   400  of    943.    .
#   step loss: 0.01
#   Batch   440  of    943.    .
#   step loss: 0.01
#   Batch   480  of    943.    .
#   step loss: 0.02
#   Batch   520  of    943.    .
#   step loss: 0.01
#   Batch   560  of    943.    .
#   step loss: 0.01
#   Batch   600  of    943.    .
#   step loss: 0.02
#   Batch   640  of    943.    .
#   step loss: 0.02
#   Batch   680  of    943.    .
#   step loss: 0.01
#   Batch   720  of    943.    .
#   step loss: 0.01
#   Batch   760  of    943.    .
#   step loss: 0.01
#   Batch   800  of    943.    .
#   step loss: 0.01
#   Batch   840  of    943.    .
#   step loss: 0.01
#   Batch   880  of    943.    .
#   step loss: 0.01
#   Batch   920  of    943.    .
#   step loss: 0.02
#
#   Average training loss: 0.01
#
# Running Validation...
# Batch accuracy: 93.95
# Batch accuracy: 94.14
# Batch accuracy: 93.95
# Batch accuracy: 92.77
# Batch accuracy: 93.36
# Batch accuracy: 94.14
# Batch accuracy: 96.48
# Batch accuracy: 94.73
# Batch accuracy: 93.16
# Batch accuracy: 91.80
# Batch accuracy: 94.53
# Batch accuracy: 94.34
# Batch accuracy: 94.53
# Batch accuracy: 94.53
# Batch accuracy: 95.31
# Batch accuracy: 93.36
# Batch accuracy: 95.70
# Batch accuracy: 93.16
# Batch accuracy: 93.16
# Batch accuracy: 95.31
# Batch accuracy: 93.16
# Batch accuracy: 94.92
# Batch accuracy: 96.29
# Batch accuracy: 95.31
# Batch accuracy: 94.14
# Batch accuracy: 95.90
# Batch accuracy: 93.95
# Batch accuracy: 94.14
# Batch accuracy: 94.53
# Batch accuracy: 93.75
# Batch accuracy: 92.77
# Batch accuracy: 95.12
# Batch accuracy: 94.53
# Batch accuracy: 95.12
# Batch accuracy: 93.36
# Batch accuracy: 96.29
# Batch accuracy: 94.34
# Batch accuracy: 95.12
# Batch accuracy: 95.12
# Batch accuracy: 92.97
# Batch accuracy: 94.73
# Batch accuracy: 95.51
# Batch accuracy: 93.55
# Batch accuracy: 92.58
# Batch accuracy: 94.92
# Batch accuracy: 92.97
# Batch accuracy: 94.53
# Batch accuracy: 95.31
# Batch accuracy: 93.95
# Batch accuracy: 95.51
# Batch accuracy: 95.51
# Batch accuracy: 93.75
# Batch accuracy: 92.58
# Batch accuracy: 93.55
# Batch accuracy: 92.97
# Batch accuracy: 92.58
# Batch accuracy: 93.95
# Batch accuracy: 91.99
# Batch accuracy: 94.73
# Batch accuracy: 95.90
# Batch accuracy: 94.73
# Batch accuracy: 93.75
# Batch accuracy: 93.36
# Batch accuracy: 94.14
# Batch accuracy: 95.31
# Batch accuracy: 94.14
# Batch accuracy: 94.53
# Batch accuracy: 93.16
# Batch accuracy: 93.95
# Batch accuracy: 94.53
# Batch accuracy: 93.95
# Batch accuracy: 93.55
# Batch accuracy: 93.75
# Batch accuracy: 94.73
# Batch accuracy: 94.14
# Batch accuracy: 95.31
# Batch accuracy: 95.31
# Batch accuracy: 92.77
# Batch accuracy: 95.12
# Batch accuracy: 95.51
# Batch accuracy: 94.14
# Batch accuracy: 93.36
# Batch accuracy: 94.53
# Batch accuracy: 94.73
# Batch accuracy: 95.31
# Batch accuracy: 94.34
# Batch accuracy: 95.12
# Batch accuracy: 95.31
# Batch accuracy: 93.36
# Batch accuracy: 94.14
# Batch accuracy: 95.31
# Batch accuracy: 92.97
# Batch accuracy: 93.16
# Batch accuracy: 93.36
# Batch accuracy: 93.95
# Batch accuracy: 91.80
# Batch accuracy: 95.31
# Batch accuracy: 94.34
# Batch accuracy: 93.75
# Batch accuracy: 95.70
# Batch accuracy: 93.36
# Batch accuracy: 95.12
# Batch accuracy: 93.95
# Batch accuracy: 92.38
# Batch accuracy: 96.25
#   Accuracy: 94.24
# The model does not improve for 3 epochs!
# Epoch    22: reducing learning rate of group 0 to 1.0000e-07.
#
# ======== Epoch 23 / 30 ========
# Training...
#   Batch    40  of    943.    .
#   step loss: 0.01
#   Batch    80  of    943.    .
#   step loss: 0.01
#   Batch   120  of    943.    .
#   step loss: 0.01
#   Batch   160  of    943.    .
#   step loss: 0.00
#   Batch   200  of    943.    .
#   step loss: 0.01
#   Batch   240  of    943.    .
#   step loss: 0.01
#   Batch   280  of    943.    .
#   step loss: 0.01
#   Batch   320  of    943.    .
#   step loss: 0.01
#   Batch   360  of    943.    .
#   step loss: 0.01
#   Batch   400  of    943.    .
#   step loss: 0.01
#   Batch   440  of    943.    .
#   step loss: 0.00
#   Batch   480  of    943.    .
#   step loss: 0.01
#   Batch   520  of    943.    .
#   step loss: 0.01
#   Batch   560  of    943.    .
#   step loss: 0.00
#   Batch   600  of    943.    .
#   step loss: 0.01
#   Batch   640  of    943.    .
#   step loss: 0.02
#   Batch   680  of    943.    .
#   step loss: 0.01
#   Batch   720  of    943.    .
#   step loss: 0.01
#   Batch   760  of    943.    .
#   step loss: 0.01
#   Batch   800  of    943.    .
#   step loss: 0.01
#   Batch   840  of    943.    .
#   step loss: 0.01
#   Batch   880  of    943.    .
#   step loss: 0.01
#   Batch   920  of    943.    .
#   step loss: 0.01
#
#   Average training loss: 0.01
#
# Running Validation...
# Batch accuracy: 94.34
# Batch accuracy: 94.14
# Batch accuracy: 93.36
# Batch accuracy: 95.12
# Batch accuracy: 94.73
# Batch accuracy: 94.14
# Batch accuracy: 94.34
# Batch accuracy: 94.34
# Batch accuracy: 93.36
# Batch accuracy: 93.36
# Batch accuracy: 94.92
# Batch accuracy: 94.34
# Batch accuracy: 93.55
# Batch accuracy: 93.16
# Batch accuracy: 91.80
# Batch accuracy: 94.73
# Batch accuracy: 95.70
# Batch accuracy: 91.80
# Batch accuracy: 95.12
# Batch accuracy: 93.75
# Batch accuracy: 94.34
# Batch accuracy: 94.73
# Batch accuracy: 93.16
# Batch accuracy: 94.92
# Batch accuracy: 95.12
# Batch accuracy: 94.14
# Batch accuracy: 94.73
# Batch accuracy: 93.75
# Batch accuracy: 94.53
# Batch accuracy: 93.95
# Batch accuracy: 92.58
# Batch accuracy: 92.97
# Batch accuracy: 94.73
# Batch accuracy: 94.53
# Batch accuracy: 94.73
# Batch accuracy: 95.51
# Batch accuracy: 94.14
# Batch accuracy: 95.12
# Batch accuracy: 94.53
# Batch accuracy: 94.73
# Batch accuracy: 93.36
# Batch accuracy: 94.92
# Batch accuracy: 94.34
# Batch accuracy: 94.53
# Batch accuracy: 93.75
# Batch accuracy: 93.36
# Batch accuracy: 93.95
# Batch accuracy: 94.53
# Batch accuracy: 94.92
# Batch accuracy: 93.16
# Batch accuracy: 93.75
# Batch accuracy: 93.16
# Batch accuracy: 92.77
# Batch accuracy: 94.53
# Batch accuracy: 94.92
# Batch accuracy: 94.14
# Batch accuracy: 93.55
# Batch accuracy: 93.36
# Batch accuracy: 94.53
# Batch accuracy: 94.73
# Batch accuracy: 95.70
# Batch accuracy: 95.90
# Batch accuracy: 95.31
# Batch accuracy: 94.92
# Batch accuracy: 93.95
# Batch accuracy: 94.92
# Batch accuracy: 92.77
# Batch accuracy: 92.97
# Batch accuracy: 94.14
# Batch accuracy: 94.34
# Batch accuracy: 95.12
# Batch accuracy: 95.12
# Batch accuracy: 94.14
# Batch accuracy: 94.53
# Batch accuracy: 93.75
# Batch accuracy: 94.92
# Batch accuracy: 95.12
# Batch accuracy: 92.19
# Batch accuracy: 96.29
# Batch accuracy: 93.75
# Batch accuracy: 93.75
# Batch accuracy: 94.14
# Batch accuracy: 92.77
# Batch accuracy: 95.12
# Batch accuracy: 95.70
# Batch accuracy: 92.97
# Batch accuracy: 92.77
# Batch accuracy: 93.55
# Batch accuracy: 95.51
# Batch accuracy: 95.90
# Batch accuracy: 95.12
# Batch accuracy: 95.31
# Batch accuracy: 95.12
# Batch accuracy: 94.53
# Batch accuracy: 94.34
# Batch accuracy: 94.14
# Batch accuracy: 92.58
# Batch accuracy: 94.53
# Batch accuracy: 94.53
# Batch accuracy: 93.55
# Batch accuracy: 93.75
# Batch accuracy: 92.97
# Batch accuracy: 95.12
# Batch accuracy: 95.12
# Batch accuracy: 94.52
#   Accuracy: 94.23
# The model does not improve for 4 epochs!
#
# ======== Epoch 24 / 30 ========
# Training...
#   Batch    40  of    943.    .
#   step loss: 0.01
#   Batch    80  of    943.    .
#   step loss: 0.01
#   Batch   120  of    943.    .
#   step loss: 0.01
#   Batch   160  of    943.    .
#   step loss: 0.02
#   Batch   200  of    943.    .
#   step loss: 0.01
#   Batch   240  of    943.    .
#   step loss: 0.01
#   Batch   280  of    943.    .
#   step loss: 0.01
#   Batch   320  of    943.    .
#   step loss: 0.01
#   Batch   360  of    943.    .
#   step loss: 0.01
#   Batch   400  of    943.    .
#   step loss: 0.02
#   Batch   440  of    943.    .
#   step loss: 0.01
#   Batch   480  of    943.    .
#   step loss: 0.01
#   Batch   520  of    943.    .
#   step loss: 0.01
#   Batch   560  of    943.    .
#   step loss: 0.01
#   Batch   600  of    943.    .
#   step loss: 0.01
#   Batch   640  of    943.    .
#   step loss: 0.01
#   Batch   680  of    943.    .
#   step loss: 0.01
#   Batch   720  of    943.    .
#   step loss: 0.01
#   Batch   760  of    943.    .
#   step loss: 0.01
#   Batch   800  of    943.    .
#   step loss: 0.01
#   Batch   840  of    943.    .
#   step loss: 0.01
#   Batch   880  of    943.    .
#   step loss: 0.01
#   Batch   920  of    943.    .
#   step loss: 0.01
#
#   Average training loss: 0.01
#
# Running Validation...
# Batch accuracy: 93.16
# Batch accuracy: 92.58
# Batch accuracy: 94.73
# Batch accuracy: 95.31
# Batch accuracy: 93.95
# Batch accuracy: 93.95
# Batch accuracy: 94.53
# Batch accuracy: 94.92
# Batch accuracy: 95.12
# Batch accuracy: 94.34
# Batch accuracy: 94.53
# Batch accuracy: 95.70
# Batch accuracy: 94.34
# Batch accuracy: 94.14
# Batch accuracy: 93.75
# Batch accuracy: 93.75
# Batch accuracy: 95.90
# Batch accuracy: 94.73
# Batch accuracy: 94.14
# Batch accuracy: 93.16
# Batch accuracy: 94.34
# Batch accuracy: 94.73
# Batch accuracy: 92.97
# Batch accuracy: 94.73
# Batch accuracy: 93.16
# Batch accuracy: 94.14
# Batch accuracy: 93.95
# Batch accuracy: 93.16
# Batch accuracy: 96.68
# Batch accuracy: 92.58
# Batch accuracy: 93.75
# Batch accuracy: 93.36
# Batch accuracy: 92.97
# Batch accuracy: 92.77
# Batch accuracy: 94.34
# Batch accuracy: 94.53
# Batch accuracy: 93.95
# Batch accuracy: 93.36
# Batch accuracy: 94.14
# Batch accuracy: 95.31
# Batch accuracy: 94.92
# Batch accuracy: 93.55
# Batch accuracy: 93.16
# Batch accuracy: 95.12
# Batch accuracy: 93.95
# Batch accuracy: 94.73
# Batch accuracy: 95.12
# Batch accuracy: 94.14
# Batch accuracy: 94.34
# Batch accuracy: 95.70
# Batch accuracy: 96.29
# Batch accuracy: 93.36
# Batch accuracy: 95.12
# Batch accuracy: 92.77
# Batch accuracy: 95.51
# Batch accuracy: 94.53
# Batch accuracy: 94.73
# Batch accuracy: 94.73
# Batch accuracy: 94.92
# Batch accuracy: 91.41
# Batch accuracy: 95.90
# Batch accuracy: 94.73
# Batch accuracy: 95.12
# Batch accuracy: 93.95
# Batch accuracy: 94.73
# Batch accuracy: 94.34
# Batch accuracy: 93.75
# Batch accuracy: 94.73
# Batch accuracy: 93.95
# Batch accuracy: 91.99
# Batch accuracy: 94.73
# Batch accuracy: 93.16
# Batch accuracy: 95.51
# Batch accuracy: 94.92
# Batch accuracy: 95.51
# Batch accuracy: 94.53
# Batch accuracy: 94.73
# Batch accuracy: 91.80
# Batch accuracy: 93.16
# Batch accuracy: 95.12
# Batch accuracy: 95.51
# Batch accuracy: 95.51
# Batch accuracy: 94.14
# Batch accuracy: 94.14
# Batch accuracy: 92.97
# Batch accuracy: 94.34
# Batch accuracy: 93.36
# Batch accuracy: 93.75
# Batch accuracy: 95.31
# Batch accuracy: 94.14
# Batch accuracy: 94.14
# Batch accuracy: 92.58
# Batch accuracy: 94.34
# Batch accuracy: 93.75
# Batch accuracy: 95.12
# Batch accuracy: 94.92
# Batch accuracy: 94.14
# Batch accuracy: 93.75
# Batch accuracy: 94.73
# Batch accuracy: 94.73
# Batch accuracy: 94.14
# Batch accuracy: 93.95
# Batch accuracy: 96.29
# Batch accuracy: 91.80
# Batch accuracy: 92.22
#   Accuracy: 94.23
# The model does not improve for 5 epochs!
#
# ======== Epoch 25 / 30 ========
# Training...
#   Batch    40  of    943.    .
#   step loss: 0.01
#   Batch    80  of    943.    .
#   step loss: 0.01
#   Batch   120  of    943.    .
#   step loss: 0.01
#   Batch   160  of    943.    .
#   step loss: 0.01
#   Batch   200  of    943.    .
#   step loss: 0.01
#   Batch   240  of    943.    .
#   step loss: 0.01
#   Batch   280  of    943.    .
#   step loss: 0.01
#   Batch   320  of    943.    .
#   step loss: 0.01
#   Batch   360  of    943.    .
#   step loss: 0.00
#   Batch   400  of    943.    .
#   step loss: 0.01
#   Batch   440  of    943.    .
#   step loss: 0.01
#   Batch   480  of    943.    .
#   step loss: 0.01
#   Batch   520  of    943.    .
#   step loss: 0.01
#   Batch   560  of    943.    .
#   step loss: 0.01
#   Batch   600  of    943.    .
#   step loss: 0.02
#   Batch   640  of    943.    .
#   step loss: 0.01
#   Batch   680  of    943.    .
#   step loss: 0.01
#   Batch   720  of    943.    .
#   step loss: 0.01
#   Batch   760  of    943.    .
#   step loss: 0.01
#   Batch   800  of    943.    .
#   step loss: 0.01
#   Batch   840  of    943.    .
#   step loss: 0.01
#   Batch   880  of    943.    .
#   step loss: 0.01
#   Batch   920  of    943.    .
#   step loss: 0.01
#
#   Average training loss: 0.01
#
# Running Validation...
# Batch accuracy: 92.97
# Batch accuracy: 93.55
# Batch accuracy: 93.55
# Batch accuracy: 93.75
# Batch accuracy: 95.31
# Batch accuracy: 94.73
# Batch accuracy: 93.75
# Batch accuracy: 94.73
# Batch accuracy: 92.97
# Batch accuracy: 95.12
# Batch accuracy: 95.90
# Batch accuracy: 94.34
# Batch accuracy: 95.12
# Batch accuracy: 92.38
# Batch accuracy: 95.90
# Batch accuracy: 91.99
# Batch accuracy: 95.12
# Batch accuracy: 93.16
# Batch accuracy: 94.73
# Batch accuracy: 93.55
# Batch accuracy: 92.19
# Batch accuracy: 93.95
# Batch accuracy: 94.73
# Batch accuracy: 94.92
# Batch accuracy: 94.73
# Batch accuracy: 94.34
# Batch accuracy: 93.75
# Batch accuracy: 93.55
# Batch accuracy: 94.14
# Batch accuracy: 92.77
# Batch accuracy: 94.34
# Batch accuracy: 95.12
# Batch accuracy: 93.16
# Batch accuracy: 94.92
# Batch accuracy: 94.53
# Batch accuracy: 95.51
# Batch accuracy: 95.31
# Batch accuracy: 95.51
# Batch accuracy: 94.73
# Batch accuracy: 95.31
# Batch accuracy: 94.34
# Batch accuracy: 92.77
# Batch accuracy: 94.34
# Batch accuracy: 95.90
# Batch accuracy: 93.36
# Batch accuracy: 94.14
# Batch accuracy: 93.75
# Batch accuracy: 94.14
# Batch accuracy: 96.68
# Batch accuracy: 94.34
# Batch accuracy: 94.34
# Batch accuracy: 92.38
# Batch accuracy: 93.36
# Batch accuracy: 95.70
# Batch accuracy: 94.73
# Batch accuracy: 92.19
# Batch accuracy: 94.73
# Batch accuracy: 95.51
# Batch accuracy: 94.34
# Batch accuracy: 94.34
# Batch accuracy: 92.38
# Batch accuracy: 93.95
# Batch accuracy: 94.34
# Batch accuracy: 92.77
# Batch accuracy: 94.34
# Batch accuracy: 93.55
# Batch accuracy: 94.73
# Batch accuracy: 92.38
# Batch accuracy: 94.53
# Batch accuracy: 95.70
# Batch accuracy: 94.34
# Batch accuracy: 94.53
# Batch accuracy: 92.38
# Batch accuracy: 96.09
# Batch accuracy: 93.36
# Batch accuracy: 94.14
# Batch accuracy: 93.36
# Batch accuracy: 95.51
# Batch accuracy: 97.07
# Batch accuracy: 92.38
# Batch accuracy: 93.95
# Batch accuracy: 94.14
# Batch accuracy: 95.90
# Batch accuracy: 94.73
# Batch accuracy: 93.95
# Batch accuracy: 93.95
# Batch accuracy: 95.90
# Batch accuracy: 94.53
# Batch accuracy: 95.12
# Batch accuracy: 94.73
# Batch accuracy: 95.31
# Batch accuracy: 94.73
# Batch accuracy: 97.07
# Batch accuracy: 94.14
# Batch accuracy: 91.99
# Batch accuracy: 95.51
# Batch accuracy: 92.77
# Batch accuracy: 92.97
# Batch accuracy: 93.95
# Batch accuracy: 94.14
# Batch accuracy: 94.73
# Batch accuracy: 93.16
# Batch accuracy: 92.58
# Batch accuracy: 93.16
# Batch accuracy: 93.66
#   Accuracy: 94.23
# The model does not improve for 6 epochs!
# ====>Stopping training, the model did not improve for 6
# ====>Best epoch: 19.
#
# Training complete!

# %%
def predict(
    model_path: Path,
    dataset: str,
    batch_size: int,
    labels_dict,
    device: torch.device
):

    print(f"====Loading dataset for testing")
    test_corpus = NLPDataset(dataset, "test", sentence_max_len, labels_dict = labels_dict, vocab= voc)

    test_dataloader = DataLoader(
        test_corpus,
        batch_size=batch_size,
        #sampler = RandomSampler(test_corpus),
        pin_memory=True,
        num_workers=0,
        drop_last=False
    )

    print(f"====Loading model for testing")
    model = torch.load(join(model_path, "best-model.pth"))
    model.to(device)
    model.eval()
    pred_labels = []
    test_labels = []
    logits_list = []

    def _list_from_tensor(tensor):
        if tensor.numel() == 1:
            return [tensor.item()]
        return list(tensor.cpu().detach().numpy())

    print("====Testing model...")
    for batch in test_dataloader:
        b_input_ids = batch[0]
        b_input_ids = torch.tensor(b_input_ids).to(device).long()
        b_labels = batch[1].to(device)
        with torch.no_grad():
            loss, logits = model(b_input_ids, b_labels)
            preds = np.argmax(logits.cpu(), axis=1) # Convert one-hot to index
            b_labels = b_labels.int()
            pred_labels.extend(_list_from_tensor(preds))
            test_labels.extend(_list_from_tensor(b_labels))
        logits_list.extend(_list_from_tensor(logits))

    print(classification_report(test_labels, pred_labels, labels=list(labels_dict.values()), target_names=np.array(list(labels_dict.keys())), digits=3, output_dict=False))
    logits_list = expit(logits_list)
    del model
    torch.cuda.empty_cache()

# %%
del train_dataloader
del validation_dataloader
del train_corpus
del val_corpus
del model
torch.cuda.empty_cache()

# %%
predict(last_saved_model, dataset, batch_size, labels_dict, device)
# Out:
# ====Loading dataset for testing
# ====Loading model for testing
# ====Testing model...
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:37: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#                                                                   precision    recall  f1-score   support
#
#                               Sintomas.Genérico.Sky não funciona      0.930     0.935     0.932      8357
#                                     Sintomas.Genérico.Instalação      0.988     0.978     0.983       647
#                                 Sintomas.Genérico.Canal não pega      0.922     0.937     0.930      5967
#                     Sintomas.Genérico.Equipamento não funciona G      0.946     0.962     0.954      2318
#                                      Sintomas.Genérico.Sem sinal      0.958     0.960     0.959     14552
#                                Sintomas.Qualificado.Cancelamento      0.934     0.959     0.946      1847
#                            Sintomas.Qualificado.Outros problemas      0.824     0.757     0.789       729
#                               Sintomas.Qualificado.NãoTéc_fatura      0.880     0.881     0.881      1451
#                           Sintomas.Qualificado.Mudança de cômodo      0.968     0.955     0.961      1975
#                         Sintomas.Genérico.Equipamento queimado G      0.977     0.986     0.981      2106
#                       Sintomas.Genérico.Problema com equipamento      0.982     0.986     0.984      9645
#                         Sintomas.Genérico.Equipamento quebrado G      0.968     0.963     0.966      1441
#               Sintomas.Qualificado.Controle não funciona para tv      0.741     0.804     0.771       107
#                            Sintomas.Genérico.Falar com atendente      0.975     0.976     0.976      8262
#                             Sintomas.Genérico.Problema com canal      0.967     0.964     0.966      3547
#                        Sintomas.Qualificado.Técnico não resolveu      0.493     0.407     0.446        91
#                           Sintomas.Genérico.Troca de equipamento      0.971     0.968     0.969      3737
#                               Sintomas.Qualificado.NãoTéc_outros      0.892     0.796     0.841       186
#                                 Sintomas.Qualificado.Banda larga      0.982     0.986     0.984      2590
#                                        Sintomas.Genérico.Mudança      0.971     0.969     0.970       891
#                           Sintomas.Qualificado.Ausência de sinal      0.989     0.990     0.990     10158
#                          Sintomas.Qualificado.Cabos e conectores      0.988     0.988     0.988      1558
#                            Sintomas.Qualificado.Técnico não veio      0.900     0.894     0.897      1474
#                      Sintomas.Qualificado.NãoTéc ponto adicional      0.894     0.891     0.892      2049
#                         Sintomas.Qualificado.Mudança de endereço      0.974     0.971     0.972      3343
#                           Sintomas.Genérico.Canal Globo não pega      0.659     0.717     0.687       304
#                            Sintomas.Qualificado.Controle perdido      0.922     0.931     0.927       306
#                           Sintomas.Qualificado.Tela com chuvisco      0.827     0.880     0.853       234
#                          Sintomas.Genérico.Mudança de endereço G      0.992     0.994     0.993      2501
#                            Sintomas.Genérico.Problema com imagem      0.961     0.965     0.963      6605
#          Sintomas.Qualificado.Equipamento liga e desliga sozinho      0.882     0.875     0.879       455
#                                    Sintomas.Qualificado.Código 6      0.885     0.874     0.879       905
#                        Sintomas.Qualificado.Equipamento não liga      0.968     0.959     0.963      1816
#                                Sintomas.Qualificado.NãoTéc_plano      0.814     0.807     0.811      1683
#                           Sintomas.Qualificado.Programação local      0.887     0.911     0.899       380
#                                    Sintomas.Qualificado.Gravação      0.931     0.939     0.935       997
#                                  Sintomas.Qualificado.Sky Online      0.921     0.926     0.924      1926
#                       Sintomas.Genérico.Canal comum não pega (G)      0.846     0.836     0.841      1200
#                    Sintomas.Genérico.Problema com visita técnica      0.995     0.997     0.996      2193
#                        Sintomas.Genérico.Texto ou código na tela      0.864     0.856     0.860      1694
#                               Sintomas.Qualificado.Código 1-2-25      0.879     0.847     0.862       658
#                                  Sintomas.Qualificado.Tela preta      0.873     0.866     0.869       861
#                 Sintomas.Qualificado.Travado no canal do cliente      0.797     0.816     0.807       506
#              Sintomas.Qualificado.Controle não funciona para sky      0.778     0.784     0.781       125
#                    Sintomas.Qualificado.Apenas imagem, sem áudio      0.902     0.847     0.873       562
#               Sintomas.Qualificado.Canal PPV não está disponível      0.903     0.910     0.907      1016
#                         Sintomas.Qualificado.Evento indisponível      0.895     0.915     0.905       130
#                                   Sintomas.Qualificado.Código 56      0.983     0.985     0.984       585
#                       Sintomas.Qualificado.Priorizar atendimento      0.885     0.907     0.896      1140
#                             Sintomas.Genérico.Problema Controle2      0.930     0.945     0.938      1661
#                            Sintomas.Genérico.Canal HD não pega G      0.890     0.894     0.892       697
#                        Sintomas.Qualificado.Reativar programação      0.934     0.950     0.942        60
#                                   Sintomas.Qualificado.Código 77      0.889     0.919     0.904      1094
#                           Sintomas.Qualificado.NãoTéc upgrade hd      0.892     0.902     0.897       419
# Sintomas.Qualificado.Informações e confirmação de visita técnica      0.894     0.873     0.883       910
#                                    Sintomas.Qualificado.Código 4      0.890     0.894     0.892       980
#                      Sintomas.Qualificado.Agendar visita técnica      0.944     0.905     0.924       316
#                         Sintomas.Qualificado.Chip do equipamento      0.948     0.989     0.968        92
#                   Sintomas.Qualificado.Equipamento superaquecido      0.887     0.940     0.913        67
#                         Sintomas.Qualificado.Irritação ou Anatel      0.954     0.958     0.956       950
#                          Sintomas.Qualificado.Código diagnóstico      0.944     0.975     0.960       122
#                             Sintomas.Genérico.Tela monocromática      0.867     0.765     0.812       187
#                            Sintomas.Genérico.Entendimento errado      0.796     0.739     0.767       322
#                                        Sintomas.Genérico.Não sei      0.811     0.782     0.796       440
#                                     Sintomas.Genérico.Código sim      0.645     0.597     0.620        67
#             Sintomas.Qualificado.Atualização crítica de endereço      0.778     0.824     0.800        17
#                             Sintomas.Genérico.Problema com áudio      0.947     0.957     0.952       301
#                              Sintomas.Qualificado.Senha - padrão      0.775     0.775     0.775       120
#                                   Sintomas.Qualificado.Tela azul      0.846     0.903     0.874       134
#                   Sintomas.Qualificado.Mudança de posição antena      0.894     0.876     0.885       654
#                             Sintomas.Genérico.Problema de antena      0.880     0.880     0.880        83
#                              Sintomas.Qualificado.Aplicativo Sky      0.991     0.996     0.994       809
#                                  Sintomas.Genérico.Canal travado      0.875     0.895     0.885       477
#                 Sintomas.Qualificado.Resolvido com sinal booster      0.764     0.764     0.764       212
#                           Sintomas.Qualificado.Legenda incorreta      0.778     0.933     0.848        30
#                                  Sintomas.Qualificado.Código 109      0.968     0.978     0.973        93
#                         Sintomas.Qualificado.Equipamento travado      0.595     0.473     0.527        93
#                          Sintomas.Genérico.Mudança de instalação      1.000     1.000     1.000        98
#                        Sintomas.Genérico.Canal opcional não pega      0.793     0.811     0.802       222
#                                   Sintomas.Qualificado.Código 19      0.917     0.898     0.907        49
#                              Sintomas.Genérico.Mudança de antena      0.987     0.984     0.985       372
#                               Sintomas.Qualificado.NãoTéc_compra      0.817     0.760     0.787       129
#                            Sintomas.Qualificado.NãoTéc sky livre      0.903     0.953     0.927       127
#                       Sintomas.Qualificado.Reset de senha padrão      0.824     0.852     0.838       115
#                           Sintomas.Qualificado.Controle quebrado      0.835     0.732     0.780       138
#                                   Sintomas.Qualificado.Código 14      0.972     0.955     0.964       111
#                         Sintomas.Qualificado.Guia de programação      0.957     0.968     0.962       409
#                              Sintomas.Qualificado.Numeração nova      0.848     0.881     0.864       101
#                       Sintomas.Qualificado.TV é HD, mas Sky é SD      0.911     0.840     0.874       268
#                           Sintomas.Genérico.Sem sinal nem código      0.737     0.692     0.714       146
#                                Sintomas.Qualificado.Cancelar Sky      0.636     0.420     0.506        50
#                                     Sintomas.Qualificado.Recarga      0.714     0.741     0.727        27
#                        Sintomas.Qualificado.Novo Controle Pedido      0.889     0.822     0.854       146
#                        Sintomas.Qualificado.Equipamento queimado      0.816     0.816     0.816       147
#                             Sintomas.Genérico.Problema com senha      0.990     0.986     0.988       291
#                             Sintomas.Qualificado.NãoTéc_cadastro      0.848     0.784     0.815       292
#                          Sintomas.Qualificado.Criar senha padrão      0.812     0.650     0.722        20
#                               Sintomas.Qualificado.Alterar áudio      0.884     0.931     0.907       204
#                         Sintomas.Qualificado.Canal fora da grade      0.853     0.880     0.866       342
#                           Sintomas.Genérico.Problema com legenda      0.968     0.960     0.964       252
#                               Sintomas.Qualificado.Problema tudo      0.895     0.821     0.856       145
#                                    Sintomas.Qualificado.Código 9      1.000     0.556     0.714         9
#                       Sintomas.Qualificado.Imagem preto e branco      0.852     0.789     0.820        95
#                                Sintomas.Qualificado.Número da OS      0.000     0.000     0.000         2
#                      Sintomas.Genérico.Atualização de endereço G      0.958     0.908     0.932        76
#                  Sintomas.Qualificado.Habilitar recurso de senha      0.901     0.821     0.859        78
#                      Sintomas.Genérico.Canal adulto não pega (G)      0.828     0.706     0.762        34
#                    Sintomas.Genérico.Problema com troca de canal      0.231     0.158     0.187        19
#                          Sintomas.Qualificado.Cliente está longe      0.533     0.250     0.340        32
#     Sintomas.Qualificado.Procurando sinal sintonizador terrestre      0.871     0.871     0.871        31
#                       Sintomas.Qualificado.Equipamento com ruído      1.000     0.905     0.950        21
#                                   Sintomas.Qualificado.Código 13      1.000     0.826     0.905        23
#                          Sintomas.Qualificado.Travado exceto 200      0.500     0.059     0.105        17
#                 Sintomas.Qualificado.Legenda não aparece na tela      0.846     0.786     0.815        70
#                       Sintomas.Qualificado.Ativar closed caption      0.000     0.000     0.000         6
#                             Sintomas.Genérico.Promessa de oferta      0.500     0.231     0.316        13
#                        Sintomas.Qualificado.Ausência sinal geral      0.750     0.429     0.545        21
#                              Sintomas.Qualificado.Áudio atrasado      0.500     0.333     0.400         6
#                       Sintomas.Qualificado.Lentidão trocar canal      0.667     0.750     0.706         8
#                     Sintomas.Qualificado.Msg carregando conteúdo      0.000     0.000     0.000         3
#                    Sintomas.Genérico.Problema com closed caption      1.000     1.000     1.000         4
#
#                                                         accuracy                          0.943    133986
#                                                        macro avg      0.845     0.818     0.827    133986
#                                                     weighted avg      0.942     0.943     0.942    133986
