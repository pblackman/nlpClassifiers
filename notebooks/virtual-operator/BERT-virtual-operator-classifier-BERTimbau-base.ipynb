# %% [markdown]
# #### Based on https://medium.com/swlh/painless-fine-tuning-of-bert-in-pytorch-b91c14912caa
# https://github.com/aniruddhachoudhury/BERT-Tutorials/blob/master/Blog%202/BERT_Fine_Tuning_Sentence_Classification.ipynb

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import matplotlib.pyplot as plt
import torch.nn as nn
from os.path import join
import torch
from nlpClassifiers.data.dataset  import NLPDataset
#from torch.optim import AdamW, SGD
from torch.utils.data import DataLoader, SequentialSampler, RandomSampler
from transformers import BertForSequenceClassification, AdamW, BertConfig
from transformers import get_linear_schedule_with_warmup
from torch.nn import LayerNorm as BertLayerNorm
import numpy as np
import time
import logging
import datetime
import random
import pandas as pd
import argparse
import pickle as pk
import itertools
import os
import shutil
from pathlib import Path
import copy
import wandb
import re
from nlpClassifiers import settings
from scipy.special import expit
from sklearn.metrics import classification_report

# %%
def predict(
    model_path: Path,
    dataset: str,
    batch_size: int,
    labels_dict,
    device: torch.device
):
       
    print(f"====Loading dataset for testing")
    test_corpus = NLPDataset(dataset, "test", sentence_max_len, bert_path, labels_dict)
    test_dataloader = DataLoader(
        test_corpus,
        batch_size=batch_size,
        #sampler = RandomSampler(test_corpus),
        pin_memory=True,
        num_workers=0,
        drop_last=False
    )

    print(f"====Loading model for testing")
    model = BertForSequenceClassification.from_pretrained(
        model_path,
        num_labels = test_corpus.num_labels,
        output_attentions = False,
        output_hidden_states = False,
    )
    model.to(device)
    model.eval()
  #  cm = ConfusionMatrix([0,1])
    pred_labels = []
    test_labels = []
    logits_list = []

    def _list_from_tensor(tensor):
        if tensor.numel() == 1:
            return [tensor.item()]
        return list(tensor.cpu().detach().numpy())

    print("====Testing model...")
    for batch in test_dataloader:
        batch = tuple(t.to(device) for t in batch)
        b_input_ids, b_segment_ids, b_input_mask, b_labels = batch
        with torch.no_grad():
            loss, logits, *_ =  model(b_input_ids, b_input_mask, token_type_ids=None, labels=b_labels)

            preds = np.argmax(logits.cpu(), axis=1) # Convert one-hot to index
            b_labels = b_labels.int()
            pred_labels.extend(_list_from_tensor(preds))
            test_labels.extend(_list_from_tensor(b_labels))
        #logits_list.extend(_list_from_tensor(logits))
        logits_list.append(logits.cpu().detach().numpy()[0])
    print(classification_report(test_labels, pred_labels, labels=list(labels_dict.values()), target_names=np.array(list(labels_dict.keys())), digits=3))
    del model
    torch.cuda.empty_cache()
    return np.array(logits_list)

# %%
def get_accuracy_from_logits(logits, labels):
    acc = (labels.cpu() == logits.cpu().argmax(-1)).float().detach().numpy()
    return float(100 * acc.sum() / len(acc))

# %%
DATA_PATH = '../../data/virtual-operator'
TRAIN_DATASET = os.path.join(DATA_PATH, 'train.csv')
VAL_DATASET = os.path.join(DATA_PATH, 'val.csv')
TEST_DATASET  = os.path.join(DATA_PATH, 'test.csv')
bert_path =  'neuralmind/bert-base-portuguese-cased'

# %%
gpu = 0
dataset = 'virtual-operator'
model_path='../../models/virtual-operator/bert-base-portuguese-tapt-classifier/base-dataset-virtual-operator-virtual-operator-100-epochs-early-stop-reset-3-bertimbau-base'
batch_size = 16
sentence_max_len = 82

# %%
device = torch.device(f"cuda:{gpu}")

# %%
train_corpus = NLPDataset(dataset, "train", sentence_max_len, bert_path)
labels_dict = train_corpus.labels_dict

# %%
prediction = predict(model_path, dataset, batch_size, labels_dict, device)
# Out:
# ====Loading dataset for testing
# ====Loading model for testing
# ====Testing model...
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#                                                                   precision    recall  f1-score   support
#
#                               Sintomas.Genérico.Sky não funciona      0.966     0.954     0.960      8357
#                                     Sintomas.Genérico.Instalação      0.994     0.992     0.993       647
#                                 Sintomas.Genérico.Canal não pega      0.947     0.957     0.952      5967
#                     Sintomas.Genérico.Equipamento não funciona G      0.983     0.967     0.975      2318
#                                      Sintomas.Genérico.Sem sinal      0.978     0.970     0.974     14552
#                                Sintomas.Qualificado.Cancelamento      0.951     0.979     0.965      1847
#                            Sintomas.Qualificado.Outros problemas      0.916     0.856     0.885       729
#                               Sintomas.Qualificado.NãoTéc_fatura      0.918     0.924     0.921      1451
#                           Sintomas.Qualificado.Mudança de cômodo      0.979     0.976     0.977      1975
#                         Sintomas.Genérico.Equipamento queimado G      0.979     0.996     0.988      2106
#                       Sintomas.Genérico.Problema com equipamento      0.988     0.993     0.991      9645
#                         Sintomas.Genérico.Equipamento quebrado G      0.983     0.978     0.981      1441
#               Sintomas.Qualificado.Controle não funciona para tv      0.842     0.897     0.869       107
#                            Sintomas.Genérico.Falar com atendente      0.986     0.984     0.985      8262
#                             Sintomas.Genérico.Problema com canal      0.984     0.977     0.980      3547
#                        Sintomas.Qualificado.Técnico não resolveu      0.788     0.571     0.662        91
#                           Sintomas.Genérico.Troca de equipamento      0.978     0.978     0.978      3737
#                               Sintomas.Qualificado.NãoTéc_outros      0.824     0.882     0.852       186
#                                 Sintomas.Qualificado.Banda larga      0.982     0.993     0.988      2590
#                                        Sintomas.Genérico.Mudança      0.975     0.970     0.972       891
#                           Sintomas.Qualificado.Ausência de sinal      0.991     0.995     0.993     10158
#                          Sintomas.Qualificado.Cabos e conectores      0.982     0.993     0.987      1558
#                            Sintomas.Qualificado.Técnico não veio      0.930     0.921     0.926      1474
#                      Sintomas.Qualificado.NãoTéc ponto adicional      0.953     0.932     0.942      2049
#                         Sintomas.Qualificado.Mudança de endereço      0.983     0.985     0.984      3343
#                           Sintomas.Genérico.Canal Globo não pega      0.729     0.859     0.789       304
#                            Sintomas.Qualificado.Controle perdido      0.962     0.984     0.973       306
#                           Sintomas.Qualificado.Tela com chuvisco      0.869     0.910     0.889       234
#                          Sintomas.Genérico.Mudança de endereço G      0.994     0.996     0.995      2501
#                            Sintomas.Genérico.Problema com imagem      0.986     0.977     0.982      6605
#          Sintomas.Qualificado.Equipamento liga e desliga sozinho      0.952     0.956     0.954       455
#                                    Sintomas.Qualificado.Código 6      0.937     0.936     0.936       905
#                        Sintomas.Qualificado.Equipamento não liga      0.977     0.985     0.981      1816
#                                Sintomas.Qualificado.NãoTéc_plano      0.886     0.896     0.891      1683
#                           Sintomas.Qualificado.Programação local      0.940     0.911     0.925       380
#                                    Sintomas.Qualificado.Gravação      0.978     0.976     0.977       997
#                                  Sintomas.Qualificado.Sky Online      0.938     0.962     0.950      1926
#                       Sintomas.Genérico.Canal comum não pega (G)      0.925     0.861     0.892      1200
#                    Sintomas.Genérico.Problema com visita técnica      0.996     1.000     0.998      2193
#                        Sintomas.Genérico.Texto ou código na tela      0.938     0.898     0.918      1694
#                               Sintomas.Qualificado.Código 1-2-25      0.930     0.970     0.949       658
#                                  Sintomas.Qualificado.Tela preta      0.933     0.886     0.909       861
#                 Sintomas.Qualificado.Travado no canal do cliente      0.806     0.911     0.855       506
#              Sintomas.Qualificado.Controle não funciona para sky      0.759     0.856     0.805       125
#                    Sintomas.Qualificado.Apenas imagem, sem áudio      0.941     0.941     0.941       562
#               Sintomas.Qualificado.Canal PPV não está disponível      0.934     0.976     0.955      1016
#                         Sintomas.Qualificado.Evento indisponível      0.903     0.931     0.917       130
#                                   Sintomas.Qualificado.Código 56      0.960     0.993     0.976       585
#                       Sintomas.Qualificado.Priorizar atendimento      0.964     0.952     0.958      1140
#                             Sintomas.Genérico.Problema Controle2      0.972     0.945     0.958      1661
#                            Sintomas.Genérico.Canal HD não pega G      0.938     0.931     0.934       697
#                        Sintomas.Qualificado.Reativar programação      0.968     1.000     0.984        60
#                                   Sintomas.Qualificado.Código 77      0.914     0.942     0.928      1094
#                           Sintomas.Qualificado.NãoTéc upgrade hd      0.869     0.964     0.914       419
# Sintomas.Qualificado.Informações e confirmação de visita técnica      0.889     0.969     0.927       910
#                                    Sintomas.Qualificado.Código 4      0.954     0.952     0.953       980
#                      Sintomas.Qualificado.Agendar visita técnica      0.959     0.956     0.957       316
#                         Sintomas.Qualificado.Chip do equipamento      0.946     0.957     0.951        92
#                   Sintomas.Qualificado.Equipamento superaquecido      0.942     0.970     0.956        67
#                         Sintomas.Qualificado.Irritação ou Anatel      0.984     0.985     0.985       950
#                          Sintomas.Qualificado.Código diagnóstico      1.000     1.000     1.000       122
#                             Sintomas.Genérico.Tela monocromática      0.908     0.840     0.872       187
#                            Sintomas.Genérico.Entendimento errado      0.895     0.870     0.882       322
#                                        Sintomas.Genérico.Não sei      0.910     0.845     0.876       440
#                                     Sintomas.Genérico.Código sim      0.868     0.881     0.874        67
#             Sintomas.Qualificado.Atualização crítica de endereço      0.737     0.824     0.778        17
#                             Sintomas.Genérico.Problema com áudio      0.961     0.977     0.969       301
#                              Sintomas.Qualificado.Senha - padrão      0.862     0.883     0.872       120
#                                   Sintomas.Qualificado.Tela azul      0.896     0.896     0.896       134
#                   Sintomas.Qualificado.Mudança de posição antena      0.962     0.884     0.921       654
#                             Sintomas.Genérico.Problema de antena      0.826     0.916     0.869        83
#                              Sintomas.Qualificado.Aplicativo Sky      0.989     0.998     0.993       809
#                                  Sintomas.Genérico.Canal travado      0.936     0.925     0.930       477
#                 Sintomas.Qualificado.Resolvido com sinal booster      0.879     0.858     0.869       212
#                           Sintomas.Qualificado.Legenda incorreta      0.900     0.900     0.900        30
#                                  Sintomas.Qualificado.Código 109      0.959     1.000     0.979        93
#                         Sintomas.Qualificado.Equipamento travado      0.791     0.731     0.760        93
#                          Sintomas.Genérico.Mudança de instalação      0.990     1.000     0.995        98
#                        Sintomas.Genérico.Canal opcional não pega      0.910     0.824     0.865       222
#                                   Sintomas.Qualificado.Código 19      0.957     0.918     0.938        49
#                              Sintomas.Genérico.Mudança de antena      0.987     0.989     0.988       372
#                               Sintomas.Qualificado.NãoTéc_compra      0.898     0.953     0.925       129
#                            Sintomas.Qualificado.NãoTéc sky livre      0.907     1.000     0.951       127
#                       Sintomas.Qualificado.Reset de senha padrão      0.893     0.870     0.881       115
#                           Sintomas.Qualificado.Controle quebrado      0.826     0.891     0.857       138
#                                   Sintomas.Qualificado.Código 14      0.982     0.991     0.987       111
#                         Sintomas.Qualificado.Guia de programação      0.964     0.995     0.980       409
#                              Sintomas.Qualificado.Numeração nova      0.825     0.931     0.874       101
#                       Sintomas.Qualificado.TV é HD, mas Sky é SD      0.964     0.910     0.937       268
#                           Sintomas.Genérico.Sem sinal nem código      0.803     0.836     0.819       146
#                                Sintomas.Qualificado.Cancelar Sky      0.810     0.680     0.739        50
#                                     Sintomas.Qualificado.Recarga      0.840     0.778     0.808        27
#                        Sintomas.Qualificado.Novo Controle Pedido      0.919     0.932     0.925       146
#                        Sintomas.Qualificado.Equipamento queimado      0.905     0.905     0.905       147
#                             Sintomas.Genérico.Problema com senha      0.990     0.997     0.993       291
#                             Sintomas.Qualificado.NãoTéc_cadastro      0.872     0.884     0.878       292
#                          Sintomas.Qualificado.Criar senha padrão      0.947     0.900     0.923        20
#                               Sintomas.Qualificado.Alterar áudio      0.925     0.961     0.942       204
#                         Sintomas.Qualificado.Canal fora da grade      0.887     0.968     0.926       342
#                           Sintomas.Genérico.Problema com legenda      0.988     0.984     0.986       252
#                               Sintomas.Qualificado.Problema tudo      0.957     0.924     0.940       145
#                                    Sintomas.Qualificado.Código 9      1.000     1.000     1.000         9
#                       Sintomas.Qualificado.Imagem preto e branco      0.865     0.874     0.869        95
#                                Sintomas.Qualificado.Número da OS      0.000     0.000     0.000         2
#                      Sintomas.Genérico.Atualização de endereço G      0.936     0.961     0.948        76
#                  Sintomas.Qualificado.Habilitar recurso de senha      0.793     0.885     0.836        78
#                      Sintomas.Genérico.Canal adulto não pega (G)      0.730     0.794     0.761        34
#                    Sintomas.Genérico.Problema com troca de canal      0.571     0.421     0.485        19
#                          Sintomas.Qualificado.Cliente está longe      0.600     0.375     0.462        32
#     Sintomas.Qualificado.Procurando sinal sintonizador terrestre      0.879     0.935     0.906        31
#                       Sintomas.Qualificado.Equipamento com ruído      1.000     0.810     0.895        21
#                                   Sintomas.Qualificado.Código 13      1.000     0.957     0.978        23
#                          Sintomas.Qualificado.Travado exceto 200      0.611     0.647     0.629        17
#                 Sintomas.Qualificado.Legenda não aparece na tela      0.883     0.971     0.925        70
#                       Sintomas.Qualificado.Ativar closed caption      0.000     0.000     0.000         6
#                             Sintomas.Genérico.Promessa de oferta      0.235     0.308     0.267        13
#                        Sintomas.Qualificado.Ausência sinal geral      1.000     0.714     0.833        21
#                              Sintomas.Qualificado.Áudio atrasado      0.375     0.500     0.429         6
#                       Sintomas.Qualificado.Lentidão trocar canal      0.545     0.750     0.632         8
#                     Sintomas.Qualificado.Msg carregando conteúdo      1.000     1.000     1.000         3
#                    Sintomas.Genérico.Problema com closed caption      1.000     1.000     1.000         4
#
#                                                         accuracy                          0.965    133986
#                                                        macro avg      0.888     0.891     0.888    133986
#                                                     weighted avg      0.965     0.965     0.965    133986
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
