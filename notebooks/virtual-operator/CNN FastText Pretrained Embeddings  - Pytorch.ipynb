# %%
from os.path import join
import os
import pandas as pd
import torch
import numpy as np
import torch.nn as nn
import torch.nn.functional as F
from torch.optim.lr_scheduler import ReduceLROnPlateau
from torch.nn.init import kaiming_uniform_
from torch.optim import SGD
from torch.utils.data import DataLoader, SequentialSampler, RandomSampler
from torch.optim import Adam
from nlpClassifiers.data.dataset  import NLPDataset, Vocabulary
from sklearn.metrics import roc_curve, auc, classification_report
from scipy.special import expit
import gensim
import shutil
from pathlib import Path
import random

# %%
ROOT = '../../'
PATH_TO_VIRTUAL_OPERATOR_DATA = join(ROOT, "data/virtual-operator")
PATH_TO_AGENT_BENCHMARK_DATA = join(ROOT, "data/agent-benchmark")
PATH_TO_ML_PT_DATA = join(ROOT, "data/mercado-livre-pt-only")

PATH_TO_VIRTUAL_OPERATOR_MODELS = join(ROOT, "models/virtual-operator")
PATH_TO_AGENT_BENCHMARK_MODELS = join(ROOT, "models/agent-benchmark")
PATH_TO_ML_PT_MODELS = join(ROOT, "models/mercado-livre-pt-only")

EMBEDDING_DIM = 300
EMBEDDINGS_FILE = '../../data/fasttext-embeddings/wiki.pt.vec'
MAX_WORDS = 30000
dataset = 'virtual-operator'
sentence_max_len = 82
batch_size = 512

epochs=30
stopwords_lang = None
gpu=1
lr=0.001
clipping_value=0.25
save_name='cnn-pytorch-fasttext-embeddings'
patience=5

# %%
BASE_PATH_TO_MODELS = {"virtual-operator": PATH_TO_VIRTUAL_OPERATOR_MODELS, "agent-benchmark": PATH_TO_AGENT_BENCHMARK_MODELS, "mercado-livre-pt": PATH_TO_ML_PT_MODELS}
FULL_PATH_TO_MODELS = join(BASE_PATH_TO_MODELS[dataset], "bow-classifier")

# %%
def _init_fn(worker_id):
    np.random.seed(seed)

# %%
def read_data(dataset, subset):
    BASE_PATH_TO_DATASET = {"virtual-operator": PATH_TO_VIRTUAL_OPERATOR_DATA, "agent-benchmark": PATH_TO_AGENT_BENCHMARK_DATA, "mercado-livre-pt": PATH_TO_ML_PT_DATA}
    BASE_PATH_TO_DATASET = {"train": join(BASE_PATH_TO_DATASET[dataset], "train.csv"), "val": join(BASE_PATH_TO_DATASET[dataset], "val.csv"), "test": join(BASE_PATH_TO_DATASET[dataset], "test.csv")}
    FULL_PATH_TO_DATASET = BASE_PATH_TO_DATASET[subset]
    
    if dataset == "mercado-livre-pt":
        sep=","
    else:
        sep=";"
    data = pd.read_csv(FULL_PATH_TO_DATASET, sep=sep, names =['utterance','label'], header=None, dtype={'utterance':str, 'label': str} )
    return data

# %%
train_df = read_data(dataset, "train")
val_df = read_data(dataset, "val")

# %%
voc = Vocabulary('CNN', stopwords_lang)
voc.build_vocab(train_df['utterance'].tolist() +  val_df['utterance'].tolist(), MAX_WORDS)
embedding_weights = voc.load_embeddings(EMBEDDINGS_FILE, EMBEDDING_DIM)
if voc.num_words < MAX_WORDS or MAX_WORDS == 0:
    MAX_WORDS = voc.num_words
# Out:
# 4456 tokens not found in vocabulary.

# %%
train_corpus = NLPDataset(dataset, "train", sentence_max_len, vocab= voc)
labels_dict = train_corpus.labels_dict
val_corpus = NLPDataset(dataset, "val", sentence_max_len, labels_dict = labels_dict, vocab= voc)

# %%
train_dataloader = DataLoader(
            train_corpus,
            sampler = RandomSampler(train_corpus),
            batch_size = batch_size,
            pin_memory=True,
            worker_init_fn=_init_fn,
            num_workers=0
)

validation_dataloader = DataLoader(
            val_corpus,
            sampler = RandomSampler(val_corpus),
            batch_size = batch_size,
            pin_memory=True,
            worker_init_fn=_init_fn,
            num_workers=0
)

# %%
def initialize_weights(model):
    if type(model) in [nn.Linear]:
        nn.init.xavier_normal_(model.weight.data)
    elif type(model) in [nn.LSTM, nn.RNN, nn.GRU]:
        nn.init.xavier_normal_(model.weight_hh_l0)
        nn.init.xavier_normal_(model.weight_ih_l0)

# %%
#del model
torch.cuda.empty_cache()

# %%
def seed_everything(seed=10):
    random.seed(seed)
    os.environ['PYTHONHASHSEED'] = str(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    torch.backends.cudnn.deterministic = True

# %%
seed_everything()

# %%
class CNNNet(nn.Module):
    def __init__(self, num_classes, num_features, criterion, embedding_dim, embedding_weights=None):
        super(CNNNet, self).__init__()
        self.criterion = criterion
        self.embedding_dim = embedding_dim
        self.n_layers = 1
        self.embedding = nn.Embedding(num_features, embedding_dim, padding_idx = 0)
        if(embedding_weights is not None):
            print("Embedding layer Weights won't be updated.")
            self.embedding.load_state_dict({'weight': embedding_weights})
            self.embedding.weight.requires_grad = False
            #self.embedding.from_pretrained(embedding_weights, freeze=True)
        else:
            self.embedding.weight.data = torch.zeros(self.embedding.weight.data.size())
            self.embedding.weight.requires_grad = True
        
        self.cnn = nn.Conv1d(embedding_dim, 256, 4)
        
        for name, param in self.cnn.named_parameters():
            if 'bias' in name:
                nn.init.constant_(param, 0.0)
            elif 'weight_ih' in name:
                nn.init.kaiming_normal_(param)
            elif 'weight_hh' in name:
                nn.init.orthogonal_(param)
             
        self.dropout = nn.Dropout(0.2)       
        self.out = nn.Linear(256, num_classes)
        self.init_weights()
    def forward(self, x, y):
        # Conv1d takes in (batch, channels, seq_len), but raw embedded is (batch, seq_len, channels)
        h_embedding = self.embedding(x)
        h_embedding = h_embedding.permute(0, 2, 1)
        h_cnn = self.cnn(h_embedding)
        h_cnn = h_cnn.permute(0, 2, 1)
        h_cnn = self.dropout(h_cnn)
        h_max_pool = self.global_max_pool(h_cnn)
        x = self.out(h_max_pool)
        loss = self.criterion(x, y)
        # return the final output
        return loss,x 
    
    @staticmethod
    def global_max_pool(x):
        """Convolution and global max pooling layer"""
        return x.max(1)[0]
    
    def init_weights(self):
        """
        Here we reproduce Keras default initialization weights to initialize Embeddings/LSTM weights
        """
        ih = (param.data for name, param in self.named_parameters() if 'weight_ih' in name)
        hh = (param.data for name, param in self.named_parameters() if 'weight_hh' in name)
        b = (param.data for name, param in self.named_parameters() if 'bias' in name)
        for t in ih:
            nn.init.xavier_uniform(t)
        for t in hh:
            nn.init.orthogonal(t)
        for t in b:
            nn.init.constant(t, 0)
    
    def init_hidden(self, batch_size, device):
        weight = next(self.parameters()).data
        hidden = (weight.new(self.n_layers, batch_size, self.embedding_dim).zero_().to(device),
                      weight.new(self.n_layers, batch_size, self.embedding_dim).zero_().to(device))
        return hidden

# %%
criterion = torch.nn.CrossEntropyLoss()
model = CNNNet(train_corpus.num_labels, MAX_WORDS, criterion, EMBEDDING_DIM, embedding_weights)
# Out:
# Embedding layer Weights won't be updated.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:60: UserWarning: nn.init.constant is now deprecated in favor of nn.init.constant_.

# %%
model.apply(initialize_weights)
# Out:
# CNNNet(
#   (criterion): CrossEntropyLoss()
#   (embedding): Embedding(22418, 300, padding_idx=0)
#   (cnn): Conv1d(300, 256, kernel_size=(4,), stride=(1,))
#   (dropout): Dropout(p=0.2, inplace=False)
#   (out): Linear(in_features=256, out_features=121, bias=True)
# )

# %%
device = torch.device(f"cuda:{gpu}")

# %%
model = model.to(device)
optimizer = Adam(model.parameters(),lr, betas=(0.7, 0.999))

# %%
def multi_acc(y_pred, y_test):
    y_pred_softmax = torch.log_softmax(y_pred, dim = 1)
    _, y_pred_tags = torch.max(y_pred_softmax, dim = 1)    
    
    correct_pred = (y_pred_tags == y_test).float()
    acc = correct_pred.sum() / len(correct_pred)
    acc = acc * 100.0

    return acc

# %%
def get_accuracy_from_logits(logits, labels):
    acc = (labels.cpu() == logits.cpu().argmax(-1)).float().detach().numpy()
    return float(100 * acc.sum() / len(acc))

# %%
scheduler = ReduceLROnPlateau(optimizer, mode='min', patience=3,verbose=True, factor=0.1)

best_epoch = -1
last_saved_model = ""
training_stats = []
global_step = 0
best_val_acc = float("-inf")
best_model_wts = None
best_curr_val = 0

for epoch_i in range(0, epochs):
    print("")
    print('======== Epoch {:} / {:} ========'.format(epoch_i + 1, epochs))
    print('Training...')
    total_train_loss = 0
    model.train()
    for step, batch in enumerate(train_dataloader):
        #val_h = model.init_hidden(len(batch[0]), device)
        #val_h = tuple([each.data for each in val_h])
         # Progress update every 40 batches.
        if step % 40 == 0 and not step == 0:
            print('  Batch {:>5,}  of  {:>5,}.    .'.format(step, len(train_dataloader)))
        b_input_ids = batch[0]
        b_labels = batch[1].to(device)
        b_input_ids = torch.tensor(b_input_ids).to(device).long()
        model.zero_grad()
        loss, logits = model(b_input_ids, b_labels)
        loss.backward()
        torch.nn.utils.clip_grad_norm_(model.parameters(), clipping_value)
        optimizer.step()
        step_loss = loss.item()
        if step % 40 == 0 and not step == 0:
            print("  step loss: {0:.2f}".format(step_loss))
        total_train_loss += step_loss
        global_step += 1
    avg_train_loss = total_train_loss / len(train_dataloader)
    # Measure how long this epoch took.
    print("")
    print("  Average training loss: {0:.2f}".format(avg_train_loss))

    print("")
    print("Running Validation...")
    model.eval()

    # Tracking variables
    total_eval_accuracy = 0.0
    total_eval_loss = 0
    nb_eval_steps = 0
    for step, batch in enumerate(validation_dataloader):
        #val_h = model.init_hidden(len(batch[0]), device)
        #val_h = tuple([each.data for each in val_h])
        b_input_ids = batch[0]
        b_input_ids = torch.tensor(b_input_ids).to(device).long()
        b_labels = batch[1].to(device)
        with torch.no_grad():
            # Forward pass, calculate logit predictions.
            loss, logits = model(b_input_ids, b_labels)
        total_eval_loss += loss
        batch_acc = get_accuracy_from_logits(logits, b_labels)
        batch_acc2 = multi_acc(logits, b_labels)
        print("Batch accuracy: {0:.2f}".format(batch_acc))
        total_eval_accuracy += batch_acc
    
    # Calculate the average loss over all of the batches.
    avg_val_accuracy = total_eval_accuracy / len(validation_dataloader)
    print("  Accuracy: {0:.2f}".format(avg_val_accuracy))
    
    if avg_val_accuracy > best_val_acc:
        print(f"New best model, saving it!")
        if avg_val_accuracy > best_curr_val:
            best_curr_val = avg_val_accuracy
        if last_saved_model:
            shutil.rmtree(last_saved_model)
        model_path = Path(
            FULL_PATH_TO_MODELS,
            f"base-dataset-{dataset}-{save_name}"
        )
        last_saved_model = model_path
        model_path.mkdir(parents=True, exist_ok=True)
        best_val_acc = avg_val_accuracy
        torch.save(model, join(model_path, "best-model.pth"))
        best_epoch = epoch_i
        n_epochs_no_improvement = 0
    elif avg_val_accuracy > best_curr_val:
        best_curr_val = avg_val_accuracy
        n_epochs_no_improvement = 0
    else:
        n_epochs_no_improvement += 1
        print(f"The model does not improve for {n_epochs_no_improvement} epochs!")

    if n_epochs_no_improvement > patience:
        print(f"====>Stopping training, the model did not improve for {n_epochs_no_improvement}\n====>Best epoch: {best_epoch + 1}.")
        break
    scheduler.step(total_eval_loss)
print("")
print("Training complete!")
# Out:
# ======== Epoch 1 / 30 ========
# Training...
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:25: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   Batch    40  of    943.    .
#   step loss: 1.62
#   Batch    80  of    943.    .
#   step loss: 1.15
#   Batch   120  of    943.    .
#   step loss: 1.03
#   Batch   160  of    943.    .
#   step loss: 0.97
#   Batch   200  of    943.    .
#   step loss: 0.89
#   Batch   240  of    943.    .
#   step loss: 0.85
#   Batch   280  of    943.    .
#   step loss: 0.75
#   Batch   320  of    943.    .
#   step loss: 0.77
#   Batch   360  of    943.    .
#   step loss: 0.59
#   Batch   400  of    943.    .
#   step loss: 0.67
#   Batch   440  of    943.    .
#   step loss: 0.62
#   Batch   480  of    943.    .
#   step loss: 0.55
#   Batch   520  of    943.    .
#   step loss: 0.52
#   Batch   560  of    943.    .
#   step loss: 0.61
#   Batch   600  of    943.    .
#   step loss: 0.59
#   Batch   640  of    943.    .
#   step loss: 0.60
#   Batch   680  of    943.    .
#   step loss: 0.47
#   Batch   720  of    943.    .
#   step loss: 0.49
#   Batch   760  of    943.    .
#   step loss: 0.46
#   Batch   800  of    943.    .
#   step loss: 0.50
#   Batch   840  of    943.    .
#   step loss: 0.54
#   Batch   880  of    943.    .
#   step loss: 0.53
#   Batch   920  of    943.    .
#   step loss: 0.48
#
#   Average training loss: 0.76
#
# Running Validation...
# Batch accuracy: 88.09
# Batch accuracy: 89.45
# Batch accuracy: 87.11
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:53: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
# Batch accuracy: 86.52
# Batch accuracy: 88.87
# Batch accuracy: 86.13
# Batch accuracy: 87.30
# Batch accuracy: 86.13
# Batch accuracy: 85.16
# Batch accuracy: 87.30
# Batch accuracy: 87.70
# Batch accuracy: 90.82
# Batch accuracy: 90.82
# Batch accuracy: 88.67
# Batch accuracy: 86.52
# Batch accuracy: 88.28
# Batch accuracy: 87.30
# Batch accuracy: 89.06
# Batch accuracy: 86.13
# Batch accuracy: 88.09
# Batch accuracy: 89.06
# Batch accuracy: 86.72
# Batch accuracy: 89.45
# Batch accuracy: 88.09
# Batch accuracy: 86.72
# Batch accuracy: 87.50
# Batch accuracy: 90.04
# Batch accuracy: 87.89
# Batch accuracy: 87.70
# Batch accuracy: 86.72
# Batch accuracy: 86.52
# Batch accuracy: 87.30
# Batch accuracy: 86.72
# Batch accuracy: 86.52
# Batch accuracy: 87.50
# Batch accuracy: 89.06
# Batch accuracy: 86.72
# Batch accuracy: 84.38
# Batch accuracy: 87.50
# Batch accuracy: 87.11
# Batch accuracy: 87.30
# Batch accuracy: 90.04
# Batch accuracy: 85.74
# Batch accuracy: 86.33
# Batch accuracy: 87.70
# Batch accuracy: 88.28
# Batch accuracy: 88.67
# Batch accuracy: 90.04
# Batch accuracy: 87.30
# Batch accuracy: 85.74
# Batch accuracy: 85.74
# Batch accuracy: 89.45
# Batch accuracy: 88.09
# Batch accuracy: 88.09
# Batch accuracy: 88.09
# Batch accuracy: 87.50
# Batch accuracy: 89.65
# Batch accuracy: 88.48
# Batch accuracy: 86.52
# Batch accuracy: 89.26
# Batch accuracy: 89.84
# Batch accuracy: 86.13
# Batch accuracy: 86.52
# Batch accuracy: 85.74
# Batch accuracy: 90.04
# Batch accuracy: 87.11
# Batch accuracy: 84.57
# Batch accuracy: 88.48
# Batch accuracy: 87.11
# Batch accuracy: 89.45
# Batch accuracy: 86.33
# Batch accuracy: 86.33
# Batch accuracy: 88.28
# Batch accuracy: 87.50
# Batch accuracy: 90.04
# Batch accuracy: 86.72
# Batch accuracy: 87.89
# Batch accuracy: 87.70
# Batch accuracy: 86.52
# Batch accuracy: 86.52
# Batch accuracy: 90.23
# Batch accuracy: 85.94
# Batch accuracy: 87.50
# Batch accuracy: 88.28
# Batch accuracy: 89.26
# Batch accuracy: 89.45
# Batch accuracy: 84.38
# Batch accuracy: 90.82
# Batch accuracy: 90.23
# Batch accuracy: 88.48
# Batch accuracy: 86.91
# Batch accuracy: 89.45
# Batch accuracy: 87.50
# Batch accuracy: 88.09
# Batch accuracy: 86.91
# Batch accuracy: 87.50
# Batch accuracy: 89.65
# Batch accuracy: 89.84
# Batch accuracy: 85.55
# Batch accuracy: 88.48
# Batch accuracy: 87.50
# Batch accuracy: 89.06
# Batch accuracy: 87.89
# Batch accuracy: 88.28
# Batch accuracy: 87.03
#   Accuracy: 87.77
# New best model, saving it!
#
# ======== Epoch 2 / 30 ========
# Training...
#   Batch    40  of    943.    .
#   step loss: 0.42
#   Batch    80  of    943.    .
#   step loss: 0.43
#   Batch   120  of    943.    .
#   step loss: 0.45
#   Batch   160  of    943.    .
#   step loss: 0.42
#   Batch   200  of    943.    .
#   step loss: 0.40
#   Batch   240  of    943.    .
#   step loss: 0.50
#   Batch   280  of    943.    .
#   step loss: 0.42
#   Batch   320  of    943.    .
#   step loss: 0.44
#   Batch   360  of    943.    .
#   step loss: 0.45
#   Batch   400  of    943.    .
#   step loss: 0.46
#   Batch   440  of    943.    .
#   step loss: 0.40
#   Batch   480  of    943.    .
#   step loss: 0.38
#   Batch   520  of    943.    .
#   step loss: 0.38
#   Batch   560  of    943.    .
#   step loss: 0.43
#   Batch   600  of    943.    .
#   step loss: 0.51
#   Batch   640  of    943.    .
#   step loss: 0.44
#   Batch   680  of    943.    .
#   step loss: 0.41
#   Batch   720  of    943.    .
#   step loss: 0.41
#   Batch   760  of    943.    .
#   step loss: 0.44
#   Batch   800  of    943.    .
#   step loss: 0.38
#   Batch   840  of    943.    .
#   step loss: 0.35
#   Batch   880  of    943.    .
#   step loss: 0.38
#   Batch   920  of    943.    .
#   step loss: 0.34
#
#   Average training loss: 0.42
#
# Running Validation...
# Batch accuracy: 90.04
# Batch accuracy: 90.62
# Batch accuracy: 89.06
# Batch accuracy: 89.45
# Batch accuracy: 91.41
# Batch accuracy: 90.82
# Batch accuracy: 88.28
# Batch accuracy: 89.26
# Batch accuracy: 87.11
# Batch accuracy: 89.06
# Batch accuracy: 90.62
# Batch accuracy: 88.09
# Batch accuracy: 90.04
# Batch accuracy: 89.84
# Batch accuracy: 90.04
# Batch accuracy: 90.82
# Batch accuracy: 89.84
# Batch accuracy: 87.30
# Batch accuracy: 89.06
# Batch accuracy: 89.26
# Batch accuracy: 90.62
# Batch accuracy: 89.06
# Batch accuracy: 88.28
# Batch accuracy: 90.62
# Batch accuracy: 89.65
# Batch accuracy: 88.28
# Batch accuracy: 88.28
# Batch accuracy: 89.65
# Batch accuracy: 90.04
# Batch accuracy: 90.04
# Batch accuracy: 90.82
# Batch accuracy: 91.02
# Batch accuracy: 90.23
# Batch accuracy: 88.09
# Batch accuracy: 89.65
# Batch accuracy: 89.26
# Batch accuracy: 86.91
# Batch accuracy: 89.45
# Batch accuracy: 87.89
# Batch accuracy: 90.23
# Batch accuracy: 89.26
# Batch accuracy: 87.50
# Batch accuracy: 89.65
# Batch accuracy: 89.06
# Batch accuracy: 88.67
# Batch accuracy: 89.65
# Batch accuracy: 91.21
# Batch accuracy: 90.82
# Batch accuracy: 90.04
# Batch accuracy: 87.30
# Batch accuracy: 92.97
# Batch accuracy: 89.26
# Batch accuracy: 88.67
# Batch accuracy: 87.89
# Batch accuracy: 89.26
# Batch accuracy: 89.84
# Batch accuracy: 91.60
# Batch accuracy: 88.48
# Batch accuracy: 89.45
# Batch accuracy: 91.21
# Batch accuracy: 90.04
# Batch accuracy: 88.48
# Batch accuracy: 88.87
# Batch accuracy: 89.26
# Batch accuracy: 89.84
# Batch accuracy: 89.06
# Batch accuracy: 91.02
# Batch accuracy: 87.70
# Batch accuracy: 90.04
# Batch accuracy: 90.23
# Batch accuracy: 90.82
# Batch accuracy: 88.09
# Batch accuracy: 87.11
# Batch accuracy: 90.82
# Batch accuracy: 86.52
# Batch accuracy: 88.87
# Batch accuracy: 88.48
# Batch accuracy: 89.06
# Batch accuracy: 88.48
# Batch accuracy: 89.26
# Batch accuracy: 87.30
# Batch accuracy: 89.45
# Batch accuracy: 88.28
# Batch accuracy: 91.60
# Batch accuracy: 90.23
# Batch accuracy: 90.43
# Batch accuracy: 90.43
# Batch accuracy: 89.65
# Batch accuracy: 91.99
# Batch accuracy: 91.02
# Batch accuracy: 89.26
# Batch accuracy: 90.43
# Batch accuracy: 89.65
# Batch accuracy: 89.06
# Batch accuracy: 88.67
# Batch accuracy: 92.77
# Batch accuracy: 88.67
# Batch accuracy: 88.48
# Batch accuracy: 91.02
# Batch accuracy: 89.45
# Batch accuracy: 86.52
# Batch accuracy: 89.26
# Batch accuracy: 90.23
# Batch accuracy: 87.11
# Batch accuracy: 93.37
#   Accuracy: 89.49
# New best model, saving it!
#
# ======== Epoch 3 / 30 ========
# Training...
#   Batch    40  of    943.    .
#   step loss: 0.39
#   Batch    80  of    943.    .
#   step loss: 0.34
#   Batch   120  of    943.    .
#   step loss: 0.27
#   Batch   160  of    943.    .
#   step loss: 0.38
#   Batch   200  of    943.    .
#   step loss: 0.33
#   Batch   240  of    943.    .
#   step loss: 0.39
#   Batch   280  of    943.    .
#   step loss: 0.35
#   Batch   320  of    943.    .
#   step loss: 0.37
#   Batch   360  of    943.    .
#   step loss: 0.41
#   Batch   400  of    943.    .
#   step loss: 0.37
#   Batch   440  of    943.    .
#   step loss: 0.37
#   Batch   480  of    943.    .
#   step loss: 0.41
#   Batch   520  of    943.    .
#   step loss: 0.33
#   Batch   560  of    943.    .
#   step loss: 0.33
#   Batch   600  of    943.    .
#   step loss: 0.36
#   Batch   640  of    943.    .
#   step loss: 0.41
#   Batch   680  of    943.    .
#   step loss: 0.29
#   Batch   720  of    943.    .
#   step loss: 0.37
#   Batch   760  of    943.    .
#   step loss: 0.35
#   Batch   800  of    943.    .
#   step loss: 0.33
#   Batch   840  of    943.    .
#   step loss: 0.33
#   Batch   880  of    943.    .
#   step loss: 0.39
#   Batch   920  of    943.    .
#   step loss: 0.36
#
#   Average training loss: 0.36
#
# Running Validation...
# Batch accuracy: 88.87
# Batch accuracy: 92.58
# Batch accuracy: 90.62
# Batch accuracy: 87.70
# Batch accuracy: 89.06
# Batch accuracy: 90.04
# Batch accuracy: 92.58
# Batch accuracy: 89.26
# Batch accuracy: 89.26
# Batch accuracy: 91.80
# Batch accuracy: 89.45
# Batch accuracy: 90.43
# Batch accuracy: 89.45
# Batch accuracy: 91.41
# Batch accuracy: 90.62
# Batch accuracy: 88.28
# Batch accuracy: 91.41
# Batch accuracy: 92.19
# Batch accuracy: 93.36
# Batch accuracy: 90.82
# Batch accuracy: 91.02
# Batch accuracy: 91.21
# Batch accuracy: 91.41
# Batch accuracy: 91.41
# Batch accuracy: 86.72
# Batch accuracy: 87.70
# Batch accuracy: 90.62
# Batch accuracy: 92.58
# Batch accuracy: 89.45
# Batch accuracy: 89.45
# Batch accuracy: 90.04
# Batch accuracy: 91.60
# Batch accuracy: 89.45
# Batch accuracy: 89.26
# Batch accuracy: 91.80
# Batch accuracy: 91.41
# Batch accuracy: 90.62
# Batch accuracy: 91.02
# Batch accuracy: 90.62
# Batch accuracy: 89.06
# Batch accuracy: 90.82
# Batch accuracy: 90.04
# Batch accuracy: 89.84
# Batch accuracy: 92.77
# Batch accuracy: 89.26
# Batch accuracy: 89.26
# Batch accuracy: 89.06
# Batch accuracy: 90.04
# Batch accuracy: 92.19
# Batch accuracy: 93.36
# Batch accuracy: 90.23
# Batch accuracy: 90.62
# Batch accuracy: 90.62
# Batch accuracy: 93.16
# Batch accuracy: 88.87
# Batch accuracy: 91.80
# Batch accuracy: 90.23
# Batch accuracy: 91.41
# Batch accuracy: 88.67
# Batch accuracy: 90.04
# Batch accuracy: 90.43
# Batch accuracy: 89.26
# Batch accuracy: 89.06
# Batch accuracy: 88.67
# Batch accuracy: 90.04
# Batch accuracy: 89.65
# Batch accuracy: 89.45
# Batch accuracy: 91.41
# Batch accuracy: 90.04
# Batch accuracy: 89.65
# Batch accuracy: 89.45
# Batch accuracy: 88.87
# Batch accuracy: 92.19
# Batch accuracy: 90.23
# Batch accuracy: 88.67
# Batch accuracy: 90.82
# Batch accuracy: 90.23
# Batch accuracy: 88.87
# Batch accuracy: 88.87
# Batch accuracy: 90.82
# Batch accuracy: 87.70
# Batch accuracy: 89.65
# Batch accuracy: 92.19
# Batch accuracy: 91.21
# Batch accuracy: 88.28
# Batch accuracy: 90.62
# Batch accuracy: 90.82
# Batch accuracy: 88.87
# Batch accuracy: 90.04
# Batch accuracy: 92.38
# Batch accuracy: 89.06
# Batch accuracy: 90.04
# Batch accuracy: 90.23
# Batch accuracy: 88.09
# Batch accuracy: 90.23
# Batch accuracy: 88.87
# Batch accuracy: 86.91
# Batch accuracy: 87.89
# Batch accuracy: 91.99
# Batch accuracy: 88.48
# Batch accuracy: 89.84
# Batch accuracy: 91.60
# Batch accuracy: 91.21
# Batch accuracy: 90.62
# Batch accuracy: 92.22
#   Accuracy: 90.23
# New best model, saving it!
#
# ======== Epoch 4 / 30 ========
# Training...
#   Batch    40  of    943.    .
#   step loss: 0.27
#   Batch    80  of    943.    .
#   step loss: 0.33
#   Batch   120  of    943.    .
#   step loss: 0.35
#   Batch   160  of    943.    .
#   step loss: 0.30
#   Batch   200  of    943.    .
#   step loss: 0.35
#   Batch   240  of    943.    .
#   step loss: 0.26
#   Batch   280  of    943.    .
#   step loss: 0.28
#   Batch   320  of    943.    .
#   step loss: 0.31
#   Batch   360  of    943.    .
#   step loss: 0.36
#   Batch   400  of    943.    .
#   step loss: 0.29
#   Batch   440  of    943.    .
#   step loss: 0.31
#   Batch   480  of    943.    .
#   step loss: 0.29
#   Batch   520  of    943.    .
#   step loss: 0.40
#   Batch   560  of    943.    .
#   step loss: 0.41
#   Batch   600  of    943.    .
#   step loss: 0.33
#   Batch   640  of    943.    .
#   step loss: 0.35
#   Batch   680  of    943.    .
#   step loss: 0.37
#   Batch   720  of    943.    .
#   step loss: 0.36
#   Batch   760  of    943.    .
#   step loss: 0.30
#   Batch   800  of    943.    .
#   step loss: 0.29
#   Batch   840  of    943.    .
#   step loss: 0.32
#   Batch   880  of    943.    .
#   step loss: 0.26
#   Batch   920  of    943.    .
#   step loss: 0.33
#
#   Average training loss: 0.32
#
# Running Validation...
# Batch accuracy: 92.19
# Batch accuracy: 92.58
# Batch accuracy: 89.65
# Batch accuracy: 92.58
# Batch accuracy: 89.06
# Batch accuracy: 92.58
# Batch accuracy: 90.23
# Batch accuracy: 89.84
# Batch accuracy: 93.36
# Batch accuracy: 90.04
# Batch accuracy: 90.62
# Batch accuracy: 91.99
# Batch accuracy: 92.97
# Batch accuracy: 89.84
# Batch accuracy: 89.65
# Batch accuracy: 91.99
# Batch accuracy: 90.82
# Batch accuracy: 90.62
# Batch accuracy: 91.02
# Batch accuracy: 89.84
# Batch accuracy: 91.80
# Batch accuracy: 91.21
# Batch accuracy: 90.04
# Batch accuracy: 88.67
# Batch accuracy: 90.62
# Batch accuracy: 89.84
# Batch accuracy: 91.60
# Batch accuracy: 91.02
# Batch accuracy: 89.45
# Batch accuracy: 92.58
# Batch accuracy: 91.41
# Batch accuracy: 91.80
# Batch accuracy: 92.77
# Batch accuracy: 91.21
# Batch accuracy: 89.84
# Batch accuracy: 90.43
# Batch accuracy: 91.60
# Batch accuracy: 91.02
# Batch accuracy: 90.23
# Batch accuracy: 91.80
# Batch accuracy: 88.48
# Batch accuracy: 91.02
# Batch accuracy: 90.23
# Batch accuracy: 89.26
# Batch accuracy: 91.21
# Batch accuracy: 89.84
# Batch accuracy: 92.58
# Batch accuracy: 90.62
# Batch accuracy: 91.21
# Batch accuracy: 90.82
# Batch accuracy: 89.84
# Batch accuracy: 92.58
# Batch accuracy: 91.21
# Batch accuracy: 90.04
# Batch accuracy: 94.34
# Batch accuracy: 90.62
# Batch accuracy: 90.04
# Batch accuracy: 91.21
# Batch accuracy: 91.02
# Batch accuracy: 91.21
# Batch accuracy: 89.84
# Batch accuracy: 92.97
# Batch accuracy: 91.21
# Batch accuracy: 90.43
# Batch accuracy: 91.02
# Batch accuracy: 92.38
# Batch accuracy: 90.23
# Batch accuracy: 91.21
# Batch accuracy: 90.62
# Batch accuracy: 90.23
# Batch accuracy: 90.23
# Batch accuracy: 91.02
# Batch accuracy: 89.26
# Batch accuracy: 90.62
# Batch accuracy: 90.23
# Batch accuracy: 90.23
# Batch accuracy: 92.19
# Batch accuracy: 90.43
# Batch accuracy: 89.84
# Batch accuracy: 89.84
# Batch accuracy: 93.55
# Batch accuracy: 91.41
# Batch accuracy: 93.16
# Batch accuracy: 91.21
# Batch accuracy: 91.41
# Batch accuracy: 90.62
# Batch accuracy: 92.77
# Batch accuracy: 90.43
# Batch accuracy: 90.62
# Batch accuracy: 90.43
# Batch accuracy: 90.23
# Batch accuracy: 89.26
# Batch accuracy: 91.21
# Batch accuracy: 88.28
# Batch accuracy: 93.75
# Batch accuracy: 91.41
# Batch accuracy: 89.26
# Batch accuracy: 90.62
# Batch accuracy: 93.16
# Batch accuracy: 88.28
# Batch accuracy: 89.84
# Batch accuracy: 89.65
# Batch accuracy: 92.38
# Batch accuracy: 91.41
# Batch accuracy: 91.35
#   Accuracy: 90.93
# New best model, saving it!
#
# ======== Epoch 5 / 30 ========
# Training...
#   Batch    40  of    943.    .
#   step loss: 0.25
#   Batch    80  of    943.    .
#   step loss: 0.32
#   Batch   120  of    943.    .
#   step loss: 0.26
#   Batch   160  of    943.    .
#   step loss: 0.31
#   Batch   200  of    943.    .
#   step loss: 0.33
#   Batch   240  of    943.    .
#   step loss: 0.32
#   Batch   280  of    943.    .
#   step loss: 0.39
#   Batch   320  of    943.    .
#   step loss: 0.28
#   Batch   360  of    943.    .
#   step loss: 0.33
#   Batch   400  of    943.    .
#   step loss: 0.24
#   Batch   440  of    943.    .
#   step loss: 0.27
#   Batch   480  of    943.    .
#   step loss: 0.25
#   Batch   520  of    943.    .
#   step loss: 0.30
#   Batch   560  of    943.    .
#   step loss: 0.24
#   Batch   600  of    943.    .
#   step loss: 0.33
#   Batch   640  of    943.    .
#   step loss: 0.30
#   Batch   680  of    943.    .
#   step loss: 0.30
#   Batch   720  of    943.    .
#   step loss: 0.34
#   Batch   760  of    943.    .
#   step loss: 0.30
#   Batch   800  of    943.    .
#   step loss: 0.27
#   Batch   840  of    943.    .
#   step loss: 0.28
#   Batch   880  of    943.    .
#   step loss: 0.26
#   Batch   920  of    943.    .
#   step loss: 0.26
#
#   Average training loss: 0.29
#
# Running Validation...
# Batch accuracy: 92.97
# Batch accuracy: 92.19
# Batch accuracy: 90.04
# Batch accuracy: 91.99
# Batch accuracy: 92.58
# Batch accuracy: 89.26
# Batch accuracy: 89.65
# Batch accuracy: 88.09
# Batch accuracy: 89.45
# Batch accuracy: 90.23
# Batch accuracy: 91.21
# Batch accuracy: 91.41
# Batch accuracy: 91.02
# Batch accuracy: 90.62
# Batch accuracy: 92.19
# Batch accuracy: 92.77
# Batch accuracy: 89.06
# Batch accuracy: 91.02
# Batch accuracy: 90.23
# Batch accuracy: 91.80
# Batch accuracy: 92.19
# Batch accuracy: 92.38
# Batch accuracy: 91.41
# Batch accuracy: 89.45
# Batch accuracy: 89.84
# Batch accuracy: 91.02
# Batch accuracy: 90.82
# Batch accuracy: 91.80
# Batch accuracy: 90.62
# Batch accuracy: 91.60
# Batch accuracy: 90.62
# Batch accuracy: 92.58
# Batch accuracy: 91.60
# Batch accuracy: 89.26
# Batch accuracy: 90.82
# Batch accuracy: 90.82
# Batch accuracy: 91.80
# Batch accuracy: 89.65
# Batch accuracy: 90.43
# Batch accuracy: 92.38
# Batch accuracy: 90.23
# Batch accuracy: 91.99
# Batch accuracy: 90.43
# Batch accuracy: 90.43
# Batch accuracy: 92.19
# Batch accuracy: 91.99
# Batch accuracy: 91.99
# Batch accuracy: 93.95
# Batch accuracy: 88.87
# Batch accuracy: 91.02
# Batch accuracy: 90.23
# Batch accuracy: 91.99
# Batch accuracy: 89.65
# Batch accuracy: 92.19
# Batch accuracy: 89.45
# Batch accuracy: 92.38
# Batch accuracy: 89.65
# Batch accuracy: 92.97
# Batch accuracy: 92.38
# Batch accuracy: 90.43
# Batch accuracy: 90.82
# Batch accuracy: 91.80
# Batch accuracy: 91.80
# Batch accuracy: 91.02
# Batch accuracy: 92.77
# Batch accuracy: 90.62
# Batch accuracy: 91.80
# Batch accuracy: 90.43
# Batch accuracy: 91.60
# Batch accuracy: 88.09
# Batch accuracy: 89.26
# Batch accuracy: 92.77
# Batch accuracy: 90.62
# Batch accuracy: 91.80
# Batch accuracy: 91.80
# Batch accuracy: 90.82
# Batch accuracy: 90.62
# Batch accuracy: 89.65
# Batch accuracy: 91.02
# Batch accuracy: 91.41
# Batch accuracy: 91.02
# Batch accuracy: 91.99
# Batch accuracy: 92.58
# Batch accuracy: 92.38
# Batch accuracy: 90.04
# Batch accuracy: 89.65
# Batch accuracy: 91.21
# Batch accuracy: 93.16
# Batch accuracy: 90.62
# Batch accuracy: 90.23
# Batch accuracy: 90.04
# Batch accuracy: 88.67
# Batch accuracy: 90.82
# Batch accuracy: 92.58
# Batch accuracy: 93.36
# Batch accuracy: 90.62
# Batch accuracy: 92.97
# Batch accuracy: 92.77
# Batch accuracy: 90.82
# Batch accuracy: 91.60
# Batch accuracy: 90.43
# Batch accuracy: 91.60
# Batch accuracy: 91.80
# Batch accuracy: 90.62
# Batch accuracy: 90.20
#   Accuracy: 91.10
# New best model, saving it!
#
# ======== Epoch 6 / 30 ========
# Training...
#   Batch    40  of    943.    .
#   step loss: 0.25
#   Batch    80  of    943.    .
#   step loss: 0.24
#   Batch   120  of    943.    .
#   step loss: 0.33
#   Batch   160  of    943.    .
#   step loss: 0.28
#   Batch   200  of    943.    .
#   step loss: 0.30
#   Batch   240  of    943.    .
#   step loss: 0.28
#   Batch   280  of    943.    .
#   step loss: 0.23
#   Batch   320  of    943.    .
#   step loss: 0.26
#   Batch   360  of    943.    .
#   step loss: 0.29
#   Batch   400  of    943.    .
#   step loss: 0.28
#   Batch   440  of    943.    .
#   step loss: 0.23
#   Batch   480  of    943.    .
#   step loss: 0.24
#   Batch   520  of    943.    .
#   step loss: 0.32
#   Batch   560  of    943.    .
#   step loss: 0.31
#   Batch   600  of    943.    .
#   step loss: 0.30
#   Batch   640  of    943.    .
#   step loss: 0.30
#   Batch   680  of    943.    .
#   step loss: 0.29
#   Batch   720  of    943.    .
#   step loss: 0.22
#   Batch   760  of    943.    .
#   step loss: 0.26
#   Batch   800  of    943.    .
#   step loss: 0.25
#   Batch   840  of    943.    .
#   step loss: 0.27
#   Batch   880  of    943.    .
#   step loss: 0.27
#   Batch   920  of    943.    .
#   step loss: 0.25
#
#   Average training loss: 0.27
#
# Running Validation...
# Batch accuracy: 90.43
# Batch accuracy: 92.77
# Batch accuracy: 92.77
# Batch accuracy: 90.23
# Batch accuracy: 92.58
# Batch accuracy: 90.23
# Batch accuracy: 90.82
# Batch accuracy: 91.80
# Batch accuracy: 91.02
# Batch accuracy: 91.60
# Batch accuracy: 89.45
# Batch accuracy: 89.26
# Batch accuracy: 91.99
# Batch accuracy: 92.97
# Batch accuracy: 92.19
# Batch accuracy: 91.21
# Batch accuracy: 89.26
# Batch accuracy: 91.21
# Batch accuracy: 88.09
# Batch accuracy: 91.60
# Batch accuracy: 92.58
# Batch accuracy: 89.26
# Batch accuracy: 89.45
# Batch accuracy: 93.75
# Batch accuracy: 91.60
# Batch accuracy: 92.38
# Batch accuracy: 90.04
# Batch accuracy: 90.23
# Batch accuracy: 92.58
# Batch accuracy: 92.77
# Batch accuracy: 92.38
# Batch accuracy: 89.06
# Batch accuracy: 90.04
# Batch accuracy: 92.19
# Batch accuracy: 89.06
# Batch accuracy: 91.80
# Batch accuracy: 91.99
# Batch accuracy: 91.99
# Batch accuracy: 91.80
# Batch accuracy: 91.80
# Batch accuracy: 91.21
# Batch accuracy: 93.16
# Batch accuracy: 89.65
# Batch accuracy: 90.82
# Batch accuracy: 92.19
# Batch accuracy: 91.21
# Batch accuracy: 91.99
# Batch accuracy: 90.62
# Batch accuracy: 87.50
# Batch accuracy: 93.36
# Batch accuracy: 90.04
# Batch accuracy: 89.26
# Batch accuracy: 91.60
# Batch accuracy: 89.65
# Batch accuracy: 93.36
# Batch accuracy: 90.82
# Batch accuracy: 93.36
# Batch accuracy: 93.55
# Batch accuracy: 92.97
# Batch accuracy: 91.99
# Batch accuracy: 92.19
# Batch accuracy: 90.04
# Batch accuracy: 89.06
# Batch accuracy: 91.02
# Batch accuracy: 90.62
# Batch accuracy: 92.38
# Batch accuracy: 90.62
# Batch accuracy: 91.21
# Batch accuracy: 92.19
# Batch accuracy: 93.36
# Batch accuracy: 89.26
# Batch accuracy: 88.87
# Batch accuracy: 91.02
# Batch accuracy: 91.60
# Batch accuracy: 89.06
# Batch accuracy: 92.19
# Batch accuracy: 91.02
# Batch accuracy: 92.38
# Batch accuracy: 92.58
# Batch accuracy: 91.80
# Batch accuracy: 93.16
# Batch accuracy: 88.87
# Batch accuracy: 90.82
# Batch accuracy: 89.45
# Batch accuracy: 91.80
# Batch accuracy: 91.41
# Batch accuracy: 91.21
# Batch accuracy: 91.21
# Batch accuracy: 89.45
# Batch accuracy: 92.19
# Batch accuracy: 90.62
# Batch accuracy: 90.62
# Batch accuracy: 91.99
# Batch accuracy: 90.04
# Batch accuracy: 90.04
# Batch accuracy: 91.02
# Batch accuracy: 93.16
# Batch accuracy: 90.04
# Batch accuracy: 93.75
# Batch accuracy: 93.36
# Batch accuracy: 90.43
# Batch accuracy: 91.80
# Batch accuracy: 91.41
# Batch accuracy: 91.02
# Batch accuracy: 90.20
#   Accuracy: 91.22
# New best model, saving it!
#
# ======== Epoch 7 / 30 ========
# Training...
#   Batch    40  of    943.    .
#   step loss: 0.30
#   Batch    80  of    943.    .
#   step loss: 0.26
#   Batch   120  of    943.    .
#   step loss: 0.22
#   Batch   160  of    943.    .
#   step loss: 0.24
#   Batch   200  of    943.    .
#   step loss: 0.27
#   Batch   240  of    943.    .
#   step loss: 0.28
#   Batch   280  of    943.    .
#   step loss: 0.26
#   Batch   320  of    943.    .
#   step loss: 0.33
#   Batch   360  of    943.    .
#   step loss: 0.22
#   Batch   400  of    943.    .
#   step loss: 0.24
#   Batch   440  of    943.    .
#   step loss: 0.24
#   Batch   480  of    943.    .
#   step loss: 0.27
#   Batch   520  of    943.    .
#   step loss: 0.27
#   Batch   560  of    943.    .
#   step loss: 0.27
#   Batch   600  of    943.    .
#   step loss: 0.29
#   Batch   640  of    943.    .
#   step loss: 0.25
#   Batch   680  of    943.    .
#   step loss: 0.22
#   Batch   720  of    943.    .
#   step loss: 0.25
#   Batch   760  of    943.    .
#   step loss: 0.25
#   Batch   800  of    943.    .
#   step loss: 0.31
#   Batch   840  of    943.    .
#   step loss: 0.26
#   Batch   880  of    943.    .
#   step loss: 0.34
#   Batch   920  of    943.    .
#   step loss: 0.34
#
#   Average training loss: 0.25
#
# Running Validation...
# Batch accuracy: 91.41
# Batch accuracy: 90.62
# Batch accuracy: 92.19
# Batch accuracy: 92.38
# Batch accuracy: 93.36
# Batch accuracy: 90.43
# Batch accuracy: 91.60
# Batch accuracy: 90.82
# Batch accuracy: 91.21
# Batch accuracy: 89.45
# Batch accuracy: 91.80
# Batch accuracy: 91.80
# Batch accuracy: 92.38
# Batch accuracy: 92.58
# Batch accuracy: 92.58
# Batch accuracy: 91.02
# Batch accuracy: 91.41
# Batch accuracy: 88.09
# Batch accuracy: 90.43
# Batch accuracy: 91.99
# Batch accuracy: 91.99
# Batch accuracy: 92.97
# Batch accuracy: 91.41
# Batch accuracy: 94.53
# Batch accuracy: 89.84
# Batch accuracy: 90.82
# Batch accuracy: 93.36
# Batch accuracy: 90.62
# Batch accuracy: 90.23
# Batch accuracy: 91.60
# Batch accuracy: 91.80
# Batch accuracy: 93.36
# Batch accuracy: 92.58
# Batch accuracy: 88.09
# Batch accuracy: 92.38
# Batch accuracy: 89.84
# Batch accuracy: 90.62
# Batch accuracy: 90.62
# Batch accuracy: 91.60
# Batch accuracy: 90.23
# Batch accuracy: 90.43
# Batch accuracy: 91.60
# Batch accuracy: 90.43
# Batch accuracy: 91.60
# Batch accuracy: 90.82
# Batch accuracy: 91.21
# Batch accuracy: 91.21
# Batch accuracy: 88.87
# Batch accuracy: 91.02
# Batch accuracy: 89.45
# Batch accuracy: 90.62
# Batch accuracy: 91.41
# Batch accuracy: 91.41
# Batch accuracy: 89.26
# Batch accuracy: 91.99
# Batch accuracy: 91.99
# Batch accuracy: 92.58
# Batch accuracy: 90.62
# Batch accuracy: 92.38
# Batch accuracy: 92.19
# Batch accuracy: 89.65
# Batch accuracy: 90.04
# Batch accuracy: 92.19
# Batch accuracy: 94.34
# Batch accuracy: 91.21
# Batch accuracy: 88.87
# Batch accuracy: 89.84
# Batch accuracy: 93.55
# Batch accuracy: 89.45
# Batch accuracy: 91.21
# Batch accuracy: 91.99
# Batch accuracy: 91.21
# Batch accuracy: 94.14
# Batch accuracy: 92.19
# Batch accuracy: 91.41
# Batch accuracy: 90.82
# Batch accuracy: 90.43
# Batch accuracy: 89.84
# Batch accuracy: 91.99
# Batch accuracy: 90.04
# Batch accuracy: 91.02
# Batch accuracy: 90.62
# Batch accuracy: 92.97
# Batch accuracy: 89.26
# Batch accuracy: 93.36
# Batch accuracy: 90.82
# Batch accuracy: 91.41
# Batch accuracy: 92.38
# Batch accuracy: 89.65
# Batch accuracy: 91.21
# Batch accuracy: 91.21
# Batch accuracy: 89.26
# Batch accuracy: 88.67
# Batch accuracy: 90.82
# Batch accuracy: 90.82
# Batch accuracy: 93.95
# Batch accuracy: 91.41
# Batch accuracy: 90.62
# Batch accuracy: 92.19
# Batch accuracy: 92.77
# Batch accuracy: 89.84
# Batch accuracy: 91.02
# Batch accuracy: 90.82
# Batch accuracy: 92.58
# Batch accuracy: 89.63
#   Accuracy: 91.24
# New best model, saving it!
#
# ======== Epoch 8 / 30 ========
# Training...
#   Batch    40  of    943.    .
#   step loss: 0.22
#   Batch    80  of    943.    .
#   step loss: 0.24
#   Batch   120  of    943.    .
#   step loss: 0.24
#   Batch   160  of    943.    .
#   step loss: 0.28
#   Batch   200  of    943.    .
#   step loss: 0.19
#   Batch   240  of    943.    .
#   step loss: 0.23
#   Batch   280  of    943.    .
#   step loss: 0.25
#   Batch   320  of    943.    .
#   step loss: 0.23
#   Batch   360  of    943.    .
#   step loss: 0.22
#   Batch   400  of    943.    .
#   step loss: 0.23
#   Batch   440  of    943.    .
#   step loss: 0.27
#   Batch   480  of    943.    .
#   step loss: 0.22
#   Batch   520  of    943.    .
#   step loss: 0.23
#   Batch   560  of    943.    .
#   step loss: 0.25
#   Batch   600  of    943.    .
#   step loss: 0.23
#   Batch   640  of    943.    .
#   step loss: 0.19
#   Batch   680  of    943.    .
#   step loss: 0.19
#   Batch   720  of    943.    .
#   step loss: 0.24
#   Batch   760  of    943.    .
#   step loss: 0.32
#   Batch   800  of    943.    .
#   step loss: 0.31
#   Batch   840  of    943.    .
#   step loss: 0.19
#   Batch   880  of    943.    .
#   step loss: 0.23
#   Batch   920  of    943.    .
#   step loss: 0.32
#
#   Average training loss: 0.24
#
# Running Validation...
# Batch accuracy: 92.97
# Batch accuracy: 91.21
# Batch accuracy: 90.62
# Batch accuracy: 91.21
# Batch accuracy: 90.04
# Batch accuracy: 91.99
# Batch accuracy: 93.75
# Batch accuracy: 91.60
# Batch accuracy: 93.36
# Batch accuracy: 93.75
# Batch accuracy: 90.62
# Batch accuracy: 90.82
# Batch accuracy: 92.97
# Batch accuracy: 94.14
# Batch accuracy: 92.97
# Batch accuracy: 91.80
# Batch accuracy: 92.38
# Batch accuracy: 92.19
# Batch accuracy: 92.38
# Batch accuracy: 90.62
# Batch accuracy: 92.19
# Batch accuracy: 91.02
# Batch accuracy: 92.97
# Batch accuracy: 89.45
# Batch accuracy: 92.58
# Batch accuracy: 91.60
# Batch accuracy: 91.80
# Batch accuracy: 91.60
# Batch accuracy: 90.43
# Batch accuracy: 91.80
# Batch accuracy: 91.41
# Batch accuracy: 91.02
# Batch accuracy: 90.62
# Batch accuracy: 92.38
# Batch accuracy: 91.21
# Batch accuracy: 91.99
# Batch accuracy: 92.97
# Batch accuracy: 91.21
# Batch accuracy: 93.75
# Batch accuracy: 92.19
# Batch accuracy: 91.80
# Batch accuracy: 91.60
# Batch accuracy: 92.38
# Batch accuracy: 92.97
# Batch accuracy: 92.19
# Batch accuracy: 91.99
# Batch accuracy: 92.97
# Batch accuracy: 93.75
# Batch accuracy: 92.77
# Batch accuracy: 91.60
# Batch accuracy: 90.82
# Batch accuracy: 90.43
# Batch accuracy: 91.21
# Batch accuracy: 91.80
# Batch accuracy: 90.62
# Batch accuracy: 90.62
# Batch accuracy: 89.84
# Batch accuracy: 91.99
# Batch accuracy: 92.38
# Batch accuracy: 92.19
# Batch accuracy: 90.43
# Batch accuracy: 94.53
# Batch accuracy: 90.62
# Batch accuracy: 92.58
# Batch accuracy: 92.38
# Batch accuracy: 92.38
# Batch accuracy: 92.19
# Batch accuracy: 90.04
# Batch accuracy: 92.38
# Batch accuracy: 91.41
# Batch accuracy: 91.41
# Batch accuracy: 92.19
# Batch accuracy: 91.80
# Batch accuracy: 90.23
# Batch accuracy: 89.84
# Batch accuracy: 89.65
# Batch accuracy: 94.14
# Batch accuracy: 91.99
# Batch accuracy: 91.80
# Batch accuracy: 90.04
# Batch accuracy: 92.58
# Batch accuracy: 90.43
# Batch accuracy: 93.36
# Batch accuracy: 91.80
# Batch accuracy: 91.60
# Batch accuracy: 93.36
# Batch accuracy: 92.77
# Batch accuracy: 91.21
# Batch accuracy: 92.38
# Batch accuracy: 92.38
# Batch accuracy: 90.82
# Batch accuracy: 92.38
# Batch accuracy: 91.60
# Batch accuracy: 92.77
# Batch accuracy: 93.95
# Batch accuracy: 90.62
# Batch accuracy: 91.60
# Batch accuracy: 91.02
# Batch accuracy: 89.26
# Batch accuracy: 92.38
# Batch accuracy: 92.38
# Batch accuracy: 92.38
# Batch accuracy: 91.99
# Batch accuracy: 92.97
# Batch accuracy: 93.08
#   Accuracy: 91.85
# New best model, saving it!
#
# ======== Epoch 9 / 30 ========
# Training...
#   Batch    40  of    943.    .
#   step loss: 0.19
#   Batch    80  of    943.    .
#   step loss: 0.21
#   Batch   120  of    943.    .
#   step loss: 0.21
#   Batch   160  of    943.    .
#   step loss: 0.22
#   Batch   200  of    943.    .
#   step loss: 0.21
#   Batch   240  of    943.    .
#   step loss: 0.23
#   Batch   280  of    943.    .
#   step loss: 0.16
#   Batch   320  of    943.    .
#   step loss: 0.22
#   Batch   360  of    943.    .
#   step loss: 0.23
#   Batch   400  of    943.    .
#   step loss: 0.26
#   Batch   440  of    943.    .
#   step loss: 0.26
#   Batch   480  of    943.    .
#   step loss: 0.18
#   Batch   520  of    943.    .
#   step loss: 0.24
#   Batch   560  of    943.    .
#   step loss: 0.22
#   Batch   600  of    943.    .
#   step loss: 0.23
#   Batch   640  of    943.    .
#   step loss: 0.23
#   Batch   680  of    943.    .
#   step loss: 0.22
#   Batch   720  of    943.    .
#   step loss: 0.22
#   Batch   760  of    943.    .
#   step loss: 0.28
#   Batch   800  of    943.    .
#   step loss: 0.23
#   Batch   840  of    943.    .
#   step loss: 0.27
#   Batch   880  of    943.    .
#   step loss: 0.26
#   Batch   920  of    943.    .
#   step loss: 0.24
#
#   Average training loss: 0.23
#
# Running Validation...
# Batch accuracy: 91.21
# Batch accuracy: 93.75
# Batch accuracy: 92.97
# Batch accuracy: 91.02
# Batch accuracy: 92.19
# Batch accuracy: 92.38
# Batch accuracy: 92.77
# Batch accuracy: 93.55
# Batch accuracy: 90.43
# Batch accuracy: 91.80
# Batch accuracy: 91.80
# Batch accuracy: 91.41
# Batch accuracy: 91.41
# Batch accuracy: 91.80
# Batch accuracy: 91.41
# Batch accuracy: 91.80
# Batch accuracy: 91.02
# Batch accuracy: 92.58
# Batch accuracy: 90.04
# Batch accuracy: 92.38
# Batch accuracy: 91.41
# Batch accuracy: 92.77
# Batch accuracy: 88.87
# Batch accuracy: 91.60
# Batch accuracy: 89.45
# Batch accuracy: 91.41
# Batch accuracy: 91.21
# Batch accuracy: 91.99
# Batch accuracy: 91.41
# Batch accuracy: 91.02
# Batch accuracy: 91.60
# Batch accuracy: 91.60
# Batch accuracy: 92.19
# Batch accuracy: 90.04
# Batch accuracy: 93.55
# Batch accuracy: 91.99
# Batch accuracy: 93.95
# Batch accuracy: 89.06
# Batch accuracy: 94.73
# Batch accuracy: 93.36
# Batch accuracy: 90.62
# Batch accuracy: 92.58
# Batch accuracy: 91.02
# Batch accuracy: 90.82
# Batch accuracy: 92.19
# Batch accuracy: 91.60
# Batch accuracy: 91.41
# Batch accuracy: 91.21
# Batch accuracy: 91.80
# Batch accuracy: 91.02
# Batch accuracy: 92.58
# Batch accuracy: 89.84
# Batch accuracy: 92.77
# Batch accuracy: 89.06
# Batch accuracy: 91.80
# Batch accuracy: 89.45
# Batch accuracy: 92.58
# Batch accuracy: 92.58
# Batch accuracy: 91.80
# Batch accuracy: 91.21
# Batch accuracy: 92.19
# Batch accuracy: 94.34
# Batch accuracy: 92.38
# Batch accuracy: 91.99
# Batch accuracy: 91.21
# Batch accuracy: 92.19
# Batch accuracy: 93.55
# Batch accuracy: 92.19
# Batch accuracy: 94.14
# Batch accuracy: 92.19
# Batch accuracy: 91.80
# Batch accuracy: 92.58
# Batch accuracy: 91.99
# Batch accuracy: 90.04
# Batch accuracy: 91.99
# Batch accuracy: 93.36
# Batch accuracy: 92.19
# Batch accuracy: 91.60
# Batch accuracy: 94.92
# Batch accuracy: 90.82
# Batch accuracy: 91.99
# Batch accuracy: 91.99
# Batch accuracy: 91.60
# Batch accuracy: 92.19
# Batch accuracy: 90.23
# Batch accuracy: 91.41
# Batch accuracy: 91.60
# Batch accuracy: 90.23
# Batch accuracy: 93.36
# Batch accuracy: 91.99
# Batch accuracy: 94.14
# Batch accuracy: 91.21
# Batch accuracy: 91.80
# Batch accuracy: 93.36
# Batch accuracy: 91.21
# Batch accuracy: 90.82
# Batch accuracy: 92.38
# Batch accuracy: 92.77
# Batch accuracy: 91.02
# Batch accuracy: 90.04
# Batch accuracy: 91.99
# Batch accuracy: 90.82
# Batch accuracy: 94.14
# Batch accuracy: 91.21
# Batch accuracy: 92.51
#   Accuracy: 91.83
# The model does not improve for 1 epochs!
#
# ======== Epoch 10 / 30 ========
# Training...
#   Batch    40  of    943.    .
#   step loss: 0.24
#   Batch    80  of    943.    .
#   step loss: 0.25
#   Batch   120  of    943.    .
#   step loss: 0.18
#   Batch   160  of    943.    .
#   step loss: 0.20
#   Batch   200  of    943.    .
#   step loss: 0.27
#   Batch   240  of    943.    .
#   step loss: 0.21
#   Batch   280  of    943.    .
#   step loss: 0.22
#   Batch   320  of    943.    .
#   step loss: 0.21
#   Batch   360  of    943.    .
#   step loss: 0.22
#   Batch   400  of    943.    .
#   step loss: 0.16
#   Batch   440  of    943.    .
#   step loss: 0.18
#   Batch   480  of    943.    .
#   step loss: 0.17
#   Batch   520  of    943.    .
#   step loss: 0.16
#   Batch   560  of    943.    .
#   step loss: 0.21
#   Batch   600  of    943.    .
#   step loss: 0.22
#   Batch   640  of    943.    .
#   step loss: 0.19
#   Batch   680  of    943.    .
#   step loss: 0.22
#   Batch   720  of    943.    .
#   step loss: 0.18
#   Batch   760  of    943.    .
#   step loss: 0.15
#   Batch   800  of    943.    .
#   step loss: 0.22
#   Batch   840  of    943.    .
#   step loss: 0.19
#   Batch   880  of    943.    .
#   step loss: 0.21
#   Batch   920  of    943.    .
#   step loss: 0.22
#
#   Average training loss: 0.22
#
# Running Validation...
# Batch accuracy: 91.02
# Batch accuracy: 92.38
# Batch accuracy: 89.26
# Batch accuracy: 91.99
# Batch accuracy: 91.41
# Batch accuracy: 91.41
# Batch accuracy: 90.04
# Batch accuracy: 90.23
# Batch accuracy: 91.21
# Batch accuracy: 91.99
# Batch accuracy: 92.38
# Batch accuracy: 94.14
# Batch accuracy: 89.65
# Batch accuracy: 92.58
# Batch accuracy: 92.97
# Batch accuracy: 91.02
# Batch accuracy: 91.41
# Batch accuracy: 91.02
# Batch accuracy: 93.16
# Batch accuracy: 91.80
# Batch accuracy: 93.55
# Batch accuracy: 92.58
# Batch accuracy: 90.62
# Batch accuracy: 90.43
# Batch accuracy: 91.21
# Batch accuracy: 92.19
# Batch accuracy: 92.77
# Batch accuracy: 91.80
# Batch accuracy: 92.97
# Batch accuracy: 92.19
# Batch accuracy: 91.60
# Batch accuracy: 90.43
# Batch accuracy: 92.19
# Batch accuracy: 91.02
# Batch accuracy: 89.84
# Batch accuracy: 93.16
# Batch accuracy: 90.23
# Batch accuracy: 90.23
# Batch accuracy: 91.02
# Batch accuracy: 91.80
# Batch accuracy: 92.38
# Batch accuracy: 92.58
# Batch accuracy: 91.41
# Batch accuracy: 91.02
# Batch accuracy: 92.77
# Batch accuracy: 92.58
# Batch accuracy: 92.38
# Batch accuracy: 90.43
# Batch accuracy: 90.23
# Batch accuracy: 92.77
# Batch accuracy: 93.55
# Batch accuracy: 93.55
# Batch accuracy: 91.99
# Batch accuracy: 93.16
# Batch accuracy: 90.62
# Batch accuracy: 92.97
# Batch accuracy: 91.80
# Batch accuracy: 90.23
# Batch accuracy: 91.99
# Batch accuracy: 91.41
# Batch accuracy: 91.60
# Batch accuracy: 90.04
# Batch accuracy: 92.38
# Batch accuracy: 89.26
# Batch accuracy: 92.19
# Batch accuracy: 93.36
# Batch accuracy: 93.36
# Batch accuracy: 89.26
# Batch accuracy: 91.60
# Batch accuracy: 91.99
# Batch accuracy: 91.80
# Batch accuracy: 94.14
# Batch accuracy: 91.21
# Batch accuracy: 90.62
# Batch accuracy: 92.77
# Batch accuracy: 91.41
# Batch accuracy: 91.21
# Batch accuracy: 93.16
# Batch accuracy: 93.36
# Batch accuracy: 90.04
# Batch accuracy: 91.60
# Batch accuracy: 92.19
# Batch accuracy: 91.02
# Batch accuracy: 91.41
# Batch accuracy: 92.97
# Batch accuracy: 91.60
# Batch accuracy: 93.16
# Batch accuracy: 91.21
# Batch accuracy: 91.02
# Batch accuracy: 92.19
# Batch accuracy: 92.58
# Batch accuracy: 91.80
# Batch accuracy: 90.43
# Batch accuracy: 89.06
# Batch accuracy: 92.38
# Batch accuracy: 91.21
# Batch accuracy: 91.99
# Batch accuracy: 93.16
# Batch accuracy: 92.38
# Batch accuracy: 90.62
# Batch accuracy: 91.41
# Batch accuracy: 92.38
# Batch accuracy: 91.41
# Batch accuracy: 91.99
# Batch accuracy: 90.78
#   Accuracy: 91.71
# The model does not improve for 2 epochs!
#
# ======== Epoch 11 / 30 ========
# Training...
#   Batch    40  of    943.    .
#   step loss: 0.21
#   Batch    80  of    943.    .
#   step loss: 0.22
#   Batch   120  of    943.    .
#   step loss: 0.14
#   Batch   160  of    943.    .
#   step loss: 0.21
#   Batch   200  of    943.    .
#   step loss: 0.19
#   Batch   240  of    943.    .
#   step loss: 0.21
#   Batch   280  of    943.    .
#   step loss: 0.16
#   Batch   320  of    943.    .
#   step loss: 0.28
#   Batch   360  of    943.    .
#   step loss: 0.23
#   Batch   400  of    943.    .
#   step loss: 0.19
#   Batch   440  of    943.    .
#   step loss: 0.19
#   Batch   480  of    943.    .
#   step loss: 0.22
#   Batch   520  of    943.    .
#   step loss: 0.19
#   Batch   560  of    943.    .
#   step loss: 0.24
#   Batch   600  of    943.    .
#   step loss: 0.21
#   Batch   640  of    943.    .
#   step loss: 0.23
#   Batch   680  of    943.    .
#   step loss: 0.20
#   Batch   720  of    943.    .
#   step loss: 0.16
#   Batch   760  of    943.    .
#   step loss: 0.16
#   Batch   800  of    943.    .
#   step loss: 0.19
#   Batch   840  of    943.    .
#   step loss: 0.23
#   Batch   880  of    943.    .
#   step loss: 0.23
#   Batch   920  of    943.    .
#   step loss: 0.20
#
#   Average training loss: 0.21
#
# Running Validation...
# Batch accuracy: 90.62
# Batch accuracy: 91.41
# Batch accuracy: 91.99
# Batch accuracy: 91.80
# Batch accuracy: 90.23
# Batch accuracy: 91.99
# Batch accuracy: 91.80
# Batch accuracy: 92.58
# Batch accuracy: 88.48
# Batch accuracy: 91.02
# Batch accuracy: 93.36
# Batch accuracy: 91.02
# Batch accuracy: 91.41
# Batch accuracy: 93.36
# Batch accuracy: 91.41
# Batch accuracy: 92.77
# Batch accuracy: 93.95
# Batch accuracy: 93.55
# Batch accuracy: 91.60
# Batch accuracy: 90.82
# Batch accuracy: 92.58
# Batch accuracy: 91.02
# Batch accuracy: 93.16
# Batch accuracy: 92.97
# Batch accuracy: 92.38
# Batch accuracy: 90.82
# Batch accuracy: 92.19
# Batch accuracy: 89.84
# Batch accuracy: 91.41
# Batch accuracy: 91.80
# Batch accuracy: 92.58
# Batch accuracy: 93.55
# Batch accuracy: 92.19
# Batch accuracy: 91.99
# Batch accuracy: 91.21
# Batch accuracy: 90.82
# Batch accuracy: 91.21
# Batch accuracy: 91.41
# Batch accuracy: 89.26
# Batch accuracy: 92.58
# Batch accuracy: 90.62
# Batch accuracy: 92.38
# Batch accuracy: 92.38
# Batch accuracy: 90.23
# Batch accuracy: 93.36
# Batch accuracy: 93.55
# Batch accuracy: 93.36
# Batch accuracy: 93.95
# Batch accuracy: 93.75
# Batch accuracy: 93.75
# Batch accuracy: 92.58
# Batch accuracy: 91.99
# Batch accuracy: 93.36
# Batch accuracy: 93.95
# Batch accuracy: 91.80
# Batch accuracy: 92.38
# Batch accuracy: 89.84
# Batch accuracy: 88.48
# Batch accuracy: 93.55
# Batch accuracy: 90.82
# Batch accuracy: 92.38
# Batch accuracy: 90.04
# Batch accuracy: 90.82
# Batch accuracy: 89.65
# Batch accuracy: 91.99
# Batch accuracy: 91.99
# Batch accuracy: 89.84
# Batch accuracy: 92.97
# Batch accuracy: 92.19
# Batch accuracy: 92.38
# Batch accuracy: 91.60
# Batch accuracy: 90.23
# Batch accuracy: 92.97
# Batch accuracy: 93.95
# Batch accuracy: 92.38
# Batch accuracy: 93.55
# Batch accuracy: 90.43
# Batch accuracy: 93.55
# Batch accuracy: 91.21
# Batch accuracy: 92.38
# Batch accuracy: 90.82
# Batch accuracy: 91.99
# Batch accuracy: 92.77
# Batch accuracy: 92.58
# Batch accuracy: 91.80
# Batch accuracy: 91.99
# Batch accuracy: 92.38
# Batch accuracy: 89.84
# Batch accuracy: 91.21
# Batch accuracy: 91.02
# Batch accuracy: 91.80
# Batch accuracy: 92.19
# Batch accuracy: 92.58
# Batch accuracy: 92.58
# Batch accuracy: 90.23
# Batch accuracy: 92.58
# Batch accuracy: 93.16
# Batch accuracy: 91.60
# Batch accuracy: 90.04
# Batch accuracy: 92.38
# Batch accuracy: 91.41
# Batch accuracy: 91.80
# Batch accuracy: 91.60
# Batch accuracy: 92.77
# Batch accuracy: 91.35
#   Accuracy: 91.88
# New best model, saving it!
#
# ======== Epoch 12 / 30 ========
# Training...
#   Batch    40  of    943.    .
#   step loss: 0.13
#   Batch    80  of    943.    .
#   step loss: 0.15
#   Batch   120  of    943.    .
#   step loss: 0.26
#   Batch   160  of    943.    .
#   step loss: 0.22
#   Batch   200  of    943.    .
#   step loss: 0.14
#   Batch   240  of    943.    .
#   step loss: 0.15
#   Batch   280  of    943.    .
#   step loss: 0.23
#   Batch   320  of    943.    .
#   step loss: 0.21
#   Batch   360  of    943.    .
#   step loss: 0.23
#   Batch   400  of    943.    .
#   step loss: 0.26
#   Batch   440  of    943.    .
#   step loss: 0.17
#   Batch   480  of    943.    .
#   step loss: 0.24
#   Batch   520  of    943.    .
#   step loss: 0.24
#   Batch   560  of    943.    .
#   step loss: 0.18
#   Batch   600  of    943.    .
#   step loss: 0.14
#   Batch   640  of    943.    .
#   step loss: 0.23
#   Batch   680  of    943.    .
#   step loss: 0.18
#   Batch   720  of    943.    .
#   step loss: 0.18
#   Batch   760  of    943.    .
#   step loss: 0.19
#   Batch   800  of    943.    .
#   step loss: 0.22
#   Batch   840  of    943.    .
#   step loss: 0.24
#   Batch   880  of    943.    .
#   step loss: 0.19
#   Batch   920  of    943.    .
#   step loss: 0.24
#
#   Average training loss: 0.20
#
# Running Validation...
# Batch accuracy: 89.84
# Batch accuracy: 92.97
# Batch accuracy: 91.41
# Batch accuracy: 92.19
# Batch accuracy: 93.16
# Batch accuracy: 91.41
# Batch accuracy: 92.77
# Batch accuracy: 91.41
# Batch accuracy: 90.04
# Batch accuracy: 91.60
# Batch accuracy: 93.16
# Batch accuracy: 93.16
# Batch accuracy: 91.99
# Batch accuracy: 91.02
# Batch accuracy: 91.60
# Batch accuracy: 94.34
# Batch accuracy: 92.58
# Batch accuracy: 90.82
# Batch accuracy: 91.99
# Batch accuracy: 91.80
# Batch accuracy: 91.41
# Batch accuracy: 92.77
# Batch accuracy: 90.23
# Batch accuracy: 92.19
# Batch accuracy: 91.80
# Batch accuracy: 93.16
# Batch accuracy: 92.58
# Batch accuracy: 93.55
# Batch accuracy: 93.55
# Batch accuracy: 94.14
# Batch accuracy: 92.58
# Batch accuracy: 91.80
# Batch accuracy: 93.36
# Batch accuracy: 91.02
# Batch accuracy: 92.58
# Batch accuracy: 91.21
# Batch accuracy: 91.21
# Batch accuracy: 91.02
# Batch accuracy: 92.19
# Batch accuracy: 91.80
# Batch accuracy: 92.77
# Batch accuracy: 92.97
# Batch accuracy: 90.04
# Batch accuracy: 92.38
# Batch accuracy: 92.19
# Batch accuracy: 92.38
# Batch accuracy: 90.04
# Batch accuracy: 92.58
# Batch accuracy: 94.14
# Batch accuracy: 92.38
# Batch accuracy: 93.16
# Batch accuracy: 91.21
# Batch accuracy: 93.16
# Batch accuracy: 92.19
# Batch accuracy: 91.80
# Batch accuracy: 91.60
# Batch accuracy: 90.04
# Batch accuracy: 92.58
# Batch accuracy: 91.80
# Batch accuracy: 91.99
# Batch accuracy: 91.21
# Batch accuracy: 92.97
# Batch accuracy: 93.36
# Batch accuracy: 91.99
# Batch accuracy: 90.23
# Batch accuracy: 92.38
# Batch accuracy: 92.58
# Batch accuracy: 90.23
# Batch accuracy: 91.21
# Batch accuracy: 89.45
# Batch accuracy: 91.02
# Batch accuracy: 90.82
# Batch accuracy: 92.19
# Batch accuracy: 91.80
# Batch accuracy: 91.80
# Batch accuracy: 91.99
# Batch accuracy: 92.58
# Batch accuracy: 91.99
# Batch accuracy: 92.38
# Batch accuracy: 90.23
# Batch accuracy: 93.36
# Batch accuracy: 90.82
# Batch accuracy: 90.04
# Batch accuracy: 91.60
# Batch accuracy: 92.77
# Batch accuracy: 93.16
# Batch accuracy: 92.58
# Batch accuracy: 93.36
# Batch accuracy: 89.26
# Batch accuracy: 91.21
# Batch accuracy: 91.41
# Batch accuracy: 91.02
# Batch accuracy: 90.82
# Batch accuracy: 90.82
# Batch accuracy: 92.38
# Batch accuracy: 90.43
# Batch accuracy: 91.99
# Batch accuracy: 94.34
# Batch accuracy: 92.97
# Batch accuracy: 90.04
# Batch accuracy: 92.58
# Batch accuracy: 91.99
# Batch accuracy: 91.60
# Batch accuracy: 91.60
# Batch accuracy: 93.08
#   Accuracy: 91.93
# New best model, saving it!
#
# ======== Epoch 13 / 30 ========
# Training...
#   Batch    40  of    943.    .
#   step loss: 0.17
#   Batch    80  of    943.    .
#   step loss: 0.22
#   Batch   120  of    943.    .
#   step loss: 0.19
#   Batch   160  of    943.    .
#   step loss: 0.22
#   Batch   200  of    943.    .
#   step loss: 0.26
#   Batch   240  of    943.    .
#   step loss: 0.23
#   Batch   280  of    943.    .
#   step loss: 0.17
#   Batch   320  of    943.    .
#   step loss: 0.20
#   Batch   360  of    943.    .
#   step loss: 0.17
#   Batch   400  of    943.    .
#   step loss: 0.23
#   Batch   440  of    943.    .
#   step loss: 0.18
#   Batch   480  of    943.    .
#   step loss: 0.17
#   Batch   520  of    943.    .
#   step loss: 0.21
#   Batch   560  of    943.    .
#   step loss: 0.18
#   Batch   600  of    943.    .
#   step loss: 0.29
#   Batch   640  of    943.    .
#   step loss: 0.23
#   Batch   680  of    943.    .
#   step loss: 0.21
#   Batch   720  of    943.    .
#   step loss: 0.22
#   Batch   760  of    943.    .
#   step loss: 0.20
#   Batch   800  of    943.    .
#   step loss: 0.25
#   Batch   840  of    943.    .
#   step loss: 0.24
#   Batch   880  of    943.    .
#   step loss: 0.19
#   Batch   920  of    943.    .
#   step loss: 0.13
#
#   Average training loss: 0.19
#
# Running Validation...
# Batch accuracy: 91.99
# Batch accuracy: 91.41
# Batch accuracy: 90.82
# Batch accuracy: 92.58
# Batch accuracy: 91.99
# Batch accuracy: 90.62
# Batch accuracy: 91.80
# Batch accuracy: 93.16
# Batch accuracy: 92.77
# Batch accuracy: 91.41
# Batch accuracy: 92.38
# Batch accuracy: 92.38
# Batch accuracy: 91.21
# Batch accuracy: 93.95
# Batch accuracy: 90.82
# Batch accuracy: 92.38
# Batch accuracy: 92.38
# Batch accuracy: 91.41
# Batch accuracy: 91.80
# Batch accuracy: 94.14
# Batch accuracy: 91.99
# Batch accuracy: 91.80
# Batch accuracy: 90.82
# Batch accuracy: 91.80
# Batch accuracy: 91.60
# Batch accuracy: 93.75
# Batch accuracy: 92.77
# Batch accuracy: 90.43
# Batch accuracy: 90.82
# Batch accuracy: 91.21
# Batch accuracy: 91.41
# Batch accuracy: 93.36
# Batch accuracy: 92.19
# Batch accuracy: 89.65
# Batch accuracy: 91.60
# Batch accuracy: 90.62
# Batch accuracy: 89.06
# Batch accuracy: 91.80
# Batch accuracy: 92.38
# Batch accuracy: 90.23
# Batch accuracy: 91.80
# Batch accuracy: 93.16
# Batch accuracy: 91.99
# Batch accuracy: 92.58
# Batch accuracy: 92.38
# Batch accuracy: 90.43
# Batch accuracy: 89.26
# Batch accuracy: 91.41
# Batch accuracy: 92.38
# Batch accuracy: 92.38
# Batch accuracy: 90.23
# Batch accuracy: 93.36
# Batch accuracy: 92.19
# Batch accuracy: 91.80
# Batch accuracy: 91.21
# Batch accuracy: 91.60
# Batch accuracy: 91.60
# Batch accuracy: 91.99
# Batch accuracy: 94.34
# Batch accuracy: 91.80
# Batch accuracy: 91.02
# Batch accuracy: 93.36
# Batch accuracy: 91.02
# Batch accuracy: 90.23
# Batch accuracy: 91.60
# Batch accuracy: 91.41
# Batch accuracy: 91.02
# Batch accuracy: 90.62
# Batch accuracy: 91.99
# Batch accuracy: 92.77
# Batch accuracy: 92.58
# Batch accuracy: 90.43
# Batch accuracy: 91.60
# Batch accuracy: 93.55
# Batch accuracy: 90.43
# Batch accuracy: 92.97
# Batch accuracy: 90.23
# Batch accuracy: 91.99
# Batch accuracy: 92.97
# Batch accuracy: 92.38
# Batch accuracy: 91.60
# Batch accuracy: 91.99
# Batch accuracy: 89.65
# Batch accuracy: 93.36
# Batch accuracy: 90.82
# Batch accuracy: 93.16
# Batch accuracy: 92.38
# Batch accuracy: 93.36
# Batch accuracy: 92.77
# Batch accuracy: 90.23
# Batch accuracy: 91.21
# Batch accuracy: 91.41
# Batch accuracy: 93.16
# Batch accuracy: 91.80
# Batch accuracy: 90.04
# Batch accuracy: 93.55
# Batch accuracy: 92.38
# Batch accuracy: 91.02
# Batch accuracy: 92.77
# Batch accuracy: 91.41
# Batch accuracy: 90.62
# Batch accuracy: 91.60
# Batch accuracy: 93.16
# Batch accuracy: 90.04
# Batch accuracy: 92.22
#   Accuracy: 91.80
# The model does not improve for 1 epochs!
#
# ======== Epoch 14 / 30 ========
# Training...
#   Batch    40  of    943.    .
#   step loss: 0.18
#   Batch    80  of    943.    .
#   step loss: 0.24
#   Batch   120  of    943.    .
#   step loss: 0.16
#   Batch   160  of    943.    .
#   step loss: 0.19
#   Batch   200  of    943.    .
#   step loss: 0.16
#   Batch   240  of    943.    .
#   step loss: 0.15
#   Batch   280  of    943.    .
#   step loss: 0.20
#   Batch   320  of    943.    .
#   step loss: 0.22
#   Batch   360  of    943.    .
#   step loss: 0.15
#   Batch   400  of    943.    .
#   step loss: 0.14
#   Batch   440  of    943.    .
#   step loss: 0.24
#   Batch   480  of    943.    .
#   step loss: 0.18
#   Batch   520  of    943.    .
#   step loss: 0.17
#   Batch   560  of    943.    .
#   step loss: 0.20
#   Batch   600  of    943.    .
#   step loss: 0.22
#   Batch   640  of    943.    .
#   step loss: 0.24
#   Batch   680  of    943.    .
#   step loss: 0.14
# ...
# Batch accuracy: 93.36
# Batch accuracy: 91.41
# Batch accuracy: 92.58
# Batch accuracy: 93.55
# Batch accuracy: 93.75
# Batch accuracy: 93.55
# Batch accuracy: 91.80
# Batch accuracy: 93.36
# Batch accuracy: 92.38
# Batch accuracy: 92.38
# Batch accuracy: 90.62
# Batch accuracy: 93.16
# Batch accuracy: 94.53
# Batch accuracy: 90.62
# Batch accuracy: 92.97
# Batch accuracy: 91.80
# Batch accuracy: 90.82
# Batch accuracy: 92.77
# Batch accuracy: 92.77
# Batch accuracy: 91.21
# Batch accuracy: 93.55
# Batch accuracy: 94.92
# Batch accuracy: 93.75
# Batch accuracy: 92.58
# Batch accuracy: 92.58
# Batch accuracy: 92.19
# Batch accuracy: 92.77
# Batch accuracy: 92.97
# Batch accuracy: 92.19
# Batch accuracy: 92.97
# Batch accuracy: 93.55
# Batch accuracy: 93.55
# Batch accuracy: 92.97
# Batch accuracy: 91.80
# Batch accuracy: 92.97
# Batch accuracy: 93.16
# Batch accuracy: 92.97
# Batch accuracy: 91.60
# Batch accuracy: 89.84
# Batch accuracy: 90.62
# Batch accuracy: 91.02
# Batch accuracy: 93.55
# Batch accuracy: 92.97
# Batch accuracy: 90.23
# Batch accuracy: 91.41
# Batch accuracy: 92.77
# Batch accuracy: 93.95
# Batch accuracy: 91.41
# Batch accuracy: 91.80
# Batch accuracy: 90.82
# Batch accuracy: 90.62
# Batch accuracy: 94.34
# Batch accuracy: 91.41
# Batch accuracy: 91.80
# Batch accuracy: 91.02
# Batch accuracy: 90.23
# Batch accuracy: 91.02
# Batch accuracy: 92.19
# Batch accuracy: 94.53
# Batch accuracy: 92.38
# Batch accuracy: 93.75
# Batch accuracy: 92.19
# Batch accuracy: 91.41
# Batch accuracy: 92.58
# Batch accuracy: 91.41
# Batch accuracy: 92.77
# Batch accuracy: 93.08
#   Accuracy: 92.40
# The model does not improve for 1 epochs!
#
# ======== Epoch 27 / 30 ========
# Training...
#   Batch    40  of    943.    .
#   step loss: 0.10
#   Batch    80  of    943.    .
#   step loss: 0.11
#   Batch   120  of    943.    .
#   step loss: 0.14
#   Batch   160  of    943.    .
#   step loss: 0.08
#   Batch   200  of    943.    .
#   step loss: 0.14
#   Batch   240  of    943.    .
#   step loss: 0.10
#   Batch   280  of    943.    .
#   step loss: 0.09
#   Batch   320  of    943.    .
#   step loss: 0.14
#   Batch   360  of    943.    .
#   step loss: 0.12
#   Batch   400  of    943.    .
#   step loss: 0.13
#   Batch   440  of    943.    .
#   step loss: 0.12
#   Batch   480  of    943.    .
#   step loss: 0.11
#   Batch   520  of    943.    .
#   step loss: 0.12
#   Batch   560  of    943.    .
#   step loss: 0.14
#   Batch   600  of    943.    .
#   step loss: 0.10
#   Batch   640  of    943.    .
#   step loss: 0.13
#   Batch   680  of    943.    .
#   step loss: 0.13
#   Batch   720  of    943.    .
#   step loss: 0.12
#   Batch   760  of    943.    .
#   step loss: 0.11
#   Batch   800  of    943.    .
#   step loss: 0.13
#   Batch   840  of    943.    .
#   step loss: 0.08
#   Batch   880  of    943.    .
#   step loss: 0.11
#   Batch   920  of    943.    .
#   step loss: 0.08
#
#   Average training loss: 0.11
#
# Running Validation...
# Batch accuracy: 92.77
# Batch accuracy: 92.97
# Batch accuracy: 92.58
# Batch accuracy: 91.99
# Batch accuracy: 94.73
# Batch accuracy: 94.53
# Batch accuracy: 92.19
# Batch accuracy: 91.41
# Batch accuracy: 91.99
# Batch accuracy: 91.80
# Batch accuracy: 92.77
# Batch accuracy: 92.77
# Batch accuracy: 93.36
# Batch accuracy: 93.16
# Batch accuracy: 91.80
# Batch accuracy: 92.97
# Batch accuracy: 93.16
# Batch accuracy: 93.36
# Batch accuracy: 94.53
# Batch accuracy: 93.16
# Batch accuracy: 93.36
# Batch accuracy: 93.55
# Batch accuracy: 92.97
# Batch accuracy: 93.16
# Batch accuracy: 91.99
# Batch accuracy: 91.21
# Batch accuracy: 92.77
# Batch accuracy: 93.55
# Batch accuracy: 94.92
# Batch accuracy: 93.36
# Batch accuracy: 90.82
# Batch accuracy: 92.38
# Batch accuracy: 93.95
# Batch accuracy: 92.97
# Batch accuracy: 94.14
# Batch accuracy: 93.16
# Batch accuracy: 91.80
# Batch accuracy: 92.19
# Batch accuracy: 90.82
# Batch accuracy: 92.58
# Batch accuracy: 92.97
# Batch accuracy: 90.62
# Batch accuracy: 91.99
# Batch accuracy: 91.60
# Batch accuracy: 91.21
# Batch accuracy: 92.97
# Batch accuracy: 90.23
# Batch accuracy: 92.77
# Batch accuracy: 90.43
# Batch accuracy: 93.55
# Batch accuracy: 90.43
# Batch accuracy: 95.90
# Batch accuracy: 92.38
# Batch accuracy: 92.19
# Batch accuracy: 91.41
# Batch accuracy: 93.36
# Batch accuracy: 93.16
# Batch accuracy: 93.36
# Batch accuracy: 91.41
# Batch accuracy: 93.36
# Batch accuracy: 92.77
# Batch accuracy: 93.36
# Batch accuracy: 92.77
# Batch accuracy: 90.23
# Batch accuracy: 92.97
# Batch accuracy: 92.19
# Batch accuracy: 92.58
# Batch accuracy: 91.60
# Batch accuracy: 92.38
# Batch accuracy: 92.97
# Batch accuracy: 91.60
# Batch accuracy: 92.77
# Batch accuracy: 89.45
# Batch accuracy: 92.77
# Batch accuracy: 91.02
# Batch accuracy: 93.16
# Batch accuracy: 92.38
# Batch accuracy: 91.60
# Batch accuracy: 91.99
# Batch accuracy: 92.97
# Batch accuracy: 91.80
# Batch accuracy: 91.99
# Batch accuracy: 92.38
# Batch accuracy: 90.82
# Batch accuracy: 92.97
# Batch accuracy: 93.16
# Batch accuracy: 91.21
# Batch accuracy: 92.38
# Batch accuracy: 91.41
# Batch accuracy: 91.99
# Batch accuracy: 92.38
# Batch accuracy: 91.41
# Batch accuracy: 93.36
# Batch accuracy: 90.82
# Batch accuracy: 91.21
# Batch accuracy: 92.38
# Batch accuracy: 92.19
# Batch accuracy: 92.77
# Batch accuracy: 91.60
# Batch accuracy: 92.19
# Batch accuracy: 92.97
# Batch accuracy: 93.16
# Batch accuracy: 92.77
# Batch accuracy: 92.38
# Batch accuracy: 90.78
#   Accuracy: 92.43
# The model does not improve for 2 epochs!
#
# ======== Epoch 28 / 30 ========
# Training...
#   Batch    40  of    943.    .
#   step loss: 0.10
#   Batch    80  of    943.    .
#   step loss: 0.14
#   Batch   120  of    943.    .
#   step loss: 0.10
#   Batch   160  of    943.    .
#   step loss: 0.10
#   Batch   200  of    943.    .
#   step loss: 0.13
#   Batch   240  of    943.    .
#   step loss: 0.14
#   Batch   280  of    943.    .
#   step loss: 0.10
#   Batch   320  of    943.    .
#   step loss: 0.08
#   Batch   360  of    943.    .
#   step loss: 0.09
#   Batch   400  of    943.    .
#   step loss: 0.10
#   Batch   440  of    943.    .
#   step loss: 0.14
#   Batch   480  of    943.    .
#   step loss: 0.09
#   Batch   520  of    943.    .
#   step loss: 0.13
#   Batch   560  of    943.    .
#   step loss: 0.10
#   Batch   600  of    943.    .
#   step loss: 0.14
#   Batch   640  of    943.    .
#   step loss: 0.10
#   Batch   680  of    943.    .
#   step loss: 0.14
#   Batch   720  of    943.    .
#   step loss: 0.10
#   Batch   760  of    943.    .
#   step loss: 0.11
#   Batch   800  of    943.    .
#   step loss: 0.10
#   Batch   840  of    943.    .
#   step loss: 0.17
#   Batch   880  of    943.    .
#   step loss: 0.11
#   Batch   920  of    943.    .
#   step loss: 0.11
#
#   Average training loss: 0.11
#
# Running Validation...
# Batch accuracy: 92.38
# Batch accuracy: 91.60
# Batch accuracy: 91.80
# Batch accuracy: 90.62
# Batch accuracy: 93.95
# Batch accuracy: 91.21
# Batch accuracy: 91.21
# Batch accuracy: 92.58
# Batch accuracy: 92.77
# Batch accuracy: 90.43
# Batch accuracy: 93.95
# Batch accuracy: 92.58
# Batch accuracy: 91.99
# Batch accuracy: 92.38
# Batch accuracy: 92.77
# Batch accuracy: 92.97
# Batch accuracy: 93.16
# Batch accuracy: 92.19
# Batch accuracy: 93.55
# Batch accuracy: 91.21
# Batch accuracy: 91.99
# Batch accuracy: 91.02
# Batch accuracy: 93.16
# Batch accuracy: 92.97
# Batch accuracy: 90.04
# Batch accuracy: 91.80
# Batch accuracy: 92.97
# Batch accuracy: 93.55
# Batch accuracy: 92.58
# Batch accuracy: 95.70
# Batch accuracy: 91.80
# Batch accuracy: 92.77
# Batch accuracy: 91.99
# Batch accuracy: 92.38
# Batch accuracy: 91.02
# Batch accuracy: 92.77
# Batch accuracy: 93.55
# Batch accuracy: 91.99
# Batch accuracy: 93.16
# Batch accuracy: 92.58
# Batch accuracy: 91.60
# Batch accuracy: 90.82
# Batch accuracy: 94.14
# Batch accuracy: 92.38
# Batch accuracy: 93.16
# Batch accuracy: 92.77
# Batch accuracy: 92.77
# Batch accuracy: 92.38
# Batch accuracy: 91.80
# Batch accuracy: 93.16
# Batch accuracy: 94.53
# Batch accuracy: 93.55
# Batch accuracy: 90.43
# Batch accuracy: 92.97
# Batch accuracy: 92.19
# Batch accuracy: 90.43
# Batch accuracy: 93.95
# Batch accuracy: 90.82
# Batch accuracy: 92.97
# Batch accuracy: 92.38
# Batch accuracy: 92.97
# Batch accuracy: 94.73
# Batch accuracy: 93.75
# Batch accuracy: 91.99
# Batch accuracy: 91.60
# Batch accuracy: 90.62
# Batch accuracy: 92.58
# Batch accuracy: 91.02
# Batch accuracy: 90.43
# Batch accuracy: 91.21
# Batch accuracy: 92.97
# Batch accuracy: 93.55
# Batch accuracy: 94.14
# Batch accuracy: 93.95
# Batch accuracy: 90.23
# Batch accuracy: 92.58
# Batch accuracy: 93.16
# Batch accuracy: 92.97
# Batch accuracy: 91.60
# Batch accuracy: 92.19
# Batch accuracy: 90.82
# Batch accuracy: 92.77
# Batch accuracy: 92.19
# Batch accuracy: 91.41
# Batch accuracy: 92.97
# Batch accuracy: 91.80
# Batch accuracy: 92.97
# Batch accuracy: 91.60
# Batch accuracy: 91.60
# Batch accuracy: 91.02
# Batch accuracy: 92.58
# Batch accuracy: 92.38
# Batch accuracy: 92.97
# Batch accuracy: 93.16
# Batch accuracy: 94.14
# Batch accuracy: 93.36
# Batch accuracy: 90.23
# Batch accuracy: 92.58
# Batch accuracy: 93.75
# Batch accuracy: 93.75
# Batch accuracy: 93.55
# Batch accuracy: 93.36
# Batch accuracy: 92.19
# Batch accuracy: 91.60
# Batch accuracy: 94.52
#   Accuracy: 92.44
# The model does not improve for 3 epochs!
#
# ======== Epoch 29 / 30 ========
# Training...
#   Batch    40  of    943.    .
#   step loss: 0.13
#   Batch    80  of    943.    .
#   step loss: 0.10
#   Batch   120  of    943.    .
#   step loss: 0.09
#   Batch   160  of    943.    .
#   step loss: 0.14
#   Batch   200  of    943.    .
#   step loss: 0.12
#   Batch   240  of    943.    .
#   step loss: 0.11
#   Batch   280  of    943.    .
#   step loss: 0.10
#   Batch   320  of    943.    .
#   step loss: 0.11
#   Batch   360  of    943.    .
#   step loss: 0.14
#   Batch   400  of    943.    .
#   step loss: 0.15
#   Batch   440  of    943.    .
#   step loss: 0.11
#   Batch   480  of    943.    .
#   step loss: 0.09
#   Batch   520  of    943.    .
#   step loss: 0.08
#   Batch   560  of    943.    .
#   step loss: 0.13
#   Batch   600  of    943.    .
#   step loss: 0.09
#   Batch   640  of    943.    .
#   step loss: 0.09
#   Batch   680  of    943.    .
#   step loss: 0.10
#   Batch   720  of    943.    .
#   step loss: 0.10
#   Batch   760  of    943.    .
#   step loss: 0.11
#   Batch   800  of    943.    .
#   step loss: 0.12
#   Batch   840  of    943.    .
#   step loss: 0.09
#   Batch   880  of    943.    .
#   step loss: 0.12
#   Batch   920  of    943.    .
#   step loss: 0.11
#
#   Average training loss: 0.11
#
# Running Validation...
# Batch accuracy: 92.38
# Batch accuracy: 91.80
# Batch accuracy: 93.36
# Batch accuracy: 92.77
# Batch accuracy: 93.36
# Batch accuracy: 91.41
# Batch accuracy: 93.55
# Batch accuracy: 92.19
# Batch accuracy: 92.77
# Batch accuracy: 91.60
# Batch accuracy: 93.55
# Batch accuracy: 93.55
# Batch accuracy: 92.77
# Batch accuracy: 90.62
# Batch accuracy: 91.21
# Batch accuracy: 92.97
# Batch accuracy: 90.82
# Batch accuracy: 92.19
# Batch accuracy: 91.99
# Batch accuracy: 90.82
# Batch accuracy: 90.23
# Batch accuracy: 92.77
# Batch accuracy: 92.77
# Batch accuracy: 92.38
# Batch accuracy: 90.43
# Batch accuracy: 94.34
# Batch accuracy: 92.97
# Batch accuracy: 90.23
# Batch accuracy: 92.19
# Batch accuracy: 92.77
# Batch accuracy: 91.80
# Batch accuracy: 93.75
# Batch accuracy: 94.92
# Batch accuracy: 91.80
# Batch accuracy: 92.77
# Batch accuracy: 91.41
# Batch accuracy: 93.16
# Batch accuracy: 90.82
# Batch accuracy: 94.53
# Batch accuracy: 93.36
# Batch accuracy: 93.16
# Batch accuracy: 93.75
# Batch accuracy: 93.95
# Batch accuracy: 92.77
# Batch accuracy: 91.99
# Batch accuracy: 91.02
# Batch accuracy: 93.95
# Batch accuracy: 92.19
# Batch accuracy: 92.58
# Batch accuracy: 92.58
# Batch accuracy: 92.77
# Batch accuracy: 91.99
# Batch accuracy: 93.16
# Batch accuracy: 92.19
# Batch accuracy: 91.21
# Batch accuracy: 91.21
# Batch accuracy: 90.62
# Batch accuracy: 93.16
# Batch accuracy: 92.58
# Batch accuracy: 90.82
# Batch accuracy: 93.16
# Batch accuracy: 90.82
# Batch accuracy: 93.75
# Batch accuracy: 93.75
# Batch accuracy: 90.82
# Batch accuracy: 92.77
# Batch accuracy: 91.99
# Batch accuracy: 92.58
# Batch accuracy: 91.02
# Batch accuracy: 92.77
# Batch accuracy: 93.16
# Batch accuracy: 90.43
# Batch accuracy: 90.23
# Batch accuracy: 93.55
# Batch accuracy: 92.19
# Batch accuracy: 92.58
# Batch accuracy: 91.02
# Batch accuracy: 93.16
# Batch accuracy: 91.80
# Batch accuracy: 93.36
# Batch accuracy: 94.14
# Batch accuracy: 93.36
# Batch accuracy: 91.99
# Batch accuracy: 92.19
# Batch accuracy: 93.95
# Batch accuracy: 90.62
# Batch accuracy: 89.84
# Batch accuracy: 91.41
# Batch accuracy: 92.19
# Batch accuracy: 92.58
# Batch accuracy: 91.80
# Batch accuracy: 93.75
# Batch accuracy: 91.41
# Batch accuracy: 93.75
# Batch accuracy: 92.77
# Batch accuracy: 92.19
# Batch accuracy: 93.95
# Batch accuracy: 91.60
# Batch accuracy: 93.55
# Batch accuracy: 93.36
# Batch accuracy: 95.70
# Batch accuracy: 90.43
# Batch accuracy: 92.19
# Batch accuracy: 94.14
# Batch accuracy: 91.93
#   Accuracy: 92.40
# The model does not improve for 4 epochs!
# Epoch    29: reducing learning rate of group 0 to 1.0000e-05.
#
# ======== Epoch 30 / 30 ========
# Training...
#   Batch    40  of    943.    .
#   step loss: 0.08
#   Batch    80  of    943.    .
#   step loss: 0.11
#   Batch   120  of    943.    .
#   step loss: 0.11
#   Batch   160  of    943.    .
#   step loss: 0.15
#   Batch   200  of    943.    .
#   step loss: 0.10
#   Batch   240  of    943.    .
#   step loss: 0.09
#   Batch   280  of    943.    .
#   step loss: 0.08
#   Batch   320  of    943.    .
#   step loss: 0.13
#   Batch   360  of    943.    .
#   step loss: 0.12
#   Batch   400  of    943.    .
#   step loss: 0.12
#   Batch   440  of    943.    .
#   step loss: 0.12
#   Batch   480  of    943.    .
#   step loss: 0.09
#   Batch   520  of    943.    .
#   step loss: 0.11
#   Batch   560  of    943.    .
#   step loss: 0.12
#   Batch   600  of    943.    .
#   step loss: 0.08
#   Batch   640  of    943.    .
#   step loss: 0.12
#   Batch   680  of    943.    .
#   step loss: 0.10
#   Batch   720  of    943.    .
#   step loss: 0.10
#   Batch   760  of    943.    .
#   step loss: 0.15
#   Batch   800  of    943.    .
#   step loss: 0.12
#   Batch   840  of    943.    .
#   step loss: 0.12
#   Batch   880  of    943.    .
#   step loss: 0.10
#   Batch   920  of    943.    .
#   step loss: 0.10
#
#   Average training loss: 0.11
#
# Running Validation...
# Batch accuracy: 91.60
# Batch accuracy: 93.95
# Batch accuracy: 94.14
# Batch accuracy: 92.58
# Batch accuracy: 91.99
# Batch accuracy: 92.19
# Batch accuracy: 92.19
# Batch accuracy: 90.23
# Batch accuracy: 92.19
# Batch accuracy: 92.38
# Batch accuracy: 92.38
# Batch accuracy: 91.21
# Batch accuracy: 89.26
# Batch accuracy: 92.38
# Batch accuracy: 91.60
# Batch accuracy: 92.77
# Batch accuracy: 92.58
# Batch accuracy: 92.58
# Batch accuracy: 92.38
# Batch accuracy: 93.55
# Batch accuracy: 92.77
# Batch accuracy: 92.38
# Batch accuracy: 92.19
# Batch accuracy: 92.19
# Batch accuracy: 91.80
# Batch accuracy: 95.70
# Batch accuracy: 93.95
# Batch accuracy: 91.41
# Batch accuracy: 93.36
# Batch accuracy: 91.60
# Batch accuracy: 94.73
# Batch accuracy: 93.55
# Batch accuracy: 94.34
# Batch accuracy: 91.21
# Batch accuracy: 93.36
# Batch accuracy: 92.19
# Batch accuracy: 93.36
# Batch accuracy: 92.97
# Batch accuracy: 92.19
# Batch accuracy: 91.21
# Batch accuracy: 92.58
# Batch accuracy: 92.58
# Batch accuracy: 91.99
# Batch accuracy: 91.41
# Batch accuracy: 92.58
# Batch accuracy: 92.38
# Batch accuracy: 91.80
# Batch accuracy: 94.53
# Batch accuracy: 94.53
# Batch accuracy: 93.95
# Batch accuracy: 92.97
# Batch accuracy: 90.43
# Batch accuracy: 92.38
# Batch accuracy: 92.58
# Batch accuracy: 92.58
# Batch accuracy: 92.58
# Batch accuracy: 92.77
# Batch accuracy: 91.21
# Batch accuracy: 93.16
# Batch accuracy: 92.97
# Batch accuracy: 91.21
# Batch accuracy: 90.82
# Batch accuracy: 91.99
# Batch accuracy: 93.36
# Batch accuracy: 91.99
# Batch accuracy: 91.80
# Batch accuracy: 95.70
# Batch accuracy: 91.21
# Batch accuracy: 92.19
# Batch accuracy: 93.36
# Batch accuracy: 91.02
# Batch accuracy: 93.16
# Batch accuracy: 93.16
# Batch accuracy: 91.21
# Batch accuracy: 93.95
# Batch accuracy: 94.14
# Batch accuracy: 90.23
# Batch accuracy: 91.02
# Batch accuracy: 94.34
# Batch accuracy: 93.16
# Batch accuracy: 91.41
# Batch accuracy: 92.97
# Batch accuracy: 95.12
# Batch accuracy: 91.80
# Batch accuracy: 91.02
# Batch accuracy: 93.55
# Batch accuracy: 91.21
# Batch accuracy: 93.16
# Batch accuracy: 93.75
# Batch accuracy: 91.02
# Batch accuracy: 91.60
# Batch accuracy: 90.04
# Batch accuracy: 91.21
# Batch accuracy: 91.99
# Batch accuracy: 92.58
# Batch accuracy: 90.82
# Batch accuracy: 91.80
# Batch accuracy: 93.75
# Batch accuracy: 93.75
# Batch accuracy: 93.55
# Batch accuracy: 92.38
# Batch accuracy: 91.21
# Batch accuracy: 89.84
# Batch accuracy: 93.16
# Batch accuracy: 91.64
#   Accuracy: 92.44
# The model does not improve for 5 epochs!
#
# Training complete!

# %%
def predict(
    model_path: Path,
    dataset: str,
    batch_size: int,
    labels_dict,
    device: torch.device
):

    print(f"====Loading dataset for testing")
    test_corpus = NLPDataset(dataset, "test", sentence_max_len, labels_dict = labels_dict, vocab= voc)

    test_dataloader = DataLoader(
        test_corpus,
        batch_size=batch_size,
        #sampler = RandomSampler(test_corpus),
        pin_memory=True,
        num_workers=0,
        drop_last=False
    )

    print(f"====Loading model for testing")
    model = torch.load(join(model_path, "best-model.pth"))
    model.to(device)
    model.eval()
    pred_labels = []
    test_labels = []
    logits_list = []

    def _list_from_tensor(tensor):
        if tensor.numel() == 1:
            return [tensor.item()]
        return list(tensor.cpu().detach().numpy())

    print("====Testing model...")
    for batch in test_dataloader:
        #h = model.init_hidden(len(batch[0]), device)
        #h = tuple([each.data for each in val_h])
        b_input_ids = batch[0]
        b_input_ids = torch.tensor(b_input_ids).to(device).long()
        b_labels = batch[1].to(device)
        with torch.no_grad():
            #h = tuple([each.data for each in h])
            loss, logits = model(b_input_ids, b_labels)
            preds = np.argmax(logits.cpu(), axis=1) # Convert one-hot to index
            b_labels = b_labels.int()
            pred_labels.extend(_list_from_tensor(preds))
            test_labels.extend(_list_from_tensor(b_labels))
        logits_list.extend(_list_from_tensor(logits))

    print(classification_report(test_labels, pred_labels, labels=list(labels_dict.values()), target_names=np.array(list(labels_dict.keys())), digits=3, output_dict=False))
    logits_list = expit(logits_list)
    del model
    torch.cuda.empty_cache()

# %%
del train_dataloader
del validation_dataloader
del train_corpus
del val_corpus
del model
torch.cuda.empty_cache()

# %%
predict(last_saved_model, dataset, batch_size, labels_dict, device)
# Out:
# ====Loading dataset for testing
# ====Loading model for testing
# ====Testing model...
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:39: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#                                                                   precision    recall  f1-score   support
#
#                               Sintomas.Genérico.Sky não funciona      0.931     0.911     0.921      8357
#                                     Sintomas.Genérico.Instalação      0.978     0.972     0.975       647
#                                 Sintomas.Genérico.Canal não pega      0.891     0.913     0.902      5967
#                     Sintomas.Genérico.Equipamento não funciona G      0.922     0.944     0.933      2318
#                                      Sintomas.Genérico.Sem sinal      0.945     0.947     0.946     14552
#                                Sintomas.Qualificado.Cancelamento      0.903     0.962     0.932      1847
#                            Sintomas.Qualificado.Outros problemas      0.800     0.704     0.749       729
#                               Sintomas.Qualificado.NãoTéc_fatura      0.839     0.830     0.834      1451
#                           Sintomas.Qualificado.Mudança de cômodo      0.948     0.940     0.944      1975
#                         Sintomas.Genérico.Equipamento queimado G      0.959     0.975     0.967      2106
#                       Sintomas.Genérico.Problema com equipamento      0.977     0.968     0.972      9645
#                         Sintomas.Genérico.Equipamento quebrado G      0.931     0.951     0.941      1441
#               Sintomas.Qualificado.Controle não funciona para tv      0.750     0.701     0.725       107
#                            Sintomas.Genérico.Falar com atendente      0.968     0.968     0.968      8262
#                             Sintomas.Genérico.Problema com canal      0.957     0.940     0.948      3547
#                        Sintomas.Qualificado.Técnico não resolveu      0.529     0.396     0.453        91
#                           Sintomas.Genérico.Troca de equipamento      0.959     0.962     0.961      3737
#                               Sintomas.Qualificado.NãoTéc_outros      0.852     0.742     0.793       186
#                                 Sintomas.Qualificado.Banda larga      0.982     0.983     0.982      2590
#                                        Sintomas.Genérico.Mudança      0.956     0.967     0.962       891
#                           Sintomas.Qualificado.Ausência de sinal      0.976     0.990     0.983     10158
#                          Sintomas.Qualificado.Cabos e conectores      0.958     0.985     0.972      1558
#                            Sintomas.Qualificado.Técnico não veio      0.874     0.893     0.884      1474
#                      Sintomas.Qualificado.NãoTéc ponto adicional      0.849     0.870     0.859      2049
#                         Sintomas.Qualificado.Mudança de endereço      0.972     0.962     0.967      3343
#                           Sintomas.Genérico.Canal Globo não pega      0.630     0.605     0.617       304
#                            Sintomas.Qualificado.Controle perdido      0.909     0.941     0.925       306
#                           Sintomas.Qualificado.Tela com chuvisco      0.709     0.791     0.747       234
#                          Sintomas.Genérico.Mudança de endereço G      0.990     0.992     0.991      2501
#                            Sintomas.Genérico.Problema com imagem      0.962     0.948     0.955      6605
#          Sintomas.Qualificado.Equipamento liga e desliga sozinho      0.879     0.879     0.879       455
#                                    Sintomas.Qualificado.Código 6      0.847     0.862     0.854       905
#                        Sintomas.Qualificado.Equipamento não liga      0.938     0.958     0.948      1816
#                                Sintomas.Qualificado.NãoTéc_plano      0.799     0.762     0.780      1683
#                           Sintomas.Qualificado.Programação local      0.858     0.887     0.872       380
#                                    Sintomas.Qualificado.Gravação      0.920     0.907     0.913       997
#                                  Sintomas.Qualificado.Sky Online      0.914     0.904     0.909      1926
#                       Sintomas.Genérico.Canal comum não pega (G)      0.779     0.751     0.765      1200
#                    Sintomas.Genérico.Problema com visita técnica      0.998     0.997     0.998      2193
#                        Sintomas.Genérico.Texto ou código na tela      0.858     0.825     0.841      1694
#                               Sintomas.Qualificado.Código 1-2-25      0.888     0.880     0.884       658
#                                  Sintomas.Qualificado.Tela preta      0.889     0.854     0.871       861
#                 Sintomas.Qualificado.Travado no canal do cliente      0.749     0.749     0.749       506
#              Sintomas.Qualificado.Controle não funciona para sky      0.650     0.728     0.687       125
#                    Sintomas.Qualificado.Apenas imagem, sem áudio      0.863     0.859     0.861       562
#               Sintomas.Qualificado.Canal PPV não está disponível      0.886     0.922     0.904      1016
#                         Sintomas.Qualificado.Evento indisponível      0.879     0.954     0.915       130
#                                   Sintomas.Qualificado.Código 56      0.990     0.990     0.990       585
#                       Sintomas.Qualificado.Priorizar atendimento      0.894     0.894     0.894      1140
#                             Sintomas.Genérico.Problema Controle2      0.917     0.930     0.923      1661
#                            Sintomas.Genérico.Canal HD não pega G      0.840     0.895     0.867       697
#                        Sintomas.Qualificado.Reativar programação      0.952     1.000     0.976        60
#                                   Sintomas.Qualificado.Código 77      0.777     0.878     0.824      1094
#                           Sintomas.Qualificado.NãoTéc upgrade hd      0.822     0.905     0.861       419
# Sintomas.Qualificado.Informações e confirmação de visita técnica      0.879     0.899     0.889       910
#                                    Sintomas.Qualificado.Código 4      0.830     0.874     0.851       980
#                      Sintomas.Qualificado.Agendar visita técnica      0.905     0.870     0.887       316
#                         Sintomas.Qualificado.Chip do equipamento      0.947     0.978     0.963        92
#                   Sintomas.Qualificado.Equipamento superaquecido      0.881     0.881     0.881        67
#                         Sintomas.Qualificado.Irritação ou Anatel      0.933     0.932     0.932       950
#                          Sintomas.Qualificado.Código diagnóstico      0.938     1.000     0.968       122
#                             Sintomas.Genérico.Tela monocromática      0.926     0.738     0.821       187
#                            Sintomas.Genérico.Entendimento errado      0.841     0.773     0.806       322
#                                        Sintomas.Genérico.Não sei      0.825     0.793     0.809       440
#                                     Sintomas.Genérico.Código sim      0.667     0.687     0.676        67
#             Sintomas.Qualificado.Atualização crítica de endereço      0.812     0.765     0.788        17
#                             Sintomas.Genérico.Problema com áudio      0.932     0.957     0.944       301
#                              Sintomas.Qualificado.Senha - padrão      0.762     0.800     0.780       120
#                                   Sintomas.Qualificado.Tela azul      0.861     0.925     0.892       134
#                   Sintomas.Qualificado.Mudança de posição antena      0.862     0.876     0.869       654
#                             Sintomas.Genérico.Problema de antena      0.901     0.880     0.890        83
#                              Sintomas.Qualificado.Aplicativo Sky      0.993     0.990     0.991       809
#                                  Sintomas.Genérico.Canal travado      0.854     0.872     0.863       477
#                 Sintomas.Qualificado.Resolvido com sinal booster      0.759     0.712     0.735       212
#                           Sintomas.Qualificado.Legenda incorreta      0.862     0.833     0.847        30
#                                  Sintomas.Qualificado.Código 109      0.949     1.000     0.974        93
#                         Sintomas.Qualificado.Equipamento travado      0.580     0.505     0.540        93
#                          Sintomas.Genérico.Mudança de instalação      1.000     1.000     1.000        98
#                        Sintomas.Genérico.Canal opcional não pega      0.758     0.761     0.760       222
#                                   Sintomas.Qualificado.Código 19      0.961     1.000     0.980        49
#                              Sintomas.Genérico.Mudança de antena      0.979     0.981     0.980       372
#                               Sintomas.Qualificado.NãoTéc_compra      0.775     0.721     0.747       129
#                            Sintomas.Qualificado.NãoTéc sky livre      0.920     0.992     0.955       127
#                       Sintomas.Qualificado.Reset de senha padrão      0.840     0.774     0.805       115
#                           Sintomas.Qualificado.Controle quebrado      0.782     0.674     0.724       138
#                                   Sintomas.Qualificado.Código 14      0.793     0.658     0.719       111
#                         Sintomas.Qualificado.Guia de programação      0.963     0.961     0.962       409
#                              Sintomas.Qualificado.Numeração nova      0.944     0.842     0.890       101
#                       Sintomas.Qualificado.TV é HD, mas Sky é SD      0.833     0.854     0.843       268
#                           Sintomas.Genérico.Sem sinal nem código      0.710     0.521     0.601       146
#                                Sintomas.Qualificado.Cancelar Sky      0.808     0.420     0.553        50
#                                     Sintomas.Qualificado.Recarga      0.750     0.778     0.764        27
#                        Sintomas.Qualificado.Novo Controle Pedido      0.924     0.829     0.874       146
#                        Sintomas.Qualificado.Equipamento queimado      0.838     0.741     0.787       147
#                             Sintomas.Genérico.Problema com senha      0.990     0.993     0.991       291
#                             Sintomas.Qualificado.NãoTéc_cadastro      0.822     0.757     0.788       292
#                          Sintomas.Qualificado.Criar senha padrão      0.909     0.500     0.645        20
#                               Sintomas.Qualificado.Alterar áudio      0.883     0.922     0.902       204
#                         Sintomas.Qualificado.Canal fora da grade      0.816     0.857     0.836       342
#                           Sintomas.Genérico.Problema com legenda      0.984     0.976     0.980       252
#                               Sintomas.Qualificado.Problema tudo      0.917     0.834     0.874       145
#                                    Sintomas.Qualificado.Código 9      1.000     0.778     0.875         9
#                       Sintomas.Qualificado.Imagem preto e branco      0.844     0.853     0.848        95
#                                Sintomas.Qualificado.Número da OS      0.000     0.000     0.000         2
#                      Sintomas.Genérico.Atualização de endereço G      0.914     0.974     0.943        76
#                  Sintomas.Qualificado.Habilitar recurso de senha      0.819     0.756     0.787        78
#                      Sintomas.Genérico.Canal adulto não pega (G)      0.828     0.706     0.762        34
#                    Sintomas.Genérico.Problema com troca de canal      0.667     0.316     0.429        19
#                          Sintomas.Qualificado.Cliente está longe      0.455     0.156     0.233        32
#     Sintomas.Qualificado.Procurando sinal sintonizador terrestre      0.844     0.871     0.857        31
#                       Sintomas.Qualificado.Equipamento com ruído      0.938     0.714     0.811        21
#                                   Sintomas.Qualificado.Código 13      0.950     0.826     0.884        23
#                          Sintomas.Qualificado.Travado exceto 200      0.571     0.235     0.333        17
#                 Sintomas.Qualificado.Legenda não aparece na tela      0.779     0.857     0.816        70
#                       Sintomas.Qualificado.Ativar closed caption      0.000     0.000     0.000         6
#                             Sintomas.Genérico.Promessa de oferta      0.333     0.077     0.125        13
#                        Sintomas.Qualificado.Ausência sinal geral      0.846     0.524     0.647        21
#                              Sintomas.Qualificado.Áudio atrasado      0.750     0.500     0.600         6
#                       Sintomas.Qualificado.Lentidão trocar canal      0.500     0.500     0.500         8
#                     Sintomas.Qualificado.Msg carregando conteúdo      1.000     0.667     0.800         3
#                    Sintomas.Genérico.Problema com closed caption      1.000     1.000     1.000         4
#
#                                                         accuracy                          0.928    133986
#                                                        macro avg      0.845     0.810     0.822    133986
#                                                     weighted avg      0.928     0.928     0.928    133986
