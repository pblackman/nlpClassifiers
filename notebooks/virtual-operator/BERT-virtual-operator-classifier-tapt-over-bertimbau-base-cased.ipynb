# %% [markdown]
# #### Based on https://medium.com/swlh/painless-fine-tuning-of-bert-in-pytorch-b91c14912caa
# https://github.com/aniruddhachoudhury/BERT-Tutorials/blob/master/Blog%202/BERT_Fine_Tuning_Sentence_Classification.ipynb

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import matplotlib.pyplot as plt
import torch.nn as nn
from os.path import join
import torch
from nlpClassifiers.data.dataset  import NLPDataset
#from torch.optim import AdamW, SGD
from torch.utils.data import DataLoader, SequentialSampler, RandomSampler
from transformers import BertForSequenceClassification, AdamW, BertConfig
from transformers import get_linear_schedule_with_warmup
from torch.nn import LayerNorm as BertLayerNorm
import numpy as np
import time
import logging
import datetime
import random
import pandas as pd
import argparse
import pickle as pk
import itertools
import os
import shutil
from pathlib import Path
import copy
import wandb
import re
from nlpClassifiers import settings
from scipy.special import expit
from sklearn.metrics import classification_report

# %%
def predict(
    model_path: Path,
    dataset: str,
    batch_size: int,
    labels_dict,
    device: torch.device
):
       
    print(f"====Loading dataset for testing")
    test_corpus = NLPDataset(dataset, "test", sentence_max_len, bert_path, labels_dict)
    test_dataloader = DataLoader(
        test_corpus,
        batch_size=batch_size,
        #sampler = RandomSampler(test_corpus),
        pin_memory=True,
        num_workers=0,
        drop_last=False
    )

    print(f"====Loading model for testing")
    model = BertForSequenceClassification.from_pretrained(
        model_path,
        num_labels = test_corpus.num_labels,
        output_attentions = False,
        output_hidden_states = True,
    )
    model.to(device)
    model.eval()
  #  cm = ConfusionMatrix([0,1])
    pred_labels = []
    test_labels = []
    logits_list = []

    def _list_from_tensor(tensor):
        if tensor.numel() == 1:
            return [tensor.item()]
        return list(tensor.cpu().detach().numpy())

    print("====Testing model...")
    for batch in test_dataloader:
        batch = tuple(t.to(device) for t in batch)
        b_input_ids, b_segment_ids, b_input_mask, b_labels = batch
        with torch.no_grad():
            loss, logits, *_ =  model(b_input_ids, b_input_mask, token_type_ids=None, labels=b_labels)

            preds = np.argmax(logits.cpu(), axis=1) # Convert one-hot to index
            b_labels = b_labels.int()
            pred_labels.extend(_list_from_tensor(preds))
            test_labels.extend(_list_from_tensor(b_labels))
        logits_list.extend(_list_from_tensor(logits))
    print(classification_report(test_labels, pred_labels, labels=list(labels_dict.values()), target_names=np.array(list(labels_dict.keys())), digits=3))
    logits_list = expit(logits_list)
    del model
    torch.cuda.empty_cache()

# %%
def get_accuracy_from_logits(logits, labels):
    acc = (labels.cpu() == logits.cpu().argmax(-1)).float().detach().numpy()
    return float(100 * acc.sum() / len(acc))

# %%
DATA_PATH = '../../data/virtual-operator'
TRAIN_DATASET = os.path.join(DATA_PATH, 'train.csv')
VAL_DATASET = os.path.join(DATA_PATH, 'val.csv')
TEST_DATASET  = os.path.join(DATA_PATH, 'test.csv')

# %%
gpu = 0
dataset = 'virtual-operator'
bert_path = '../../models/virtual-operator/bertimbau-adaptive-base-finetuned/'
batch_size = 16
sentence_max_len = 82

# %%
device = torch.device(f"cuda:{gpu}")

# %%
model_path='../../models/virtual-operator/bert-base-portuguese-tapt-classifier/base-dataset-virtual-operator-virtual-operator-100-epochs-early-stop-reset-now-wandb'

# %%
train_corpus = NLPDataset(dataset, "train", sentence_max_len, bert_path)
labels_dict = train_corpus.labels_dict

# %%
predict(model_path, dataset, batch_size, labels_dict, device)
# Out:
# ====Loading dataset for testing
# ====Loading model for testing
# ====Testing model...
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#                                                                   precision    recall  f1-score   support
#
#                               Sintomas.Genérico.Sky não funciona      0.968     0.957     0.962      8357
#                                     Sintomas.Genérico.Instalação      0.998     0.992     0.995       647
#                                 Sintomas.Genérico.Canal não pega      0.952     0.951     0.952      5967
#                     Sintomas.Genérico.Equipamento não funciona G      0.967     0.977     0.972      2318
#                                      Sintomas.Genérico.Sem sinal      0.972     0.977     0.974     14552
#                                Sintomas.Qualificado.Cancelamento      0.963     0.981     0.972      1847
#                            Sintomas.Qualificado.Outros problemas      0.911     0.874     0.892       729
#                               Sintomas.Qualificado.NãoTéc_fatura      0.945     0.927     0.936      1451
#                           Sintomas.Qualificado.Mudança de cômodo      0.986     0.965     0.975      1975
#                         Sintomas.Genérico.Equipamento queimado G      0.978     0.997     0.988      2106
#                       Sintomas.Genérico.Problema com equipamento      0.993     0.991     0.992      9645
#                         Sintomas.Genérico.Equipamento quebrado G      0.973     0.983     0.978      1441
#               Sintomas.Qualificado.Controle não funciona para tv      0.920     0.860     0.889       107
#                            Sintomas.Genérico.Falar com atendente      0.990     0.981     0.985      8262
#                             Sintomas.Genérico.Problema com canal      0.977     0.983     0.980      3547
#                        Sintomas.Qualificado.Técnico não resolveu      0.727     0.527     0.611        91
#                           Sintomas.Genérico.Troca de equipamento      0.986     0.977     0.981      3737
#                               Sintomas.Qualificado.NãoTéc_outros      0.896     0.876     0.886       186
#                                 Sintomas.Qualificado.Banda larga      0.984     0.990     0.987      2590
#                                        Sintomas.Genérico.Mudança      0.977     0.980     0.978       891
#                           Sintomas.Qualificado.Ausência de sinal      0.993     0.994     0.994     10158
#                          Sintomas.Qualificado.Cabos e conectores      0.992     0.988     0.990      1558
#                            Sintomas.Qualificado.Técnico não veio      0.952     0.931     0.941      1474
#                      Sintomas.Qualificado.NãoTéc ponto adicional      0.933     0.958     0.945      2049
#                         Sintomas.Qualificado.Mudança de endereço      0.984     0.987     0.985      3343
#                           Sintomas.Genérico.Canal Globo não pega      0.781     0.773     0.777       304
#                            Sintomas.Qualificado.Controle perdido      0.955     0.977     0.966       306
#                           Sintomas.Qualificado.Tela com chuvisco      0.880     0.936     0.907       234
#                          Sintomas.Genérico.Mudança de endereço G      0.995     0.993     0.994      2501
#                            Sintomas.Genérico.Problema com imagem      0.976     0.984     0.980      6605
#          Sintomas.Qualificado.Equipamento liga e desliga sozinho      0.922     0.963     0.942       455
#                                    Sintomas.Qualificado.Código 6      0.945     0.947     0.946       905
#                        Sintomas.Qualificado.Equipamento não liga      0.983     0.982     0.983      1816
#                                Sintomas.Qualificado.NãoTéc_plano      0.922     0.873     0.897      1683
#                           Sintomas.Qualificado.Programação local      0.925     0.939     0.932       380
#                                    Sintomas.Qualificado.Gravação      0.976     0.980     0.978       997
#                                  Sintomas.Qualificado.Sky Online      0.942     0.969     0.955      1926
#                       Sintomas.Genérico.Canal comum não pega (G)      0.891     0.890     0.891      1200
#                    Sintomas.Genérico.Problema com visita técnica      0.998     0.999     0.999      2193
#                        Sintomas.Genérico.Texto ou código na tela      0.936     0.886     0.911      1694
#                               Sintomas.Qualificado.Código 1-2-25      0.942     0.965     0.953       658
#                                  Sintomas.Qualificado.Tela preta      0.957     0.886     0.920       861
#                 Sintomas.Qualificado.Travado no canal do cliente      0.837     0.891     0.863       506
#              Sintomas.Qualificado.Controle não funciona para sky      0.843     0.776     0.808       125
#                    Sintomas.Qualificado.Apenas imagem, sem áudio      0.956     0.931     0.943       562
#               Sintomas.Qualificado.Canal PPV não está disponível      0.960     0.966     0.963      1016
#                         Sintomas.Qualificado.Evento indisponível      0.911     0.946     0.928       130
#                                   Sintomas.Qualificado.Código 56      0.988     0.990     0.989       585
#                       Sintomas.Qualificado.Priorizar atendimento      0.932     0.969     0.950      1140
#                             Sintomas.Genérico.Problema Controle2      0.961     0.956     0.958      1661
#                            Sintomas.Genérico.Canal HD não pega G      0.962     0.908     0.934       697
#                        Sintomas.Qualificado.Reativar programação      0.952     1.000     0.976        60
#                                   Sintomas.Qualificado.Código 77      0.916     0.952     0.934      1094
#                           Sintomas.Qualificado.NãoTéc upgrade hd      0.931     0.936     0.933       419
# Sintomas.Qualificado.Informações e confirmação de visita técnica      0.947     0.954     0.950       910
#                                    Sintomas.Qualificado.Código 4      0.957     0.955     0.956       980
#                      Sintomas.Qualificado.Agendar visita técnica      0.980     0.953     0.966       316
#                         Sintomas.Qualificado.Chip do equipamento      0.938     0.989     0.963        92
#                   Sintomas.Qualificado.Equipamento superaquecido      0.970     0.955     0.962        67
#                         Sintomas.Qualificado.Irritação ou Anatel      0.964     0.989     0.977       950
#                          Sintomas.Qualificado.Código diagnóstico      0.976     0.992     0.984       122
#                             Sintomas.Genérico.Tela monocromática      0.918     0.834     0.874       187
#                            Sintomas.Genérico.Entendimento errado      0.876     0.919     0.897       322
#                                        Sintomas.Genérico.Não sei      0.873     0.902     0.887       440
#                                     Sintomas.Genérico.Código sim      0.875     0.836     0.855        67
#             Sintomas.Qualificado.Atualização crítica de endereço      0.923     0.706     0.800        17
#                             Sintomas.Genérico.Problema com áudio      0.940     0.983     0.961       301
#                              Sintomas.Qualificado.Senha - padrão      0.835     0.925     0.877       120
#                                   Sintomas.Qualificado.Tela azul      0.842     0.955     0.895       134
#                   Sintomas.Qualificado.Mudança de posição antena      0.892     0.950     0.920       654
#                             Sintomas.Genérico.Problema de antena      0.859     0.952     0.903        83
#                              Sintomas.Qualificado.Aplicativo Sky      0.996     0.996     0.996       809
#                                  Sintomas.Genérico.Canal travado      0.919     0.933     0.926       477
#                 Sintomas.Qualificado.Resolvido com sinal booster      0.841     0.849     0.845       212
#                           Sintomas.Qualificado.Legenda incorreta      0.929     0.867     0.897        30
#                                  Sintomas.Qualificado.Código 109      0.989     1.000     0.995        93
#                         Sintomas.Qualificado.Equipamento travado      0.948     0.591     0.728        93
#                          Sintomas.Genérico.Mudança de instalação      0.990     1.000     0.995        98
#                        Sintomas.Genérico.Canal opcional não pega      0.834     0.860     0.847       222
#                                   Sintomas.Qualificado.Código 19      0.959     0.959     0.959        49
#                              Sintomas.Genérico.Mudança de antena      0.984     0.997     0.991       372
#                               Sintomas.Qualificado.NãoTéc_compra      0.893     0.907     0.900       129
#                            Sintomas.Qualificado.NãoTéc sky livre      0.933     0.992     0.962       127
#                       Sintomas.Qualificado.Reset de senha padrão      0.882     0.913     0.897       115
#                           Sintomas.Qualificado.Controle quebrado      0.694     0.906     0.786       138
#                                   Sintomas.Qualificado.Código 14      0.982     0.973     0.977       111
#                         Sintomas.Qualificado.Guia de programação      0.969     0.995     0.982       409
#                              Sintomas.Qualificado.Numeração nova      0.922     0.941     0.931       101
#                       Sintomas.Qualificado.TV é HD, mas Sky é SD      0.968     0.896     0.930       268
#                           Sintomas.Genérico.Sem sinal nem código      0.833     0.719     0.772       146
#                                Sintomas.Qualificado.Cancelar Sky      0.741     0.800     0.769        50
#                                     Sintomas.Qualificado.Recarga      0.926     0.926     0.926        27
#                        Sintomas.Qualificado.Novo Controle Pedido      0.924     0.918     0.921       146
#                        Sintomas.Qualificado.Equipamento queimado      0.880     0.898     0.889       147
#                             Sintomas.Genérico.Problema com senha      0.993     0.997     0.995       291
#                             Sintomas.Qualificado.NãoTéc_cadastro      0.922     0.887     0.904       292
#                          Sintomas.Qualificado.Criar senha padrão      1.000     0.850     0.919        20
#                               Sintomas.Qualificado.Alterar áudio      0.909     0.980     0.943       204
#                         Sintomas.Qualificado.Canal fora da grade      0.910     0.944     0.927       342
#                           Sintomas.Genérico.Problema com legenda      0.977     0.992     0.984       252
#                               Sintomas.Qualificado.Problema tudo      0.971     0.917     0.943       145
#                                    Sintomas.Qualificado.Código 9      1.000     0.889     0.941         9
#                       Sintomas.Qualificado.Imagem preto e branco      0.904     0.895     0.899        95
#                                Sintomas.Qualificado.Número da OS      0.000     0.000     0.000         2
#                      Sintomas.Genérico.Atualização de endereço G      0.973     0.961     0.967        76
#                  Sintomas.Qualificado.Habilitar recurso de senha      0.971     0.872     0.919        78
#                      Sintomas.Genérico.Canal adulto não pega (G)      0.824     0.824     0.824        34
#                    Sintomas.Genérico.Problema com troca de canal      0.667     0.526     0.588        19
#                          Sintomas.Qualificado.Cliente está longe      0.667     0.312     0.426        32
#     Sintomas.Qualificado.Procurando sinal sintonizador terrestre      0.838     1.000     0.912        31
#                       Sintomas.Qualificado.Equipamento com ruído      0.950     0.905     0.927        21
#                                   Sintomas.Qualificado.Código 13      1.000     0.957     0.978        23
#                          Sintomas.Qualificado.Travado exceto 200      0.667     0.471     0.552        17
#                 Sintomas.Qualificado.Legenda não aparece na tela      0.930     0.943     0.936        70
#                       Sintomas.Qualificado.Ativar closed caption      0.000     0.000     0.000         6
#                             Sintomas.Genérico.Promessa de oferta      0.500     0.154     0.235        13
#                        Sintomas.Qualificado.Ausência sinal geral      0.850     0.810     0.829        21
#                              Sintomas.Qualificado.Áudio atrasado      0.667     0.333     0.444         6
#                       Sintomas.Qualificado.Lentidão trocar canal      0.556     0.625     0.588         8
#                     Sintomas.Qualificado.Msg carregando conteúdo      1.000     1.000     1.000         3
#                    Sintomas.Genérico.Problema com closed caption      1.000     1.000     1.000         4
#
#                                                         accuracy                          0.967    133986
#                                                        macro avg      0.902     0.888     0.892    133986
#                                                     weighted avg      0.967     0.967     0.966    133986
