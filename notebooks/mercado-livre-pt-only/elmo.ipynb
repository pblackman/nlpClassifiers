# %% [markdown]
# #### Based on https://mlexplained.com/2019/01/30/an-in-depth-tutorial-to-allennlp-from-basics-to-elmo-and-bert/

# %%
# %load_ext autoreload
# %autoreload 2

# %%
#!pip install allennlp==0.9.0

# %%
import csv
import logging
import numpy as np
import os
import pandas as pd
import sys
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F

from allennlp.common.checks import ConfigurationError
from allennlp.data import Instance
from allennlp.data.fields import LabelField, TextField, Field, ArrayField
from allennlp.data.instance import Instance
from allennlp.data.iterators import BasicIterator, DataIterator, BucketIterator
from allennlp.data.tokenizers import Tokenizer, WordTokenizer, Token
from allennlp.data.tokenizers.word_splitter import JustSpacesWordSplitter
from allennlp.data.token_indexers import TokenIndexer, SingleIdTokenIndexer
from allennlp.data.vocabulary import Vocabulary
from allennlp.training.metrics import CategoricalAccuracy
from allennlp.common.file_utils import cached_path
from allennlp.data.dataset_readers.dataset_reader import DatasetReader
from allennlp.models import Model
from allennlp.modules.seq2vec_encoders import Seq2VecEncoder, PytorchSeq2VecWrapper
from allennlp.modules.text_field_embedders import TextFieldEmbedder, BasicTextFieldEmbedder
from allennlp.data.tokenizers.word_splitter import SpacyWordSplitter
from allennlp.data.token_indexers.elmo_indexer import ELMoCharacterMapper, ELMoTokenCharactersIndexer
from allennlp.modules.token_embedders import ElmoTokenEmbedder
from allennlp.nn import util as nn_util
from allennlp.nn.util import get_text_field_mask
from allennlp.training.trainer import Trainer
from functools import partial
from overrides import overrides
from pathlib import Path
from scipy.special import expit # the sigmoid function
from sklearn.metrics import classification_report
from tqdm import tqdm
from typing import Dict, List, Callable, Iterable
import random

# %%
logger = logging.getLogger(__name__)  # pylint: disable=invalid-name

class AgentBenchmarkDatasetReader(DatasetReader):
    def __init__(self,
                 config,
                 tokenizer: Callable[[str], List[str]]=lambda x: x.split(),
                 token_indexers: Dict[str, TokenIndexer] = None) -> None:
        super().__init__(lazy=False)
        self._tokenizer = tokenizer or WordTokenizer(JustSpacesWordSplitter())
        self._token_indexers = token_indexers or {"tokens": SingleIdTokenIndexer()}
        self._config = config

    @overrides
    def _read(self, file_path):
        logger.info("Reading instances from lines in file at: %s", file_path)
        with open(cached_path(file_path), mode="r", encoding='utf-8') as data_file:
            logger.info("Reading instances from lines in file at: %s", file_path)
            i = 0
            for line in data_file:
                i+=1
                if self._config.testing: 
                    if i == 50000:
                       break
                line = line.strip("\n")
                if not line:
                    continue
                line_data = line.split(",")
                if line_data[0] == "utterance":
                    continue
                utterance = line_data[0]
                label = line_data[1]

                if utterance == "":
                    break

                yield self.text_to_instance(
                        [Token(x) for x in self._tokenizer(utterance)], label)

    @overrides
    def text_to_instance(self,  # type: ignore
                         tokens:List[Token],
                         label: str = None) -> Instance:
        # pylint: disable=arguments-differ
        sentence_field = TextField(tokens, self._token_indexers)
        fields = { "tokens" : sentence_field}

        if label is not None:
            fields['label'] = LabelField(label, "labels")

        return Instance(fields)

# %%
ELMO_MODEL_PATH="../../models/mercado-livre-pt-only/elmo-model.th"
ELMO_VOCAB_PATH="../../models/mercado-livre-pt-only/elmo-vocabulary"

# %%
DATA_PATH = '../../data/mercado-livre-pt-only'
TRAIN_DATASET = os.path.join(DATA_PATH, 'train.csv')
VAL_DATASET = os.path.join(DATA_PATH, 'val.csv')
TEST_DATASET  = os.path.join(DATA_PATH, 'test.csv')

# %%
def seed_everything(seed=10):
    random.seed(seed)
    os.environ['PYTHONHASHSEED'] = str(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    torch.backends.cudnn.deterministic = True

# %%
seed_everything()

# %%
class Config(dict):
    def __init__(self, **kwargs):
        super().__init__(**kwargs)
        for k, v in kwargs.items():
            setattr(self, k, v)
    
    def set(self, key, val):
        self[key] = val
        setattr(self, key, val)
        
config = Config(
    lazy=False,
    testing=False,
    seed=1,
    batch_size=512,
    lr=3e-2,
    epochs=30,
    hidden_sz=300,
    max_seq_len=82, # necessary to limit memory usage
    max_vocab_size=30000,
)

# %%
USE_GPU =torch.cuda.is_available()
gpu=2

# %%
 print(torch.rand(2,3).cuda())
# Out:
# tensor([[0.4581, 0.4829, 0.3125],
#         [0.6150, 0.2139, 0.4118]], device='cuda:0')

# %%
print(torch.__version__)
# Out:
# 1.7.1

# %%
torch.manual_seed(config.seed)

# %% [markdown]
# ### Prepare token handlers

# %%
# the token indexer is responsible for mapping tokens to integers
token_indexer = ELMoTokenCharactersIndexer()

def tokenizer(x: str):
    return [w.text for w in
            SpacyWordSplitter(language='pt_core_news_sm', 
                              pos_tags=False).split_words(x)[:config.max_seq_len]]

# %%
reader = AgentBenchmarkDatasetReader(config, tokenizer=tokenizer,
    token_indexers={"tokens": token_indexer})
train_dataset = reader.read(TRAIN_DATASET)
val_dataset = reader.read(VAL_DATASET)
test_dataset = reader.read(TEST_DATASET)
# Out:
# 498780it [03:41, 2246.81it/s]
# 55420it [00:25, 2159.96it/s]
# 138550it [01:01, 2254.30it/s]

# %%
vars(train_dataset[0].fields["tokens"])
# Out:
# {'tokens': [cabo,
#   fio,
#   de,
#   aco,
#   pesca,
#   flexivel,
#   marine,
#   sports,
#   90lbs,
#   -,
#   10,
#   m],
#  '_token_indexers': {'tokens': <allennlp.data.token_indexers.elmo_indexer.ELMoTokenCharactersIndexer at 0x7fe93128e080>},
#  '_indexed_tokens': None,
#  '_indexer_name_to_indexed_token': None,
#  '_token_index_to_indexer_name': None}

# %%
vocab = Vocabulary.from_instances(train_dataset)
# Out:
# 100%|██████████| 498780/498780 [00:02<00:00, 168831.44it/s]

# %%
vars(vocab)
# Out:
# {'_padding_token': '@@PADDING@@',
#  '_oov_token': '@@UNKNOWN@@',
#  '_non_padded_namespaces': {'*labels', '*tags'},
#  '_token_to_index': _TokenToIndexDefaultDict(None,
#                           {'labels': {'CAR_SEAT_COVERS': 0,
#                             'AUTOMOTIVE_SHIFT_LEVER_KNOBS': 1,
#                             'CAR_ANTENNAS': 2,
#                             'FOOTBALL_SHIRTS': 3,
#                             'SURVEILLANCE_CAMERAS': 4,
#                             'VIDEO_GAMES': 5,
#                             'WALLPAPERS': 6,
#                             'WRISTWATCHES': 7,
#                             'SUNGLASSES': 8,
#                             'CARPETS': 9,
#                             'HANDBAGS': 10,
#                             'DOLLS': 11,
#                             'BOOKS': 12,
#                             'LIGHT_BULBS': 13,
#                             'RAM_MEMORY_MODULES': 14,
#                             'JACKETS_AND_COATS': 15,
#                             'MOBILE_DEVICE_CHARGERS': 16,
#                             'ACTION_FIGURES': 17,
#                             'PANTS': 18,
#                             'COMPUTER_PROCESSORS': 19,
#                             'AUTOMOTIVE_WEATHERSTRIPS': 20,
#                             'ELECTRIC_GUITARS': 21,
#                             'DIGITAL_VOICE_RECORDERS': 22,
#                             'ENGINE_OILS': 23,
#                             'MUSICAL_KEYBOARD_CASES_AND_BAGS': 24,
#                             'T_SHIRTS': 25,
#                             'FISHING_REELS': 26,
#                             'EYESHADOWS': 27,
#                             'AUTOMOTIVE_SIDE_VIEW_MIRRORS': 28,
#                             'FOOTBALL_SHOES': 29,
#                             'TELEVISIONS': 30,
#                             'SPARK_PLUGS': 31,
#                             'SMARTWATCHES': 32,
#                             'AUTOMOTIVE_MOLDINGS': 33,
#                             'CAR_WHEELS': 34,
#                             'AUTOMOTIVE_CLUTCH_KITS': 35,
#                             'MOTORCYCLE_HELMETS': 36,
#                             'HAIR_CLIPPERS': 37,
#                             'DECORATIVE_VINYLS': 38,
#                             'FOUNDATIONS': 39,
#                             'PUREBRED_DOGS': 40,
#                             'COMPUTER_MONITORS': 41,
#                             'BACKPACKS': 42,
#                             'PEDAL_EFFECTS': 43,
#                             'DRESSES': 44,
#                             'DESKTOP_COMPUTER_POWER_SUPPLIES': 45,
#                             'STUFFED_TOYS': 46,
#                             'CELL_BATTERIES': 47,
#                             'MEMORY_CARDS': 48,
#                             'WALLETS': 49,
#                             'AUTOMOTIVE_AMPLIFIERS': 50,
#                             'BOARD_GAMES': 51,
#                             'DRONES': 52,
#                             'TABLETS': 53,
#                             'GAMEPADS_AND_JOYSTICKS': 54,
#                             'DIECAST_VEHICLES': 55,
#                             'FLASHLIGHTS': 56,
#                             'FANS': 57,
#                             'STOOLS': 58,
#                             'CAR_AV_RECEIVERS': 59,
#                             'ROLLER_SKATES': 60,
#                             'FISHING_LINES': 61,
#                             'SUITCASES': 62,
#                             'SUSPENSION_BALL_JOINTS': 63,
#                             'COFFEE_MAKERS': 64,
#                             'LIPSTICKS': 65,
#                             'CAMERA_BATTERIES': 66,
#                             'MOTORCYCLE_JACKETS': 67,
#                             'BABY_CAR_SEATS': 68,
#                             'WHEELS_BEARINGS': 69,
#                             'TV_AND_MONITOR_MOUNTS': 70,
#                             'TABLECLOTHS': 71,
#                             'NOTEBOOKS': 72,
#                             'PARKING_SENSORS': 73,
#                             'AUTOMOTIVE_SIDE_VIEW_MIRROR_GLASSES': 74,
#                             'CALCULATORS': 75,
#                             'MAKEUP_BRUSHES': 76,
#                             'MATTRESSES': 77,
#                             'COMICS': 78,
#                             'VEHICLE_STICKERS': 79,
#                             'REFRIGERATORS': 80,
#                             'SPEAKERS': 81,
#                             'AUTOMOTIVE_EMBLEMS': 82,
#                             'BATHROOM_FAUCETS': 83,
#                             'MUSICAL_KEYBOARDS': 84,
#                             'WOMEN_SWIMWEAR': 85,
#                             'PORTABLE_CELLPHONE_CHARGERS': 86,
#                             'ARTIFICIAL_FLOWERS': 87,
#                             'OUTER_TIE_ROD_ENDS': 88,
#                             'KITCHEN_POTS': 89,
#                             'WALL_CLOCKS': 90,
#                             'HOVERBOARDS': 91,
#                             'SPORT_WATCHES': 92,
#                             'CEILING_LIGHTS': 93,
#                             'BABY_STROLLERS': 94,
#                             'BASS_GUITARS': 95,
#                             'MICROPHONES': 96,
#                             'FLOOD_LIGHTS': 97,
#                             'ANALOG_CAMERAS': 98,
#                             'DEEP_FRYERS': 99,
#                             'BLENDERS': 100,
#                             'RANGES': 101,
#                             'DVD_RECORDERS': 102,
#                             'SHAVING_MACHINES': 103,
#                             'INSTRUMENT_AMPLIFIERS': 104,
#                             'FREEZERS': 105,
#                             'CV_JOINTS': 106,
#                             'SCULPTURES': 107,
#                             'IRONS': 108,
#                             'KITCHEN_FAUCETS': 109,
#                             'SUPPLEMENTS': 110,
#                             'ROOF_RACKS': 111,
#                             'BATHROOM_SINKS': 112,
#                             'CAMERA_TRIPODS': 113,
#                             'MALE_UNDERWEAR': 114,
#                             'VEHICLE_SPEAKERS': 115,
#                             'STREAMING_MEDIA_DEVICES': 116,
#                             'ENGINE_CONTROL_MODULES': 117,
#                             'ELECTRIC_DRILLS': 118,
#                             'COOKING_SCALES': 119,
#                             'HOME_APPLIANCE_CONTACTORS_AND_RELAYS': 120,
#                             'REAR_WHEEL_HUBS_BEARING_ASSEMBLY': 121,
#                             'PRINTERS': 122,
#                             'WATER_RADIATORS': 123,
#                             'AUTOMOTIVE_WATER_PUMPS': 124,
#                             'AM_FM_RADIOS': 125,
#                             'SOLDERING_MACHINES': 126,
#                             'DRINKING_GLASSES': 127,
#                             'BODY_SKIN_CARE_PRODUCTS': 128,
#                             'FABRICS': 129,
#                             'BABY_DIAPERS': 130,
#                             'ENGINE_INTAKE_HOSES': 131,
#                             'WRENCHES': 132,
#                             'CAR_POWER_STEERING_PUMPS': 133,
#                             'ELECTRIC_SAWS': 134,
#                             'STARTERS': 135,
#                             'SERVING_AND_HOME_TRAYS': 136,
#                             'MOTORCYCLE_FAIRINGS': 137,
#                             'AIR_COMPRESSORS': 138,
#                             'VR_HEADSETS': 139,
#                             'MIXERS': 140,
#                             'VEHICLE_BRAKE_PADS': 141,
#                             'GAME_CONSOLES': 142,
#                             'BRACELETS_AND_ANKLE_BRACES': 143,
#                             'DESKTOP_COMPUTER_COOLERS_AND_FANS': 144,
#                             'ELECTRIC_PRESSURE_WASHERS': 145,
#                             'FACIAL_SKIN_CARE_PRODUCTS': 146,
#                             'AUTOMOTIVE_DOORS': 147,
#                             'CELLPHONES': 148,
#                             'MUGS': 149,
#                             'ENGINE_BEARINGS': 150,
#                             'PLANTS': 151,
#                             'AUDIO_AMPLIFIERS': 152,
#                             'ACCORDIONS': 153,
#                             'TV_ANTENNAS': 154,
#                             'KITCHEN_RANGE_HOODS': 155,
#                             'AUDIO_INTERFACES': 156,
#                             'GATE_MOTORS': 157,
#                             'GLASSES_FRAMES': 158,
#                             'ALARMS_AND_SENSORS': 159,
#                             'BODYWEIGHT_SCALES': 160,
#                             'FOG_LIGHTS': 161,
#                             'SANDER_MACHINES': 162,
#                             'SEWING_MACHINES': 163,
#                             'CD_AND_DVD_PLAYERS': 164,
#                             'EMERGENCY_LIGHTS': 165,
#                             'CAMERA_CHARGERS': 166,
#                             'WALKIE_TALKIES': 167,
#                             'EROTIC_CREAMS': 168,
#                             'TV_SMPS': 169,
#                             'KITCHEN_TOWELS': 170,
#                             'COSTUMES': 171,
#                             'KEYBOARD_AND_MOUSE_KITS': 172,
#                             'DECORATIVE_VASES': 173,
#                             'SHORTS': 174,
#                             'TURNTABLES': 175,
#                             'OPERATING_SYSTEMS': 176,
#                             'CAR_GEARBOXES': 177,
#                             'WHISKEYS': 178,
#                             'TOOTHBRUSHES': 179,
#                             'WATCH_BANDS': 180,
#                             'TABLE_AND_DESK_LAMPS': 181,
#                             'AUTOMOTIVE_SUSPENSION_CONTROL_ARMS': 182,
#                             'BAR_CODE_SCANNERS': 183,
#                             'MARTIAL_ARTS_AND_BOXING_GLOVES': 184,
#                             'ADHESIVE_TAPES': 185,
#                             'KITCHEN_SINKS': 186,
#                             'ELECTRICAL_CABLES': 187,
#                             'TOY_BUILDING_SETS': 188,
#                             'TOILET_RUGS': 189,
#                             'WATER_HEATERS': 190,
#                             'INTERACTIVE_GAMING_FIGURES': 191,
#                             'AIRSOFT_GUNS': 192,
#                             'BUMPER_IMPACT_ABSORBERS': 193,
#                             'CABIN_FILTERS': 194,
#                             'CAR_STEREOS': 195,
#                             'CRIBS': 196,
#                             'MOTORCYCLE_CLUTCH_COVERS': 197,
#                             'SHOWER_HEADS': 198,
#                             'HOME_HEATERS': 199,
#                             'ULTRABOOKS': 200,
#                             'SPORT_AND_BAZAAR_BOTTLES': 201,
#                             'HEADBOARDS': 202,
#                             'WATER_DISPENSERS': 203,
#                             'MOTORCYCLE_CASES': 204,
#                             'MOTORCYCLE_TURN_SIGNAL_LIGHTS': 205,
#                             'BABY_MONITORS': 206,
#                             'ANTI_THEFT_STUDS': 207,
#                             'CAMERA_LENSES': 208,
#                             'HABERDASHERY_RIBBONS': 209,
#                             'LED_STAGE_LIGHTS': 210,
#                             'AQUARIUM_FILTERS': 211,
#                             'CUSHIONS': 212,
#                             'DRUMS': 213,
#                             'ELECTRONIC_ENTRANCE_INTERCOMS': 214,
#                             'REMOTE_CONTROL_TOY_VEHICLES': 215,
#                             'POSTERS': 216,
#                             'CAR_DISTRIBUTOR_CAPS': 217,
#                             'KITCHEN_KNIVES': 218,
#                             'DJ_EFFECTS_PROCESSORS': 219,
#                             'MOUSE_PADS': 220,
#                             'SIDEBOARDS': 221,
#                             'DRAWERS': 222,
#                             'TOILET_SEATS': 223,
#                             'WINDSHIELD_WIPERS': 224,
#                             'LIP_GLOSSES': 225,
#                             'GRAPHICS_TABLETS': 226,
#                             'NETWORK_CABLES': 227,
#                             'ALL_IN_ONE': 228,
#                             'HEADPHONES': 229,
#                             'AV_RECEIVERS': 230,
#                             'DISPOSABLE_CUPS': 231,
#                             'BINOCULARS': 232,
#                             'TRAILER_HITCHES': 233,
#                             'BICYCLES': 234,
#                             'PENCIL_CASES': 235,
#                             'WINES': 236,
#                             'RESISTANCE_BANDS': 237,
#                             'BLANK_DISCS': 238,
#                             'DJ_CONTROLLERS': 239,
#                             'BLU_RAY_PLAYERS': 240,
#                             'HUMIDIFIERS_AND_VAPORIZERS': 241,
#                             'WALL_LIGHTS': 242,
#                             'OVENS': 243,
#                             'BEERS': 244,
#                             'HOOKAHS': 245,
#                             'FACE_MASKS': 246,
#                             'TACTICAL_AND_SPORTING_KNIVES_AND_BLADES': 247,
#                             'CYCLING_COMPUTERS': 248,
#                             'INDOOR_CURTAINS_AND_BLINDS': 249,
#                             'CATS_AND_DOGS_FOODS': 250,
#                             'HAIRDRESSING_SCISSORS': 251,
#                             'HOME_SHELVES': 252,
#                             'CACHACAS': 253,
#                             'SCREEN_PRINTERS': 254,
#                             'FOOTBALL_BALLS': 255,
#                             'CELLPHONE_TABLET_AND_GPS_SCREEN_PROTECTORS': 256,
#                             'SKIRTS': 257,
#                             'AIR_MATTRESSES': 258,
#                             'NOTEBOOKS_AND_WRITING_PADS': 259,
#                             'SOUVENIRS': 260,
#                             'PICTURE_FRAMES': 261,
#                             'MOTORCYCLE_GLOVES': 262,
#                             'VIOLINS': 263,
#                             'AUTOMOTIVE_DOOR_PANELS': 264,
#                             'HOME_OFFICE_DESKS': 265,
#                             'DISHWASHERS': 266,
#                             'CIRCUIT_BREAKERS': 267,
#                             'FURNITURE_KNOBS': 268,
#                             'LUMBAR_AND_ABDOMINAL_BRACES': 269,
#                             'MOTORCYCLE_TIRES': 270,
#                             'LATHES': 271,
#                             'NETBOOKS': 272,
#                             'FISH_TANKS': 273,
#                             'STEERING_COLUMNS': 274,
#                             'MAGAZINES': 275,
#                             'DRILL_BITS': 276,
#                             'YARNS': 277,
#                             'CONTINUOUS_INK_SYSTEMS': 278,
#                             'PENDRIVES': 279,
#                             'ABS_SENSORS': 280,
#                             'BRAKE_BOOSTERS': 281,
#                             'SUSPENSION_CONTROL_ARM_BUSHINGS': 282,
#                             'AUTOMOTIVE_POWER_WINDOW_REGULATORS': 283,
#                             'PORTABLE_EVAPORATIVE_AIR_COOLERS': 284,
#                             'FOOD_PROCESSORS': 285,
#                             'NECKTIES': 286,
#                             'PORTABLE_GENERATORS': 287,
#                             'ENGINE_PISTONS': 288,
#                             'BLANKETS': 289,
#                             'NAIL_DRYERS': 290,
#                             'AUTOMOTIVE_HEADLIGHTS': 291,
#                             'KNEE_BRACES_SUPPORTS': 292,
#                             'FLEA_AND_TICK_TREATMENTS': 293,
#                             'AUTOMOTIVE_WHEEL_COVERS': 294,
#                             'FLUTES': 295,
#                             'ELLIPTICAL_MACHINES': 296,
#                             'CRIB_BEDDING_SETS': 297,
#                             'MARKERS_AND_HIGHLIGHTERS': 298,
#                             'AUTOMOTIVE_FENDERS': 299,
#                             'MODEMS': 300,
#                             'TORSION_BARS': 301,
#                             'MAGNIFYING_GLASSES': 302,
#                             'ELECTRIC_SCREWDRIVERS': 303,
#                             'ELECTRICAL_OUTLETS': 304,
#                             'BABY_SWIMWEAR': 305,
#                             'AUTOMOTIVE_SPRING_SUSPENSIONS': 306,
#                             'COMPUTER_AND_TV_FLEX_CABLES': 307,
#                             'AUTOMOTIVE_TRUNK_LIDS': 308,
#                             'MOTORCYCLE_PANTS': 309,
#                             'SWEATSHIRTS_AND_HOODIES': 310,
#                             'ELECTRONIC_DRUMS': 311,
#                             'SHIRTS': 312,
#                             'VIBRATORS': 313,
#                             'TV_REPLACEMENT_BACKLIGHT_LED_STRIPS': 314,
#                             'RACKS_AND_PINIONS': 315,
#                             'HANDICRAFT_BOXES': 316,
#                             'BRUSH_CUTTERS': 317,
#                             'BABY_PLAYARDS': 318,
#                             'TOOL_BOXES': 319,
#                             'HABERDASHERY_LACE_EDGINGS': 320,
#                             'ENGINE_CRANKSHAFT_PULLEYS': 321,
#                             'GUITAR_STRINGS': 322,
#                             'PARTY_DECORATIVE_BACKDROPS': 323,
#                             'JUMPSUITS_AND_OVERALLS': 324,
#                             'BOOTS': 325,
#                             'DIAPER_BAGS': 326,
#                             'FUEL_INJECTORS': 327,
#                             'HORSE_SADDLES': 328,
#                             'CRAYONS': 329,
#                             'THERMOSES': 330,
#                             'LIQUORS': 331,
#                             'SUBMERSIBLE_PUMPS': 332,
#                             'BABY_BOTTLES': 333,
#                             'KITCHEN_PLAYSETS': 334,
#                             'SOFAS': 335,
#                             'CAR_AIR_FRESHENERS': 336,
#                             'SOFA_AND_FUTON_COVERS': 337,
#                             'OFFICE_CHAIRS': 338,
#                             'SWAY_BARS': 339,
#                             'PAINTBALL_MARKERS': 340,
#                             'DOORS': 341,
#                             'VESTS': 342,
#                             'CAR_AC_CONDENSERS': 343,
#                             'BABIES_FOOTWEAR': 344,
#                             'VODKAS': 345,
#                             'EPILATORS': 346,
#                             'HEAT_GUNS': 347,
#                             'PERMANENT_EPILATORS': 348,
#                             'TOY_TRAINS': 349,
#                             'CLEANING_CLOTHS': 350,
#                             'CAMERAS': 351,
#                             'MASCARAS': 352,
#                             'CLOTHES_HANGERS': 353,
#                             'GAZEBOS': 354,
#                             'NECKLACES': 355,
#                             'WHEELCHAIRS': 356,
#                             'CELLPHONE_AND_TABLET_CASES': 357,
#                             'ROUTERS': 358,
#                             'SWAY_BAR_LINKS': 359,
#                             'EROTIC_PUMPS': 360,
#                             'LIQUID_HAND_AND_BODY_SOAPS': 361,
#                             'HAIR_TREATMENTS': 362,
#                             'BABIES_FORMULA': 363,
#                             'SOCKS': 364,
#                             'CONCEALERS': 365,
#                             'BABY_HIGH_CHAIRS': 366,
#                             'CHARMS_AND_MEDALS': 367,
#                             'MIRRORS': 368,
#                             'PAINTBALLS': 369,
#                             'POWERED_RIDE_ON_TOYS': 370,
#                             'ANIMAL_CLIPPERS': 371,
#                             'MOTORCYCLE_BATTERIES': 372,
#                             'COMBUSTION_CHAINSAWS': 373,
#                             'KEYCHAINS': 374,
#                             'SEWING_THREADS': 375,
#                             'PORTABLE_ELECTRIC_MASSAGERS': 376,
#                             'HAND_AND_FOOT_CREAMS': 377,
#                             'ENGINE_COOLING_FAN_SHROUDS': 378,
#                             'OFFICE_SOFTWARE': 379,
#                             'HAMMOCKS': 380,
#                             'SLATWALL_PANELS': 381,
#                             'DJ_TURNTABLES': 382,
#                             'AUTOMOTIVE_TIRES': 383,
#                             'DATA_CABLES_AND_ADAPTERS': 384,
#                             'TELEVISION_MAIN_PLATE_REPLACEMENTS': 385,
#                             'BATHROOM_ACCESSORIES_SETS': 386,
#                             'SWIMMING_GOGGLES': 387,
#                             'COOKIES_CUTTERS': 388,
#                             'MULTIGAME_MACHINES': 389,
#                             'ORTHOPEDIC_WRIST_BRACES': 390,
#                             'BABY_CLOTHING_SETS': 391,
#                             'IDLER_ARMS': 392,
#                             'CUSHION_COVERS': 393,
#                             'BED_SHEETS': 394,
#                             'LENS_FILTERS': 395,
#                             'PUZZLES': 396,
#                             'DISC_PACKAGINGS': 397,
#                             'MOTORCYCLE_JERSEYS': 398,
#                             'STATIONARY_BICYCLES': 399,
#                             'SHOCK_MOUNT_INSOLATORS': 400,
#                             'INDUSTRIAL_AND_COMMERCIAL_SCALES': 401,
#                             'SNEAKERS': 402,
#                             'INTEGRATED_CIRCUITS': 403,
#                             'MOVIES': 404,
#                             'CRASHED_CARS': 405,
#                             'PARTY_MASKS': 406,
#                             'VINYL_ROLLS': 407,
#                             'VEHICLE_CV_AXLES': 408,
#                             'VIDEO_GAME_PREPAID_CARDS': 409,
#                             'MICRO_ROTARY_TOOLS': 410,
#                             'ENGINE_VALVES_SPRING_RETAINERS': 411,
#                             'LAPTOP_CHARGERS': 412,
#                             'UMBRELLAS': 413,
#                             'EROTIC_BOOKS': 414,
#                             'GYM_GLOVES': 415,
#                             'FISHING_LURES': 416,
#                             'TABLE_RUNNERS': 417,
#                             'LATEX_ENAMEL_AND_ACRYLIC_PAINTS': 418,
#                             'SAFETY_FOOTWEAR': 419,
#                             'AUTOMOTIVE_SHOCK_ABSORBERS': 420,
#                             'TREADMILLS': 421,
#                             'HATS_AND_CAPS': 422,
#                             'ESSENTIAL_OILS': 423,
#                             'ENGINE_CYLINDER_HEAD_BOLTS': 424,
#                             'UPS_BATTERIES': 425,
#                             'WELDING_MASKS': 426,
#                             'FUEL_INJECTION_RAILS': 427,
#                             'THERMOMETERS': 428,
#                             'TOOTHPASTES': 429,
#                             'PARKING_BRAKE_HANDLES': 430,
#                             'PUZZLE_CUBES': 431,
#                             'STRING_TRIMMERS': 432,
#                             'BAR_SOAPS': 433,
#                             'DISHES_PLATES': 434,
#                             'CLOTHING_PATCHES': 435,
#                             'DOG_CARRIERS_AND_CARRYING_BAGS': 436,
#                             'SCREWS': 437,
#                             'PAJAMAS': 438,
#                             'LONGBOARDS': 439,
#                             'GARDEN_HOSES': 440,
#                             'INDUSTRIAL_BLENDERS': 441,
#                             'THERMAL_CUPS_AND_TUMBLERS': 442,
#                             'GLOW_PLUG_CONTROLLERS': 443,
#                             'AUTOMOTIVE_AIR_FILTERS': 444,
#                             'LASER_MEASURES': 445,
#                             'CELLPHONE_COVERS': 446,
#                             'AUTOMOTIVE_ARMRESTS': 447,
#                             'MICROMETERS': 448,
#                             'PROJECTOR_SCREENS': 449,
#                             'TRANSISTORS': 450,
#                             'TV_STORAGE_UNITS': 451,
#                             'PERFUMES': 452,
#                             'LAPTOP_LCD_SCREENS': 453,
#                             'DINING_SETS': 454,
#                             'UKULELES': 455,
#                             'RICE_COOKERS': 456,
#                             'EMBROIDERY_MACHINES': 457,
#                             'MOTORCYCLE_RAIN_SUITS': 458,
#                             'CELLPHONE_REPLACEMENT_CAMERAS': 459,
#                             'PAPER_CLIPS': 460,
#                             'ENGINE_INTAKE_MANIFOLDS': 461,
#                             'EYELINERS': 462,
#                             'AUTOMOTIVE_THROTTLE_BODIES': 463,
#                             'BODY_SHAPERS': 464,
#                             'WASHING_AND_DRYER_MACHINE_COVERS': 465,
#                             'CAMERA_MONOPODS': 466,
#                             'NEBULIZERS': 467,
#                             'SELF_ADHESIVE_LABELS': 468,
#                             'BELTS': 469,
#                             'PANTIES': 470,
#                             'DISHES_RACKS': 471,
#                             'SAFES': 472,
#                             'TABLE_DRILLS': 473,
#                             'CARDS_AND_INVITATIONS': 474,
#                             '3D_PRINTERS': 475,
#                             'ALTERNATORS': 476,
#                             'LUGGAGE_TAGS': 477,
#                             'BIRD_TOYS': 478,
#                             'CAKE_STANDS': 479,
#                             'SANDALS_AND_FLIP_FLOPS': 480,
#                             'TRADING_CARD_GAMES': 481,
#                             'HAIR_SHAMPOOS_AND_CONDITIONERS': 482,
#                             'UNIVERSAL_HOME_GYMS': 483,
#                             'PADLOCKS': 484,
#                             'EARRINGS': 485,
#                             'ENGINE_VALVES': 486,
#                             'FRAME_POOLS': 487,
#                             'DECORATIVE_BASKETS': 488,
#                             'RINGS': 489,
#                             'STICKY_NOTES': 490,
#                             'AUTOMOTIVE_AC_COMPRESSORS': 491,
#                             'AUTOMOTIVE_OIL_FILTERS': 492,
#                             'BEDS': 493,
#                             'AIR_FRESHENERS': 494,
#                             'AIRBAGS': 495,
#                             'HARD_DRIVES_AND_SSDS': 496,
#                             'EROTIC_BALLS': 497,
#                             'STYLUSES': 498,
#                             'COMPUTER_MOTHERBOARDS': 499,
#                             'CURLING_IRONS': 500,
#                             'BABY_SAFETY_LOCKS': 501,
#                             'IRRIGATION_VALVES': 502,
#                             'TOILETRY_BAGS': 503,
#                             'BARBECUE_TOOL_SETS': 504,
#                             'MANGA': 505,
#                             'JUMP_ROPES': 506,
#                             'HOSPITAL_BEDS': 507,
#                             'AUTOMOTIVE_NERF_BARS': 508,
#                             'HEARING_PROTECTORS': 509,
#                             'GAS_LIFT_SUPPORTS': 510,
#                             'CASH_DRAWERS': 511,
#                             'KITCHEN_FURNITURE': 512,
#                             'WORKOUT_BENCHES': 513,
#                             'CELLPHONE_BATTERIES': 514,
#                             'STIMULATING_PILLS_AND_CAPSULES': 515,
#                             'EROTIC_MALE_UNDERWEAR': 516,
#                             'ELECTRONIC_MUSCLE_STIMULATORS': 517,
#                             'BLOUSES': 518,
#                             'POOL_INFLATABLES': 519,
#                             'EXTERNAL_LAPTOP_COOLERS': 520,
#                             'VIDEO_CAMERAS': 521,
#                             'AUTOMOTIVE_SHOCK_ABSORBER_BUMP_STOPS': 522,
#                             'VASES': 523,
#                             'CHRISTMAS_TREES': 524,
#                             'SIDE_TABLES': 525,
#                             'MOTORCYCLE_SUITS': 526,
#                             'DESKTOP_COMPUTERS': 527,
#                             'WARDROBES': 528,
#                             'GARDENING_AND_AGRICULTURE_SEEDS': 529,
#                             'DINING_CHAIRS': 530,
#                             'STETHOSCOPES': 531,
#                             'CONTINUOUS_LIGHTING': 532,
#                             'ENGINE_TAPPET_GUIDE_HOLDS': 533,
#                             'DIFFERENTIALS': 534,
#                             'BOOKCASES': 535,
#                             'BUTT_PLUGS': 536,
#                             'DENTAL_PLIERS': 537,
#                             'TEQUILAS': 538,
#                             'SAXOPHONES': 539,
#                             'SUITS': 540,
#                             'PUSH_AND_RIDING_TOYS': 541,
#                             'COMMERCIAL_LIGHT_SIGNS': 542,
#                             'POWER_STEERING_FLUID_RESERVOIRS': 543,
#                             'LAPTOP_BATTERIES': 544,
#                             'HAND_FANS': 545,
#                             'GRAPHICS_CARDS': 546,
#                             'VIDEO_CAPTURE_DEVICES': 547,
#                             'CHAMPAGNES': 548,
#                             'MUSIC_STANDS': 549,
#                             'FOOD_CARTS': 550,
#                             'SEX_TOY_KITS': 551,
#                             'SPARK_PLUG_WIRESETS': 552,
#                             'SUNSCREENS': 553,
#                             'CAR_WINDOW_SWITCHES': 554,
#                             'DECORATIVE_BOXES': 555,
#                             'NETWORK_CARDS': 556,
#                             'BATTERY_CHARGERS': 557,
#                             'FLATWARE_SETS': 558,
#                             'PILLOWS': 559,
#                             'PLAYING_CARDS': 560,
#                             'PLACEMATS': 561,
#                             'BLOOD_PRESSURE_MONITORS': 562,
#                             'INK_CARTRIDGES': 563,
#                             'LEGGINGS': 564,
#                             'FIRE_EXTINGUISHERS': 565,
#                             'CLUTCH_SLAVE_CYLINDERS': 566,
#                             'VOLTAGE_DETECTORS': 567,
#                             'COLLECTIBLE_CANS_BOTTLES_AND_SODA_SIPHONS': 568,
#                             'NIGHTSTANDS': 569,
#                             'MOTORCYCLE_IGNITION_COILS': 570,
#                             'LASER_PRINTER_DRUMS': 571,
#                             'HEEL_CUPS': 572,
#                             'BABY_BLANKETS': 573,
#                             'FOOTBALL_JACKETS': 574,
#                             'SPORTS_CONES': 575,
#                             'IP_TELEPHONES': 576,
#                             'FOLDERS_AND_EXPANDING_FILES': 577,
#                             'HAND_BRAKE_CABLES': 578,
#                             'THERMAL_REFRIGERATORS_AND_BAGS': 579,
#                             'MIRROR_BALLS': 580,
#                             'SPICE_RACKS': 581,
#                             'LAPTOP_KEYBOARDS': 582,
#                             'KITCHEN_APRONS': 583,
#                             'PENS': 584,
#                             'BABY_BODYSUITS': 585,
#                             'ARTIFICIAL_PLANTS': 586,
#                             'CONDOMS': 587,
#                             'PACKAGING_ROLLS': 588,
#                             'COIN_PURSES': 589,
#                             'TOILETS': 590,
#                             'BATHROOM_GRAB_BARS': 591,
#                             'PC_KEYBOARDS': 592,
#                             'SOLDERING_STATIONS': 593,
#                             'HAIR_STRAIGHTENING_BRUSHES': 594,
#                             'COFFEE_TABLES': 595,
#                             'TOILET_PAPER_HOLDERS': 596,
#                             'AUTOMOTIVE_MANUAL_TRANSMISSION_SHIFT_LEVERS': 597,
#                             'DRILLS_SCREWDRIVERS': 598,
#                             'ELECTRIC_BATHROOM_FAUCETS': 599,
#                             'DRUM_PEDALS': 600,
#                             'GIFT_CARDS': 601,
#                             'NON_CORRECTIVE_CONTACT_LENSES': 602,
#                             'BEER_DISPENSERS': 603,
#                             'FINGERPRINT_READERS': 604,
#                             'INTERCOOLER_HOSES': 605,
#                             'DRIVE_SHAFTS': 606,
#                             'STATUES': 607,
#                             'SIM_CARDS': 608,
#                             'WORLD_GLOBES': 609,
#                             'LABEL_MAKERS': 610,
#                             'PREAMPLIFIERS': 611,
#                             'SECURITY_SEALS': 612,
#                             'CHALKBOARD_AND_WHITEBOARD_ERASERS': 613,
#                             'AIR_CONDITIONERS': 614,
#                             'KIDS_TABLES_AND_CHAIRS_SETS': 615,
#                             'WINDOWS': 616,
#                             'PERSONAL_LUBRICANTS_AND_GELS': 617,
#                             'POOL_COVERS': 618,
#                             'CUT_OFF_AND_GRINDING_WHEELS': 619,
#                             'KITCHEN_BOWLS': 620,
#                             'LUNCHBOXES': 621,
#                             'LIFE_JACKETS': 622,
#                             'CALIPERS': 623,
#                             'FOOD_SLICERS': 624,
#                             'BABY_STERILIZERS': 625,
#                             'BEAUTY_WIGS': 626,
#                             'SWIMMING_POOL_HEATERS': 627,
#                             'SANDPAPERS': 628,
#                             'MOTORCYCLE_FENDERS': 629,
#                             'HEATER_CORES': 630,
#                             'ELECTRIC_GRILLS': 631,
#                             'VEHICLE_BRAKE_DISCS': 632,
#                             'EGR_VALVES': 633,
#                             'FOOTBALL_CAPS': 634,
#                             'TELEPHONES': 635,
#                             'MOTORCYCLE_CRASH_BARS': 636,
#                             'ENGINE_CRANKSHAFT_POSITION_SENSORS': 637,
#                             'FISHING_VESTS': 638,
#                             'DRINK_PITCHERS': 639,
#                             'CRANKSHAFTS': 640,
#                             'COMFORTERS': 641,
#                             'XENON_KITS': 642,
#                             'WATER_PURIFIERS_FILTERS': 643,
#                             'INSTANT_COFFEE': 644,
#                             'SAFETY_GOGGLES': 645,
#                             'MDF_BOARDS': 646,
#                             'INDUSTRIAL_ICE_CREAM_MACHINES': 647,
#                             'WETSUITS': 648,
#                             'VEHICLE_LED_BULBS': 649,
#                             'SOLAR_PANELS': 650,
#                             'FISHING_RODS': 651,
#                             'VACUUM_TUBES': 652,
#                             'MEN_SWIMWEAR': 653,
#                             'STEAM_CLEANERS': 654,
#                             'TV_RECEIVERS_AND_DECODERS': 655,
#                             'CELLPHONE_REPAIR_TOOL_KITS': 656,
#                             'CATS': 657,
#                             'LOAFERS_AND_OXFORDS': 658,
#                             'FABRIC_SOFTENERS': 659,
#                             'MOTORCYCLE_DISTRIBUTION_CHAINS': 660,
#                             'AUTOMOBILE_FENDER_LINERS': 661,
#                             'ELECTRIC_DEMOLITION_HAMMERS': 662,
#                             'HAIR_STRAIGHTENERS': 663,
#                             'BABY_BOUNCERS': 664,
#                             'VIBRATION_PLATFORMS': 665,
#                             'BILLIARD_TABLES': 666,
#                             'ENGINE_GASKET_SETS': 667,
#                             'TOY_GARAGES_AND_GAS_STATIONS': 668,
#                             'BRAKE_LIGHTS': 669,
#                             'CARD_PAYMENT_TERMINALS': 670,
#                             'NOTEBOOK_CASES': 671,
#                             'VARNISHES': 672,
#                             'MAP_SENSORS': 673,
#                             'CAR_AC_HOSE_ASSEMBLIES': 674,
#                             'HAND_FILES': 675,
#                             'GUITAR_PICKS': 676,
#                             'WASTE_BASKETS': 677,
#                             'BEDROOM_SETS': 678,
#                             'ALTERNATOR_PULLEYS': 679,
#                             'BAR_CLAMPS': 680,
#                             'ORTHOTICS': 681,
#                             'EROTIC_MAGAZINES': 682,
#                             'ANTIVIRUS_AND_INTERNET_SECURITY': 683,
#                             'HONEY': 684,
#                             'EMBROIDERY_DESIGNS': 685,
#                             'POOL_LIGHTS': 686,
#                             'BEDLINERS': 687,
#                             'VACUUM_CLEANERS': 688,
#                             'MARKING_AND_WARNING_TAPES': 689,
#                             'DINING_TABLES': 690,
#                             'FOOTBALL_GOALKEEPER_GLOVES': 691,
#                             'ORTHOPEDIC_ANKLE_BRACES': 692,
#                             'CAMERA_BATTERY_GRIPS': 693,
#                             'CAR_ENGINE_CAMSHAFTS': 694,
#                             'FLOUR': 695,
#                             'SCALEXTRIC_CARS': 696,
#                             'CAT_SCRATCHERS': 697,
#                             'BASKETBALL_JERSEYS': 698,
#                             'MALE_MASTURBATORS': 699,
#                             'PILATES_BALLS': 700,
#                             'EQUALIZERS': 701,
#                             'TOY_ROBOTS': 702,
#                             'IGNITION_SWITCH_ACTUATORS': 703,
#                             'HAIR_DRYERS': 704,
#                             'JEWELRY_DISPLAYS': 705,
#                             'BABY_PACIFIERS': 706,
#                             'CATS_AND_DOGS_TREATS': 707,
#                             'TELEPHONE_CABLES': 708,
#                             'MINI_PCS': 709,
#                             'SCREEN_PRINTING_MACHINES': 710,
#                             'HEDGE_TRIMMERS': 711,
#                             'ORTHOPEDIC_WALKER_BOOTS': 712,
#                             'PET_COLLARS': 713,
#                             'CAR_LIGHT_BULBS': 714,
#                             'GARDEN_BENCHES': 715,
#                             'ENGINE_COOLING_FAN_MOTORS': 716,
#                             'RUBBER_FLOORS': 717,
#                             'TACTICAL_VESTS': 718,
#                             'MICROWAVES': 719,
#                             'DISTRIBUTION_KITS': 720,
#                             'LIVING_ROOM_SETS': 721,
#                             'HAND_POLISHERS': 722,
#                             'INDUSTRIAL_DOUGH_KNEADERS': 723,
#                             'BABY_WALKERS': 724,
#                             'BICYCLE_FRAMES': 725,
#                             'POWER_GRINDERS': 726,
#                             'KATANA_SWORDS': 727,
#                             'PIPES_AND_TUBES': 728,
#                             'NETWORK_SWITCHES': 729,
#                             'CERAMIC_TILES': 730,
#                             'TREADMILL_RUNNING_BELTS': 731,
#                             'PLAYGROUND_SLIDES': 732,
#                             'AUTOMOTIVE_MIRROR_COVERS': 733,
#                             'CAR_DOOR_HINGES': 734,
#                             'BRAKE_MASTER_CYLINDERS': 735,
#                             'POOL_WATERFALLS': 736,
#                             'PNEUMATIC_STAPLERS': 737,
#                             'WASHING_MACHINES': 738,
#                             'PENCILS': 739,
#                             'POOL_PUMPS': 740,
#                             'WASTE_CONTAINERS': 741,
#                             'SOAP_HOLDERS': 742,
#                             'SHADE_CLOTHS': 743,
#                             'CATS_LITTER': 744,
#                             'SPARKLING_WINES': 745,
#                             'RADIO_FREQUENCY_MICROPHONES': 746,
#                             'KIDS_WALKIE_TALKIES': 747,
#                             'WINE_CELLARS': 748,
#                             'SKIN_REPELLENTS': 749,
#                             'SCOOTERS': 750,
#                             'GARAGE_DOORS': 751,
#                             'BREAST_FEEDING_PILLOWS': 752,
#                             'TENTS': 753,
#                             'AUTOMOTIVE_TRANSMISSION_GEARS': 754,
#                             'MATE_GOURDS': 755,
#                             'PAINT_ROLLERS': 756,
#                             'SUNBATHING_CHAIRS': 757,
#                             'FLOOR_LAMPS': 758,
#                             'COOKTOPS': 759,
#                             'KITCHEN_MOLDS': 760,
#                             'DOG_LEASHES': 761,
#                             'FITNESS_TRAMPOLINES': 762,
#                             'SALT': 763,
#                             'AB_ROLLER_WHEELS': 764,
#                             'CAR_SCREENS': 765,
#                             'MEDICAL_WALKERS': 766,
#                             'CAN_OPENERS': 767,
#                             'OUTDOOR_TABLES': 768,
#                             'BRAKE_DRUMS': 769,
#                             'HEARING_AIDS': 770,
#                             'TEA': 771,
#                             'POWER_STRIPS': 772,
#                             'VEHICLE_CLUTCH_CABLES': 773,
#                             'SCHOOL_AND_OFFICE_GLUES': 774,
#                             'MINI_COMPONENT_SYSTEMS': 775,
#                             'POUFS': 776,
#                             'SOLID_SWEET_PASTES': 777,
#                             'OSCILLOSCOPES': 778,
#                             'FISHES': 779,
#                             'ACOUSTIC_PANELS': 780,
#                             'GPS': 781,
#                             'CARABINERS': 782,
#                             'ELBOW_SUPPORTS': 783,
#                             'LAWN_MOWER_BLADES': 784,
#                             'GOLF_CLUBS_SETS': 785,
#                             'BOX_SPRING_AND_MATTRESS_SETS': 786,
#                             'DEHUMIDIFIERS': 787,
#                             'VEGETABLES_AND_FRUITS_CHOPPERS': 788,
#                             'NAPKIN_HOLDERS': 789,
#                             'HOME_THEATERS': 790,
#                             'PENIS_SLEEVES': 791,
#                             'TOWEL_HOLDERS': 792,
#                             'PADDLE_TENNIS_RACKETS': 793,
#                             'MEGAPHONES': 794,
#                             'TV_REMOTE_CONTROLS': 795,
#                             'INFLATABLE_POOLS': 796,
#                             'PORTABLE_DVD_PLAYERS': 797,
#                             'ISOPROPYL_ALCOHOLS': 798,
#                             'BICYCLE_PEDALS': 799,
#                             'FREEZER_BAGS': 800,
#                             'GARDEN_SOIL': 801,
#                             'DRUM_BRAKE_SHOES': 802,
#                             'LINGERIE_SETS': 803,
#                             'AIRBRUSHES': 804,
#                             'PATIO_FURNITURE_SETS': 805,
#                             'LAPTOP_BRIEFCASES': 806,
#                             'HOOD_HINGES': 807,
#                             'BATHROOM_VANITIES': 808,
#                             'DILDOS': 809,
#                             'VEHICLE_BRAKE_HYDRAULIC_HOSES': 810,
#                             'ESPADRILLES': 811,
#                             'ELECTRIC_AIR_PUMPS': 812,
#                             'DRYER_MACHINES': 813,
#                             'POPCORN_MACHINES': 814,
#                             'ORAL_IRRIGATORS': 815,
#                             'HAIRDRESSING_CAPS': 816,
#                             'AUDIO_AND_VIDEO_CABLES_AND_ADAPTERS': 817,
#                             'TOY_PLANES': 818,
#                             'LASER_POINTERS': 819,
#                             'DRONE_BATTERIES': 820,
#                             'TABLE_CLOCKS': 821,
#                             'STRAWS': 822,
#                             'SWEETENERS': 823,
#                             'STOVETOP_POPCORN_POPPERS': 824,
#                             'WAFFLE_MAKERS': 825,
#                             'EXHAUST_MANIFOLDS': 826,
#                             'CYMBALS': 827,
#                             'MERCHANDISER_REFRIGERATORS': 828,
#                             'PHOTO_ALBUMS': 829,
#                             'MOUTHWASHES': 830,
#                             'HAMMER_DRILLS': 831,
#                             'TORQUE_WRENCHES': 832,
#                             'CUPCAKE_STANDS': 833,
#                             'AUTOMOTIVE_CLUTCH_MASTER_CYLINDERS': 834,
#                             'DIVING_MASKS': 835,
#                             'PLUNGE_ROUTERS': 836,
#                             'SCHOOL_AND_OFFICE_PAPERS': 837,
#                             'COTTON_CANDY_MACHINES': 838,
#                             'PARTY_HATS': 839,
#                             'HOLE_PUNCHES': 840,
#                             'CAMERA_CASES': 841,
#                             'MAKEUP_VANITIES': 842,
#                             'COMPOSTERS': 843,
#                             'DOG_BEDS': 844,
#                             'ECT_SENSORS': 845,
#                             'ELECTRIC_HAND_PLANERS': 846,
#                             'CLEANING_SPONGES': 847,
#                             'FETAL_DOPPLERS': 848,
#                             'TANDEM_CHAIRS': 849,
#                             'LASER_LEVELS': 850,
#                             'ELECTROLYTIC_CAPACITORS': 851,
#                             'ANTIQUE_CHAIRS': 852,
#                             'CAMERA_REPLACEMENT_DISPLAYS': 853,
#                             'VINYL_FLOORINGS': 854,
#                             'IGNITION_CONTROL_MODULES': 855,
#                             'LAMINATORS': 856,
#                             'SAFETY_HELMETS': 857,
#                             'ELECTRIC_BLOWERS': 858,
#                             'BALL_PIT_BALLS': 859,
#                             'ENERGETIC_STONES': 860,
#                             'AUTOMOTIVE_CV_JOINT_BOOTS': 861,
#                             'KITCHEN_CABINET_ORGANIZERS': 862,
#                             'WOOD_BURNING_MACHINES': 863,
#                             'MOTORCYCLE_CHEST_PROTECTORS': 864,
#                             'MICRODERMABRASION_MACHINES': 865,
#                             'CAR_SCANNERS': 866,
#                             'RACQUETS': 867,
#                             'INFLATABLE_SOFAS': 868,
#                             'BICYCLE_AND_MOTORCYCLE_ALARMS': 869,
#                             'ELECTRICAL_TIMERS': 870,
#                             'MAGNETIC_WELDING_HOLDERS': 871,
#                             'MOTORCYCLE_LEVERS': 872,
#                             'CHOCOLATE_WATERFALLS': 873,
#                             'LAUNDRY_BASKETS': 874,
#                             'LIGHT_STANDS': 875,
#                             'VARIABLE_FREQUENCY_DRIVES': 876,
#                             'VIDEO_CASSETTES': 877,
#                             'ARCHERY_BOWS': 878,
#                             'DRUM_STANDS': 879,
#                             'ICE_BUCKETS': 880,
#                             'FLATWARE_ORGANIZERS': 881,
#                             'CUTTING_BOARDS': 882,
#                             'SNARE_DRUMS': 883,
#                             'BABY_GYMS': 884,
#                             'BICYCLE_WHEELS': 885,
#                             'CYCLING_HELMETS': 886,
#                             'AUTOMOTIVE_CELLPHONE_AND_GPS_MOUNTS': 887,
#                             'WHEEL_STUDS': 888,
#                             'STAPLERS': 889,
#                             'SAFETY_GLOVES': 890,
#                             'DRONE_PROPELLERS': 891,
#                             'MAGNETIC_COMPASSES': 892,
#                             'AUTOMOTIVE_SEATS': 893,
#                             'PINBALLS': 894,
#                             'JEWELRY_BOXES': 895,
#                             'LAPTOP_HOUSINGS': 896,
#                             'TABLE_TENNIS_TABLES': 897,
#                             'BABY_JUMPERS': 898,
#                             'CAR_CENTER_CONSOLES': 899,
#                             'TELESCOPES': 900,
#                             'SHOE_RACKS': 901,
#                             'DOLLHOUSES': 902,
#                             'MULTIMETERS': 903,
#                             'POWER_STEERING_HOSES': 904,
#                             'WIRELESS_ANTENNAS': 905,
#                             'RADIO_BASE_STATIONS': 906,
#                             'COAT_RACKS': 907,
#                             'BABY_PACIFIER_CLIPS': 908,
#                             'ENGINE_COOLING_FAN_SWITCHES': 909,
#                             'HAND_SAWS': 910,
#                             'GAUZES': 911,
#                             'KNITTING_NEEDLES': 912,
#                             'PROJECTOR_MOUNTS': 913,
#                             'BEER_FAUCETS': 914,
#                             'KITES': 915,
# ...
#                            'ENGINE_COOLING_FAN_CLUTCHES': 16,
#                            'COLLECTIBLE_CANS_BOTTLES_AND_SODA_SIPHONS': 106,
#                            'STRING_TRIMMERS': 216,
#                            'SAFETY_HELMETS': 25,
#                            'CERAMIC_TILES': 46,
#                            'BIRD_TOYS': 166,
#                            'TOILETS': 95,
#                            'NOTEBOOK_CASES': 62,
#                            'COUNTERFEIT_MONEY_DETECTOR_MACHINE': 8,
#                            'LAPTOP_HOUSINGS': 21,
#                            'ORTHOPEDIC_WRIST_BRACES': 276,
#                            'POWER_STEERING_FLUID_RESERVOIRS': 116,
#                            'SAFES': 175,
#                            'TOY_GARAGES_AND_GAS_STATIONS': 63,
#                            'MOTORCYCLE_JERSEYS': 266,
#                            'EQUALIZERS': 53,
#                            'BLOOD_PRESSURE_MONITORS': 110,
#                            'FITNESS_TRAMPOLINES': 38,
#                            'IRRIGATION_VALVES': 144,
#                            'BEER_DISPENSERS': 87,
#                            'COMPRESSION_SLEEVES': 13,
#                            'TOY_PLANES': 30,
#                            'BATHROOM_GRAB_BARS': 95,
#                            'NETWORK_CARDS': 111,
#                            'RICE': 9,
#                            'STIMULATING_PILLS_AND_CAPSULES': 138,
#                            'LABEL_MAKERS': 85,
#                            'CATS': 67,
#                            'WINES': 656,
#                            'SECURITY_SEALS': 84,
#                            'DEHUMIDIFIERS': 33,
#                            'COMPOSTERS': 27,
#                            'AXES': 13,
#                            'PADLOCKS': 160,
#                            'RACQUETS': 23,
#                            'CAR_DOOR_HINGES': 45,
#                            'BODY_SHAPERS': 179,
#                            'MINI_COMPONENT_SYSTEMS': 35,
#                            'INFLATABLE_SOFAS': 23,
#                            'STATIONARY_BICYCLES': 266,
#                            'VEGETABLES_AND_FRUITS_CHOPPERS': 33,
#                            'VARNISHES': 62,
#                            'STYLUSES': 150,
#                            'LUNCHBOXES': 80,
#                            'ENGINE_CYLINDER_HEAD_BOLTS': 231,
#                            'BABY_BOTTLES': 362,
#                            'BICYCLE_AND_MOTORCYCLE_ALARMS': 23,
#                            'MDF_BOARDS': 71,
#                            'BASEBALL_AND_SOFTBALL_BATS': 19,
#                            'DOG_BEDS': 27,
#                            'LIQUID_HAND_AND_BODY_SOAPS': 322,
#                            'VACUUM_TUBES': 68,
#                            'BABY_GYMS': 22,
#                            'CNC_LATHES': 13,
#                            'MOTORCYCLE_FENDERS': 77,
#                            'NIGHTSTANDS': 105,
#                            'LONGBOARDS': 203,
#                            'PARTY_MASKS': 251,
#                            'WASTE_CONTAINERS': 42,
#                            'BABY_BODYSUITS': 97,
#                            'POUFS': 35,
#                            'CUSHION_COVERS': 272,
#                            'DRIVE_SHAFTS': 86,
#                            'BRAKE_MASTER_CYLINDERS': 45,
#                            'GAS_LIFT_SUPPORTS': 139,
#                            'LAPTOP_BATTERIES': 116,
#                            'POOL_WATERFALLS': 45,
#                            'ECT_SENSORS': 27,
#                            'FOLDERS_AND_EXPANDING_FILES': 101,
#                            'CAR_LIGHT_BULBS': 50,
#                            'FISHING_VESTS': 74,
#                            'SIDE_TABLES': 132,
#                            'BARBECUE_TOOL_SETS': 142,
#                            'DENTAL_CHAIRS': 16,
#                            'SUNBATHING_CHAIRS': 39,
#                            'BICYCLE_FRAMES': 48,
#                            'IP_TELEPHONES': 102,
#                            'DRINK_PITCHERS': 74,
#                            'AUTOMOTIVE_TRANSMISSION_GEARS': 40,
#                            'MULTIMETERS': 20,
#                            'MEAT_GRINDERS': 11,
#                            'INDUSTRIAL_ICE_CREAM_MACHINES': 71,
#                            'FOOTBALL_CAPS': 76,
#                            'LOAFERS_AND_OXFORDS': 67,
#                            'PAINTBALL_O_RINGS': 10,
#                            'ELECTRICAL_TIMERS': 23,
#                            'TACTICAL_VESTS': 49,
#                            'ACOUSTIC_PANELS': 34,
#                            'ELECTRIC_HAND_PLANERS': 27,
#                            'TOILETRY_BAGS': 143,
#                            'WINE_CELLARS': 41,
#                            'ELECTRIC_DEMOLITION_HAMMERS': 66,
#                            'TABLE_TENNIS_TABLES': 21,
#                            'POOL_COVERS': 81,
#                            'GARDEN_SOIL': 31,
#                            'MARKING_AND_WARNING_TAPES': 57,
#                            'CYMBALS': 29,
#                            'VIDEO_CAPTURE_DEVICES': 114,
#                            'DRUM_BRAKE_SHOES': 31,
#                            'DECORATIVE_BASKETS': 157,
#                            'CONDOMS': 96,
#                            'TREADMILL_RUNNING_BELTS': 46,
#                            'HAND_BRAKE_CABLES': 101,
#                            'SUNSCREENS': 112,
#                            'MAGNETIC_WELDING_HOLDERS': 23,
#                            'TOILET_PAPER_HOLDERS': 92,
#                            'VIDEOCASSETTE_PLAYERS': 13,
#                            'CUT_OFF_AND_GRINDING_WHEELS': 81,
#                            'JEWELRY_DISPLAYS': 52,
#                            'CLEANING_SPONGES': 27,
#                            'SKIN_REPELLENTS': 41,
#                            'SOCKS': 319,
#                            'MERCHANDISER_REFRIGERATORS': 29,
#                            'TENNIS_BALLS': 9,
#                            'AIR_CONDITIONERS': 83,
#                            'TOWEL_HOLDERS': 32,
#                            'RUM': 16,
#                            'GPS': 34,
#                            'HONEY': 58,
#                            'MANUAL_HAMMERS': 11,
#                            'BILLIARD_TABLES': 64,
#                            'BICYCLE_WHEELS': 22,
#                            'BRAKE_LIGHTS': 63,
#                            'FETAL_DOPPLERS': 27,
#                            'LEGGINGS': 108,
#                            'DIVING_MASKS': 28,
#                            'LASER_POINTERS': 30,
#                            'MOTORCYCLE_LEVERS': 23,
#                            'PADDLE_TENNIS_RACKETS': 32,
#                            'PORCELAIN_TILES': 19,
#                            'BALL_PIT_BALLS': 24,
#                            'HARMONICAS': 14,
#                            'PHOTO_ALBUMS': 29,
#                            'LINGERIE_SETS': 31,
#                            'MEGAPHONES': 32,
#                            'TV_REMOTE_CONTROLS': 32,
#                            'TRADING_CARD_GAMES': 163,
#                            'DRONE_BATTERIES': 30,
#                            'UNIVERSAL_CAR_REMOTES': 14,
#                            'DRUM_PEDALS': 88,
#                            'TABLE_CLOCKS': 30,
#                            'EROTIC_ANAL_AND_VAGINAL_DOUCHES': 11,
#                            'HAIR_STRAIGHTENERS': 66,
#                            'MICROWAVES': 49,
#                            'PUPPETS': 15,
#                            'REFLECTIVE_VESTS': 16,
#                            'EMBROIDERY_DESIGNS': 58,
#                            'MICROMETERS': 194,
#                            'MOTORCYCLE_IGNITION_COILS': 105,
#                            'DINING_SETS': 188,
#                            'AIRBRUSHES': 31,
#                            'CARABINERS': 34,
#                            'SOAP_HOLDERS': 42,
#                            'INFLATABLE_POOLS': 32,
#                            'GIFT_CARDS': 88,
#                            'POOL_LIGHTS': 58,
#                            'PATIO_FURNITURE_SETS': 31,
#                            'SCOOTERS': 41,
#                            'CYCLING_HELMETS': 22,
#                            'CHOCOLATE_WATERFALLS': 23,
#                            'HOSPITAL_BEDS': 140,
#                            'MAP_SENSORS': 62,
#                            'CLUTCH_FORKS': 10,
#                            'ELBOW_SUPPORTS': 34,
#                            'LAPTOP_BRIEFCASES': 31,
#                            'OUTDOOR_TABLES': 36,
#                            'DISTRIBUTION_KITS': 49,
#                            'JUICERS': 16,
#                            'VEHICLE_TRACKERS': 16,
#                            'BRAKE_DRUMS': 36,
#                            'AB_ROLLER_WHEELS': 37,
#                            'HOOD_HINGES': 31,
#                            'DENTAL_PLIERS': 122,
#                            'CLUTCH_BEARINGS': 11,
#                            'POWER_STEERING_HOSES': 20,
#                            'MOUTHWASHES': 29,
#                            'WIRELESS_ANTENNAS': 20,
#                            'LAUNDRY_BASKETS': 23,
#                            'LIVING_ROOM_SETS': 49,
#                            'BABY_PACIFIERS': 52,
#                            'HAND_POLISHERS': 49,
#                            'SHADE_CLOTHS': 42,
#                            'HAMMER_DRILLS': 29,
#                            'POWER_GRINDERS': 48,
#                            'CAMERA_STRAPS': 9,
#                            'LAWN_MOWER_BLADES': 34,
#                            'PNEUMATIC_STAPLERS': 45,
#                            'THERMAL_REFRIGERATORS_AND_BAGS': 101,
#                            'LIGHT_STANDS': 23,
#                            'STRAWS': 30,
#                            'SUITS': 121,
#                            'BATHROOM_VANITIES': 31,
#                            'VIBRATION_PLATFORMS': 65,
#                            'DINING_TABLES': 57,
#                            'TURNTABLE_NEEDLES': 9,
#                            'HEARING_AIDS': 36,
#                            'ORTHOPEDIC_WALKER_BOOTS': 51,
#                            'TEA': 36,
#                            'TORQUE_WRENCHES': 29,
#                            'CATS_LITTER': 42,
#                            'MATE_GOURDS': 40,
#                            'MEAT_HOOKS': 9,
#                            'AUTOMOTIVE_DEFLECTORS': 17,
#                            'VARIABLE_FREQUENCY_DRIVES': 23,
#                            'SWEETENERS': 30,
#                            'AUTOMOTIVE_CELLPHONE_AND_GPS_MOUNTS': 22,
#                            'RADIO_BASE_STATIONS': 20,
#                            'CRUTCHES': 13,
#                            'POWER_STRIPS': 36,
#                            'KATANA_SWORDS': 48,
#                            'CATS_AND_DOGS_TREATS': 52,
#                            'MEMORY_CARD_READERS': 10,
#                            'TELEPHONE_CABLES': 52,
#                            'SOLID_SWEET_PASTES': 35,
#                            'DISPOSABLE_GLOVES': 10,
#                            'MOTORCYCLE_GRAB_BARS': 12,
#                            'PLUNGE_ROUTERS': 28,
#                            'GROOVE_JOINT_PLIERS': 14,
#                            'BICYCLE_HANDLEBARS': 19,
#                            'SOLDERING_STATIONS': 94,
#                            'TANDEM_CHAIRS': 27,
#                            'GARAGE_DOORS': 41,
#                            'SPARK_PLUG_WIRESETS': 113,
#                            'ELECTRIC_SHOWER_HEADS': 18,
#                            'PORTABLE_DVD_PLAYERS': 32,
#                            'DILDOS': 31,
#                            'INDUSTRIAL_DOUGH_KNEADERS': 49,
#                            'UNIVERSAL_REMOTE_CONTROLS': 9,
#                            'WHEEL_STUDS': 22,
#                            'FABRIC_SOFTENERS': 67,
#                            'MOTORCYCLE_DISTRIBUTION_CHAINS': 67,
#                            'DOOR_AND_WINDOW_LOCKS': 13,
#                            'GINS': 14,
#                            'HAND_TRUCKS': 13,
#                            'STAPLERS': 22,
#                            'APERITIFS': 18,
#                            'SHOWER_CURTAINS': 16,
#                            'ANTIQUE_CHAIRS': 26,
#                            'YOGURT_MAKERS': 19,
#                            'SHIN_GUARDS': 9,
#                            'GOLF_CLUBS_SETS': 34,
#                            'FOOTBALL_GOALKEEPER_GLOVES': 57,
#                            'LASER_LEVELS': 27,
#                            'KEYBOARD_CONTROLLERS': 16,
#                            'ALTERNATOR_PULLEYS': 60,
#                            'CAMERA_AND_CELLPHONE_STABILIZERS': 13,
#                            'BABY_JUMPERS': 21,
#                            'CAMERA_REPLACEMENT_DISPLAYS': 26,
#                            'CRANKSHAFTS': 74,
#                            'BREAD_MAKERS': 13,
#                            'SCHOOL_AND_OFFICE_PAPERS': 28,
#                            'STOVETOP_POPCORN_POPPERS': 30,
#                            'BREAST_FEEDING_PILLOWS': 41,
#                            'POOL_CLEANERS': 16,
#                            'LINEMAN_PLIERS': 9,
#                            'COAT_RACKS': 20,
#                            'POOL_PUMPS': 43,
#                            'WATER_PURIFIERS_FILTERS': 73,
#                            'SAFETY_GLOVES': 22,
#                            'ISOPROPYL_ALCOHOLS': 32,
#                            'VEHICLE_BRAKE_HYDRAULIC_HOSES': 31,
#                            'MEDICINE_BALLS': 13,
#                            'KITCHEN_GRATERS': 17,
#                            'NAPKIN_HOLDERS': 33,
#                            'PUNCHING_BAGS': 11,
#                            'ESPADRILLES': 31,
#                            'CAR_CENTER_CONSOLES': 21,
#                            'VIDEO_CASSETTES': 23,
#                            'POTENTIOMETERS': 17,
#                            'READY_TO_DRINK_COCKTAILS': 9,
#                            'FLOOR_LAMPS': 39,
#                            'DRONE_PROPELLERS': 22,
#                            'TENTS': 41,
#                            'SAFETY_HARNESSES': 13,
#                            'SYRINGES': 14,
#                            'BEDLINERS': 58,
#                            'ELECTROLYTIC_CAPACITORS': 27,
#                            'BASKET_BALLS': 7,
#                            'OTOSCOPES': 16,
#                            'WAFFLE_MAKERS': 30,
#                            'PENIS_RINGS': 13,
#                            'ELECTRIC_AIR_PUMPS': 31,
#                            'COFFEE_CAPSULES': 18,
#                            'BABY_PACIFIER_CLIPS': 20,
#                            'KEY_RACKS': 16,
#                            'DEODORANTS': 19,
#                            'INDUSTRIAL_PULLEYS': 19,
#                            'BILL_COUNTERS': 18,
#                            'AUDIO_AND_VIDEO_CONNECTORS': 16,
#                            'WASHING_MACHINES': 44,
#                            'ENGINE_COOLING_FAN_SWITCHES': 20,
#                            'AUTOMOTIVE_BATTERIES': 19,
#                            'CHIP_AND_DIP_SERVERS': 14,
#                            'ARCHERY_BOWS': 23,
#                            'VINYL_FLOORINGS': 26,
#                            'MENSTRUAL_CUPS': 19,
#                            'SLEEPING_BAGS': 13,
#                            'RUBBER_STAMPS': 17,
#                            'DRYER_MACHINES': 31,
#                            'ENERGETIC_STONES': 24,
#                            'BICYCLE_PEDALS': 32,
#                            'MOTORCYCLE_CARBURETORS': 16,
#                            'SCREWDRIVERS_SETS': 12,
#                            'EDIBLE_SEEDS': 11,
#                            'STORE_SHOPPING_CARTS': 13,
#                            'SWIMMING_NOSE_CLIPS': 7,
#                            'AFTERSHAVES': 11,
#                            'AIRBAG_MODULES': 9,
#                            'HAND_SAWS': 20,
#                            'NECK_GAITERS_MASKS_AND_BALACLAVAS': 8,
#                            'MAGNETIC_COMPASSES': 22,
#                            'MAKEUP_TRAIN_CASES': 13,
#                            'POPCORN_MACHINES': 31,
#                            'LAMP_HOLDERS': 15,
#                            'IGNITION_CONTROL_MODULES': 26,
#                            ...})})}

# %%
num_labels = 1048

# %%
from allennlp.data.iterators import BucketIterator

# %%
iterator = BucketIterator(batch_size=config.batch_size, 
                          sorting_keys=[("tokens", "num_tokens")],
                         )

# %%
iterator.index_with(vocab)

# %%
label_dict = vocab.get_index_to_token_vocabulary('tokens')

# %%
batch = next(iter(iterator(train_dataset)))

# %%
batch["tokens"]["tokens"]
# Out:
# tensor([[[259, 108, 106,  ..., 261, 261, 261],
#          [259,  51,  50,  ..., 261, 261, 261],
#          [259, 116, 113,  ..., 261, 261, 261],
#          ...,
#          [259, 104, 102,  ..., 261, 261, 261],
#          [259, 116,  98,  ..., 261, 261, 261],
#          [259,  99, 106,  ..., 261, 261, 261]],
#
#         [[259,  99,  98,  ..., 261, 261, 261],
#          [259, 106, 111,  ..., 261, 261, 261],
#          [259, 113, 105,  ..., 261, 261, 261],
#          ...,
#          [259,  52,  54,  ..., 261, 261, 261],
#          [259, 113,  98,  ..., 261, 261, 261],
#          [  0,   0,   0,  ...,   0,   0,   0]],
#
#         [[259, 117, 102,  ..., 261, 261, 261],
#          [259, 100,  98,  ..., 261, 261, 261],
#          [259, 100, 117,  ..., 261, 261, 261],
#          ...,
#          [259, 101, 102,  ..., 261, 261, 261],
#          [259, 116, 112,  ..., 261, 261, 261],
#          [259,  98, 110,  ..., 261, 261, 261]],
#
#         ...,
#
#         [[259, 113, 115,  ..., 261, 261, 261],
#          [259, 111,  98,  ..., 261, 261, 261],
#          [259, 113, 102,  ..., 261, 261, 261],
#          ...,
#          [259,  51, 260,  ..., 261, 261, 261],
#          [259, 100,  98,  ..., 261, 261, 261],
#          [  0,   0,   0,  ...,   0,   0,   0]],
#
#         [[259, 110, 106,  ..., 261, 261, 261],
#          [259, 110, 106,  ..., 261, 261, 261],
#          [259, 104, 115,  ..., 261, 261, 261],
#          ...,
#          [259, 110, 102,  ..., 261, 261, 261],
#          [259, 114, 118,  ..., 261, 261, 261],
#          [259, 100,  98,  ..., 261, 261, 261]],
#
#         [[259, 103, 115,  ..., 261, 261, 261],
#          [259, 102, 109,  ..., 261, 261, 261],
#          [259, 110, 112,  ..., 261, 261, 261],
#          ...,
#          [259,  50,  54,  ..., 261, 261, 261],
#          [259, 111,  98,  ..., 261, 261, 261],
#          [  0,   0,   0,  ...,   0,   0,   0]]])

# %%
class BaselineModel(Model):
    def __init__(self, word_embeddings: TextFieldEmbedder,
                 encoder: Seq2VecEncoder,
                 out_sz: int):
        super().__init__(vocab)
        self.word_embeddings = word_embeddings
        self.encoder = encoder
        self.projection = nn.Linear(self.encoder.get_output_dim(), out_sz)
        self.loss = torch.nn.CrossEntropyLoss()
        self.metrics = {
                "accuracy": CategoricalAccuracy()
                #,"accuracy3": CategoricalAccuracy(top_k=3)
        }
        
    def forward(self, tokens: Dict[str, torch.Tensor],
                label: torch.Tensor) -> torch.Tensor:
        
        mask = get_text_field_mask(tokens)
        embeddings = self.word_embeddings(tokens)
        state = self.encoder(embeddings, mask)
        class_logits = self.projection(state)
        class_probabilities = F.softmax(class_logits)
        
        if label is not None:
            if label.shape[0] == 1:
                loss = self.loss(class_logits, label)
            else:    
                loss = self.loss(class_logits, label.squeeze(-1))
        
            for metric in self.metrics.values():
                if label.shape[0] == 1:
                    metric(class_logits, label)
                else:
                    metric(class_logits, label.squeeze(-1))
        
        output = {"class_logits": class_logits, "class_probabilities": class_probabilities, "loss": loss }
        return output

# %%
options_file = 'https://s3-us-west-2.amazonaws.com/allennlp/models/elmo/contributed/pt/elmo_pt_options.json'
weight_file = 'https://s3-us-west-2.amazonaws.com/allennlp/models/elmo/contributed/pt/elmo_pt_weights.hdf5'

elmo_embedder = ElmoTokenEmbedder(options_file, weight_file)
word_embeddings = BasicTextFieldEmbedder({"tokens": elmo_embedder})

# %%
encoder: Seq2VecEncoder = PytorchSeq2VecWrapper(nn.LSTM(word_embeddings.get_output_dim(), config.hidden_sz, 
                                                        bidirectional=True, batch_first=True))

# %%
model = BaselineModel(
    word_embeddings, 
    encoder, num_labels)

# %%
if USE_GPU: model.cuda(gpu)
else: model

# %%
batch = nn_util.move_to_device(batch, gpu if USE_GPU else -1)

# %%
tokens = batch["tokens"]
labels = batch

# %%
mask = get_text_field_mask(tokens)

# %%
embeddings = model.word_embeddings(tokens)
state = model.encoder(embeddings, mask)
class_logits = model.projection(state)

# %%
embeddings.size()
# Out:
# torch.Size([512, 10, 1024])

# %%
state
# Out:
# tensor([[ 0.2972, -0.0752,  0.0504,  ..., -0.2361,  0.0104, -0.1632],
#         [ 0.0572,  0.0513, -0.0315,  ..., -0.2705,  0.0430,  0.3052],
#         [-0.1446, -0.0170, -0.4060,  ..., -0.1722,  0.0446, -0.2055],
#         ...,
#         [-0.0524,  0.0836,  0.0408,  ..., -0.1700,  0.0982, -0.0396],
#         [ 0.0246,  0.0489, -0.2029,  ..., -0.1581,  0.0872,  0.2152],
#         [ 0.0175,  0.1782,  0.0237,  ...,  0.0011,  0.1411,  0.1077]],
#        device='cuda:2', grad_fn=<ViewBackward>)

# %%
model(**batch)
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:22: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
# {'class_logits': tensor([[-5.9148e-02, -7.0721e-02, -1.1920e-01,  ...,  4.7724e-02,
#            8.3995e-02, -8.2435e-02],
#          [-1.0090e-01,  5.3150e-02,  1.0017e-01,  ..., -4.9621e-02,
#            1.6763e-01, -2.0815e-01],
#          [-3.4649e-02,  2.2156e-02, -9.0239e-02,  ..., -2.0660e-04,
#            1.0688e-02,  8.4100e-02],
#          ...,
#          [-1.7105e-01,  1.2732e-02, -1.0934e-05,  ..., -8.7087e-02,
#           -9.6925e-02, -2.4802e-02],
#          [-1.2206e-01,  8.8779e-02,  1.3225e-01,  ...,  2.9692e-03,
#           -4.1607e-03, -7.0190e-02],
#          [-5.3652e-02, -5.3688e-03,  1.5957e-03,  ...,  2.1658e-02,
#           -5.5652e-02,  5.7587e-02]], device='cuda:2', grad_fn=<AddmmBackward>),
#  'class_probabilities': tensor([[0.0009, 0.0009, 0.0008,  ..., 0.0010, 0.0010, 0.0009],
#          [0.0009, 0.0010, 0.0011,  ..., 0.0009, 0.0011, 0.0008],
#          [0.0009, 0.0010, 0.0009,  ..., 0.0009, 0.0010, 0.0010],
#          ...,
#          [0.0008, 0.0010, 0.0010,  ..., 0.0009, 0.0009, 0.0009],
#          [0.0008, 0.0010, 0.0011,  ..., 0.0010, 0.0009, 0.0009],
#          [0.0009, 0.0009, 0.0009,  ..., 0.0010, 0.0009, 0.0010]],
#         device='cuda:2', grad_fn=<SoftmaxBackward>),
#  'loss': tensor(6.9649, device='cuda:2', grad_fn=<NllLossBackward>)}

# %%
loss = model(**batch)["loss"]
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:22: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.

# %%
loss
# Out:
# tensor(6.9584, device='cuda:2', grad_fn=<NllLossBackward>)

# %%
loss.backward()

# %%
[x.grad for x in list(model.encoder.parameters())]
# Out:
# [tensor([[-6.0827e-05, -4.1661e-05,  3.9743e-05,  ..., -1.4868e-05,
#            4.9867e-05,  2.2017e-05],
#          [-1.2223e-04,  2.1713e-05,  1.8538e-05,  ..., -1.1245e-04,
#            2.5176e-05,  2.6623e-05],
#          [-2.1081e-05,  1.6477e-05, -5.2541e-05,  ..., -4.5968e-05,
#            3.5557e-05, -2.8829e-06],
#          ...,
#          [-1.6109e-05,  4.5520e-05, -1.2063e-06,  ...,  7.5589e-05,
#           -4.6699e-05, -3.2060e-05],
#          [ 7.7857e-05,  8.7021e-05,  1.1329e-05,  ...,  4.2701e-05,
#            8.5330e-06,  1.2885e-07],
#          [-8.2162e-05, -1.2985e-05,  2.9444e-05,  ..., -9.2555e-05,
#            2.9029e-05,  4.5379e-05]], device='cuda:2'),
#  tensor([[-1.2705e-05,  2.3131e-06, -1.3766e-05,  ...,  1.3586e-06,
#           -1.9021e-05, -6.3431e-06],
#          [-1.4106e-05, -3.4165e-06,  1.7656e-05,  ...,  5.5108e-06,
#            1.1438e-05,  1.2764e-05],
#          [ 2.6794e-06, -6.0544e-07,  1.2590e-05,  ...,  1.3125e-05,
#           -1.3010e-06,  1.4601e-05],
#          ...,
#          [-1.1255e-05, -9.5788e-06, -2.1226e-05,  ..., -1.5960e-05,
#           -1.3749e-06, -1.8608e-05],
#          [ 1.0641e-06, -1.0633e-05,  2.1673e-05,  ...,  9.8996e-06,
#           -3.0080e-05, -2.5163e-05],
#          [ 5.0460e-06,  1.6735e-05, -3.3808e-05,  ..., -2.4892e-05,
#            2.4720e-05, -3.2000e-05]], device='cuda:2'),
#  tensor([-2.4487e-06, -5.4961e-05,  2.2325e-05,  ...,  5.9620e-05,
#           9.4193e-05,  3.0967e-05], device='cuda:2'),
#  tensor([-2.4487e-06, -5.4961e-05,  2.2325e-05,  ...,  5.9620e-05,
#           9.4193e-05,  3.0967e-05], device='cuda:2'),
#  tensor([[-6.3633e-05,  6.5576e-06,  5.9385e-05,  ..., -6.8615e-05,
#           -1.2271e-05, -4.8138e-05],
#          [-4.0506e-05, -5.3224e-05,  1.4557e-04,  ..., -7.1687e-06,
#            1.1473e-05, -5.2780e-05],
#          [-8.2166e-05,  3.9624e-05,  4.3458e-05,  ..., -7.3846e-05,
#           -3.4334e-05, -5.4143e-05],
#          ...,
#          [ 8.4479e-06,  5.7622e-05,  7.0374e-05,  ..., -4.5678e-05,
#            1.0614e-04, -9.8165e-06],
#          [-2.3936e-05,  1.1671e-04, -1.4359e-04,  ..., -7.6170e-05,
#           -4.5402e-05, -4.7597e-05],
#          [-2.0355e-06, -1.7014e-05,  1.0262e-04,  ...,  4.8932e-05,
#            1.1731e-05,  2.2423e-05]], device='cuda:2'),
#  tensor([[-1.8721e-05,  4.1040e-05,  2.8201e-05,  ...,  1.8355e-05,
#           -8.8330e-06, -9.9310e-06],
#          [-1.0395e-05,  1.5578e-05, -7.0271e-07,  ...,  1.7741e-05,
#           -4.5384e-06, -7.0321e-07],
#          [ 3.5794e-06,  6.5053e-06,  1.1735e-05,  ...,  3.8442e-06,
#           -1.3190e-05, -3.0713e-06],
#          ...,
#          [-1.1686e-05,  5.7421e-06, -1.6352e-05,  ..., -7.7462e-06,
#            3.2614e-05, -1.0057e-06],
#          [ 1.7857e-05, -3.6087e-07, -1.0388e-05,  ..., -6.9047e-06,
#            1.3102e-05,  2.4833e-05],
#          [ 8.0655e-06,  2.6536e-06,  3.9561e-06,  ..., -5.8738e-06,
#           -5.6685e-06, -1.1450e-05]], device='cuda:2'),
#  tensor([-1.6052e-04, -1.0957e-04, -4.0627e-05,  ...,  4.9313e-05,
#           5.6092e-05, -8.5703e-06], device='cuda:2'),
#  tensor([-1.6052e-04, -1.0957e-04, -4.0627e-05,  ...,  4.9313e-05,
#           5.6092e-05, -8.5703e-06], device='cuda:2')]

# %% [markdown]
# ## TRAIN

# %%
optimizer = optim.Adam(model.parameters(), lr=config.lr)

# %%
from allennlp.training.trainer import Trainer

trainer = Trainer(
    model=model,
    patience=5,
    optimizer=optimizer,
    iterator=iterator,
    train_dataset=train_dataset,
    validation_dataset=val_dataset,
    cuda_device=gpu if USE_GPU else -1,
    num_epochs=config.epochs,
)

# %%
metrics = trainer.train()
# Out:
# /usr/local/lib/python3.6/dist-packages/torch/nn/modules/container.py:435: UserWarning: Setting attributes on ParameterList is not supported.
#   warnings.warn("Setting attributes on ParameterList is not supported.")
#   0%|          | 0/975 [00:00<?, ?it/s]/usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:22: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
# loss: 1.3008 ||: 100%|██████████| 975/975 [12:16<00:00,  1.32it/s]
# loss: 0.5782 ||: 100%|██████████| 109/109 [00:59<00:00,  1.83it/s]
# /usr/local/lib/python3.6/dist-packages/torch/nn/modules/container.py:435: UserWarning: Setting attributes on ParameterList is not supported.
#   warnings.warn("Setting attributes on ParameterList is not supported.")
#   0%|          | 0/975 [00:00<?, ?it/s]/usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:22: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
# loss: 0.5884 ||: 100%|██████████| 975/975 [12:34<00:00,  1.29it/s]
# loss: 0.4622 ||: 100%|██████████| 109/109 [00:39<00:00,  2.76it/s]
# /usr/local/lib/python3.6/dist-packages/torch/nn/modules/container.py:435: UserWarning: Setting attributes on ParameterList is not supported.
#   warnings.warn("Setting attributes on ParameterList is not supported.")
#   0%|          | 0/975 [00:00<?, ?it/s]/usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:22: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
# loss: 0.4820 ||: 100%|██████████| 975/975 [12:30<00:00,  1.30it/s]
# loss: 0.4289 ||: 100%|██████████| 109/109 [01:00<00:00,  1.79it/s]
# /usr/local/lib/python3.6/dist-packages/torch/nn/modules/container.py:435: UserWarning: Setting attributes on ParameterList is not supported.
#   warnings.warn("Setting attributes on ParameterList is not supported.")
#   0%|          | 0/975 [00:00<?, ?it/s]/usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:22: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
# loss: 0.4289 ||: 100%|██████████| 975/975 [12:19<00:00,  1.32it/s]
# loss: 0.4074 ||: 100%|██████████| 109/109 [01:21<00:00,  1.34it/s]
# /usr/local/lib/python3.6/dist-packages/torch/nn/modules/container.py:435: UserWarning: Setting attributes on ParameterList is not supported.
#   warnings.warn("Setting attributes on ParameterList is not supported.")
#   0%|          | 0/975 [00:00<?, ?it/s]/usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:22: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
# loss: 0.4010 ||: 100%|██████████| 975/975 [12:03<00:00,  1.35it/s]
# loss: 0.4176 ||: 100%|██████████| 109/109 [01:19<00:00,  1.38it/s]
# /usr/local/lib/python3.6/dist-packages/torch/nn/modules/container.py:435: UserWarning: Setting attributes on ParameterList is not supported.
#   warnings.warn("Setting attributes on ParameterList is not supported.")
#   0%|          | 0/975 [00:00<?, ?it/s]/usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:22: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
# loss: 0.3719 ||: 100%|██████████| 975/975 [11:56<00:00,  1.36it/s]
# loss: 0.4212 ||: 100%|██████████| 109/109 [01:17<00:00,  1.40it/s]
# /usr/local/lib/python3.6/dist-packages/torch/nn/modules/container.py:435: UserWarning: Setting attributes on ParameterList is not supported.
#   warnings.warn("Setting attributes on ParameterList is not supported.")
#   0%|          | 0/975 [00:00<?, ?it/s]/usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:22: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
# loss: 0.3551 ||: 100%|██████████| 975/975 [11:38<00:00,  1.40it/s]
# loss: 0.4035 ||: 100%|██████████| 109/109 [01:16<00:00,  1.42it/s]
# /usr/local/lib/python3.6/dist-packages/torch/nn/modules/container.py:435: UserWarning: Setting attributes on ParameterList is not supported.
#   warnings.warn("Setting attributes on ParameterList is not supported.")
#   0%|          | 0/975 [00:00<?, ?it/s]/usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:22: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
# loss: 0.3508 ||: 100%|██████████| 975/975 [11:52<00:00,  1.37it/s]
# loss: 0.4400 ||: 100%|██████████| 109/109 [01:17<00:00,  1.41it/s]
# /usr/local/lib/python3.6/dist-packages/torch/nn/modules/container.py:435: UserWarning: Setting attributes on ParameterList is not supported.
#   warnings.warn("Setting attributes on ParameterList is not supported.")
#   0%|          | 0/975 [00:00<?, ?it/s]/usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:22: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
# loss: 0.3242 ||: 100%|██████████| 975/975 [11:53<00:00,  1.37it/s]
# loss: 0.3907 ||: 100%|██████████| 109/109 [01:16<00:00,  1.42it/s]
# /usr/local/lib/python3.6/dist-packages/torch/nn/modules/container.py:435: UserWarning: Setting attributes on ParameterList is not supported.
#   warnings.warn("Setting attributes on ParameterList is not supported.")
#   0%|          | 0/975 [00:00<?, ?it/s]/usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:22: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
# loss: 1.2951 ||: 100%|██████████| 975/975 [12:01<00:00,  1.35it/s]
# loss: 0.7276 ||: 100%|██████████| 109/109 [01:06<00:00,  1.63it/s]
# /usr/local/lib/python3.6/dist-packages/torch/nn/modules/container.py:435: UserWarning: Setting attributes on ParameterList is not supported.
#   warnings.warn("Setting attributes on ParameterList is not supported.")
#   0%|          | 0/975 [00:00<?, ?it/s]/usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:22: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
# loss: 0.5840 ||: 100%|██████████| 975/975 [12:13<00:00,  1.33it/s]
# loss: 0.4734 ||: 100%|██████████| 109/109 [00:40<00:00,  2.72it/s]
# /usr/local/lib/python3.6/dist-packages/torch/nn/modules/container.py:435: UserWarning: Setting attributes on ParameterList is not supported.
#   warnings.warn("Setting attributes on ParameterList is not supported.")
#   0%|          | 0/975 [00:00<?, ?it/s]/usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:22: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
# loss: 0.3951 ||: 100%|██████████| 975/975 [08:47<00:00,  1.85it/s]
# loss: 0.4305 ||: 100%|██████████| 109/109 [00:39<00:00,  2.73it/s]
# /usr/local/lib/python3.6/dist-packages/torch/nn/modules/container.py:435: UserWarning: Setting attributes on ParameterList is not supported.
#   warnings.warn("Setting attributes on ParameterList is not supported.")
#   0%|          | 0/975 [00:00<?, ?it/s]/usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:22: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
# loss: 0.3456 ||: 100%|██████████| 975/975 [08:49<00:00,  1.84it/s]
# loss: 0.4318 ||: 100%|██████████| 109/109 [00:39<00:00,  2.76it/s]
# /usr/local/lib/python3.6/dist-packages/torch/nn/modules/container.py:435: UserWarning: Setting attributes on ParameterList is not supported.
#   warnings.warn("Setting attributes on ParameterList is not supported.")
#   0%|          | 0/975 [00:00<?, ?it/s]/usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:22: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
# loss: 0.3194 ||: 100%|██████████| 975/975 [08:52<00:00,  1.83it/s]
# loss: 0.4392 ||: 100%|██████████| 109/109 [00:39<00:00,  2.76it/s]

# %%
# Here's how to save the model.
with open(ELMO_MODEL_PATH, 'wb+') as f:
    torch.save(model.state_dict(), f)

vocab.save_to_files(ELMO_VOCAB_PATH)

# %%
# And here's how to reload the model.
vocab2 = Vocabulary.from_files(ELMO_VOCAB_PATH)

model = BaselineModel(
    word_embeddings, 
    encoder, num_labels)

with open(ELMO_MODEL_PATH, 'rb') as f:
    model.load_state_dict(torch.load(f))

# %%
model.cuda(gpu)
# Out:
# BaselineModel(
#   (word_embeddings): BasicTextFieldEmbedder(
#     (token_embedder_tokens): ElmoTokenEmbedder(
#       (_elmo): Elmo(
#         (_elmo_lstm): _ElmoBiLm(
#           (_token_embedder): _ElmoCharacterEncoder(
#             (char_conv_0): Conv1d(16, 32, kernel_size=(1,), stride=(1,))
#             (char_conv_1): Conv1d(16, 32, kernel_size=(2,), stride=(1,))
#             (char_conv_2): Conv1d(16, 64, kernel_size=(3,), stride=(1,))
#             (char_conv_3): Conv1d(16, 128, kernel_size=(4,), stride=(1,))
#             (char_conv_4): Conv1d(16, 256, kernel_size=(5,), stride=(1,))
#             (char_conv_5): Conv1d(16, 512, kernel_size=(6,), stride=(1,))
#             (char_conv_6): Conv1d(16, 1024, kernel_size=(7,), stride=(1,))
#             (_highways): Highway(
#               (_layers): ModuleList(
#                 (0): Linear(in_features=2048, out_features=4096, bias=True)
#                 (1): Linear(in_features=2048, out_features=4096, bias=True)
#               )
#             )
#             (_projection): Linear(in_features=2048, out_features=512, bias=True)
#           )
#           (_elmo_lstm): ElmoLstm(
#             (forward_layer_0): LstmCellWithProjection(
#               (input_linearity): Linear(in_features=512, out_features=16384, bias=False)
#               (state_linearity): Linear(in_features=512, out_features=16384, bias=True)
#               (state_projection): Linear(in_features=4096, out_features=512, bias=False)
#             )
#             (backward_layer_0): LstmCellWithProjection(
#               (input_linearity): Linear(in_features=512, out_features=16384, bias=False)
#               (state_linearity): Linear(in_features=512, out_features=16384, bias=True)
#               (state_projection): Linear(in_features=4096, out_features=512, bias=False)
#             )
#             (forward_layer_1): LstmCellWithProjection(
#               (input_linearity): Linear(in_features=512, out_features=16384, bias=False)
#               (state_linearity): Linear(in_features=512, out_features=16384, bias=True)
#               (state_projection): Linear(in_features=4096, out_features=512, bias=False)
#             )
#             (backward_layer_1): LstmCellWithProjection(
#               (input_linearity): Linear(in_features=512, out_features=16384, bias=False)
#               (state_linearity): Linear(in_features=512, out_features=16384, bias=True)
#               (state_projection): Linear(in_features=4096, out_features=512, bias=False)
#             )
#           )
#         )
#         (_dropout): Dropout(p=0.5, inplace=False)
#         (scalar_mix_0): ScalarMix(
#           (scalar_parameters): ParameterList(
#               (0): Parameter containing: [torch.cuda.FloatTensor of size 1 (GPU 2)]
#               (1): Parameter containing: [torch.cuda.FloatTensor of size 1 (GPU 2)]
#               (2): Parameter containing: [torch.cuda.FloatTensor of size 1 (GPU 2)]
#           )
#         )
#       )
#     )
#   )
#   (encoder): PytorchSeq2VecWrapper(
#     (_module): LSTM(1024, 300, batch_first=True, bidirectional=True)
#   )
#   (projection): Linear(in_features=600, out_features=1048, bias=True)
#   (loss): CrossEntropyLoss()
# )

# %% [markdown]
# ### Generating Predictions

# %%
from tqdm import tqdm
from scipy.special import expit # the sigmoid function

def tonp(tsr): return tsr.detach().cpu().numpy()

class Predictor:
    def __init__(self, model: Model, iterator: DataIterator,
                 cuda_device: int=-1) -> None:
        self.model = model
        self.iterator = iterator
        self.cuda_device = cuda_device
        
    def _extract_data(self, batch) -> np.ndarray:
        out_dict = self.model(**batch)
        return tonp(out_dict["class_probabilities"])
    
    def predict(self, ds: Iterable[Instance]) -> np.ndarray:
        pred_generator = self.iterator(ds, num_epochs=1, shuffle=False)
        self.model.eval()
        pred_generator_tqdm = tqdm(pred_generator,
                                   total=self.iterator.get_num_batches(ds))
        preds = []
        with torch.no_grad():
            for batch in pred_generator_tqdm:
                batch = nn_util.move_to_device(batch, self.cuda_device)
                preds.append(self._extract_data(batch))
        return np.concatenate(preds, axis=0)

# %%
from allennlp.data.iterators import BasicIterator
# iterate over the dataset without changing its order
seq_iterator = BasicIterator(batch_size=64)
seq_iterator.index_with(vocab)

# %%
predictor = Predictor(model, seq_iterator, cuda_device=gpu if USE_GPU else -1)
test_preds = predictor.predict(test_dataset)
# Out:
#   0%|          | 0/2165 [00:00<?, ?it/s]/usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:22: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
# 100%|██████████| 2165/2165 [03:37<00:00,  9.94it/s]

# %%
Y_pred=test_preds.argmax(axis=1)

# %%
Y_test = []
for x in test_dataset:
    Y_test.append(vars(x.fields['label'])['_label_id'])

# %%
label_dict = model.vocab.get_index_to_token_vocabulary('labels')

# %%
label_dict[26]
# Out:
# 'FISHING_REELS'

# %%
from sklearn.metrics import classification_report
print(classification_report(Y_test, Y_pred, digits=3))
# Out:
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#               precision    recall  f1-score   support
#
#            0      0.991     0.997     0.994       942
#            1      1.000     1.000     1.000       938
#            2      0.999     0.993     0.996       934
#            3      0.945     0.960     0.953       921
#            4      0.901     0.910     0.905       909
#            5      0.963     0.981     0.972       908
#            6      0.971     0.903     0.936       885
#            7      0.950     0.951     0.950       876
#            8      0.955     0.975     0.965       875
#            9      0.940     0.967     0.953       857
#           10      0.944     0.935     0.940       850
#           11      0.890     0.903     0.896       843
#           12      0.816     0.765     0.790       834
#           13      0.923     0.942     0.933       829
#           14      0.969     0.988     0.978       822
#           15      0.919     0.886     0.902       815
#           16      0.926     0.970     0.948       804
#           17      0.612     0.593     0.602       800
#           18      0.904     0.946     0.925       799
#           19      0.985     0.965     0.975       794
#           20      0.940     0.967     0.953       788
#           21      0.928     0.945     0.936       778
#           22      0.918     0.920     0.919       774
#           23      0.961     0.968     0.964       770
#           24      0.991     0.972     0.981       760
#           25      0.931     0.958     0.944       742
#           26      0.957     0.973     0.965       740
#           27      0.963     0.959     0.961       738
#          712      0.583     0.500     0.538        14
#          713      0.786     0.786     0.786        14
#          714      0.857     0.429     0.571        14
#          715      0.692     0.643     0.667        14
#          716      0.737     1.000     0.848        14
#          717      0.909     0.769     0.833        13
#          718      0.786     0.846     0.815        13
#          719      0.846     0.846     0.846        13
#          720      1.000     0.643     0.783        14
#          721      0.571     0.571     0.571        14
#          722      0.714     0.714     0.714        14
#          723      1.000     0.846     0.917        13
#          724      0.917     0.846     0.880        13
#          725      0.857     0.923     0.889        13
#          726      0.846     0.846     0.846        13
#          727      0.733     0.846     0.786        13
#          728      0.462     0.462     0.462        13
#          729      0.917     0.846     0.880        13
#          730      0.667     0.923     0.774        13
#          731      1.000     1.000     1.000        13
#          732      0.923     0.923     0.923        13
#          733      0.875     0.583     0.700        12
#          734      0.857     0.923     0.889        13
#          735      0.727     0.667     0.696        12
#          736      1.000     0.846     0.917        13
#          737      1.000     0.923     0.960        13
#          738      1.000     0.833     0.909        12
#          739      0.632     1.000     0.774        12
#          740      0.833     0.833     0.833        12
#          741      0.692     0.750     0.720        12
#          742      0.417     0.417     0.417        12
#          743      0.846     0.917     0.880        12
#          744      1.000     0.917     0.957        12
#          745      0.600     0.500     0.545        12
#          746      0.692     0.818     0.750        11
#          747      0.692     0.750     0.720        12
#          748      0.846     1.000     0.917        11
#          749      0.900     0.818     0.857        11
#          750      0.909     0.833     0.870        12
#          751      0.800     0.667     0.727        12
#          752      0.692     0.818     0.750        11
#          753      0.900     0.818     0.857        11
#          754      0.778     0.636     0.700        11
#          755      1.000     0.455     0.625        11
#          756      1.000     0.909     0.952        11
#          757      0.800     0.727     0.762        11
#          758      0.636     0.636     0.636        11
#          759      0.500     0.364     0.421        11
#          760      0.500     0.500     0.500        10
#          761      0.909     1.000     0.952        10
#          762      0.786     1.000     0.880        11
#          763      1.000     1.000     1.000        10
#          764      1.000     1.000     1.000        10
#          765      0.571     0.800     0.667        10
#          766      0.889     0.800     0.842        10
#          767      0.500     0.300     0.375        10
#          768      0.800     0.400     0.533        10
#          769      1.000     1.000     1.000        10
#          770      0.900     0.900     0.900        10
#          771      0.750     0.300     0.429        10
#          772      0.700     0.700     0.700        10
#          773      0.900     0.900     0.900        10
#          774      0.200     0.100     0.133        10
#          775      0.250     0.300     0.273        10
#          776      0.800     0.800     0.800        10
#          777      0.667     0.600     0.632        10
#          778      0.778     0.700     0.737        10
#          779      0.571     0.444     0.500         9
#          780      0.800     0.889     0.842         9
#          781      0.875     0.778     0.824         9
#          782      0.727     0.889     0.800         9
#          783      0.818     1.000     0.900         9
#          784      0.833     0.556     0.667         9
#          785      1.000     0.889     0.941         9
#          786      0.625     0.556     0.588         9
#          787      0.667     0.444     0.533         9
#          788      0.800     0.444     0.571         9
#          789      0.625     0.556     0.588         9
#          790      0.600     0.667     0.632         9
#          791      0.625     0.556     0.588         9
#          792      1.000     0.667     0.800         9
#          793      1.000     0.889     0.941         9
#          794      1.000     0.778     0.875         9
#          795      0.429     0.333     0.375         9
#          796      0.750     0.333     0.462         9
#          883      0.667     0.667     0.667         6
#          884      0.625     0.833     0.714         6
#          885      0.750     0.500     0.600         6
#          886      0.750     0.500     0.600         6
#          887      0.833     0.833     0.833         6
#          888      0.000     0.000     0.000         6
#          889      0.750     1.000     0.857         6
#          890      0.750     0.500     0.600         6
#          891      1.000     0.500     0.667         6
#          892      0.400     0.667     0.500         6
#          893      0.500     0.333     0.400         6
#          894      0.600     0.500     0.545         6
#          895      0.500     0.333     0.400         6
#          896      0.800     0.667     0.727         6
#          897      1.000     1.000     1.000         6
#          898      0.500     0.333     0.400         6
#          899      0.250     0.333     0.286         6
#          900      0.800     0.800     0.800         5
#          901      0.667     0.400     0.500         5
#          902      0.400     0.800     0.533         5
#          903      0.667     0.667     0.667         6
#          904      0.333     0.333     0.333         6
#          905      0.500     0.400     0.444         5
#          906      0.000     0.000     0.000         6
#          907      0.400     0.333     0.364         6
#          908      0.714     1.000     0.833         5
#          909      0.500     0.667     0.571         6
#          910      0.750     1.000     0.857         6
#          911      0.833     0.833     0.833         6
#          912      0.600     0.500     0.545         6
#          913      0.750     0.600     0.667         5
#          914      0.571     0.800     0.667         5
#          915      1.000     1.000     1.000         5
#          916      1.000     1.000     1.000         5
#          917      1.000     1.000     1.000         5
#          918      0.667     0.400     0.500         5
#          919      0.667     0.400     0.500         5
#          920      0.667     0.400     0.500         5
#          921      0.500     0.800     0.615         5
#          922      0.400     0.400     0.400         5
#          923      1.000     1.000     1.000         5
#          924      0.333     0.200     0.250         5
#          925      0.273     0.600     0.375         5
#          926      0.667     0.400     0.500         5
#          927      0.667     0.800     0.727         5
#          928      0.800     0.800     0.800         5
#          929      1.000     0.800     0.889         5
#          930      1.000     1.000     1.000         5
#          931      0.333     0.400     0.364         5
#          932      0.571     0.800     0.667         5
#          933      0.400     0.400     0.400         5
#          934      1.000     0.500     0.667         4
#          935      1.000     0.250     0.400         4
#          936      1.000     1.000     1.000         5
#          937      0.600     0.750     0.667         4
#          938      1.000     1.000     1.000         4
#          939      0.750     0.750     0.750         4
#          940      0.714     1.000     0.833         5
#          941      0.333     0.200     0.250         5
#          942      0.500     1.000     0.667         5
#          943      0.750     0.750     0.750         4
#          944      0.200     0.200     0.200         5
#          945      1.000     0.600     0.750         5
#          946      0.500     0.750     0.600         4
#          947      0.000     0.000     0.000         4
#          948      0.000     0.000     0.000         4
#          949      0.667     0.800     0.727         5
#          950      1.000     0.250     0.400         4
#          951      0.000     0.000     0.000         4
#          952      0.000     0.000     0.000         4
#          953      0.600     0.750     0.667         4
#          954      0.500     0.500     0.500         4
#          955      1.000     0.250     0.400         4
#          956      0.750     0.750     0.750         4
#          957      1.000     1.000     1.000         4
#          958      0.800     1.000     0.889         4
#          959      0.500     0.750     0.600         4
#          960      0.429     0.750     0.545         4
#          961      0.500     0.250     0.333         4
#          962      0.800     1.000     0.889         4
#          963      0.400     0.500     0.444         4
#          964      0.750     0.750     0.750         4
#          965      1.000     0.500     0.667         4
#          966      0.500     1.000     0.667         4
#          967      1.000     0.500     0.667         4
#          968      1.000     0.333     0.500         3
