# %%
# %load_ext autoreload
# %autoreload 2

from os.path import join
import os
import pandas as pd
import torch
import numpy as np
import torch.nn as nn
import torch.nn.functional as F
from torch.optim.lr_scheduler import ReduceLROnPlateau
from torch.nn.init import kaiming_uniform_
from torch.optim import SGD
from torch.utils.data import DataLoader, SequentialSampler, RandomSampler
from torch.optim import Adam
from torch.autograd import Variable
from nlpClassifiers.data.dataset  import NLPDataset, Vocabulary
from sklearn.metrics import roc_curve, auc, classification_report
from scipy.special import expit
import gensim
import shutil
from pathlib import Path
import random

# %%
ROOT = '../../'
PATH_TO_VIRTUAL_OPERATOR_DATA = join(ROOT, "data/virtual-operator")
PATH_TO_AGENT_BENCHMARK_DATA = join(ROOT, "data/agent-benchmark")
PATH_TO_ML_PT_DATA = join(ROOT, "data/mercado-livre-pt-only")

PATH_TO_VIRTUAL_OPERATOR_MODELS = join(ROOT, "models/virtual-operator")
PATH_TO_AGENT_BENCHMARK_MODELS = join(ROOT, "models/agent-benchmark")
PATH_TO_ML_PT_MODELS = join(ROOT, "models/mercado-livre-pt-only")
EMBEDDINGS_FILE = '../../data/twitter-pt/vocab/word2vec-model-tweets-pmann-reduced-pt.bin'
EMBEDDING_DIM = 300
MAX_WORDS = 30000
dataset = 'mercado-livre-pt'

sentence_max_len = 82
batch_size = 512
biLSTM = True
epochs=30
stopwords_lang = None
gpu=1
lr=1e-3
clipping_value=0.25
save_name='bilstm-pytorch-word2vec-tweets-embeddings'
patience=5

# %%
BASE_PATH_TO_MODELS = {"virtual-operator": PATH_TO_VIRTUAL_OPERATOR_MODELS, "agent-benchmark": PATH_TO_AGENT_BENCHMARK_MODELS, "mercado-livre-pt": PATH_TO_ML_PT_MODELS}
FULL_PATH_TO_MODELS = join(BASE_PATH_TO_MODELS[dataset], "bilstm-classifier")

# %%
def _init_fn(worker_id):
    np.random.seed(seed)

# %%
def read_data(dataset, subset):
    BASE_PATH_TO_DATASET = {"virtual-operator": PATH_TO_VIRTUAL_OPERATOR_DATA, "agent-benchmark": PATH_TO_AGENT_BENCHMARK_DATA, "mercado-livre-pt": PATH_TO_ML_PT_DATA}
    BASE_PATH_TO_DATASET = {"train": join(BASE_PATH_TO_DATASET[dataset], "train.csv"), "val": join(BASE_PATH_TO_DATASET[dataset], "val.csv"), "test": join(BASE_PATH_TO_DATASET[dataset], "test.csv")}
    FULL_PATH_TO_DATASET = BASE_PATH_TO_DATASET[subset]
    
    if dataset == "mercado-livre-pt":
        sep=","
    else:
        sep=";"
    data = pd.read_csv(FULL_PATH_TO_DATASET, sep=sep, names =['utterance','label'], header=None, dtype={'utterance':str, 'label': str} )
    return data

# %%
train_df = read_data(dataset, "train")
val_df = read_data(dataset, "val")

# %%
voc = Vocabulary('CNN', stopwords_lang)
voc.build_vocab(train_df['utterance'].tolist() +  val_df['utterance'].tolist(), MAX_WORDS)
embedding_weights = voc.load_embeddings(EMBEDDINGS_FILE, EMBEDDING_DIM)
if voc.num_words < MAX_WORDS or MAX_WORDS == 0:
    MAX_WORDS = voc.num_words
# Out:
# 17400 tokens not found in vocabulary.

# %%
embedding_weights.size()
# Out:
# torch.Size([30000, 300])

# %%
train_corpus = NLPDataset(dataset, "train", sentence_max_len, vocab= voc)
labels_dict = train_corpus.labels_dict
val_corpus = NLPDataset(dataset, "val", sentence_max_len, labels_dict = labels_dict, vocab= voc)

# %%
train_dataloader = DataLoader(
            train_corpus,
            sampler = RandomSampler(train_corpus),
            batch_size = batch_size,
            pin_memory=True,
            #shuffle=True,
            worker_init_fn=_init_fn,
            num_workers=0
)

validation_dataloader = DataLoader(
            val_corpus,
            sampler = RandomSampler(val_corpus),
            batch_size = batch_size,
            pin_memory=True,
            #shuffle=True,
            worker_init_fn=_init_fn,
            num_workers=0
)

# %%
#del model
torch.cuda.empty_cache()

# %%
def seed_everything(seed=10):
    random.seed(seed)
    os.environ['PYTHONHASHSEED'] = str(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    torch.backends.cudnn.deterministic = True

# %%
seed_everything()

# %%
device = torch.device(f"cuda:{gpu}")

# %%
class LSTMNet(nn.Module):
    def __init__(self, device, num_classes, num_features, criterion, embedding_dim, bidirectional, embedding_weights=None):
        super(LSTMNet, self).__init__()
        self.criterion = criterion
        self.embedding_dim = embedding_dim
        self.lstm_units = embedding_dim
        self.lstm_act = nn.Tanh()
        self.num_directions = 2 if bidirectional else 1
        self.device = device
        self.n_layers = 1
        self.embedding = nn.Embedding(num_features, embedding_dim, padding_idx = 0)
        
        if(embedding_weights is not None):
            print("Embedding layer Weights won't be updated.")
            #self.embedding.from_pretrained(embedding_weights, freeze=True)
            self.embedding.load_state_dict({'weight': embedding_weights})
            self.embedding.weight.requires_grad = False
        else:
            self.embedding.weight.data = torch.zeros(self.embedding.weight.data.size())
            self.embedding.weight.requires_grad = True

        self.lstm = nn.LSTM(embedding_dim, self.lstm_units, num_layers=self.n_layers, bidirectional=bidirectional, batch_first=True)

        self.dropout = nn.Dropout(0.2)       
        self.linear = nn.Linear(self.num_directions * self.lstm_units, num_classes)   
        self.init_weights()
        
    def forward(self, x, y):

        # lstm step => then ONLY take the sequence's final timetep to pass into the linear/dense layer
        # Note: lstm_out contains outputs for every step of the sequence we are looping over (for BPTT)
        # but we just need the output of the last step of the sequence, aka lstm_out[-1]
        #print("x input:", x.size())
        #set_trace()
        x = self.embedding(x)
        #print("embeddings:", x.size())
        x_, (h_n, c_n) = self.lstm(x)
        h = x_[:,-0,:]
        #h = self.lstm_act(h)
        '''        
        if self.num_directions == 2:
            h = torch.cat((h_n[-2, :, :], h_n[-1, :, :]), dim=1)
        else:
            h = h_n[-1, :, :]
        '''
        #print("h before activation:", h.size())
        #print("h after activation:", h.size())
        output = self.dropout(h)
        output = self.linear(output)
        #print("output after linear:", output.size())
        loss = self.criterion(output.squeeze(), y)
        #print("loss:", loss.size())
        return loss,output
    
    def init_weights(self):  
        nn.init.xavier_normal_(self.lstm.weight_hh_l0)
        nn.init.xavier_normal_(self.lstm.weight_ih_l0)
        nn.init.xavier_normal_(self.linear.weight.data)
       
        for name, param in self.lstm.named_parameters():
            if 'bias' in name:
                nn.init.constant_(param, 0.0)
            elif 'weight_ih' in name:
                nn.init.kaiming_normal_(param)
            elif 'weight_hh' in name:
                nn.init.orthogonal_(param)

# %%
criterion = torch.nn.CrossEntropyLoss()
model = LSTMNet(device, train_corpus.num_labels, MAX_WORDS, criterion, EMBEDDING_DIM, biLSTM, embedding_weights)
# Out:
# Embedding layer Weights won't be updated.

# %%
model = model.to(device)
optimizer = Adam(model.parameters(),lr, betas=(0.7, 0.999))

# %%
embeddings_clone = model.embedding.weight.clone()

# %%
torch.equal(embeddings_clone,model.embedding.weight)
# Out:
# True

# %%
embeddings_clone
# Out:
# tensor([[ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#         [ 1.8510, -0.1590, -0.4167,  ..., -2.2873,  1.6216, -0.8041],
#         [ 1.8510, -0.1590, -0.4167,  ..., -2.2873,  1.6216, -0.8041],
#         ...,
#         [ 0.6787,  0.0442,  1.8077,  ..., -0.0784, -0.6259,  0.1017],
#         [ 0.6787,  0.0442,  1.8077,  ..., -0.0784, -0.6259,  0.1017],
#         [ 0.6787,  0.0442,  1.8077,  ..., -0.0784, -0.6259,  0.1017]],
#        device='cuda:1')

# %%
def get_accuracy_from_logits(logits, labels):
    acc = (labels.cpu() == logits.cpu().argmax(-1)).float().detach().numpy()
    return float(100 * acc.sum() / len(acc))

# %%
scheduler = ReduceLROnPlateau(optimizer, mode='min', patience=3,verbose=True, factor=0.1)

best_epoch = -1
last_saved_model = ""
training_stats = []
global_step = 0
best_val_acc = float("-inf")
best_model_wts = None
best_curr_val = 0

for epoch_i in range(0, epochs):
    print("")
    print('======== Epoch {:} / {:} ========'.format(epoch_i + 1, epochs))
    print('Training...')
    total_train_loss = 0
    model.train()
    for step, batch in enumerate(train_dataloader):
         # Progress update every 40 batches.
        if step % 40 == 0 and not step == 0:
            print('  Batch {:>5,}  of  {:>5,}.    .'.format(step, len(train_dataloader)))
        b_input_ids = batch[0]
        b_labels = batch[1].clone().detach().to(device)
        b_input_ids = b_input_ids.clone().detach().to(device).long()
        loss, logits= model(b_input_ids, b_labels)
        step_loss = loss.item()
        model.zero_grad()
        loss.backward()
        torch.nn.utils.clip_grad_norm_(model.parameters(), clipping_value)
        optimizer.step()
        

        if step % 40 == 0 and not step == 0:
            print("  step loss: {0:.2f}".format(step_loss))
        total_train_loss += step_loss
        global_step += 1
    avg_train_loss = total_train_loss / len(train_dataloader)
    # Measure how long this epoch took.
    print("")
    print("  Average training loss: {0:.2f}".format(avg_train_loss))

    print("")
    print("Running Validation...")
    model.eval()

    # Tracking variables
    total_eval_accuracy = 0.0
    total_eval_loss = 0
    nb_eval_steps = 0
    for step, batch in enumerate(validation_dataloader):
        b_input_ids = batch[0]
        b_input_ids = b_input_ids.clone().detach().to(device).long()
        b_labels = batch[1].to(device)
        with torch.no_grad():
            # Forward pass, calculate logit predictions.
            loss, logits = model(b_input_ids, b_labels)
        total_eval_loss += loss
        batch_acc = get_accuracy_from_logits(logits, b_labels)
        print("Batch accuracy: {0:.2f}".format(batch_acc))
        total_eval_accuracy += batch_acc
    
    # Calculate the average loss over all of the batches.
    avg_val_accuracy = total_eval_accuracy / len(validation_dataloader)
    print("  Accuracy: {0:.2f}".format(avg_val_accuracy))
    
    if avg_val_accuracy > best_val_acc:
        print(f"New best model, saving it!")
        if avg_val_accuracy > best_curr_val:
            best_curr_val = avg_val_accuracy
        if last_saved_model:
            shutil.rmtree(last_saved_model)
        model_path = Path(
            FULL_PATH_TO_MODELS,
            f"base-dataset-{dataset}-{save_name}"
        )
        last_saved_model = model_path
        model_path.mkdir(parents=True, exist_ok=True)
        best_val_acc = avg_val_accuracy
        torch.save(model, join(model_path, "best-model.pth"))
        best_epoch = epoch_i
        n_epochs_no_improvement = 0
    elif avg_val_accuracy > best_curr_val:
        best_curr_val = avg_val_accuracy
        n_epochs_no_improvement = 0
    else:
        n_epochs_no_improvement += 1
        print(f"The model does not improve for {n_epochs_no_improvement} epochs!")

    if n_epochs_no_improvement > patience:
        print(f"====>Stopping training, the model did not improve for {n_epochs_no_improvement}\n====>Best epoch: {best_epoch + 1}.")
        break
    scheduler.step(total_eval_loss)
print("")
print("Training complete!")
# Out:
# ======== Epoch 1 / 30 ========
# Training...
#   Batch    40  of    975.    .
#   step loss: 3.72
#   Batch    80  of    975.    .
#   step loss: 2.62
#   Batch   120  of    975.    .
#   step loss: 2.14
#   Batch   160  of    975.    .
#   step loss: 1.71
#   Batch   200  of    975.    .
#   step loss: 1.54
#   Batch   240  of    975.    .
#   step loss: 1.38
#   Batch   280  of    975.    .
#   step loss: 1.16
#   Batch   320  of    975.    .
#   step loss: 1.28
#   Batch   360  of    975.    .
#   step loss: 1.32
#   Batch   400  of    975.    .
#   step loss: 1.12
#   Batch   440  of    975.    .
#   step loss: 1.16
#   Batch   480  of    975.    .
#   step loss: 1.09
#   Batch   520  of    975.    .
#   step loss: 0.97
#   Batch   560  of    975.    .
#   step loss: 1.09
#   Batch   600  of    975.    .
#   step loss: 0.97
#   Batch   640  of    975.    .
#   step loss: 0.98
#   Batch   680  of    975.    .
#   step loss: 0.90
#   Batch   720  of    975.    .
#   step loss: 0.84
#   Batch   760  of    975.    .
#   step loss: 0.77
#   Batch   800  of    975.    .
#   step loss: 0.89
#   Batch   840  of    975.    .
#   step loss: 0.80
#   Batch   880  of    975.    .
#   step loss: 0.81
#   Batch   920  of    975.    .
#   step loss: 0.80
#   Batch   960  of    975.    .
#   step loss: 0.65
#
#   Average training loss: 1.38
#
# Running Validation...
# Batch accuracy: 84.57
# Batch accuracy: 81.84
# Batch accuracy: 87.11
# Batch accuracy: 86.91
# Batch accuracy: 80.86
# Batch accuracy: 83.98
# Batch accuracy: 84.18
# Batch accuracy: 85.35
# Batch accuracy: 83.40
# Batch accuracy: 85.35
# Batch accuracy: 88.48
# Batch accuracy: 85.74
# Batch accuracy: 84.57
# Batch accuracy: 88.48
# Batch accuracy: 85.35
# Batch accuracy: 82.62
# Batch accuracy: 86.52
# Batch accuracy: 84.18
# Batch accuracy: 81.45
# Batch accuracy: 84.38
# Batch accuracy: 85.16
# Batch accuracy: 86.52
# Batch accuracy: 86.33
# Batch accuracy: 85.16
# Batch accuracy: 88.28
# Batch accuracy: 82.42
# Batch accuracy: 86.13
# Batch accuracy: 83.59
# Batch accuracy: 87.30
# Batch accuracy: 84.57
# Batch accuracy: 84.57
# Batch accuracy: 87.50
# Batch accuracy: 87.30
# Batch accuracy: 87.70
# Batch accuracy: 86.91
# Batch accuracy: 84.77
# Batch accuracy: 83.98
# Batch accuracy: 84.18
# Batch accuracy: 85.16
# Batch accuracy: 86.52
# Batch accuracy: 82.62
# Batch accuracy: 86.91
# Batch accuracy: 86.13
# Batch accuracy: 85.35
# Batch accuracy: 83.59
# Batch accuracy: 85.74
# Batch accuracy: 83.01
# Batch accuracy: 84.38
# Batch accuracy: 85.55
# Batch accuracy: 87.50
# Batch accuracy: 84.96
# Batch accuracy: 85.55
# Batch accuracy: 85.55
# Batch accuracy: 84.96
# Batch accuracy: 85.35
# Batch accuracy: 87.70
# Batch accuracy: 84.38
# Batch accuracy: 84.96
# Batch accuracy: 86.72
# Batch accuracy: 85.16
# Batch accuracy: 86.13
# Batch accuracy: 82.23
# Batch accuracy: 85.94
# Batch accuracy: 83.98
# Batch accuracy: 84.18
# Batch accuracy: 85.16
# Batch accuracy: 86.13
# Batch accuracy: 86.72
# Batch accuracy: 86.52
# Batch accuracy: 82.81
# Batch accuracy: 86.72
# Batch accuracy: 81.45
# Batch accuracy: 85.55
# Batch accuracy: 88.28
# Batch accuracy: 84.96
# Batch accuracy: 85.55
# Batch accuracy: 83.59
# Batch accuracy: 87.50
# Batch accuracy: 84.57
# Batch accuracy: 84.96
# Batch accuracy: 84.77
# Batch accuracy: 83.20
# Batch accuracy: 86.13
# Batch accuracy: 86.72
# Batch accuracy: 84.57
# Batch accuracy: 83.98
# Batch accuracy: 86.33
# Batch accuracy: 87.11
# Batch accuracy: 87.11
# Batch accuracy: 85.94
# Batch accuracy: 86.91
# Batch accuracy: 86.72
# Batch accuracy: 84.96
# Batch accuracy: 86.13
# Batch accuracy: 84.77
# Batch accuracy: 85.16
# Batch accuracy: 85.35
# Batch accuracy: 84.18
# Batch accuracy: 84.96
# Batch accuracy: 86.52
# Batch accuracy: 86.91
# Batch accuracy: 84.57
# Batch accuracy: 88.09
# Batch accuracy: 83.59
# Batch accuracy: 85.74
# Batch accuracy: 84.18
# Batch accuracy: 84.96
# Batch accuracy: 85.16
# Batch accuracy: 83.87
#   Accuracy: 85.29
# New best model, saving it!
#
# ======== Epoch 2 / 30 ========
# Training...
#   Batch    40  of    975.    .
#   step loss: 0.74
#   Batch    80  of    975.    .
#   step loss: 0.60
#   Batch   120  of    975.    .
#   step loss: 0.60
#   Batch   160  of    975.    .
#   step loss: 0.52
#   Batch   200  of    975.    .
#   step loss: 0.56
#   Batch   240  of    975.    .
#   step loss: 0.59
#   Batch   280  of    975.    .
#   step loss: 0.61
#   Batch   320  of    975.    .
#   step loss: 0.67
#   Batch   360  of    975.    .
#   step loss: 0.74
#   Batch   400  of    975.    .
#   step loss: 0.68
#   Batch   440  of    975.    .
#   step loss: 0.58
#   Batch   480  of    975.    .
#   step loss: 0.53
#   Batch   520  of    975.    .
#   step loss: 0.52
#   Batch   560  of    975.    .
#   step loss: 0.76
#   Batch   600  of    975.    .
#   step loss: 0.51
#   Batch   640  of    975.    .
#   step loss: 0.54
#   Batch   680  of    975.    .
#   step loss: 0.54
#   Batch   720  of    975.    .
#   step loss: 0.47
#   Batch   760  of    975.    .
#   step loss: 0.61
#   Batch   800  of    975.    .
#   step loss: 0.53
#   Batch   840  of    975.    .
#   step loss: 0.45
#   Batch   880  of    975.    .
#   step loss: 0.54
#   Batch   920  of    975.    .
#   step loss: 0.53
#   Batch   960  of    975.    .
#   step loss: 0.53
#
#   Average training loss: 0.59
#
# Running Validation...
# Batch accuracy: 87.70
# Batch accuracy: 86.33
# Batch accuracy: 88.87
# Batch accuracy: 86.72
# Batch accuracy: 88.28
# Batch accuracy: 89.06
# Batch accuracy: 88.48
# Batch accuracy: 90.43
# Batch accuracy: 88.48
# Batch accuracy: 88.09
# Batch accuracy: 89.06
# Batch accuracy: 87.11
# Batch accuracy: 87.89
# Batch accuracy: 86.91
# Batch accuracy: 88.87
# Batch accuracy: 85.74
# Batch accuracy: 88.09
# Batch accuracy: 87.70
# Batch accuracy: 89.84
# Batch accuracy: 85.55
# Batch accuracy: 88.67
# Batch accuracy: 87.30
# Batch accuracy: 87.89
# Batch accuracy: 91.60
# Batch accuracy: 89.06
# Batch accuracy: 90.04
# Batch accuracy: 87.30
# Batch accuracy: 89.84
# Batch accuracy: 87.11
# Batch accuracy: 88.28
# Batch accuracy: 85.94
# Batch accuracy: 88.09
# Batch accuracy: 88.48
# Batch accuracy: 89.65
# Batch accuracy: 89.45
# Batch accuracy: 88.48
# Batch accuracy: 89.06
# Batch accuracy: 87.50
# Batch accuracy: 88.67
# Batch accuracy: 87.50
# Batch accuracy: 85.35
# Batch accuracy: 91.21
# Batch accuracy: 87.50
# Batch accuracy: 88.67
# Batch accuracy: 86.72
# Batch accuracy: 90.04
# Batch accuracy: 86.72
# Batch accuracy: 85.55
# Batch accuracy: 88.67
# Batch accuracy: 85.35
# Batch accuracy: 88.87
# Batch accuracy: 88.87
# Batch accuracy: 86.72
# Batch accuracy: 88.67
# Batch accuracy: 88.87
# Batch accuracy: 86.33
# Batch accuracy: 89.84
# Batch accuracy: 86.91
# Batch accuracy: 86.33
# Batch accuracy: 89.45
# Batch accuracy: 86.72
# Batch accuracy: 88.28
# Batch accuracy: 88.09
# Batch accuracy: 88.48
# Batch accuracy: 89.65
# Batch accuracy: 87.30
# Batch accuracy: 87.50
# Batch accuracy: 89.06
# Batch accuracy: 86.72
# Batch accuracy: 88.09
# Batch accuracy: 87.70
# Batch accuracy: 87.89
# Batch accuracy: 88.28
# Batch accuracy: 89.26
# Batch accuracy: 87.70
# Batch accuracy: 90.82
# Batch accuracy: 88.67
# Batch accuracy: 89.45
# Batch accuracy: 89.06
# Batch accuracy: 87.11
# Batch accuracy: 88.09
# Batch accuracy: 89.45
# Batch accuracy: 89.26
# Batch accuracy: 87.50
# Batch accuracy: 87.70
# Batch accuracy: 87.50
# Batch accuracy: 88.28
# Batch accuracy: 87.89
# Batch accuracy: 88.48
# Batch accuracy: 87.70
# Batch accuracy: 88.87
# Batch accuracy: 90.62
# Batch accuracy: 86.13
# Batch accuracy: 90.82
# Batch accuracy: 88.09
# Batch accuracy: 88.87
# Batch accuracy: 87.89
# Batch accuracy: 89.65
# Batch accuracy: 90.62
# Batch accuracy: 84.96
# Batch accuracy: 87.30
# Batch accuracy: 88.28
# Batch accuracy: 87.70
# Batch accuracy: 88.28
# Batch accuracy: 89.65
# Batch accuracy: 90.62
# Batch accuracy: 89.84
# Batch accuracy: 87.30
# Batch accuracy: 91.94
#   Accuracy: 88.26
# New best model, saving it!
#
# ======== Epoch 3 / 30 ========
# Training...
#   Batch    40  of    975.    .
#   step loss: 0.38
#   Batch    80  of    975.    .
#   step loss: 0.41
#   Batch   120  of    975.    .
#   step loss: 0.46
#   Batch   160  of    975.    .
#   step loss: 0.45
#   Batch   200  of    975.    .
#   step loss: 0.38
#   Batch   240  of    975.    .
#   step loss: 0.47
#   Batch   280  of    975.    .
#   step loss: 0.40
#   Batch   320  of    975.    .
#   step loss: 0.42
#   Batch   360  of    975.    .
#   step loss: 0.39
#   Batch   400  of    975.    .
#   step loss: 0.38
#   Batch   440  of    975.    .
#   step loss: 0.46
#   Batch   480  of    975.    .
#   step loss: 0.45
#   Batch   520  of    975.    .
#   step loss: 0.45
#   Batch   560  of    975.    .
#   step loss: 0.48
#   Batch   600  of    975.    .
#   step loss: 0.47
#   Batch   640  of    975.    .
#   step loss: 0.42
#   Batch   680  of    975.    .
#   step loss: 0.41
#   Batch   720  of    975.    .
#   step loss: 0.49
#   Batch   760  of    975.    .
#   step loss: 0.48
#   Batch   800  of    975.    .
#   step loss: 0.36
#   Batch   840  of    975.    .
#   step loss: 0.41
#   Batch   880  of    975.    .
#   step loss: 0.46
#   Batch   920  of    975.    .
#   step loss: 0.37
#   Batch   960  of    975.    .
#   step loss: 0.40
#
#   Average training loss: 0.44
#
# Running Validation...
# Batch accuracy: 88.67
# Batch accuracy: 89.65
# Batch accuracy: 91.41
# Batch accuracy: 87.89
# Batch accuracy: 88.28
# Batch accuracy: 87.89
# Batch accuracy: 90.82
# Batch accuracy: 88.09
# Batch accuracy: 87.70
# Batch accuracy: 89.26
# Batch accuracy: 89.45
# Batch accuracy: 92.58
# Batch accuracy: 90.04
# Batch accuracy: 89.84
# Batch accuracy: 88.48
# Batch accuracy: 91.02
# Batch accuracy: 87.50
# Batch accuracy: 89.45
# Batch accuracy: 89.45
# Batch accuracy: 90.43
# Batch accuracy: 88.87
# Batch accuracy: 87.30
# Batch accuracy: 89.06
# Batch accuracy: 89.45
# Batch accuracy: 91.60
# Batch accuracy: 91.80
# Batch accuracy: 88.09
# Batch accuracy: 88.67
# Batch accuracy: 90.23
# Batch accuracy: 87.11
# Batch accuracy: 88.67
# Batch accuracy: 90.04
# Batch accuracy: 88.48
# Batch accuracy: 87.89
# Batch accuracy: 90.62
# Batch accuracy: 90.04
# Batch accuracy: 90.23
# Batch accuracy: 88.67
# Batch accuracy: 89.45
# Batch accuracy: 90.04
# Batch accuracy: 89.65
# Batch accuracy: 92.58
# Batch accuracy: 91.21
# Batch accuracy: 89.45
# Batch accuracy: 89.84
# Batch accuracy: 88.09
# Batch accuracy: 90.04
# Batch accuracy: 91.80
# Batch accuracy: 86.72
# Batch accuracy: 91.21
# Batch accuracy: 88.67
# Batch accuracy: 89.45
# Batch accuracy: 89.84
# Batch accuracy: 87.70
# Batch accuracy: 88.87
# Batch accuracy: 89.06
# Batch accuracy: 87.50
# Batch accuracy: 90.82
# Batch accuracy: 86.91
# Batch accuracy: 89.06
# Batch accuracy: 90.43
# Batch accuracy: 91.02
# Batch accuracy: 89.65
# Batch accuracy: 89.84
# Batch accuracy: 91.02
# Batch accuracy: 89.84
# Batch accuracy: 90.82
# Batch accuracy: 89.06
# Batch accuracy: 86.91
# Batch accuracy: 90.23
# Batch accuracy: 91.41
# Batch accuracy: 89.45
# Batch accuracy: 89.45
# Batch accuracy: 88.48
# Batch accuracy: 89.26
# Batch accuracy: 89.45
# Batch accuracy: 88.09
# Batch accuracy: 88.48
# Batch accuracy: 89.65
# Batch accuracy: 88.09
# Batch accuracy: 90.82
# Batch accuracy: 91.60
# Batch accuracy: 88.28
# Batch accuracy: 90.04
# Batch accuracy: 90.82
# Batch accuracy: 88.87
# Batch accuracy: 89.26
# Batch accuracy: 89.84
# Batch accuracy: 87.30
# Batch accuracy: 87.70
# Batch accuracy: 90.04
# Batch accuracy: 90.43
# Batch accuracy: 89.06
# Batch accuracy: 89.06
# Batch accuracy: 89.26
# Batch accuracy: 89.65
# Batch accuracy: 89.45
# Batch accuracy: 90.04
# Batch accuracy: 89.26
# Batch accuracy: 88.87
# Batch accuracy: 88.87
# Batch accuracy: 88.28
# Batch accuracy: 89.45
# Batch accuracy: 89.26
# Batch accuracy: 89.45
# Batch accuracy: 90.23
# Batch accuracy: 89.45
# Batch accuracy: 89.06
# Batch accuracy: 90.32
#   Accuracy: 89.43
# New best model, saving it!
#
# ======== Epoch 4 / 30 ========
# Training...
#   Batch    40  of    975.    .
#   step loss: 0.26
#   Batch    80  of    975.    .
#   step loss: 0.44
#   Batch   120  of    975.    .
#   step loss: 0.36
#   Batch   160  of    975.    .
#   step loss: 0.36
#   Batch   200  of    975.    .
#   step loss: 0.32
#   Batch   240  of    975.    .
#   step loss: 0.30
#   Batch   280  of    975.    .
#   step loss: 0.30
#   Batch   320  of    975.    .
#   step loss: 0.35
#   Batch   360  of    975.    .
#   step loss: 0.25
#   Batch   400  of    975.    .
#   step loss: 0.34
#   Batch   440  of    975.    .
#   step loss: 0.48
#   Batch   480  of    975.    .
#   step loss: 0.33
#   Batch   520  of    975.    .
#   step loss: 0.30
#   Batch   560  of    975.    .
#   step loss: 0.35
#   Batch   600  of    975.    .
#   step loss: 0.42
#   Batch   640  of    975.    .
#   step loss: 0.39
#   Batch   680  of    975.    .
#   step loss: 0.37
#   Batch   720  of    975.    .
#   step loss: 0.36
#   Batch   760  of    975.    .
#   step loss: 0.39
#   Batch   800  of    975.    .
#   step loss: 0.29
#   Batch   840  of    975.    .
#   step loss: 0.37
#   Batch   880  of    975.    .
#   step loss: 0.39
#   Batch   920  of    975.    .
#   step loss: 0.48
#   Batch   960  of    975.    .
#   step loss: 0.37
#
#   Average training loss: 0.36
#
# Running Validation...
# Batch accuracy: 88.48
# Batch accuracy: 88.67
# Batch accuracy: 89.65
# Batch accuracy: 91.60
# Batch accuracy: 90.04
# Batch accuracy: 90.43
# Batch accuracy: 89.45
# Batch accuracy: 89.26
# Batch accuracy: 90.82
# Batch accuracy: 91.60
# Batch accuracy: 90.04
# Batch accuracy: 90.23
# Batch accuracy: 89.06
# Batch accuracy: 90.62
# Batch accuracy: 90.23
# Batch accuracy: 88.48
# Batch accuracy: 90.82
# Batch accuracy: 88.67
# Batch accuracy: 90.82
# Batch accuracy: 91.99
# Batch accuracy: 92.97
# Batch accuracy: 91.60
# Batch accuracy: 89.65
# Batch accuracy: 90.43
# Batch accuracy: 90.04
# Batch accuracy: 91.21
# Batch accuracy: 90.82
# Batch accuracy: 88.67
# Batch accuracy: 92.38
# Batch accuracy: 90.43
# Batch accuracy: 90.62
# Batch accuracy: 87.50
# Batch accuracy: 90.23
# Batch accuracy: 90.23
# Batch accuracy: 90.82
# Batch accuracy: 92.38
# Batch accuracy: 88.09
# Batch accuracy: 88.09
# Batch accuracy: 89.26
# Batch accuracy: 88.87
# Batch accuracy: 89.45
# Batch accuracy: 90.62
# Batch accuracy: 89.65
# Batch accuracy: 88.87
# Batch accuracy: 90.04
# Batch accuracy: 88.87
# Batch accuracy: 91.80
# Batch accuracy: 90.23
# Batch accuracy: 90.23
# Batch accuracy: 88.87
# Batch accuracy: 90.04
# Batch accuracy: 88.48
# Batch accuracy: 91.02
# Batch accuracy: 91.21
# Batch accuracy: 89.65
# Batch accuracy: 91.80
# Batch accuracy: 91.41
# Batch accuracy: 90.62
# Batch accuracy: 87.30
# Batch accuracy: 89.84
# Batch accuracy: 89.06
# Batch accuracy: 90.82
# Batch accuracy: 91.02
# Batch accuracy: 89.26
# Batch accuracy: 89.45
# Batch accuracy: 89.65
# Batch accuracy: 89.65
# Batch accuracy: 89.45
# Batch accuracy: 90.82
# Batch accuracy: 90.82
# Batch accuracy: 87.89
# Batch accuracy: 90.23
# Batch accuracy: 93.16
# Batch accuracy: 91.80
# Batch accuracy: 91.21
# Batch accuracy: 91.60
# Batch accuracy: 89.26
# Batch accuracy: 89.06
# Batch accuracy: 90.43
# Batch accuracy: 89.84
# Batch accuracy: 90.04
# Batch accuracy: 91.41
# Batch accuracy: 91.02
# Batch accuracy: 91.02
# Batch accuracy: 89.26
# Batch accuracy: 91.02
# Batch accuracy: 88.87
# Batch accuracy: 91.02
# Batch accuracy: 89.84
# Batch accuracy: 91.60
# Batch accuracy: 90.04
# Batch accuracy: 89.06
# Batch accuracy: 91.02
# Batch accuracy: 89.84
# Batch accuracy: 89.06
# Batch accuracy: 91.21
# Batch accuracy: 89.65
# Batch accuracy: 86.91
# Batch accuracy: 91.41
# Batch accuracy: 88.67
# Batch accuracy: 91.60
# Batch accuracy: 88.87
# Batch accuracy: 89.45
# Batch accuracy: 90.62
# Batch accuracy: 92.19
# Batch accuracy: 89.65
# Batch accuracy: 88.48
# Batch accuracy: 92.38
# Batch accuracy: 90.32
#   Accuracy: 90.14
# New best model, saving it!
#
# ======== Epoch 5 / 30 ========
# Training...
#   Batch    40  of    975.    .
#   step loss: 0.27
#   Batch    80  of    975.    .
#   step loss: 0.19
#   Batch   120  of    975.    .
#   step loss: 0.26
#   Batch   160  of    975.    .
#   step loss: 0.27
#   Batch   200  of    975.    .
#   step loss: 0.29
#   Batch   240  of    975.    .
#   step loss: 0.27
#   Batch   280  of    975.    .
#   step loss: 0.32
#   Batch   320  of    975.    .
#   step loss: 0.32
#   Batch   360  of    975.    .
#   step loss: 0.34
#   Batch   400  of    975.    .
#   step loss: 0.32
#   Batch   440  of    975.    .
#   step loss: 0.36
#   Batch   480  of    975.    .
#   step loss: 0.40
#   Batch   520  of    975.    .
#   step loss: 0.30
#   Batch   560  of    975.    .
#   step loss: 0.27
#   Batch   600  of    975.    .
#   step loss: 0.27
#   Batch   640  of    975.    .
#   step loss: 0.26
#   Batch   680  of    975.    .
#   step loss: 0.30
#   Batch   720  of    975.    .
#   step loss: 0.22
#   Batch   760  of    975.    .
#   step loss: 0.41
#   Batch   800  of    975.    .
#   step loss: 0.32
#   Batch   840  of    975.    .
#   step loss: 0.34
#   Batch   880  of    975.    .
#   step loss: 0.26
#   Batch   920  of    975.    .
#   step loss: 0.26
#   Batch   960  of    975.    .
#   step loss: 0.32
#
#   Average training loss: 0.30
#
# Running Validation...
# Batch accuracy: 91.99
# Batch accuracy: 90.23
# Batch accuracy: 91.60
# Batch accuracy: 90.62
# Batch accuracy: 91.99
# Batch accuracy: 91.41
# Batch accuracy: 91.60
# Batch accuracy: 91.80
# Batch accuracy: 89.45
# Batch accuracy: 90.62
# Batch accuracy: 89.45
# Batch accuracy: 90.82
# Batch accuracy: 91.41
# Batch accuracy: 92.38
# Batch accuracy: 91.41
# Batch accuracy: 91.02
# Batch accuracy: 88.87
# Batch accuracy: 92.97
# Batch accuracy: 91.41
# Batch accuracy: 90.04
# Batch accuracy: 90.43
# Batch accuracy: 88.09
# Batch accuracy: 90.23
# Batch accuracy: 89.65
# Batch accuracy: 88.28
# Batch accuracy: 89.65
# Batch accuracy: 93.75
# Batch accuracy: 90.04
# Batch accuracy: 90.23
# Batch accuracy: 90.23
# Batch accuracy: 91.02
# Batch accuracy: 91.02
# Batch accuracy: 90.43
# Batch accuracy: 89.65
# Batch accuracy: 90.23
# Batch accuracy: 90.04
# Batch accuracy: 90.23
# Batch accuracy: 89.06
# Batch accuracy: 89.84
# Batch accuracy: 90.62
# Batch accuracy: 91.21
# Batch accuracy: 90.23
# Batch accuracy: 91.02
# Batch accuracy: 90.43
# Batch accuracy: 88.87
# Batch accuracy: 92.77
# Batch accuracy: 87.50
# Batch accuracy: 89.84
# Batch accuracy: 89.06
# Batch accuracy: 91.02
# Batch accuracy: 90.04
# Batch accuracy: 89.65
# Batch accuracy: 89.45
# Batch accuracy: 87.11
# Batch accuracy: 90.82
# Batch accuracy: 90.43
# Batch accuracy: 90.62
# Batch accuracy: 89.45
# Batch accuracy: 89.45
# Batch accuracy: 90.62
# Batch accuracy: 90.04
# Batch accuracy: 90.62
# Batch accuracy: 90.04
# Batch accuracy: 90.62
# Batch accuracy: 91.99
# Batch accuracy: 90.62
# Batch accuracy: 92.19
# Batch accuracy: 91.02
# Batch accuracy: 91.60
# Batch accuracy: 90.04
# Batch accuracy: 90.23
# Batch accuracy: 88.67
# Batch accuracy: 91.80
# Batch accuracy: 90.43
# Batch accuracy: 90.82
# Batch accuracy: 90.23
# Batch accuracy: 89.65
# Batch accuracy: 91.21
# Batch accuracy: 91.21
# Batch accuracy: 90.82
# Batch accuracy: 90.23
# Batch accuracy: 90.43
# Batch accuracy: 88.28
# Batch accuracy: 89.26
# Batch accuracy: 93.16
# Batch accuracy: 90.62
# Batch accuracy: 90.43
# Batch accuracy: 93.16
# Batch accuracy: 89.65
# Batch accuracy: 90.23
# Batch accuracy: 90.62
# Batch accuracy: 91.80
# Batch accuracy: 90.43
# Batch accuracy: 89.45
# Batch accuracy: 88.87
# Batch accuracy: 91.02
# Batch accuracy: 91.41
# Batch accuracy: 89.84
# Batch accuracy: 91.41
# Batch accuracy: 89.65
# Batch accuracy: 91.41
# Batch accuracy: 88.48
# Batch accuracy: 89.06
# Batch accuracy: 90.43
# Batch accuracy: 90.23
# Batch accuracy: 90.23
# Batch accuracy: 87.70
# Batch accuracy: 87.89
# Batch accuracy: 91.13
#   Accuracy: 90.40
# New best model, saving it!
#
# ======== Epoch 6 / 30 ========
# Training...
#   Batch    40  of    975.    .
#   step loss: 0.26
#   Batch    80  of    975.    .
#   step loss: 0.26
#   Batch   120  of    975.    .
#   step loss: 0.25
#   Batch   160  of    975.    .
#   step loss: 0.24
#   Batch   200  of    975.    .
#   step loss: 0.22
#   Batch   240  of    975.    .
#   step loss: 0.21
#   Batch   280  of    975.    .
#   step loss: 0.25
#   Batch   320  of    975.    .
#   step loss: 0.30
#   Batch   360  of    975.    .
#   step loss: 0.20
#   Batch   400  of    975.    .
#   step loss: 0.27
#   Batch   440  of    975.    .
#   step loss: 0.22
#   Batch   480  of    975.    .
#   step loss: 0.17
#   Batch   520  of    975.    .
#   step loss: 0.22
#   Batch   560  of    975.    .
#   step loss: 0.22
#   Batch   600  of    975.    .
#   step loss: 0.25
#   Batch   640  of    975.    .
#   step loss: 0.28
#   Batch   680  of    975.    .
#   step loss: 0.23
#   Batch   720  of    975.    .
#   step loss: 0.26
#   Batch   760  of    975.    .
#   step loss: 0.26
#   Batch   800  of    975.    .
#   step loss: 0.22
#   Batch   840  of    975.    .
#   step loss: 0.26
#   Batch   880  of    975.    .
#   step loss: 0.24
#   Batch   920  of    975.    .
#   step loss: 0.32
#   Batch   960  of    975.    .
#   step loss: 0.25
#
#   Average training loss: 0.25
#
# Running Validation...
# Batch accuracy: 91.02
# Batch accuracy: 91.41
# Batch accuracy: 91.99
# Batch accuracy: 90.82
# Batch accuracy: 89.26
# Batch accuracy: 88.67
# Batch accuracy: 92.19
# Batch accuracy: 90.04
# Batch accuracy: 91.02
# Batch accuracy: 91.60
# Batch accuracy: 90.04
# Batch accuracy: 88.48
# Batch accuracy: 88.87
# Batch accuracy: 91.02
# Batch accuracy: 88.09
# Batch accuracy: 91.41
# Batch accuracy: 89.06
# Batch accuracy: 92.19
# Batch accuracy: 90.82
# Batch accuracy: 90.82
# Batch accuracy: 94.34
# Batch accuracy: 92.38
# Batch accuracy: 89.65
# Batch accuracy: 88.67
# Batch accuracy: 90.82
# Batch accuracy: 89.26
# Batch accuracy: 92.77
# Batch accuracy: 91.80
# Batch accuracy: 89.65
# Batch accuracy: 90.82
# Batch accuracy: 90.82
# Batch accuracy: 91.41
# Batch accuracy: 90.23
# Batch accuracy: 91.21
# Batch accuracy: 90.23
# Batch accuracy: 92.19
# Batch accuracy: 89.06
# Batch accuracy: 92.19
# Batch accuracy: 90.23
# Batch accuracy: 88.48
# Batch accuracy: 89.06
# Batch accuracy: 92.19
# Batch accuracy: 92.38
# Batch accuracy: 88.67
# Batch accuracy: 92.58
# Batch accuracy: 90.04
# Batch accuracy: 91.02
# Batch accuracy: 91.02
# Batch accuracy: 92.58
# Batch accuracy: 89.65
# Batch accuracy: 88.09
# Batch accuracy: 89.26
# Batch accuracy: 91.41
# Batch accuracy: 89.84
# Batch accuracy: 90.62
# Batch accuracy: 91.41
# Batch accuracy: 90.62
# Batch accuracy: 88.48
# Batch accuracy: 91.02
# Batch accuracy: 89.06
# Batch accuracy: 90.23
# Batch accuracy: 89.45
# Batch accuracy: 89.26
# Batch accuracy: 89.84
# Batch accuracy: 91.21
# Batch accuracy: 91.99
# Batch accuracy: 89.06
# Batch accuracy: 92.97
# Batch accuracy: 91.02
# Batch accuracy: 90.82
# Batch accuracy: 89.84
# Batch accuracy: 90.23
# Batch accuracy: 91.60
# Batch accuracy: 88.87
# Batch accuracy: 90.43
# Batch accuracy: 88.67
# Batch accuracy: 90.62
# Batch accuracy: 90.82
# Batch accuracy: 90.82
# Batch accuracy: 90.62
# Batch accuracy: 89.65
# Batch accuracy: 91.02
# Batch accuracy: 90.62
# Batch accuracy: 91.80
# Batch accuracy: 89.65
# Batch accuracy: 89.65
# Batch accuracy: 91.60
# Batch accuracy: 89.26
# Batch accuracy: 92.19
# Batch accuracy: 91.21
# Batch accuracy: 91.80
# Batch accuracy: 91.02
# Batch accuracy: 91.99
# Batch accuracy: 90.82
# Batch accuracy: 91.41
# Batch accuracy: 90.23
# Batch accuracy: 91.60
# Batch accuracy: 91.41
# Batch accuracy: 90.82
# Batch accuracy: 91.02
# Batch accuracy: 93.75
# Batch accuracy: 90.43
# Batch accuracy: 90.23
# Batch accuracy: 89.26
# Batch accuracy: 91.80
# Batch accuracy: 91.02
# Batch accuracy: 88.48
# Batch accuracy: 89.45
# Batch accuracy: 92.74
#   Accuracy: 90.63
# New best model, saving it!
#
# ======== Epoch 7 / 30 ========
# Training...
#   Batch    40  of    975.    .
#   step loss: 0.20
#   Batch    80  of    975.    .
#   step loss: 0.24
#   Batch   120  of    975.    .
#   step loss: 0.19
#   Batch   160  of    975.    .
#   step loss: 0.16
#   Batch   200  of    975.    .
#   step loss: 0.19
#   Batch   240  of    975.    .
#   step loss: 0.21
#   Batch   280  of    975.    .
#   step loss: 0.23
#   Batch   320  of    975.    .
#   step loss: 0.25
#   Batch   360  of    975.    .
#   step loss: 0.22
#   Batch   400  of    975.    .
#   step loss: 0.27
#   Batch   440  of    975.    .
#   step loss: 0.26
#   Batch   480  of    975.    .
#   step loss: 0.18
#   Batch   520  of    975.    .
#   step loss: 0.23
#   Batch   560  of    975.    .
#   step loss: 0.26
#   Batch   600  of    975.    .
#   step loss: 0.29
#   Batch   640  of    975.    .
#   step loss: 0.27
#   Batch   680  of    975.    .
#   step loss: 0.26
#   Batch   720  of    975.    .
#   step loss: 0.21
#   Batch   760  of    975.    .
#   step loss: 0.19
#   Batch   800  of    975.    .
#   step loss: 0.30
#   Batch   840  of    975.    .
#   step loss: 0.23
#   Batch   880  of    975.    .
#   step loss: 0.24
#   Batch   920  of    975.    .
#   step loss: 0.31
#   Batch   960  of    975.    .
#   step loss: 0.15
#
#   Average training loss: 0.22
#
# Running Validation...
# Batch accuracy: 90.62
# Batch accuracy: 91.02
# Batch accuracy: 89.84
# Batch accuracy: 92.38
# Batch accuracy: 91.99
# Batch accuracy: 87.30
# Batch accuracy: 92.58
# Batch accuracy: 91.99
# Batch accuracy: 91.21
# Batch accuracy: 90.43
# Batch accuracy: 91.41
# Batch accuracy: 89.26
# Batch accuracy: 89.06
# Batch accuracy: 88.67
# Batch accuracy: 91.21
# Batch accuracy: 91.02
# Batch accuracy: 89.06
# Batch accuracy: 90.82
# Batch accuracy: 91.02
# Batch accuracy: 88.28
# Batch accuracy: 89.26
# Batch accuracy: 89.45
# Batch accuracy: 91.60
# Batch accuracy: 92.58
# Batch accuracy: 90.43
# Batch accuracy: 91.21
# Batch accuracy: 89.45
# Batch accuracy: 91.02
# Batch accuracy: 91.02
# Batch accuracy: 90.43
# Batch accuracy: 89.65
# Batch accuracy: 90.62
# Batch accuracy: 91.02
# Batch accuracy: 90.23
# Batch accuracy: 89.84
# Batch accuracy: 92.38
# Batch accuracy: 89.06
# Batch accuracy: 91.21
# Batch accuracy: 91.02
# Batch accuracy: 90.23
# Batch accuracy: 89.45
# Batch accuracy: 92.19
# Batch accuracy: 90.23
# Batch accuracy: 87.30
# Batch accuracy: 91.21
# Batch accuracy: 93.36
# Batch accuracy: 90.23
# Batch accuracy: 89.84
# Batch accuracy: 90.04
# Batch accuracy: 90.82
# Batch accuracy: 90.23
# Batch accuracy: 91.80
# Batch accuracy: 91.41
# Batch accuracy: 91.41
# Batch accuracy: 91.02
# Batch accuracy: 90.62
# Batch accuracy: 90.23
# Batch accuracy: 90.82
# Batch accuracy: 89.06
# Batch accuracy: 89.06
# Batch accuracy: 91.21
# Batch accuracy: 89.65
# Batch accuracy: 89.84
# Batch accuracy: 91.60
# Batch accuracy: 90.43
# Batch accuracy: 88.48
# Batch accuracy: 90.23
# Batch accuracy: 91.41
# Batch accuracy: 91.41
# Batch accuracy: 90.04
# Batch accuracy: 88.48
# Batch accuracy: 90.04
# Batch accuracy: 92.19
# Batch accuracy: 89.06
# Batch accuracy: 90.23
# Batch accuracy: 92.19
# Batch accuracy: 91.21
# Batch accuracy: 91.60
# Batch accuracy: 92.19
# Batch accuracy: 89.84
# Batch accuracy: 90.62
# Batch accuracy: 90.04
# Batch accuracy: 88.87
# Batch accuracy: 88.67
# Batch accuracy: 90.04
# Batch accuracy: 89.65
# Batch accuracy: 91.80
# Batch accuracy: 90.23
# Batch accuracy: 91.02
# Batch accuracy: 91.21
# Batch accuracy: 91.99
# Batch accuracy: 89.65
# Batch accuracy: 90.43
# Batch accuracy: 89.26
# Batch accuracy: 91.60
# Batch accuracy: 92.77
# Batch accuracy: 91.99
# Batch accuracy: 93.36
# Batch accuracy: 90.62
# Batch accuracy: 90.43
# Batch accuracy: 91.60
# Batch accuracy: 92.19
# Batch accuracy: 92.58
# Batch accuracy: 90.43
# Batch accuracy: 91.21
# Batch accuracy: 91.99
# Batch accuracy: 91.80
# Batch accuracy: 91.02
# Batch accuracy: 91.13
#   Accuracy: 90.65
# New best model, saving it!
#
# ======== Epoch 8 / 30 ========
# Training...
#   Batch    40  of    975.    .
#   step loss: 0.22
#   Batch    80  of    975.    .
#   step loss: 0.16
#   Batch   120  of    975.    .
#   step loss: 0.19
#   Batch   160  of    975.    .
#   step loss: 0.18
#   Batch   200  of    975.    .
#   step loss: 0.17
#   Batch   240  of    975.    .
#   step loss: 0.23
#   Batch   280  of    975.    .
#   step loss: 0.27
#   Batch   320  of    975.    .
#   step loss: 0.23
#   Batch   360  of    975.    .
#   step loss: 0.16
#   Batch   400  of    975.    .
#   step loss: 0.16
#   Batch   440  of    975.    .
#   step loss: 0.21
#   Batch   480  of    975.    .
#   step loss: 0.19
#   Batch   520  of    975.    .
#   step loss: 0.24
#   Batch   560  of    975.    .
#   step loss: 0.20
#   Batch   600  of    975.    .
#   step loss: 0.15
#   Batch   640  of    975.    .
#   step loss: 0.23
#   Batch   680  of    975.    .
#   step loss: 0.19
#   Batch   720  of    975.    .
#   step loss: 0.20
#   Batch   760  of    975.    .
#   step loss: 0.18
#   Batch   800  of    975.    .
#   step loss: 0.15
#   Batch   840  of    975.    .
#   step loss: 0.18
#   Batch   880  of    975.    .
#   step loss: 0.22
#   Batch   920  of    975.    .
#   step loss: 0.24
#   Batch   960  of    975.    .
#   step loss: 0.28
#
#   Average training loss: 0.19
#
# Running Validation...
# Batch accuracy: 89.26
# Batch accuracy: 90.43
# Batch accuracy: 92.19
# Batch accuracy: 88.67
# Batch accuracy: 89.06
# Batch accuracy: 91.02
# Batch accuracy: 91.21
# Batch accuracy: 92.58
# Batch accuracy: 90.82
# Batch accuracy: 91.02
# Batch accuracy: 90.43
# Batch accuracy: 91.21
# Batch accuracy: 87.11
# Batch accuracy: 89.65
# Batch accuracy: 90.43
# Batch accuracy: 93.36
# Batch accuracy: 91.60
# Batch accuracy: 90.82
# Batch accuracy: 91.02
# Batch accuracy: 91.21
# Batch accuracy: 91.21
# Batch accuracy: 89.84
# Batch accuracy: 91.80
# Batch accuracy: 89.45
# Batch accuracy: 90.82
# Batch accuracy: 91.80
# Batch accuracy: 89.26
# Batch accuracy: 90.82
# Batch accuracy: 90.23
# Batch accuracy: 89.45
# Batch accuracy: 91.02
# Batch accuracy: 90.62
# Batch accuracy: 92.58
# Batch accuracy: 89.84
# Batch accuracy: 90.23
# Batch accuracy: 94.14
# Batch accuracy: 89.45
# Batch accuracy: 90.04
# Batch accuracy: 90.04
# Batch accuracy: 90.82
# Batch accuracy: 89.06
# Batch accuracy: 90.82
# Batch accuracy: 90.23
# Batch accuracy: 87.89
# Batch accuracy: 91.02
# Batch accuracy: 90.62
# Batch accuracy: 90.23
# Batch accuracy: 89.06
# Batch accuracy: 92.38
# Batch accuracy: 91.41
# Batch accuracy: 90.23
# Batch accuracy: 93.16
# Batch accuracy: 90.43
# Batch accuracy: 91.21
# Batch accuracy: 88.87
# Batch accuracy: 88.48
# Batch accuracy: 89.84
# Batch accuracy: 90.82
# Batch accuracy: 91.41
# Batch accuracy: 90.43
# Batch accuracy: 90.82
# Batch accuracy: 91.21
# Batch accuracy: 91.80
# Batch accuracy: 91.21
# Batch accuracy: 92.58
# Batch accuracy: 92.19
# Batch accuracy: 91.80
# Batch accuracy: 88.28
# Batch accuracy: 91.99
# Batch accuracy: 90.82
# Batch accuracy: 91.41
# Batch accuracy: 91.60
# Batch accuracy: 89.84
# Batch accuracy: 90.43
# Batch accuracy: 88.48
# Batch accuracy: 90.23
# Batch accuracy: 91.99
# Batch accuracy: 90.23
# Batch accuracy: 92.97
# Batch accuracy: 93.95
# Batch accuracy: 91.21
# Batch accuracy: 90.82
# Batch accuracy: 94.14
# Batch accuracy: 90.23
# Batch accuracy: 92.77
# Batch accuracy: 91.21
# Batch accuracy: 91.02
# Batch accuracy: 90.62
# Batch accuracy: 91.21
# Batch accuracy: 91.02
# Batch accuracy: 92.38
# Batch accuracy: 90.62
# Batch accuracy: 93.75
# Batch accuracy: 90.23
# Batch accuracy: 90.82
# Batch accuracy: 88.48
# Batch accuracy: 89.84
# Batch accuracy: 91.99
# Batch accuracy: 90.23
# Batch accuracy: 90.04
# Batch accuracy: 91.99
# Batch accuracy: 89.84
# Batch accuracy: 91.02
# Batch accuracy: 89.65
# Batch accuracy: 90.04
# Batch accuracy: 91.60
# Batch accuracy: 92.19
# Batch accuracy: 91.21
# Batch accuracy: 88.71
#   Accuracy: 90.80
# New best model, saving it!
#
# ======== Epoch 9 / 30 ========
# Training...
#   Batch    40  of    975.    .
#   step loss: 0.17
#   Batch    80  of    975.    .
#   step loss: 0.13
#   Batch   120  of    975.    .
#   step loss: 0.15
#   Batch   160  of    975.    .
#   step loss: 0.17
#   Batch   200  of    975.    .
#   step loss: 0.16
#   Batch   240  of    975.    .
#   step loss: 0.16
#   Batch   280  of    975.    .
#   step loss: 0.13
#   Batch   320  of    975.    .
#   step loss: 0.17
#   Batch   360  of    975.    .
#   step loss: 0.20
#   Batch   400  of    975.    .
#   step loss: 0.19
#   Batch   440  of    975.    .
#   step loss: 0.22
#   Batch   480  of    975.    .
#   step loss: 0.14
#   Batch   520  of    975.    .
#   step loss: 0.18
#   Batch   560  of    975.    .
#   step loss: 0.15
#   Batch   600  of    975.    .
#   step loss: 0.22
#   Batch   640  of    975.    .
#   step loss: 0.19
#   Batch   680  of    975.    .
#   step loss: 0.18
#   Batch   720  of    975.    .
#   step loss: 0.19
#   Batch   760  of    975.    .
#   step loss: 0.20
#   Batch   800  of    975.    .
#   step loss: 0.14
#   Batch   840  of    975.    .
#   step loss: 0.17
#   Batch   880  of    975.    .
#   step loss: 0.21
#   Batch   920  of    975.    .
#   step loss: 0.19
#   Batch   960  of    975.    .
#   step loss: 0.14
#
#   Average training loss: 0.17
#
# Running Validation...
# Batch accuracy: 91.02
# Batch accuracy: 93.16
# Batch accuracy: 92.58
# Batch accuracy: 91.02
# Batch accuracy: 91.80
# Batch accuracy: 88.09
# Batch accuracy: 92.19
# Batch accuracy: 91.99
# Batch accuracy: 90.82
# Batch accuracy: 90.04
# Batch accuracy: 87.70
# Batch accuracy: 90.43
# Batch accuracy: 91.41
# Batch accuracy: 88.67
# Batch accuracy: 91.41
# Batch accuracy: 91.41
# Batch accuracy: 90.43
# Batch accuracy: 88.87
# Batch accuracy: 90.43
# Batch accuracy: 87.70
# Batch accuracy: 90.43
# Batch accuracy: 91.21
# Batch accuracy: 91.60
# Batch accuracy: 92.58
# Batch accuracy: 91.21
# Batch accuracy: 91.02
# Batch accuracy: 90.62
# Batch accuracy: 88.87
# Batch accuracy: 91.41
# Batch accuracy: 91.99
# Batch accuracy: 91.99
# Batch accuracy: 91.41
# Batch accuracy: 92.19
# Batch accuracy: 91.60
# Batch accuracy: 91.02
# Batch accuracy: 90.43
# Batch accuracy: 92.97
# Batch accuracy: 90.82
# Batch accuracy: 89.84
# Batch accuracy: 89.06
# Batch accuracy: 90.82
# Batch accuracy: 89.84
# Batch accuracy: 91.41
# Batch accuracy: 91.41
# Batch accuracy: 91.60
# Batch accuracy: 90.62
# Batch accuracy: 92.19
# Batch accuracy: 91.60
# Batch accuracy: 91.60
# Batch accuracy: 90.04
# Batch accuracy: 91.02
# Batch accuracy: 91.21
# Batch accuracy: 92.38
# Batch accuracy: 90.82
# Batch accuracy: 91.99
# Batch accuracy: 90.62
# Batch accuracy: 90.23
# Batch accuracy: 91.02
# Batch accuracy: 93.55
# Batch accuracy: 91.02
# Batch accuracy: 91.41
# Batch accuracy: 91.80
# Batch accuracy: 91.41
# Batch accuracy: 91.41
# Batch accuracy: 89.84
# Batch accuracy: 91.02
# Batch accuracy: 92.97
# Batch accuracy: 90.04
# Batch accuracy: 89.84
# Batch accuracy: 91.60
# Batch accuracy: 89.65
# Batch accuracy: 89.26
# Batch accuracy: 90.82
# Batch accuracy: 91.02
# Batch accuracy: 90.62
# Batch accuracy: 91.60
# Batch accuracy: 92.38
# Batch accuracy: 91.60
# Batch accuracy: 89.45
# Batch accuracy: 89.84
# Batch accuracy: 91.21
# Batch accuracy: 91.02
# Batch accuracy: 90.43
# Batch accuracy: 92.19
# Batch accuracy: 91.41
# Batch accuracy: 91.41
# Batch accuracy: 90.43
# Batch accuracy: 91.99
# Batch accuracy: 90.43
# Batch accuracy: 90.62
# Batch accuracy: 92.38
# Batch accuracy: 93.16
# Batch accuracy: 90.62
# Batch accuracy: 91.60
# Batch accuracy: 92.97
# Batch accuracy: 92.38
# Batch accuracy: 91.80
# Batch accuracy: 89.26
# Batch accuracy: 89.65
# Batch accuracy: 90.82
# Batch accuracy: 89.65
# Batch accuracy: 90.04
# Batch accuracy: 91.41
# Batch accuracy: 91.60
# Batch accuracy: 91.80
# Batch accuracy: 90.82
# Batch accuracy: 91.41
# Batch accuracy: 89.84
# Batch accuracy: 98.39
#   Accuracy: 91.07
# New best model, saving it!
#
# ======== Epoch 10 / 30 ========
# Training...
#   Batch    40  of    975.    .
#   step loss: 0.11
#   Batch    80  of    975.    .
#   step loss: 0.13
#   Batch   120  of    975.    .
#   step loss: 0.12
#   Batch   160  of    975.    .
#   step loss: 0.14
#   Batch   200  of    975.    .
#   step loss: 0.16
#   Batch   240  of    975.    .
#   step loss: 0.13
#   Batch   280  of    975.    .
#   step loss: 0.15
#   Batch   320  of    975.    .
#   step loss: 0.15
#   Batch   360  of    975.    .
#   step loss: 0.13
#   Batch   400  of    975.    .
#   step loss: 0.17
#   Batch   440  of    975.    .
#   step loss: 0.14
#   Batch   480  of    975.    .
#   step loss: 0.15
#   Batch   520  of    975.    .
#   step loss: 0.12
#   Batch   560  of    975.    .
#   step loss: 0.13
#   Batch   600  of    975.    .
#   step loss: 0.17
#   Batch   640  of    975.    .
#   step loss: 0.16
#   Batch   680  of    975.    .
#   step loss: 0.20
#   Batch   720  of    975.    .
#   step loss: 0.18
#   Batch   760  of    975.    .
#   step loss: 0.16
#   Batch   800  of    975.    .
#   step loss: 0.13
#   Batch   840  of    975.    .
#   step loss: 0.16
#   Batch   880  of    975.    .
#   step loss: 0.18
#   Batch   920  of    975.    .
#   step loss: 0.12
#   Batch   960  of    975.    .
#   step loss: 0.21
#
#   Average training loss: 0.15
#
# Running Validation...
# Batch accuracy: 91.21
# Batch accuracy: 89.65
# Batch accuracy: 91.21
# Batch accuracy: 90.04
# Batch accuracy: 90.82
# Batch accuracy: 91.60
# Batch accuracy: 92.38
# Batch accuracy: 91.02
# Batch accuracy: 89.26
# Batch accuracy: 89.65
# Batch accuracy: 89.45
# Batch accuracy: 90.82
# Batch accuracy: 89.65
# Batch accuracy: 88.87
# Batch accuracy: 90.43
# Batch accuracy: 91.99
# Batch accuracy: 93.36
# Batch accuracy: 90.04
# Batch accuracy: 89.45
# Batch accuracy: 93.36
# Batch accuracy: 87.70
# Batch accuracy: 91.80
# Batch accuracy: 90.82
# Batch accuracy: 88.28
# Batch accuracy: 90.23
# Batch accuracy: 91.02
# Batch accuracy: 90.23
# Batch accuracy: 92.58
# Batch accuracy: 91.21
# Batch accuracy: 92.19
# Batch accuracy: 90.04
# Batch accuracy: 89.84
# Batch accuracy: 92.97
# Batch accuracy: 91.60
# Batch accuracy: 92.38
# Batch accuracy: 88.48
# Batch accuracy: 91.60
# Batch accuracy: 90.62
# Batch accuracy: 92.58
# Batch accuracy: 92.38
# Batch accuracy: 90.43
# Batch accuracy: 92.97
# Batch accuracy: 92.38
# Batch accuracy: 90.04
# Batch accuracy: 90.43
# Batch accuracy: 89.65
# Batch accuracy: 89.45
# Batch accuracy: 91.60
# Batch accuracy: 91.41
# Batch accuracy: 88.28
# Batch accuracy: 86.33
# Batch accuracy: 91.21
# Batch accuracy: 91.02
# Batch accuracy: 92.19
# Batch accuracy: 91.60
# Batch accuracy: 91.60
# Batch accuracy: 93.55
# Batch accuracy: 90.04
# Batch accuracy: 90.04
# Batch accuracy: 92.97
# Batch accuracy: 90.62
# Batch accuracy: 91.41
# Batch accuracy: 88.87
# Batch accuracy: 88.28
# Batch accuracy: 90.62
# Batch accuracy: 91.41
# Batch accuracy: 91.60
# Batch accuracy: 90.62
# Batch accuracy: 89.45
# Batch accuracy: 91.80
# Batch accuracy: 90.82
# Batch accuracy: 89.84
# Batch accuracy: 90.82
# Batch accuracy: 90.82
# Batch accuracy: 91.41
# Batch accuracy: 91.80
# Batch accuracy: 91.60
# Batch accuracy: 91.02
# Batch accuracy: 91.99
# Batch accuracy: 91.21
# Batch accuracy: 90.04
# Batch accuracy: 91.99
# Batch accuracy: 89.06
# Batch accuracy: 89.65
# Batch accuracy: 90.04
# Batch accuracy: 90.04
# Batch accuracy: 92.38
# Batch accuracy: 92.58
# Batch accuracy: 92.19
# Batch accuracy: 91.99
# Batch accuracy: 92.38
# Batch accuracy: 91.60
# Batch accuracy: 89.06
# Batch accuracy: 92.19
# Batch accuracy: 91.02
# Batch accuracy: 90.23
# Batch accuracy: 93.16
# Batch accuracy: 91.41
# Batch accuracy: 90.82
# Batch accuracy: 91.02
# Batch accuracy: 89.06
# Batch accuracy: 91.02
# Batch accuracy: 92.38
# Batch accuracy: 90.62
# Batch accuracy: 92.19
# Batch accuracy: 89.65
# Batch accuracy: 91.60
# Batch accuracy: 91.41
# Batch accuracy: 91.13
#   Accuracy: 90.90
# The model does not improve for 1 epochs!
#
# ======== Epoch 11 / 30 ========
# Training...
#   Batch    40  of    975.    .
#   step loss: 0.15
#   Batch    80  of    975.    .
#   step loss: 0.09
#   Batch   120  of    975.    .
#   step loss: 0.12
#   Batch   160  of    975.    .
#   step loss: 0.14
#   Batch   200  of    975.    .
#   step loss: 0.15
#   Batch   240  of    975.    .
#   step loss: 0.09
#   Batch   280  of    975.    .
#   step loss: 0.10
#   Batch   320  of    975.    .
#   step loss: 0.12
#   Batch   360  of    975.    .
#   step loss: 0.19
#   Batch   400  of    975.    .
#   step loss: 0.11
#   Batch   440  of    975.    .
#   step loss: 0.19
#   Batch   480  of    975.    .
#   step loss: 0.12
#   Batch   520  of    975.    .
#   step loss: 0.17
#   Batch   560  of    975.    .
#   step loss: 0.14
#   Batch   600  of    975.    .
#   step loss: 0.09
#   Batch   640  of    975.    .
#   step loss: 0.11
#   Batch   680  of    975.    .
#   step loss: 0.13
#   Batch   720  of    975.    .
#   step loss: 0.15
#   Batch   760  of    975.    .
#   step loss: 0.21
#   Batch   800  of    975.    .
#   step loss: 0.16
#   Batch   840  of    975.    .
#   step loss: 0.16
#   Batch   880  of    975.    .
#   step loss: 0.12
#   Batch   920  of    975.    .
#   step loss: 0.13
#   Batch   960  of    975.    .
#   step loss: 0.18
#
#   Average training loss: 0.13
#
# Running Validation...
# Batch accuracy: 90.82
# Batch accuracy: 92.19
# Batch accuracy: 91.41
# Batch accuracy: 90.23
# Batch accuracy: 89.84
# Batch accuracy: 91.21
# Batch accuracy: 91.99
# Batch accuracy: 92.38
# Batch accuracy: 90.82
# Batch accuracy: 91.21
# Batch accuracy: 92.58
# Batch accuracy: 91.99
# Batch accuracy: 89.45
# Batch accuracy: 90.82
# Batch accuracy: 92.97
# Batch accuracy: 90.82
# Batch accuracy: 89.45
# Batch accuracy: 90.43
# Batch accuracy: 91.02
# Batch accuracy: 92.38
# Batch accuracy: 91.60
# Batch accuracy: 90.82
# Batch accuracy: 89.26
# Batch accuracy: 89.65
# Batch accuracy: 90.23
# Batch accuracy: 89.45
# Batch accuracy: 93.16
# Batch accuracy: 90.43
# Batch accuracy: 91.21
# Batch accuracy: 90.82
# Batch accuracy: 92.97
# Batch accuracy: 92.58
# Batch accuracy: 90.04
# Batch accuracy: 88.67
# Batch accuracy: 92.19
# Batch accuracy: 90.23
# Batch accuracy: 91.41
# Batch accuracy: 91.41
# Batch accuracy: 90.04
# Batch accuracy: 89.65
# Batch accuracy: 93.55
# Batch accuracy: 91.41
# Batch accuracy: 91.21
# Batch accuracy: 88.87
# Batch accuracy: 91.21
# Batch accuracy: 88.67
# Batch accuracy: 90.62
# Batch accuracy: 92.19
# Batch accuracy: 90.82
# Batch accuracy: 91.41
# Batch accuracy: 88.48
# Batch accuracy: 89.45
# Batch accuracy: 89.45
# Batch accuracy: 92.19
# Batch accuracy: 88.87
# Batch accuracy: 89.45
# Batch accuracy: 91.60
# Batch accuracy: 90.82
# Batch accuracy: 90.04
# Batch accuracy: 90.82
# Batch accuracy: 91.80
# Batch accuracy: 92.77
# Batch accuracy: 89.84
# Batch accuracy: 90.23
# Batch accuracy: 92.97
# Batch accuracy: 91.02
# Batch accuracy: 88.67
# Batch accuracy: 90.04
# Batch accuracy: 93.75
# Batch accuracy: 90.04
# Batch accuracy: 91.02
# Batch accuracy: 89.65
# Batch accuracy: 92.97
# Batch accuracy: 92.19
# Batch accuracy: 92.58
# Batch accuracy: 87.89
# Batch accuracy: 92.19
# Batch accuracy: 89.84
# Batch accuracy: 91.60
# Batch accuracy: 86.52
# Batch accuracy: 90.04
# Batch accuracy: 91.60
# Batch accuracy: 91.80
# Batch accuracy: 90.62
# Batch accuracy: 90.04
# Batch accuracy: 91.99
# Batch accuracy: 90.62
# Batch accuracy: 89.84
# Batch accuracy: 92.77
# Batch accuracy: 91.21
# Batch accuracy: 92.38
# Batch accuracy: 90.62
# Batch accuracy: 90.43
# Batch accuracy: 91.41
# Batch accuracy: 93.16
# Batch accuracy: 90.04
# Batch accuracy: 90.43
# Batch accuracy: 91.02
# Batch accuracy: 91.21
# Batch accuracy: 88.87
# Batch accuracy: 90.04
# Batch accuracy: 90.23
# Batch accuracy: 91.41
# Batch accuracy: 89.84
# Batch accuracy: 92.97
# Batch accuracy: 90.82
# Batch accuracy: 90.62
# Batch accuracy: 91.02
# Batch accuracy: 90.32
#   Accuracy: 90.88
# The model does not improve for 2 epochs!
#
# ======== Epoch 12 / 30 ========
# Training...
#   Batch    40  of    975.    .
#   step loss: 0.08
#   Batch    80  of    975.    .
#   step loss: 0.12
#   Batch   120  of    975.    .
#   step loss: 0.13
#   Batch   160  of    975.    .
#   step loss: 0.09
#   Batch   200  of    975.    .
#   step loss: 0.15
#   Batch   240  of    975.    .
#   step loss: 0.13
#   Batch   280  of    975.    .
#   step loss: 0.14
#   Batch   320  of    975.    .
#   step loss: 0.13
#   Batch   360  of    975.    .
#   step loss: 0.10
#   Batch   400  of    975.    .
#   step loss: 0.14
#   Batch   440  of    975.    .
#   step loss: 0.09
#   Batch   480  of    975.    .
#   step loss: 0.11
#   Batch   520  of    975.    .
#   step loss: 0.13
#   Batch   560  of    975.    .
#   step loss: 0.07
#   Batch   600  of    975.    .
#   step loss: 0.09
#   Batch   640  of    975.    .
#   step loss: 0.13
#   Batch   680  of    975.    .
#   step loss: 0.12
#   Batch   720  of    975.    .
#   step loss: 0.11
#   Batch   760  of    975.    .
#   step loss: 0.10
#   Batch   800  of    975.    .
#   step loss: 0.15
#   Batch   840  of    975.    .
#   step loss: 0.12
#   Batch   880  of    975.    .
#   step loss: 0.11
#   Batch   920  of    975.    .
#   step loss: 0.12
#   Batch   960  of    975.    .
#   step loss: 0.10
#
#   Average training loss: 0.12
#
# Running Validation...
# Batch accuracy: 91.60
# Batch accuracy: 90.62
# Batch accuracy: 89.06
# Batch accuracy: 90.62
# Batch accuracy: 90.62
# Batch accuracy: 88.09
# Batch accuracy: 91.41
# Batch accuracy: 91.21
# Batch accuracy: 89.45
# Batch accuracy: 91.80
# Batch accuracy: 91.99
# Batch accuracy: 90.23
# Batch accuracy: 89.06
# Batch accuracy: 87.89
# Batch accuracy: 91.60
# Batch accuracy: 91.02
# Batch accuracy: 91.80
# Batch accuracy: 91.02
# Batch accuracy: 92.19
# Batch accuracy: 90.82
# Batch accuracy: 88.87
# Batch accuracy: 89.26
# Batch accuracy: 92.38
# Batch accuracy: 88.87
# Batch accuracy: 89.65
# Batch accuracy: 91.02
# Batch accuracy: 90.62
# Batch accuracy: 90.82
# Batch accuracy: 91.80
# Batch accuracy: 91.41
# Batch accuracy: 88.87
# Batch accuracy: 89.84
# Batch accuracy: 91.80
# Batch accuracy: 91.60
# Batch accuracy: 91.80
# Batch accuracy: 91.21
# Batch accuracy: 91.80
# Batch accuracy: 89.26
# Batch accuracy: 91.80
# Batch accuracy: 90.23
# Batch accuracy: 91.41
# Batch accuracy: 91.60
# Batch accuracy: 91.80
# Batch accuracy: 89.84
# Batch accuracy: 91.21
# Batch accuracy: 92.19
# Batch accuracy: 92.77
# Batch accuracy: 90.04
# Batch accuracy: 92.19
# Batch accuracy: 89.84
# Batch accuracy: 93.55
# Batch accuracy: 90.82
# Batch accuracy: 91.02
# Batch accuracy: 90.82
# Batch accuracy: 90.62
# Batch accuracy: 91.60
# Batch accuracy: 87.11
# Batch accuracy: 92.38
# Batch accuracy: 91.80
# Batch accuracy: 88.87
# Batch accuracy: 91.60
# Batch accuracy: 92.77
# Batch accuracy: 92.58
# Batch accuracy: 92.38
# Batch accuracy: 91.60
# Batch accuracy: 91.60
# Batch accuracy: 90.04
# Batch accuracy: 91.41
# Batch accuracy: 89.26
# Batch accuracy: 89.84
# Batch accuracy: 90.82
# Batch accuracy: 92.19
# Batch accuracy: 89.65
# Batch accuracy: 91.99
# Batch accuracy: 91.21
# Batch accuracy: 91.80
# Batch accuracy: 92.77
# Batch accuracy: 91.60
# Batch accuracy: 89.45
# Batch accuracy: 90.04
# Batch accuracy: 92.38
# Batch accuracy: 92.58
# Batch accuracy: 90.62
# Batch accuracy: 91.60
# Batch accuracy: 90.23
# Batch accuracy: 91.99
# Batch accuracy: 90.82
# Batch accuracy: 92.19
# Batch accuracy: 90.43
# Batch accuracy: 90.82
# Batch accuracy: 91.41
# Batch accuracy: 90.23
# Batch accuracy: 90.82
# Batch accuracy: 87.89
# Batch accuracy: 90.62
# Batch accuracy: 91.41
# Batch accuracy: 91.02
# Batch accuracy: 91.02
# Batch accuracy: 92.19
# Batch accuracy: 89.65
# Batch accuracy: 91.60
# Batch accuracy: 91.80
# Batch accuracy: 89.84
# Batch accuracy: 91.60
# Batch accuracy: 91.41
# Batch accuracy: 91.21
# Batch accuracy: 93.55
# Batch accuracy: 90.04
# Batch accuracy: 90.32
#   Accuracy: 90.94
# The model does not improve for 3 epochs!
#
# ======== Epoch 13 / 30 ========
# Training...
#   Batch    40  of    975.    .
#   step loss: 0.09
#   Batch    80  of    975.    .
#   step loss: 0.09
#   Batch   120  of    975.    .
#   step loss: 0.13
#   Batch   160  of    975.    .
#   step loss: 0.13
#   Batch   200  of    975.    .
#   step loss: 0.09
#   Batch   240  of    975.    .
#   step loss: 0.09
#   Batch   280  of    975.    .
#   step loss: 0.12
#   Batch   320  of    975.    .
#   step loss: 0.10
#   Batch   360  of    975.    .
#   step loss: 0.09
#   Batch   400  of    975.    .
#   step loss: 0.10
#   Batch   440  of    975.    .
#   step loss: 0.11
#   Batch   480  of    975.    .
#   step loss: 0.14
#   Batch   520  of    975.    .
#   step loss: 0.09
#   Batch   560  of    975.    .
#   step loss: 0.11
#   Batch   600  of    975.    .
#   step loss: 0.10
#   Batch   640  of    975.    .
#   step loss: 0.12
#   Batch   680  of    975.    .
#   step loss: 0.14
#   Batch   720  of    975.    .
#   step loss: 0.09
#   Batch   760  of    975.    .
#   step loss: 0.14
#   Batch   800  of    975.    .
#   step loss: 0.10
#   Batch   840  of    975.    .
#   step loss: 0.11
#   Batch   880  of    975.    .
#   step loss: 0.10
#   Batch   920  of    975.    .
#   step loss: 0.10
#   Batch   960  of    975.    .
#   step loss: 0.09
#
#   Average training loss: 0.11
#
# Running Validation...
# Batch accuracy: 91.02
# Batch accuracy: 91.60
# Batch accuracy: 92.38
# Batch accuracy: 92.19
# Batch accuracy: 91.41
# Batch accuracy: 91.21
# Batch accuracy: 88.67
# Batch accuracy: 91.60
# Batch accuracy: 91.80
# Batch accuracy: 92.77
# Batch accuracy: 90.43
# Batch accuracy: 91.02
# Batch accuracy: 90.23
# Batch accuracy: 91.21
# Batch accuracy: 92.58
# Batch accuracy: 91.99
# Batch accuracy: 90.62
# Batch accuracy: 92.97
# Batch accuracy: 92.97
# Batch accuracy: 91.80
# Batch accuracy: 88.09
# Batch accuracy: 91.21
# Batch accuracy: 91.99
# Batch accuracy: 91.60
# Batch accuracy: 90.62
# Batch accuracy: 90.62
# Batch accuracy: 91.99
# Batch accuracy: 91.21
# Batch accuracy: 90.04
# Batch accuracy: 90.82
# Batch accuracy: 90.23
# Batch accuracy: 91.99
# Batch accuracy: 90.04
# Batch accuracy: 92.38
# Batch accuracy: 90.62
# Batch accuracy: 90.43
# Batch accuracy: 90.82
# Batch accuracy: 90.23
# Batch accuracy: 90.04
# Batch accuracy: 89.84
# Batch accuracy: 92.97
# Batch accuracy: 90.23
# Batch accuracy: 89.06
# Batch accuracy: 91.41
# Batch accuracy: 91.41
# Batch accuracy: 88.87
# Batch accuracy: 90.82
# Batch accuracy: 89.06
# Batch accuracy: 89.84
# Batch accuracy: 91.80
# Batch accuracy: 91.41
# Batch accuracy: 91.41
# Batch accuracy: 91.41
# Batch accuracy: 92.58
# Batch accuracy: 93.36
# Batch accuracy: 90.82
# Batch accuracy: 90.82
# Batch accuracy: 88.67
# Batch accuracy: 92.38
# Batch accuracy: 88.67
# Batch accuracy: 91.60
# Batch accuracy: 90.43
# Batch accuracy: 87.50
# Batch accuracy: 89.84
# Batch accuracy: 92.19
# Batch accuracy: 91.60
# Batch accuracy: 91.21
# Batch accuracy: 91.80
# Batch accuracy: 91.02
# Batch accuracy: 92.19
# Batch accuracy: 91.99
# Batch accuracy: 92.19
# Batch accuracy: 91.41
# Batch accuracy: 91.80
# Batch accuracy: 90.43
# Batch accuracy: 88.48
# Batch accuracy: 91.02
# Batch accuracy: 90.82
# Batch accuracy: 91.02
# Batch accuracy: 88.67
# Batch accuracy: 91.21
# Batch accuracy: 91.41
# Batch accuracy: 90.43
# Batch accuracy: 91.21
# Batch accuracy: 91.80
# Batch accuracy: 90.62
# Batch accuracy: 91.41
# Batch accuracy: 90.43
# Batch accuracy: 93.36
# Batch accuracy: 90.23
# Batch accuracy: 91.99
# Batch accuracy: 88.09
# Batch accuracy: 91.99
# Batch accuracy: 91.41
# ...
# Batch accuracy: 87.30
# Batch accuracy: 91.99
# Batch accuracy: 90.82
# Batch accuracy: 91.60
# Batch accuracy: 92.97
# Batch accuracy: 93.16
# Batch accuracy: 88.87
# Batch accuracy: 88.67
# Batch accuracy: 93.36
# Batch accuracy: 90.62
# Batch accuracy: 92.97
# Batch accuracy: 90.43
# Batch accuracy: 94.53
# Batch accuracy: 91.21
# Batch accuracy: 89.65
# Batch accuracy: 93.55
# Batch accuracy: 91.41
# Batch accuracy: 91.99
# Batch accuracy: 88.28
# Batch accuracy: 89.06
# Batch accuracy: 91.41
# Batch accuracy: 92.19
# Batch accuracy: 89.26
# Batch accuracy: 91.99
# Batch accuracy: 91.41
# Batch accuracy: 91.60
# Batch accuracy: 91.99
# Batch accuracy: 91.60
# Batch accuracy: 90.82
# Batch accuracy: 92.97
# Batch accuracy: 90.82
# Batch accuracy: 94.14
# Batch accuracy: 92.19
# Batch accuracy: 90.82
# Batch accuracy: 91.02
# Batch accuracy: 91.41
# Batch accuracy: 90.43
# Batch accuracy: 91.94
#   Accuracy: 91.40
# The model does not improve for 2 epochs!
#
# ======== Epoch 23 / 30 ========
# Training...
#   Batch    40  of    975.    .
#   step loss: 0.04
#   Batch    80  of    975.    .
#   step loss: 0.03
#   Batch   120  of    975.    .
#   step loss: 0.05
#   Batch   160  of    975.    .
#   step loss: 0.03
#   Batch   200  of    975.    .
#   step loss: 0.03
#   Batch   240  of    975.    .
#   step loss: 0.04
#   Batch   280  of    975.    .
#   step loss: 0.05
#   Batch   320  of    975.    .
#   step loss: 0.03
#   Batch   360  of    975.    .
#   step loss: 0.05
#   Batch   400  of    975.    .
#   step loss: 0.03
#   Batch   440  of    975.    .
#   step loss: 0.03
#   Batch   480  of    975.    .
#   step loss: 0.05
#   Batch   520  of    975.    .
#   step loss: 0.04
#   Batch   560  of    975.    .
#   step loss: 0.05
#   Batch   600  of    975.    .
#   step loss: 0.07
#   Batch   640  of    975.    .
#   step loss: 0.03
#   Batch   680  of    975.    .
#   step loss: 0.06
#   Batch   720  of    975.    .
#   step loss: 0.07
#   Batch   760  of    975.    .
#   step loss: 0.03
#   Batch   800  of    975.    .
#   step loss: 0.04
#   Batch   840  of    975.    .
#   step loss: 0.04
#   Batch   880  of    975.    .
#   step loss: 0.03
#   Batch   920  of    975.    .
#   step loss: 0.04
#   Batch   960  of    975.    .
#   step loss: 0.07
#
#   Average training loss: 0.04
#
# Running Validation...
# Batch accuracy: 90.43
# Batch accuracy: 91.60
# Batch accuracy: 93.36
# Batch accuracy: 90.43
# Batch accuracy: 91.41
# Batch accuracy: 91.41
# Batch accuracy: 91.41
# Batch accuracy: 90.23
# Batch accuracy: 91.02
# Batch accuracy: 90.04
# Batch accuracy: 91.60
# Batch accuracy: 89.65
# Batch accuracy: 91.21
# Batch accuracy: 91.99
# Batch accuracy: 93.16
# Batch accuracy: 91.21
# Batch accuracy: 91.60
# Batch accuracy: 89.65
# Batch accuracy: 90.82
# Batch accuracy: 93.16
# Batch accuracy: 90.82
# Batch accuracy: 92.38
# Batch accuracy: 91.80
# Batch accuracy: 90.43
# Batch accuracy: 93.16
# Batch accuracy: 90.23
# Batch accuracy: 89.45
# Batch accuracy: 91.99
# Batch accuracy: 92.58
# Batch accuracy: 92.97
# Batch accuracy: 92.38
# Batch accuracy: 91.02
# Batch accuracy: 91.02
# Batch accuracy: 90.23
# Batch accuracy: 91.60
# Batch accuracy: 91.99
# Batch accuracy: 89.45
# Batch accuracy: 90.43
# Batch accuracy: 92.19
# Batch accuracy: 92.58
# Batch accuracy: 90.43
# Batch accuracy: 90.43
# Batch accuracy: 92.38
# Batch accuracy: 90.04
# Batch accuracy: 91.60
# Batch accuracy: 90.82
# Batch accuracy: 90.43
# Batch accuracy: 92.19
# Batch accuracy: 88.87
# Batch accuracy: 91.21
# Batch accuracy: 89.84
# Batch accuracy: 91.02
# Batch accuracy: 91.41
# Batch accuracy: 90.04
# Batch accuracy: 91.41
# Batch accuracy: 89.45
# Batch accuracy: 87.89
# Batch accuracy: 89.45
# Batch accuracy: 92.38
# Batch accuracy: 92.97
# Batch accuracy: 93.55
# Batch accuracy: 91.99
# Batch accuracy: 92.97
# Batch accuracy: 92.38
# Batch accuracy: 92.77
# Batch accuracy: 91.99
# Batch accuracy: 91.02
# Batch accuracy: 89.84
# Batch accuracy: 91.02
# Batch accuracy: 91.80
# Batch accuracy: 93.36
# Batch accuracy: 92.97
# Batch accuracy: 89.26
# Batch accuracy: 90.82
# Batch accuracy: 90.82
# Batch accuracy: 91.99
# Batch accuracy: 92.77
# Batch accuracy: 91.41
# Batch accuracy: 90.04
# Batch accuracy: 90.43
# Batch accuracy: 90.43
# Batch accuracy: 91.41
# Batch accuracy: 91.41
# Batch accuracy: 90.82
# Batch accuracy: 92.97
# Batch accuracy: 92.38
# Batch accuracy: 91.02
# Batch accuracy: 90.62
# Batch accuracy: 89.84
# Batch accuracy: 93.75
# Batch accuracy: 91.99
# Batch accuracy: 91.99
# Batch accuracy: 91.80
# Batch accuracy: 91.60
# Batch accuracy: 92.58
# Batch accuracy: 92.19
# Batch accuracy: 92.97
# Batch accuracy: 92.19
# Batch accuracy: 93.16
# Batch accuracy: 92.19
# Batch accuracy: 93.75
# Batch accuracy: 90.82
# Batch accuracy: 91.41
# Batch accuracy: 91.60
# Batch accuracy: 91.21
# Batch accuracy: 90.23
# Batch accuracy: 91.41
# Batch accuracy: 92.19
# Batch accuracy: 89.52
#   Accuracy: 91.39
# The model does not improve for 3 epochs!
#
# ======== Epoch 24 / 30 ========
# Training...
#   Batch    40  of    975.    .
#   step loss: 0.03
#   Batch    80  of    975.    .
#   step loss: 0.04
#   Batch   120  of    975.    .
#   step loss: 0.05
#   Batch   160  of    975.    .
#   step loss: 0.04
#   Batch   200  of    975.    .
#   step loss: 0.06
#   Batch   240  of    975.    .
#   step loss: 0.06
#   Batch   280  of    975.    .
#   step loss: 0.02
#   Batch   320  of    975.    .
#   step loss: 0.04
#   Batch   360  of    975.    .
#   step loss: 0.04
#   Batch   400  of    975.    .
#   step loss: 0.03
#   Batch   440  of    975.    .
#   step loss: 0.07
#   Batch   480  of    975.    .
#   step loss: 0.02
#   Batch   520  of    975.    .
#   step loss: 0.04
#   Batch   560  of    975.    .
#   step loss: 0.04
#   Batch   600  of    975.    .
#   step loss: 0.04
#   Batch   640  of    975.    .
#   step loss: 0.03
#   Batch   680  of    975.    .
#   step loss: 0.03
#   Batch   720  of    975.    .
#   step loss: 0.05
#   Batch   760  of    975.    .
#   step loss: 0.04
#   Batch   800  of    975.    .
#   step loss: 0.05
#   Batch   840  of    975.    .
#   step loss: 0.06
#   Batch   880  of    975.    .
#   step loss: 0.04
#   Batch   920  of    975.    .
#   step loss: 0.03
#   Batch   960  of    975.    .
#   step loss: 0.03
#
#   Average training loss: 0.04
#
# Running Validation...
# Batch accuracy: 93.16
# Batch accuracy: 91.80
# Batch accuracy: 90.04
# Batch accuracy: 91.80
# Batch accuracy: 90.43
# Batch accuracy: 91.99
# Batch accuracy: 91.02
# Batch accuracy: 90.62
# Batch accuracy: 90.23
# Batch accuracy: 93.16
# Batch accuracy: 93.16
# Batch accuracy: 92.19
# Batch accuracy: 93.55
# Batch accuracy: 90.82
# Batch accuracy: 91.41
# Batch accuracy: 89.84
# Batch accuracy: 90.23
# Batch accuracy: 90.23
# Batch accuracy: 89.45
# Batch accuracy: 91.41
# Batch accuracy: 90.82
# Batch accuracy: 92.58
# Batch accuracy: 92.77
# Batch accuracy: 89.06
# Batch accuracy: 95.12
# Batch accuracy: 88.67
# Batch accuracy: 91.21
# Batch accuracy: 91.60
# Batch accuracy: 91.80
# Batch accuracy: 93.16
# Batch accuracy: 92.38
# Batch accuracy: 92.19
# Batch accuracy: 90.23
# Batch accuracy: 90.43
# Batch accuracy: 90.62
# Batch accuracy: 91.80
# Batch accuracy: 91.80
# Batch accuracy: 92.19
# Batch accuracy: 90.43
# Batch accuracy: 91.60
# Batch accuracy: 90.43
# Batch accuracy: 93.55
# Batch accuracy: 91.21
# Batch accuracy: 92.77
# Batch accuracy: 92.97
# Batch accuracy: 92.77
# Batch accuracy: 91.21
# Batch accuracy: 90.04
# Batch accuracy: 91.99
# Batch accuracy: 90.43
# Batch accuracy: 91.80
# Batch accuracy: 91.60
# Batch accuracy: 91.41
# Batch accuracy: 91.21
# Batch accuracy: 89.84
# Batch accuracy: 91.99
# Batch accuracy: 93.16
# Batch accuracy: 92.77
# Batch accuracy: 93.75
# Batch accuracy: 91.99
# Batch accuracy: 91.99
# Batch accuracy: 90.04
# Batch accuracy: 92.38
# Batch accuracy: 89.26
# Batch accuracy: 90.82
# Batch accuracy: 91.60
# Batch accuracy: 91.02
# Batch accuracy: 92.58
# Batch accuracy: 91.21
# Batch accuracy: 91.60
# Batch accuracy: 90.82
# Batch accuracy: 91.21
# Batch accuracy: 90.43
# Batch accuracy: 89.06
# Batch accuracy: 91.21
# Batch accuracy: 90.62
# Batch accuracy: 89.84
# Batch accuracy: 88.87
# Batch accuracy: 93.55
# Batch accuracy: 92.77
# Batch accuracy: 91.60
# Batch accuracy: 89.84
# Batch accuracy: 90.04
# Batch accuracy: 90.43
# Batch accuracy: 89.06
# Batch accuracy: 91.80
# Batch accuracy: 89.06
# Batch accuracy: 91.60
# Batch accuracy: 90.62
# Batch accuracy: 93.75
# Batch accuracy: 90.23
# Batch accuracy: 94.14
# Batch accuracy: 92.19
# Batch accuracy: 91.60
# Batch accuracy: 91.21
# Batch accuracy: 92.38
# Batch accuracy: 90.62
# Batch accuracy: 90.82
# Batch accuracy: 90.82
# Batch accuracy: 92.77
# Batch accuracy: 92.97
# Batch accuracy: 91.41
# Batch accuracy: 89.65
# Batch accuracy: 90.43
# Batch accuracy: 91.41
# Batch accuracy: 90.43
# Batch accuracy: 92.38
# Batch accuracy: 92.97
# Batch accuracy: 91.94
#   Accuracy: 91.40
# The model does not improve for 4 epochs!
#
# ======== Epoch 25 / 30 ========
# Training...
#   Batch    40  of    975.    .
#   step loss: 0.04
#   Batch    80  of    975.    .
#   step loss: 0.03
#   Batch   120  of    975.    .
#   step loss: 0.04
#   Batch   160  of    975.    .
#   step loss: 0.06
#   Batch   200  of    975.    .
#   step loss: 0.05
#   Batch   240  of    975.    .
#   step loss: 0.06
#   Batch   280  of    975.    .
#   step loss: 0.05
#   Batch   320  of    975.    .
#   step loss: 0.04
#   Batch   360  of    975.    .
#   step loss: 0.04
#   Batch   400  of    975.    .
#   step loss: 0.04
#   Batch   440  of    975.    .
#   step loss: 0.05
#   Batch   480  of    975.    .
#   step loss: 0.04
#   Batch   520  of    975.    .
#   step loss: 0.03
#   Batch   560  of    975.    .
#   step loss: 0.06
#   Batch   600  of    975.    .
#   step loss: 0.06
#   Batch   640  of    975.    .
#   step loss: 0.04
#   Batch   680  of    975.    .
#   step loss: 0.03
#   Batch   720  of    975.    .
#   step loss: 0.04
#   Batch   760  of    975.    .
#   step loss: 0.07
#   Batch   800  of    975.    .
#   step loss: 0.03
#   Batch   840  of    975.    .
#   step loss: 0.05
#   Batch   880  of    975.    .
#   step loss: 0.05
#   Batch   920  of    975.    .
#   step loss: 0.05
#   Batch   960  of    975.    .
#   step loss: 0.03
#
#   Average training loss: 0.04
#
# Running Validation...
# Batch accuracy: 93.16
# Batch accuracy: 90.62
# Batch accuracy: 92.19
# Batch accuracy: 89.65
# Batch accuracy: 91.60
# Batch accuracy: 89.45
# Batch accuracy: 92.19
# Batch accuracy: 90.43
# Batch accuracy: 91.41
# Batch accuracy: 91.21
# Batch accuracy: 90.82
# Batch accuracy: 93.95
# Batch accuracy: 92.19
# Batch accuracy: 89.06
# Batch accuracy: 91.41
# Batch accuracy: 89.06
# Batch accuracy: 91.60
# Batch accuracy: 91.80
# Batch accuracy: 93.55
# Batch accuracy: 91.41
# Batch accuracy: 91.60
# Batch accuracy: 89.84
# Batch accuracy: 91.99
# Batch accuracy: 88.87
# Batch accuracy: 91.80
# Batch accuracy: 91.80
# Batch accuracy: 89.06
# Batch accuracy: 91.80
# Batch accuracy: 91.21
# Batch accuracy: 93.36
# Batch accuracy: 92.97
# Batch accuracy: 92.38
# Batch accuracy: 91.41
# Batch accuracy: 90.82
# Batch accuracy: 93.55
# Batch accuracy: 91.21
# Batch accuracy: 91.80
# Batch accuracy: 91.80
# Batch accuracy: 90.43
# Batch accuracy: 92.38
# Batch accuracy: 91.80
# Batch accuracy: 90.62
# Batch accuracy: 92.38
# Batch accuracy: 89.65
# Batch accuracy: 88.67
# Batch accuracy: 93.75
# Batch accuracy: 92.58
# Batch accuracy: 92.77
# Batch accuracy: 91.80
# Batch accuracy: 89.65
# Batch accuracy: 90.23
# Batch accuracy: 90.43
# Batch accuracy: 91.41
# Batch accuracy: 92.19
# Batch accuracy: 92.58
# Batch accuracy: 92.38
# Batch accuracy: 90.43
# Batch accuracy: 92.19
# Batch accuracy: 91.02
# Batch accuracy: 92.38
# Batch accuracy: 90.82
# Batch accuracy: 92.19
# Batch accuracy: 93.95
# Batch accuracy: 91.80
# Batch accuracy: 91.80
# Batch accuracy: 91.60
# Batch accuracy: 93.16
# Batch accuracy: 90.82
# Batch accuracy: 91.80
# Batch accuracy: 89.26
# Batch accuracy: 93.16
# Batch accuracy: 91.21
# Batch accuracy: 90.43
# Batch accuracy: 91.80
# Batch accuracy: 91.80
# Batch accuracy: 89.06
# Batch accuracy: 88.87
# Batch accuracy: 90.43
# Batch accuracy: 90.23
# Batch accuracy: 91.80
# Batch accuracy: 90.82
# Batch accuracy: 90.04
# Batch accuracy: 90.62
# Batch accuracy: 91.60
# Batch accuracy: 91.60
# Batch accuracy: 89.45
# Batch accuracy: 90.04
# Batch accuracy: 92.97
# Batch accuracy: 92.19
# Batch accuracy: 92.19
# Batch accuracy: 92.38
# Batch accuracy: 89.06
# Batch accuracy: 92.38
# Batch accuracy: 92.58
# Batch accuracy: 92.19
# Batch accuracy: 92.58
# Batch accuracy: 89.45
# Batch accuracy: 91.99
# Batch accuracy: 91.21
# Batch accuracy: 91.02
# Batch accuracy: 91.21
# Batch accuracy: 90.23
# Batch accuracy: 92.77
# Batch accuracy: 92.97
# Batch accuracy: 90.62
# Batch accuracy: 91.21
# Batch accuracy: 92.19
# Batch accuracy: 91.41
# Batch accuracy: 94.35
#   Accuracy: 91.42
# The model does not improve for 5 epochs!
# Epoch    25: reducing learning rate of group 0 to 1.0000e-07.
#
# ======== Epoch 26 / 30 ========
# Training...
#   Batch    40  of    975.    .
#   step loss: 0.08
#   Batch    80  of    975.    .
#   step loss: 0.06
#   Batch   120  of    975.    .
#   step loss: 0.04
#   Batch   160  of    975.    .
#   step loss: 0.05
#   Batch   200  of    975.    .
#   step loss: 0.04
#   Batch   240  of    975.    .
#   step loss: 0.06
#   Batch   280  of    975.    .
#   step loss: 0.05
#   Batch   320  of    975.    .
#   step loss: 0.04
#   Batch   360  of    975.    .
#   step loss: 0.03
#   Batch   400  of    975.    .
#   step loss: 0.03
#   Batch   440  of    975.    .
#   step loss: 0.04
#   Batch   480  of    975.    .
#   step loss: 0.07
#   Batch   520  of    975.    .
#   step loss: 0.05
#   Batch   560  of    975.    .
#   step loss: 0.05
#   Batch   600  of    975.    .
#   step loss: 0.04
#   Batch   640  of    975.    .
#   step loss: 0.03
#   Batch   680  of    975.    .
#   step loss: 0.04
#   Batch   720  of    975.    .
#   step loss: 0.03
#   Batch   760  of    975.    .
#   step loss: 0.05
#   Batch   800  of    975.    .
#   step loss: 0.03
#   Batch   840  of    975.    .
#   step loss: 0.04
#   Batch   880  of    975.    .
#   step loss: 0.06
#   Batch   920  of    975.    .
#   step loss: 0.04
#   Batch   960  of    975.    .
#   step loss: 0.04
#
#   Average training loss: 0.04
#
# Running Validation...
# Batch accuracy: 90.62
# Batch accuracy: 92.19
# Batch accuracy: 90.82
# Batch accuracy: 91.80
# Batch accuracy: 89.45
# Batch accuracy: 91.80
# Batch accuracy: 93.36
# Batch accuracy: 91.99
# Batch accuracy: 92.77
# Batch accuracy: 91.21
# Batch accuracy: 90.43
# Batch accuracy: 90.62
# Batch accuracy: 92.19
# Batch accuracy: 87.50
# Batch accuracy: 92.38
# Batch accuracy: 90.82
# Batch accuracy: 88.48
# Batch accuracy: 91.99
# Batch accuracy: 91.02
# Batch accuracy: 91.99
# Batch accuracy: 92.38
# Batch accuracy: 91.99
# Batch accuracy: 89.45
# Batch accuracy: 89.65
# Batch accuracy: 91.21
# Batch accuracy: 91.02
# Batch accuracy: 90.23
# Batch accuracy: 92.38
# Batch accuracy: 92.19
# Batch accuracy: 93.36
# Batch accuracy: 91.80
# Batch accuracy: 89.45
# Batch accuracy: 92.97
# Batch accuracy: 91.99
# Batch accuracy: 89.84
# Batch accuracy: 92.38
# Batch accuracy: 91.02
# Batch accuracy: 92.38
# Batch accuracy: 92.19
# Batch accuracy: 88.87
# Batch accuracy: 94.34
# Batch accuracy: 90.43
# Batch accuracy: 91.60
# Batch accuracy: 91.99
# Batch accuracy: 90.23
# Batch accuracy: 93.16
# Batch accuracy: 91.21
# Batch accuracy: 91.02
# Batch accuracy: 90.04
# Batch accuracy: 91.21
# Batch accuracy: 93.16
# Batch accuracy: 93.16
# Batch accuracy: 91.02
# Batch accuracy: 91.80
# Batch accuracy: 89.84
# Batch accuracy: 91.99
# Batch accuracy: 92.97
# Batch accuracy: 90.62
# Batch accuracy: 92.19
# Batch accuracy: 90.62
# Batch accuracy: 93.55
# Batch accuracy: 89.26
# Batch accuracy: 91.02
# Batch accuracy: 90.43
# Batch accuracy: 89.06
# Batch accuracy: 91.99
# Batch accuracy: 91.99
# Batch accuracy: 90.23
# Batch accuracy: 92.38
# Batch accuracy: 91.41
# Batch accuracy: 90.82
# Batch accuracy: 92.97
# Batch accuracy: 91.21
# Batch accuracy: 92.19
# Batch accuracy: 92.97
# Batch accuracy: 89.06
# Batch accuracy: 93.16
# Batch accuracy: 90.82
# Batch accuracy: 92.77
# Batch accuracy: 90.82
# Batch accuracy: 91.99
# Batch accuracy: 91.02
# Batch accuracy: 91.21
# Batch accuracy: 89.65
# Batch accuracy: 92.97
# Batch accuracy: 93.55
# Batch accuracy: 89.45
# Batch accuracy: 90.62
# Batch accuracy: 90.62
# Batch accuracy: 90.82
# Batch accuracy: 91.60
# Batch accuracy: 91.60
# Batch accuracy: 92.19
# Batch accuracy: 91.41
# Batch accuracy: 92.97
# Batch accuracy: 93.55
# Batch accuracy: 90.43
# Batch accuracy: 92.97
# Batch accuracy: 91.80
# Batch accuracy: 90.62
# Batch accuracy: 92.58
# Batch accuracy: 90.23
# Batch accuracy: 93.16
# Batch accuracy: 90.04
# Batch accuracy: 91.80
# Batch accuracy: 89.45
# Batch accuracy: 90.82
# Batch accuracy: 91.60
# Batch accuracy: 91.13
#   Accuracy: 91.40
# The model does not improve for 6 epochs!
# ====>Stopping training, the model did not improve for 6
# ====>Best epoch: 20.
#
# Training complete!

# %%
def predict(
    model_path: Path,
    dataset: str,
    batch_size: int,
    labels_dict,
    device: torch.device
):

    print(f"====Loading dataset for testing")
    test_corpus = NLPDataset(dataset, "test", sentence_max_len, labels_dict = labels_dict, vocab= voc)

    test_dataloader = DataLoader(
        test_corpus,
        batch_size=batch_size,
        #sampler = RandomSampler(test_corpus),
        pin_memory=True,
        num_workers=0,
        drop_last=False
    )

    print(f"====Loading model for testing")
    model = torch.load(join(model_path, "best-model.pth"))
    model.to(device)
    model.eval()
    pred_labels = []
    test_labels = []
    logits_list = []

    def _list_from_tensor(tensor):
        if tensor.numel() == 1:
            return [tensor.item()]
        return list(tensor.cpu().detach().numpy())

    print("====Testing model...")
    for batch in test_dataloader:
        b_input_ids = batch[0]
        b_input_ids = torch.tensor(b_input_ids).to(device).long()
        b_labels = batch[1].to(device)
        with torch.no_grad():
            loss, logits = model(b_input_ids, b_labels)
            preds = np.argmax(logits.cpu(), axis=1) # Convert one-hot to index
            b_labels = b_labels.int()
            pred_labels.extend(_list_from_tensor(preds))
            test_labels.extend(_list_from_tensor(b_labels))
        logits_list.extend(_list_from_tensor(logits))

    print(classification_report(test_labels, pred_labels, labels=list(labels_dict.values()), target_names=np.array(list(labels_dict.keys())), digits=3, output_dict=False))
    logits_list = expit(logits_list)
    del model
    torch.cuda.empty_cache()

# %%
predict(last_saved_model, dataset, batch_size, labels_dict, device)
# Out:
# ====Loading dataset for testing
# ====Loading model for testing
# ====Testing model...
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:37: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#                                              precision    recall  f1-score   support
#
#                               FISHING_LINES      0.781     0.812     0.796       584
#                      MOBILE_DEVICE_CHARGERS      0.934     0.950     0.942       804
#                                  SUNGLASSES      0.948     0.965     0.956       875
#                                    FREEZERS      0.857     0.914     0.885       444
#                                  CAR_WHEELS      0.976     0.996     0.986       720
#                            BATHROOM_FAUCETS      0.870     0.864     0.867       521
#                              ACTION_FIGURES      0.637     0.681     0.658       800
#                                       IRONS      0.977     0.968     0.972       433
#                                  MATTRESSES      0.970     0.972     0.971       534
#                       SWIMMING_POOL_HEATERS      0.905     0.905     0.905        21
#                              KITCHEN_KNIVES      0.910     0.946     0.927       202
#                                 TELEVISIONS      0.898     0.944     0.920       728
#                    SPORT_AND_BAZAAR_BOTTLES      0.861     0.869     0.865       229
#                                    STARTERS      0.961     0.980     0.971       354
#                                  FACE_MASKS      0.768     0.837     0.801       166
#                             KITCHEN_FAUCETS      0.875     0.896     0.885       431
#     TACTICAL_AND_SPORTING_KNIVES_AND_BLADES      0.924     0.890     0.907       164
#                                   NOTEBOOKS      0.891     0.950     0.920       543
#                                 DEEP_FRYERS      0.962     0.936     0.949       455
#                                TORSION_BARS      0.984     0.992     0.988       123
#                            AUDIO_AMPLIFIERS      0.746     0.814     0.778       311
#                              CEILING_LIGHTS      0.933     0.941     0.937       472
#                                       BELTS      0.889     0.980     0.932        49
#                    AUTOMOTIVE_WEATHERSTRIPS      0.941     0.958     0.950       788
#                                  HEADBOARDS      0.991     0.974     0.982       228
#                                       YARNS      0.809     0.894     0.849       142
#                                SMARTWATCHES      0.941     0.928     0.935       724
#                             FOOTBALL_SHIRTS      0.973     0.974     0.973       921
#                      AUTOMOTIVE_CLUTCH_KITS      0.971     0.985     0.978       719
#                                WRISTWATCHES      0.937     0.949     0.943       876
#                                  WALLPAPERS      0.964     0.942     0.953       885
#         AUTOMOTIVE_SIDE_VIEW_MIRROR_GLASSES      0.985     0.987     0.986       536
#                            AUDIO_INTERFACES      0.872     0.887     0.879       300
#                            KITCHEN_PLAYSETS      0.919     0.910     0.915       100
#                                 LIGHT_BULBS      0.932     0.938     0.935       829
#                              CELL_BATTERIES      0.933     0.937     0.935       670
#                        SURVEILLANCE_CAMERAS      0.923     0.873     0.898       909
#                                   THERMOSES      0.806     0.830     0.818       100
#                  HUMIDIFIERS_AND_VAPORIZERS      0.860     0.850     0.855       173
#                              KITCHEN_APRONS      0.905     0.704     0.792        27
#                         PORTABLE_GENERATORS      0.977     0.977     0.977       132
#                                  CELLPHONES      0.873     0.897     0.885       329
#                            HANDICRAFT_BOXES      0.726     0.688     0.706       112
#                         EMBROIDERY_MACHINES      0.804     0.725     0.763        51
#                                     CAMERAS      0.827     0.674     0.743        92
#             DESKTOP_COMPUTER_POWER_SUPPLIES      0.975     0.976     0.976       679
#                              BABIES_FORMULA      0.989     0.977     0.983        88
#                     MOTORCYCLE_SPEEDOMETERS      0.667     0.500     0.571         4
#                                     CARPETS      0.924     0.964     0.943       857
#                       CARDS_AND_INVITATIONS      0.844     0.809     0.826        47
#                            ELECTRIC_GUITARS      0.947     0.942     0.945       778
#                           COMPUTER_MONITORS      0.942     0.956     0.949       701
#                          MULTIGAME_MACHINES      0.800     0.779     0.789        77
#                                 TABLECLOTHS      0.958     0.974     0.966       544
#                                   VIBRATORS      0.825     0.803     0.814       117
#                                      PLANTS      0.940     0.946     0.943       313
#                                AM_FM_RADIOS      0.895     0.914     0.904       383
#                      ENGINE_CONTROL_MODULES      0.958     0.981     0.969       415
#             LATEX_ENAMEL_AND_ACRYLIC_PAINTS      0.985     1.000     0.993        67
#             MUSICAL_KEYBOARD_CASES_AND_BAGS      0.987     0.982     0.984       760
#                                 VIDEO_GAMES      0.968     0.978     0.973       908
#                          ARTIFICIAL_FLOWERS      0.900     0.926     0.913       497
#                          OUTER_TIE_ROD_ENDS      0.984     0.980     0.982       496
#                           EXHAUST_MANIFOLDS      0.727     1.000     0.842         8
#                     DIGITAL_VOICE_RECORDERS      0.890     0.941     0.915       774
#                               REFRIGERATORS      0.931     0.927     0.929       524
#                             DISPOSABLE_CUPS      0.756     0.809     0.781       188
#                                  EYESHADOWS      0.961     0.942     0.951       738
#                                      RANGES      0.960     0.962     0.961       450
#          AUTOMOTIVE_POWER_WINDOW_REGULATORS      0.940     0.913     0.926       138
#                                     HOOKAHS      0.994     0.935     0.963       168
#                       AUTOMOTIVE_AMPLIFIERS      0.928     0.914     0.921       662
#                           PROJECTOR_SCREENS      0.980     0.906     0.941        53
#                          AUTOMOTIVE_EMBLEMS      0.908     0.905     0.906       524
#                           PAINTBALL_MARKERS      0.874     0.856     0.865        97
#               AUTOMOTIVE_SPRING_SUSPENSIONS      0.906     0.959     0.932       121
#                                 ENGINE_OILS      0.954     0.966     0.960       770
#                            BATTERY_CHARGERS      0.700     0.700     0.700        30
#                     SWEATSHIRTS_AND_HOODIES      0.933     0.941     0.937       118
#                      CONTINUOUS_INK_SYSTEMS      0.977     0.929     0.952       140
#                              BATHROOM_SINKS      0.934     0.967     0.951       427
#                                MEMORY_CARDS      0.958     0.963     0.960       669
#                                    HANDBAGS      0.935     0.951     0.943       850
#                               KITCHEN_SINKS      0.899     0.877     0.888       253
#                            CAMERA_BATTERIES      0.919     0.937     0.928       554
#                             WATER_RADIATORS      0.947     0.942     0.945       399
#                           CYCLING_COMPUTERS      0.909     0.925     0.917       161
#                                EROTIC_BOOKS      1.000     0.985     0.992        67
#                            MOTORCYCLE_CASES      0.991     0.982     0.986       222
#                                    COSTUMES      0.963     0.949     0.956       276
#                           BODYWEIGHT_SCALES      0.879     0.891     0.885       293
#                      GAMEPADS_AND_JOYSTICKS      0.951     0.956     0.954       612
#                                       PANTS      0.895     0.937     0.916       799
#                                      STOOLS      0.958     0.965     0.961       594
#                               FISHING_REELS      0.973     0.959     0.966       740
#                                     WALLETS      0.973     0.964     0.968       665
#                           MUSICAL_KEYBOARDS      0.930     0.959     0.944       511
#                                  ULTRABOOKS      0.900     0.853     0.876       232
#                             ENGINE_BEARINGS      0.985     0.976     0.980       327
#                    CAR_POWER_STEERING_PUMPS      0.984     0.989     0.987       370
#                                     TABLETS      0.950     0.936     0.943       624
#                              MAKEUP_BRUSHES      0.966     0.953     0.959       534
#                               HORSE_SADDLES      1.000     0.961     0.980       102
#                          CD_AND_DVD_PLAYERS      0.869     0.887     0.878       291
#                    VIDEO_GAME_PREPAID_CARDS      0.833     0.809     0.821        68
#                             SCREEN_PRINTERS      0.937     0.955     0.946       156
#                                  ROOF_RACKS      0.968     0.974     0.971       428
#                                  HEADPHONES      0.957     0.931     0.944       189
#                       ELECTRIC_SCREWDRIVERS      0.929     0.746     0.827       122
#                             VACUUM_CLEANERS      0.875     0.875     0.875        16
#                                 FLASHLIGHTS      0.967     0.965     0.966       606
#                                HOME_SHELVES      0.754     0.803     0.778       157
#                               BRUSH_CUTTERS      0.908     0.900     0.904       110
#                         COMPUTER_PROCESSORS      0.967     0.960     0.963       794
#                                    NECKTIES      0.985     0.963     0.974       134
#                          MOTORCYCLE_JACKETS      0.934     0.929     0.932       551
#                                    WRENCHES      0.948     0.987     0.967       371
#                                 WHEELCHAIRS      0.978     1.000     0.989        90
#                          RAM_MEMORY_MODULES      0.973     0.970     0.971       822
#                                PENCIL_CASES      0.949     0.913     0.930       183
#                AUTOMOTIVE_SHIFT_LEVER_KNOBS      1.000     0.999     0.999       938
#                                        MUGS      0.912     0.948     0.930       329
#                              WALKIE_TALKIES      0.908     0.936     0.922       283
#                                       DOLLS      0.890     0.924     0.907       843
#                                  TREADMILLS      0.955     0.969     0.962        65
#                                 SPARK_PLUGS      0.962     0.953     0.958       726
#                               HAIR_CLIPPERS      0.835     0.894     0.863       714
#                                   SUITCASES      0.951     0.964     0.957       582
#                                 BLANK_DISCS      0.840     0.882     0.860       178
#                                    SPEAKERS      0.934     0.950     0.942       525
#                               DVD_RECORDERS      0.951     0.947     0.949       450
#                     KEYBOARD_AND_MOUSE_KITS      0.952     0.938     0.945       275
#                             CAR_SEAT_COVERS      0.988     0.996     0.992       942
#          AUTOMOTIVE_SUSPENSION_CONTROL_ARMS      0.947     0.976     0.961       254
#                           BAR_CODE_SCANNERS      0.980     0.980     0.980       254
#                         AUTOMOTIVE_MOLDINGS      0.947     0.963     0.955       720
#                               BABY_SWIMWEAR      0.892     0.884     0.888       121
#                        TABLE_AND_DESK_LAMPS      0.875     0.862     0.868       260
#                           JACKETS_AND_COATS      0.902     0.912     0.907       815
#                                  CHAMPAGNES      0.781     0.806     0.794        31
#                              FOOTBALL_SHOES      0.989     0.989     0.989       734
#                           CHARMS_AND_MEDALS      0.881     0.860     0.871        86
#                                 MICROPHONES      0.948     0.974     0.961       465
#                         PERMANENT_EPILATORS      0.798     0.798     0.798        94
#                              WOMEN_SWIMWEAR      0.938     0.936     0.937       500
#                  PARTY_DECORATIVE_BACKDROPS      0.936     0.981     0.958       105
#                               ROLLER_SKATES      0.983     0.986     0.985       586
#                                      COMICS      0.767     0.790     0.779       534
#                                       BOOKS      0.677     0.813     0.739       834
#                              CUPCAKE_STANDS      0.571     0.500     0.533         8
#                               UPS_BATTERIES      0.738     0.750     0.744        64
#                                 CAKE_STANDS      0.886     0.867     0.876        45
#            REAR_WHEEL_HUBS_BEARING_ASSEMBLY      0.985     0.990     0.988       401
#                            DIECAST_VEHICLES      0.858     0.899     0.878       606
#                                 CALCULATORS      0.983     0.974     0.978       536
#                                 TV_ANTENNAS      0.974     0.981     0.977       310
#                                 PAPER_CLIPS      0.977     0.843     0.905        51
#                              MALE_UNDERWEAR      0.967     0.964     0.966       422
#                                  ALL_IN_ONE      0.934     0.905     0.919       189
#                            DRINKING_GLASSES      0.816     0.838     0.827       382
#                                       DRUMS      0.888     0.939     0.913       212
#                               WELDING_MASKS      0.982     0.857     0.915        63
#                                    WHISKEYS      0.931     0.966     0.949       267
#                               VIDEO_CAMERAS      0.879     0.784     0.829        37
#                               COFFEE_MAKERS      0.966     0.958     0.962       567
#                        KNEE_BRACES_SUPPORTS      0.902     0.930     0.916       129
#                                 WALL_CLOCKS      0.965     0.971     0.968       480
#                                 WALL_LIGHTS      0.948     0.948     0.948       172
#                              GARDEN_BENCHES      0.714     0.714     0.714        14
#                                  SCULPTURES      0.877     0.895     0.886       437
#                                        FANS      0.968     0.958     0.963       597
#                                 FOUNDATIONS      0.913     0.942     0.927       706
#                                   EYELINERS      0.795     0.700     0.745        50
#                                  DRILL_BITS      0.957     0.923     0.940       143
#                                PC_KEYBOARDS      0.882     0.577     0.698        26
#                               EROTIC_CREAMS      0.842     0.882     0.862       279
#                           DESKTOP_COMPUTERS      0.886     0.861     0.873        36
#                           DECORATIVE_VINYLS      0.919     0.942     0.930       709
#                                 BOARD_GAMES      0.834     0.893     0.863       654
#                         KITCHEN_RANGE_HOODS      0.961     0.961     0.961       309
#                                     DRAWERS      0.990     0.965     0.977       198
#                             FURNITURE_KNOBS      0.900     0.918     0.909       147
#        HOME_APPLIANCE_CONTACTORS_AND_RELAYS      0.948     0.941     0.945       408
#                            SHAVING_MACHINES      0.795     0.762     0.778       449
#                                TOOTHBRUSHES      0.962     0.943     0.952       265
#                     STREAMING_MEDIA_DEVICES      0.905     0.940     0.922       415
#                      CAR_AC_HOSE_ASSEMBLIES      1.000     0.471     0.640        17
#                              SWAY_BAR_LINKS      0.938     0.843     0.888        89
#                               PREAMPLIFIERS      0.375     0.261     0.308        23
#                                  FISH_TANKS      0.941     0.876     0.907       145
#                                      DRONES      0.972     0.960     0.966       653
#                            EMERGENCY_LIGHTS      0.917     0.920     0.919       288
#                                    BLENDERS      0.916     0.936     0.926       452
#                              LASER_MEASURES      0.927     0.927     0.927        55
#                                CASH_DRAWERS      0.971     0.895     0.932        38
#                             CAMERA_CHARGERS      0.916     0.923     0.920       285
#                            CAR_AV_RECEIVERS      0.935     0.934     0.935       589
#                            STEERING_COLUMNS      0.966     0.993     0.979       143
#                                      SKIRTS      0.949     0.974     0.962       154
#                             SANDER_MACHINES      0.948     0.935     0.941       292
#                                RICE_COOKERS      0.980     0.962     0.971        52
#                              BRAKE_BOOSTERS      0.923     0.950     0.936       139
#                                    NETBOOKS      0.939     0.855     0.895       145
#                               FISHING_LURES      0.776     0.776     0.776        67
#                            AUTOMOTIVE_TIRES      0.923     0.750     0.828        80
#                                     STATUES      0.353     0.261     0.300        23
#                                    T_SHIRTS      0.939     0.957     0.948       742
#                             OFFICE_SOFTWARE      0.608     0.549     0.577        82
#                              BABY_CAR_SEATS      0.950     0.964     0.957       550
#                                 WATCH_BANDS      0.894     0.887     0.890       265
#                                        PENS      0.667     0.741     0.702        27
#                   BATHROOM_ACCESSORIES_SETS      0.818     0.808     0.813        78
#                                 CAR_STEREOS      0.847     0.864     0.855       243
#  CELLPHONE_TABLET_AND_GPS_SCREEN_PROTECTORS      0.911     0.923     0.917       155
#                              GLASSES_FRAMES      0.934     0.905     0.919       296
#                                AIRSOFT_GUNS      0.967     0.959     0.963       245
#                                   HAND_FANS      0.788     0.812     0.800        32
#                                  SIDEBOARDS      0.913     0.945     0.929       201
#                            VEHICLE_STICKERS      0.971     0.958     0.965       530
#                              BABY_STROLLERS      0.948     0.972     0.960       468
#                                      MOVIES      0.698     0.620     0.657        71
#                          MICRO_ROTARY_TOOLS      0.928     0.928     0.928        69
#                                   SOUVENIRS      0.913     0.907     0.910       151
#                                      VODKAS      0.935     0.915     0.925        94
#                               PUREBRED_DOGS      0.942     0.962     0.952       705
#                                     VIOLINS      0.967     0.974     0.970       151
#                                 HOVERBOARDS      0.967     0.973     0.970       480
#                      SUSPENSION_BALL_JOINTS      0.977     0.960     0.969       579
#                                   BACKPACKS      0.955     0.974     0.965       699
#                              ADHESIVE_TAPES      0.926     0.945     0.935       253
#                           ELECTRICAL_CABLES      0.972     0.972     0.972       250
#                               COFFEE_TABLES      1.000     0.769     0.870        26
#                  INTERACTIVE_GAMING_FIGURES      0.960     0.963     0.961       246
#                   AUTOMOTIVE_AC_COMPRESSORS      0.943     0.767     0.846        43
#                       HAIRDRESSING_SCISSORS      0.963     0.975     0.969       160
#                                    CUSHIONS      0.897     0.901     0.899       213
#                   THERMAL_CUPS_AND_TUMBLERS      0.872     0.732     0.796        56
#         TV_REPLACEMENT_BACKLIGHT_LED_STRIPS      0.924     0.948     0.936       115
#                         ENGINE_INTAKE_HOSES      0.917     0.944     0.930       373
#                    AUTOMOBILE_FENDER_LINERS      0.889     0.889     0.889        18
#                              DJ_CONTROLLERS      0.763     0.811     0.787       175
#                                STUFFED_TOYS      0.801     0.831     0.816       679
#              MARTIAL_ARTS_AND_BOXING_GLOVES      0.964     0.961     0.963       254
#                               CAMERA_LENSES      0.953     0.922     0.937       219
#                                EROTIC_PUMPS      0.929     0.876     0.902        89
#                               PAINT_ROLLERS      0.909     0.909     0.909        11
#                                MEN_SWIMWEAR      0.800     0.667     0.727        18
#                 PORTABLE_CELLPHONE_CHARGERS      0.956     0.916     0.936       500
#                              ANALOG_CAMERAS      0.848     0.943     0.893       457
#                             HAIR_TREATMENTS      0.682     0.674     0.678        89
#                       DJ_EFFECTS_PROCESSORS      0.643     0.703     0.671       202
#                     BUMPER_IMPACT_ABSORBERS      0.963     0.951     0.957       245
#                  NOTEBOOKS_AND_WRITING_PADS      0.870     0.922     0.895       153
#                         FINGERPRINT_READERS      0.955     0.875     0.913        24
#                                    BLANKETS      0.846     0.878     0.861       131
#                                 SUPPLEMENTS      0.725     0.786     0.754       430
#                                    HAMMOCKS      0.976     0.976     0.976        82
#                AUTOMOTIVE_SIDE_VIEW_MIRRORS      0.969     0.970     0.969       737
#                   FACIAL_SKIN_CARE_PRODUCTS      0.745     0.804     0.773       341
#                             PACKAGING_ROLLS      0.963     1.000     0.981        26
#                       TV_AND_MONITOR_MOUNTS      0.976     0.984     0.980       546
#                                CAR_ANTENNAS      0.998     0.995     0.996       934
#                                    CACHACAS      0.966     0.917     0.941       157
#                                     TV_SMPS      0.843     0.867     0.855       279
#                              KITCHEN_TOWELS      0.972     0.989     0.980       277
#                                    CALIPERS      0.909     0.909     0.909        22
#                             PARKING_SENSORS      0.976     0.985     0.981       539
#                   ELECTRIC_PRESSURE_WASHERS      0.985     0.971     0.978       343
#              HAIR_SHAMPOOS_AND_CONDITIONERS      0.895     0.773     0.829        44
#                                STETHOSCOPES      0.968     0.833     0.896        36
#                                    PRINTERS      0.916     0.930     0.923       400
#                             ELECTRIC_DRILLS      0.943     0.961     0.952       414
#                                KITCHEN_POTS      0.916     0.940     0.928       485
#                              FUEL_INJECTORS      0.833     0.922     0.876       103
#                            VEHICLE_SPEAKERS      0.935     0.950     0.942       421
#                           HOME_OFFICE_DESKS      0.903     0.940     0.921       149
#                              GUITAR_STRINGS      0.900     0.934     0.917       106
#                             DISC_PACKAGINGS      0.853     0.784     0.817        74
#                                 LIP_GLOSSES      0.891     0.900     0.895       190
#                                     DRESSES      0.967     0.971     0.969       692
#                                BASS_GUITARS      0.944     0.934     0.939       467
#                                  TURNTABLES      0.839     0.830     0.834       270
#                           TOY_BUILDING_SETS      0.850     0.839     0.844       249
#                                  BED_SHEETS      0.844     0.867     0.855        75
#                               CAR_GEARBOXES      0.970     0.985     0.978       267
#                                FLOOD_LIGHTS      0.931     0.957     0.943       462
#                          SOLDERING_MACHINES      0.961     0.963     0.962       383
#                            ELECTRONIC_DRUMS      0.889     0.821     0.853       117
#                    DATA_CABLES_AND_ADAPTERS      0.837     0.900     0.867        80
#                      AUTOMOTIVE_WATER_PUMPS      0.913     0.887     0.900       391
#                              FOOTBALL_BALLS      0.951     0.994     0.972       156
#                                LENS_FILTERS      0.932     0.907     0.919        75
#                       INSTRUMENT_AMPLIFIERS      0.862     0.864     0.863       449
#                                MUSIC_STANDS      0.931     0.844     0.885        32
#                        CAR_DISTRIBUTOR_CAPS      0.969     0.917     0.942       205
#                                  MOUSE_PADS      0.970     0.950     0.960       201
#                                     FABRICS      0.904     0.918     0.911       379
#                               CABIN_FILTERS      1.000     1.000     1.000       244
#                             SEWING_MACHINES      0.907     0.938     0.923       292
#                                      MIXERS      0.963     0.957     0.960       350
#                         MOTORCYCLE_FAIRINGS      0.883     0.898     0.890       353
#                                   CV_JOINTS      0.947     0.964     0.955       443
#                  HAIR_STRAIGHTENING_BRUSHES      0.926     0.962     0.943        26
#                             WHEELS_BEARINGS      0.985     0.989     0.987       547
#                                AV_RECEIVERS      0.816     0.803     0.810       188
#                              NETWORK_CABLES      0.942     0.937     0.939       190
#                                       CRIBS      0.883     0.901     0.892       242
#                                HOME_HEATERS      0.894     0.897     0.896       234
#                  BRACELETS_AND_ANKLE_BRACES      0.898     0.887     0.892       346
#                                    SNEAKERS      0.938     0.847     0.891        72
#                  AUTOMOTIVE_THROTTLE_BODIES      0.959     0.940     0.949        50
#                              COOKING_SCALES      0.905     0.930     0.917       412
#                               PEDAL_EFFECTS      0.925     0.924     0.924       695
#                              ENGINE_PISTONS      0.873     0.886     0.880       132
#                               FLATWARE_SETS      0.862     0.806     0.833        31
#                                     PANTIES      0.846     0.898     0.871        49
#                          ELECTRICAL_OUTLETS      0.877     0.934     0.905       122
#                          BABY_CLOTHING_SETS      0.667     0.763     0.712        76
#                              STEAM_CLEANERS      0.923     0.632     0.750        19
#                            DECORATIVE_VASES      0.838     0.909     0.872       274
#                             FOOD_PROCESSORS      0.925     0.822     0.871       135
#                             TRAILER_HITCHES      0.989     0.984     0.986       184
#                       SOFA_AND_FUTON_COVERS      1.000     0.960     0.979        99
#                                      SHIRTS      0.913     0.890     0.901       118
#                       VEHICLE_CLUTCH_CABLES      1.000     1.000     1.000        10
#                                 GATE_MOTORS      0.938     0.956     0.947       298
#                                  FOG_LIGHTS      0.936     0.949     0.942       292
#                                   SIM_CARDS      0.905     0.792     0.844        24
#                               BABY_MONITORS      0.968     0.973     0.971       220
#                            VEHICLE_CV_AXLES      0.985     0.928     0.955        69
#                                   LIPSTICKS      0.941     0.961     0.951       562
#                      SERVING_AND_HOME_TRAYS      0.928     0.915     0.922       354
#                                    COOKTOPS      0.800     0.364     0.500        11
#                              GRAPHICS_CARDS      1.000     0.938     0.968        32
#                          FIRE_EXTINGUISHERS      0.966     0.933     0.949        30
#                  KITCHEN_CABINET_ORGANIZERS      0.333     0.143     0.200         7
#                                       SOFAS      0.867     0.910     0.888       100
#                            GRAPHICS_TABLETS      0.973     0.963     0.968       190
#                                      SHORTS      0.935     0.945     0.940       274
#                            SWIMMING_GOGGLES      0.906     0.753     0.823        77
#                            POOL_INFLATABLES      0.850     0.919     0.883        37
#                                       DOORS      0.768     0.887     0.823        97
#                               SPORT_WATCHES      0.883     0.931     0.906       478
#            PORTABLE_EVAPORATIVE_AIR_COOLERS      0.930     0.862     0.895       138
#              DOG_CARRIERS_AND_CARRYING_BAGS      0.926     0.877     0.901        57
#                     ENGINE_INTAKE_MANIFOLDS      0.980     0.980     0.980        51
#                          MOTORCYCLE_HELMETS      0.985     0.996     0.990       715
#                        COMBUSTION_CHAINSAWS      0.988     0.976     0.982        84
#               ELECTRONIC_ENTRANCE_INTERCOMS      0.938     0.938     0.938       211
#                                     CRAYONS      0.990     0.980     0.985       101
#                                THERMOMETERS      0.924     0.968     0.946        63
#                              CAMERA_TRIPODS      0.950     0.939     0.945       427
#                           ARTIFICIAL_PLANTS      0.760     0.704     0.731        27
#                            PROJECTOR_MOUNTS      0.750     0.600     0.667         5
#                 PORTABLE_ELECTRIC_MASSAGERS      0.843     0.904     0.872        83
#               NON_CORRECTIVE_CONTACT_LENSES      1.000     0.833     0.909        24
#                                     PUZZLES      0.873     0.932     0.902        74
#            WASHING_AND_DRYER_MACHINE_COVERS      0.941     0.960     0.950        50
#                        PUSH_AND_RIDING_TOYS      0.684     0.406     0.510        32
#                                SHOWER_HEADS      0.863     0.881     0.872       235
#                            ANTI_THEFT_STUDS      0.954     0.941     0.947       220
#                               HATS_AND_CAPS      0.818     0.831     0.824        65
#                                   MAGAZINES      0.718     0.587     0.646       143
#                  ENGINE_COOLING_FAN_SHROUDS      0.859     0.952     0.903        83
#                      AUTOMOTIVE_OIL_FILTERS      0.857     0.837     0.847        43
#                            MOTORCYCLE_TIRES      0.856     0.973     0.911       147
#               MOTORCYCLE_TURN_SIGNAL_LIGHTS      0.977     0.977     0.977       221
#                                     PILLOWS      1.000     0.903     0.949        31
#                                    TEQUILAS      0.943     1.000     0.971        33
#                                 TOILET_RUGS      0.854     0.867     0.861       249
#                                      FLUTES      0.880     0.859     0.870       128
#                                    UKULELES      0.943     0.962     0.952        52
#                                 TOOTHPASTES      0.889     0.903     0.896        62
#                       MOTORCYCLE_CRASH_BARS      0.833     0.714     0.769        21
#                             PIPES_AND_TUBES      0.636     0.538     0.583        13
#                                FOOD_SLICERS      0.850     0.773     0.810        22
#           DESKTOP_COMPUTER_COOLERS_AND_FANS      0.923     0.933     0.928       345
#                                   SWAY_BARS      0.929     0.929     0.929        98
#                            AQUARIUM_FILTERS      0.954     0.963     0.958       214
#               CELLPHONE_REPLACEMENT_CAMERAS      0.980     0.941     0.960        51
#                                     MIRRORS      0.875     0.814     0.843        86
#                             BLU_RAY_PLAYERS      0.906     0.880     0.893       175
#                          AUTOMOTIVE_FENDERS      0.908     0.871     0.889       124
#                             SPARKLING_WINES      0.667     0.500     0.571        12
#              ENGINE_VALVES_SPRING_RETAINERS      0.942     0.956     0.949        68
#                                BABY_WALKERS      1.000     0.923     0.960        13
#             ANTIVIRUS_AND_INTERNET_SECURITY      0.933     0.875     0.903        16
#                       COTTON_CANDY_MACHINES      1.000     1.000     1.000         7
#                             ORAL_IRRIGATORS      1.000     0.750     0.857         8
#                    MOTORCYCLE_CLUTCH_COVERS      0.900     0.900     0.900       239
#                               GAME_CONSOLES      0.930     0.876     0.902       347
#                               TABLE_RUNNERS      0.955     0.940     0.947        67
#                           PLAYGROUND_SLIDES      0.909     0.769     0.833        13
#                                 3D_PRINTERS      0.957     0.936     0.946        47
#                                 DIAPER_BAGS      0.960     0.942     0.951       103
#                               ELECTRIC_SAWS      0.983     0.972     0.978       363
#                           KITCHEN_FURNITURE      0.946     0.921     0.933        38
#                            BABY_HIGH_CHAIRS      0.754     0.591     0.662        88
#                                    MINI_PCS      0.538     0.500     0.519        14
#                                    MASCARAS      0.898     0.859     0.878        92
#                     AUTOMOTIVE_WHEEL_COVERS      0.919     0.884     0.901       129
#                           WINDSHIELD_WIPERS      0.974     0.968     0.971       190
#                                     LIQUORS      0.960     0.950     0.955       100
#                            CLOTHING_PATCHES      0.960     0.828     0.889        58
#                       WOOD_BURNING_MACHINES      1.000     0.857     0.923         7
#                                  BINOCULARS      0.919     0.914     0.916       186
#                      COMMERCIAL_LIGHT_SIGNS      0.969     0.969     0.969        32
#                            WATER_DISPENSERS      0.964     0.947     0.955       225
#                       GLOW_PLUG_CONTROLLERS      0.891     0.875     0.883        56
#                                  TELEPHONES      0.882     0.714     0.789        21
#                             AIR_COMPRESSORS      0.910     0.949     0.929       353
#                           OPERATING_SYSTEMS      0.864     0.848     0.856       270
#                        CAR_ENGINE_CAMSHAFTS      0.750     1.000     0.857        15
#                             CLOTHES_HANGERS      0.957     0.957     0.957        92
#                                    WETSUITS      1.000     0.737     0.848        19
#                                TOILET_SEATS      1.000     0.984     0.992       191
#                            AUTOMOTIVE_DOORS      0.979     0.976     0.977       332
#             SUSPENSION_CONTROL_ARM_BUSHINGS      0.841     0.768     0.803       138
#                          VEHICLE_BRAKE_PADS      0.961     0.980     0.970       350
#                 REMOTE_CONTROL_TOY_VEHICLES      0.920     0.876     0.897       209
#                        AUTOMOTIVE_NERF_BARS      1.000     1.000     1.000        38
#                              ESSENTIAL_OILS      0.845     0.754     0.797        65
#                             SLATWALL_PANELS      0.963     0.963     0.963        80
#                                  TOOL_BOXES      0.896     0.945     0.920       109
#                                BABY_DIAPERS      0.986     0.971     0.978       375
#                          ALARMS_AND_SENSORS      0.898     0.892     0.895       295
#                            MOTORCYCLE_SUITS      0.921     0.946     0.933        37
#                               KITCHEN_BOWLS      0.800     0.545     0.649        22
#                              CAT_SCRATCHERS      0.917     0.733     0.815        15
#                              INK_CARTRIDGES      0.750     0.600     0.667        30
#                    MARKERS_AND_HIGHLIGHTERS      0.845     0.865     0.855       126
#                      JUMPSUITS_AND_OVERALLS      0.885     0.802     0.842       106
#                                 NAIL_DRYERS      0.992     0.924     0.957       131
#                             CAMERA_MONOPODS      0.780     0.796     0.788        49
#                                    BICYCLES      0.972     0.935     0.953       184
#                                        SALT      1.000     0.900     0.947        10
#                    SCREEN_PRINTING_MACHINES      0.636     0.500     0.560        14
#                                        BEDS      0.929     0.907     0.918        43
#                     BODY_SKIN_CARE_PRODUCTS      0.720     0.766     0.742       380
# AUTOMOTIVE_MANUAL_TRANSMISSION_SHIFT_LEVERS      0.750     0.600     0.667        25
#                            TV_STORAGE_UNITS      0.870     0.904     0.887        52
#                       AUTOMOTIVE_HEADLIGHTS      0.912     0.954     0.933       131
#                                  PAINTBALLS      0.878     0.929     0.903        85
#                                      SCREWS      0.862     0.877     0.870        57
#                                  TOY_ROBOTS      0.667     0.400     0.500        15
#                                     POSTERS      0.943     0.956     0.949       206
#                            MOTORCYCLE_PANTS      0.942     0.822     0.878       118
#                         INTEGRATED_CIRCUITS      0.677     0.611     0.642        72
#                                GARDEN_HOSES      0.914     0.946     0.930        56
#                                 ALTERNATORS      0.857     0.875     0.866        48
#                          MAGNIFYING_GLASSES      0.955     0.869     0.910       122
#                                    PERFUMES      0.887     0.904     0.895        52
#                                       FLOUR      0.938     1.000     0.968        15
#                                FISHING_RODS      0.773     0.895     0.829        19
#                  CELLPHONE_AND_TABLET_CASES      0.838     0.912     0.874        91
#                                     PAJAMAS      0.946     0.946     0.946        56
#                                  BUTT_PLUGS      0.725     0.853     0.784        34
#                 LUMBAR_AND_ABDOMINAL_BRACES      0.973     0.973     0.973       147
#                              AIR_MATTRESSES      0.966     0.909     0.936       154
#                               WATER_HEATERS      0.991     0.935     0.963       247
#                                 DISHWASHERS      0.965     0.939     0.952       148
#                        ELECTRIC_LAWN_MOWERS      1.000     0.750     0.857         4
#                               HOME_THEATERS      0.750     0.333     0.462         9
#                            LED_STAGE_LIGHTS      0.821     0.787     0.804       216
#           CHALKBOARD_AND_WHITEBOARD_ERASERS      1.000     0.870     0.930        23
#                               BABY_BOUNCERS      0.812     0.722     0.765        18
#                                       RINGS      0.804     0.860     0.831        43
#                      AUTOMOTIVE_AIR_FILTERS      0.981     0.964     0.972        55
#                                LUGGAGE_TAGS      0.932     0.872     0.901        47
#                                HEATER_CORES      0.938     0.714     0.811        21
#                             CLEANING_CLOTHS      0.882     0.882     0.882        93
#                              AIR_FRESHENERS      0.611     0.512     0.557        43
#                                     BLOUSES      0.659     0.711     0.684        38
#                             SAFETY_FOOTWEAR      0.914     0.970     0.941        66
#                                FREEZER_BAGS      0.750     0.750     0.750         8
#                      SHOCK_MOUNT_INSOLATORS      0.805     0.849     0.827        73
#                                  BAR_CLAMPS      0.800     0.500     0.615        16
#                             CHRISTMAS_TREES      0.971     0.919     0.944        37
#                          CAR_AIR_FRESHENERS      0.759     0.859     0.806        99
#                          BASKETBALL_JERSEYS      1.000     0.733     0.846        15
#                                  ACCORDIONS      0.971     0.961     0.966       311
#                                  FOOD_CARTS      0.966     0.903     0.933        31
#                                   HEAT_GUNS      0.989     0.989     0.989        94
#                   ENGINE_CRANKSHAFT_PULLEYS      0.899     0.916     0.907       107
#                                  PARTY_HATS      0.571     0.500     0.533         8
#                             RECEPTION_DESKS      1.000     1.000     1.000         4
#                              PICTURE_FRAMES      0.906     0.894     0.900       151
#                               OSCILLOSCOPES      0.900     0.900     0.900        10
#                   HABERDASHERY_LACE_EDGINGS      0.935     0.917     0.926       109
#                                       BEERS      0.970     0.965     0.968       170
#                                HOLE_PUNCHES      1.000     0.571     0.727         7
#                               DJ_TURNTABLES      0.697     0.575     0.630        80
#                                 VR_HEADSETS      0.974     0.974     0.974       352
#                             KITCHEN_MORTARS      1.000     0.500     0.667         4
#                                       OVENS      0.944     0.982     0.963       171
#                                DISHES_RACKS      0.698     0.612     0.652        49
#                                    EARRINGS      0.889     0.909     0.899        44
#                                   WARDROBES      0.921     0.972     0.946        36
#                           RACKS_AND_PINIONS      0.964     0.938     0.951       113
#                                   BOOKCASES      0.757     0.800     0.778        35
#                                  TOY_TRAINS      0.847     0.766     0.804        94
#                      CARD_PAYMENT_TERMINALS      0.867     0.765     0.812        17
#                           SUBMERSIBLE_PUMPS      0.959     0.940     0.949       100
#             GARDENING_AND_AGRICULTURE_SEEDS      0.892     0.917     0.904        36
#                                      MODEMS      0.797     0.829     0.813       123
#                               OFFICE_CHAIRS      0.861     0.888     0.874        98
#                                   PENDRIVES      0.903     0.935     0.919       139
#                                   NECKLACES      0.840     0.868     0.854        91
#                          ENGINE_GASKET_SETS      0.556     0.294     0.385        17
#                  AUTOMOTIVE_SHOCK_ABSORBERS      0.655     0.864     0.745        66
#                                 VINYL_ROLLS      0.643     0.643     0.643        70
#               TROLLEY_AND_FURNITURE_CASTERS      0.000     0.000     0.000         4
#                   TV_RECEIVERS_AND_DECODERS      0.824     0.778     0.800        18
#                                LIFE_JACKETS      0.778     0.636     0.700        22
#                        SELF_ADHESIVE_LABELS      0.739     0.694     0.716        49
#                   IGNITION_SWITCH_ACTUATORS      1.000     1.000     1.000        14
#                            BABY_STERILIZERS      0.889     0.727     0.800        22
#                       PARKING_BRAKE_HANDLES      0.967     0.967     0.967        61
#                      CLUTCH_SLAVE_CYLINDERS      0.750     0.800     0.774        30
#                                      FISHES      0.667     0.667     0.667         9
#                             COOKIES_CUTTERS      0.875     0.818     0.846        77
#                                  NEBULIZERS      0.880     0.898     0.889        49
#                                  COMFORTERS      0.667     0.800     0.727        20
#                         ELLIPTICAL_MACHINES      0.889     0.875     0.882       128
#                               ENGINE_VALVES      0.857     0.818     0.837        44
#                                  SANDPAPERS      0.778     0.667     0.718        21
#        AUTOMOTIVE_SHOCK_ABSORBER_BUMP_STOPS      0.970     0.865     0.914        37
#                                     GAZEBOS      0.977     0.945     0.961        91
#                                  XENON_KITS      0.765     0.650     0.703        20
#                      AUTOMOTIVE_DOOR_PANELS      0.973     0.967     0.970       150
#                  INDOOR_CURTAINS_AND_BLINDS      0.930     0.913     0.922       161
#                         CAR_WINDOW_SWITCHES      0.867     0.839     0.852        31
#                                   EPILATORS      0.845     0.755     0.798        94
#                           MALE_MASTURBATORS      0.846     0.733     0.786        15
#                         DRILLS_SCREWDRIVERS      0.600     0.625     0.612        24
#                                  CONCEALERS      0.877     0.807     0.840        88
#                     SCHOOL_AND_OFFICE_GLUES      0.615     0.800     0.696        10
#                      SANDALS_AND_FLIP_FLOPS      0.935     0.956     0.945        45
#                                   BAR_SOAPS      0.770     0.783     0.777        60
#                   ELECTRIC_BATHROOM_FAUCETS      0.792     0.760     0.776        25
#                           VOLTAGE_DETECTORS      1.000     0.897     0.945        29
#                     ORTHOPEDIC_ANKLE_BRACES      1.000     0.733     0.846        15
#                              HEDGE_TRIMMERS      1.000     1.000     1.000        14
#                         STABILIZERS_AND_UPS      0.667     1.000     0.800         2
#                               BABY_PLAYARDS      0.892     0.827     0.858       110
#                            RESISTANCE_BANDS      0.902     0.917     0.909       180
#                             LAPTOP_CHARGERS      0.908     0.868     0.887        68
#                       COMPUTER_MOTHERBOARDS      0.810     0.829     0.819        41
# ...
#                            LIVING_ROOM_SETS      0.818     0.643     0.720        14
#                              BABY_PACIFIERS      1.000     0.867     0.929        15
#                              HAND_POLISHERS      0.750     0.643     0.692        14
#                                SHADE_CLOTHS      1.000     1.000     1.000        12
#                               HAMMER_DRILLS      0.667     0.250     0.364         8
#                              POWER_GRINDERS      1.000     0.692     0.818        13
#                               CAMERA_STRAPS      1.000     0.667     0.800         3
#                           LAWN_MOWER_BLADES      0.700     0.778     0.737         9
#                          PNEUMATIC_STAPLERS      1.000     1.000     1.000        13
#              THERMAL_REFRIGERATORS_AND_BAGS      1.000     0.679     0.809        28
#                                LIGHT_STANDS      0.750     0.429     0.545         7
#                                      STRAWS      1.000     0.625     0.769         8
#                                       SUITS      0.750     0.636     0.689        33
#                           BATHROOM_VANITIES      0.667     0.500     0.571         8
#                         VIBRATION_PLATFORMS      0.750     0.833     0.789        18
#                               DINING_TABLES      1.000     0.750     0.857        16
#                           TURNTABLE_NEEDLES      1.000     0.667     0.800         3
#                                HEARING_AIDS      1.000     0.800     0.889        10
#                     ORTHOPEDIC_WALKER_BOOTS      0.800     0.571     0.667        14
#                                         TEA      0.833     0.500     0.625        10
#                             TORQUE_WRENCHES      1.000     1.000     1.000         8
#                                 CATS_LITTER      1.000     0.917     0.957        12
#                                 MATE_GOURDS      1.000     0.455     0.625        11
#                                  MEAT_HOOKS      0.500     1.000     0.667         2
#                       AUTOMOTIVE_DEFLECTORS      1.000     1.000     1.000         5
#                   VARIABLE_FREQUENCY_DRIVES      1.000     0.857     0.923         7
#                                  SWEETENERS      1.000     0.875     0.933         8
#         AUTOMOTIVE_CELLPHONE_AND_GPS_MOUNTS      0.667     0.667     0.667         6
#                         RADIO_BASE_STATIONS      0.000     0.000     0.000         6
#                                    CRUTCHES      1.000     1.000     1.000         4
#                                POWER_STRIPS      1.000     0.600     0.750        10
#                               KATANA_SWORDS      0.900     0.692     0.783        13
#                        CATS_AND_DOGS_TREATS      0.800     0.571     0.667        14
#                         MEMORY_CARD_READERS      0.667     0.667     0.667         3
#                            TELEPHONE_CABLES      1.000     0.929     0.963        14
#                          SOLID_SWEET_PASTES      0.875     0.700     0.778        10
#                           DISPOSABLE_GLOVES      1.000     0.333     0.500         3
#                        MOTORCYCLE_GRAB_BARS      0.750     1.000     0.857         3
#                              PLUNGE_ROUTERS      1.000     0.500     0.667         8
#                         GROOVE_JOINT_PLIERS      0.800     1.000     0.889         4
#                          BICYCLE_HANDLEBARS      0.750     0.600     0.667         5
#                          SOLDERING_STATIONS      0.857     0.923     0.889        26
#                               TANDEM_CHAIRS      0.333     0.286     0.308         7
#                                GARAGE_DOORS      0.889     0.667     0.762        12
#                         SPARK_PLUG_WIRESETS      1.000     0.812     0.897        32
#                       ELECTRIC_SHOWER_HEADS      0.333     0.200     0.250         5
#                        PORTABLE_DVD_PLAYERS      0.500     0.111     0.182         9
#                                      DILDOS      0.400     0.250     0.308         8
#                   INDUSTRIAL_DOUGH_KNEADERS      0.786     0.846     0.815        13
#                   UNIVERSAL_REMOTE_CONTROLS      1.000     0.333     0.500         3
#                                 WHEEL_STUDS      1.000     0.167     0.286         6
#                            FABRIC_SOFTENERS      0.783     0.947     0.857        19
#              MOTORCYCLE_DISTRIBUTION_CHAINS      0.889     0.842     0.865        19
#                       DOOR_AND_WINDOW_LOCKS      1.000     0.333     0.500         3
#                                        GINS      1.000     1.000     1.000         4
#                                 HAND_TRUCKS      1.000     0.500     0.667         4
#                                    STAPLERS      0.800     0.667     0.727         6
#                                   APERITIFS      0.500     0.200     0.286         5
#                             SHOWER_CURTAINS      1.000     1.000     1.000         4
#                              ANTIQUE_CHAIRS      1.000     0.286     0.444         7
#                               YOGURT_MAKERS      0.667     0.400     0.500         5
#                                 SHIN_GUARDS      1.000     0.500     0.667         2
#                             GOLF_CLUBS_SETS      1.000     0.667     0.800         9
#                  FOOTBALL_GOALKEEPER_GLOVES      0.923     0.750     0.828        16
#                                LASER_LEVELS      0.700     0.875     0.778         8
#                        KEYBOARD_CONTROLLERS      0.000     0.000     0.000         5
#                          ALTERNATOR_PULLEYS      0.923     0.706     0.800        17
#            CAMERA_AND_CELLPHONE_STABILIZERS      1.000     0.667     0.800         3
#                                BABY_JUMPERS      0.750     0.500     0.600         6
#                 CAMERA_REPLACEMENT_DISPLAYS      1.000     0.714     0.833         7
#                                 CRANKSHAFTS      0.947     0.857     0.900        21
#                                BREAD_MAKERS      0.500     0.667     0.571         3
#                    SCHOOL_AND_OFFICE_PAPERS      0.667     0.250     0.364         8
#                    STOVETOP_POPCORN_POPPERS      0.857     0.750     0.800         8
#                      BREAST_FEEDING_PILLOWS      0.750     0.545     0.632        11
#                               POOL_CLEANERS      1.000     0.600     0.750         5
#                              LINEMAN_PLIERS      0.667     0.667     0.667         3
#                                  COAT_RACKS      0.750     0.500     0.600         6
#                                  POOL_PUMPS      0.769     0.833     0.800        12
#                     WATER_PURIFIERS_FILTERS      0.812     0.650     0.722        20
#                               SAFETY_GLOVES      0.500     0.333     0.400         6
#                          ISOPROPYL_ALCOHOLS      1.000     0.778     0.875         9
#               VEHICLE_BRAKE_HYDRAULIC_HOSES      1.000     0.778     0.875         9
#                              MEDICINE_BALLS      1.000     0.250     0.400         4
#                             KITCHEN_GRATERS      0.600     0.600     0.600         5
#                              NAPKIN_HOLDERS      0.800     0.444     0.571         9
#                               PUNCHING_BAGS      0.250     0.333     0.286         3
#                                 ESPADRILLES      0.800     0.500     0.615         8
#                         CAR_CENTER_CONSOLES      0.625     0.833     0.714         6
#                             VIDEO_CASSETTES      1.000     0.500     0.667         6
#                              POTENTIOMETERS      1.000     0.400     0.571         5
#                    READY_TO_DRINK_COCKTAILS      0.000     0.000     0.000         2
#                                 FLOOR_LAMPS      0.875     0.636     0.737        11
#                            DRONE_PROPELLERS      1.000     0.667     0.800         6
#                                       TENTS      0.786     1.000     0.880        11
#                            SAFETY_HARNESSES      1.000     0.500     0.667         4
#                                    SYRINGES      1.000     0.750     0.857         4
#                                   BEDLINERS      0.867     0.812     0.839        16
#                     ELECTROLYTIC_CAPACITORS      1.000     0.714     0.833         7
#                                BASKET_BALLS      1.000     1.000     1.000         2
#                                   OTOSCOPES      1.000     1.000     1.000         4
#                               WAFFLE_MAKERS      0.750     0.375     0.500         8
#                                 PENIS_RINGS      1.000     0.250     0.400         4
#                          ELECTRIC_AIR_PUMPS      0.875     0.875     0.875         8
#                             COFFEE_CAPSULES      1.000     0.600     0.750         5
#                         BABY_PACIFIER_CLIPS      0.556     1.000     0.714         5
#                                   KEY_RACKS      0.500     0.750     0.600         4
#                                  DEODORANTS      1.000     0.800     0.889         5
#                          INDUSTRIAL_PULLEYS      1.000     0.800     0.889         5
#                               BILL_COUNTERS      1.000     0.800     0.889         5
#                  AUDIO_AND_VIDEO_CONNECTORS      0.000     0.000     0.000         4
#                            WASHING_MACHINES      1.000     0.833     0.909        12
#                 ENGINE_COOLING_FAN_SWITCHES      0.667     0.667     0.667         6
#                        AUTOMOTIVE_BATTERIES      0.500     0.200     0.286         5
#                        CHIP_AND_DIP_SERVERS      0.000     0.000     0.000         4
#                                ARCHERY_BOWS      0.857     1.000     0.923         6
#                             VINYL_FLOORINGS      0.600     0.429     0.500         7
#                              MENSTRUAL_CUPS      1.000     1.000     1.000         5
#                               SLEEPING_BAGS      1.000     0.500     0.667         4
#                               RUBBER_STAMPS      0.667     0.800     0.727         5
#                              DRYER_MACHINES      1.000     0.750     0.857         8
#                            ENERGETIC_STONES      0.429     0.429     0.429         7
#                              BICYCLE_PEDALS      1.000     0.667     0.800         9
#                      MOTORCYCLE_CARBURETORS      0.667     0.800     0.727         5
#                           SCREWDRIVERS_SETS      1.000     0.333     0.500         3
#                                EDIBLE_SEEDS      0.500     0.333     0.400         3
#                        STORE_SHOPPING_CARTS      1.000     0.750     0.857         4
#                         SWIMMING_NOSE_CLIPS      1.000     0.500     0.667         2
#                                 AFTERSHAVES      0.000     0.000     0.000         3
#                              AIRBAG_MODULES      1.000     1.000     1.000         3
#                                   HAND_SAWS      1.000     1.000     1.000         6
#           NECK_GAITERS_MASKS_AND_BALACLAVAS      0.000     0.000     0.000         2
#                          MAGNETIC_COMPASSES      0.800     0.667     0.727         6
#                          MAKEUP_TRAIN_CASES      1.000     0.500     0.667         4
#                            POPCORN_MACHINES      1.000     1.000     1.000         9
#                                LAMP_HOLDERS      0.250     0.250     0.250         4
#                    IGNITION_CONTROL_MODULES      0.250     0.143     0.182         7
#                             CAR_FRONT_MASKS      0.667     1.000     0.800         2
#                               HAND_BLENDERS      0.000     0.000     0.000         3
#                              KIDS_TRICYCLES      1.000     1.000     1.000         4
#                              AIRGUN_PELLETS      0.667     0.500     0.571         4
#                            AUTOMOTIVE_SEATS      0.500     0.333     0.400         6
#              MOTORCYCLE_TRANSMISSION_CROWNS      0.500     0.250     0.333         4
#                                  LAMINATORS      1.000     0.714     0.833         7
#                                 CEREAL_BARS      1.000     0.667     0.800         3
#                                MUSIC_ALBUMS      0.500     0.250     0.333         4
#                   AUTOMOTIVE_CV_JOINT_BOOTS      0.833     0.714     0.769         7
#                           MICROWAVE_KEYPADS      1.000     0.667     0.800         3
#                           WALL_ANCHOR_PLUGS      0.750     0.750     0.750         4
#                                 DRUM_STANDS      1.000     0.286     0.444         7
#                                 PET_COLLARS      0.909     0.714     0.800        14
#                             GATE_GEAR_RACKS      1.000     0.500     0.667         4
#                                   CAR_HOODS      1.000     1.000     1.000         3
#                        SCREEN_PRINTING_KITS      0.333     0.250     0.286         4
#                                  LED_STRIPS      1.000     0.500     0.667         4
#                             SANDWICH_MAKERS      0.000     0.000     0.000         2
#                              DENTAL_FLOSSES      1.000     1.000     1.000         2
#                              CAMERA_FLASHES      1.000     0.800     0.889         5
#                           DOG_NAIL_CLIPPERS      1.000     0.500     0.667         2
#                                    PINBALLS      0.500     0.333     0.400         6
#                                      GAUZES      1.000     0.667     0.800         6
#                                        SODS      0.667     0.667     0.667         3
#                          ELECTRICITY_METERS      0.000     0.000     0.000         4
#                             METAL_DETECTORS      1.000     0.667     0.800         3
#                          ELECTRIC_CHAINSAWS      1.000     0.333     0.500         3
#                            KNITTING_NEEDLES      0.600     0.500     0.545         6
#                           SWIMMING_EARPLUGS      0.000     0.000     0.000         2
#                                 SOUND_CARDS      1.000     0.200     0.333         5
#                                    STEPPERS      0.750     0.750     0.750         4
#                                 FANNY_PACKS      0.667     0.500     0.571         4
#                          TOOTHBRUSH_HOLDERS      0.000     0.000     0.000         2
#                          TABLE_TENNIS_BALLS      1.000     0.500     0.667         2
#                 ENGINE_OIL_PRESSURE_SENSORS      0.667     0.667     0.667         3
#                                 ICE_BUCKETS      1.000     0.571     0.727         7
#                               MASSAGE_SOFAS      1.000     0.250     0.400         4
#                              STYLING_CHAIRS      0.500     0.500     0.500         2
#                               BICYCLE_SEATS      0.500     0.333     0.400         3
#                            VOLLEYBALL_BALLS      0.000     0.000     0.000         3
#                           SPHYGMOMANOMETERS      0.500     0.250     0.333         4
#                              BINDING_SPINES      0.500     0.500     0.500         2
#                    DIGITAL_WEATHER_STATIONS      1.000     0.500     0.667         2
#                          HOME_BOTTLE_STANDS      1.000     0.667     0.800         3
#                                   DOORBELLS      0.500     0.500     0.500         2
#                                DRIED_FRUITS      0.667     1.000     0.800         2
#                            BOXING_HEADGEARS      1.000     0.500     0.667         2
#
#                                    accuracy                          0.916    138550
#                                   macro avg      0.852     0.782     0.805    138550
#                                weighted avg      0.916     0.916     0.915    138550
