# %% [markdown]
# #### Based on https://medium.com/swlh/painless-fine-tuning-of-bert-in-pytorch-b91c14912caa
# https://github.com/aniruddhachoudhury/BERT-Tutorials/blob/master/Blog%202/BERT_Fine_Tuning_Sentence_Classification.ipynb

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import matplotlib.pyplot as plt
import torch.nn as nn
from os.path import join
import sys
import torch
from nlpClassifiers.data.dataset  import NLPDataset
#from torch.optim import AdamW, SGD
from torch.utils.data import DataLoader, SequentialSampler, RandomSampler
from transformers import BertForSequenceClassification, AdamW, BertConfig
from transformers import get_linear_schedule_with_warmup
from torch.nn import LayerNorm as BertLayerNorm
import numpy as np
import time
import logging
import datetime
import random
import pandas as pd
import argparse
import pickle as pk
import itertools
import os
import shutil
from pathlib import Path
import copy
import wandb
import re
from nlpClassifiers import settings
from scipy.special import expit
from sklearn.metrics import classification_report
# Out:
# wandb: WARNING W&B installed but not logged in.  Run `wandb login` or set the WANDB_API_KEY env variable.

# %%
def predict(
    model_path: Path,
    dataset: str,
    batch_size: int,
    labels_dict,
    device: torch.device
):
       
    print(f"====Loading dataset for testing")
    test_corpus = NLPDataset(dataset, "test", sentence_max_len, bert_path, labels_dict)
    test_dataloader = DataLoader(
        test_corpus,
        batch_size=batch_size,
        sampler = RandomSampler(test_corpus),
        pin_memory=True,
        num_workers=0,
        drop_last=True
    )

    print(f"====Loading model for testing")
    model = BertForSequenceClassification.from_pretrained(
        model_path,
        num_labels = test_corpus.num_labels,
        output_attentions = False,
        output_hidden_states = True,
    )
    model.to(device)
    model.eval()
  #  cm = ConfusionMatrix([0,1])
    pred_labels = []
    test_labels = []
    logits_list = []

    def _list_from_tensor(tensor):
        if tensor.numel() == 1:
            return [tensor.item()]
        return list(tensor.cpu().detach().numpy())

    print("====Testing model...")
    for batch in test_dataloader:
        batch = tuple(t.to(device) for t in batch)
        b_input_ids, b_segment_ids, b_input_mask, b_labels = batch
        with torch.no_grad():
            loss, logits, *_ =  model(b_input_ids, b_input_mask, token_type_ids=None, labels=b_labels)

            preds = np.argmax(logits.cpu(), axis=1) # Convert one-hot to index
            b_labels = b_labels.int()
            pred_labels.extend(_list_from_tensor(preds))
            test_labels.extend(_list_from_tensor(b_labels))
        logits_list.extend(_list_from_tensor(logits))
    print(classification_report(test_labels, pred_labels, labels=list(labels_dict.values()), target_names=np.array(list(labels_dict.keys())), digits=3))
    logits_list = expit(logits_list)
    del model
    torch.cuda.empty_cache()

# %%
def get_accuracy_from_logits(logits, labels):
    acc = (labels.cpu() == logits.cpu().argmax(-1)).float().detach().numpy()
    return float(100 * acc.sum() / len(acc))

# %%
# !tail -n 10 ../../data/mercado-livre-pt-only/train.csv
# Out:
# protetor porta flexivel gm chevette 1990 preto univ,AUTOMOTIVE_WEATHERSTRIPS
# fogao vintage pecas original continental,RANGES
# 100 adesivos bolo no pote etiqueta rotulo personalizado 5 cm,SELF_ADHESIVE_LABELS
# eliptico caloi act home fitness clt 20,ELLIPTICAL_MACHINES
# gravar conversa do skype produtos espionagem grava audio bd1,DIGITAL_VOICE_RECORDERS
# 12 faca desossar inox 5 plenus pre tramontina 23425005,KITCHEN_KNIVES
# controle n64 usb,GAMEPADS_AND_JOYSTICKS
# pinceis daymakeup- 1 pincel delinear- temos todos os pinceis,MAKEUP_BRUSHES
# _protetor solar de parabrisa kangoo express logan master,AUTOMOTIVE_WEATHERSTRIPS
# chave combinada tramontina 19 ee51071,WRENCHES

# %%
DATA_PATH = '../../data/virtual-operator'
MODELS_PATH = '../../models/virtual-operator/bert-base-portuguese-tapt-classifier/'
PATH_TO_BERT = '../../models/virtual-operator/bertimbau-adaptive-base-finetuned/'
TRAIN_DATASET = os.path.join(DATA_PATH, 'train.csv')
VAL_DATASET = os.path.join(DATA_PATH, 'val.csv')
TEST_DATASET  = os.path.join(DATA_PATH, 'test.csv')
PATH_TO_VIRTUAL_OPERATOR_MODELS =  "../../models/virtual-operator"
PATH_TO_AGENT_BENCHMARK_MODELS = "../../models/agent-benchmark"
PATH_TO_ML_PT_MODELS = "../../models/mercado-livre-pt-only"

# %%
gpu = 7
dataset = 'mercado-livre-pt'
save_name = 'mercado-livre-pt-100-epochs-early-stop-reset-multilingual-base-dataset-fixed'
bert_path = 'bert-base-multilingual-cased'
batch_size = 16
sentence_max_len = 30

# %%
BASE_PATH_TO_MODELS = {"virtual-operator": PATH_TO_VIRTUAL_OPERATOR_MODELS, "agent-benchmark": PATH_TO_AGENT_BENCHMARK_MODELS, "mercado-livre-pt": PATH_TO_ML_PT_MODELS}
FULL_PATH_TO_MODELS = join(BASE_PATH_TO_MODELS[dataset], "bert-base-portuguese-tapt-classifier")

# %%
device = torch.device(f"cuda:{gpu}")

# %%
model_path = Path(
    FULL_PATH_TO_MODELS, 
    f"base-dataset-{dataset}-{save_name}"
)
last_saved_model = model_path

# %%
train_corpus = NLPDataset(dataset, "train", sentence_max_len, bert_path)
labels_dict = train_corpus.labels_dict

# %%
predict(last_saved_model, dataset, batch_size, labels_dict, device)
# Out:
# ====Loading dataset for testing
# ====Loading model for testing
# ====Testing model...
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/_classification.py:1221: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#                                              precision    recall  f1-score   support
#
#                               FISHING_LINES      0.933     0.908     0.920       584
#                      MOBILE_DEVICE_CHARGERS      0.984     0.965     0.974       804
#                                  SUNGLASSES      0.985     0.974     0.979       875
#                                    FREEZERS      0.922     0.953     0.937       444
#                                  CAR_WHEELS      0.990     0.997     0.994       720
#                            BATHROOM_FAUCETS      0.911     0.900     0.905       521
#                              ACTION_FIGURES      0.800     0.740     0.769       800
#                                       IRONS      0.988     0.982     0.985       433
#                                  MATTRESSES      0.991     0.985     0.988       534
#                       SWIMMING_POOL_HEATERS      0.870     0.952     0.909        21
#                              KITCHEN_KNIVES      0.960     0.950     0.955       202
#                                 TELEVISIONS      0.960     0.966     0.963       728
#                    SPORT_AND_BAZAAR_BOTTLES      0.923     0.939     0.931       229
#                                    STARTERS      0.975     0.977     0.976       354
#                                  FACE_MASKS      0.853     0.910     0.880       166
#                             KITCHEN_FAUCETS      0.895     0.914     0.905       431
#     TACTICAL_AND_SPORTING_KNIVES_AND_BLADES      0.975     0.957     0.966       164
#                                   NOTEBOOKS      0.935     0.954     0.944       543
#                                 DEEP_FRYERS      0.984     0.960     0.972       455
#                                TORSION_BARS      1.000     1.000     1.000       123
#                            AUDIO_AMPLIFIERS      0.773     0.900     0.832       311
#                              CEILING_LIGHTS      0.943     0.972     0.957       472
#                                       BELTS      0.925     1.000     0.961        49
#                    AUTOMOTIVE_WEATHERSTRIPS      0.952     0.983     0.967       787
#                                  HEADBOARDS      1.000     0.987     0.993       228
#                                       YARNS      0.887     0.944     0.915       142
#                                SMARTWATCHES      0.956     0.964     0.960       724
#                             FOOTBALL_SHIRTS      0.967     0.979     0.973       921
#                      AUTOMOTIVE_CLUTCH_KITS      0.993     0.997     0.995       719
#                                WRISTWATCHES      0.977     0.962     0.970       876
#                                  WALLPAPERS      0.968     0.954     0.961       885
#         AUTOMOTIVE_SIDE_VIEW_MIRROR_GLASSES      0.987     0.994     0.991       536
#                            AUDIO_INTERFACES      0.958     0.920     0.939       300
#                            KITCHEN_PLAYSETS      0.960     0.970     0.965       100
#                                 LIGHT_BULBS      0.968     0.961     0.965       829
#                              CELL_BATTERIES      0.971     0.963     0.967       670
#                        SURVEILLANCE_CAMERAS      0.935     0.905     0.920       908
#                                   THERMOSES      0.854     0.820     0.837       100
#                  HUMIDIFIERS_AND_VAPORIZERS      0.971     0.965     0.968       173
#                              KITCHEN_APRONS      0.870     0.741     0.800        27
#                         PORTABLE_GENERATORS      0.985     1.000     0.992       132
#                                  CELLPHONES      0.975     0.933     0.953       329
#                            HANDICRAFT_BOXES      0.897     0.777     0.833       112
#                         EMBROIDERY_MACHINES      0.917     0.863     0.889        51
#                                     CAMERAS      0.855     0.772     0.811        92
#             DESKTOP_COMPUTER_POWER_SUPPLIES      0.984     0.991     0.988       679
#                              BABIES_FORMULA      0.989     1.000     0.994        88
#                     MOTORCYCLE_SPEEDOMETERS      1.000     0.750     0.857         4
#                                     CARPETS      0.973     0.975     0.974       857
#                       CARDS_AND_INVITATIONS      0.907     0.830     0.867        47
#                            ELECTRIC_GUITARS      0.968     0.979     0.974       778
#                           COMPUTER_MONITORS      0.977     0.973     0.975       701
#                          MULTIGAME_MACHINES      0.833     0.909     0.870        77
#                                 TABLECLOTHS      0.987     0.982     0.984       544
#                                   VIBRATORS      0.878     0.863     0.871       117
#                                      PLANTS      0.987     0.981     0.984       313
#                                AM_FM_RADIOS      0.951     0.961     0.956       383
#                      ENGINE_CONTROL_MODULES      0.998     0.998     0.998       415
#             LATEX_ENAMEL_AND_ACRYLIC_PAINTS      1.000     1.000     1.000        67
#             MUSICAL_KEYBOARD_CASES_AND_BAGS      0.988     0.989     0.989       760
#                                 VIDEO_GAMES      0.974     0.993     0.984       908
#                          ARTIFICIAL_FLOWERS      0.943     0.960     0.951       497
#                          OUTER_TIE_ROD_ENDS      0.996     0.976     0.986       496
#                           EXHAUST_MANIFOLDS      0.727     1.000     0.842         8
#                     DIGITAL_VOICE_RECORDERS      0.908     0.935     0.922       774
#                               REFRIGERATORS      0.967     0.950     0.959       524
#                             DISPOSABLE_CUPS      0.885     0.856     0.870       188
#                                  EYESHADOWS      0.990     0.972     0.981       738
#                                      RANGES      0.975     0.964     0.970       450
#          AUTOMOTIVE_POWER_WINDOW_REGULATORS      0.985     0.935     0.959       138
#                                     HOOKAHS      1.000     0.970     0.985       168
#                       AUTOMOTIVE_AMPLIFIERS      0.978     0.943     0.960       662
#                           PROJECTOR_SCREENS      0.964     1.000     0.981        53
#                          AUTOMOTIVE_EMBLEMS      0.965     0.956     0.961       523
#                           PAINTBALL_MARKERS      0.906     0.990     0.946        97
#               AUTOMOTIVE_SPRING_SUSPENSIONS      0.975     0.975     0.975       121
#                                 ENGINE_OILS      0.990     0.982     0.986       770
#                            BATTERY_CHARGERS      0.676     0.767     0.719        30
#                     SWEATSHIRTS_AND_HOODIES      0.917     0.941     0.929       118
#                      CONTINUOUS_INK_SYSTEMS      0.986     0.979     0.982       140
#                              BATHROOM_SINKS      0.967     0.953     0.960       427
#                                MEMORY_CARDS      0.986     0.978     0.982       669
#                                    HANDBAGS      0.952     0.958     0.955       850
#                               KITCHEN_SINKS      0.903     0.925     0.914       253
#                            CAMERA_BATTERIES      0.989     0.955     0.972       554
#                             WATER_RADIATORS      0.958     0.972     0.965       399
#                           CYCLING_COMPUTERS      0.962     0.938     0.950       161
#                                EROTIC_BOOKS      1.000     0.985     0.992        67
#                            MOTORCYCLE_CASES      0.991     1.000     0.996       222
#                                    COSTUMES      0.953     0.960     0.957       276
#                           BODYWEIGHT_SCALES      0.926     0.942     0.934       293
#                      GAMEPADS_AND_JOYSTICKS      0.975     0.974     0.975       612
#                                       PANTS      0.949     0.952     0.951       799
#                                      STOOLS      0.981     0.975     0.978       594
#                               FISHING_REELS      0.992     0.985     0.988       740
#                                     WALLETS      0.983     0.973     0.978       665
#                           MUSICAL_KEYBOARDS      0.967     0.980     0.974       511
#                                  ULTRABOOKS      0.921     0.905     0.913       232
#                             ENGINE_BEARINGS      0.997     0.982     0.989       327
#                    CAR_POWER_STEERING_PUMPS      0.989     0.995     0.992       370
#                                     TABLETS      0.974     0.973     0.974       624
#                              MAKEUP_BRUSHES      0.985     0.985     0.985       534
#                               HORSE_SADDLES      0.990     1.000     0.995       102
#                          CD_AND_DVD_PLAYERS      0.934     0.924     0.929       291
#                    VIDEO_GAME_PREPAID_CARDS      0.923     0.882     0.902        68
#                             SCREEN_PRINTERS      0.962     0.962     0.962       156
#                                  ROOF_RACKS      0.993     0.986     0.989       428
#                                  HEADPHONES      0.973     0.968     0.971       189
#                       ELECTRIC_SCREWDRIVERS      0.791     0.902     0.843       122
#                             VACUUM_CLEANERS      1.000     0.875     0.933        16
#                                 FLASHLIGHTS      0.987     0.988     0.988       606
#                                HOME_SHELVES      0.887     0.854     0.870       157
#                               BRUSH_CUTTERS      0.972     0.955     0.963       110
#                         COMPUTER_PROCESSORS      0.996     0.986     0.991       794
#                                    NECKTIES      0.985     0.985     0.985       134
#                          MOTORCYCLE_JACKETS      0.969     0.953     0.961       551
#                                    WRENCHES      0.958     0.992     0.975       371
#                                 WHEELCHAIRS      0.968     1.000     0.984        90
#                          RAM_MEMORY_MODULES      0.998     0.988     0.993       822
#                                PENCIL_CASES      0.966     0.940     0.953       183
#                AUTOMOTIVE_SHIFT_LEVER_KNOBS      1.000     1.000     1.000       938
#                                        MUGS      0.921     0.951     0.936       329
#                              WALKIE_TALKIES      0.952     0.972     0.962       283
#                                       DOLLS      0.919     0.954     0.936       843
#                                  TREADMILLS      1.000     0.985     0.992        65
#                                 SPARK_PLUGS      0.963     0.955     0.959       726
#                               HAIR_CLIPPERS      0.882     0.882     0.882       713
#                                   SUITCASES      0.971     0.981     0.976       582
#                                 BLANK_DISCS      0.952     0.888     0.919       178
#                                    SPEAKERS      0.948     0.973     0.961       525
#                               DVD_RECORDERS      0.973     0.967     0.970       450
#                     KEYBOARD_AND_MOUSE_KITS      0.960     0.960     0.960       275
#                             CAR_SEAT_COVERS      0.994     0.996     0.995       942
#          AUTOMOTIVE_SUSPENSION_CONTROL_ARMS      0.969     0.980     0.975       254
#                           BAR_CODE_SCANNERS      0.973     0.980     0.976       254
#                         AUTOMOTIVE_MOLDINGS      0.976     0.974     0.975       720
#                               BABY_SWIMWEAR      0.891     0.876     0.883       121
#                        TABLE_AND_DESK_LAMPS      0.968     0.942     0.955       260
#                           JACKETS_AND_COATS      0.942     0.936     0.939       815
#                                  CHAMPAGNES      0.875     0.903     0.889        31
#                              FOOTBALL_SHOES      0.997     0.999     0.998       734
#                           CHARMS_AND_MEDALS      0.965     0.953     0.959        86
#                                 MICROPHONES      0.983     0.996     0.989       465
#                         PERMANENT_EPILATORS      0.906     0.926     0.916        94
#                              WOMEN_SWIMWEAR      0.953     0.968     0.960       500
#                  PARTY_DECORATIVE_BACKDROPS      0.981     0.990     0.986       105
#                               ROLLER_SKATES      0.997     0.997     0.997       586
#                                      COMICS      0.845     0.826     0.835       534
#                                       BOOKS      0.829     0.856     0.842       834
#                              CUPCAKE_STANDS      0.714     0.625     0.667         8
#                               UPS_BATTERIES      0.905     0.891     0.898        64
#                                 CAKE_STANDS      0.854     0.911     0.882        45
#            REAR_WHEEL_HUBS_BEARING_ASSEMBLY      0.983     1.000     0.991       401
#                            DIECAST_VEHICLES      0.950     0.947     0.949       606
#                                 CALCULATORS      0.991     0.989     0.990       536
#                                 TV_ANTENNAS      0.993     0.984     0.989       310
#                                 PAPER_CLIPS      0.961     0.961     0.961        51
#                              MALE_UNDERWEAR      0.979     0.983     0.981       422
#                                  ALL_IN_ONE      0.967     0.942     0.954       189
#                            DRINKING_GLASSES      0.866     0.880     0.873       382
#                                       DRUMS      0.904     0.981     0.941       212
#                               WELDING_MASKS      0.950     0.905     0.927        63
#                                    WHISKEYS      0.967     0.974     0.970       267
#                               VIDEO_CAMERAS      0.943     0.892     0.917        37
#                               COFFEE_MAKERS      0.986     0.979     0.982       567
#                        KNEE_BRACES_SUPPORTS      0.962     0.977     0.969       129
#                                 WALL_CLOCKS      0.987     0.985     0.986       480
#                                 WALL_LIGHTS      0.988     0.983     0.985       172
#                              GARDEN_BENCHES      0.611     0.786     0.688        14
#                                  SCULPTURES      0.936     0.943     0.940       437
#                                        FANS      0.980     0.982     0.981       597
#                                 FOUNDATIONS      0.937     0.966     0.951       706
#                                   EYELINERS      0.935     0.860     0.896        50
#                                  DRILL_BITS      0.952     0.979     0.966       143
#                                PC_KEYBOARDS      0.842     0.615     0.711        26
#                               EROTIC_CREAMS      0.919     0.932     0.925       279
#                           DESKTOP_COMPUTERS      0.846     0.917     0.880        36
#                           DECORATIVE_VINYLS      0.940     0.968     0.953       709
#                                 BOARD_GAMES      0.935     0.945     0.940       654
#                         KITCHEN_RANGE_HOODS      0.990     0.987     0.989       309
#                                     DRAWERS      0.966     0.990     0.978       198
#                             FURNITURE_KNOBS      0.967     0.993     0.980       147
#        HOME_APPLIANCE_CONTACTORS_AND_RELAYS      0.983     0.980     0.982       408
#                            SHAVING_MACHINES      0.828     0.815     0.822       449
#                                TOOTHBRUSHES      0.977     0.977     0.977       265
#                     STREAMING_MEDIA_DEVICES      0.973     0.957     0.965       415
#                      CAR_AC_HOSE_ASSEMBLIES      0.909     0.588     0.714        17
#                              SWAY_BAR_LINKS      0.917     0.865     0.890        89
#                               PREAMPLIFIERS      0.786     0.478     0.595        23
#                                  FISH_TANKS      0.979     0.945     0.961       145
#                                      DRONES      0.997     0.985     0.991       653
#                            EMERGENCY_LIGHTS      0.955     0.955     0.955       288
#                                    BLENDERS      0.921     0.958     0.939       452
#                              LASER_MEASURES      0.962     0.927     0.944        55
#                                CASH_DRAWERS      0.946     0.921     0.933        38
#                             CAMERA_CHARGERS      0.921     0.940     0.931       285
#                            CAR_AV_RECEIVERS      0.942     0.937     0.940       589
#                            STEERING_COLUMNS      0.979     0.993     0.986       143
#                                      SKIRTS      0.974     0.968     0.971       154
#                             SANDER_MACHINES      0.982     0.955     0.969       292
#                                RICE_COOKERS      1.000     1.000     1.000        52
#                              BRAKE_BOOSTERS      0.972     0.993     0.982       139
#                                    NETBOOKS      0.900     0.931     0.915       145
#                               FISHING_LURES      0.800     0.836     0.818        67
#                            AUTOMOTIVE_TIRES      0.944     0.838     0.887        80
#                                     STATUES      0.714     0.435     0.541        23
#                                    T_SHIRTS      0.968     0.966     0.967       742
#                             OFFICE_SOFTWARE      0.894     0.720     0.797        82
#                              BABY_CAR_SEATS      0.985     0.984     0.985       550
#                                 WATCH_BANDS      0.921     0.921     0.921       265
#                                        PENS      0.793     0.852     0.821        27
#                   BATHROOM_ACCESSORIES_SETS      0.913     0.808     0.857        78
#                                 CAR_STEREOS      0.879     0.864     0.871       243
#  CELLPHONE_TABLET_AND_GPS_SCREEN_PROTECTORS      0.914     0.955     0.934       155
#                              GLASSES_FRAMES      0.938     0.970     0.953       296
#                                AIRSOFT_GUNS      0.972     0.976     0.974       245
#                                   HAND_FANS      0.811     0.938     0.870        32
#                                  SIDEBOARDS      0.990     0.975     0.982       201
#                            VEHICLE_STICKERS      0.985     0.968     0.976       530
#                              BABY_STROLLERS      0.970     0.983     0.977       468
#                                      MOVIES      0.908     0.831     0.868        71
#                          MICRO_ROTARY_TOOLS      0.957     0.971     0.964        69
#                                   SOUVENIRS      0.910     0.934     0.922       151
#                                      VODKAS      0.918     0.957     0.938        94
#                               PUREBRED_DOGS      0.989     0.989     0.989       705
#                                     VIOLINS      0.980     0.993     0.987       151
#                                 HOVERBOARDS      0.988     0.990     0.989       480
#                      SUSPENSION_BALL_JOINTS      0.988     0.979     0.984       579
#                                   BACKPACKS      0.975     0.987     0.981       699
#                              ADHESIVE_TAPES      0.984     0.968     0.976       253
#                           ELECTRICAL_CABLES      0.988     0.992     0.990       250
#                               COFFEE_TABLES      1.000     0.846     0.917        26
#                  INTERACTIVE_GAMING_FIGURES      0.972     0.996     0.984       246
#                   AUTOMOTIVE_AC_COMPRESSORS      0.909     0.930     0.920        43
#                       HAIRDRESSING_SCISSORS      0.975     0.994     0.985       160
#                                    CUSHIONS      0.954     0.981     0.968       213
#                   THERMAL_CUPS_AND_TUMBLERS      0.891     0.875     0.883        56
#         TV_REPLACEMENT_BACKLIGHT_LED_STRIPS      0.983     0.991     0.987       115
#                         ENGINE_INTAKE_HOSES      0.937     0.949     0.943       373
#                    AUTOMOBILE_FENDER_LINERS      0.941     0.889     0.914        18
#                              DJ_CONTROLLERS      0.904     0.914     0.909       175
#                                STUFFED_TOYS      0.862     0.898     0.880       679
#              MARTIAL_ARTS_AND_BOXING_GLOVES      0.969     0.976     0.973       254
#                               CAMERA_LENSES      0.981     0.954     0.968       219
#                                EROTIC_PUMPS      0.988     0.933     0.960        89
#                               PAINT_ROLLERS      0.917     1.000     0.957        11
#                                MEN_SWIMWEAR      0.875     0.778     0.824        18
#                 PORTABLE_CELLPHONE_CHARGERS      0.940     0.968     0.954       500
#                              ANALOG_CAMERAS      0.922     0.978     0.949       457
#                             HAIR_TREATMENTS      0.905     0.854     0.879        89
#                       DJ_EFFECTS_PROCESSORS      0.846     0.787     0.815       202
#                     BUMPER_IMPACT_ABSORBERS      0.952     0.976     0.964       245
#                  NOTEBOOKS_AND_WRITING_PADS      0.980     0.980     0.980       153
#                         FINGERPRINT_READERS      0.957     0.917     0.936        24
#                                    BLANKETS      0.854     0.939     0.895       131
#                                 SUPPLEMENTS      0.884     0.900     0.892       430
#                                    HAMMOCKS      0.988     0.988     0.988        82
#                AUTOMOTIVE_SIDE_VIEW_MIRRORS      0.980     0.988     0.984       737
#                   FACIAL_SKIN_CARE_PRODUCTS      0.873     0.845     0.858       341
#                             PACKAGING_ROLLS      1.000     1.000     1.000        26
#                       TV_AND_MONITOR_MOUNTS      0.984     0.998     0.991       546
#                                CAR_ANTENNAS      0.998     1.000     0.999       934
#                                    CACHACAS      0.981     0.981     0.981       157
#                                     TV_SMPS      0.911     0.921     0.916       279
#                              KITCHEN_TOWELS      0.978     0.986     0.982       277
#                                    CALIPERS      1.000     1.000     1.000        22
#                             PARKING_SENSORS      0.985     0.996     0.991       539
#                   ELECTRIC_PRESSURE_WASHERS      0.988     0.988     0.988       343
#              HAIR_SHAMPOOS_AND_CONDITIONERS      0.909     0.909     0.909        44
#                                STETHOSCOPES      0.971     0.944     0.958        36
#                                    PRINTERS      0.972     0.965     0.969       400
#                             ELECTRIC_DRILLS      0.973     0.954     0.963       414
#                                KITCHEN_POTS      0.971     0.969     0.970       485
#                              FUEL_INJECTORS      0.913     0.913     0.913       103
#                            VEHICLE_SPEAKERS      0.974     0.979     0.976       421
#                           HOME_OFFICE_DESKS      0.931     0.993     0.961       149
#                              GUITAR_STRINGS      0.945     0.972     0.958       106
#                             DISC_PACKAGINGS      0.793     0.932     0.857        74
#                                 LIP_GLOSSES      0.941     0.932     0.937       190
#                                     DRESSES      0.981     0.983     0.982       692
#                                BASS_GUITARS      0.976     0.966     0.971       467
#                                  TURNTABLES      0.911     0.915     0.913       270
#                           TOY_BUILDING_SETS      0.915     0.912     0.913       249
#                                  BED_SHEETS      0.971     0.907     0.938        75
#                               CAR_GEARBOXES      0.996     0.985     0.991       267
#                                FLOOD_LIGHTS      0.970     0.972     0.971       462
#                          SOLDERING_MACHINES      0.979     0.979     0.979       383
#                            ELECTRONIC_DRUMS      0.973     0.915     0.943       117
#                    DATA_CABLES_AND_ADAPTERS      0.843     0.938     0.888        80
#                      AUTOMOTIVE_WATER_PUMPS      0.912     0.877     0.894       391
#                              FOOTBALL_BALLS      0.981     0.994     0.987       156
#                                LENS_FILTERS      0.961     0.973     0.967        75
#                       INSTRUMENT_AMPLIFIERS      0.976     0.915     0.945       449
#                                MUSIC_STANDS      1.000     0.938     0.968        32
#                        CAR_DISTRIBUTOR_CAPS      0.955     0.922     0.938       205
#                                  MOUSE_PADS      0.995     0.980     0.987       201
#                                     FABRICS      0.942     0.947     0.945       379
#                               CABIN_FILTERS      0.996     0.996     0.996       244
#                             SEWING_MACHINES      0.976     0.966     0.971       292
#                                      MIXERS      0.958     0.989     0.973       350
#                         MOTORCYCLE_FAIRINGS      0.936     0.955     0.945       353
#                                   CV_JOINTS      0.982     0.968     0.975       443
#                  HAIR_STRAIGHTENING_BRUSHES      0.897     1.000     0.945        26
#                             WHEELS_BEARINGS      0.996     0.993     0.995       547
#                                AV_RECEIVERS      0.868     0.872     0.870       188
#                              NETWORK_CABLES      0.968     0.958     0.963       190
#                                       CRIBS      0.949     0.926     0.937       242
#                                HOME_HEATERS      0.973     0.932     0.952       234
#                  BRACELETS_AND_ANKLE_BRACES      0.929     0.948     0.938       346
#                                    SNEAKERS      0.946     0.972     0.959        72
#                  AUTOMOTIVE_THROTTLE_BODIES      0.960     0.960     0.960        50
#                              COOKING_SCALES      0.928     0.942     0.935       412
#                               PEDAL_EFFECTS      0.968     0.957     0.962       695
#                              ENGINE_PISTONS      0.969     0.955     0.962       132
#                               FLATWARE_SETS      0.964     0.871     0.915        31
#                                     PANTIES      0.885     0.939     0.911        49
#                          ELECTRICAL_OUTLETS      0.975     0.959     0.967       122
#                          BABY_CLOTHING_SETS      0.897     0.803     0.847        76
#                              STEAM_CLEANERS      0.929     0.684     0.788        19
#                            DECORATIVE_VASES      0.901     0.898     0.899       274
#                             FOOD_PROCESSORS      0.983     0.867     0.921       135
#                             TRAILER_HITCHES      1.000     0.995     0.997       184
#                       SOFA_AND_FUTON_COVERS      1.000     1.000     1.000        99
#                                      SHIRTS      0.894     0.932     0.913       118
#                       VEHICLE_CLUTCH_CABLES      1.000     1.000     1.000        10
#                                 GATE_MOTORS      0.977     0.987     0.982       298
#                                  FOG_LIGHTS      0.976     0.973     0.974       292
#                                   SIM_CARDS      0.957     0.917     0.936        24
#                               BABY_MONITORS      0.991     0.982     0.986       220
#                            VEHICLE_CV_AXLES      0.986     1.000     0.993        69
#                                   LIPSTICKS      0.972     0.975     0.973       561
#                      SERVING_AND_HOME_TRAYS      0.971     0.958     0.964       354
#                                    COOKTOPS      0.700     0.636     0.667        11
#                              GRAPHICS_CARDS      1.000     1.000     1.000        32
#                          FIRE_EXTINGUISHERS      1.000     0.967     0.983        30
#                  KITCHEN_CABINET_ORGANIZERS      0.200     0.143     0.167         7
#                                       SOFAS      0.890     0.970     0.928       100
#                            GRAPHICS_TABLETS      0.974     0.974     0.974       190
#                                      SHORTS      0.931     0.985     0.957       274
#                            SWIMMING_GOGGLES      0.972     0.909     0.940        77
#                            POOL_INFLATABLES      0.872     0.919     0.895        37
#                                       DOORS      0.917     0.907     0.912        97
#                               SPORT_WATCHES      0.942     0.954     0.948       478
#            PORTABLE_EVAPORATIVE_AIR_COOLERS      0.934     0.928     0.931       138
#              DOG_CARRIERS_AND_CARRYING_BAGS      0.945     0.912     0.929        57
#                     ENGINE_INTAKE_MANIFOLDS      0.944     1.000     0.971        51
#                          MOTORCYCLE_HELMETS      0.993     1.000     0.997       715
#                        COMBUSTION_CHAINSAWS      0.988     1.000     0.994        84
#               ELECTRONIC_ENTRANCE_INTERCOMS      0.986     0.967     0.976       211
#                                     CRAYONS      1.000     0.990     0.995       101
#                                THERMOMETERS      0.969     1.000     0.984        63
#                              CAMERA_TRIPODS      0.986     0.974     0.980       427
#                           ARTIFICIAL_PLANTS      0.739     0.630     0.680        27
#                            PROJECTOR_MOUNTS      1.000     0.800     0.889         5
#                 PORTABLE_ELECTRIC_MASSAGERS      0.927     0.916     0.921        83
#               NON_CORRECTIVE_CONTACT_LENSES      0.955     0.875     0.913        24
#                                     PUZZLES      0.947     0.959     0.953        74
#            WASHING_AND_DRYER_MACHINE_COVERS      0.980     1.000     0.990        50
#                        PUSH_AND_RIDING_TOYS      0.800     0.625     0.702        32
#                                SHOWER_HEADS      0.878     0.919     0.898       235
#                            ANTI_THEFT_STUDS      0.942     0.968     0.955       220
#                               HATS_AND_CAPS      0.824     0.938     0.878        65
#                                   MAGAZINES      0.778     0.783     0.780       143
#                  ENGINE_COOLING_FAN_SHROUDS      1.000     1.000     1.000        83
#                      AUTOMOTIVE_OIL_FILTERS      0.860     0.860     0.860        43
#                            MOTORCYCLE_TIRES      0.916     0.959     0.937       147
#               MOTORCYCLE_TURN_SIGNAL_LIGHTS      0.995     1.000     0.998       221
#                                     PILLOWS      0.968     0.968     0.968        31
#                                    TEQUILAS      0.917     1.000     0.957        33
#                                 TOILET_RUGS      0.921     0.936     0.928       249
#                                      FLUTES      0.983     0.922     0.952       128
#                                    UKULELES      0.981     0.981     0.981        52
#                                 TOOTHPASTES      0.896     0.968     0.930        62
#                       MOTORCYCLE_CRASH_BARS      0.952     0.952     0.952        21
#                             PIPES_AND_TUBES      0.562     0.692     0.621        13
#                                FOOD_SLICERS      0.909     0.909     0.909        22
#           DESKTOP_COMPUTER_COOLERS_AND_FANS      0.968     0.977     0.973       345
#                                   SWAY_BARS      0.959     0.959     0.959        98
#                            AQUARIUM_FILTERS      0.977     0.981     0.979       214
#               CELLPHONE_REPLACEMENT_CAMERAS      0.962     0.980     0.971        51
#                                     MIRRORS      0.894     0.977     0.933        86
#                             BLU_RAY_PLAYERS      0.966     0.971     0.969       175
#                          AUTOMOTIVE_FENDERS      0.960     0.984     0.972       123
#                             SPARKLING_WINES      0.667     0.667     0.667        12
#              ENGINE_VALVES_SPRING_RETAINERS      0.971     0.985     0.978        68
#                                BABY_WALKERS      1.000     0.923     0.960        13
#             ANTIVIRUS_AND_INTERNET_SECURITY      0.938     0.938     0.938        16
#                       COTTON_CANDY_MACHINES      1.000     1.000     1.000         7
#                             ORAL_IRRIGATORS      1.000     1.000     1.000         8
#                    MOTORCYCLE_CLUTCH_COVERS      0.931     0.954     0.942       239
#                               GAME_CONSOLES      0.957     0.902     0.929       347
#                               TABLE_RUNNERS      0.931     1.000     0.964        67
#                           PLAYGROUND_SLIDES      1.000     1.000     1.000        13
#                                 3D_PRINTERS      0.979     0.979     0.979        47
#                                 DIAPER_BAGS      0.961     0.961     0.961       103
#                               ELECTRIC_SAWS      0.986     0.989     0.988       363
#                           KITCHEN_FURNITURE      0.826     1.000     0.905        38
#                            BABY_HIGH_CHAIRS      0.733     0.841     0.783        88
#                                    MINI_PCS      0.733     0.786     0.759        14
#                                    MASCARAS      0.926     0.957     0.941        92
#                     AUTOMOTIVE_WHEEL_COVERS      0.984     0.977     0.981       129
#                           WINDSHIELD_WIPERS      0.959     0.984     0.971       190
#                                     LIQUORS      1.000     0.940     0.969       100
#                            CLOTHING_PATCHES      0.981     0.914     0.946        58
#                       WOOD_BURNING_MACHINES      1.000     1.000     1.000         7
#                                  BINOCULARS      1.000     0.973     0.986       186
#                      COMMERCIAL_LIGHT_SIGNS      0.941     1.000     0.970        32
#                            WATER_DISPENSERS      0.973     0.951     0.962       225
#                       GLOW_PLUG_CONTROLLERS      0.932     0.982     0.957        56
#                                  TELEPHONES      0.864     0.905     0.884        21
#                             AIR_COMPRESSORS      0.964     0.983     0.973       353
#                           OPERATING_SYSTEMS      0.906     0.967     0.935       270
#                        CAR_ENGINE_CAMSHAFTS      0.714     1.000     0.833        15
#                             CLOTHES_HANGERS      1.000     0.935     0.966        92
#                                    WETSUITS      0.941     0.842     0.889        19
#                                TOILET_SEATS      0.995     0.995     0.995       191
#                            AUTOMOTIVE_DOORS      0.971     0.997     0.984       332
#             SUSPENSION_CONTROL_ARM_BUSHINGS      0.877     0.826     0.851       138
#                          VEHICLE_BRAKE_PADS      0.986     0.989     0.987       350
#                 REMOTE_CONTROL_TOY_VEHICLES      0.905     0.914     0.910       209
#                        AUTOMOTIVE_NERF_BARS      1.000     1.000     1.000        38
#                              ESSENTIAL_OILS      0.866     0.892     0.879        65
#                             SLATWALL_PANELS      1.000     1.000     1.000        80
#                                  TOOL_BOXES      0.946     0.972     0.959       109
#                                BABY_DIAPERS      0.992     0.987     0.989       375
#                          ALARMS_AND_SENSORS      0.950     0.959     0.954       295
#                            MOTORCYCLE_SUITS      1.000     0.892     0.943        37
#                               KITCHEN_BOWLS      0.955     0.955     0.955        22
#                              CAT_SCRATCHERS      0.933     0.933     0.933        15
#                              INK_CARTRIDGES      0.824     0.933     0.875        30
#                    MARKERS_AND_HIGHLIGHTERS      0.952     0.937     0.944       126
#                      JUMPSUITS_AND_OVERALLS      0.917     0.943     0.930       106
#                                 NAIL_DRYERS      0.992     0.947     0.969       131
#                             CAMERA_MONOPODS      0.936     0.898     0.917        49
#                                    BICYCLES      0.967     0.962     0.965       184
#                                        SALT      1.000     1.000     1.000        10
#                    SCREEN_PRINTING_MACHINES      0.778     1.000     0.875        14
#                                        BEDS      0.953     0.953     0.953        43
#                     BODY_SKIN_CARE_PRODUCTS      0.830     0.837     0.834       380
# AUTOMOTIVE_MANUAL_TRANSMISSION_SHIFT_LEVERS      0.808     0.840     0.824        25
#                            TV_STORAGE_UNITS      0.942     0.942     0.942        52
#                       AUTOMOTIVE_HEADLIGHTS      0.949     0.985     0.966       131
#                                  PAINTBALLS      0.911     0.965     0.937        85
#                                      SCREWS      0.931     0.947     0.939        57
#                                  TOY_ROBOTS      1.000     0.600     0.750        15
#                                     POSTERS      0.957     0.981     0.969       206
#                            MOTORCYCLE_PANTS      0.932     0.932     0.932       118
#                         INTEGRATED_CIRCUITS      0.756     0.903     0.823        72
#                                GARDEN_HOSES      1.000     0.964     0.982        56
#                                 ALTERNATORS      0.913     0.875     0.894        48
#                          MAGNIFYING_GLASSES      0.991     0.926     0.958       122
#                                    PERFUMES      0.891     0.942     0.916        52
#                                       FLOUR      0.833     1.000     0.909        15
#                                FISHING_RODS      0.947     0.947     0.947        19
#                  CELLPHONE_AND_TABLET_CASES      0.895     0.934     0.914        91
#                                     PAJAMAS      0.964     0.964     0.964        56
#                                  BUTT_PLUGS      0.794     0.794     0.794        34
#                 LUMBAR_AND_ABDOMINAL_BRACES      0.966     0.952     0.959       147
#                              AIR_MATTRESSES      0.956     0.987     0.971       154
#                               WATER_HEATERS      0.996     0.964     0.979       247
#                                 DISHWASHERS      0.973     0.966     0.969       148
#                        ELECTRIC_LAWN_MOWERS      1.000     0.750     0.857         4
#                               HOME_THEATERS      0.857     0.667     0.750         9
#                            LED_STAGE_LIGHTS      0.902     0.894     0.898       216
#           CHALKBOARD_AND_WHITEBOARD_ERASERS      0.955     0.913     0.933        23
#                               BABY_BOUNCERS      0.800     0.889     0.842        18
#                                       RINGS      0.913     0.977     0.944        43
#                      AUTOMOTIVE_AIR_FILTERS      0.948     1.000     0.973        55
#                                LUGGAGE_TAGS      0.917     0.936     0.926        47
#                                HEATER_CORES      1.000     0.714     0.833        21
#                             CLEANING_CLOTHS      0.935     0.925     0.930        93
#                              AIR_FRESHENERS      0.800     0.558     0.658        43
#                                     BLOUSES      0.646     0.816     0.721        38
#                             SAFETY_FOOTWEAR      1.000     1.000     1.000        66
#                                FREEZER_BAGS      0.875     0.875     0.875         8
#                      SHOCK_MOUNT_INSOLATORS      0.825     0.904     0.863        73
#                                  BAR_CLAMPS      1.000     0.688     0.815        16
#                             CHRISTMAS_TREES      1.000     0.946     0.972        37
#                          CAR_AIR_FRESHENERS      0.892     0.919     0.905        99
#                          BASKETBALL_JERSEYS      1.000     0.867     0.929        15
#                                  ACCORDIONS      0.997     0.981     0.989       311
#                                  FOOD_CARTS      0.853     0.935     0.892        31
#                                   HEAT_GUNS      1.000     0.989     0.995        94
#                   ENGINE_CRANKSHAFT_PULLEYS      0.944     0.953     0.949       107
#                                  PARTY_HATS      0.800     0.500     0.615         8
#                             RECEPTION_DESKS      0.800     1.000     0.889         4
#                              PICTURE_FRAMES      0.987     0.974     0.980       151
#                               OSCILLOSCOPES      1.000     0.900     0.947        10
#                   HABERDASHERY_LACE_EDGINGS      0.981     0.945     0.963       109
#                                       BEERS      0.988     0.965     0.976       170
#                                HOLE_PUNCHES      1.000     0.857     0.923         7
#                               DJ_TURNTABLES      0.952     0.738     0.831        80
#                                 VR_HEADSETS      0.983     0.989     0.986       352
#                             KITCHEN_MORTARS      1.000     1.000     1.000         4
#                                       OVENS      0.950     0.994     0.971       171
#                                DISHES_RACKS      0.685     0.755     0.718        49
#                                    EARRINGS      0.932     0.932     0.932        44
#                                   WARDROBES      0.921     0.972     0.946        36
#                           RACKS_AND_PINIONS      0.965     0.965     0.965       113
#                                   BOOKCASES      0.868     0.943     0.904        35
#                                  TOY_TRAINS      0.920     0.851     0.884        94
#                      CARD_PAYMENT_TERMINALS      0.850     1.000     0.919        17
#                           SUBMERSIBLE_PUMPS      0.970     0.980     0.975       100
#             GARDENING_AND_AGRICULTURE_SEEDS      0.900     1.000     0.947        36
#                                      MODEMS      0.837     0.919     0.876       123
#                               OFFICE_CHAIRS      0.892     0.929     0.910        98
#                                   PENDRIVES      0.957     0.957     0.957       139
#                                   NECKLACES      0.977     0.945     0.961        91
#                          ENGINE_GASKET_SETS      0.438     0.412     0.424        17
#                  AUTOMOTIVE_SHOCK_ABSORBERS      0.785     0.939     0.855        66
#                                 VINYL_ROLLS      0.742     0.657     0.697        70
#               TROLLEY_AND_FURNITURE_CASTERS      1.000     1.000     1.000         4
#                   TV_RECEIVERS_AND_DECODERS      0.762     0.889     0.821        18
#                                LIFE_JACKETS      1.000     0.545     0.706        22
#                        SELF_ADHESIVE_LABELS      0.875     0.857     0.866        49
#                   IGNITION_SWITCH_ACTUATORS      1.000     1.000     1.000        14
#                            BABY_STERILIZERS      0.917     1.000     0.957        22
#                       PARKING_BRAKE_HANDLES      0.967     0.967     0.967        61
#                      CLUTCH_SLAVE_CYLINDERS      0.788     0.867     0.825        30
#                                      FISHES      0.875     0.778     0.824         9
#                             COOKIES_CUTTERS      0.961     0.961     0.961        77
#                                  NEBULIZERS      0.980     1.000     0.990        49
#                                  COMFORTERS      0.696     0.800     0.744        20
#                         ELLIPTICAL_MACHINES      0.938     0.945     0.942       128
#                               ENGINE_VALVES      0.930     0.909     0.920        44
#                                  SANDPAPERS      0.895     0.810     0.850        21
#        AUTOMOTIVE_SHOCK_ABSORBER_BUMP_STOPS      0.971     0.919     0.944        37
#                                     GAZEBOS      1.000     0.967     0.983        91
#                                  XENON_KITS      0.952     1.000     0.976        20
#                      AUTOMOTIVE_DOOR_PANELS      0.987     1.000     0.993       150
#                  INDOOR_CURTAINS_AND_BLINDS      0.958     0.994     0.976       161
#                         CAR_WINDOW_SWITCHES      0.867     0.839     0.852        31
#                                   EPILATORS      0.859     0.904     0.881        94
#                           MALE_MASTURBATORS      0.923     0.800     0.857        15
#                         DRILLS_SCREWDRIVERS      0.636     0.292     0.400        24
#                                  CONCEALERS      0.838     0.943     0.888        88
#                     SCHOOL_AND_OFFICE_GLUES      0.615     0.800     0.696        10
#                      SANDALS_AND_FLIP_FLOPS      0.936     0.978     0.957        45
#                                   BAR_SOAPS      0.765     0.867     0.812        60
#                   ELECTRIC_BATHROOM_FAUCETS      0.905     0.760     0.826        25
#                           VOLTAGE_DETECTORS      1.000     1.000     1.000        29
#                     ORTHOPEDIC_ANKLE_BRACES      0.938     1.000     0.968        15
#                              HEDGE_TRIMMERS      0.933     1.000     0.966        14
#                         STABILIZERS_AND_UPS      1.000     1.000     1.000         2
#                               BABY_PLAYARDS      0.953     0.918     0.935       110
#                            RESISTANCE_BANDS      0.967     0.978     0.972       180
#                             LAPTOP_CHARGERS      0.926     0.926     0.926        68
#                       COMPUTER_MOTHERBOARDS      0.681     0.780     0.727        41
#                                 COIN_PURSES      0.920     0.885     0.902        26
#                                       VESTS      0.949     0.959     0.954        97
#                           HAIRDRESSING_CAPS      1.000     0.750     0.857         8
#                                CAMERA_CASES      0.800     0.571     0.667         7
#                           MOTORCYCLE_GLOVES      0.948     0.974     0.961       151
#                 COMPUTER_AND_TV_FLEX_CABLES      0.960     0.992     0.975       120
#                                       MANGA      0.897     0.897     0.897        39
#                                SELF_TANNERS      1.000     1.000     1.000         3
#                          HEARING_PROTECTORS      0.975     1.000     0.987        39
#                               DIFFERENTIALS      0.971     0.943     0.957        35
#                    FLEA_AND_TICK_TREATMENTS      0.962     0.984     0.973       129
# ...
#                            LIVING_ROOM_SETS      1.000     0.500     0.667        14
#                              BABY_PACIFIERS      0.938     1.000     0.968        15
#                              HAND_POLISHERS      0.706     0.857     0.774        14
#                                SHADE_CLOTHS      1.000     1.000     1.000        12
#                               HAMMER_DRILLS      0.714     0.625     0.667         8
#                              POWER_GRINDERS      0.786     0.846     0.815        13
#                               CAMERA_STRAPS      1.000     1.000     1.000         3
#                           LAWN_MOWER_BLADES      0.727     0.889     0.800         9
#                          PNEUMATIC_STAPLERS      1.000     1.000     1.000        13
#              THERMAL_REFRIGERATORS_AND_BAGS      0.917     0.786     0.846        28
#                                LIGHT_STANDS      0.778     1.000     0.875         7
#                                      STRAWS      1.000     0.750     0.857         8
#                                       SUITS      0.767     0.697     0.730        33
#                           BATHROOM_VANITIES      1.000     0.875     0.933         8
#                         VIBRATION_PLATFORMS      1.000     0.889     0.941        18
#                               DINING_TABLES      0.882     0.938     0.909        16
#                           TURNTABLE_NEEDLES      1.000     0.667     0.800         3
#                                HEARING_AIDS      0.750     0.900     0.818        10
#                     ORTHOPEDIC_WALKER_BOOTS      0.778     0.500     0.609        14
#                                         TEA      0.875     0.700     0.778        10
#                             TORQUE_WRENCHES      1.000     1.000     1.000         8
#                                 CATS_LITTER      0.917     0.917     0.917        12
#                                 MATE_GOURDS      0.917     1.000     0.957        11
#                                  MEAT_HOOKS      0.667     1.000     0.800         2
#                       AUTOMOTIVE_DEFLECTORS      1.000     1.000     1.000         5
#                   VARIABLE_FREQUENCY_DRIVES      1.000     0.857     0.923         7
#                                  SWEETENERS      1.000     1.000     1.000         8
#         AUTOMOTIVE_CELLPHONE_AND_GPS_MOUNTS      0.800     0.667     0.727         6
#                         RADIO_BASE_STATIONS      0.333     0.167     0.222         6
#                                    CRUTCHES      0.800     1.000     0.889         4
#                                POWER_STRIPS      0.889     0.800     0.842        10
#                               KATANA_SWORDS      0.917     0.846     0.880        13
#                        CATS_AND_DOGS_TREATS      0.917     0.786     0.846        14
#                         MEMORY_CARD_READERS      0.333     0.333     0.333         3
#                            TELEPHONE_CABLES      0.929     0.929     0.929        14
#                          SOLID_SWEET_PASTES      1.000     0.800     0.889        10
#                           DISPOSABLE_GLOVES      1.000     1.000     1.000         3
#                        MOTORCYCLE_GRAB_BARS      1.000     1.000     1.000         3
#                              PLUNGE_ROUTERS      1.000     0.875     0.933         8
#                         GROOVE_JOINT_PLIERS      0.800     1.000     0.889         4
#                          BICYCLE_HANDLEBARS      1.000     0.800     0.889         5
#                          SOLDERING_STATIONS      0.862     0.962     0.909        26
#                               TANDEM_CHAIRS      0.600     0.429     0.500         7
#                                GARAGE_DOORS      1.000     0.750     0.857        12
#                         SPARK_PLUG_WIRESETS      0.931     0.844     0.885        32
#                       ELECTRIC_SHOWER_HEADS      1.000     0.200     0.333         5
#                        PORTABLE_DVD_PLAYERS      0.857     0.667     0.750         9
#                                      DILDOS      0.308     0.500     0.381         8
#                   INDUSTRIAL_DOUGH_KNEADERS      1.000     0.846     0.917        13
#                   UNIVERSAL_REMOTE_CONTROLS      0.500     0.333     0.400         3
#                                 WHEEL_STUDS      0.333     0.167     0.222         6
#                            FABRIC_SOFTENERS      0.900     0.947     0.923        19
#              MOTORCYCLE_DISTRIBUTION_CHAINS      0.905     1.000     0.950        19
#                       DOOR_AND_WINDOW_LOCKS      1.000     0.333     0.500         3
#                                        GINS      0.800     1.000     0.889         4
#                                 HAND_TRUCKS      1.000     0.250     0.400         4
#                                    STAPLERS      1.000     1.000     1.000         6
#                                   APERITIFS      1.000     0.800     0.889         5
#                             SHOWER_CURTAINS      1.000     1.000     1.000         4
#                              ANTIQUE_CHAIRS      0.800     0.571     0.667         7
#                               YOGURT_MAKERS      1.000     0.600     0.750         5
#                                 SHIN_GUARDS      1.000     0.500     0.667         2
#                             GOLF_CLUBS_SETS      1.000     0.778     0.875         9
#                  FOOTBALL_GOALKEEPER_GLOVES      0.882     0.938     0.909        16
#                                LASER_LEVELS      0.727     1.000     0.842         8
#                        KEYBOARD_CONTROLLERS      0.111     0.200     0.143         5
#                          ALTERNATOR_PULLEYS      0.941     0.941     0.941        17
#            CAMERA_AND_CELLPHONE_STABILIZERS      0.667     0.667     0.667         3
#                                BABY_JUMPERS      0.800     0.667     0.727         6
#                 CAMERA_REPLACEMENT_DISPLAYS      1.000     1.000     1.000         7
#                                 CRANKSHAFTS      0.952     0.952     0.952        21
#                                BREAD_MAKERS      0.600     1.000     0.750         3
#                    SCHOOL_AND_OFFICE_PAPERS      0.857     0.750     0.800         8
#                    STOVETOP_POPCORN_POPPERS      0.714     0.625     0.667         8
#                      BREAST_FEEDING_PILLOWS      0.900     0.818     0.857        11
#                               POOL_CLEANERS      0.800     0.800     0.800         5
#                              LINEMAN_PLIERS      0.600     1.000     0.750         3
#                                  COAT_RACKS      0.455     0.833     0.588         6
#                                  POOL_PUMPS      0.917     0.917     0.917        12
#                     WATER_PURIFIERS_FILTERS      0.750     0.600     0.667        20
#                               SAFETY_GLOVES      0.250     0.167     0.200         6
#                          ISOPROPYL_ALCOHOLS      0.889     0.889     0.889         9
#               VEHICLE_BRAKE_HYDRAULIC_HOSES      0.778     0.778     0.778         9
#                              MEDICINE_BALLS      0.750     0.750     0.750         4
#                             KITCHEN_GRATERS      0.667     0.800     0.727         5
#                              NAPKIN_HOLDERS      1.000     0.889     0.941         9
#                               PUNCHING_BAGS      0.250     0.333     0.286         3
#                                 ESPADRILLES      1.000     0.875     0.933         8
#                         CAR_CENTER_CONSOLES      1.000     0.833     0.909         6
#                             VIDEO_CASSETTES      0.667     1.000     0.800         6
#                              POTENTIOMETERS      1.000     1.000     1.000         5
#                    READY_TO_DRINK_COCKTAILS      0.000     0.000     0.000         2
#                                 FLOOR_LAMPS      0.800     0.727     0.762        11
#                            DRONE_PROPELLERS      0.857     1.000     0.923         6
#                                       TENTS      0.846     1.000     0.917        11
#                            SAFETY_HARNESSES      1.000     0.500     0.667         4
#                                    SYRINGES      0.800     1.000     0.889         4
#                                   BEDLINERS      0.765     0.812     0.788        16
#                     ELECTROLYTIC_CAPACITORS      1.000     1.000     1.000         7
#                                BASKET_BALLS      1.000     1.000     1.000         2
#                                   OTOSCOPES      1.000     1.000     1.000         4
#                               WAFFLE_MAKERS      1.000     1.000     1.000         8
#                                 PENIS_RINGS      0.667     0.500     0.571         4
#                          ELECTRIC_AIR_PUMPS      0.875     0.875     0.875         8
#                             COFFEE_CAPSULES      0.600     0.600     0.600         5
#                         BABY_PACIFIER_CLIPS      0.714     1.000     0.833         5
#                                   KEY_RACKS      0.500     0.250     0.333         4
#                                  DEODORANTS      0.833     1.000     0.909         5
#                          INDUSTRIAL_PULLEYS      0.833     1.000     0.909         5
#                               BILL_COUNTERS      1.000     1.000     1.000         5
#                  AUDIO_AND_VIDEO_CONNECTORS      0.500     0.250     0.333         4
#                            WASHING_MACHINES      1.000     1.000     1.000        12
#                 ENGINE_COOLING_FAN_SWITCHES      0.625     0.833     0.714         6
#                        AUTOMOTIVE_BATTERIES      0.556     1.000     0.714         5
#                        CHIP_AND_DIP_SERVERS      0.500     0.250     0.333         4
#                                ARCHERY_BOWS      0.750     1.000     0.857         6
#                             VINYL_FLOORINGS      0.700     1.000     0.824         7
#                              MENSTRUAL_CUPS      1.000     1.000     1.000         5
#                               SLEEPING_BAGS      0.750     0.750     0.750         4
#                               RUBBER_STAMPS      0.714     1.000     0.833         5
#                              DRYER_MACHINES      0.667     0.750     0.706         8
#                            ENERGETIC_STONES      1.000     0.857     0.923         7
#                              BICYCLE_PEDALS      0.889     0.889     0.889         9
#                      MOTORCYCLE_CARBURETORS      1.000     0.800     0.889         5
#                           SCREWDRIVERS_SETS      1.000     0.333     0.500         3
#                                EDIBLE_SEEDS      0.667     0.667     0.667         3
#                        STORE_SHOPPING_CARTS      1.000     1.000     1.000         4
#                         SWIMMING_NOSE_CLIPS      1.000     0.500     0.667         2
#                                 AFTERSHAVES      0.000     0.000     0.000         3
#                              AIRBAG_MODULES      1.000     1.000     1.000         3
#                                   HAND_SAWS      1.000     1.000     1.000         6
#           NECK_GAITERS_MASKS_AND_BALACLAVAS      0.667     1.000     0.800         2
#                          MAGNETIC_COMPASSES      1.000     1.000     1.000         6
#                          MAKEUP_TRAIN_CASES      0.750     0.750     0.750         4
#                            POPCORN_MACHINES      1.000     0.889     0.941         9
#                                LAMP_HOLDERS      0.571     1.000     0.727         4
#                    IGNITION_CONTROL_MODULES      0.500     0.286     0.364         7
#                             CAR_FRONT_MASKS      1.000     1.000     1.000         2
#                               HAND_BLENDERS      0.500     0.333     0.400         3
#                              KIDS_TRICYCLES      1.000     1.000     1.000         4
#                              AIRGUN_PELLETS      1.000     0.250     0.400         4
#                            AUTOMOTIVE_SEATS      0.444     0.667     0.533         6
#              MOTORCYCLE_TRANSMISSION_CROWNS      1.000     1.000     1.000         4
#                                  LAMINATORS      1.000     0.714     0.833         7
#                                 CEREAL_BARS      1.000     0.667     0.800         3
#                                MUSIC_ALBUMS      0.600     0.750     0.667         4
#                   AUTOMOTIVE_CV_JOINT_BOOTS      0.875     1.000     0.933         7
#                           MICROWAVE_KEYPADS      1.000     1.000     1.000         3
#                           WALL_ANCHOR_PLUGS      1.000     0.750     0.857         4
#                                 DRUM_STANDS      0.600     0.429     0.500         7
#                                 PET_COLLARS      0.867     0.929     0.897        14
#                             GATE_GEAR_RACKS      1.000     0.750     0.857         4
#                                   CAR_HOODS      1.000     1.000     1.000         3
#                        SCREEN_PRINTING_KITS      1.000     0.750     0.857         4
#                                  LED_STRIPS      1.000     1.000     1.000         4
#                             SANDWICH_MAKERS      1.000     1.000     1.000         2
#                              DENTAL_FLOSSES      1.000     0.500     0.667         2
#                              CAMERA_FLASHES      1.000     0.800     0.889         5
#                           DOG_NAIL_CLIPPERS      1.000     0.500     0.667         2
#                                    PINBALLS      1.000     0.667     0.800         6
#                                      GAUZES      1.000     0.833     0.909         6
#                                        SODS      1.000     0.667     0.800         3
#                          ELECTRICITY_METERS      0.000     0.000     0.000         4
#                             METAL_DETECTORS      1.000     1.000     1.000         3
#                          ELECTRIC_CHAINSAWS      1.000     0.333     0.500         3
#                            KNITTING_NEEDLES      0.500     0.833     0.625         6
#                           SWIMMING_EARPLUGS      1.000     0.500     0.667         2
#                                 SOUND_CARDS      0.800     0.800     0.800         5
#                                    STEPPERS      0.667     0.500     0.571         4
#                                 FANNY_PACKS      0.444     1.000     0.615         4
#                          TOOTHBRUSH_HOLDERS      0.000     0.000     0.000         2
#                          TABLE_TENNIS_BALLS      1.000     0.500     0.667         2
#                 ENGINE_OIL_PRESSURE_SENSORS      0.000     0.000     0.000         3
#                                 ICE_BUCKETS      1.000     0.571     0.727         7
#                               MASSAGE_SOFAS      0.800     1.000     0.889         4
#                              STYLING_CHAIRS      1.000     0.500     0.667         2
#                               BICYCLE_SEATS      1.000     1.000     1.000         3
#                            VOLLEYBALL_BALLS      1.000     0.667     0.800         3
#                           SPHYGMOMANOMETERS      0.500     0.250     0.333         4
#                              BINDING_SPINES      0.500     0.500     0.500         2
#                    DIGITAL_WEATHER_STATIONS      1.000     1.000     1.000         2
#                          HOME_BOTTLE_STANDS      1.000     0.667     0.800         3
#                                   DOORBELLS      0.500     0.500     0.500         2
#                                DRIED_FRUITS      1.000     1.000     1.000         2
#                            BOXING_HEADGEARS      1.000     1.000     1.000         2
#
#                                    accuracy                          0.950    138544
#                                   macro avg      0.897     0.873     0.878    138544
#                                weighted avg      0.951     0.950     0.950    138544
