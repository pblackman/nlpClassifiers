# %% [markdown]
# #### Based on https://medium.com/swlh/painless-fine-tuning-of-bert-in-pytorch-b91c14912caa
# https://github.com/aniruddhachoudhury/BERT-Tutorials/blob/master/Blog%202/BERT_Fine_Tuning_Sentence_Classification.ipynb

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import matplotlib.pyplot as plt
import torch.nn as nn
from os.path import join
import torch
from nlpClassifiers.data.dataset  import NLPDataset
#from torch.optim import AdamW, SGD
from torch.utils.data import DataLoader, SequentialSampler, RandomSampler
from transformers import BertForSequenceClassification, AdamW, BertConfig
from transformers import get_linear_schedule_with_warmup
from torch.nn import LayerNorm as BertLayerNorm
import numpy as np
import time
import logging
import datetime
import random
import pandas as pd
import argparse
import pickle as pk
import itertools
import os
import shutil
from pathlib import Path
import copy
import wandb
import re
from nlpClassifiers import settings
from scipy.special import expit
from sklearn.metrics import classification_report
# Out:
# /usr/local/lib/python3.6/dist-packages/gensim/similarities/__init__.py:15: UserWarning: The gensim.similarities.levenshtein submodule is disabled, because the optional Levenshtein package <https://pypi.org/project/python-Levenshtein/> is unavailable. Install Levenhstein (e.g. `pip install python-Levenshtein`) to suppress this warning.
#   warnings.warn(msg)

# %%
def predict(
    model_path: Path,
    dataset: str,
    batch_size: int,
    labels_dict,
    device: torch.device
):
       
    print(f"====Loading dataset for testing")
    test_corpus = NLPDataset(dataset, "test", sentence_max_len, bert_path, labels_dict)
    test_dataloader = DataLoader(
        test_corpus,
        batch_size=batch_size,
        #sampler = RandomSampler(test_corpus),
        pin_memory=True,
        num_workers=0,
        drop_last=False
    )

    print(f"====Loading model for testing")
    model = BertForSequenceClassification.from_pretrained(
        model_path,
        num_labels = test_corpus.num_labels,
        output_attentions = False,
        output_hidden_states = True,
    )
    model.to(device)
    model.eval()
  #  cm = ConfusionMatrix([0,1])
    pred_labels = []
    test_labels = []
    logits_list = []

    def _list_from_tensor(tensor):
        if tensor.numel() == 1:
            return [tensor.item()]
        return list(tensor.cpu().detach().numpy())

    print("====Testing model...")
    for batch in test_dataloader:
        batch = tuple(t.to(device) for t in batch)
        b_input_ids, b_segment_ids, b_input_mask, b_labels = batch
        with torch.no_grad():
            loss, logits, *_ =  model(b_input_ids, b_input_mask, token_type_ids=None, labels=b_labels)

            preds = np.argmax(logits.cpu(), axis=1) # Convert one-hot to index
            b_labels = b_labels.int()
            pred_labels.extend(_list_from_tensor(preds))
            test_labels.extend(_list_from_tensor(b_labels))
        logits_list.extend(_list_from_tensor(logits))
    print(classification_report(test_labels, pred_labels, labels=list(labels_dict.values()), target_names=np.array(list(labels_dict.keys())), digits=3))
    logits_list = expit(logits_list)
    del model
    torch.cuda.empty_cache()

# %%
def get_accuracy_from_logits(logits, labels):
    acc = (labels.cpu() == logits.cpu().argmax(-1)).float().detach().numpy()
    return float(100 * acc.sum() / len(acc))

# %%
DATA_PATH = '../../data/virtual-operator'
TRAIN_DATASET = os.path.join(DATA_PATH, 'train.csv')
VAL_DATASET = os.path.join(DATA_PATH, 'val.csv')
TEST_DATASET  = os.path.join(DATA_PATH, 'test.csv')
PATH_TO_VIRTUAL_OPERATOR_MODELS =  "../../models/virtual-operator"
PATH_TO_AGENT_BENCHMARK_MODELS = "../../models/agent-benchmark"
PATH_TO_ML_PT_MODELS = "../../models/mercado-livre-pt-only"

# %%
gpu = 0
dataset = 'mercado-livre-pt'
save_name = 'mercado-livre-pt-100-epochs-early-stop-reset-3-bertimbau-base'
bert_path = 'neuralmind/bert-base-portuguese-cased'
batch_size = 16
sentence_max_len = 82

# %%
BASE_PATH_TO_MODELS = {"virtual-operator": PATH_TO_VIRTUAL_OPERATOR_MODELS, "agent-benchmark": PATH_TO_AGENT_BENCHMARK_MODELS, "mercado-livre-pt": PATH_TO_ML_PT_MODELS}
FULL_PATH_TO_MODELS = join(BASE_PATH_TO_MODELS[dataset], "bert-base-portuguese-tapt-classifier")

# %%
device = torch.device(f"cuda:{gpu}")

# %%
model_path = Path(
    FULL_PATH_TO_MODELS, 
    f"base-dataset-{dataset}-{save_name}"
)
last_saved_model = model_path

# %%
last_saved_model
# Out:
# PosixPath('../../models/mercado-livre-pt-only/bert-base-portuguese-tapt-classifier/base-dataset-mercado-livre-pt-mercado-livre-pt-100-epochs-early-stop-reset-3-bertimbau-base')

# %%
train_corpus = NLPDataset(dataset, "train", sentence_max_len, bert_path)
labels_dict = train_corpus.labels_dict

# %%
predict(last_saved_model, dataset, batch_size, labels_dict, device)
# Out:
# ====Loading dataset for testing
# ====Loading model for testing
# ====Testing model...
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#                                              precision    recall  f1-score   support
#
#                               FISHING_LINES      0.901     0.916     0.908       584
#                      MOBILE_DEVICE_CHARGERS      0.969     0.975     0.972       804
#                                  SUNGLASSES      0.978     0.983     0.981       875
#                                    FREEZERS      0.945     0.930     0.938       444
#                                  CAR_WHEELS      0.993     0.997     0.995       720
#                            BATHROOM_FAUCETS      0.919     0.889     0.903       521
#                              ACTION_FIGURES      0.793     0.759     0.776       800
#                                       IRONS      0.984     0.979     0.981       433
#                                  MATTRESSES      0.991     0.985     0.988       534
#                       SWIMMING_POOL_HEATERS      0.870     0.952     0.909        21
#                              KITCHEN_KNIVES      0.960     0.960     0.960       202
#                                 TELEVISIONS      0.974     0.962     0.968       728
#                    SPORT_AND_BAZAAR_BOTTLES      0.863     0.934     0.897       229
#                                    STARTERS      0.980     0.977     0.979       354
#                                  FACE_MASKS      0.831     0.892     0.860       166
#                             KITCHEN_FAUCETS      0.890     0.919     0.904       431
#     TACTICAL_AND_SPORTING_KNIVES_AND_BLADES      0.994     0.939     0.966       164
#                                   NOTEBOOKS      0.952     0.947     0.949       543
#                                 DEEP_FRYERS      0.978     0.971     0.975       455
#                                TORSION_BARS      0.992     1.000     0.996       123
#                            AUDIO_AMPLIFIERS      0.834     0.855     0.844       311
#                              CEILING_LIGHTS      0.972     0.953     0.963       472
#                                       BELTS      0.960     0.980     0.970        49
#                    AUTOMOTIVE_WEATHERSTRIPS      0.966     0.984     0.975       788
#                                  HEADBOARDS      1.000     0.987     0.993       228
#                                       YARNS      0.910     0.930     0.920       142
#                                SMARTWATCHES      0.925     0.965     0.945       724
#                             FOOTBALL_SHIRTS      0.985     0.976     0.980       921
#                      AUTOMOTIVE_CLUTCH_KITS      0.985     0.994     0.990       719
#                                WRISTWATCHES      0.974     0.957     0.965       876
#                                  WALLPAPERS      0.978     0.949     0.963       885
#         AUTOMOTIVE_SIDE_VIEW_MIRROR_GLASSES      0.980     0.998     0.989       536
#                            AUDIO_INTERFACES      0.880     0.930     0.904       300
#                            KITCHEN_PLAYSETS      0.932     0.960     0.946       100
#                                 LIGHT_BULBS      0.935     0.971     0.953       829
#                              CELL_BATTERIES      0.971     0.966     0.969       670
#                        SURVEILLANCE_CAMERAS      0.939     0.903     0.921       909
#                                   THERMOSES      0.846     0.880     0.863       100
#                  HUMIDIFIERS_AND_VAPORIZERS      0.966     0.971     0.968       173
#                              KITCHEN_APRONS      0.880     0.815     0.846        27
#                         PORTABLE_GENERATORS      1.000     1.000     1.000       132
#                                  CELLPHONES      0.960     0.945     0.953       329
#                            HANDICRAFT_BOXES      0.798     0.812     0.805       112
#                         EMBROIDERY_MACHINES      0.918     0.882     0.900        51
#                                     CAMERAS      0.854     0.826     0.840        92
#             DESKTOP_COMPUTER_POWER_SUPPLIES      0.984     0.987     0.985       679
#                              BABIES_FORMULA      0.988     0.966     0.977        88
#                     MOTORCYCLE_SPEEDOMETERS      1.000     0.750     0.857         4
#                                     CARPETS      0.967     0.981     0.974       857
#                       CARDS_AND_INVITATIONS      0.889     0.851     0.870        47
#                            ELECTRIC_GUITARS      0.971     0.976     0.973       778
#                           COMPUTER_MONITORS      0.973     0.979     0.976       701
#                          MULTIGAME_MACHINES      0.859     0.870     0.865        77
#                                 TABLECLOTHS      0.974     0.982     0.978       544
#                                   VIBRATORS      0.847     0.897     0.871       117
#                                      PLANTS      0.984     0.990     0.987       313
#                                AM_FM_RADIOS      0.965     0.927     0.945       383
#                      ENGINE_CONTROL_MODULES      0.995     0.993     0.994       415
#             LATEX_ENAMEL_AND_ACRYLIC_PAINTS      1.000     1.000     1.000        67
#             MUSICAL_KEYBOARD_CASES_AND_BAGS      0.984     0.986     0.985       760
#                                 VIDEO_GAMES      0.979     0.988     0.984       908
#                          ARTIFICIAL_FLOWERS      0.954     0.954     0.954       497
#                          OUTER_TIE_ROD_ENDS      0.984     0.978     0.981       496
#                           EXHAUST_MANIFOLDS      0.889     1.000     0.941         8
#                     DIGITAL_VOICE_RECORDERS      0.902     0.947     0.924       774
#                               REFRIGERATORS      0.963     0.950     0.957       524
#                             DISPOSABLE_CUPS      0.845     0.867     0.856       188
#                                  EYESHADOWS      0.976     0.980     0.978       738
#                                      RANGES      0.973     0.967     0.970       450
#          AUTOMOTIVE_POWER_WINDOW_REGULATORS      0.942     0.949     0.946       138
#                                     HOOKAHS      0.982     0.952     0.967       168
#                       AUTOMOTIVE_AMPLIFIERS      0.966     0.944     0.955       662
#                           PROJECTOR_SCREENS      1.000     0.981     0.990        53
#                          AUTOMOTIVE_EMBLEMS      0.947     0.958     0.953       524
#                           PAINTBALL_MARKERS      0.958     0.948     0.953        97
#               AUTOMOTIVE_SPRING_SUSPENSIONS      0.975     0.983     0.979       121
#                                 ENGINE_OILS      0.984     0.979     0.982       770
#                            BATTERY_CHARGERS      0.706     0.800     0.750        30
#                     SWEATSHIRTS_AND_HOODIES      0.926     0.958     0.942       118
#                      CONTINUOUS_INK_SYSTEMS      0.986     0.979     0.982       140
#                              BATHROOM_SINKS      0.933     0.979     0.955       427
#                                MEMORY_CARDS      0.983     0.979     0.981       669
#                                    HANDBAGS      0.960     0.956     0.958       850
#                               KITCHEN_SINKS      0.937     0.881     0.908       253
#                            CAMERA_BATTERIES      0.975     0.978     0.977       554
#                             WATER_RADIATORS      0.970     0.972     0.971       399
#                           CYCLING_COMPUTERS      0.951     0.957     0.954       161
#                                EROTIC_BOOKS      0.957     0.985     0.971        67
#                            MOTORCYCLE_CASES      0.995     0.995     0.995       222
#                                    COSTUMES      0.971     0.964     0.967       276
#                           BODYWEIGHT_SCALES      0.937     0.959     0.948       293
#                      GAMEPADS_AND_JOYSTICKS      0.969     0.982     0.976       612
#                                       PANTS      0.940     0.960     0.950       799
#                                      STOOLS      0.998     0.973     0.986       594
#                               FISHING_REELS      0.989     0.977     0.983       740
#                                     WALLETS      0.989     0.973     0.981       665
#                           MUSICAL_KEYBOARDS      0.965     0.969     0.967       511
#                                  ULTRABOOKS      0.903     0.918     0.910       232
#                             ENGINE_BEARINGS      0.944     0.982     0.963       327
#                    CAR_POWER_STEERING_PUMPS      0.992     0.995     0.993       370
#                                     TABLETS      0.966     0.968     0.967       624
#                              MAKEUP_BRUSHES      0.989     0.976     0.982       534
#                               HORSE_SADDLES      1.000     1.000     1.000       102
#                          CD_AND_DVD_PLAYERS      0.894     0.955     0.924       291
#                    VIDEO_GAME_PREPAID_CARDS      0.891     0.838     0.864        68
#                             SCREEN_PRINTERS      0.956     0.968     0.962       156
#                                  ROOF_RACKS      0.984     0.988     0.986       428
#                                  HEADPHONES      0.963     0.952     0.957       189
#                       ELECTRIC_SCREWDRIVERS      0.873     0.844     0.858       122
#                             VACUUM_CLEANERS      1.000     0.875     0.933        16
#                                 FLASHLIGHTS      0.992     0.983     0.988       606
#                                HOME_SHELVES      0.881     0.898     0.890       157
#                               BRUSH_CUTTERS      0.964     0.964     0.964       110
#                         COMPUTER_PROCESSORS      0.994     0.979     0.986       794
#                                    NECKTIES      0.992     0.978     0.985       134
#                          MOTORCYCLE_JACKETS      0.967     0.969     0.968       551
#                                    WRENCHES      0.971     0.984     0.977       371
#                                 WHEELCHAIRS      0.989     0.989     0.989        90
#                          RAM_MEMORY_MODULES      0.994     0.991     0.993       822
#                                PENCIL_CASES      0.994     0.940     0.966       183
#                AUTOMOTIVE_SHIFT_LEVER_KNOBS      1.000     1.000     1.000       938
#                                        MUGS      0.951     0.936     0.943       329
#                              WALKIE_TALKIES      0.952     0.982     0.967       283
#                                       DOLLS      0.933     0.943     0.938       843
#                                  TREADMILLS      0.984     0.969     0.977        65
#                                 SPARK_PLUGS      0.958     0.952     0.955       726
#                               HAIR_CLIPPERS      0.882     0.880     0.881       714
#                                   SUITCASES      0.964     0.976     0.970       582
#                                 BLANK_DISCS      0.948     0.921     0.934       178
#                                    SPEAKERS      0.949     0.962     0.956       525
#                               DVD_RECORDERS      0.978     0.969     0.973       450
#                     KEYBOARD_AND_MOUSE_KITS      0.981     0.964     0.972       275
#                             CAR_SEAT_COVERS      0.995     0.997     0.996       942
#          AUTOMOTIVE_SUSPENSION_CONTROL_ARMS      0.969     0.992     0.981       254
#                           BAR_CODE_SCANNERS      0.973     0.980     0.976       254
#                         AUTOMOTIVE_MOLDINGS      0.980     0.976     0.978       720
#                               BABY_SWIMWEAR      0.855     0.926     0.889       121
#                        TABLE_AND_DESK_LAMPS      0.961     0.958     0.960       260
#                           JACKETS_AND_COATS      0.925     0.957     0.941       815
#                                  CHAMPAGNES      0.903     0.903     0.903        31
#                              FOOTBALL_SHOES      0.999     0.992     0.995       734
#                           CHARMS_AND_MEDALS      0.976     0.953     0.965        86
#                                 MICROPHONES      0.967     0.996     0.981       465
#                         PERMANENT_EPILATORS      0.887     0.915     0.901        94
#                              WOMEN_SWIMWEAR      0.978     0.962     0.970       500
#                  PARTY_DECORATIVE_BACKDROPS      0.963     0.990     0.977       105
#                               ROLLER_SKATES      0.985     0.995     0.990       586
#                                      COMICS      0.850     0.826     0.838       534
#                                       BOOKS      0.864     0.850     0.857       834
#                              CUPCAKE_STANDS      0.500     0.625     0.556         8
#                               UPS_BATTERIES      0.817     0.906     0.859        64
#                                 CAKE_STANDS      0.956     0.956     0.956        45
#            REAR_WHEEL_HUBS_BEARING_ASSEMBLY      0.983     0.995     0.989       401
#                            DIECAST_VEHICLES      0.983     0.934     0.958       606
#                                 CALCULATORS      0.993     0.989     0.991       536
#                                 TV_ANTENNAS      0.984     0.997     0.990       310
#                                 PAPER_CLIPS      1.000     0.961     0.980        51
#                              MALE_UNDERWEAR      0.969     0.976     0.973       422
#                                  ALL_IN_ONE      0.973     0.958     0.965       189
#                            DRINKING_GLASSES      0.864     0.880     0.872       382
#                                       DRUMS      0.950     0.976     0.963       212
#                               WELDING_MASKS      0.983     0.905     0.942        63
#                                    WHISKEYS      0.953     0.985     0.969       267
#                               VIDEO_CAMERAS      0.944     0.919     0.932        37
#                               COFFEE_MAKERS      0.977     0.981     0.979       567
#                        KNEE_BRACES_SUPPORTS      0.919     0.961     0.939       129
#                                 WALL_CLOCKS      0.987     0.985     0.986       480
#                                 WALL_LIGHTS      0.982     0.977     0.980       172
#                              GARDEN_BENCHES      0.600     0.643     0.621        14
#                                  SCULPTURES      0.947     0.941     0.944       437
#                                        FANS      0.975     0.982     0.978       597
#                                 FOUNDATIONS      0.950     0.963     0.956       706
#                                   EYELINERS      0.911     0.820     0.863        50
#                                  DRILL_BITS      0.986     0.979     0.982       143
#                                PC_KEYBOARDS      0.875     0.808     0.840        26
#                               EROTIC_CREAMS      0.922     0.935     0.929       279
#                           DESKTOP_COMPUTERS      0.892     0.917     0.904        36
#                           DECORATIVE_VINYLS      0.940     0.973     0.956       709
#                                 BOARD_GAMES      0.952     0.937     0.945       654
#                         KITCHEN_RANGE_HOODS      0.997     0.984     0.990       309
#                                     DRAWERS      0.990     0.985     0.987       198
#                             FURNITURE_KNOBS      0.973     0.993     0.983       147
#        HOME_APPLIANCE_CONTACTORS_AND_RELAYS      0.990     0.980     0.985       408
#                            SHAVING_MACHINES      0.861     0.815     0.838       449
#                                TOOTHBRUSHES      0.996     0.981     0.989       265
#                     STREAMING_MEDIA_DEVICES      0.954     0.949     0.952       415
#                      CAR_AC_HOSE_ASSEMBLIES      0.846     0.647     0.733        17
#                              SWAY_BAR_LINKS      0.849     0.888     0.868        89
#                               PREAMPLIFIERS      0.632     0.522     0.571        23
#                                  FISH_TANKS      0.986     0.945     0.965       145
#                                      DRONES      0.985     0.983     0.984       653
#                            EMERGENCY_LIGHTS      0.932     0.951     0.942       288
#                                    BLENDERS      0.944     0.931     0.938       452
#                              LASER_MEASURES      0.930     0.964     0.946        55
#                                CASH_DRAWERS      1.000     0.947     0.973        38
#                             CAMERA_CHARGERS      0.915     0.940     0.927       285
#                            CAR_AV_RECEIVERS      0.949     0.939     0.944       589
#                            STEERING_COLUMNS      1.000     0.979     0.989       143
#                                      SKIRTS      0.974     0.974     0.974       154
#                             SANDER_MACHINES      0.969     0.959     0.964       292
#                                RICE_COOKERS      0.897     1.000     0.945        52
#                              BRAKE_BOOSTERS      0.993     0.993     0.993       139
#                                    NETBOOKS      0.930     0.917     0.924       145
#                               FISHING_LURES      0.857     0.896     0.876        67
#                            AUTOMOTIVE_TIRES      0.864     0.875     0.870        80
#                                     STATUES      0.529     0.391     0.450        23
#                                    T_SHIRTS      0.949     0.980     0.964       742
#                             OFFICE_SOFTWARE      0.785     0.756     0.770        82
#                              BABY_CAR_SEATS      0.978     0.980     0.979       550
#                                 WATCH_BANDS      0.910     0.921     0.916       265
#                                        PENS      0.806     0.926     0.862        27
#                   BATHROOM_ACCESSORIES_SETS      0.857     0.769     0.811        78
#                                 CAR_STEREOS      0.831     0.872     0.851       243
#  CELLPHONE_TABLET_AND_GPS_SCREEN_PROTECTORS      0.901     0.942     0.921       155
#                              GLASSES_FRAMES      0.966     0.956     0.961       296
#                                AIRSOFT_GUNS      0.971     0.971     0.971       245
#                                   HAND_FANS      0.829     0.906     0.866        32
#                                  SIDEBOARDS      0.985     0.980     0.983       201
#                            VEHICLE_STICKERS      0.985     0.966     0.975       530
#                              BABY_STROLLERS      0.939     0.994     0.966       468
#                                      MOVIES      0.857     0.761     0.806        71
#                          MICRO_ROTARY_TOOLS      0.985     0.957     0.971        69
#                                   SOUVENIRS      0.897     0.921     0.908       151
#                                      VODKAS      0.918     0.957     0.938        94
#                               PUREBRED_DOGS      0.960     0.990     0.975       705
#                                     VIOLINS      0.993     0.993     0.993       151
#                                 HOVERBOARDS      0.996     0.990     0.993       480
#                      SUSPENSION_BALL_JOINTS      0.978     0.983     0.980       579
#                                   BACKPACKS      0.965     0.984     0.975       699
#                              ADHESIVE_TAPES      0.949     0.964     0.957       253
#                           ELECTRICAL_CABLES      0.988     1.000     0.994       250
#                               COFFEE_TABLES      0.957     0.846     0.898        26
#                  INTERACTIVE_GAMING_FIGURES      0.976     1.000     0.988       246
#                   AUTOMOTIVE_AC_COMPRESSORS      0.953     0.953     0.953        43
#                       HAIRDRESSING_SCISSORS      0.975     0.988     0.981       160
#                                    CUSHIONS      0.986     0.958     0.971       213
#                   THERMAL_CUPS_AND_TUMBLERS      0.891     0.875     0.883        56
#         TV_REPLACEMENT_BACKLIGHT_LED_STRIPS      0.983     0.983     0.983       115
#                         ENGINE_INTAKE_HOSES      0.940     0.968     0.954       373
#                    AUTOMOBILE_FENDER_LINERS      0.900     1.000     0.947        18
#                              DJ_CONTROLLERS      0.905     0.926     0.915       175
#                                STUFFED_TOYS      0.878     0.904     0.891       679
#              MARTIAL_ARTS_AND_BOXING_GLOVES      0.996     0.980     0.988       254
#                               CAMERA_LENSES      0.977     0.973     0.975       219
#                                EROTIC_PUMPS      0.988     0.921     0.953        89
#                               PAINT_ROLLERS      1.000     0.909     0.952        11
#                                MEN_SWIMWEAR      0.778     0.778     0.778        18
#                 PORTABLE_CELLPHONE_CHARGERS      0.979     0.946     0.962       500
#                              ANALOG_CAMERAS      0.961     0.974     0.967       457
#                             HAIR_TREATMENTS      0.800     0.854     0.826        89
#                       DJ_EFFECTS_PROCESSORS      0.791     0.827     0.809       202
#                     BUMPER_IMPACT_ABSORBERS      0.979     0.963     0.971       245
#                  NOTEBOOKS_AND_WRITING_PADS      0.968     0.980     0.974       153
#                         FINGERPRINT_READERS      0.957     0.917     0.936        24
#                                    BLANKETS      0.926     0.855     0.889       131
#                                 SUPPLEMENTS      0.858     0.898     0.877       430
#                                    HAMMOCKS      1.000     0.988     0.994        82
#                AUTOMOTIVE_SIDE_VIEW_MIRRORS      0.986     0.969     0.977       737
#                   FACIAL_SKIN_CARE_PRODUCTS      0.860     0.868     0.864       341
#                             PACKAGING_ROLLS      0.963     1.000     0.981        26
#                       TV_AND_MONITOR_MOUNTS      0.995     0.995     0.995       546
#                                CAR_ANTENNAS      0.999     0.997     0.998       934
#                                    CACHACAS      0.981     0.981     0.981       157
#                                     TV_SMPS      0.929     0.943     0.936       279
#                              KITCHEN_TOWELS      0.986     0.986     0.986       277
#                                    CALIPERS      1.000     1.000     1.000        22
#                             PARKING_SENSORS      0.959     0.996     0.977       539
#                   ELECTRIC_PRESSURE_WASHERS      0.988     0.985     0.987       343
#              HAIR_SHAMPOOS_AND_CONDITIONERS      0.949     0.841     0.892        44
#                                STETHOSCOPES      1.000     0.917     0.957        36
#                                    PRINTERS      0.970     0.963     0.966       400
#                             ELECTRIC_DRILLS      0.976     0.971     0.973       414
#                                KITCHEN_POTS      0.960     0.948     0.954       485
#                              FUEL_INJECTORS      0.913     0.913     0.913       103
#                            VEHICLE_SPEAKERS      0.958     0.964     0.961       421
#                           HOME_OFFICE_DESKS      0.955     0.987     0.970       149
#                              GUITAR_STRINGS      0.955     1.000     0.977       106
#                             DISC_PACKAGINGS      0.883     0.919     0.901        74
#                                 LIP_GLOSSES      0.927     0.932     0.929       190
#                                     DRESSES      0.981     0.974     0.978       692
#                                BASS_GUITARS      0.980     0.961     0.971       467
#                                  TURNTABLES      0.914     0.900     0.907       270
#                           TOY_BUILDING_SETS      0.933     0.900     0.916       249
#                                  BED_SHEETS      0.921     0.933     0.927        75
#                               CAR_GEARBOXES      0.996     0.985     0.991       267
#                                FLOOD_LIGHTS      0.963     0.970     0.967       462
#                          SOLDERING_MACHINES      0.987     0.979     0.983       383
#                            ELECTRONIC_DRUMS      0.956     0.932     0.944       117
#                    DATA_CABLES_AND_ADAPTERS      0.871     0.925     0.897        80
#                      AUTOMOTIVE_WATER_PUMPS      0.914     0.893     0.903       391
#                              FOOTBALL_BALLS      0.981     0.987     0.984       156
#                                LENS_FILTERS      0.973     0.947     0.959        75
#                       INSTRUMENT_AMPLIFIERS      0.941     0.931     0.936       449
#                                MUSIC_STANDS      1.000     1.000     1.000        32
#                        CAR_DISTRIBUTOR_CAPS      0.945     0.922     0.933       205
#                                  MOUSE_PADS      0.995     0.975     0.985       201
#                                     FABRICS      0.940     0.953     0.946       379
#                               CABIN_FILTERS      0.980     0.996     0.988       244
#                             SEWING_MACHINES      0.966     0.973     0.969       292
#                                      MIXERS      0.974     0.980     0.977       350
#                         MOTORCYCLE_FAIRINGS      0.965     0.941     0.953       353
#                                   CV_JOINTS      0.977     0.966     0.972       443
#                  HAIR_STRAIGHTENING_BRUSHES      0.963     1.000     0.981        26
#                             WHEELS_BEARINGS      0.991     0.991     0.991       547
#                                AV_RECEIVERS      0.874     0.883     0.878       188
#                              NETWORK_CABLES      0.930     0.984     0.957       190
#                                       CRIBS      0.939     0.946     0.942       242
#                                HOME_HEATERS      0.960     0.932     0.946       234
#                  BRACELETS_AND_ANKLE_BRACES      0.937     0.951     0.944       346
#                                    SNEAKERS      0.873     0.958     0.914        72
#                  AUTOMOTIVE_THROTTLE_BODIES      0.979     0.940     0.959        50
#                              COOKING_SCALES      0.945     0.954     0.949       412
#                               PEDAL_EFFECTS      0.949     0.967     0.958       695
#                              ENGINE_PISTONS      0.977     0.955     0.966       132
#                               FLATWARE_SETS      1.000     0.871     0.931        31
#                                     PANTIES      0.902     0.939     0.920        49
#                          ELECTRICAL_OUTLETS      0.901     0.967     0.933       122
#                          BABY_CLOTHING_SETS      0.914     0.842     0.877        76
#                              STEAM_CLEANERS      0.938     0.789     0.857        19
#                            DECORATIVE_VASES      0.892     0.934     0.913       274
#                             FOOD_PROCESSORS      0.983     0.859     0.917       135
#                             TRAILER_HITCHES      0.995     1.000     0.997       184
#                       SOFA_AND_FUTON_COVERS      1.000     0.990     0.995        99
#                                      SHIRTS      0.964     0.907     0.934       118
#                       VEHICLE_CLUTCH_CABLES      1.000     1.000     1.000        10
#                                 GATE_MOTORS      0.967     0.970     0.968       298
#                                  FOG_LIGHTS      0.966     0.986     0.976       292
#                                   SIM_CARDS      0.880     0.917     0.898        24
#                               BABY_MONITORS      0.982     0.986     0.984       220
#                            VEHICLE_CV_AXLES      0.985     0.971     0.978        69
#                                   LIPSTICKS      0.953     0.979     0.966       562
#                      SERVING_AND_HOME_TRAYS      0.974     0.960     0.967       354
#                                    COOKTOPS      0.583     0.636     0.609        11
#                              GRAPHICS_CARDS      0.941     1.000     0.970        32
#                          FIRE_EXTINGUISHERS      1.000     0.967     0.983        30
#                  KITCHEN_CABINET_ORGANIZERS      0.667     0.286     0.400         7
#                                       SOFAS      0.879     0.940     0.908       100
#                            GRAPHICS_TABLETS      0.995     0.974     0.984       190
#                                      SHORTS      0.946     0.967     0.957       274
#                            SWIMMING_GOGGLES      0.921     0.909     0.915        77
#                            POOL_INFLATABLES      0.900     0.973     0.935        37
#                                       DOORS      0.957     0.918     0.937        97
#                               SPORT_WATCHES      0.945     0.933     0.939       478
#            PORTABLE_EVAPORATIVE_AIR_COOLERS      0.914     0.928     0.921       138
#              DOG_CARRIERS_AND_CARRYING_BAGS      0.897     0.912     0.904        57
#                     ENGINE_INTAKE_MANIFOLDS      0.942     0.961     0.951        51
#                          MOTORCYCLE_HELMETS      0.992     1.000     0.996       715
#                        COMBUSTION_CHAINSAWS      1.000     1.000     1.000        84
#               ELECTRONIC_ENTRANCE_INTERCOMS      0.967     0.962     0.964       211
#                                     CRAYONS      0.990     0.970     0.980       101
#                                THERMOMETERS      0.955     1.000     0.977        63
#                              CAMERA_TRIPODS      0.990     0.967     0.979       427
#                           ARTIFICIAL_PLANTS      0.576     0.704     0.633        27
#                            PROJECTOR_MOUNTS      0.800     0.800     0.800         5
#                 PORTABLE_ELECTRIC_MASSAGERS      0.974     0.892     0.931        83
#               NON_CORRECTIVE_CONTACT_LENSES      0.913     0.875     0.894        24
#                                     PUZZLES      0.934     0.959     0.947        74
#            WASHING_AND_DRYER_MACHINE_COVERS      0.961     0.980     0.970        50
#                        PUSH_AND_RIDING_TOYS      0.643     0.562     0.600        32
#                                SHOWER_HEADS      0.887     0.932     0.909       235
#                            ANTI_THEFT_STUDS      0.981     0.950     0.965       220
#                               HATS_AND_CAPS      0.836     0.938     0.884        65
#                                   MAGAZINES      0.797     0.741     0.768       143
#                  ENGINE_COOLING_FAN_SHROUDS      1.000     0.988     0.994        83
#                      AUTOMOTIVE_OIL_FILTERS      0.860     0.860     0.860        43
#                            MOTORCYCLE_TIRES      0.930     0.898     0.913       147
#               MOTORCYCLE_TURN_SIGNAL_LIGHTS      0.995     1.000     0.998       221
#                                     PILLOWS      0.968     0.968     0.968        31
#                                    TEQUILAS      0.970     0.970     0.970        33
#                                 TOILET_RUGS      0.927     0.924     0.926       249
#                                      FLUTES      0.983     0.922     0.952       128
#                                    UKULELES      0.945     1.000     0.972        52
#                                 TOOTHPASTES      0.922     0.952     0.937        62
#                       MOTORCYCLE_CRASH_BARS      1.000     0.905     0.950        21
#                             PIPES_AND_TUBES      0.500     0.692     0.581        13
#                                FOOD_SLICERS      0.952     0.909     0.930        22
#           DESKTOP_COMPUTER_COOLERS_AND_FANS      0.947     0.986     0.966       345
#                                   SWAY_BARS      0.959     0.959     0.959        98
#                            AQUARIUM_FILTERS      0.972     0.981     0.977       214
#               CELLPHONE_REPLACEMENT_CAMERAS      1.000     0.961     0.980        51
#                                     MIRRORS      0.941     0.930     0.936        86
#                             BLU_RAY_PLAYERS      0.955     0.971     0.963       175
#                          AUTOMOTIVE_FENDERS      0.968     0.984     0.976       124
#                             SPARKLING_WINES      0.900     0.750     0.818        12
#              ENGINE_VALVES_SPRING_RETAINERS      0.971     0.985     0.978        68
#                                BABY_WALKERS      0.867     1.000     0.929        13
#             ANTIVIRUS_AND_INTERNET_SECURITY      1.000     0.938     0.968        16
#                       COTTON_CANDY_MACHINES      1.000     1.000     1.000         7
#                             ORAL_IRRIGATORS      1.000     0.875     0.933         8
#                    MOTORCYCLE_CLUTCH_COVERS      0.924     0.971     0.947       239
#                               GAME_CONSOLES      0.955     0.922     0.938       347
#                               TABLE_RUNNERS      0.943     0.985     0.964        67
#                           PLAYGROUND_SLIDES      0.929     1.000     0.963        13
#                                 3D_PRINTERS      1.000     1.000     1.000        47
#                                 DIAPER_BAGS      0.933     0.942     0.937       103
#                               ELECTRIC_SAWS      0.978     0.992     0.985       363
#                           KITCHEN_FURNITURE      0.923     0.947     0.935        38
#                            BABY_HIGH_CHAIRS      0.852     0.784     0.817        88
#                                    MINI_PCS      0.750     0.857     0.800        14
#                                    MASCARAS      0.967     0.946     0.956        92
#                     AUTOMOTIVE_WHEEL_COVERS      0.969     0.984     0.977       129
#                           WINDSHIELD_WIPERS      0.979     0.984     0.982       190
#                                     LIQUORS      0.990     0.960     0.975       100
#                            CLOTHING_PATCHES      0.964     0.914     0.938        58
#                       WOOD_BURNING_MACHINES      1.000     1.000     1.000         7
#                                  BINOCULARS      0.989     0.962     0.975       186
#                      COMMERCIAL_LIGHT_SIGNS      0.914     1.000     0.955        32
#                            WATER_DISPENSERS      0.924     0.969     0.946       225
#                       GLOW_PLUG_CONTROLLERS      0.964     0.964     0.964        56
#                                  TELEPHONES      0.857     0.857     0.857        21
#                             AIR_COMPRESSORS      0.972     0.969     0.970       353
#                           OPERATING_SYSTEMS      0.940     0.933     0.937       270
#                        CAR_ENGINE_CAMSHAFTS      0.789     1.000     0.882        15
#                             CLOTHES_HANGERS      0.989     0.957     0.972        92
#                                    WETSUITS      0.941     0.842     0.889        19
#                                TOILET_SEATS      0.990     0.990     0.990       191
#                            AUTOMOTIVE_DOORS      0.991     0.997     0.994       332
#             SUSPENSION_CONTROL_ARM_BUSHINGS      0.864     0.826     0.844       138
#                          VEHICLE_BRAKE_PADS      0.997     0.991     0.994       350
#                 REMOTE_CONTROL_TOY_VEHICLES      0.903     0.933     0.918       209
#                        AUTOMOTIVE_NERF_BARS      0.974     1.000     0.987        38
#                              ESSENTIAL_OILS      0.870     0.923     0.896        65
#                             SLATWALL_PANELS      0.988     0.988     0.988        80
#                                  TOOL_BOXES      0.906     0.972     0.938       109
#                                BABY_DIAPERS      0.992     0.976     0.984       375
#                          ALARMS_AND_SENSORS      0.915     0.946     0.930       295
#                            MOTORCYCLE_SUITS      1.000     0.919     0.958        37
#                               KITCHEN_BOWLS      0.857     0.818     0.837        22
#                              CAT_SCRATCHERS      1.000     0.933     0.966        15
#                              INK_CARTRIDGES      0.900     0.900     0.900        30
#                    MARKERS_AND_HIGHLIGHTERS      0.913     0.921     0.917       126
#                      JUMPSUITS_AND_OVERALLS      0.909     0.943     0.926       106
#                                 NAIL_DRYERS      0.992     0.947     0.969       131
#                             CAMERA_MONOPODS      0.868     0.939     0.902        49
#                                    BICYCLES      0.989     0.962     0.975       184
#                                        SALT      1.000     1.000     1.000        10
#                    SCREEN_PRINTING_MACHINES      0.875     1.000     0.933        14
#                                        BEDS      0.933     0.977     0.955        43
#                     BODY_SKIN_CARE_PRODUCTS      0.871     0.834     0.852       380
# AUTOMOTIVE_MANUAL_TRANSMISSION_SHIFT_LEVERS      0.821     0.920     0.868        25
#                            TV_STORAGE_UNITS      0.961     0.942     0.951        52
#                       AUTOMOTIVE_HEADLIGHTS      0.970     0.977     0.973       131
#                                  PAINTBALLS      0.920     0.953     0.936        85
#                                      SCREWS      0.881     0.912     0.897        57
#                                  TOY_ROBOTS      0.786     0.733     0.759        15
#                                     POSTERS      0.976     0.976     0.976       206
#                            MOTORCYCLE_PANTS      0.941     0.941     0.941       118
#                         INTEGRATED_CIRCUITS      0.912     0.861     0.886        72
#                                GARDEN_HOSES      0.982     0.982     0.982        56
#                                 ALTERNATORS      0.915     0.896     0.905        48
#                          MAGNIFYING_GLASSES      0.983     0.926     0.954       122
#                                    PERFUMES      0.923     0.923     0.923        52
#                                       FLOUR      0.833     1.000     0.909        15
#                                FISHING_RODS      0.826     1.000     0.905        19
#                  CELLPHONE_AND_TABLET_CASES      0.912     0.912     0.912        91
#                                     PAJAMAS      0.949     1.000     0.974        56
#                                  BUTT_PLUGS      0.871     0.794     0.831        34
#                 LUMBAR_AND_ABDOMINAL_BRACES      0.972     0.952     0.962       147
#                              AIR_MATTRESSES      0.980     0.974     0.977       154
#                               WATER_HEATERS      0.983     0.964     0.973       247
#                                 DISHWASHERS      0.973     0.959     0.966       148
#                        ELECTRIC_LAWN_MOWERS      1.000     0.750     0.857         4
#                               HOME_THEATERS      0.545     0.667     0.600         9
#                            LED_STAGE_LIGHTS      0.900     0.880     0.890       216
#           CHALKBOARD_AND_WHITEBOARD_ERASERS      0.913     0.913     0.913        23
#                               BABY_BOUNCERS      0.708     0.944     0.810        18
#                                       RINGS      1.000     0.977     0.988        43
#                      AUTOMOTIVE_AIR_FILTERS      0.948     1.000     0.973        55
#                                LUGGAGE_TAGS      0.896     0.915     0.905        47
#                                HEATER_CORES      1.000     0.714     0.833        21
#                             CLEANING_CLOTHS      0.926     0.946     0.936        93
#                              AIR_FRESHENERS      0.871     0.628     0.730        43
#                                     BLOUSES      0.725     0.763     0.744        38
#                             SAFETY_FOOTWEAR      1.000     1.000     1.000        66
#                                FREEZER_BAGS      0.778     0.875     0.824         8
#                      SHOCK_MOUNT_INSOLATORS      0.812     0.890     0.850        73
#                                  BAR_CLAMPS      1.000     0.750     0.857        16
#                             CHRISTMAS_TREES      1.000     0.946     0.972        37
#                          CAR_AIR_FRESHENERS      0.777     0.879     0.825        99
#                          BASKETBALL_JERSEYS      0.923     0.800     0.857        15
#                                  ACCORDIONS      0.981     0.981     0.981       311
#                                  FOOD_CARTS      0.857     0.968     0.909        31
#                                   HEAT_GUNS      1.000     0.989     0.995        94
#                   ENGINE_CRANKSHAFT_PULLEYS      0.919     0.953     0.936       107
#                                  PARTY_HATS      0.625     0.625     0.625         8
#                             RECEPTION_DESKS      0.667     1.000     0.800         4
#                              PICTURE_FRAMES      0.949     0.987     0.968       151
#                               OSCILLOSCOPES      1.000     0.900     0.947        10
#                   HABERDASHERY_LACE_EDGINGS      0.944     0.927     0.935       109
#                                       BEERS      0.988     0.971     0.979       170
#                                HOLE_PUNCHES      0.833     0.714     0.769         7
#                               DJ_TURNTABLES      0.776     0.738     0.756        80
#                                 VR_HEADSETS      0.983     0.989     0.986       352
#                             KITCHEN_MORTARS      1.000     1.000     1.000         4
#                                       OVENS      0.933     0.977     0.954       171
#                                DISHES_RACKS      0.731     0.776     0.752        49
#                                    EARRINGS      0.935     0.977     0.956        44
#                                   WARDROBES      0.921     0.972     0.946        36
#                           RACKS_AND_PINIONS      0.991     0.956     0.973       113
#                                   BOOKCASES      0.917     0.943     0.930        35
#                                  TOY_TRAINS      0.872     0.872     0.872        94
#                      CARD_PAYMENT_TERMINALS      0.889     0.941     0.914        17
#                           SUBMERSIBLE_PUMPS      0.980     0.990     0.985       100
#             GARDENING_AND_AGRICULTURE_SEEDS      0.850     0.944     0.895        36
#                                      MODEMS      0.879     0.886     0.883       123
#                               OFFICE_CHAIRS      0.922     0.959     0.940        98
#                                   PENDRIVES      0.971     0.971     0.971       139
#                                   NECKLACES      0.956     0.945     0.950        91
#                          ENGINE_GASKET_SETS      1.000     0.353     0.522        17
#                  AUTOMOTIVE_SHOCK_ABSORBERS      0.831     0.742     0.784        66
#                                 VINYL_ROLLS      0.773     0.729     0.750        70
#               TROLLEY_AND_FURNITURE_CASTERS      1.000     0.750     0.857         4
#                   TV_RECEIVERS_AND_DECODERS      0.700     0.778     0.737        18
#                                LIFE_JACKETS      0.789     0.682     0.732        22
#                        SELF_ADHESIVE_LABELS      0.891     0.837     0.863        49
#                   IGNITION_SWITCH_ACTUATORS      1.000     1.000     1.000        14
#                            BABY_STERILIZERS      0.917     1.000     0.957        22
#                       PARKING_BRAKE_HANDLES      0.938     0.984     0.960        61
#                      CLUTCH_SLAVE_CYLINDERS      0.658     0.833     0.735        30
#                                      FISHES      1.000     0.667     0.800         9
#                             COOKIES_CUTTERS      0.912     0.948     0.930        77
#                                  NEBULIZERS      1.000     1.000     1.000        49
#                                  COMFORTERS      0.630     0.850     0.723        20
#                         ELLIPTICAL_MACHINES      0.967     0.930     0.948       128
#                               ENGINE_VALVES      0.952     0.909     0.930        44
#                                  SANDPAPERS      0.900     0.857     0.878        21
#        AUTOMOTIVE_SHOCK_ABSORBER_BUMP_STOPS      1.000     0.838     0.912        37
#                                     GAZEBOS      0.978     0.956     0.967        91
#                                  XENON_KITS      0.952     1.000     0.976        20
#                      AUTOMOTIVE_DOOR_PANELS      0.980     1.000     0.990       150
#                  INDOOR_CURTAINS_AND_BLINDS      0.969     0.981     0.975       161
#                         CAR_WINDOW_SWITCHES      0.906     0.935     0.921        31
#                                   EPILATORS      0.824     0.894     0.857        94
#                           MALE_MASTURBATORS      0.917     0.733     0.815        15
#                         DRILLS_SCREWDRIVERS      0.533     0.667     0.593        24
#                                  CONCEALERS      0.953     0.920     0.936        88
#                     SCHOOL_AND_OFFICE_GLUES      0.692     0.900     0.783        10
#                      SANDALS_AND_FLIP_FLOPS      1.000     0.956     0.977        45
#                                   BAR_SOAPS      0.797     0.917     0.853        60
#                   ELECTRIC_BATHROOM_FAUCETS      0.833     0.800     0.816        25
#                           VOLTAGE_DETECTORS      0.967     1.000     0.983        29
#                     ORTHOPEDIC_ANKLE_BRACES      1.000     0.867     0.929        15
#                              HEDGE_TRIMMERS      1.000     1.000     1.000        14
#                         STABILIZERS_AND_UPS      1.000     1.000     1.000         2
#                               BABY_PLAYARDS      0.971     0.900     0.934       110
#                            RESISTANCE_BANDS      0.967     0.967     0.967       180
#                             LAPTOP_CHARGERS      0.940     0.926     0.933        68
#                       COMPUTER_MOTHERBOARDS      0.778     0.854     0.814        41
#                                 COIN_PURSES      0.852     0.885     0.868        26
#                                       VESTS      1.000     0.969     0.984        97
#                           HAIRDRESSING_CAPS      1.000     1.000     1.000         8
# ...
#                            LIVING_ROOM_SETS      0.769     0.714     0.741        14
#                              BABY_PACIFIERS      1.000     1.000     1.000        15
#                              HAND_POLISHERS      0.706     0.857     0.774        14
#                                SHADE_CLOTHS      1.000     1.000     1.000        12
#                               HAMMER_DRILLS      1.000     0.375     0.545         8
#                              POWER_GRINDERS      0.765     1.000     0.867        13
#                               CAMERA_STRAPS      1.000     0.667     0.800         3
#                           LAWN_MOWER_BLADES      0.778     0.778     0.778         9
#                          PNEUMATIC_STAPLERS      1.000     1.000     1.000        13
#              THERMAL_REFRIGERATORS_AND_BAGS      0.840     0.750     0.792        28
#                                LIGHT_STANDS      1.000     1.000     1.000         7
#                                      STRAWS      1.000     0.750     0.857         8
#                                       SUITS      0.880     0.667     0.759        33
#                           BATHROOM_VANITIES      0.833     0.625     0.714         8
#                         VIBRATION_PLATFORMS      1.000     1.000     1.000        18
#                               DINING_TABLES      0.875     0.875     0.875        16
#                           TURNTABLE_NEEDLES      1.000     0.667     0.800         3
#                                HEARING_AIDS      1.000     1.000     1.000        10
#                     ORTHOPEDIC_WALKER_BOOTS      0.818     0.643     0.720        14
#                                         TEA      0.750     0.600     0.667        10
#                             TORQUE_WRENCHES      1.000     1.000     1.000         8
#                                 CATS_LITTER      1.000     0.917     0.957        12
#                                 MATE_GOURDS      0.733     1.000     0.846        11
#                                  MEAT_HOOKS      0.667     1.000     0.800         2
#                       AUTOMOTIVE_DEFLECTORS      1.000     1.000     1.000         5
#                   VARIABLE_FREQUENCY_DRIVES      1.000     0.857     0.923         7
#                                  SWEETENERS      1.000     1.000     1.000         8
#         AUTOMOTIVE_CELLPHONE_AND_GPS_MOUNTS      0.833     0.833     0.833         6
#                         RADIO_BASE_STATIONS      0.333     0.167     0.222         6
#                                    CRUTCHES      1.000     1.000     1.000         4
#                                POWER_STRIPS      1.000     0.400     0.571        10
#                               KATANA_SWORDS      0.833     0.769     0.800        13
#                        CATS_AND_DOGS_TREATS      0.917     0.786     0.846        14
#                         MEMORY_CARD_READERS      0.500     0.333     0.400         3
#                            TELEPHONE_CABLES      1.000     0.929     0.963        14
#                          SOLID_SWEET_PASTES      1.000     0.800     0.889        10
#                           DISPOSABLE_GLOVES      1.000     0.667     0.800         3
#                        MOTORCYCLE_GRAB_BARS      1.000     1.000     1.000         3
#                              PLUNGE_ROUTERS      0.857     0.750     0.800         8
#                         GROOVE_JOINT_PLIERS      0.800     1.000     0.889         4
#                          BICYCLE_HANDLEBARS      0.667     0.800     0.727         5
#                          SOLDERING_STATIONS      0.923     0.923     0.923        26
#                               TANDEM_CHAIRS      0.800     0.571     0.667         7
#                                GARAGE_DOORS      0.818     0.750     0.783        12
#                         SPARK_PLUG_WIRESETS      0.900     0.844     0.871        32
#                       ELECTRIC_SHOWER_HEADS      1.000     0.200     0.333         5
#                        PORTABLE_DVD_PLAYERS      1.000     0.778     0.875         9
#                                      DILDOS      0.333     0.375     0.353         8
#                   INDUSTRIAL_DOUGH_KNEADERS      0.917     0.846     0.880        13
#                   UNIVERSAL_REMOTE_CONTROLS      1.000     0.333     0.500         3
#                                 WHEEL_STUDS      0.200     0.167     0.182         6
#                            FABRIC_SOFTENERS      0.900     0.947     0.923        19
#              MOTORCYCLE_DISTRIBUTION_CHAINS      0.900     0.947     0.923        19
#                       DOOR_AND_WINDOW_LOCKS      1.000     0.333     0.500         3
#                                        GINS      0.750     0.750     0.750         4
#                                 HAND_TRUCKS      0.600     0.750     0.667         4
#                                    STAPLERS      1.000     1.000     1.000         6
#                                   APERITIFS      1.000     1.000     1.000         5
#                             SHOWER_CURTAINS      1.000     1.000     1.000         4
#                              ANTIQUE_CHAIRS      1.000     0.286     0.444         7
#                               YOGURT_MAKERS      0.800     0.800     0.800         5
#                                 SHIN_GUARDS      1.000     0.500     0.667         2
#                             GOLF_CLUBS_SETS      0.889     0.889     0.889         9
#                  FOOTBALL_GOALKEEPER_GLOVES      1.000     0.875     0.933        16
#                                LASER_LEVELS      0.875     0.875     0.875         8
#                        KEYBOARD_CONTROLLERS      0.125     0.200     0.154         5
#                          ALTERNATOR_PULLEYS      0.941     0.941     0.941        17
#            CAMERA_AND_CELLPHONE_STABILIZERS      0.667     0.667     0.667         3
#                                BABY_JUMPERS      1.000     0.667     0.800         6
#                 CAMERA_REPLACEMENT_DISPLAYS      1.000     1.000     1.000         7
#                                 CRANKSHAFTS      1.000     0.667     0.800        21
#                                BREAD_MAKERS      0.750     1.000     0.857         3
#                    SCHOOL_AND_OFFICE_PAPERS      0.625     0.625     0.625         8
#                    STOVETOP_POPCORN_POPPERS      1.000     0.750     0.857         8
#                      BREAST_FEEDING_PILLOWS      0.900     0.818     0.857        11
#                               POOL_CLEANERS      0.800     0.800     0.800         5
#                              LINEMAN_PLIERS      0.500     1.000     0.667         3
#                                  COAT_RACKS      0.429     0.500     0.462         6
#                                  POOL_PUMPS      0.923     1.000     0.960        12
#                     WATER_PURIFIERS_FILTERS      0.889     0.400     0.552        20
#                               SAFETY_GLOVES      0.500     0.167     0.250         6
#                          ISOPROPYL_ALCOHOLS      0.889     0.889     0.889         9
#               VEHICLE_BRAKE_HYDRAULIC_HOSES      0.875     0.778     0.824         9
#                              MEDICINE_BALLS      1.000     0.750     0.857         4
#                             KITCHEN_GRATERS      0.667     0.800     0.727         5
#                              NAPKIN_HOLDERS      0.889     0.889     0.889         9
#                               PUNCHING_BAGS      1.000     0.333     0.500         3
#                                 ESPADRILLES      1.000     0.875     0.933         8
#                         CAR_CENTER_CONSOLES      0.455     0.833     0.588         6
#                             VIDEO_CASSETTES      0.750     1.000     0.857         6
#                              POTENTIOMETERS      1.000     1.000     1.000         5
#                    READY_TO_DRINK_COCKTAILS      0.000     0.000     0.000         2
#                                 FLOOR_LAMPS      0.818     0.818     0.818        11
#                            DRONE_PROPELLERS      0.714     0.833     0.769         6
#                                       TENTS      0.786     1.000     0.880        11
#                            SAFETY_HARNESSES      1.000     0.500     0.667         4
#                                    SYRINGES      0.800     1.000     0.889         4
#                                   BEDLINERS      0.857     0.750     0.800        16
#                     ELECTROLYTIC_CAPACITORS      1.000     1.000     1.000         7
#                                BASKET_BALLS      1.000     1.000     1.000         2
#                                   OTOSCOPES      1.000     1.000     1.000         4
#                               WAFFLE_MAKERS      1.000     0.875     0.933         8
#                                 PENIS_RINGS      1.000     0.500     0.667         4
#                          ELECTRIC_AIR_PUMPS      0.875     0.875     0.875         8
#                             COFFEE_CAPSULES      1.000     0.600     0.750         5
#                         BABY_PACIFIER_CLIPS      0.714     1.000     0.833         5
#                                   KEY_RACKS      0.667     0.500     0.571         4
#                                  DEODORANTS      0.750     0.600     0.667         5
#                          INDUSTRIAL_PULLEYS      0.833     1.000     0.909         5
#                               BILL_COUNTERS      1.000     1.000     1.000         5
#                  AUDIO_AND_VIDEO_CONNECTORS      0.000     0.000     0.000         4
#                            WASHING_MACHINES      0.909     0.833     0.870        12
#                 ENGINE_COOLING_FAN_SWITCHES      0.714     0.833     0.769         6
#                        AUTOMOTIVE_BATTERIES      1.000     0.600     0.750         5
#                        CHIP_AND_DIP_SERVERS      0.500     0.250     0.333         4
#                                ARCHERY_BOWS      0.750     1.000     0.857         6
#                             VINYL_FLOORINGS      0.778     1.000     0.875         7
#                              MENSTRUAL_CUPS      1.000     1.000     1.000         5
#                               SLEEPING_BAGS      0.429     0.750     0.545         4
#                               RUBBER_STAMPS      0.500     0.800     0.615         5
#                              DRYER_MACHINES      1.000     0.750     0.857         8
#                            ENERGETIC_STONES      0.778     1.000     0.875         7
#                              BICYCLE_PEDALS      1.000     0.778     0.875         9
#                      MOTORCYCLE_CARBURETORS      0.800     0.800     0.800         5
#                           SCREWDRIVERS_SETS      1.000     0.667     0.800         3
#                                EDIBLE_SEEDS      0.667     0.667     0.667         3
#                        STORE_SHOPPING_CARTS      1.000     0.750     0.857         4
#                         SWIMMING_NOSE_CLIPS      1.000     1.000     1.000         2
#                                 AFTERSHAVES      1.000     0.333     0.500         3
#                              AIRBAG_MODULES      1.000     1.000     1.000         3
#                                   HAND_SAWS      0.857     1.000     0.923         6
#           NECK_GAITERS_MASKS_AND_BALACLAVAS      1.000     0.500     0.667         2
#                          MAGNETIC_COMPASSES      1.000     1.000     1.000         6
#                          MAKEUP_TRAIN_CASES      1.000     0.500     0.667         4
#                            POPCORN_MACHINES      1.000     1.000     1.000         9
#                                LAMP_HOLDERS      0.400     0.500     0.444         4
#                    IGNITION_CONTROL_MODULES      0.500     0.143     0.222         7
#                             CAR_FRONT_MASKS      1.000     1.000     1.000         2
#                               HAND_BLENDERS      0.000     0.000     0.000         3
#                              KIDS_TRICYCLES      1.000     1.000     1.000         4
#                              AIRGUN_PELLETS      1.000     0.250     0.400         4
#                            AUTOMOTIVE_SEATS      0.625     0.833     0.714         6
#              MOTORCYCLE_TRANSMISSION_CROWNS      1.000     1.000     1.000         4
#                                  LAMINATORS      1.000     0.714     0.833         7
#                                 CEREAL_BARS      1.000     0.667     0.800         3
#                                MUSIC_ALBUMS      1.000     0.750     0.857         4
#                   AUTOMOTIVE_CV_JOINT_BOOTS      0.700     1.000     0.824         7
#                           MICROWAVE_KEYPADS      1.000     0.667     0.800         3
#                           WALL_ANCHOR_PLUGS      1.000     0.500     0.667         4
#                                 DRUM_STANDS      0.714     0.714     0.714         7
#                                 PET_COLLARS      0.929     0.929     0.929        14
#                             GATE_GEAR_RACKS      1.000     0.750     0.857         4
#                                   CAR_HOODS      1.000     1.000     1.000         3
#                        SCREEN_PRINTING_KITS      1.000     1.000     1.000         4
#                                  LED_STRIPS      0.800     1.000     0.889         4
#                             SANDWICH_MAKERS      0.667     1.000     0.800         2
#                              DENTAL_FLOSSES      1.000     1.000     1.000         2
#                              CAMERA_FLASHES      0.833     1.000     0.909         5
#                           DOG_NAIL_CLIPPERS      0.667     1.000     0.800         2
#                                    PINBALLS      1.000     0.833     0.909         6
#                                      GAUZES      1.000     0.833     0.909         6
#                                        SODS      1.000     0.667     0.800         3
#                          ELECTRICITY_METERS      0.000     0.000     0.000         4
#                             METAL_DETECTORS      1.000     0.667     0.800         3
#                          ELECTRIC_CHAINSAWS      1.000     0.667     0.800         3
#                            KNITTING_NEEDLES      0.600     1.000     0.750         6
#                           SWIMMING_EARPLUGS      0.000     0.000     0.000         2
#                                 SOUND_CARDS      1.000     0.800     0.889         5
#                                    STEPPERS      0.667     0.500     0.571         4
#                                 FANNY_PACKS      0.667     1.000     0.800         4
#                          TOOTHBRUSH_HOLDERS      1.000     0.500     0.667         2
#                          TABLE_TENNIS_BALLS      1.000     1.000     1.000         2
#                 ENGINE_OIL_PRESSURE_SENSORS      0.000     0.000     0.000         3
#                                 ICE_BUCKETS      0.800     0.571     0.667         7
#                               MASSAGE_SOFAS      1.000     1.000     1.000         4
#                              STYLING_CHAIRS      1.000     0.500     0.667         2
#                               BICYCLE_SEATS      1.000     1.000     1.000         3
#                            VOLLEYBALL_BALLS      1.000     0.667     0.800         3
#                           SPHYGMOMANOMETERS      0.750     0.750     0.750         4
#                              BINDING_SPINES      1.000     0.500     0.667         2
#                    DIGITAL_WEATHER_STATIONS      1.000     1.000     1.000         2
#                          HOME_BOTTLE_STANDS      1.000     0.667     0.800         3
#                                   DOORBELLS      0.500     0.500     0.500         2
#                                DRIED_FRUITS      1.000     1.000     1.000         2
#                            BOXING_HEADGEARS      1.000     0.500     0.667         2
#
#                                    accuracy                          0.950    138550
#                                   macro avg      0.899     0.872     0.879    138550
#                                weighted avg      0.951     0.950     0.950    138550
