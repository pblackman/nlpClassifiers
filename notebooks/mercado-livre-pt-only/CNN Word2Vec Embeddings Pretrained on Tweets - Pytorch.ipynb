# %%
from os.path import join
import os
import pandas as pd
import torch
import numpy as np
import torch.nn as nn
import torch.nn.functional as F
from torch.optim.lr_scheduler import ReduceLROnPlateau
from torch.nn.init import kaiming_uniform_
from torch.optim import SGD
from torch.utils.data import DataLoader, SequentialSampler, RandomSampler
from torch.optim import Adam
from nlpClassifiers.data.dataset  import NLPDataset, Vocabulary
from sklearn.metrics import roc_curve, auc, classification_report
from scipy.special import expit
import gensim
import shutil
from pathlib import Path
import random

# %%
ROOT = '../../'
PATH_TO_VIRTUAL_OPERATOR_DATA = join(ROOT, "data/virtual-operator")
PATH_TO_AGENT_BENCHMARK_DATA = join(ROOT, "data/agent-benchmark")
PATH_TO_ML_PT_DATA = join(ROOT, "data/mercado-livre-pt-only")

PATH_TO_VIRTUAL_OPERATOR_MODELS = join(ROOT, "models/virtual-operator")
PATH_TO_AGENT_BENCHMARK_MODELS = join(ROOT, "models/agent-benchmark")
PATH_TO_ML_PT_MODELS = join(ROOT, "models/mercado-livre-pt-only")

EMBEDDING_DIM = 300
EMBEDDINGS_FILE = '../../data/twitter-pt/vocab/word2vec-model-tweets-pmann-reduced-pt.bin'
MAX_WORDS = 30000
dataset = 'mercado-livre-pt'
sentence_max_len = 82
batch_size = 512

epochs=30
stopwords_lang = None
gpu=1
lr=0.001
clipping_value=0.25
save_name='cnn-pytorch-word2vec-tweets-embeddings'
patience=5

# %%
BASE_PATH_TO_MODELS = {"virtual-operator": PATH_TO_VIRTUAL_OPERATOR_MODELS, "agent-benchmark": PATH_TO_AGENT_BENCHMARK_MODELS, "mercado-livre-pt": PATH_TO_ML_PT_MODELS}
FULL_PATH_TO_MODELS = join(BASE_PATH_TO_MODELS[dataset], "bow-classifier")

# %%
def _init_fn(worker_id):
    np.random.seed(seed)

# %%
def read_data(dataset, subset):
    BASE_PATH_TO_DATASET = {"virtual-operator": PATH_TO_VIRTUAL_OPERATOR_DATA, "agent-benchmark": PATH_TO_AGENT_BENCHMARK_DATA, "mercado-livre-pt": PATH_TO_ML_PT_DATA}
    BASE_PATH_TO_DATASET = {"train": join(BASE_PATH_TO_DATASET[dataset], "train.csv"), "val": join(BASE_PATH_TO_DATASET[dataset], "val.csv"), "test": join(BASE_PATH_TO_DATASET[dataset], "test.csv")}
    FULL_PATH_TO_DATASET = BASE_PATH_TO_DATASET[subset]
    
    if dataset == "mercado-livre-pt":
        sep=","
    else:
        sep=";"
    data = pd.read_csv(FULL_PATH_TO_DATASET, sep=sep, names =['utterance','label'], header=None, dtype={'utterance':str, 'label': str} )
    return data

# %%
train_df = read_data(dataset, "train")
val_df = read_data(dataset, "val")

# %%
voc = Vocabulary('CNN', stopwords_lang)
voc.build_vocab(train_df['utterance'].tolist() +  val_df['utterance'].tolist(), MAX_WORDS)
embedding_weights = voc.load_embeddings(EMBEDDINGS_FILE, EMBEDDING_DIM)
if voc.num_words < MAX_WORDS or MAX_WORDS == 0:
    MAX_WORDS = voc.num_words
# Out:
# 17400 tokens not found in vocabulary.

# %%
train_corpus = NLPDataset(dataset, "train", sentence_max_len, vocab= voc)
labels_dict = train_corpus.labels_dict
val_corpus = NLPDataset(dataset, "val", sentence_max_len, labels_dict = labels_dict, vocab= voc)

# %%
train_dataloader = DataLoader(
            train_corpus,
            sampler = RandomSampler(train_corpus),
            batch_size = batch_size,
            pin_memory=True,
            worker_init_fn=_init_fn,
            num_workers=0
)

validation_dataloader = DataLoader(
            val_corpus,
            sampler = RandomSampler(val_corpus),
            batch_size = batch_size,
            pin_memory=True,
            worker_init_fn=_init_fn,
            num_workers=0
)

# %%
def initialize_weights(model):
    if type(model) in [nn.Linear]:
        nn.init.xavier_normal_(model.weight.data)
    elif type(model) in [nn.LSTM, nn.RNN, nn.GRU]:
        nn.init.xavier_normal_(model.weight_hh_l0)
        nn.init.xavier_normal_(model.weight_ih_l0)

# %%
#del model
torch.cuda.empty_cache()

# %%
def seed_everything(seed=10):
    random.seed(seed)
    os.environ['PYTHONHASHSEED'] = str(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    torch.backends.cudnn.deterministic = True

# %%
seed_everything()

# %%
class CNNNet(nn.Module):
    def __init__(self, num_classes, num_features, criterion, embedding_dim, embedding_weights=None):
        super(CNNNet, self).__init__()
        self.criterion = criterion
        self.embedding_dim = embedding_dim
        self.n_layers = 1
        self.embedding = nn.Embedding(num_features, embedding_dim, padding_idx = 0)
        if(embedding_weights is not None):
            print("Embedding layer Weights won't be updated.")
            self.embedding.load_state_dict({'weight': embedding_weights})
            self.embedding.weight.requires_grad = False
            #self.embedding.from_pretrained(embedding_weights, freeze=True)
        else:
            self.embedding.weight.data = torch.zeros(self.embedding.weight.data.size())
            self.embedding.weight.requires_grad = True
        
        self.cnn = nn.Conv1d(embedding_dim, 256, 4)
        
        for name, param in self.cnn.named_parameters():
            if 'bias' in name:
                nn.init.constant_(param, 0.0)
            elif 'weight_ih' in name:
                nn.init.kaiming_normal_(param)
            elif 'weight_hh' in name:
                nn.init.orthogonal_(param)
             
        self.dropout = nn.Dropout(0.2)       
        self.out = nn.Linear(256, num_classes)
        self.init_weights()
    def forward(self, x, y):
        # Conv1d takes in (batch, channels, seq_len), but raw embedded is (batch, seq_len, channels)
        h_embedding = self.embedding(x)
        h_embedding = h_embedding.permute(0, 2, 1)
        h_cnn = self.cnn(h_embedding)
        h_cnn = h_cnn.permute(0, 2, 1)
        h_cnn = self.dropout(h_cnn)
        h_max_pool = self.global_max_pool(h_cnn)
        x = self.out(h_max_pool)
        loss = self.criterion(x, y)
        # return the final output
        return loss,x 
    
    @staticmethod
    def global_max_pool(x):
        """Convolution and global max pooling layer"""
        return x.max(1)[0]
    
    def init_weights(self):
        """
        Here we reproduce Keras default initialization weights to initialize Embeddings/LSTM weights
        """
        ih = (param.data for name, param in self.named_parameters() if 'weight_ih' in name)
        hh = (param.data for name, param in self.named_parameters() if 'weight_hh' in name)
        b = (param.data for name, param in self.named_parameters() if 'bias' in name)
        for t in ih:
            nn.init.xavier_uniform(t)
        for t in hh:
            nn.init.orthogonal(t)
        for t in b:
            nn.init.constant(t, 0)
    
    def init_hidden(self, batch_size, device):
        weight = next(self.parameters()).data
        hidden = (weight.new(self.n_layers, batch_size, self.embedding_dim).zero_().to(device),
                      weight.new(self.n_layers, batch_size, self.embedding_dim).zero_().to(device))
        return hidden

# %%
criterion = torch.nn.CrossEntropyLoss()
model = CNNNet(train_corpus.num_labels, MAX_WORDS, criterion, EMBEDDING_DIM, embedding_weights)
# Out:
# Embedding layer Weights won't be updated.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:60: UserWarning: nn.init.constant is now deprecated in favor of nn.init.constant_.

# %%
model.apply(initialize_weights)
# Out:
# CNNNet(
#   (criterion): CrossEntropyLoss()
#   (embedding): Embedding(30000, 300, padding_idx=0)
#   (cnn): Conv1d(300, 256, kernel_size=(4,), stride=(1,))
#   (dropout): Dropout(p=0.2, inplace=False)
#   (out): Linear(in_features=256, out_features=1048, bias=True)
# )

# %%
device = torch.device(f"cuda:{gpu}")

# %%
model = model.to(device)
optimizer = Adam(model.parameters(),lr, betas=(0.7, 0.999))

# %%
def multi_acc(y_pred, y_test):
    y_pred_softmax = torch.log_softmax(y_pred, dim = 1)
    _, y_pred_tags = torch.max(y_pred_softmax, dim = 1)    
    
    correct_pred = (y_pred_tags == y_test).float()
    acc = correct_pred.sum() / len(correct_pred)
    acc = acc * 100.0

    return acc

# %%
def get_accuracy_from_logits(logits, labels):
    acc = (labels.cpu() == logits.cpu().argmax(-1)).float().detach().numpy()
    return float(100 * acc.sum() / len(acc))

# %%
scheduler = ReduceLROnPlateau(optimizer, mode='min', patience=3,verbose=True, factor=0.1)

best_epoch = -1
last_saved_model = ""
training_stats = []
global_step = 0
best_val_acc = float("-inf")
best_model_wts = None
best_curr_val = 0

for epoch_i in range(0, epochs):
    print("")
    print('======== Epoch {:} / {:} ========'.format(epoch_i + 1, epochs))
    print('Training...')
    total_train_loss = 0
    model.train()
    for step, batch in enumerate(train_dataloader):
        #val_h = model.init_hidden(len(batch[0]), device)
        #val_h = tuple([each.data for each in val_h])
         # Progress update every 40 batches.
        if step % 40 == 0 and not step == 0:
            print('  Batch {:>5,}  of  {:>5,}.    .'.format(step, len(train_dataloader)))
        b_input_ids = batch[0]
        b_labels = batch[1].to(device)
        b_input_ids = torch.tensor(b_input_ids).to(device).long()
        model.zero_grad()
        loss, logits = model(b_input_ids, b_labels)
        loss.backward()
        torch.nn.utils.clip_grad_norm_(model.parameters(), clipping_value)
        optimizer.step()
        step_loss = loss.item()
        if step % 40 == 0 and not step == 0:
            print("  step loss: {0:.2f}".format(step_loss))
        total_train_loss += step_loss
        global_step += 1
    avg_train_loss = total_train_loss / len(train_dataloader)
    # Measure how long this epoch took.
    print("")
    print("  Average training loss: {0:.2f}".format(avg_train_loss))

    print("")
    print("Running Validation...")
    model.eval()

    # Tracking variables
    total_eval_accuracy = 0.0
    total_eval_loss = 0
    nb_eval_steps = 0
    for step, batch in enumerate(validation_dataloader):
        #val_h = model.init_hidden(len(batch[0]), device)
        #val_h = tuple([each.data for each in val_h])
        b_input_ids = batch[0]
        b_input_ids = torch.tensor(b_input_ids).to(device).long()
        b_labels = batch[1].to(device)
        with torch.no_grad():
            # Forward pass, calculate logit predictions.
            loss, logits = model(b_input_ids, b_labels)
        total_eval_loss += loss
        batch_acc = get_accuracy_from_logits(logits, b_labels)
        batch_acc2 = multi_acc(logits, b_labels)
        print("Batch accuracy: {0:.2f}".format(batch_acc))
        total_eval_accuracy += batch_acc
    
    # Calculate the average loss over all of the batches.
    avg_val_accuracy = total_eval_accuracy / len(validation_dataloader)
    print("  Accuracy: {0:.2f}".format(avg_val_accuracy))
    
    if avg_val_accuracy > best_val_acc:
        print(f"New best model, saving it!")
        if avg_val_accuracy > best_curr_val:
            best_curr_val = avg_val_accuracy
        if last_saved_model:
            shutil.rmtree(last_saved_model)
        model_path = Path(
            FULL_PATH_TO_MODELS,
            f"base-dataset-{dataset}-{save_name}"
        )
        last_saved_model = model_path
        model_path.mkdir(parents=True, exist_ok=True)
        best_val_acc = avg_val_accuracy
        torch.save(model, join(model_path, "best-model.pth"))
        best_epoch = epoch_i
        n_epochs_no_improvement = 0
    elif avg_val_accuracy > best_curr_val:
        best_curr_val = avg_val_accuracy
        n_epochs_no_improvement = 0
    else:
        n_epochs_no_improvement += 1
        print(f"The model does not improve for {n_epochs_no_improvement} epochs!")

    if n_epochs_no_improvement > patience:
        print(f"====>Stopping training, the model did not improve for {n_epochs_no_improvement}\n====>Best epoch: {best_epoch + 1}.")
        break
    scheduler.step(total_eval_loss)
print("")
print("Training complete!")
# Out:
# ======== Epoch 1 / 30 ========
# Training...
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:25: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   Batch    40  of    975.    .
#   step loss: 4.73
#   Batch    80  of    975.    .
#   step loss: 3.83
#   Batch   120  of    975.    .
#   step loss: 3.14
#   Batch   160  of    975.    .
#   step loss: 2.81
#   Batch   200  of    975.    .
#   step loss: 2.64
#   Batch   240  of    975.    .
#   step loss: 2.27
#   Batch   280  of    975.    .
#   step loss: 2.46
#   Batch   320  of    975.    .
#   step loss: 2.37
#   Batch   360  of    975.    .
#   step loss: 2.04
#   Batch   400  of    975.    .
#   step loss: 1.73
#   Batch   440  of    975.    .
#   step loss: 2.04
#   Batch   480  of    975.    .
#   step loss: 2.03
#   Batch   520  of    975.    .
#   step loss: 1.72
#   Batch   560  of    975.    .
#   step loss: 1.81
#   Batch   600  of    975.    .
#   step loss: 1.61
#   Batch   640  of    975.    .
#   step loss: 1.59
#   Batch   680  of    975.    .
#   step loss: 1.56
#   Batch   720  of    975.    .
#   step loss: 1.47
#   Batch   760  of    975.    .
#   step loss: 1.59
#   Batch   800  of    975.    .
#   step loss: 1.52
#   Batch   840  of    975.    .
#   step loss: 1.32
#   Batch   880  of    975.    .
#   step loss: 1.40
#   Batch   920  of    975.    .
#   step loss: 1.52
#   Batch   960  of    975.    .
#   step loss: 1.38
#
#   Average training loss: 2.24
#
# Running Validation...
# Batch accuracy: 75.20
# Batch accuracy: 74.02
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:53: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
# Batch accuracy: 71.29
# Batch accuracy: 73.05
# Batch accuracy: 70.70
# Batch accuracy: 73.05
# Batch accuracy: 72.46
# Batch accuracy: 72.85
# Batch accuracy: 72.27
# Batch accuracy: 74.41
# Batch accuracy: 76.56
# Batch accuracy: 69.14
# Batch accuracy: 68.36
# Batch accuracy: 75.20
# Batch accuracy: 72.07
# Batch accuracy: 74.22
# Batch accuracy: 75.20
# Batch accuracy: 69.73
# Batch accuracy: 75.20
# Batch accuracy: 75.20
# Batch accuracy: 72.27
# Batch accuracy: 75.39
# Batch accuracy: 75.78
# Batch accuracy: 71.09
# Batch accuracy: 73.24
# Batch accuracy: 71.29
# Batch accuracy: 78.12
# Batch accuracy: 74.80
# Batch accuracy: 72.85
# Batch accuracy: 72.66
# Batch accuracy: 76.95
# Batch accuracy: 71.88
# Batch accuracy: 75.39
# Batch accuracy: 74.22
# Batch accuracy: 70.51
# Batch accuracy: 70.31
# Batch accuracy: 74.61
# Batch accuracy: 74.22
# Batch accuracy: 74.61
# Batch accuracy: 72.27
# Batch accuracy: 74.41
# Batch accuracy: 73.24
# Batch accuracy: 74.22
# Batch accuracy: 76.95
# Batch accuracy: 72.27
# Batch accuracy: 73.44
# Batch accuracy: 73.24
# Batch accuracy: 74.41
# Batch accuracy: 73.63
# Batch accuracy: 76.76
# Batch accuracy: 72.46
# Batch accuracy: 76.76
# Batch accuracy: 73.44
# Batch accuracy: 77.54
# Batch accuracy: 70.31
# Batch accuracy: 76.56
# Batch accuracy: 70.90
# Batch accuracy: 75.00
# Batch accuracy: 75.59
# Batch accuracy: 72.27
# Batch accuracy: 70.70
# Batch accuracy: 70.70
# Batch accuracy: 73.05
# Batch accuracy: 74.61
# Batch accuracy: 70.90
# Batch accuracy: 75.98
# Batch accuracy: 74.41
# Batch accuracy: 75.20
# Batch accuracy: 71.88
# Batch accuracy: 72.85
# Batch accuracy: 78.91
# Batch accuracy: 73.83
# Batch accuracy: 70.90
# Batch accuracy: 73.24
# Batch accuracy: 74.80
# Batch accuracy: 69.73
# Batch accuracy: 73.24
# Batch accuracy: 76.17
# Batch accuracy: 69.92
# Batch accuracy: 71.88
# Batch accuracy: 71.68
# Batch accuracy: 75.39
# Batch accuracy: 74.22
# Batch accuracy: 73.24
# Batch accuracy: 72.85
# Batch accuracy: 72.66
# Batch accuracy: 78.91
# Batch accuracy: 77.15
# Batch accuracy: 75.20
# Batch accuracy: 76.56
# Batch accuracy: 73.24
# Batch accuracy: 70.51
# Batch accuracy: 74.80
# Batch accuracy: 72.46
# Batch accuracy: 73.63
# Batch accuracy: 72.27
# Batch accuracy: 72.85
# Batch accuracy: 71.88
# Batch accuracy: 70.70
# Batch accuracy: 74.02
# Batch accuracy: 71.88
# Batch accuracy: 72.27
# Batch accuracy: 75.78
# Batch accuracy: 76.37
# Batch accuracy: 71.88
# Batch accuracy: 74.02
# Batch accuracy: 73.05
# Batch accuracy: 73.05
# Batch accuracy: 75.00
#   Accuracy: 73.55
# New best model, saving it!
#
# ======== Epoch 2 / 30 ========
# Training...
#   Batch    40  of    975.    .
#   step loss: 1.28
#   Batch    80  of    975.    .
#   step loss: 1.25
#   Batch   120  of    975.    .
#   step loss: 1.24
#   Batch   160  of    975.    .
#   step loss: 1.13
#   Batch   200  of    975.    .
#   step loss: 1.29
#   Batch   240  of    975.    .
#   step loss: 1.09
#   Batch   280  of    975.    .
#   step loss: 1.14
#   Batch   320  of    975.    .
#   step loss: 1.12
#   Batch   360  of    975.    .
#   step loss: 1.10
#   Batch   400  of    975.    .
#   step loss: 1.20
#   Batch   440  of    975.    .
#   step loss: 1.09
#   Batch   480  of    975.    .
#   step loss: 1.11
#   Batch   520  of    975.    .
#   step loss: 1.23
#   Batch   560  of    975.    .
#   step loss: 1.24
#   Batch   600  of    975.    .
#   step loss: 1.21
#   Batch   640  of    975.    .
#   step loss: 1.10
#   Batch   680  of    975.    .
#   step loss: 1.10
#   Batch   720  of    975.    .
#   step loss: 1.27
#   Batch   760  of    975.    .
#   step loss: 1.01
#   Batch   800  of    975.    .
#   step loss: 0.98
#   Batch   840  of    975.    .
#   step loss: 1.20
#   Batch   880  of    975.    .
#   step loss: 1.08
#   Batch   920  of    975.    .
#   step loss: 1.16
#   Batch   960  of    975.    .
#   step loss: 1.06
#
#   Average training loss: 1.17
#
# Running Validation...
# Batch accuracy: 80.08
# Batch accuracy: 78.32
# Batch accuracy: 75.98
# Batch accuracy: 78.71
# Batch accuracy: 78.32
# Batch accuracy: 78.12
# Batch accuracy: 79.10
# Batch accuracy: 77.54
# Batch accuracy: 75.98
# Batch accuracy: 75.00
# Batch accuracy: 78.71
# Batch accuracy: 82.81
# Batch accuracy: 80.66
# Batch accuracy: 80.86
# Batch accuracy: 77.15
# Batch accuracy: 77.15
# Batch accuracy: 79.30
# Batch accuracy: 79.88
# Batch accuracy: 78.91
# Batch accuracy: 79.30
# Batch accuracy: 75.39
# Batch accuracy: 78.71
# Batch accuracy: 78.71
# Batch accuracy: 77.93
# Batch accuracy: 75.20
# Batch accuracy: 77.34
# Batch accuracy: 74.41
# Batch accuracy: 82.23
# Batch accuracy: 77.15
# Batch accuracy: 78.91
# Batch accuracy: 79.49
# Batch accuracy: 80.27
# Batch accuracy: 75.00
# Batch accuracy: 80.66
# Batch accuracy: 77.73
# Batch accuracy: 80.47
# Batch accuracy: 78.91
# Batch accuracy: 80.86
# Batch accuracy: 76.95
# Batch accuracy: 78.91
# Batch accuracy: 80.27
# Batch accuracy: 80.47
# Batch accuracy: 81.64
# Batch accuracy: 77.15
# Batch accuracy: 82.03
# Batch accuracy: 84.18
# Batch accuracy: 80.86
# Batch accuracy: 82.62
# Batch accuracy: 79.49
# Batch accuracy: 77.34
# Batch accuracy: 80.27
# Batch accuracy: 75.98
# Batch accuracy: 80.47
# Batch accuracy: 79.30
# Batch accuracy: 76.17
# Batch accuracy: 79.49
# Batch accuracy: 78.71
# Batch accuracy: 76.95
# Batch accuracy: 78.52
# Batch accuracy: 80.27
# Batch accuracy: 76.76
# Batch accuracy: 78.12
# Batch accuracy: 75.39
# Batch accuracy: 77.73
# Batch accuracy: 79.69
# Batch accuracy: 77.93
# Batch accuracy: 78.32
# Batch accuracy: 79.49
# Batch accuracy: 75.59
# Batch accuracy: 79.88
# Batch accuracy: 78.52
# Batch accuracy: 77.54
# Batch accuracy: 79.30
# Batch accuracy: 78.52
# Batch accuracy: 79.30
# Batch accuracy: 80.86
# Batch accuracy: 76.37
# Batch accuracy: 81.05
# Batch accuracy: 77.15
# Batch accuracy: 76.95
# Batch accuracy: 80.47
# Batch accuracy: 78.91
# Batch accuracy: 80.08
# Batch accuracy: 80.66
# Batch accuracy: 76.37
# Batch accuracy: 77.34
# Batch accuracy: 80.27
# Batch accuracy: 77.73
# Batch accuracy: 80.66
# Batch accuracy: 80.27
# Batch accuracy: 78.32
# Batch accuracy: 83.59
# Batch accuracy: 77.15
# Batch accuracy: 80.27
# Batch accuracy: 76.56
# Batch accuracy: 75.78
# Batch accuracy: 79.10
# Batch accuracy: 79.10
# Batch accuracy: 75.00
# Batch accuracy: 78.71
# Batch accuracy: 78.71
# Batch accuracy: 81.45
# Batch accuracy: 79.69
# Batch accuracy: 80.47
# Batch accuracy: 80.47
# Batch accuracy: 82.23
# Batch accuracy: 80.08
# Batch accuracy: 78.32
# Batch accuracy: 83.06
#   Accuracy: 78.85
# New best model, saving it!
#
# ======== Epoch 3 / 30 ========
# Training...
#   Batch    40  of    975.    .
#   step loss: 0.92
#   Batch    80  of    975.    .
#   step loss: 1.00
#   Batch   120  of    975.    .
#   step loss: 0.98
#   Batch   160  of    975.    .
#   step loss: 1.04
#   Batch   200  of    975.    .
#   step loss: 0.87
#   Batch   240  of    975.    .
#   step loss: 0.90
#   Batch   280  of    975.    .
#   step loss: 1.11
#   Batch   320  of    975.    .
#   step loss: 1.05
#   Batch   360  of    975.    .
#   step loss: 0.95
#   Batch   400  of    975.    .
#   step loss: 0.80
#   Batch   440  of    975.    .
#   step loss: 0.98
#   Batch   480  of    975.    .
#   step loss: 1.03
#   Batch   520  of    975.    .
#   step loss: 1.01
#   Batch   560  of    975.    .
#   step loss: 0.94
#   Batch   600  of    975.    .
#   step loss: 0.87
#   Batch   640  of    975.    .
#   step loss: 0.96
#   Batch   680  of    975.    .
#   step loss: 0.92
#   Batch   720  of    975.    .
#   step loss: 0.86
#   Batch   760  of    975.    .
#   step loss: 0.87
#   Batch   800  of    975.    .
#   step loss: 1.01
#   Batch   840  of    975.    .
#   step loss: 0.89
#   Batch   880  of    975.    .
#   step loss: 1.06
#   Batch   920  of    975.    .
#   step loss: 0.89
#   Batch   960  of    975.    .
#   step loss: 0.84
#
#   Average training loss: 0.93
#
# Running Validation...
# Batch accuracy: 82.62
# Batch accuracy: 82.42
# Batch accuracy: 82.81
# Batch accuracy: 82.42
# Batch accuracy: 80.08
# Batch accuracy: 82.62
# Batch accuracy: 81.45
# Batch accuracy: 81.84
# Batch accuracy: 80.27
# Batch accuracy: 79.69
# Batch accuracy: 79.10
# Batch accuracy: 83.79
# Batch accuracy: 84.57
# Batch accuracy: 80.27
# Batch accuracy: 81.25
# Batch accuracy: 81.25
# Batch accuracy: 83.20
# Batch accuracy: 81.45
# Batch accuracy: 83.20
# Batch accuracy: 81.84
# Batch accuracy: 79.49
# Batch accuracy: 79.88
# Batch accuracy: 81.64
# Batch accuracy: 82.42
# Batch accuracy: 83.40
# Batch accuracy: 77.93
# Batch accuracy: 80.08
# Batch accuracy: 82.81
# Batch accuracy: 78.91
# Batch accuracy: 81.45
# Batch accuracy: 80.47
# Batch accuracy: 80.27
# Batch accuracy: 83.59
# Batch accuracy: 79.49
# Batch accuracy: 79.88
# Batch accuracy: 79.69
# Batch accuracy: 79.10
# Batch accuracy: 82.62
# Batch accuracy: 80.08
# Batch accuracy: 84.18
# Batch accuracy: 82.42
# Batch accuracy: 79.88
# Batch accuracy: 81.45
# Batch accuracy: 82.62
# Batch accuracy: 83.79
# Batch accuracy: 79.10
# Batch accuracy: 80.66
# Batch accuracy: 78.71
# Batch accuracy: 82.81
# Batch accuracy: 76.76
# Batch accuracy: 80.66
# Batch accuracy: 81.84
# Batch accuracy: 78.32
# Batch accuracy: 81.05
# Batch accuracy: 79.69
# Batch accuracy: 83.40
# Batch accuracy: 80.08
# Batch accuracy: 83.20
# Batch accuracy: 82.62
# Batch accuracy: 83.20
# Batch accuracy: 82.03
# Batch accuracy: 80.47
# Batch accuracy: 82.23
# Batch accuracy: 84.18
# Batch accuracy: 82.03
# Batch accuracy: 83.59
# Batch accuracy: 79.88
# Batch accuracy: 81.45
# Batch accuracy: 81.05
# Batch accuracy: 81.25
# Batch accuracy: 79.88
# Batch accuracy: 79.10
# Batch accuracy: 81.05
# Batch accuracy: 81.45
# Batch accuracy: 80.66
# Batch accuracy: 82.03
# Batch accuracy: 78.71
# Batch accuracy: 80.47
# Batch accuracy: 83.40
# Batch accuracy: 78.91
# Batch accuracy: 83.98
# Batch accuracy: 80.86
# Batch accuracy: 82.62
# Batch accuracy: 81.64
# Batch accuracy: 79.88
# Batch accuracy: 80.27
# Batch accuracy: 81.64
# Batch accuracy: 83.59
# Batch accuracy: 79.69
# Batch accuracy: 80.08
# Batch accuracy: 80.66
# Batch accuracy: 80.08
# Batch accuracy: 82.03
# Batch accuracy: 81.84
# Batch accuracy: 82.62
# Batch accuracy: 81.84
# Batch accuracy: 77.93
# Batch accuracy: 82.23
# Batch accuracy: 82.23
# Batch accuracy: 85.74
# Batch accuracy: 82.62
# Batch accuracy: 81.84
# Batch accuracy: 83.20
# Batch accuracy: 80.27
# Batch accuracy: 80.66
# Batch accuracy: 82.81
# Batch accuracy: 82.62
# Batch accuracy: 83.79
# Batch accuracy: 82.26
#   Accuracy: 81.39
# New best model, saving it!
#
# ======== Epoch 4 / 30 ========
# Training...
#   Batch    40  of    975.    .
#   step loss: 0.81
#   Batch    80  of    975.    .
#   step loss: 0.85
#   Batch   120  of    975.    .
#   step loss: 0.73
#   Batch   160  of    975.    .
#   step loss: 0.83
#   Batch   200  of    975.    .
#   step loss: 0.76
#   Batch   240  of    975.    .
#   step loss: 0.80
#   Batch   280  of    975.    .
#   step loss: 0.80
#   Batch   320  of    975.    .
#   step loss: 0.79
#   Batch   360  of    975.    .
#   step loss: 0.71
#   Batch   400  of    975.    .
#   step loss: 0.77
#   Batch   440  of    975.    .
#   step loss: 0.80
#   Batch   480  of    975.    .
#   step loss: 0.90
#   Batch   520  of    975.    .
#   step loss: 0.86
#   Batch   560  of    975.    .
#   step loss: 0.85
#   Batch   600  of    975.    .
#   step loss: 0.95
#   Batch   640  of    975.    .
#   step loss: 0.85
#   Batch   680  of    975.    .
#   step loss: 0.86
#   Batch   720  of    975.    .
#   step loss: 0.79
#   Batch   760  of    975.    .
#   step loss: 0.76
#   Batch   800  of    975.    .
#   step loss: 0.84
#   Batch   840  of    975.    .
#   step loss: 0.65
#   Batch   880  of    975.    .
#   step loss: 0.68
#   Batch   920  of    975.    .
#   step loss: 0.85
#   Batch   960  of    975.    .
#   step loss: 0.79
#
#   Average training loss: 0.80
#
# Running Validation...
# Batch accuracy: 81.25
# Batch accuracy: 80.86
# Batch accuracy: 82.62
# Batch accuracy: 81.64
# Batch accuracy: 79.69
# Batch accuracy: 83.40
# Batch accuracy: 84.38
# Batch accuracy: 83.20
# Batch accuracy: 81.64
# Batch accuracy: 81.05
# Batch accuracy: 80.66
# Batch accuracy: 81.84
# Batch accuracy: 85.94
# Batch accuracy: 80.27
# Batch accuracy: 83.79
# Batch accuracy: 82.62
# Batch accuracy: 82.62
# Batch accuracy: 82.42
# Batch accuracy: 83.40
# Batch accuracy: 83.59
# Batch accuracy: 83.79
# Batch accuracy: 82.03
# Batch accuracy: 83.59
# Batch accuracy: 82.03
# Batch accuracy: 80.86
# Batch accuracy: 82.42
# Batch accuracy: 86.33
# Batch accuracy: 83.40
# Batch accuracy: 81.64
# Batch accuracy: 82.42
# Batch accuracy: 82.03
# Batch accuracy: 82.23
# Batch accuracy: 81.64
# Batch accuracy: 81.84
# Batch accuracy: 82.62
# Batch accuracy: 83.98
# Batch accuracy: 84.18
# Batch accuracy: 81.25
# Batch accuracy: 84.96
# Batch accuracy: 82.81
# Batch accuracy: 81.64
# Batch accuracy: 82.23
# Batch accuracy: 81.05
# Batch accuracy: 82.62
# Batch accuracy: 79.49
# Batch accuracy: 79.88
# Batch accuracy: 82.81
# Batch accuracy: 84.57
# Batch accuracy: 79.10
# Batch accuracy: 83.98
# Batch accuracy: 85.16
# Batch accuracy: 84.18
# Batch accuracy: 81.64
# Batch accuracy: 83.59
# Batch accuracy: 81.05
# Batch accuracy: 80.47
# Batch accuracy: 80.27
# Batch accuracy: 82.42
# Batch accuracy: 84.77
# Batch accuracy: 83.20
# Batch accuracy: 85.35
# Batch accuracy: 80.86
# Batch accuracy: 83.40
# Batch accuracy: 81.05
# Batch accuracy: 83.20
# Batch accuracy: 83.01
# Batch accuracy: 83.40
# Batch accuracy: 82.03
# Batch accuracy: 85.16
# Batch accuracy: 83.98
# Batch accuracy: 80.47
# Batch accuracy: 81.05
# Batch accuracy: 84.96
# Batch accuracy: 82.23
# Batch accuracy: 84.18
# Batch accuracy: 83.79
# Batch accuracy: 84.18
# Batch accuracy: 82.42
# Batch accuracy: 79.69
# Batch accuracy: 79.69
# Batch accuracy: 81.25
# Batch accuracy: 83.20
# Batch accuracy: 82.23
# Batch accuracy: 82.42
# Batch accuracy: 81.05
# Batch accuracy: 81.84
# Batch accuracy: 83.98
# Batch accuracy: 80.27
# Batch accuracy: 81.84
# Batch accuracy: 84.57
# Batch accuracy: 81.05
# Batch accuracy: 84.38
# Batch accuracy: 80.66
# Batch accuracy: 84.57
# Batch accuracy: 82.81
# Batch accuracy: 83.40
# Batch accuracy: 81.64
# Batch accuracy: 83.79
# Batch accuracy: 83.98
# Batch accuracy: 81.64
# Batch accuracy: 82.62
# Batch accuracy: 83.98
# Batch accuracy: 82.81
# Batch accuracy: 81.25
# Batch accuracy: 81.84
# Batch accuracy: 83.40
# Batch accuracy: 87.11
# Batch accuracy: 83.40
# Batch accuracy: 89.52
#   Accuracy: 82.64
# New best model, saving it!
#
# ======== Epoch 5 / 30 ========
# Training...
#   Batch    40  of    975.    .
#   step loss: 0.80
#   Batch    80  of    975.    .
#   step loss: 0.60
#   Batch   120  of    975.    .
#   step loss: 0.71
#   Batch   160  of    975.    .
#   step loss: 0.77
#   Batch   200  of    975.    .
#   step loss: 0.64
#   Batch   240  of    975.    .
#   step loss: 0.60
#   Batch   280  of    975.    .
#   step loss: 0.73
#   Batch   320  of    975.    .
#   step loss: 0.70
#   Batch   360  of    975.    .
#   step loss: 0.67
#   Batch   400  of    975.    .
#   step loss: 0.65
#   Batch   440  of    975.    .
#   step loss: 0.81
#   Batch   480  of    975.    .
#   step loss: 0.76
#   Batch   520  of    975.    .
#   step loss: 0.73
#   Batch   560  of    975.    .
#   step loss: 0.70
#   Batch   600  of    975.    .
#   step loss: 0.80
#   Batch   640  of    975.    .
#   step loss: 0.86
#   Batch   680  of    975.    .
#   step loss: 0.78
#   Batch   720  of    975.    .
#   step loss: 0.57
#   Batch   760  of    975.    .
#   step loss: 0.77
#   Batch   800  of    975.    .
#   step loss: 0.71
#   Batch   840  of    975.    .
#   step loss: 0.68
#   Batch   880  of    975.    .
#   step loss: 0.72
#   Batch   920  of    975.    .
#   step loss: 0.81
#   Batch   960  of    975.    .
#   step loss: 0.79
#
#   Average training loss: 0.72
#
# Running Validation...
# Batch accuracy: 84.96
# Batch accuracy: 81.05
# Batch accuracy: 82.42
# Batch accuracy: 82.42
# Batch accuracy: 82.62
# Batch accuracy: 82.42
# Batch accuracy: 79.10
# Batch accuracy: 81.84
# Batch accuracy: 82.62
# Batch accuracy: 81.05
# Batch accuracy: 83.20
# Batch accuracy: 83.59
# Batch accuracy: 80.86
# Batch accuracy: 83.01
# Batch accuracy: 84.57
# Batch accuracy: 85.16
# Batch accuracy: 84.57
# Batch accuracy: 84.57
# Batch accuracy: 82.42
# Batch accuracy: 83.98
# Batch accuracy: 83.40
# Batch accuracy: 83.59
# Batch accuracy: 82.03
# Batch accuracy: 79.30
# Batch accuracy: 83.98
# Batch accuracy: 84.77
# Batch accuracy: 81.45
# Batch accuracy: 83.01
# Batch accuracy: 83.40
# Batch accuracy: 87.30
# Batch accuracy: 84.38
# Batch accuracy: 85.74
# Batch accuracy: 82.81
# Batch accuracy: 87.11
# Batch accuracy: 81.45
# Batch accuracy: 87.11
# Batch accuracy: 81.84
# Batch accuracy: 83.40
# Batch accuracy: 86.13
# Batch accuracy: 82.81
# Batch accuracy: 82.42
# Batch accuracy: 82.62
# Batch accuracy: 81.84
# Batch accuracy: 84.38
# Batch accuracy: 85.55
# Batch accuracy: 84.57
# Batch accuracy: 83.20
# Batch accuracy: 83.01
# Batch accuracy: 83.20
# Batch accuracy: 83.79
# Batch accuracy: 85.16
# Batch accuracy: 85.94
# Batch accuracy: 84.18
# Batch accuracy: 82.81
# Batch accuracy: 83.59
# Batch accuracy: 83.40
# Batch accuracy: 80.86
# Batch accuracy: 84.77
# Batch accuracy: 83.98
# Batch accuracy: 83.40
# Batch accuracy: 83.01
# Batch accuracy: 83.79
# Batch accuracy: 82.23
# Batch accuracy: 84.38
# Batch accuracy: 83.98
# Batch accuracy: 83.40
# Batch accuracy: 81.84
# Batch accuracy: 83.79
# Batch accuracy: 81.84
# Batch accuracy: 82.81
# Batch accuracy: 82.81
# Batch accuracy: 82.42
# Batch accuracy: 82.23
# Batch accuracy: 81.25
# Batch accuracy: 81.25
# Batch accuracy: 81.05
# Batch accuracy: 82.81
# Batch accuracy: 82.62
# Batch accuracy: 85.74
# Batch accuracy: 83.40
# Batch accuracy: 82.62
# Batch accuracy: 85.55
# Batch accuracy: 83.98
# Batch accuracy: 84.77
# Batch accuracy: 84.38
# Batch accuracy: 83.01
# Batch accuracy: 81.84
# Batch accuracy: 83.59
# Batch accuracy: 86.33
# Batch accuracy: 81.25
# Batch accuracy: 83.98
# Batch accuracy: 85.55
# Batch accuracy: 84.38
# Batch accuracy: 82.03
# Batch accuracy: 81.25
# Batch accuracy: 82.81
# Batch accuracy: 82.23
# Batch accuracy: 84.96
# Batch accuracy: 83.98
# Batch accuracy: 81.84
# Batch accuracy: 82.03
# Batch accuracy: 82.03
# Batch accuracy: 80.47
# Batch accuracy: 81.84
# Batch accuracy: 83.01
# Batch accuracy: 85.35
# Batch accuracy: 81.25
# Batch accuracy: 84.77
# Batch accuracy: 87.90
#   Accuracy: 83.30
# New best model, saving it!
#
# ======== Epoch 6 / 30 ========
# Training...
#   Batch    40  of    975.    .
#   step loss: 0.50
#   Batch    80  of    975.    .
#   step loss: 0.60
#   Batch   120  of    975.    .
#   step loss: 0.63
#   Batch   160  of    975.    .
#   step loss: 0.61
#   Batch   200  of    975.    .
#   step loss: 0.58
#   Batch   240  of    975.    .
#   step loss: 0.82
#   Batch   280  of    975.    .
#   step loss: 0.62
#   Batch   320  of    975.    .
#   step loss: 0.67
#   Batch   360  of    975.    .
#   step loss: 0.73
#   Batch   400  of    975.    .
#   step loss: 0.65
#   Batch   440  of    975.    .
#   step loss: 0.61
#   Batch   480  of    975.    .
#   step loss: 0.69
#   Batch   520  of    975.    .
#   step loss: 0.66
#   Batch   560  of    975.    .
#   step loss: 0.66
#   Batch   600  of    975.    .
#   step loss: 0.69
#   Batch   640  of    975.    .
#   step loss: 0.57
#   Batch   680  of    975.    .
#   step loss: 0.80
#   Batch   720  of    975.    .
#   step loss: 0.49
#   Batch   760  of    975.    .
#   step loss: 0.68
#   Batch   800  of    975.    .
#   step loss: 0.60
#   Batch   840  of    975.    .
#   step loss: 0.73
#   Batch   880  of    975.    .
#   step loss: 0.59
#   Batch   920  of    975.    .
#   step loss: 0.55
#   Batch   960  of    975.    .
#   step loss: 0.66
#
#   Average training loss: 0.66
#
# Running Validation...
# Batch accuracy: 83.98
# Batch accuracy: 85.74
# Batch accuracy: 82.81
# Batch accuracy: 80.47
# Batch accuracy: 83.79
# Batch accuracy: 85.55
# Batch accuracy: 82.62
# Batch accuracy: 83.79
# Batch accuracy: 80.08
# Batch accuracy: 83.20
# Batch accuracy: 83.59
# Batch accuracy: 85.16
# Batch accuracy: 86.91
# Batch accuracy: 83.40
# Batch accuracy: 85.55
# Batch accuracy: 84.18
# Batch accuracy: 84.38
# Batch accuracy: 84.77
# Batch accuracy: 82.42
# Batch accuracy: 82.62
# Batch accuracy: 83.01
# Batch accuracy: 83.98
# Batch accuracy: 84.77
# Batch accuracy: 84.77
# Batch accuracy: 83.59
# Batch accuracy: 83.79
# Batch accuracy: 86.33
# Batch accuracy: 84.96
# Batch accuracy: 81.45
# Batch accuracy: 87.11
# Batch accuracy: 84.18
# Batch accuracy: 85.74
# Batch accuracy: 82.42
# Batch accuracy: 80.47
# Batch accuracy: 83.20
# Batch accuracy: 83.20
# Batch accuracy: 83.40
# Batch accuracy: 84.57
# Batch accuracy: 82.81
# Batch accuracy: 85.35
# Batch accuracy: 85.74
# Batch accuracy: 84.38
# Batch accuracy: 82.62
# Batch accuracy: 83.79
# Batch accuracy: 84.57
# Batch accuracy: 84.77
# Batch accuracy: 83.98
# Batch accuracy: 82.81
# Batch accuracy: 84.38
# Batch accuracy: 83.01
# Batch accuracy: 85.16
# Batch accuracy: 83.59
# Batch accuracy: 85.74
# Batch accuracy: 83.59
# Batch accuracy: 84.18
# Batch accuracy: 85.35
# Batch accuracy: 81.84
# Batch accuracy: 82.62
# Batch accuracy: 84.96
# Batch accuracy: 82.81
# Batch accuracy: 87.30
# Batch accuracy: 85.16
# Batch accuracy: 83.79
# Batch accuracy: 81.25
# Batch accuracy: 84.18
# Batch accuracy: 82.03
# Batch accuracy: 82.81
# Batch accuracy: 85.16
# Batch accuracy: 85.55
# Batch accuracy: 84.38
# Batch accuracy: 84.77
# Batch accuracy: 86.13
# Batch accuracy: 88.48
# Batch accuracy: 83.01
# Batch accuracy: 84.96
# Batch accuracy: 83.01
# Batch accuracy: 83.20
# Batch accuracy: 84.77
# Batch accuracy: 84.38
# Batch accuracy: 84.18
# Batch accuracy: 85.55
# Batch accuracy: 86.91
# Batch accuracy: 86.33
# Batch accuracy: 84.38
# Batch accuracy: 82.03
# Batch accuracy: 83.59
# Batch accuracy: 84.96
# Batch accuracy: 83.98
# Batch accuracy: 83.79
# Batch accuracy: 84.77
# Batch accuracy: 84.96
# Batch accuracy: 84.77
# Batch accuracy: 86.52
# Batch accuracy: 83.01
# Batch accuracy: 84.18
# Batch accuracy: 84.18
# Batch accuracy: 83.79
# Batch accuracy: 82.81
# Batch accuracy: 81.05
# Batch accuracy: 84.38
# Batch accuracy: 84.18
# Batch accuracy: 85.55
# Batch accuracy: 83.98
# Batch accuracy: 83.79
# Batch accuracy: 84.57
# Batch accuracy: 83.40
# Batch accuracy: 82.42
# Batch accuracy: 86.33
# Batch accuracy: 79.03
#   Accuracy: 84.05
# New best model, saving it!
#
# ======== Epoch 7 / 30 ========
# Training...
#   Batch    40  of    975.    .
#   step loss: 0.57
#   Batch    80  of    975.    .
#   step loss: 0.52
#   Batch   120  of    975.    .
#   step loss: 0.47
#   Batch   160  of    975.    .
#   step loss: 0.55
#   Batch   200  of    975.    .
#   step loss: 0.72
#   Batch   240  of    975.    .
#   step loss: 0.59
#   Batch   280  of    975.    .
#   step loss: 0.56
#   Batch   320  of    975.    .
#   step loss: 0.74
#   Batch   360  of    975.    .
#   step loss: 0.61
#   Batch   400  of    975.    .
#   step loss: 0.66
#   Batch   440  of    975.    .
#   step loss: 0.73
#   Batch   480  of    975.    .
#   step loss: 0.82
#   Batch   520  of    975.    .
#   step loss: 0.63
#   Batch   560  of    975.    .
#   step loss: 0.62
#   Batch   600  of    975.    .
#   step loss: 0.67
#   Batch   640  of    975.    .
#   step loss: 0.45
#   Batch   680  of    975.    .
#   step loss: 0.59
#   Batch   720  of    975.    .
#   step loss: 0.56
#   Batch   760  of    975.    .
#   step loss: 0.57
#   Batch   800  of    975.    .
#   step loss: 0.58
#   Batch   840  of    975.    .
#   step loss: 0.65
#   Batch   880  of    975.    .
#   step loss: 0.63
#   Batch   920  of    975.    .
#   step loss: 0.63
#   Batch   960  of    975.    .
#   step loss: 0.62
#
#   Average training loss: 0.62
#
# Running Validation...
# Batch accuracy: 83.20
# Batch accuracy: 86.72
# Batch accuracy: 84.38
# Batch accuracy: 84.96
# Batch accuracy: 85.55
# Batch accuracy: 83.98
# Batch accuracy: 82.42
# Batch accuracy: 84.57
# Batch accuracy: 87.11
# Batch accuracy: 85.35
# Batch accuracy: 87.11
# Batch accuracy: 83.59
# Batch accuracy: 84.57
# Batch accuracy: 83.59
# Batch accuracy: 84.18
# Batch accuracy: 85.55
# Batch accuracy: 84.96
# Batch accuracy: 83.79
# Batch accuracy: 83.20
# Batch accuracy: 82.42
# Batch accuracy: 84.38
# Batch accuracy: 87.11
# Batch accuracy: 82.81
# Batch accuracy: 84.18
# Batch accuracy: 83.98
# Batch accuracy: 87.89
# Batch accuracy: 83.40
# Batch accuracy: 83.79
# Batch accuracy: 87.11
# Batch accuracy: 85.55
# Batch accuracy: 84.96
# Batch accuracy: 84.77
# Batch accuracy: 83.79
# Batch accuracy: 86.33
# Batch accuracy: 85.74
# Batch accuracy: 81.84
# Batch accuracy: 85.55
# Batch accuracy: 83.01
# Batch accuracy: 83.79
# Batch accuracy: 86.91
# Batch accuracy: 83.59
# Batch accuracy: 79.69
# Batch accuracy: 81.05
# Batch accuracy: 83.98
# Batch accuracy: 81.64
# Batch accuracy: 84.18
# Batch accuracy: 83.59
# Batch accuracy: 84.96
# Batch accuracy: 84.18
# Batch accuracy: 83.40
# Batch accuracy: 85.94
# Batch accuracy: 88.09
# Batch accuracy: 84.77
# Batch accuracy: 84.38
# Batch accuracy: 85.74
# Batch accuracy: 82.23
# Batch accuracy: 81.45
# Batch accuracy: 84.96
# Batch accuracy: 82.81
# Batch accuracy: 85.94
# Batch accuracy: 84.77
# Batch accuracy: 84.18
# Batch accuracy: 79.88
# Batch accuracy: 83.98
# Batch accuracy: 86.72
# Batch accuracy: 86.91
# Batch accuracy: 84.77
# Batch accuracy: 82.81
# Batch accuracy: 83.20
# Batch accuracy: 83.98
# Batch accuracy: 81.84
# Batch accuracy: 83.79
# Batch accuracy: 87.11
# Batch accuracy: 86.72
# Batch accuracy: 83.20
# Batch accuracy: 84.18
# Batch accuracy: 87.50
# Batch accuracy: 83.40
# Batch accuracy: 87.70
# Batch accuracy: 84.57
# Batch accuracy: 83.40
# Batch accuracy: 83.79
# Batch accuracy: 83.40
# Batch accuracy: 86.13
# Batch accuracy: 86.13
# Batch accuracy: 84.96
# Batch accuracy: 83.40
# Batch accuracy: 85.94
# Batch accuracy: 83.20
# Batch accuracy: 83.40
# Batch accuracy: 84.38
# Batch accuracy: 84.38
# Batch accuracy: 85.74
# Batch accuracy: 83.20
# Batch accuracy: 85.55
# Batch accuracy: 82.62
# Batch accuracy: 87.50
# Batch accuracy: 84.57
# Batch accuracy: 83.59
# Batch accuracy: 83.40
# Batch accuracy: 83.59
# Batch accuracy: 86.33
# Batch accuracy: 86.33
# Batch accuracy: 85.74
# Batch accuracy: 83.79
# Batch accuracy: 84.96
# Batch accuracy: 83.40
# Batch accuracy: 85.35
# Batch accuracy: 90.32
#   Accuracy: 84.54
# New best model, saving it!
#
# ======== Epoch 8 / 30 ========
# Training...
#   Batch    40  of    975.    .
#   step loss: 0.45
#   Batch    80  of    975.    .
#   step loss: 0.52
#   Batch   120  of    975.    .
#   step loss: 0.51
#   Batch   160  of    975.    .
#   step loss: 0.58
#   Batch   200  of    975.    .
#   step loss: 0.66
#   Batch   240  of    975.    .
#   step loss: 0.49
#   Batch   280  of    975.    .
#   step loss: 0.52
#   Batch   320  of    975.    .
#   step loss: 0.54
#   Batch   360  of    975.    .
#   step loss: 0.47
#   Batch   400  of    975.    .
#   step loss: 0.65
#   Batch   440  of    975.    .
#   step loss: 0.72
#   Batch   480  of    975.    .
#   step loss: 0.56
#   Batch   520  of    975.    .
#   step loss: 0.61
#   Batch   560  of    975.    .
#   step loss: 0.65
#   Batch   600  of    975.    .
#   step loss: 0.51
#   Batch   640  of    975.    .
#   step loss: 0.63
#   Batch   680  of    975.    .
#   step loss: 0.74
#   Batch   720  of    975.    .
#   step loss: 0.66
#   Batch   760  of    975.    .
#   step loss: 0.61
#   Batch   800  of    975.    .
#   step loss: 0.81
#   Batch   840  of    975.    .
#   step loss: 0.62
#   Batch   880  of    975.    .
#   step loss: 0.64
#   Batch   920  of    975.    .
#   step loss: 0.64
#   Batch   960  of    975.    .
#   step loss: 0.72
#
#   Average training loss: 0.58
#
# Running Validation...
# Batch accuracy: 86.13
# Batch accuracy: 86.33
# Batch accuracy: 84.96
# Batch accuracy: 85.16
# Batch accuracy: 88.28
# Batch accuracy: 83.79
# Batch accuracy: 82.03
# Batch accuracy: 85.35
# Batch accuracy: 82.42
# Batch accuracy: 81.84
# Batch accuracy: 85.35
# Batch accuracy: 82.62
# Batch accuracy: 85.35
# Batch accuracy: 84.18
# Batch accuracy: 81.45
# Batch accuracy: 86.91
# Batch accuracy: 81.45
# Batch accuracy: 85.55
# Batch accuracy: 85.35
# Batch accuracy: 82.23
# Batch accuracy: 83.98
# Batch accuracy: 85.16
# Batch accuracy: 83.40
# Batch accuracy: 82.81
# Batch accuracy: 81.84
# Batch accuracy: 82.42
# Batch accuracy: 85.55
# Batch accuracy: 87.30
# Batch accuracy: 85.16
# Batch accuracy: 86.52
# Batch accuracy: 85.55
# Batch accuracy: 86.13
# Batch accuracy: 87.50
# Batch accuracy: 83.59
# Batch accuracy: 88.28
# Batch accuracy: 82.23
# Batch accuracy: 85.55
# Batch accuracy: 89.06
# Batch accuracy: 85.55
# Batch accuracy: 83.98
# Batch accuracy: 83.20
# Batch accuracy: 81.25
# Batch accuracy: 82.81
# Batch accuracy: 85.16
# Batch accuracy: 84.77
# Batch accuracy: 84.77
# Batch accuracy: 85.16
# Batch accuracy: 82.23
# Batch accuracy: 84.57
# Batch accuracy: 83.59
# Batch accuracy: 85.35
# Batch accuracy: 86.52
# Batch accuracy: 85.35
# Batch accuracy: 85.94
# Batch accuracy: 85.16
# Batch accuracy: 86.52
# Batch accuracy: 87.30
# Batch accuracy: 85.94
# Batch accuracy: 87.11
# Batch accuracy: 83.79
# Batch accuracy: 81.45
# Batch accuracy: 84.96
# Batch accuracy: 85.94
# Batch accuracy: 83.79
# Batch accuracy: 86.52
# Batch accuracy: 84.57
# Batch accuracy: 84.18
# Batch accuracy: 84.18
# Batch accuracy: 85.94
# Batch accuracy: 85.35
# Batch accuracy: 83.40
# Batch accuracy: 87.30
# Batch accuracy: 85.16
# Batch accuracy: 82.42
# Batch accuracy: 83.98
# Batch accuracy: 83.79
# Batch accuracy: 85.55
# Batch accuracy: 82.81
# Batch accuracy: 85.74
# Batch accuracy: 83.40
# Batch accuracy: 85.74
# Batch accuracy: 86.13
# Batch accuracy: 84.18
# Batch accuracy: 82.81
# Batch accuracy: 84.96
# Batch accuracy: 86.91
# Batch accuracy: 83.40
# Batch accuracy: 84.96
# Batch accuracy: 85.16
# Batch accuracy: 87.11
# Batch accuracy: 84.38
# Batch accuracy: 84.57
# Batch accuracy: 83.98
# Batch accuracy: 84.96
# Batch accuracy: 84.96
# Batch accuracy: 86.72
# Batch accuracy: 83.01
# Batch accuracy: 85.16
# Batch accuracy: 84.96
# Batch accuracy: 86.72
# Batch accuracy: 84.77
# Batch accuracy: 84.77
# Batch accuracy: 86.13
# Batch accuracy: 86.72
# Batch accuracy: 84.38
# Batch accuracy: 82.81
# Batch accuracy: 85.74
# Batch accuracy: 82.42
# Batch accuracy: 82.26
#   Accuracy: 84.73
# New best model, saving it!
#
# ======== Epoch 9 / 30 ========
# Training...
#   Batch    40  of    975.    .
#   step loss: 0.58
#   Batch    80  of    975.    .
#   step loss: 0.53
#   Batch   120  of    975.    .
#   step loss: 0.56
#   Batch   160  of    975.    .
#   step loss: 0.58
#   Batch   200  of    975.    .
#   step loss: 0.53
#   Batch   240  of    975.    .
#   step loss: 0.53
#   Batch   280  of    975.    .
#   step loss: 0.59
#   Batch   320  of    975.    .
#   step loss: 0.55
#   Batch   360  of    975.    .
#   step loss: 0.47
#   Batch   400  of    975.    .
#   step loss: 0.62
#   Batch   440  of    975.    .
#   step loss: 0.57
#   Batch   480  of    975.    .
#   step loss: 0.53
#   Batch   520  of    975.    .
#   step loss: 0.59
#   Batch   560  of    975.    .
#   step loss: 0.59
#   Batch   600  of    975.    .
#   step loss: 0.51
#   Batch   640  of    975.    .
#   step loss: 0.59
#   Batch   680  of    975.    .
#   step loss: 0.50
#   Batch   720  of    975.    .
#   step loss: 0.55
#   Batch   760  of    975.    .
#   step loss: 0.55
#   Batch   800  of    975.    .
#   step loss: 0.53
#   Batch   840  of    975.    .
#   step loss: 0.53
#   Batch   880  of    975.    .
#   step loss: 0.56
#   Batch   920  of    975.    .
#   step loss: 0.59
#   Batch   960  of    975.    .
#   step loss: 0.52
#
#   Average training loss: 0.55
#
# Running Validation...
# Batch accuracy: 84.96
# Batch accuracy: 86.72
# Batch accuracy: 84.18
# Batch accuracy: 86.33
# Batch accuracy: 84.96
# Batch accuracy: 83.01
# Batch accuracy: 82.62
# Batch accuracy: 86.33
# Batch accuracy: 84.18
# Batch accuracy: 84.38
# Batch accuracy: 84.77
# Batch accuracy: 88.67
# Batch accuracy: 84.57
# Batch accuracy: 86.91
# Batch accuracy: 85.94
# Batch accuracy: 79.69
# Batch accuracy: 82.23
# Batch accuracy: 86.72
# Batch accuracy: 85.74
# Batch accuracy: 82.81
# Batch accuracy: 87.70
# Batch accuracy: 85.16
# Batch accuracy: 86.13
# Batch accuracy: 81.45
# Batch accuracy: 83.98
# Batch accuracy: 82.42
# Batch accuracy: 86.52
# Batch accuracy: 84.77
# Batch accuracy: 87.11
# Batch accuracy: 88.09
# Batch accuracy: 81.64
# Batch accuracy: 83.98
# Batch accuracy: 84.38
# Batch accuracy: 84.77
# Batch accuracy: 82.62
# Batch accuracy: 83.40
# Batch accuracy: 84.77
# Batch accuracy: 86.72
# Batch accuracy: 84.57
# Batch accuracy: 84.96
# Batch accuracy: 83.79
# Batch accuracy: 85.74
# Batch accuracy: 84.57
# Batch accuracy: 82.81
# Batch accuracy: 83.20
# Batch accuracy: 83.01
# Batch accuracy: 85.16
# Batch accuracy: 83.79
# Batch accuracy: 83.98
# Batch accuracy: 87.11
# Batch accuracy: 84.77
# Batch accuracy: 87.11
# Batch accuracy: 83.20
# Batch accuracy: 83.20
# Batch accuracy: 83.79
# Batch accuracy: 82.42
# Batch accuracy: 87.11
# Batch accuracy: 82.42
# Batch accuracy: 85.16
# Batch accuracy: 87.30
# Batch accuracy: 85.35
# Batch accuracy: 86.33
# Batch accuracy: 87.50
# Batch accuracy: 86.33
# Batch accuracy: 82.23
# Batch accuracy: 84.18
# Batch accuracy: 86.13
# Batch accuracy: 85.94
# Batch accuracy: 85.55
# Batch accuracy: 84.96
# Batch accuracy: 83.79
# Batch accuracy: 84.96
# Batch accuracy: 87.11
# Batch accuracy: 88.09
# Batch accuracy: 83.79
# Batch accuracy: 84.57
# Batch accuracy: 86.33
# Batch accuracy: 82.03
# Batch accuracy: 83.40
# Batch accuracy: 84.96
# Batch accuracy: 86.72
# Batch accuracy: 87.89
# Batch accuracy: 86.72
# Batch accuracy: 87.89
# Batch accuracy: 82.81
# Batch accuracy: 86.52
# Batch accuracy: 86.52
# Batch accuracy: 85.35
# Batch accuracy: 87.30
# Batch accuracy: 84.57
# Batch accuracy: 85.55
# Batch accuracy: 84.18
# Batch accuracy: 85.16
# Batch accuracy: 83.79
# Batch accuracy: 85.55
# Batch accuracy: 86.13
# Batch accuracy: 84.77
# Batch accuracy: 83.40
# Batch accuracy: 84.57
# Batch accuracy: 86.72
# Batch accuracy: 84.57
# Batch accuracy: 86.33
# Batch accuracy: 85.74
# Batch accuracy: 83.01
# Batch accuracy: 84.18
# Batch accuracy: 87.89
# Batch accuracy: 84.77
# Batch accuracy: 82.03
# Batch accuracy: 79.03
#   Accuracy: 84.90
# New best model, saving it!
#
# ======== Epoch 10 / 30 ========
# Training...
#   Batch    40  of    975.    .
#   step loss: 0.44
#   Batch    80  of    975.    .
#   step loss: 0.47
#   Batch   120  of    975.    .
#   step loss: 0.42
#   Batch   160  of    975.    .
#   step loss: 0.51
#   Batch   200  of    975.    .
#   step loss: 0.54
#   Batch   240  of    975.    .
#   step loss: 0.62
#   Batch   280  of    975.    .
#   step loss: 0.54
#   Batch   320  of    975.    .
#   step loss: 0.55
#   Batch   360  of    975.    .
#   step loss: 0.57
#   Batch   400  of    975.    .
#   step loss: 0.57
#   Batch   440  of    975.    .
#   step loss: 0.53
#   Batch   480  of    975.    .
#   step loss: 0.62
#   Batch   520  of    975.    .
#   step loss: 0.54
#   Batch   560  of    975.    .
#   step loss: 0.59
#   Batch   600  of    975.    .
#   step loss: 0.50
#   Batch   640  of    975.    .
#   step loss: 0.47
#   Batch   680  of    975.    .
#   step loss: 0.63
#   Batch   720  of    975.    .
#   step loss: 0.36
#   Batch   760  of    975.    .
#   step loss: 0.53
#   Batch   800  of    975.    .
#   step loss: 0.51
#   Batch   840  of    975.    .
#   step loss: 0.50
#   Batch   880  of    975.    .
#   step loss: 0.55
#   Batch   920  of    975.    .
#   step loss: 0.50
#   Batch   960  of    975.    .
#   step loss: 0.59
#
#   Average training loss: 0.53
#
# Running Validation...
# Batch accuracy: 86.91
# Batch accuracy: 84.77
# Batch accuracy: 86.13
# Batch accuracy: 87.11
# Batch accuracy: 84.96
# Batch accuracy: 85.94
# Batch accuracy: 85.94
# Batch accuracy: 86.33
# Batch accuracy: 84.57
# Batch accuracy: 84.77
# Batch accuracy: 86.13
# Batch accuracy: 86.91
# Batch accuracy: 87.50
# Batch accuracy: 86.52
# Batch accuracy: 85.35
# Batch accuracy: 86.91
# Batch accuracy: 84.18
# Batch accuracy: 84.38
# Batch accuracy: 84.96
# Batch accuracy: 83.59
# Batch accuracy: 84.18
# Batch accuracy: 84.96
# Batch accuracy: 84.38
# Batch accuracy: 83.79
# Batch accuracy: 85.55
# Batch accuracy: 85.74
# Batch accuracy: 87.11
# Batch accuracy: 83.20
# Batch accuracy: 83.01
# Batch accuracy: 84.77
# Batch accuracy: 85.74
# Batch accuracy: 83.98
# Batch accuracy: 85.94
# Batch accuracy: 87.30
# Batch accuracy: 85.16
# Batch accuracy: 81.84
# Batch accuracy: 84.18
# Batch accuracy: 84.18
# Batch accuracy: 86.91
# Batch accuracy: 87.89
# Batch accuracy: 87.30
# Batch accuracy: 85.74
# Batch accuracy: 84.57
# Batch accuracy: 85.35
# Batch accuracy: 85.94
# Batch accuracy: 84.18
# Batch accuracy: 85.94
# Batch accuracy: 81.84
# Batch accuracy: 85.94
# Batch accuracy: 86.52
# Batch accuracy: 85.74
# Batch accuracy: 83.98
# Batch accuracy: 85.16
# Batch accuracy: 86.13
# Batch accuracy: 87.30
# Batch accuracy: 83.98
# Batch accuracy: 83.20
# Batch accuracy: 86.72
# Batch accuracy: 86.13
# Batch accuracy: 81.25
# Batch accuracy: 82.81
# Batch accuracy: 84.38
# Batch accuracy: 85.55
# Batch accuracy: 84.38
# Batch accuracy: 84.96
# Batch accuracy: 86.33
# Batch accuracy: 83.59
# Batch accuracy: 84.96
# Batch accuracy: 85.16
# Batch accuracy: 85.55
# Batch accuracy: 85.55
# Batch accuracy: 84.77
# Batch accuracy: 84.38
# Batch accuracy: 84.38
# Batch accuracy: 83.40
# Batch accuracy: 83.98
# Batch accuracy: 85.74
# Batch accuracy: 84.57
# Batch accuracy: 84.77
# Batch accuracy: 86.13
# Batch accuracy: 82.42
# Batch accuracy: 87.11
# Batch accuracy: 82.03
# Batch accuracy: 83.59
# Batch accuracy: 84.38
# Batch accuracy: 84.77
# Batch accuracy: 84.57
# Batch accuracy: 84.96
# Batch accuracy: 85.74
# Batch accuracy: 85.74
# Batch accuracy: 82.81
# Batch accuracy: 86.72
# Batch accuracy: 86.13
# Batch accuracy: 84.38
# Batch accuracy: 83.98
# Batch accuracy: 84.77
# Batch accuracy: 82.62
# Batch accuracy: 86.52
# Batch accuracy: 87.70
# Batch accuracy: 86.52
# Batch accuracy: 83.98
# Batch accuracy: 85.16
# Batch accuracy: 82.62
# Batch accuracy: 84.77
# Batch accuracy: 84.77
# Batch accuracy: 87.11
# Batch accuracy: 84.57
# Batch accuracy: 87.70
# Batch accuracy: 87.10
#   Accuracy: 85.11
# New best model, saving it!
#
# ======== Epoch 11 / 30 ========
# Training...
#   Batch    40  of    975.    .
#   step loss: 0.51
#   Batch    80  of    975.    .
#   step loss: 0.55
#   Batch   120  of    975.    .
#   step loss: 0.46
#   Batch   160  of    975.    .
#   step loss: 0.49
#   Batch   200  of    975.    .
#   step loss: 0.57
#   Batch   240  of    975.    .
#   step loss: 0.44
#   Batch   280  of    975.    .
#   step loss: 0.44
#   Batch   320  of    975.    .
#   step loss: 0.51
#   Batch   360  of    975.    .
#   step loss: 0.50
#   Batch   400  of    975.    .
#   step loss: 0.51
#   Batch   440  of    975.    .
#   step loss: 0.50
#   Batch   480  of    975.    .
#   step loss: 0.50
#   Batch   520  of    975.    .
#   step loss: 0.66
#   Batch   560  of    975.    .
#   step loss: 0.48
#   Batch   600  of    975.    .
#   step loss: 0.53
#   Batch   640  of    975.    .
#   step loss: 0.50
#   Batch   680  of    975.    .
#   step loss: 0.41
#   Batch   720  of    975.    .
#   step loss: 0.53
#   Batch   760  of    975.    .
#   step loss: 0.50
#   Batch   800  of    975.    .
#   step loss: 0.49
#   Batch   840  of    975.    .
#   step loss: 0.43
#   Batch   880  of    975.    .
#   step loss: 0.48
#   Batch   920  of    975.    .
#   step loss: 0.47
#   Batch   960  of    975.    .
#   step loss: 0.50
#
#   Average training loss: 0.51
#
# Running Validation...
# Batch accuracy: 84.96
# Batch accuracy: 86.52
# Batch accuracy: 85.94
# Batch accuracy: 83.40
# Batch accuracy: 83.01
# Batch accuracy: 86.13
# Batch accuracy: 85.35
# Batch accuracy: 83.59
# Batch accuracy: 86.13
# Batch accuracy: 85.94
# Batch accuracy: 86.72
# Batch accuracy: 87.50
# Batch accuracy: 84.18
# Batch accuracy: 84.38
# Batch accuracy: 86.13
# Batch accuracy: 84.96
# Batch accuracy: 88.48
# Batch accuracy: 86.91
# Batch accuracy: 84.18
# Batch accuracy: 85.55
# Batch accuracy: 86.91
# Batch accuracy: 85.74
# Batch accuracy: 85.35
# Batch accuracy: 83.59
# Batch accuracy: 85.94
# Batch accuracy: 82.62
# Batch accuracy: 83.59
# Batch accuracy: 86.52
# Batch accuracy: 83.79
# Batch accuracy: 86.33
# Batch accuracy: 86.52
# Batch accuracy: 83.79
# Batch accuracy: 85.55
# Batch accuracy: 87.30
# Batch accuracy: 86.52
# Batch accuracy: 88.48
# Batch accuracy: 85.55
# Batch accuracy: 85.16
# Batch accuracy: 84.38
# Batch accuracy: 84.77
# Batch accuracy: 88.09
# Batch accuracy: 86.13
# Batch accuracy: 85.74
# Batch accuracy: 83.79
# Batch accuracy: 84.77
# Batch accuracy: 84.57
# Batch accuracy: 87.11
# Batch accuracy: 86.13
# Batch accuracy: 83.20
# Batch accuracy: 85.16
# Batch accuracy: 83.98
# Batch accuracy: 87.70
# Batch accuracy: 84.77
# Batch accuracy: 88.48
# Batch accuracy: 86.33
# Batch accuracy: 86.52
# Batch accuracy: 86.91
# Batch accuracy: 85.16
# Batch accuracy: 84.96
# Batch accuracy: 86.33
# Batch accuracy: 86.33
# Batch accuracy: 84.57
# Batch accuracy: 86.52
# Batch accuracy: 85.94
# Batch accuracy: 85.35
# Batch accuracy: 85.55
# Batch accuracy: 82.81
# Batch accuracy: 85.35
# Batch accuracy: 85.55
# Batch accuracy: 84.77
# Batch accuracy: 84.57
# Batch accuracy: 86.72
# Batch accuracy: 86.13
# Batch accuracy: 85.35
# Batch accuracy: 83.79
# Batch accuracy: 86.91
# Batch accuracy: 83.40
# Batch accuracy: 84.96
# Batch accuracy: 84.77
# Batch accuracy: 82.03
# Batch accuracy: 87.70
# Batch accuracy: 83.79
# Batch accuracy: 83.20
# Batch accuracy: 82.23
# Batch accuracy: 84.77
# Batch accuracy: 88.09
# Batch accuracy: 86.52
# Batch accuracy: 85.74
# Batch accuracy: 85.94
# Batch accuracy: 85.94
# Batch accuracy: 85.35
# Batch accuracy: 87.70
# Batch accuracy: 87.30
# Batch accuracy: 85.94
# Batch accuracy: 88.48
# Batch accuracy: 82.42
# Batch accuracy: 86.13
# Batch accuracy: 83.79
# Batch accuracy: 86.91
# Batch accuracy: 88.28
# Batch accuracy: 82.42
# Batch accuracy: 86.72
# Batch accuracy: 86.72
# Batch accuracy: 87.30
# Batch accuracy: 83.59
# Batch accuracy: 85.55
# Batch accuracy: 84.18
# Batch accuracy: 86.91
# Batch accuracy: 87.10
#   Accuracy: 85.53
# New best model, saving it!
#
# ======== Epoch 12 / 30 ========
# Training...
#   Batch    40  of    975.    .
#   step loss: 0.40
#   Batch    80  of    975.    .
#   step loss: 0.42
#   Batch   120  of    975.    .
#   step loss: 0.45
#   Batch   160  of    975.    .
#   step loss: 0.51
#   Batch   200  of    975.    .
#   step loss: 0.54
#   Batch   240  of    975.    .
#   step loss: 0.45
#   Batch   280  of    975.    .
#   step loss: 0.53
#   Batch   320  of    975.    .
#   step loss: 0.53
#   Batch   360  of    975.    .
#   step loss: 0.42
#   Batch   400  of    975.    .
#   step loss: 0.43
#   Batch   440  of    975.    .
#   step loss: 0.45
#   Batch   480  of    975.    .
#   step loss: 0.41
#   Batch   520  of    975.    .
#   step loss: 0.45
#   Batch   560  of    975.    .
#   step loss: 0.54
#   Batch   600  of    975.    .
#   step loss: 0.45
#   Batch   640  of    975.    .
#   step loss: 0.52
#   Batch   680  of    975.    .
#   step loss: 0.47
#   Batch   720  of    975.    .
#   step loss: 0.40
#   Batch   760  of    975.    .
#   step loss: 0.46
#   Batch   800  of    975.    .
#   step loss: 0.42
#   Batch   840  of    975.    .
#   step loss: 0.47
#   Batch   880  of    975.    .
#   step loss: 0.53
#   Batch   920  of    975.    .
#   step loss: 0.50
#   Batch   960  of    975.    .
#   step loss: 0.43
#
#   Average training loss: 0.49
#
# Running Validation...
# Batch accuracy: 88.87
# Batch accuracy: 85.35
# Batch accuracy: 83.59
# Batch accuracy: 85.74
# Batch accuracy: 82.81
# Batch accuracy: 86.33
# Batch accuracy: 87.50
# Batch accuracy: 83.40
# Batch accuracy: 83.98
# Batch accuracy: 83.20
# Batch accuracy: 83.20
# Batch accuracy: 85.74
# Batch accuracy: 88.67
# Batch accuracy: 85.55
# Batch accuracy: 84.38
# Batch accuracy: 83.79
# Batch accuracy: 85.35
# Batch accuracy: 85.35
# Batch accuracy: 87.11
# Batch accuracy: 86.33
# Batch accuracy: 87.50
# Batch accuracy: 88.67
# Batch accuracy: 84.38
# Batch accuracy: 85.55
# Batch accuracy: 86.33
# Batch accuracy: 85.16
# Batch accuracy: 85.74
# Batch accuracy: 86.52
# Batch accuracy: 83.98
# Batch accuracy: 82.03
# Batch accuracy: 86.13
# Batch accuracy: 88.28
# Batch accuracy: 86.33
# Batch accuracy: 85.74
# Batch accuracy: 84.77
# Batch accuracy: 83.59
# Batch accuracy: 84.77
# Batch accuracy: 88.28
# Batch accuracy: 88.48
# Batch accuracy: 85.74
# Batch accuracy: 85.74
# Batch accuracy: 85.74
# Batch accuracy: 83.98
# Batch accuracy: 83.98
# Batch accuracy: 85.94
# Batch accuracy: 85.16
# Batch accuracy: 83.98
# Batch accuracy: 86.72
# Batch accuracy: 83.20
# Batch accuracy: 87.30
# Batch accuracy: 89.45
# Batch accuracy: 86.72
# Batch accuracy: 87.70
# Batch accuracy: 84.18
# Batch accuracy: 88.67
# Batch accuracy: 86.33
# Batch accuracy: 87.50
# Batch accuracy: 85.94
# Batch accuracy: 84.96
# Batch accuracy: 82.23
# Batch accuracy: 84.96
# Batch accuracy: 84.38
# Batch accuracy: 83.79
# Batch accuracy: 84.96
# Batch accuracy: 87.89
# Batch accuracy: 82.62
# Batch accuracy: 85.35
# Batch accuracy: 85.55
# Batch accuracy: 84.18
# Batch accuracy: 84.57
# Batch accuracy: 85.94
# Batch accuracy: 83.98
# Batch accuracy: 85.35
# Batch accuracy: 83.98
# Batch accuracy: 85.55
# Batch accuracy: 84.38
# Batch accuracy: 83.98
# Batch accuracy: 83.59
# Batch accuracy: 87.89
# Batch accuracy: 86.72
# Batch accuracy: 86.72
# Batch accuracy: 86.13
# Batch accuracy: 88.67
# Batch accuracy: 87.50
# Batch accuracy: 84.96
# Batch accuracy: 86.91
# Batch accuracy: 87.11
# Batch accuracy: 87.50
# Batch accuracy: 87.30
# Batch accuracy: 84.38
# Batch accuracy: 85.55
# Batch accuracy: 85.94
# Batch accuracy: 85.16
# Batch accuracy: 84.77
# Batch accuracy: 84.38
# Batch accuracy: 84.96
# Batch accuracy: 84.18
# Batch accuracy: 84.57
# Batch accuracy: 83.01
# Batch accuracy: 87.30
# Batch accuracy: 85.74
# Batch accuracy: 85.35
# Batch accuracy: 85.94
# Batch accuracy: 86.33
# Batch accuracy: 84.96
# Batch accuracy: 81.45
# Batch accuracy: 84.77
# Batch accuracy: 83.59
# Batch accuracy: 87.90
#   Accuracy: 85.53
# New best model, saving it!
#
# ======== Epoch 13 / 30 ========
# Training...
#   Batch    40  of    975.    .
#   step loss: 0.50
#   Batch    80  of    975.    .
#   step loss: 0.39
#   Batch   120  of    975.    .
#   step loss: 0.49
#   Batch   160  of    975.    .
#   step loss: 0.41
#   Batch   200  of    975.    .
#   step loss: 0.38
#   Batch   240  of    975.    .
#   step loss: 0.51
#   Batch   280  of    975.    .
#   step loss: 0.49
#   Batch   320  of    975.    .
#   step loss: 0.49
#   Batch   360  of    975.    .
#   step loss: 0.45
#   Batch   400  of    975.    .
#   step loss: 0.42
#   Batch   440  of    975.    .
#   step loss: 0.40
#   Batch   480  of    975.    .
#   step loss: 0.62
#   Batch   520  of    975.    .
#   step loss: 0.39
#   Batch   560  of    975.    .
#   step loss: 0.52
#   Batch   600  of    975.    .
#   step loss: 0.41
#   Batch   640  of    975.    .
#   step loss: 0.56
#   Batch   680  of    975.    .
#   step loss: 0.59
#   Batch   720  of    975.    .
#   step loss: 0.50
#   Batch   760  of    975.    .
#   step loss: 0.50
#   Batch   800  of    975.    .
#   step loss: 0.46
#   Batch   840  of    975.    .
#   step loss: 0.47
#   Batch   880  of    975.    .
#   step loss: 0.39
#   Batch   920  of    975.    .
#   step loss: 0.56
#   Batch   960  of    975.    .
#   step loss: 0.41
#
#   Average training loss: 0.47
#
# Running Validation...
# Batch accuracy: 85.74
# Batch accuracy: 85.94
# Batch accuracy: 85.16
# Batch accuracy: 85.55
# Batch accuracy: 85.74
# Batch accuracy: 85.74
# Batch accuracy: 84.18
# Batch accuracy: 86.52
# Batch accuracy: 85.16
# Batch accuracy: 87.89
# Batch accuracy: 84.77
# Batch accuracy: 86.13
# Batch accuracy: 84.77
# Batch accuracy: 87.11
# Batch accuracy: 84.77
# Batch accuracy: 84.38
# Batch accuracy: 86.52
# Batch accuracy: 85.35
# Batch accuracy: 82.03
# Batch accuracy: 86.52
# Batch accuracy: 86.13
# Batch accuracy: 89.45
# Batch accuracy: 84.57
# Batch accuracy: 86.72
# Batch accuracy: 88.87
# Batch accuracy: 84.18
# Batch accuracy: 83.40
# Batch accuracy: 85.94
# Batch accuracy: 85.35
# Batch accuracy: 85.74
# Batch accuracy: 85.74
# Batch accuracy: 85.35
# Batch accuracy: 85.35
# Batch accuracy: 85.16
# Batch accuracy: 84.18
# Batch accuracy: 85.55
# Batch accuracy: 87.89
# Batch accuracy: 83.98
# Batch accuracy: 83.20
# Batch accuracy: 86.33
# Batch accuracy: 83.20
# Batch accuracy: 84.57
# Batch accuracy: 89.65
# Batch accuracy: 87.89
# Batch accuracy: 84.38
# Batch accuracy: 84.57
# Batch accuracy: 84.77
# Batch accuracy: 85.94
# Batch accuracy: 83.79
# Batch accuracy: 89.65
# Batch accuracy: 81.64
# Batch accuracy: 89.84
# Batch accuracy: 86.13
# Batch accuracy: 84.96
# Batch accuracy: 86.13
# Batch accuracy: 85.94
# Batch accuracy: 87.50
# Batch accuracy: 84.38
# Batch accuracy: 88.09
# Batch accuracy: 85.35
# Batch accuracy: 88.67
# Batch accuracy: 84.77
# Batch accuracy: 84.38
# Batch accuracy: 86.33
# Batch accuracy: 86.91
# Batch accuracy: 87.11
# Batch accuracy: 83.59
# Batch accuracy: 83.98
# Batch accuracy: 84.38
# Batch accuracy: 83.98
# Batch accuracy: 86.72
# Batch accuracy: 87.89
# ...
# Batch accuracy: 87.30
# Batch accuracy: 88.28
# Batch accuracy: 88.09
# Batch accuracy: 86.13
# Batch accuracy: 88.48
# Batch accuracy: 86.72
# Batch accuracy: 87.70
# Batch accuracy: 85.16
# Batch accuracy: 87.70
# Batch accuracy: 86.72
# Batch accuracy: 85.94
# Batch accuracy: 86.33
# Batch accuracy: 87.11
# Batch accuracy: 87.50
# Batch accuracy: 88.09
# Batch accuracy: 85.74
# Batch accuracy: 86.13
# Batch accuracy: 87.70
# Batch accuracy: 87.30
# Batch accuracy: 88.48
# Batch accuracy: 89.65
# Batch accuracy: 90.23
# Batch accuracy: 88.09
# Batch accuracy: 87.11
# Batch accuracy: 87.11
# Batch accuracy: 86.72
# Batch accuracy: 87.70
# Batch accuracy: 89.45
# Batch accuracy: 85.74
# Batch accuracy: 87.30
# Batch accuracy: 87.70
# Batch accuracy: 87.70
# Batch accuracy: 88.28
# Batch accuracy: 85.74
# Batch accuracy: 88.09
# Batch accuracy: 88.67
# Batch accuracy: 87.89
# Batch accuracy: 87.50
# Batch accuracy: 87.11
# Batch accuracy: 85.16
# Batch accuracy: 86.52
# Batch accuracy: 85.74
# Batch accuracy: 87.89
# Batch accuracy: 87.70
# Batch accuracy: 87.10
#   Accuracy: 87.59
# The model does not improve for 3 epochs!
#
# ======== Epoch 27 / 30 ========
# Training...
#   Batch    40  of    975.    .
#   step loss: 0.21
#   Batch    80  of    975.    .
#   step loss: 0.23
#   Batch   120  of    975.    .
#   step loss: 0.23
#   Batch   160  of    975.    .
#   step loss: 0.26
#   Batch   200  of    975.    .
#   step loss: 0.22
#   Batch   240  of    975.    .
#   step loss: 0.30
#   Batch   280  of    975.    .
#   step loss: 0.24
#   Batch   320  of    975.    .
#   step loss: 0.29
#   Batch   360  of    975.    .
#   step loss: 0.34
#   Batch   400  of    975.    .
#   step loss: 0.22
#   Batch   440  of    975.    .
#   step loss: 0.30
#   Batch   480  of    975.    .
#   step loss: 0.26
#   Batch   520  of    975.    .
#   step loss: 0.25
#   Batch   560  of    975.    .
#   step loss: 0.28
#   Batch   600  of    975.    .
#   step loss: 0.20
#   Batch   640  of    975.    .
#   step loss: 0.26
#   Batch   680  of    975.    .
#   step loss: 0.30
#   Batch   720  of    975.    .
#   step loss: 0.23
#   Batch   760  of    975.    .
#   step loss: 0.27
#   Batch   800  of    975.    .
#   step loss: 0.26
#   Batch   840  of    975.    .
#   step loss: 0.30
#   Batch   880  of    975.    .
#   step loss: 0.28
#   Batch   920  of    975.    .
#   step loss: 0.30
#   Batch   960  of    975.    .
#   step loss: 0.27
#
#   Average training loss: 0.26
#
# Running Validation...
# Batch accuracy: 87.30
# Batch accuracy: 86.33
# Batch accuracy: 87.50
# Batch accuracy: 87.11
# Batch accuracy: 89.65
# Batch accuracy: 88.48
# Batch accuracy: 86.91
# Batch accuracy: 88.48
# Batch accuracy: 87.30
# Batch accuracy: 87.50
# Batch accuracy: 85.94
# Batch accuracy: 89.45
# Batch accuracy: 88.48
# Batch accuracy: 86.13
# Batch accuracy: 88.48
# Batch accuracy: 88.87
# Batch accuracy: 87.89
# Batch accuracy: 87.89
# Batch accuracy: 85.35
# Batch accuracy: 88.09
# Batch accuracy: 87.70
# Batch accuracy: 89.06
# Batch accuracy: 88.09
# Batch accuracy: 86.13
# Batch accuracy: 88.28
# Batch accuracy: 87.30
# Batch accuracy: 89.65
# Batch accuracy: 88.48
# Batch accuracy: 87.89
# Batch accuracy: 87.89
# Batch accuracy: 89.26
# Batch accuracy: 87.30
# Batch accuracy: 86.33
# Batch accuracy: 86.72
# Batch accuracy: 88.28
# Batch accuracy: 84.96
# Batch accuracy: 87.11
# Batch accuracy: 87.11
# Batch accuracy: 88.48
# Batch accuracy: 86.13
# Batch accuracy: 90.43
# Batch accuracy: 87.89
# Batch accuracy: 85.16
# Batch accuracy: 87.89
# Batch accuracy: 88.87
# Batch accuracy: 86.72
# Batch accuracy: 87.70
# Batch accuracy: 88.09
# Batch accuracy: 87.89
# Batch accuracy: 89.65
# Batch accuracy: 86.13
# Batch accuracy: 87.50
# Batch accuracy: 85.94
# Batch accuracy: 87.50
# Batch accuracy: 87.89
# Batch accuracy: 86.52
# Batch accuracy: 88.87
# Batch accuracy: 87.11
# Batch accuracy: 88.28
# Batch accuracy: 87.50
# Batch accuracy: 88.48
# Batch accuracy: 85.74
# Batch accuracy: 85.94
# Batch accuracy: 86.13
# Batch accuracy: 84.96
# Batch accuracy: 87.11
# Batch accuracy: 86.52
# Batch accuracy: 85.94
# Batch accuracy: 84.96
# Batch accuracy: 88.67
# Batch accuracy: 86.13
# Batch accuracy: 87.89
# Batch accuracy: 86.13
# Batch accuracy: 86.13
# Batch accuracy: 89.65
# Batch accuracy: 87.50
# Batch accuracy: 87.50
# Batch accuracy: 90.43
# Batch accuracy: 87.50
# Batch accuracy: 87.11
# Batch accuracy: 89.84
# Batch accuracy: 87.11
# Batch accuracy: 87.11
# Batch accuracy: 89.65
# Batch accuracy: 86.72
# Batch accuracy: 86.91
# Batch accuracy: 84.77
# Batch accuracy: 89.06
# Batch accuracy: 88.67
# Batch accuracy: 85.94
# Batch accuracy: 87.11
# Batch accuracy: 89.45
# Batch accuracy: 88.67
# Batch accuracy: 90.82
# Batch accuracy: 89.06
# Batch accuracy: 88.87
# Batch accuracy: 88.87
# Batch accuracy: 87.50
# Batch accuracy: 87.30
# Batch accuracy: 87.70
# Batch accuracy: 85.94
# Batch accuracy: 87.70
# Batch accuracy: 88.48
# Batch accuracy: 88.09
# Batch accuracy: 86.91
# Batch accuracy: 88.87
# Batch accuracy: 89.45
# Batch accuracy: 88.48
# Batch accuracy: 84.68
#   Accuracy: 87.60
# The model does not improve for 4 epochs!
#
# ======== Epoch 28 / 30 ========
# Training...
#   Batch    40  of    975.    .
#   step loss: 0.19
#   Batch    80  of    975.    .
#   step loss: 0.27
#   Batch   120  of    975.    .
#   step loss: 0.21
#   Batch   160  of    975.    .
#   step loss: 0.34
#   Batch   200  of    975.    .
#   step loss: 0.21
#   Batch   240  of    975.    .
#   step loss: 0.22
#   Batch   280  of    975.    .
#   step loss: 0.30
#   Batch   320  of    975.    .
#   step loss: 0.24
#   Batch   360  of    975.    .
#   step loss: 0.18
#   Batch   400  of    975.    .
#   step loss: 0.36
#   Batch   440  of    975.    .
#   step loss: 0.24
#   Batch   480  of    975.    .
#   step loss: 0.23
#   Batch   520  of    975.    .
#   step loss: 0.24
#   Batch   560  of    975.    .
#   step loss: 0.28
#   Batch   600  of    975.    .
#   step loss: 0.27
#   Batch   640  of    975.    .
#   step loss: 0.24
#   Batch   680  of    975.    .
#   step loss: 0.22
#   Batch   720  of    975.    .
#   step loss: 0.23
#   Batch   760  of    975.    .
#   step loss: 0.30
#   Batch   800  of    975.    .
#   step loss: 0.26
#   Batch   840  of    975.    .
#   step loss: 0.23
#   Batch   880  of    975.    .
#   step loss: 0.27
#   Batch   920  of    975.    .
#   step loss: 0.21
#   Batch   960  of    975.    .
#   step loss: 0.28
#
#   Average training loss: 0.26
#
# Running Validation...
# Batch accuracy: 87.50
# Batch accuracy: 87.70
# Batch accuracy: 88.48
# Batch accuracy: 86.33
# Batch accuracy: 87.50
# Batch accuracy: 88.09
# Batch accuracy: 89.65
# Batch accuracy: 89.84
# Batch accuracy: 87.11
# Batch accuracy: 84.77
# Batch accuracy: 87.70
# Batch accuracy: 87.70
# Batch accuracy: 88.48
# Batch accuracy: 86.72
# Batch accuracy: 90.23
# Batch accuracy: 88.48
# Batch accuracy: 86.52
# Batch accuracy: 89.84
# Batch accuracy: 86.13
# Batch accuracy: 85.94
# Batch accuracy: 86.91
# Batch accuracy: 88.28
# Batch accuracy: 86.72
# Batch accuracy: 90.43
# Batch accuracy: 84.57
# Batch accuracy: 86.52
# Batch accuracy: 82.42
# Batch accuracy: 88.48
# Batch accuracy: 86.52
# Batch accuracy: 86.72
# Batch accuracy: 87.50
# Batch accuracy: 87.70
# Batch accuracy: 86.33
# Batch accuracy: 91.02
# Batch accuracy: 89.26
# Batch accuracy: 87.70
# Batch accuracy: 85.35
# Batch accuracy: 89.65
# Batch accuracy: 88.48
# Batch accuracy: 89.84
# Batch accuracy: 86.33
# Batch accuracy: 88.09
# Batch accuracy: 88.28
# Batch accuracy: 87.30
# Batch accuracy: 89.65
# Batch accuracy: 87.11
# Batch accuracy: 89.06
# Batch accuracy: 88.67
# Batch accuracy: 85.35
# Batch accuracy: 87.50
# Batch accuracy: 85.55
# Batch accuracy: 89.06
# Batch accuracy: 89.06
# Batch accuracy: 88.28
# Batch accuracy: 87.50
# Batch accuracy: 88.28
# Batch accuracy: 87.89
# Batch accuracy: 86.91
# Batch accuracy: 89.45
# Batch accuracy: 89.65
# Batch accuracy: 88.67
# Batch accuracy: 86.91
# Batch accuracy: 90.04
# Batch accuracy: 86.52
# Batch accuracy: 84.38
# Batch accuracy: 86.33
# Batch accuracy: 85.16
# Batch accuracy: 89.65
# Batch accuracy: 88.28
# Batch accuracy: 91.60
# Batch accuracy: 88.67
# Batch accuracy: 86.91
# Batch accuracy: 85.55
# Batch accuracy: 86.91
# Batch accuracy: 87.11
# Batch accuracy: 87.89
# Batch accuracy: 90.62
# Batch accuracy: 89.06
# Batch accuracy: 86.52
# Batch accuracy: 88.67
# Batch accuracy: 84.38
# Batch accuracy: 85.16
# Batch accuracy: 85.55
# Batch accuracy: 86.52
# Batch accuracy: 86.13
# Batch accuracy: 87.50
# Batch accuracy: 88.87
# Batch accuracy: 86.33
# Batch accuracy: 89.45
# Batch accuracy: 85.35
# Batch accuracy: 88.48
# Batch accuracy: 86.33
# Batch accuracy: 87.50
# Batch accuracy: 87.89
# Batch accuracy: 87.89
# Batch accuracy: 86.52
# Batch accuracy: 86.33
# Batch accuracy: 89.06
# Batch accuracy: 87.30
# Batch accuracy: 86.91
# Batch accuracy: 87.70
# Batch accuracy: 87.89
# Batch accuracy: 88.48
# Batch accuracy: 88.48
# Batch accuracy: 86.33
# Batch accuracy: 88.28
# Batch accuracy: 88.09
# Batch accuracy: 88.09
# Batch accuracy: 87.10
#   Accuracy: 87.61
# New best model, saving it!
#
# ======== Epoch 29 / 30 ========
# Training...
#   Batch    40  of    975.    .
#   step loss: 0.28
#   Batch    80  of    975.    .
#   step loss: 0.21
#   Batch   120  of    975.    .
#   step loss: 0.34
#   Batch   160  of    975.    .
#   step loss: 0.25
#   Batch   200  of    975.    .
#   step loss: 0.26
#   Batch   240  of    975.    .
#   step loss: 0.20
#   Batch   280  of    975.    .
#   step loss: 0.26
#   Batch   320  of    975.    .
#   step loss: 0.22
#   Batch   360  of    975.    .
#   step loss: 0.25
#   Batch   400  of    975.    .
#   step loss: 0.18
#   Batch   440  of    975.    .
#   step loss: 0.23
#   Batch   480  of    975.    .
#   step loss: 0.24
#   Batch   520  of    975.    .
#   step loss: 0.29
#   Batch   560  of    975.    .
#   step loss: 0.21
#   Batch   600  of    975.    .
#   step loss: 0.25
#   Batch   640  of    975.    .
#   step loss: 0.32
#   Batch   680  of    975.    .
#   step loss: 0.27
#   Batch   720  of    975.    .
#   step loss: 0.22
#   Batch   760  of    975.    .
#   step loss: 0.28
#   Batch   800  of    975.    .
#   step loss: 0.20
#   Batch   840  of    975.    .
#   step loss: 0.24
#   Batch   880  of    975.    .
#   step loss: 0.28
#   Batch   920  of    975.    .
#   step loss: 0.27
#   Batch   960  of    975.    .
#   step loss: 0.22
#
#   Average training loss: 0.25
#
# Running Validation...
# Batch accuracy: 85.35
# Batch accuracy: 88.48
# Batch accuracy: 88.87
# Batch accuracy: 87.11
# Batch accuracy: 88.87
# Batch accuracy: 84.38
# Batch accuracy: 85.55
# Batch accuracy: 84.77
# Batch accuracy: 87.30
# Batch accuracy: 84.96
# Batch accuracy: 90.04
# Batch accuracy: 86.91
# Batch accuracy: 89.65
# Batch accuracy: 89.26
# Batch accuracy: 88.87
# Batch accuracy: 87.11
# Batch accuracy: 87.89
# Batch accuracy: 86.52
# Batch accuracy: 88.09
# Batch accuracy: 87.70
# Batch accuracy: 89.45
# Batch accuracy: 87.89
# Batch accuracy: 86.33
# Batch accuracy: 87.70
# Batch accuracy: 87.30
# Batch accuracy: 86.52
# Batch accuracy: 89.26
# Batch accuracy: 89.06
# Batch accuracy: 88.67
# Batch accuracy: 88.87
# Batch accuracy: 87.30
# Batch accuracy: 89.84
# Batch accuracy: 84.18
# Batch accuracy: 85.74
# Batch accuracy: 88.87
# Batch accuracy: 89.84
# Batch accuracy: 88.09
# Batch accuracy: 89.45
# Batch accuracy: 86.91
# Batch accuracy: 86.33
# Batch accuracy: 88.28
# Batch accuracy: 86.33
# Batch accuracy: 86.91
# Batch accuracy: 86.91
# Batch accuracy: 89.65
# Batch accuracy: 87.50
# Batch accuracy: 85.35
# Batch accuracy: 90.04
# Batch accuracy: 88.09
# Batch accuracy: 87.11
# Batch accuracy: 88.48
# Batch accuracy: 87.11
# Batch accuracy: 90.43
# Batch accuracy: 87.30
# Batch accuracy: 86.33
# Batch accuracy: 85.94
# Batch accuracy: 85.35
# Batch accuracy: 88.28
# Batch accuracy: 89.26
# Batch accuracy: 87.11
# Batch accuracy: 87.50
# Batch accuracy: 85.74
# Batch accuracy: 87.89
# Batch accuracy: 87.11
# Batch accuracy: 89.65
# Batch accuracy: 89.84
# Batch accuracy: 85.55
# Batch accuracy: 84.77
# Batch accuracy: 86.33
# Batch accuracy: 87.11
# Batch accuracy: 89.26
# Batch accuracy: 88.87
# Batch accuracy: 87.11
# Batch accuracy: 88.48
# Batch accuracy: 86.13
# Batch accuracy: 89.06
# Batch accuracy: 86.91
# Batch accuracy: 84.38
# Batch accuracy: 87.70
# Batch accuracy: 88.67
# Batch accuracy: 88.48
# Batch accuracy: 90.43
# Batch accuracy: 89.45
# Batch accuracy: 86.33
# Batch accuracy: 89.84
# Batch accuracy: 87.70
# Batch accuracy: 87.11
# Batch accuracy: 87.30
# Batch accuracy: 87.70
# Batch accuracy: 88.87
# Batch accuracy: 87.11
# Batch accuracy: 88.48
# Batch accuracy: 87.70
# Batch accuracy: 86.52
# Batch accuracy: 85.35
# Batch accuracy: 85.55
# Batch accuracy: 85.16
# Batch accuracy: 88.87
# Batch accuracy: 88.09
# Batch accuracy: 90.82
# Batch accuracy: 87.50
# Batch accuracy: 88.28
# Batch accuracy: 88.48
# Batch accuracy: 89.26
# Batch accuracy: 86.72
# Batch accuracy: 88.48
# Batch accuracy: 86.13
# Batch accuracy: 86.52
# Batch accuracy: 84.68
#   Accuracy: 87.60
# The model does not improve for 1 epochs!
#
# ======== Epoch 30 / 30 ========
# Training...
#   Batch    40  of    975.    .
#   step loss: 0.29
#   Batch    80  of    975.    .
#   step loss: 0.29
#   Batch   120  of    975.    .
#   step loss: 0.23
#   Batch   160  of    975.    .
#   step loss: 0.25
#   Batch   200  of    975.    .
#   step loss: 0.25
#   Batch   240  of    975.    .
#   step loss: 0.27
#   Batch   280  of    975.    .
#   step loss: 0.26
#   Batch   320  of    975.    .
#   step loss: 0.25
#   Batch   360  of    975.    .
#   step loss: 0.24
#   Batch   400  of    975.    .
#   step loss: 0.29
#   Batch   440  of    975.    .
#   step loss: 0.25
#   Batch   480  of    975.    .
#   step loss: 0.21
#   Batch   520  of    975.    .
#   step loss: 0.28
#   Batch   560  of    975.    .
#   step loss: 0.32
#   Batch   600  of    975.    .
#   step loss: 0.20
#   Batch   640  of    975.    .
#   step loss: 0.24
#   Batch   680  of    975.    .
#   step loss: 0.30
#   Batch   720  of    975.    .
#   step loss: 0.30
#   Batch   760  of    975.    .
#   step loss: 0.21
#   Batch   800  of    975.    .
#   step loss: 0.26
#   Batch   840  of    975.    .
#   step loss: 0.29
#   Batch   880  of    975.    .
#   step loss: 0.25
#   Batch   920  of    975.    .
#   step loss: 0.22
#   Batch   960  of    975.    .
#   step loss: 0.21
#
#   Average training loss: 0.25
#
# Running Validation...
# Batch accuracy: 86.13
# Batch accuracy: 89.26
# Batch accuracy: 84.77
# Batch accuracy: 86.52
# Batch accuracy: 87.30
# Batch accuracy: 85.94
# Batch accuracy: 86.72
# Batch accuracy: 87.89
# Batch accuracy: 89.26
# Batch accuracy: 88.87
# Batch accuracy: 88.67
# Batch accuracy: 86.72
# Batch accuracy: 88.09
# Batch accuracy: 86.33
# Batch accuracy: 89.65
# Batch accuracy: 88.67
# Batch accuracy: 88.28
# Batch accuracy: 87.11
# Batch accuracy: 88.48
# Batch accuracy: 86.13
# Batch accuracy: 88.09
# Batch accuracy: 88.09
# Batch accuracy: 86.91
# Batch accuracy: 88.87
# Batch accuracy: 85.94
# Batch accuracy: 88.67
# Batch accuracy: 86.52
# Batch accuracy: 88.67
# Batch accuracy: 86.52
# Batch accuracy: 90.62
# Batch accuracy: 88.28
# Batch accuracy: 88.09
# Batch accuracy: 86.33
# Batch accuracy: 87.30
# Batch accuracy: 87.70
# Batch accuracy: 88.28
# Batch accuracy: 87.30
# Batch accuracy: 85.74
# Batch accuracy: 88.28
# Batch accuracy: 83.20
# Batch accuracy: 89.45
# Batch accuracy: 87.70
# Batch accuracy: 89.26
# Batch accuracy: 86.33
# Batch accuracy: 88.09
# Batch accuracy: 86.33
# Batch accuracy: 86.91
# Batch accuracy: 89.45
# Batch accuracy: 87.11
# Batch accuracy: 86.91
# Batch accuracy: 87.30
# Batch accuracy: 86.52
# Batch accuracy: 90.62
# Batch accuracy: 88.28
# Batch accuracy: 88.28
# Batch accuracy: 87.50
# Batch accuracy: 86.52
# Batch accuracy: 89.06
# Batch accuracy: 91.02
# Batch accuracy: 88.28
# Batch accuracy: 87.89
# Batch accuracy: 89.65
# Batch accuracy: 88.48
# Batch accuracy: 88.67
# Batch accuracy: 86.13
# Batch accuracy: 88.87
# Batch accuracy: 86.91
# Batch accuracy: 89.84
# Batch accuracy: 88.28
# Batch accuracy: 86.91
# Batch accuracy: 86.52
# Batch accuracy: 84.38
# Batch accuracy: 87.89
# Batch accuracy: 86.52
# Batch accuracy: 84.38
# Batch accuracy: 87.89
# Batch accuracy: 88.67
# Batch accuracy: 86.72
# Batch accuracy: 88.09
# Batch accuracy: 89.06
# Batch accuracy: 89.65
# Batch accuracy: 85.55
# Batch accuracy: 88.09
# Batch accuracy: 87.89
# Batch accuracy: 85.94
# Batch accuracy: 87.70
# Batch accuracy: 87.11
# Batch accuracy: 86.72
# Batch accuracy: 89.26
# Batch accuracy: 87.50
# Batch accuracy: 86.52
# Batch accuracy: 87.11
# Batch accuracy: 86.52
# Batch accuracy: 87.89
# Batch accuracy: 85.74
# Batch accuracy: 86.33
# Batch accuracy: 87.30
# Batch accuracy: 91.02
# Batch accuracy: 86.72
# Batch accuracy: 86.72
# Batch accuracy: 86.91
# Batch accuracy: 85.35
# Batch accuracy: 85.94
# Batch accuracy: 89.06
# Batch accuracy: 88.67
# Batch accuracy: 87.50
# Batch accuracy: 85.16
# Batch accuracy: 87.11
# Batch accuracy: 88.71
#   Accuracy: 87.56
# The model does not improve for 2 epochs!
#
# Training complete!

# %%
def predict(
    model_path: Path,
    dataset: str,
    batch_size: int,
    labels_dict,
    device: torch.device
):

    print(f"====Loading dataset for testing")
    test_corpus = NLPDataset(dataset, "test", sentence_max_len, labels_dict = labels_dict, vocab= voc)

    test_dataloader = DataLoader(
        test_corpus,
        batch_size=batch_size,
        #sampler = RandomSampler(test_corpus),
        pin_memory=True,
        num_workers=0,
        drop_last=False
    )

    print(f"====Loading model for testing")
    model = torch.load(join(model_path, "best-model.pth"))
    model.to(device)
    model.eval()
    pred_labels = []
    test_labels = []
    logits_list = []

    def _list_from_tensor(tensor):
        if tensor.numel() == 1:
            return [tensor.item()]
        return list(tensor.cpu().detach().numpy())

    print("====Testing model...")
    for batch in test_dataloader:
        #h = model.init_hidden(len(batch[0]), device)
        #h = tuple([each.data for each in val_h])
        b_input_ids = batch[0]
        b_input_ids = torch.tensor(b_input_ids).to(device).long()
        b_labels = batch[1].to(device)
        with torch.no_grad():
            #h = tuple([each.data for each in h])
            loss, logits = model(b_input_ids, b_labels)
            preds = np.argmax(logits.cpu(), axis=1) # Convert one-hot to index
            b_labels = b_labels.int()
            pred_labels.extend(_list_from_tensor(preds))
            test_labels.extend(_list_from_tensor(b_labels))
        logits_list.extend(_list_from_tensor(logits))

    print(classification_report(test_labels, pred_labels, labels=list(labels_dict.values()), target_names=np.array(list(labels_dict.keys())), digits=3, output_dict=False))
    logits_list = expit(logits_list)
    del model
    torch.cuda.empty_cache()

# %%
del train_dataloader
del validation_dataloader
del train_corpus
del val_corpus
del model
torch.cuda.empty_cache()

# %%
predict(last_saved_model, dataset, batch_size, labels_dict, device)
# Out:
# ====Loading dataset for testing
# ====Loading model for testing
# ====Testing model...
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:39: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#                                              precision    recall  f1-score   support
#
#                               FISHING_LINES      0.703     0.750     0.726       584
#                      MOBILE_DEVICE_CHARGERS      0.918     0.930     0.924       804
#                                  SUNGLASSES      0.955     0.957     0.956       875
#                                    FREEZERS      0.861     0.849     0.855       444
#                                  CAR_WHEELS      0.956     0.996     0.976       720
#                            BATHROOM_FAUCETS      0.824     0.843     0.833       521
#                              ACTION_FIGURES      0.641     0.531     0.581       800
#                                       IRONS      0.959     0.961     0.960       433
#                                  MATTRESSES      0.939     0.951     0.945       534
#                       SWIMMING_POOL_HEATERS      0.792     0.905     0.844        21
#                              KITCHEN_KNIVES      0.901     0.946     0.923       202
#                                 TELEVISIONS      0.873     0.900     0.886       728
#                    SPORT_AND_BAZAAR_BOTTLES      0.741     0.712     0.726       229
#                                    STARTERS      0.934     0.921     0.927       354
#                                  FACE_MASKS      0.800     0.723     0.759       166
#                             KITCHEN_FAUCETS      0.858     0.882     0.870       431
#     TACTICAL_AND_SPORTING_KNIVES_AND_BLADES      0.934     0.860     0.895       164
#                                   NOTEBOOKS      0.886     0.913     0.899       543
#                                 DEEP_FRYERS      0.906     0.912     0.909       455
#                                TORSION_BARS      0.976     0.992     0.984       123
#                            AUDIO_AMPLIFIERS      0.700     0.714     0.707       311
#                              CEILING_LIGHTS      0.891     0.900     0.896       472
#                                       BELTS      0.915     0.878     0.896        49
#                    AUTOMOTIVE_WEATHERSTRIPS      0.901     0.948     0.924       788
#                                  HEADBOARDS      0.982     0.969     0.976       228
#                                       YARNS      0.723     0.845     0.779       142
#                                SMARTWATCHES      0.933     0.898     0.915       724
#                             FOOTBALL_SHIRTS      0.940     0.949     0.944       921
#                      AUTOMOTIVE_CLUTCH_KITS      0.937     0.975     0.956       719
#                                WRISTWATCHES      0.911     0.932     0.921       876
#                                  WALLPAPERS      0.947     0.932     0.940       885
#         AUTOMOTIVE_SIDE_VIEW_MIRROR_GLASSES      0.978     0.974     0.976       536
#                            AUDIO_INTERFACES      0.876     0.827     0.851       300
#                            KITCHEN_PLAYSETS      0.885     0.850     0.867       100
#                                 LIGHT_BULBS      0.898     0.924     0.911       829
#                              CELL_BATTERIES      0.890     0.928     0.909       670
#                        SURVEILLANCE_CAMERAS      0.902     0.850     0.875       909
#                                   THERMOSES      0.802     0.770     0.786       100
#                  HUMIDIFIERS_AND_VAPORIZERS      0.752     0.682     0.715       173
#                              KITCHEN_APRONS      0.450     0.333     0.383        27
#                         PORTABLE_GENERATORS      0.962     0.970     0.966       132
#                                  CELLPHONES      0.890     0.815     0.851       329
#                            HANDICRAFT_BOXES      0.634     0.696     0.664       112
#                         EMBROIDERY_MACHINES      0.646     0.608     0.626        51
#                                     CAMERAS      0.725     0.630     0.674        92
#             DESKTOP_COMPUTER_POWER_SUPPLIES      0.962     0.969     0.966       679
#                              BABIES_FORMULA      0.899     0.909     0.904        88
#                     MOTORCYCLE_SPEEDOMETERS      1.000     0.250     0.400         4
#                                     CARPETS      0.918     0.940     0.929       857
#                       CARDS_AND_INVITATIONS      0.889     0.851     0.870        47
#                            ELECTRIC_GUITARS      0.908     0.904     0.906       778
#                           COMPUTER_MONITORS      0.933     0.947     0.940       701
#                          MULTIGAME_MACHINES      0.766     0.636     0.695        77
#                                 TABLECLOTHS      0.947     0.947     0.947       544
#                                   VIBRATORS      0.763     0.744     0.753       117
#                                      PLANTS      0.921     0.933     0.927       313
#                                AM_FM_RADIOS      0.867     0.883     0.875       383
#                      ENGINE_CONTROL_MODULES      0.881     0.947     0.913       415
#             LATEX_ENAMEL_AND_ACRYLIC_PAINTS      0.957     1.000     0.978        67
#             MUSICAL_KEYBOARD_CASES_AND_BAGS      0.980     0.974     0.977       760
#                                 VIDEO_GAMES      0.959     0.969     0.964       908
#                          ARTIFICIAL_FLOWERS      0.862     0.901     0.881       497
#                          OUTER_TIE_ROD_ENDS      0.988     0.978     0.983       496
#                           EXHAUST_MANIFOLDS      0.875     0.875     0.875         8
#                     DIGITAL_VOICE_RECORDERS      0.862     0.934     0.896       774
#                               REFRIGERATORS      0.821     0.885     0.852       524
#                             DISPOSABLE_CUPS      0.709     0.777     0.741       188
#                                  EYESHADOWS      0.901     0.927     0.914       738
#                                      RANGES      0.940     0.947     0.944       450
#          AUTOMOTIVE_POWER_WINDOW_REGULATORS      0.913     0.913     0.913       138
#                                     HOOKAHS      0.933     0.911     0.922       168
#                       AUTOMOTIVE_AMPLIFIERS      0.870     0.882     0.876       662
#                           PROJECTOR_SCREENS      1.000     0.868     0.929        53
#                          AUTOMOTIVE_EMBLEMS      0.889     0.859     0.874       524
#                           PAINTBALL_MARKERS      0.857     0.742     0.796        97
#               AUTOMOTIVE_SPRING_SUSPENSIONS      0.846     0.860     0.852       121
#                                 ENGINE_OILS      0.932     0.951     0.941       770
#                            BATTERY_CHARGERS      0.680     0.567     0.618        30
#                     SWEATSHIRTS_AND_HOODIES      0.886     0.924     0.905       118
#                      CONTINUOUS_INK_SYSTEMS      0.865     0.871     0.868       140
#                              BATHROOM_SINKS      0.904     0.927     0.916       427
#                                MEMORY_CARDS      0.957     0.955     0.956       669
#                                    HANDBAGS      0.920     0.939     0.930       850
#                               KITCHEN_SINKS      0.878     0.826     0.851       253
#                            CAMERA_BATTERIES      0.922     0.915     0.918       554
#                             WATER_RADIATORS      0.845     0.905     0.874       399
#                           CYCLING_COMPUTERS      0.780     0.857     0.817       161
#                                EROTIC_BOOKS      1.000     0.985     0.992        67
#                            MOTORCYCLE_CASES      0.909     0.941     0.925       222
#                                    COSTUMES      0.929     0.949     0.939       276
#                           BODYWEIGHT_SCALES      0.852     0.887     0.870       293
#                      GAMEPADS_AND_JOYSTICKS      0.945     0.928     0.937       612
#                                       PANTS      0.882     0.919     0.900       799
#                                      STOOLS      0.886     0.944     0.914       594
#                               FISHING_REELS      0.896     0.899     0.897       740
#                                     WALLETS      0.966     0.949     0.958       665
#                           MUSICAL_KEYBOARDS      0.893     0.902     0.898       511
#                                  ULTRABOOKS      0.779     0.836     0.807       232
#                             ENGINE_BEARINGS      0.944     0.976     0.959       327
#                    CAR_POWER_STEERING_PUMPS      0.971     0.986     0.979       370
#                                     TABLETS      0.936     0.939     0.938       624
#                              MAKEUP_BRUSHES      0.910     0.929     0.919       534
#                               HORSE_SADDLES      0.820     0.892     0.854       102
#                          CD_AND_DVD_PLAYERS      0.854     0.825     0.839       291
#                    VIDEO_GAME_PREPAID_CARDS      0.693     0.765     0.727        68
#                             SCREEN_PRINTERS      0.911     0.923     0.917       156
#                                  ROOF_RACKS      0.960     0.944     0.952       428
#                                  HEADPHONES      0.916     0.868     0.891       189
#                       ELECTRIC_SCREWDRIVERS      0.809     0.730     0.767       122
#                             VACUUM_CLEANERS      0.867     0.812     0.839        16
#                                 FLASHLIGHTS      0.943     0.959     0.951       606
#                                HOME_SHELVES      0.687     0.656     0.671       157
#                               BRUSH_CUTTERS      0.773     0.836     0.803       110
#                         COMPUTER_PROCESSORS      0.889     0.947     0.917       794
#                                    NECKTIES      0.955     0.955     0.955       134
#                          MOTORCYCLE_JACKETS      0.922     0.924     0.923       551
#                                    WRENCHES      0.937     0.960     0.948       371
#                                 WHEELCHAIRS      0.967     0.989     0.978        90
#                          RAM_MEMORY_MODULES      0.973     0.960     0.966       822
#                                PENCIL_CASES      0.904     0.880     0.892       183
#                AUTOMOTIVE_SHIFT_LEVER_KNOBS      0.999     1.000     0.999       938
#                                        MUGS      0.859     0.906     0.882       329
#                              WALKIE_TALKIES      0.856     0.862     0.859       283
#                                       DOLLS      0.861     0.909     0.884       843
#                                  TREADMILLS      0.899     0.954     0.925        65
#                                 SPARK_PLUGS      0.950     0.949     0.950       726
#                               HAIR_CLIPPERS      0.837     0.832     0.834       714
#                                   SUITCASES      0.957     0.957     0.957       582
#                                 BLANK_DISCS      0.799     0.826     0.812       178
#                                    SPEAKERS      0.938     0.920     0.929       525
#                               DVD_RECORDERS      0.855     0.929     0.890       450
#                     KEYBOARD_AND_MOUSE_KITS      0.941     0.920     0.930       275
#                             CAR_SEAT_COVERS      0.988     0.994     0.991       942
#          AUTOMOTIVE_SUSPENSION_CONTROL_ARMS      0.942     0.965     0.953       254
#                           BAR_CODE_SCANNERS      0.976     0.965     0.970       254
#                         AUTOMOTIVE_MOLDINGS      0.897     0.917     0.907       720
#                               BABY_SWIMWEAR      0.909     0.826     0.866       121
#                        TABLE_AND_DESK_LAMPS      0.822     0.765     0.793       260
#                           JACKETS_AND_COATS      0.867     0.870     0.868       815
#                                  CHAMPAGNES      0.697     0.742     0.719        31
#                              FOOTBALL_SHOES      0.981     0.984     0.982       734
#                           CHARMS_AND_MEDALS      0.774     0.756     0.765        86
#                                 MICROPHONES      0.909     0.944     0.926       465
#                         PERMANENT_EPILATORS      0.872     0.798     0.833        94
#                              WOMEN_SWIMWEAR      0.904     0.938     0.921       500
#                  PARTY_DECORATIVE_BACKDROPS      0.961     0.933     0.947       105
#                               ROLLER_SKATES      0.976     0.969     0.973       586
#                                      COMICS      0.757     0.764     0.760       534
#                                       BOOKS      0.752     0.677     0.713       834
#                              CUPCAKE_STANDS      0.600     0.375     0.462         8
#                               UPS_BATTERIES      0.629     0.688     0.657        64
#                                 CAKE_STANDS      0.805     0.733     0.767        45
#            REAR_WHEEL_HUBS_BEARING_ASSEMBLY      0.964     0.993     0.978       401
#                            DIECAST_VEHICLES      0.786     0.855     0.819       606
#                                 CALCULATORS      0.968     0.957     0.962       536
#                                 TV_ANTENNAS      0.971     0.968     0.969       310
#                                 PAPER_CLIPS      0.854     0.804     0.828        51
#                              MALE_UNDERWEAR      0.962     0.955     0.958       422
#                                  ALL_IN_ONE      0.882     0.873     0.878       189
#                            DRINKING_GLASSES      0.771     0.767     0.769       382
#                                       DRUMS      0.813     0.901     0.855       212
#                               WELDING_MASKS      0.930     0.841     0.883        63
#                                    WHISKEYS      0.921     0.955     0.938       267
#                               VIDEO_CAMERAS      0.893     0.676     0.769        37
#                               COFFEE_MAKERS      0.950     0.937     0.943       567
#                        KNEE_BRACES_SUPPORTS      0.699     0.791     0.742       129
#                                 WALL_CLOCKS      0.972     0.935     0.953       480
#                                 WALL_LIGHTS      0.879     0.890     0.884       172
#                              GARDEN_BENCHES      0.500     0.429     0.462        14
#                                  SCULPTURES      0.772     0.812     0.792       437
#                                        FANS      0.964     0.946     0.955       597
#                                 FOUNDATIONS      0.918     0.924     0.921       706
#                                   EYELINERS      0.841     0.740     0.787        50
#                                  DRILL_BITS      0.921     0.902     0.912       143
#                                PC_KEYBOARDS      0.706     0.462     0.558        26
#                               EROTIC_CREAMS      0.779     0.821     0.799       279
#                           DESKTOP_COMPUTERS      0.774     0.667     0.716        36
#                           DECORATIVE_VINYLS      0.878     0.917     0.897       709
#                                 BOARD_GAMES      0.845     0.850     0.848       654
#                         KITCHEN_RANGE_HOODS      0.954     0.945     0.950       309
#                                     DRAWERS      0.824     0.924     0.871       198
#                             FURNITURE_KNOBS      0.772     0.830     0.800       147
#        HOME_APPLIANCE_CONTACTORS_AND_RELAYS      0.844     0.875     0.859       408
#                            SHAVING_MACHINES      0.736     0.726     0.731       449
#                                TOOTHBRUSHES      0.911     0.932     0.922       265
#                     STREAMING_MEDIA_DEVICES      0.874     0.884     0.879       415
#                      CAR_AC_HOSE_ASSEMBLIES      0.727     0.471     0.571        17
#                              SWAY_BAR_LINKS      0.849     0.820     0.834        89
#                               PREAMPLIFIERS      0.385     0.217     0.278        23
#                                  FISH_TANKS      0.830     0.807     0.818       145
#                                      DRONES      0.932     0.930     0.931       653
#                            EMERGENCY_LIGHTS      0.888     0.882     0.885       288
#                                    BLENDERS      0.935     0.892     0.913       452
#                              LASER_MEASURES      0.860     0.891     0.875        55
#                                CASH_DRAWERS      1.000     0.921     0.959        38
#                             CAMERA_CHARGERS      0.902     0.909     0.906       285
#                            CAR_AV_RECEIVERS      0.893     0.896     0.895       589
#                            STEERING_COLUMNS      0.986     0.986     0.986       143
#                                      SKIRTS      0.898     0.968     0.931       154
#                             SANDER_MACHINES      0.865     0.897     0.881       292
#                                RICE_COOKERS      0.923     0.923     0.923        52
#                              BRAKE_BOOSTERS      0.969     0.914     0.941       139
#                                    NETBOOKS      0.698     0.717     0.707       145
#                               FISHING_LURES      0.739     0.761     0.750        67
#                            AUTOMOTIVE_TIRES      0.817     0.725     0.768        80
#                                     STATUES      0.533     0.348     0.421        23
#                                    T_SHIRTS      0.933     0.941     0.937       742
#                             OFFICE_SOFTWARE      0.558     0.524     0.541        82
#                              BABY_CAR_SEATS      0.946     0.949     0.947       550
#                                 WATCH_BANDS      0.876     0.857     0.866       265
#                                        PENS      0.677     0.778     0.724        27
#                   BATHROOM_ACCESSORIES_SETS      0.541     0.769     0.635        78
#                                 CAR_STEREOS      0.807     0.790     0.798       243
#  CELLPHONE_TABLET_AND_GPS_SCREEN_PROTECTORS      0.849     0.871     0.860       155
#                              GLASSES_FRAMES      0.897     0.878     0.887       296
#                                AIRSOFT_GUNS      0.917     0.951     0.934       245
#                                   HAND_FANS      0.793     0.719     0.754        32
#                                  SIDEBOARDS      0.766     0.766     0.766       201
#                            VEHICLE_STICKERS      0.974     0.932     0.953       530
#                              BABY_STROLLERS      0.929     0.949     0.939       468
#                                      MOVIES      0.612     0.423     0.500        71
#                          MICRO_ROTARY_TOOLS      0.857     0.783     0.818        69
#                                   SOUVENIRS      0.908     0.854     0.881       151
#                                      VODKAS      0.898     0.936     0.917        94
#                               PUREBRED_DOGS      0.790     0.936     0.857       705
#                                     VIOLINS      0.936     0.974     0.955       151
#                                 HOVERBOARDS      0.937     0.960     0.949       480
#                      SUSPENSION_BALL_JOINTS      0.960     0.959     0.959       579
#                                   BACKPACKS      0.929     0.950     0.939       699
#                              ADHESIVE_TAPES      0.849     0.909     0.878       253
#                           ELECTRICAL_CABLES      0.948     0.952     0.950       250
#                               COFFEE_TABLES      0.909     0.769     0.833        26
#                  INTERACTIVE_GAMING_FIGURES      0.960     0.963     0.961       246
#                   AUTOMOTIVE_AC_COMPRESSORS      0.792     0.884     0.835        43
#                       HAIRDRESSING_SCISSORS      0.927     0.956     0.942       160
#                                    CUSHIONS      0.920     0.812     0.863       213
#                   THERMAL_CUPS_AND_TUMBLERS      0.667     0.571     0.615        56
#         TV_REPLACEMENT_BACKLIGHT_LED_STRIPS      0.913     0.913     0.913       115
#                         ENGINE_INTAKE_HOSES      0.901     0.930     0.916       373
#                    AUTOMOBILE_FENDER_LINERS      0.889     0.889     0.889        18
#                              DJ_CONTROLLERS      0.815     0.783     0.799       175
#                                STUFFED_TOYS      0.744     0.795     0.769       679
#              MARTIAL_ARTS_AND_BOXING_GLOVES      0.938     0.949     0.943       254
#                               CAMERA_LENSES      0.917     0.904     0.910       219
#                                EROTIC_PUMPS      0.875     0.865     0.870        89
#                               PAINT_ROLLERS      0.909     0.909     0.909        11
#                                MEN_SWIMWEAR      0.688     0.611     0.647        18
#                 PORTABLE_CELLPHONE_CHARGERS      0.918     0.894     0.906       500
#                              ANALOG_CAMERAS      0.865     0.869     0.867       457
#                             HAIR_TREATMENTS      0.654     0.573     0.611        89
#                       DJ_EFFECTS_PROCESSORS      0.586     0.554     0.570       202
#                     BUMPER_IMPACT_ABSORBERS      0.859     0.918     0.888       245
#                  NOTEBOOKS_AND_WRITING_PADS      0.802     0.876     0.838       153
#                         FINGERPRINT_READERS      0.808     0.875     0.840        24
#                                    BLANKETS      0.752     0.786     0.769       131
#                                 SUPPLEMENTS      0.531     0.658     0.588       430
#                                    HAMMOCKS      0.952     0.963     0.958        82
#                AUTOMOTIVE_SIDE_VIEW_MIRRORS      0.952     0.959     0.955       737
#                   FACIAL_SKIN_CARE_PRODUCTS      0.626     0.774     0.692       341
#                             PACKAGING_ROLLS      1.000     1.000     1.000        26
#                       TV_AND_MONITOR_MOUNTS      0.945     0.980     0.962       546
#                                CAR_ANTENNAS      0.991     0.994     0.993       934
#                                    CACHACAS      0.947     0.904     0.925       157
#                                     TV_SMPS      0.832     0.849     0.840       279
#                              KITCHEN_TOWELS      0.954     0.971     0.962       277
#                                    CALIPERS      1.000     0.864     0.927        22
#                             PARKING_SENSORS      0.978     0.976     0.977       539
#                   ELECTRIC_PRESSURE_WASHERS      0.925     0.930     0.927       343
#              HAIR_SHAMPOOS_AND_CONDITIONERS      0.781     0.568     0.658        44
#                                STETHOSCOPES      0.781     0.694     0.735        36
#                                    PRINTERS      0.891     0.820     0.854       400
#                             ELECTRIC_DRILLS      0.954     0.947     0.950       414
#                                KITCHEN_POTS      0.846     0.893     0.869       485
#                              FUEL_INJECTORS      0.867     0.825     0.846       103
#                            VEHICLE_SPEAKERS      0.906     0.893     0.900       421
#                           HOME_OFFICE_DESKS      0.822     0.866     0.843       149
#                              GUITAR_STRINGS      0.915     0.915     0.915       106
#                             DISC_PACKAGINGS      0.803     0.770     0.786        74
#                                 LIP_GLOSSES      0.902     0.874     0.888       190
#                                     DRESSES      0.957     0.968     0.963       692
#                                BASS_GUITARS      0.912     0.936     0.924       467
#                                  TURNTABLES      0.762     0.770     0.766       270
#                           TOY_BUILDING_SETS      0.814     0.791     0.802       249
#                                  BED_SHEETS      0.690     0.773     0.730        75
#                               CAR_GEARBOXES      0.915     0.929     0.922       267
#                                FLOOD_LIGHTS      0.912     0.937     0.924       462
#                          SOLDERING_MACHINES      0.928     0.943     0.935       383
#                            ELECTRONIC_DRUMS      0.848     0.761     0.802       117
#                    DATA_CABLES_AND_ADAPTERS      0.800     0.850     0.824        80
#                      AUTOMOTIVE_WATER_PUMPS      0.894     0.880     0.887       391
#                              FOOTBALL_BALLS      0.931     0.955     0.943       156
#                                LENS_FILTERS      0.872     0.907     0.889        75
#                       INSTRUMENT_AMPLIFIERS      0.807     0.802     0.804       449
#                                MUSIC_STANDS      0.897     0.812     0.852        32
#                        CAR_DISTRIBUTOR_CAPS      0.899     0.912     0.906       205
#                                  MOUSE_PADS      0.907     0.871     0.888       201
#                                     FABRICS      0.876     0.842     0.859       379
#                               CABIN_FILTERS      0.968     0.996     0.982       244
#                             SEWING_MACHINES      0.894     0.897     0.896       292
#                                      MIXERS      0.951     0.946     0.948       350
#                         MOTORCYCLE_FAIRINGS      0.904     0.824     0.862       353
#                                   CV_JOINTS      0.961     0.957     0.959       443
#                  HAIR_STRAIGHTENING_BRUSHES      0.857     0.923     0.889        26
#                             WHEELS_BEARINGS      0.934     0.963     0.949       547
#                                AV_RECEIVERS      0.500     0.633     0.559       188
#                              NETWORK_CABLES      0.880     0.926     0.903       190
#                                       CRIBS      0.737     0.777     0.757       242
#                                HOME_HEATERS      0.904     0.880     0.892       234
#                  BRACELETS_AND_ANKLE_BRACES      0.809     0.855     0.831       346
#                                    SNEAKERS      0.905     0.792     0.844        72
#                  AUTOMOTIVE_THROTTLE_BODIES      0.920     0.920     0.920        50
#                              COOKING_SCALES      0.904     0.915     0.910       412
#                               PEDAL_EFFECTS      0.899     0.895     0.897       695
#                              ENGINE_PISTONS      0.782     0.841     0.810       132
#                               FLATWARE_SETS      0.710     0.710     0.710        31
#                                     PANTIES      0.848     0.796     0.821        49
#                          ELECTRICAL_OUTLETS      0.846     0.902     0.873       122
#                          BABY_CLOTHING_SETS      0.646     0.671     0.658        76
#                              STEAM_CLEANERS      0.333     0.316     0.324        19
#                            DECORATIVE_VASES      0.805     0.858     0.830       274
#                             FOOD_PROCESSORS      0.757     0.785     0.771       135
#                             TRAILER_HITCHES      0.889     0.957     0.921       184
#                       SOFA_AND_FUTON_COVERS      0.989     0.949     0.969        99
#                                      SHIRTS      0.935     0.856     0.894       118
#                       VEHICLE_CLUTCH_CABLES      1.000     0.800     0.889        10
#                                 GATE_MOTORS      0.933     0.940     0.936       298
#                                  FOG_LIGHTS      0.929     0.942     0.935       292
#                                   SIM_CARDS      0.900     0.750     0.818        24
#                               BABY_MONITORS      0.947     0.973     0.960       220
#                            VEHICLE_CV_AXLES      0.938     0.884     0.910        69
#                                   LIPSTICKS      0.944     0.931     0.937       562
#                      SERVING_AND_HOME_TRAYS      0.909     0.847     0.877       354
#                                    COOKTOPS      1.000     0.364     0.533        11
#                              GRAPHICS_CARDS      0.968     0.938     0.952        32
#                          FIRE_EXTINGUISHERS      0.727     0.800     0.762        30
#                  KITCHEN_CABINET_ORGANIZERS      1.000     0.143     0.250         7
#                                       SOFAS      0.880     0.810     0.844       100
#                            GRAPHICS_TABLETS      0.903     0.932     0.917       190
#                                      SHORTS      0.901     0.861     0.881       274
#                            SWIMMING_GOGGLES      0.841     0.753     0.795        77
#                            POOL_INFLATABLES      0.805     0.892     0.846        37
#                                       DOORS      0.738     0.784     0.760        97
#                               SPORT_WATCHES      0.816     0.833     0.824       478
#            PORTABLE_EVAPORATIVE_AIR_COOLERS      0.772     0.761     0.766       138
#              DOG_CARRIERS_AND_CARRYING_BAGS      0.920     0.807     0.860        57
#                     ENGINE_INTAKE_MANIFOLDS      0.926     0.980     0.952        51
#                          MOTORCYCLE_HELMETS      0.977     0.990     0.983       715
#                        COMBUSTION_CHAINSAWS      0.948     0.869     0.907        84
#               ELECTRONIC_ENTRANCE_INTERCOMS      0.919     0.910     0.914       211
#                                     CRAYONS      0.971     0.980     0.975       101
#                                THERMOMETERS      0.864     0.810     0.836        63
#                              CAMERA_TRIPODS      0.814     0.862     0.837       427
#                           ARTIFICIAL_PLANTS      0.842     0.593     0.696        27
#                            PROJECTOR_MOUNTS      0.500     0.400     0.444         5
#                 PORTABLE_ELECTRIC_MASSAGERS      0.782     0.819     0.800        83
#               NON_CORRECTIVE_CONTACT_LENSES      0.952     0.833     0.889        24
#                                     PUZZLES      0.776     0.703     0.738        74
#            WASHING_AND_DRYER_MACHINE_COVERS      0.906     0.960     0.932        50
#                        PUSH_AND_RIDING_TOYS      0.458     0.344     0.393        32
#                                SHOWER_HEADS      0.848     0.834     0.841       235
#                            ANTI_THEFT_STUDS      0.957     0.900     0.927       220
#                               HATS_AND_CAPS      0.662     0.662     0.662        65
#                                   MAGAZINES      0.625     0.490     0.549       143
#                  ENGINE_COOLING_FAN_SHROUDS      0.895     0.928     0.911        83
#                      AUTOMOTIVE_OIL_FILTERS      0.833     0.698     0.759        43
#                            MOTORCYCLE_TIRES      0.851     0.891     0.870       147
#               MOTORCYCLE_TURN_SIGNAL_LIGHTS      0.934     0.959     0.946       221
#                                     PILLOWS      1.000     0.806     0.893        31
#                                    TEQUILAS      0.968     0.909     0.937        33
#                                 TOILET_RUGS      0.859     0.880     0.869       249
#                                      FLUTES      0.845     0.766     0.803       128
#                                    UKULELES      0.963     1.000     0.981        52
#                                 TOOTHPASTES      0.855     0.855     0.855        62
#                       MOTORCYCLE_CRASH_BARS      0.812     0.619     0.703        21
#                             PIPES_AND_TUBES      0.556     0.385     0.455        13
#                                FOOD_SLICERS      0.680     0.773     0.723        22
#           DESKTOP_COMPUTER_COOLERS_AND_FANS      0.863     0.893     0.877       345
#                                   SWAY_BARS      0.957     0.908     0.932        98
#                            AQUARIUM_FILTERS      0.882     0.911     0.897       214
#               CELLPHONE_REPLACEMENT_CAMERAS      0.960     0.941     0.950        51
#                                     MIRRORS      0.795     0.814     0.805        86
#                             BLU_RAY_PLAYERS      0.866     0.777     0.819       175
#                          AUTOMOTIVE_FENDERS      0.908     0.798     0.850       124
#                             SPARKLING_WINES      0.714     0.417     0.526        12
#              ENGINE_VALVES_SPRING_RETAINERS      0.968     0.897     0.931        68
#                                BABY_WALKERS      0.714     0.385     0.500        13
#             ANTIVIRUS_AND_INTERNET_SECURITY      0.591     0.812     0.684        16
#                       COTTON_CANDY_MACHINES      1.000     0.714     0.833         7
#                             ORAL_IRRIGATORS      1.000     0.500     0.667         8
#                    MOTORCYCLE_CLUTCH_COVERS      0.902     0.887     0.895       239
#                               GAME_CONSOLES      0.864     0.804     0.833       347
#                               TABLE_RUNNERS      0.913     0.940     0.926        67
#                           PLAYGROUND_SLIDES      0.889     0.615     0.727        13
#                                 3D_PRINTERS      0.915     0.915     0.915        47
#                                 DIAPER_BAGS      0.951     0.951     0.951       103
#                               ELECTRIC_SAWS      0.983     0.981     0.982       363
#                           KITCHEN_FURNITURE      0.667     0.684     0.675        38
#                            BABY_HIGH_CHAIRS      0.558     0.489     0.521        88
#                                    MINI_PCS      0.538     0.500     0.519        14
#                                    MASCARAS      0.798     0.859     0.827        92
#                     AUTOMOTIVE_WHEEL_COVERS      0.823     0.791     0.806       129
#                           WINDSHIELD_WIPERS      0.900     0.900     0.900       190
#                                     LIQUORS      0.959     0.930     0.944       100
#                            CLOTHING_PATCHES      0.878     0.741     0.804        58
#                       WOOD_BURNING_MACHINES      0.333     0.429     0.375         7
#                                  BINOCULARS      0.916     0.882     0.899       186
#                      COMMERCIAL_LIGHT_SIGNS      0.969     0.969     0.969        32
#                            WATER_DISPENSERS      0.914     0.893     0.903       225
#                       GLOW_PLUG_CONTROLLERS      0.825     0.839     0.832        56
#                                  TELEPHONES      1.000     0.571     0.727        21
#                             AIR_COMPRESSORS      0.926     0.924     0.925       353
#                           OPERATING_SYSTEMS      0.833     0.815     0.824       270
#                        CAR_ENGINE_CAMSHAFTS      0.765     0.867     0.812        15
#                             CLOTHES_HANGERS      0.929     0.859     0.893        92
#                                    WETSUITS      0.875     0.737     0.800        19
#                                TOILET_SEATS      0.989     0.979     0.984       191
#                            AUTOMOTIVE_DOORS      0.958     0.970     0.964       332
#             SUSPENSION_CONTROL_ARM_BUSHINGS      0.726     0.768     0.746       138
#                          VEHICLE_BRAKE_PADS      0.900     0.954     0.926       350
#                 REMOTE_CONTROL_TOY_VEHICLES      0.842     0.842     0.842       209
#                        AUTOMOTIVE_NERF_BARS      0.925     0.974     0.949        38
#                              ESSENTIAL_OILS      0.627     0.646     0.636        65
#                             SLATWALL_PANELS      0.951     0.963     0.957        80
#                                  TOOL_BOXES      0.899     0.899     0.899       109
#                                BABY_DIAPERS      0.960     0.968     0.964       375
#                          ALARMS_AND_SENSORS      0.882     0.864     0.873       295
#                            MOTORCYCLE_SUITS      0.824     0.757     0.789        37
#                               KITCHEN_BOWLS      0.417     0.227     0.294        22
#                              CAT_SCRATCHERS      0.889     0.533     0.667        15
#                              INK_CARTRIDGES      0.450     0.600     0.514        30
#                    MARKERS_AND_HIGHLIGHTERS      0.818     0.786     0.802       126
#                      JUMPSUITS_AND_OVERALLS      0.719     0.604     0.656       106
#                                 NAIL_DRYERS      0.938     0.924     0.931       131
#                             CAMERA_MONOPODS      0.544     0.633     0.585        49
#                                    BICYCLES      0.919     0.929     0.924       184
#                                        SALT      1.000     0.900     0.947        10
#                    SCREEN_PRINTING_MACHINES      0.278     0.357     0.313        14
#                                        BEDS      0.844     0.884     0.864        43
#                     BODY_SKIN_CARE_PRODUCTS      0.738     0.697     0.717       380
# AUTOMOTIVE_MANUAL_TRANSMISSION_SHIFT_LEVERS      0.542     0.520     0.531        25
#                            TV_STORAGE_UNITS      0.880     0.846     0.863        52
#                       AUTOMOTIVE_HEADLIGHTS      0.870     0.916     0.892       131
#                                  PAINTBALLS      0.889     0.847     0.867        85
#                                      SCREWS      0.758     0.877     0.813        57
#                                  TOY_ROBOTS      0.500     0.400     0.444        15
#                                     POSTERS      0.881     0.932     0.906       206
#                            MOTORCYCLE_PANTS      0.887     0.864     0.876       118
#                         INTEGRATED_CIRCUITS      0.682     0.625     0.652        72
#                                GARDEN_HOSES      0.925     0.875     0.899        56
#                                 ALTERNATORS      0.324     0.500     0.393        48
#                          MAGNIFYING_GLASSES      0.964     0.885     0.923       122
#                                    PERFUMES      0.843     0.827     0.835        52
#                                       FLOUR      0.833     1.000     0.909        15
#                                FISHING_RODS      0.778     0.737     0.757        19
#                  CELLPHONE_AND_TABLET_CASES      0.870     0.879     0.874        91
#                                     PAJAMAS      0.907     0.875     0.891        56
#                                  BUTT_PLUGS      0.706     0.706     0.706        34
#                 LUMBAR_AND_ABDOMINAL_BRACES      0.926     0.939     0.932       147
#                              AIR_MATTRESSES      0.922     0.922     0.922       154
#                               WATER_HEATERS      0.966     0.919     0.942       247
#                                 DISHWASHERS      0.924     0.905     0.915       148
#                        ELECTRIC_LAWN_MOWERS      1.000     0.500     0.667         4
#                               HOME_THEATERS      0.667     0.222     0.333         9
#                            LED_STAGE_LIGHTS      0.796     0.685     0.736       216
#           CHALKBOARD_AND_WHITEBOARD_ERASERS      0.950     0.826     0.884        23
#                               BABY_BOUNCERS      0.619     0.722     0.667        18
#                                       RINGS      0.902     0.860     0.881        43
#                      AUTOMOTIVE_AIR_FILTERS      0.917     0.800     0.854        55
#                                LUGGAGE_TAGS      0.881     0.787     0.831        47
#                                HEATER_CORES      0.812     0.619     0.703        21
#                             CLEANING_CLOTHS      0.885     0.828     0.856        93
#                              AIR_FRESHENERS      0.727     0.372     0.492        43
#                                     BLOUSES      0.585     0.632     0.608        38
#                             SAFETY_FOOTWEAR      0.831     0.894     0.861        66
#                                FREEZER_BAGS      1.000     0.750     0.857         8
#                      SHOCK_MOUNT_INSOLATORS      0.679     0.726     0.702        73
#                                  BAR_CLAMPS      0.900     0.562     0.692        16
#                             CHRISTMAS_TREES      1.000     0.865     0.928        37
#                          CAR_AIR_FRESHENERS      0.738     0.768     0.752        99
#                          BASKETBALL_JERSEYS      0.917     0.733     0.815        15
#                                  ACCORDIONS      0.905     0.923     0.914       311
#                                  FOOD_CARTS      0.964     0.871     0.915        31
#                                   HEAT_GUNS      0.916     0.926     0.921        94
#                   ENGINE_CRANKSHAFT_PULLEYS      0.839     0.879     0.858       107
#                                  PARTY_HATS      0.333     0.125     0.182         8
#                             RECEPTION_DESKS      1.000     0.750     0.857         4
#                              PICTURE_FRAMES      0.869     0.788     0.826       151
#                               OSCILLOSCOPES      0.900     0.900     0.900        10
#                   HABERDASHERY_LACE_EDGINGS      0.856     0.872     0.864       109
#                                       BEERS      0.920     0.947     0.933       170
#                                HOLE_PUNCHES      0.800     0.571     0.667         7
#                               DJ_TURNTABLES      0.682     0.562     0.616        80
#                                 VR_HEADSETS      0.983     0.963     0.973       352
#                             KITCHEN_MORTARS      0.000     0.000     0.000         4
#                                       OVENS      0.970     0.947     0.959       171
#                                DISHES_RACKS      0.479     0.469     0.474        49
#                                    EARRINGS      0.854     0.932     0.891        44
#                                   WARDROBES      0.821     0.889     0.853        36
#                           RACKS_AND_PINIONS      0.956     0.956     0.956       113
#                                   BOOKCASES      0.684     0.743     0.712        35
#                                  TOY_TRAINS      0.819     0.628     0.711        94
#                      CARD_PAYMENT_TERMINALS      0.750     0.706     0.727        17
#                           SUBMERSIBLE_PUMPS      0.978     0.890     0.932       100
#             GARDENING_AND_AGRICULTURE_SEEDS      0.892     0.917     0.904        36
#                                      MODEMS      0.731     0.772     0.751       123
#                               OFFICE_CHAIRS      0.859     0.867     0.863        98
#                                   PENDRIVES      0.857     0.906     0.881       139
#                                   NECKLACES      0.869     0.582     0.697        91
#                          ENGINE_GASKET_SETS      0.500     0.235     0.320        17
#                  AUTOMOTIVE_SHOCK_ABSORBERS      0.549     0.682     0.608        66
#                                 VINYL_ROLLS      0.486     0.500     0.493        70
#               TROLLEY_AND_FURNITURE_CASTERS      0.000     0.000     0.000         4
#                   TV_RECEIVERS_AND_DECODERS      0.692     0.500     0.581        18
#                                LIFE_JACKETS      1.000     0.773     0.872        22
#                        SELF_ADHESIVE_LABELS      0.652     0.612     0.632        49
#                   IGNITION_SWITCH_ACTUATORS      1.000     0.929     0.963        14
#                            BABY_STERILIZERS      0.667     0.636     0.651        22
#                       PARKING_BRAKE_HANDLES      0.950     0.934     0.942        61
#                      CLUTCH_SLAVE_CYLINDERS      0.700     0.700     0.700        30
#                                      FISHES      0.500     0.222     0.308         9
#                             COOKIES_CUTTERS      0.795     0.753     0.773        77
#                                  NEBULIZERS      0.870     0.816     0.842        49
#                                  COMFORTERS      0.438     0.350     0.389        20
#                         ELLIPTICAL_MACHINES      0.264     0.703     0.384       128
#                               ENGINE_VALVES      0.853     0.659     0.744        44
#                                  SANDPAPERS      0.812     0.619     0.703        21
#        AUTOMOTIVE_SHOCK_ABSORBER_BUMP_STOPS      0.939     0.838     0.886        37
#                                     GAZEBOS      0.880     0.890     0.885        91
#                                  XENON_KITS      0.688     0.550     0.611        20
#                      AUTOMOTIVE_DOOR_PANELS      0.942     0.973     0.957       150
#                  INDOOR_CURTAINS_AND_BLINDS      0.861     0.882     0.871       161
#                         CAR_WINDOW_SWITCHES      0.862     0.806     0.833        31
#                                   EPILATORS      0.772     0.755     0.763        94
#                           MALE_MASTURBATORS      0.700     0.467     0.560        15
#                         DRILLS_SCREWDRIVERS      0.650     0.542     0.591        24
#                                  CONCEALERS      0.824     0.852     0.838        88
#                     SCHOOL_AND_OFFICE_GLUES      0.429     0.300     0.353        10
#                      SANDALS_AND_FLIP_FLOPS      0.840     0.933     0.884        45
#                                   BAR_SOAPS      0.672     0.650     0.661        60
#                   ELECTRIC_BATHROOM_FAUCETS      0.750     0.840     0.792        25
#                           VOLTAGE_DETECTORS      0.963     0.897     0.929        29
#                     ORTHOPEDIC_ANKLE_BRACES      0.857     0.800     0.828        15
#                              HEDGE_TRIMMERS      0.933     1.000     0.966        14
#                         STABILIZERS_AND_UPS      0.000     0.000     0.000         2
#                               BABY_PLAYARDS      0.752     0.800     0.775       110
#                            RESISTANCE_BANDS      0.804     0.867     0.834       180
#                             LAPTOP_CHARGERS      0.918     0.824     0.868        68
#                       COMPUTER_MOTHERBOARDS      0.780     0.780     0.780        41
# ...
#                            LIVING_ROOM_SETS      0.562     0.643     0.600        14
#                              BABY_PACIFIERS      0.909     0.667     0.769        15
#                              HAND_POLISHERS      0.300     0.214     0.250        14
#                                SHADE_CLOTHS      0.800     1.000     0.889        12
#                               HAMMER_DRILLS      0.600     0.375     0.462         8
#                              POWER_GRINDERS      0.714     0.385     0.500        13
#                               CAMERA_STRAPS      0.000     0.000     0.000         3
#                           LAWN_MOWER_BLADES      0.333     0.222     0.267         9
#                          PNEUMATIC_STAPLERS      0.812     1.000     0.897        13
#              THERMAL_REFRIGERATORS_AND_BAGS      0.864     0.679     0.760        28
#                                LIGHT_STANDS      0.500     0.143     0.222         7
#                                      STRAWS      0.857     0.750     0.800         8
#                                       SUITS      0.615     0.485     0.542        33
#                           BATHROOM_VANITIES      0.333     0.250     0.286         8
#                         VIBRATION_PLATFORMS      0.812     0.722     0.765        18
#                               DINING_TABLES      0.857     0.750     0.800        16
#                           TURNTABLE_NEEDLES      0.000     0.000     0.000         3
#                                HEARING_AIDS      0.462     0.600     0.522        10
#                     ORTHOPEDIC_WALKER_BOOTS      0.462     0.429     0.444        14
#                                         TEA      1.000     0.700     0.824        10
#                             TORQUE_WRENCHES      1.000     0.875     0.933         8
#                                 CATS_LITTER      0.909     0.833     0.870        12
#                                 MATE_GOURDS      1.000     0.364     0.533        11
#                                  MEAT_HOOKS      1.000     0.500     0.667         2
#                       AUTOMOTIVE_DEFLECTORS      1.000     0.800     0.889         5
#                   VARIABLE_FREQUENCY_DRIVES      0.800     0.571     0.667         7
#                                  SWEETENERS      0.625     0.625     0.625         8
#         AUTOMOTIVE_CELLPHONE_AND_GPS_MOUNTS      0.750     0.500     0.600         6
#                         RADIO_BASE_STATIONS      0.400     0.333     0.364         6
#                                    CRUTCHES      0.000     0.000     0.000         4
#                                POWER_STRIPS      0.625     0.500     0.556        10
#                               KATANA_SWORDS      0.800     0.615     0.696        13
#                        CATS_AND_DOGS_TREATS      0.750     0.429     0.545        14
#                         MEMORY_CARD_READERS      0.000     0.000     0.000         3
#                            TELEPHONE_CABLES      1.000     0.929     0.963        14
#                          SOLID_SWEET_PASTES      0.583     0.700     0.636        10
#                           DISPOSABLE_GLOVES      1.000     0.333     0.500         3
#                        MOTORCYCLE_GRAB_BARS      1.000     1.000     1.000         3
#                              PLUNGE_ROUTERS      0.750     0.375     0.500         8
#                         GROOVE_JOINT_PLIERS      0.750     0.750     0.750         4
#                          BICYCLE_HANDLEBARS      0.250     0.200     0.222         5
#                          SOLDERING_STATIONS      0.800     0.769     0.784        26
#                               TANDEM_CHAIRS      0.333     0.143     0.200         7
#                                GARAGE_DOORS      0.800     0.333     0.471        12
#                         SPARK_PLUG_WIRESETS      1.000     0.750     0.857        32
#                       ELECTRIC_SHOWER_HEADS      0.333     0.200     0.250         5
#                        PORTABLE_DVD_PLAYERS      0.333     0.111     0.167         9
#                                      DILDOS      0.429     0.375     0.400         8
#                   INDUSTRIAL_DOUGH_KNEADERS      0.167     0.231     0.194        13
#                   UNIVERSAL_REMOTE_CONTROLS      0.500     0.333     0.400         3
#                                 WHEEL_STUDS      0.222     0.333     0.267         6
#                            FABRIC_SOFTENERS      0.778     0.737     0.757        19
#              MOTORCYCLE_DISTRIBUTION_CHAINS      0.773     0.895     0.829        19
#                       DOOR_AND_WINDOW_LOCKS      0.000     0.000     0.000         3
#                                        GINS      1.000     0.250     0.400         4
#                                 HAND_TRUCKS      0.333     0.250     0.286         4
#                                    STAPLERS      0.500     0.500     0.500         6
#                                   APERITIFS      0.250     0.200     0.222         5
#                             SHOWER_CURTAINS      1.000     1.000     1.000         4
#                              ANTIQUE_CHAIRS      0.375     0.429     0.400         7
#                               YOGURT_MAKERS      0.333     0.200     0.250         5
#                                 SHIN_GUARDS      0.000     0.000     0.000         2
#                             GOLF_CLUBS_SETS      0.667     0.444     0.533         9
#                  FOOTBALL_GOALKEEPER_GLOVES      0.857     0.750     0.800        16
#                                LASER_LEVELS      0.667     0.500     0.571         8
#                        KEYBOARD_CONTROLLERS      0.500     0.200     0.286         5
#                          ALTERNATOR_PULLEYS      0.778     0.412     0.538        17
#            CAMERA_AND_CELLPHONE_STABILIZERS      0.500     0.333     0.400         3
#                                BABY_JUMPERS      0.667     0.333     0.444         6
#                 CAMERA_REPLACEMENT_DISPLAYS      0.455     0.714     0.556         7
#                                 CRANKSHAFTS      0.875     0.333     0.483        21
#                                BREAD_MAKERS      0.667     0.667     0.667         3
#                    SCHOOL_AND_OFFICE_PAPERS      0.500     0.375     0.429         8
#                    STOVETOP_POPCORN_POPPERS      1.000     0.500     0.667         8
#                      BREAST_FEEDING_PILLOWS      0.500     0.545     0.522        11
#                               POOL_CLEANERS      1.000     0.400     0.571         5
#                              LINEMAN_PLIERS      1.000     0.667     0.800         3
#                                  COAT_RACKS      1.000     0.167     0.286         6
#                                  POOL_PUMPS      1.000     0.833     0.909        12
#                     WATER_PURIFIERS_FILTERS      0.857     0.300     0.444        20
#                               SAFETY_GLOVES      1.000     0.500     0.667         6
#                          ISOPROPYL_ALCOHOLS      1.000     0.778     0.875         9
#               VEHICLE_BRAKE_HYDRAULIC_HOSES      0.375     0.333     0.353         9
#                              MEDICINE_BALLS      1.000     0.500     0.667         4
#                             KITCHEN_GRATERS      0.000     0.000     0.000         5
#                              NAPKIN_HOLDERS      0.600     0.333     0.429         9
#                               PUNCHING_BAGS      0.000     0.000     0.000         3
#                                 ESPADRILLES      0.667     0.250     0.364         8
#                         CAR_CENTER_CONSOLES      0.750     0.500     0.600         6
#                             VIDEO_CASSETTES      0.800     0.667     0.727         6
#                              POTENTIOMETERS      0.333     0.200     0.250         5
#                    READY_TO_DRINK_COCKTAILS      0.000     0.000     0.000         2
#                                 FLOOR_LAMPS      0.727     0.727     0.727        11
#                            DRONE_PROPELLERS      0.714     0.833     0.769         6
#                                       TENTS      0.900     0.818     0.857        11
#                            SAFETY_HARNESSES      0.000     0.000     0.000         4
#                                    SYRINGES      1.000     0.250     0.400         4
#                                   BEDLINERS      1.000     0.688     0.815        16
#                     ELECTROLYTIC_CAPACITORS      0.667     0.286     0.400         7
#                                BASKET_BALLS      1.000     0.500     0.667         2
#                                   OTOSCOPES      0.077     0.250     0.118         4
#                               WAFFLE_MAKERS      1.000     0.625     0.769         8
#                                 PENIS_RINGS      0.000     0.000     0.000         4
#                          ELECTRIC_AIR_PUMPS      0.583     0.875     0.700         8
#                             COFFEE_CAPSULES      0.667     0.400     0.500         5
#                         BABY_PACIFIER_CLIPS      1.000     1.000     1.000         5
#                                   KEY_RACKS      0.000     0.000     0.000         4
#                                  DEODORANTS      1.000     0.800     0.889         5
#                          INDUSTRIAL_PULLEYS      0.500     0.400     0.444         5
#                               BILL_COUNTERS      1.000     0.600     0.750         5
#                  AUDIO_AND_VIDEO_CONNECTORS      0.000     0.000     0.000         4
#                            WASHING_MACHINES      0.714     0.417     0.526        12
#                 ENGINE_COOLING_FAN_SWITCHES      1.000     0.500     0.667         6
#                        AUTOMOTIVE_BATTERIES      0.000     0.000     0.000         5
#                        CHIP_AND_DIP_SERVERS      1.000     0.250     0.400         4
#                                ARCHERY_BOWS      0.714     0.833     0.769         6
#                             VINYL_FLOORINGS      0.667     0.571     0.615         7
#                              MENSTRUAL_CUPS      1.000     1.000     1.000         5
#                               SLEEPING_BAGS      0.500     0.500     0.500         4
#                               RUBBER_STAMPS      1.000     0.400     0.571         5
#                              DRYER_MACHINES      0.667     0.500     0.571         8
#                            ENERGETIC_STONES      0.286     0.286     0.286         7
#                              BICYCLE_PEDALS      0.857     0.667     0.750         9
#                      MOTORCYCLE_CARBURETORS      0.750     0.600     0.667         5
#                           SCREWDRIVERS_SETS      0.000     0.000     0.000         3
#                                EDIBLE_SEEDS      1.000     0.333     0.500         3
#                        STORE_SHOPPING_CARTS      1.000     0.750     0.857         4
#                         SWIMMING_NOSE_CLIPS      1.000     0.500     0.667         2
#                                 AFTERSHAVES      0.000     0.000     0.000         3
#                              AIRBAG_MODULES      1.000     0.667     0.800         3
#                                   HAND_SAWS      0.600     0.500     0.545         6
#           NECK_GAITERS_MASKS_AND_BALACLAVAS      0.000     0.000     0.000         2
#                          MAGNETIC_COMPASSES      0.625     0.833     0.714         6
#                          MAKEUP_TRAIN_CASES      0.000     0.000     0.000         4
#                            POPCORN_MACHINES      0.700     0.778     0.737         9
#                                LAMP_HOLDERS      0.667     0.500     0.571         4
#                    IGNITION_CONTROL_MODULES      0.000     0.000     0.000         7
#                             CAR_FRONT_MASKS      0.500     0.500     0.500         2
#                               HAND_BLENDERS      0.000     0.000     0.000         3
#                              KIDS_TRICYCLES      0.000     0.000     0.000         4
#                              AIRGUN_PELLETS      0.500     0.250     0.333         4
#                            AUTOMOTIVE_SEATS      0.200     0.167     0.182         6
#              MOTORCYCLE_TRANSMISSION_CROWNS      0.333     0.250     0.286         4
#                                  LAMINATORS      0.444     0.571     0.500         7
#                                 CEREAL_BARS      1.000     0.333     0.500         3
#                                MUSIC_ALBUMS      0.000     0.000     0.000         4
#                   AUTOMOTIVE_CV_JOINT_BOOTS      0.400     0.286     0.333         7
#                           MICROWAVE_KEYPADS      1.000     0.667     0.800         3
#                           WALL_ANCHOR_PLUGS      1.000     0.250     0.400         4
#                                 DRUM_STANDS      1.000     0.429     0.600         7
#                                 PET_COLLARS      0.900     0.643     0.750        14
#                             GATE_GEAR_RACKS      1.000     0.500     0.667         4
#                                   CAR_HOODS      0.333     0.667     0.444         3
#                        SCREEN_PRINTING_KITS      0.667     0.500     0.571         4
#                                  LED_STRIPS      1.000     0.750     0.857         4
#                             SANDWICH_MAKERS      0.000     0.000     0.000         2
#                              DENTAL_FLOSSES      0.333     0.500     0.400         2
#                              CAMERA_FLASHES      1.000     0.600     0.750         5
#                           DOG_NAIL_CLIPPERS      1.000     1.000     1.000         2
#                                    PINBALLS      0.000     0.000     0.000         6
#                                      GAUZES      1.000     0.500     0.667         6
#                                        SODS      1.000     0.667     0.800         3
#                          ELECTRICITY_METERS      0.000     0.000     0.000         4
#                             METAL_DETECTORS      0.000     0.000     0.000         3
#                          ELECTRIC_CHAINSAWS      0.000     0.000     0.000         3
#                            KNITTING_NEEDLES      0.667     0.333     0.444         6
#                           SWIMMING_EARPLUGS      0.000     0.000     0.000         2
#                                 SOUND_CARDS      0.750     0.600     0.667         5
#                                    STEPPERS      0.000     0.000     0.000         4
#                                 FANNY_PACKS      0.000     0.000     0.000         4
#                          TOOTHBRUSH_HOLDERS      0.000     0.000     0.000         2
#                          TABLE_TENNIS_BALLS      1.000     0.500     0.667         2
#                 ENGINE_OIL_PRESSURE_SENSORS      0.500     0.333     0.400         3
#                                 ICE_BUCKETS      0.800     0.571     0.667         7
#                               MASSAGE_SOFAS      1.000     0.500     0.667         4
#                              STYLING_CHAIRS      1.000     0.500     0.667         2
#                               BICYCLE_SEATS      0.000     0.000     0.000         3
#                            VOLLEYBALL_BALLS      0.000     0.000     0.000         3
#                           SPHYGMOMANOMETERS      1.000     0.250     0.400         4
#                              BINDING_SPINES      0.000     0.000     0.000         2
#                    DIGITAL_WEATHER_STATIONS      0.500     0.500     0.500         2
#                          HOME_BOTTLE_STANDS      1.000     0.667     0.800         3
#                                   DOORBELLS      0.000     0.000     0.000         2
#                                DRIED_FRUITS      0.333     0.500     0.400         2
#                            BOXING_HEADGEARS      1.000     0.500     0.667         2
#
#                                    accuracy                          0.878    138550
#                                   macro avg      0.766     0.692     0.715    138550
#                                weighted avg      0.879     0.878     0.877    138550
