# %%
from os.path import join
import os
import pandas as pd
import torch
import numpy as np
import torch.nn as nn
import torch.nn.functional as F
from torch.optim.lr_scheduler import ReduceLROnPlateau
from torch.nn.init import kaiming_uniform_
from torch.optim import SGD
from torch.utils.data import DataLoader, SequentialSampler, RandomSampler
from torch.optim import Adam
from nlpClassifiers.data.dataset  import NLPDataset, Vocabulary
from sklearn.metrics import roc_curve, auc, classification_report
from scipy.special import expit
import gensim
import shutil
from pathlib import Path
import random

# %%
ROOT = '../../'
PATH_TO_VIRTUAL_OPERATOR_DATA = join(ROOT, "data/virtual-operator")
PATH_TO_AGENT_BENCHMARK_DATA = join(ROOT, "data/agent-benchmark")
PATH_TO_ML_PT_DATA = join(ROOT, "data/mercado-livre-pt-only")

PATH_TO_VIRTUAL_OPERATOR_MODELS = join(ROOT, "models/virtual-operator")
PATH_TO_AGENT_BENCHMARK_MODELS = join(ROOT, "models/agent-benchmark")
PATH_TO_ML_PT_MODELS = join(ROOT, "models/mercado-livre-pt-only")

EMBEDDING_DIM = 300
EMBEDDINGS_FILE = '../../data/fasttext-embeddings/wiki.pt.vec'
MAX_WORDS = 30000
dataset = 'mercado-livre-pt'
sentence_max_len = 82
batch_size = 512

epochs=30
stopwords_lang = None
gpu=1
lr=0.001
clipping_value=0.25
save_name='cnn-pytorch-fasttext-embeddings'
patience=5

# %%
BASE_PATH_TO_MODELS = {"virtual-operator": PATH_TO_VIRTUAL_OPERATOR_MODELS, "agent-benchmark": PATH_TO_AGENT_BENCHMARK_MODELS, "mercado-livre-pt": PATH_TO_ML_PT_MODELS}
FULL_PATH_TO_MODELS = join(BASE_PATH_TO_MODELS[dataset], "bow-classifier")

# %%
def _init_fn(worker_id):
    np.random.seed(seed)

# %%
def read_data(dataset, subset):
    BASE_PATH_TO_DATASET = {"virtual-operator": PATH_TO_VIRTUAL_OPERATOR_DATA, "agent-benchmark": PATH_TO_AGENT_BENCHMARK_DATA, "mercado-livre-pt": PATH_TO_ML_PT_DATA}
    BASE_PATH_TO_DATASET = {"train": join(BASE_PATH_TO_DATASET[dataset], "train.csv"), "val": join(BASE_PATH_TO_DATASET[dataset], "val.csv"), "test": join(BASE_PATH_TO_DATASET[dataset], "test.csv")}
    FULL_PATH_TO_DATASET = BASE_PATH_TO_DATASET[subset]
    
    if dataset == "mercado-livre-pt":
        sep=","
    else:
        sep=";"
    data = pd.read_csv(FULL_PATH_TO_DATASET, sep=sep, names =['utterance','label'], header=None, dtype={'utterance':str, 'label': str} )
    return data

# %%
train_df = read_data(dataset, "train")
val_df = read_data(dataset, "val")

# %%
voc = Vocabulary('CNN', stopwords_lang)
voc.build_vocab(train_df['utterance'].tolist() +  val_df['utterance'].tolist(), MAX_WORDS)
embedding_weights = voc.load_embeddings(EMBEDDINGS_FILE, EMBEDDING_DIM)
if voc.num_words < MAX_WORDS or MAX_WORDS == 0:
    MAX_WORDS = voc.num_words
# Out:
# 13817 tokens not found in vocabulary.

# %%
voc.num_words
# Out:
# 235869

# %%
embedding_weights.size()
# Out:
# torch.Size([30000, 300])

# %%
train_corpus = NLPDataset(dataset, "train", sentence_max_len, vocab= voc)
labels_dict = train_corpus.labels_dict
val_corpus = NLPDataset(dataset, "val", sentence_max_len, labels_dict = labels_dict, vocab= voc)

# %%
train_dataloader = DataLoader(
            train_corpus,
            sampler = RandomSampler(train_corpus),
            batch_size = batch_size,
            pin_memory=True,
            worker_init_fn=_init_fn,
            num_workers=0
)

validation_dataloader = DataLoader(
            val_corpus,
            sampler = RandomSampler(val_corpus),
            batch_size = batch_size,
            pin_memory=True,
            worker_init_fn=_init_fn,
            num_workers=0
)

# %%
def initialize_weights(model):
    if type(model) in [nn.Linear]:
        nn.init.xavier_normal_(model.weight.data)
    elif type(model) in [nn.LSTM, nn.RNN, nn.GRU]:
        nn.init.xavier_normal_(model.weight_hh_l0)
        nn.init.xavier_normal_(model.weight_ih_l0)

# %%
#del model
torch.cuda.empty_cache()

# %%
def seed_everything(seed=10):
    random.seed(seed)
    os.environ['PYTHONHASHSEED'] = str(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    torch.backends.cudnn.deterministic = True

# %%
seed_everything()

# %%
class CNNNet(nn.Module):
    def __init__(self, num_classes, num_features, criterion, embedding_dim, embedding_weights=None):
        super(CNNNet, self).__init__()
        self.criterion = criterion
        self.embedding_dim = embedding_dim
        self.n_layers = 1
        self.embedding = nn.Embedding(num_features, embedding_dim, padding_idx = 0)
        if(embedding_weights is not None):
            print("Embedding layer Weights won't be updated.")
            self.embedding.load_state_dict({'weight': embedding_weights})
            self.embedding.weight.requires_grad = False
            #self.embedding.from_pretrained(embedding_weights, freeze=True)
        else:
            self.embedding.weight.data = torch.zeros(self.embedding.weight.data.size())
            self.embedding.weight.requires_grad = True
        
        self.cnn = nn.Conv1d(embedding_dim, 256, 4)
        
        for name, param in self.cnn.named_parameters():
            if 'bias' in name:
                nn.init.constant_(param, 0.0)
            elif 'weight_ih' in name:
                nn.init.kaiming_normal_(param)
            elif 'weight_hh' in name:
                nn.init.orthogonal_(param)
             
        self.dropout = nn.Dropout(0.2)       
        self.out = nn.Linear(256, num_classes)
        self.init_weights()
    def forward(self, x, y):
        # Conv1d takes in (batch, channels, seq_len), but raw embedded is (batch, seq_len, channels)
        h_embedding = self.embedding(x)
        h_embedding = h_embedding.permute(0, 2, 1)
        h_cnn = self.cnn(h_embedding)
        h_cnn = h_cnn.permute(0, 2, 1)
        h_cnn = self.dropout(h_cnn)
        h_max_pool = self.global_max_pool(h_cnn)
        x = self.out(h_max_pool)
        loss = self.criterion(x, y)
        # return the final output
        return loss,x 
    
    @staticmethod
    def global_max_pool(x):
        """Convolution and global max pooling layer"""
        return x.max(1)[0]
    
    def init_weights(self):
        """
        Here we reproduce Keras default initialization weights to initialize Embeddings/LSTM weights
        """
        ih = (param.data for name, param in self.named_parameters() if 'weight_ih' in name)
        hh = (param.data for name, param in self.named_parameters() if 'weight_hh' in name)
        b = (param.data for name, param in self.named_parameters() if 'bias' in name)
        for t in ih:
            nn.init.xavier_uniform(t)
        for t in hh:
            nn.init.orthogonal(t)
        for t in b:
            nn.init.constant(t, 0)
    
    def init_hidden(self, batch_size, device):
        weight = next(self.parameters()).data
        hidden = (weight.new(self.n_layers, batch_size, self.embedding_dim).zero_().to(device),
                      weight.new(self.n_layers, batch_size, self.embedding_dim).zero_().to(device))
        return hidden

# %%
criterion = torch.nn.CrossEntropyLoss()
model = CNNNet(train_corpus.num_labels, MAX_WORDS, criterion, EMBEDDING_DIM, embedding_weights)
# Out:
# Embedding layer Weights won't be updated.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:60: UserWarning: nn.init.constant is now deprecated in favor of nn.init.constant_.

# %%
model.apply(initialize_weights)
# Out:
# CNNNet(
#   (criterion): CrossEntropyLoss()
#   (embedding): Embedding(30000, 300, padding_idx=0)
#   (cnn): Conv1d(300, 256, kernel_size=(4,), stride=(1,))
#   (dropout): Dropout(p=0.2, inplace=False)
#   (out): Linear(in_features=256, out_features=1048, bias=True)
# )

# %%
device = torch.device(f"cuda:{gpu}")

# %%
model = model.to(device)
optimizer = Adam(model.parameters(),lr, betas=(0.7, 0.999))

# %%
def multi_acc(y_pred, y_test):
    y_pred_softmax = torch.log_softmax(y_pred, dim = 1)
    _, y_pred_tags = torch.max(y_pred_softmax, dim = 1)    
    
    correct_pred = (y_pred_tags == y_test).float()
    acc = correct_pred.sum() / len(correct_pred)
    acc = acc * 100.0

    return acc

# %%
def get_accuracy_from_logits(logits, labels):
    acc = (labels.cpu() == logits.cpu().argmax(-1)).float().detach().numpy()
    return float(100 * acc.sum() / len(acc))

# %%
scheduler = ReduceLROnPlateau(optimizer, mode='min', patience=3,verbose=True, factor=0.1)

best_epoch = -1
last_saved_model = ""
training_stats = []
global_step = 0
best_val_acc = float("-inf")
best_model_wts = None
best_curr_val = 0

for epoch_i in range(0, epochs):
    print("")
    print('======== Epoch {:} / {:} ========'.format(epoch_i + 1, epochs))
    print('Training...')
    total_train_loss = 0
    model.train()
    for step, batch in enumerate(train_dataloader):
        #val_h = model.init_hidden(len(batch[0]), device)
        #val_h = tuple([each.data for each in val_h])
         # Progress update every 40 batches.
        if step % 40 == 0 and not step == 0:
            print('  Batch {:>5,}  of  {:>5,}.    .'.format(step, len(train_dataloader)))
        b_input_ids = batch[0]
        b_labels = batch[1].to(device)
        b_input_ids = torch.tensor(b_input_ids).to(device).long()
        model.zero_grad()
        loss, logits = model(b_input_ids, b_labels)
        loss.backward()
        torch.nn.utils.clip_grad_norm_(model.parameters(), clipping_value)
        optimizer.step()
        step_loss = loss.item()
        if step % 40 == 0 and not step == 0:
            print("  step loss: {0:.2f}".format(step_loss))
        total_train_loss += step_loss
        global_step += 1
    avg_train_loss = total_train_loss / len(train_dataloader)
    # Measure how long this epoch took.
    print("")
    print("  Average training loss: {0:.2f}".format(avg_train_loss))

    print("")
    print("Running Validation...")
    model.eval()

    # Tracking variables
    total_eval_accuracy = 0.0
    total_eval_loss = 0
    nb_eval_steps = 0
    for step, batch in enumerate(validation_dataloader):
        #val_h = model.init_hidden(len(batch[0]), device)
        #val_h = tuple([each.data for each in val_h])
        b_input_ids = batch[0]
        b_input_ids = torch.tensor(b_input_ids).to(device).long()
        b_labels = batch[1].to(device)
        with torch.no_grad():
            # Forward pass, calculate logit predictions.
            loss, logits = model(b_input_ids, b_labels)
        total_eval_loss += loss
        batch_acc = get_accuracy_from_logits(logits, b_labels)
        batch_acc2 = multi_acc(logits, b_labels)
        print("Batch accuracy: {0:.2f}".format(batch_acc))
        total_eval_accuracy += batch_acc
    
    # Calculate the average loss over all of the batches.
    avg_val_accuracy = total_eval_accuracy / len(validation_dataloader)
    print("  Accuracy: {0:.2f}".format(avg_val_accuracy))
    
    if avg_val_accuracy > best_val_acc:
        print(f"New best model, saving it!")
        if avg_val_accuracy > best_curr_val:
            best_curr_val = avg_val_accuracy
        if last_saved_model:
            shutil.rmtree(last_saved_model)
        model_path = Path(
            FULL_PATH_TO_MODELS,
            f"base-dataset-{dataset}-{save_name}"
        )
        last_saved_model = model_path
        model_path.mkdir(parents=True, exist_ok=True)
        best_val_acc = avg_val_accuracy
        torch.save(model, join(model_path, "best-model.pth"))
        best_epoch = epoch_i
        n_epochs_no_improvement = 0
    elif avg_val_accuracy > best_curr_val:
        best_curr_val = avg_val_accuracy
        n_epochs_no_improvement = 0
    else:
        n_epochs_no_improvement += 1
        print(f"The model does not improve for {n_epochs_no_improvement} epochs!")

    if n_epochs_no_improvement > patience:
        print(f"====>Stopping training, the model did not improve for {n_epochs_no_improvement}\n====>Best epoch: {best_epoch + 1}.")
        break
    scheduler.step(total_eval_loss)
print("")
print("Training complete!")
# Out:
# ======== Epoch 1 / 30 ========
# Training...
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:25: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   Batch    40  of    975.    .
#   step loss: 5.46
#   Batch    80  of    975.    .
#   step loss: 4.49
#   Batch   120  of    975.    .
#   step loss: 3.41
#   Batch   160  of    975.    .
#   step loss: 2.93
#   Batch   200  of    975.    .
#   step loss: 2.32
#   Batch   240  of    975.    .
#   step loss: 2.08
#   Batch   280  of    975.    .
#   step loss: 2.03
#   Batch   320  of    975.    .
#   step loss: 1.80
#   Batch   360  of    975.    .
#   step loss: 1.67
#   Batch   400  of    975.    .
#   step loss: 1.30
#   Batch   440  of    975.    .
#   step loss: 1.38
#   Batch   480  of    975.    .
#   step loss: 1.34
#   Batch   520  of    975.    .
#   step loss: 1.08
#   Batch   560  of    975.    .
#   step loss: 1.18
#   Batch   600  of    975.    .
#   step loss: 1.05
#   Batch   640  of    975.    .
#   step loss: 1.05
#   Batch   680  of    975.    .
#   step loss: 1.01
#   Batch   720  of    975.    .
#   step loss: 0.86
#   Batch   760  of    975.    .
#   step loss: 0.88
#   Batch   800  of    975.    .
#   step loss: 0.82
#   Batch   840  of    975.    .
#   step loss: 0.86
#   Batch   880  of    975.    .
#   step loss: 0.81
#   Batch   920  of    975.    .
#   step loss: 0.82
#   Batch   960  of    975.    .
#   step loss: 0.82
#
#   Average training loss: 1.85
#
# Running Validation...
# Batch accuracy: 88.09
# Batch accuracy: 83.98
# Batch accuracy: 82.03
# Batch accuracy: 85.55
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:53: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
# Batch accuracy: 81.84
# Batch accuracy: 88.48
# Batch accuracy: 85.35
# Batch accuracy: 83.20
# Batch accuracy: 84.57
# Batch accuracy: 87.70
# Batch accuracy: 84.38
# Batch accuracy: 84.57
# Batch accuracy: 83.59
# Batch accuracy: 87.11
# Batch accuracy: 84.38
# Batch accuracy: 84.57
# Batch accuracy: 85.16
# Batch accuracy: 82.03
# Batch accuracy: 84.18
# Batch accuracy: 85.55
# Batch accuracy: 85.35
# Batch accuracy: 81.45
# Batch accuracy: 89.06
# Batch accuracy: 82.23
# Batch accuracy: 85.74
# Batch accuracy: 86.13
# Batch accuracy: 87.50
# Batch accuracy: 86.52
# Batch accuracy: 83.01
# Batch accuracy: 84.96
# Batch accuracy: 86.13
# Batch accuracy: 86.13
# Batch accuracy: 88.09
# Batch accuracy: 85.55
# Batch accuracy: 83.79
# Batch accuracy: 80.47
# Batch accuracy: 86.52
# Batch accuracy: 86.52
# Batch accuracy: 82.23
# Batch accuracy: 84.57
# Batch accuracy: 85.35
# Batch accuracy: 84.18
# Batch accuracy: 84.77
# Batch accuracy: 86.72
# Batch accuracy: 83.20
# Batch accuracy: 88.09
# Batch accuracy: 84.38
# Batch accuracy: 84.57
# Batch accuracy: 84.77
# Batch accuracy: 87.70
# Batch accuracy: 84.38
# Batch accuracy: 85.55
# Batch accuracy: 84.77
# Batch accuracy: 88.09
# Batch accuracy: 81.84
# Batch accuracy: 88.28
# Batch accuracy: 83.20
# Batch accuracy: 86.13
# Batch accuracy: 84.57
# Batch accuracy: 85.55
# Batch accuracy: 82.03
# Batch accuracy: 83.59
# Batch accuracy: 84.18
# Batch accuracy: 86.52
# Batch accuracy: 84.57
# Batch accuracy: 85.74
# Batch accuracy: 83.40
# Batch accuracy: 87.50
# Batch accuracy: 83.40
# Batch accuracy: 85.35
# Batch accuracy: 87.11
# Batch accuracy: 84.96
# Batch accuracy: 84.38
# Batch accuracy: 84.77
# Batch accuracy: 83.98
# Batch accuracy: 81.25
# Batch accuracy: 84.77
# Batch accuracy: 86.33
# Batch accuracy: 85.55
# Batch accuracy: 84.38
# Batch accuracy: 83.59
# Batch accuracy: 85.16
# Batch accuracy: 87.11
# Batch accuracy: 83.79
# Batch accuracy: 85.55
# Batch accuracy: 83.40
# Batch accuracy: 86.91
# Batch accuracy: 86.72
# Batch accuracy: 86.33
# Batch accuracy: 87.50
# Batch accuracy: 84.57
# Batch accuracy: 84.77
# Batch accuracy: 87.70
# Batch accuracy: 84.38
# Batch accuracy: 82.42
# Batch accuracy: 86.13
# Batch accuracy: 86.13
# Batch accuracy: 84.18
# Batch accuracy: 83.98
# Batch accuracy: 83.40
# Batch accuracy: 85.55
# Batch accuracy: 86.33
# Batch accuracy: 85.94
# Batch accuracy: 87.11
# Batch accuracy: 80.27
# Batch accuracy: 84.96
# Batch accuracy: 84.57
# Batch accuracy: 84.18
# Batch accuracy: 85.48
#   Accuracy: 85.01
# New best model, saving it!
#
# ======== Epoch 2 / 30 ========
# Training...
#   Batch    40  of    975.    .
#   step loss: 0.63
#   Batch    80  of    975.    .
#   step loss: 0.77
#   Batch   120  of    975.    .
#   step loss: 0.71
#   Batch   160  of    975.    .
#   step loss: 0.60
#   Batch   200  of    975.    .
#   step loss: 0.70
#   Batch   240  of    975.    .
#   step loss: 0.51
#   Batch   280  of    975.    .
#   step loss: 0.66
#   Batch   320  of    975.    .
#   step loss: 0.60
#   Batch   360  of    975.    .
#   step loss: 0.55
#   Batch   400  of    975.    .
#   step loss: 0.59
#   Batch   440  of    975.    .
#   step loss: 0.56
#   Batch   480  of    975.    .
#   step loss: 0.54
#   Batch   520  of    975.    .
#   step loss: 0.66
#   Batch   560  of    975.    .
#   step loss: 0.66
#   Batch   600  of    975.    .
#   step loss: 0.53
#   Batch   640  of    975.    .
#   step loss: 0.57
#   Batch   680  of    975.    .
#   step loss: 0.52
#   Batch   720  of    975.    .
#   step loss: 0.69
#   Batch   760  of    975.    .
#   step loss: 0.48
#   Batch   800  of    975.    .
#   step loss: 0.45
#   Batch   840  of    975.    .
#   step loss: 0.66
#   Batch   880  of    975.    .
#   step loss: 0.52
#   Batch   920  of    975.    .
#   step loss: 0.60
#   Batch   960  of    975.    .
#   step loss: 0.48
#
#   Average training loss: 0.60
#
# Running Validation...
# Batch accuracy: 90.23
# Batch accuracy: 88.67
# Batch accuracy: 86.91
# Batch accuracy: 90.82
# Batch accuracy: 88.28
# Batch accuracy: 86.33
# Batch accuracy: 89.84
# Batch accuracy: 89.65
# Batch accuracy: 86.52
# Batch accuracy: 85.94
# Batch accuracy: 88.48
# Batch accuracy: 89.84
# Batch accuracy: 89.26
# Batch accuracy: 90.82
# Batch accuracy: 90.04
# Batch accuracy: 88.09
# Batch accuracy: 89.06
# Batch accuracy: 90.04
# Batch accuracy: 90.04
# Batch accuracy: 88.09
# Batch accuracy: 88.28
# Batch accuracy: 89.84
# Batch accuracy: 87.89
# Batch accuracy: 87.50
# Batch accuracy: 87.30
# Batch accuracy: 91.41
# Batch accuracy: 89.06
# Batch accuracy: 91.80
# Batch accuracy: 89.84
# Batch accuracy: 89.06
# Batch accuracy: 87.50
# Batch accuracy: 91.80
# Batch accuracy: 87.50
# Batch accuracy: 90.62
# Batch accuracy: 84.18
# Batch accuracy: 90.62
# Batch accuracy: 90.04
# Batch accuracy: 89.45
# Batch accuracy: 87.11
# Batch accuracy: 88.48
# Batch accuracy: 88.28
# Batch accuracy: 87.89
# Batch accuracy: 89.84
# Batch accuracy: 87.30
# Batch accuracy: 90.04
# Batch accuracy: 91.02
# Batch accuracy: 89.26
# Batch accuracy: 90.04
# Batch accuracy: 90.23
# Batch accuracy: 87.70
# Batch accuracy: 89.84
# Batch accuracy: 86.72
# Batch accuracy: 89.65
# Batch accuracy: 89.65
# Batch accuracy: 90.04
# Batch accuracy: 87.70
# Batch accuracy: 89.65
# Batch accuracy: 87.89
# Batch accuracy: 89.26
# Batch accuracy: 89.84
# Batch accuracy: 87.30
# Batch accuracy: 88.28
# Batch accuracy: 87.50
# Batch accuracy: 88.48
# Batch accuracy: 90.04
# Batch accuracy: 87.89
# Batch accuracy: 90.82
# Batch accuracy: 89.26
# Batch accuracy: 88.48
# Batch accuracy: 89.84
# Batch accuracy: 88.09
# Batch accuracy: 86.52
# Batch accuracy: 89.84
# Batch accuracy: 89.45
# Batch accuracy: 87.70
# Batch accuracy: 88.28
# Batch accuracy: 88.28
# Batch accuracy: 89.45
# Batch accuracy: 87.89
# Batch accuracy: 88.67
# Batch accuracy: 89.45
# Batch accuracy: 90.23
# Batch accuracy: 89.65
# Batch accuracy: 89.06
# Batch accuracy: 88.48
# Batch accuracy: 88.09
# Batch accuracy: 90.23
# Batch accuracy: 88.67
# Batch accuracy: 89.26
# Batch accuracy: 89.26
# Batch accuracy: 89.06
# Batch accuracy: 90.82
# Batch accuracy: 85.94
# Batch accuracy: 89.65
# Batch accuracy: 89.45
# Batch accuracy: 87.70
# Batch accuracy: 91.60
# Batch accuracy: 86.91
# Batch accuracy: 86.91
# Batch accuracy: 88.09
# Batch accuracy: 88.28
# Batch accuracy: 89.45
# Batch accuracy: 90.62
# Batch accuracy: 91.02
# Batch accuracy: 91.02
# Batch accuracy: 91.02
# Batch accuracy: 91.41
# Batch accuracy: 89.65
# Batch accuracy: 90.32
#   Accuracy: 89.00
# New best model, saving it!
#
# ======== Epoch 3 / 30 ========
# Training...
#   Batch    40  of    975.    .
#   step loss: 0.40
#   Batch    80  of    975.    .
#   step loss: 0.45
#   Batch   120  of    975.    .
#   step loss: 0.42
#   Batch   160  of    975.    .
#   step loss: 0.47
#   Batch   200  of    975.    .
#   step loss: 0.41
#   Batch   240  of    975.    .
#   step loss: 0.44
#   Batch   280  of    975.    .
#   step loss: 0.58
#   Batch   320  of    975.    .
#   step loss: 0.51
#   Batch   360  of    975.    .
#   step loss: 0.39
#   Batch   400  of    975.    .
#   step loss: 0.38
#   Batch   440  of    975.    .
#   step loss: 0.46
#   Batch   480  of    975.    .
#   step loss: 0.42
#   Batch   520  of    975.    .
#   step loss: 0.53
#   Batch   560  of    975.    .
#   step loss: 0.41
#   Batch   600  of    975.    .
#   step loss: 0.37
#   Batch   640  of    975.    .
#   step loss: 0.48
#   Batch   680  of    975.    .
#   step loss: 0.42
#   Batch   720  of    975.    .
#   step loss: 0.36
#   Batch   760  of    975.    .
#   step loss: 0.44
#   Batch   800  of    975.    .
#   step loss: 0.52
#   Batch   840  of    975.    .
#   step loss: 0.43
#   Batch   880  of    975.    .
#   step loss: 0.49
#   Batch   920  of    975.    .
#   step loss: 0.40
#   Batch   960  of    975.    .
#   step loss: 0.39
#
#   Average training loss: 0.44
#
# Running Validation...
# Batch accuracy: 90.43
# Batch accuracy: 90.43
# Batch accuracy: 89.26
# Batch accuracy: 90.82
# Batch accuracy: 90.43
# Batch accuracy: 91.41
# Batch accuracy: 91.41
# Batch accuracy: 92.19
# Batch accuracy: 90.23
# Batch accuracy: 89.06
# Batch accuracy: 89.65
# Batch accuracy: 92.58
# Batch accuracy: 92.97
# Batch accuracy: 90.23
# Batch accuracy: 89.65
# Batch accuracy: 91.80
# Batch accuracy: 90.43
# Batch accuracy: 91.21
# Batch accuracy: 91.60
# Batch accuracy: 89.65
# Batch accuracy: 88.67
# Batch accuracy: 90.04
# Batch accuracy: 90.82
# Batch accuracy: 90.04
# Batch accuracy: 90.23
# Batch accuracy: 89.45
# Batch accuracy: 87.70
# Batch accuracy: 90.82
# Batch accuracy: 87.70
# Batch accuracy: 91.80
# Batch accuracy: 91.02
# Batch accuracy: 89.65
# Batch accuracy: 91.41
# Batch accuracy: 90.62
# Batch accuracy: 89.06
# Batch accuracy: 88.48
# Batch accuracy: 89.65
# Batch accuracy: 89.65
# Batch accuracy: 91.41
# Batch accuracy: 92.77
# Batch accuracy: 91.21
# Batch accuracy: 91.99
# Batch accuracy: 88.48
# Batch accuracy: 91.60
# Batch accuracy: 90.62
# Batch accuracy: 88.28
# Batch accuracy: 88.67
# Batch accuracy: 89.26
# Batch accuracy: 91.99
# Batch accuracy: 91.80
# Batch accuracy: 91.99
# Batch accuracy: 90.82
# Batch accuracy: 89.06
# Batch accuracy: 90.43
# Batch accuracy: 90.23
# Batch accuracy: 90.23
# Batch accuracy: 89.65
# Batch accuracy: 91.21
# Batch accuracy: 92.19
# Batch accuracy: 89.65
# Batch accuracy: 88.67
# Batch accuracy: 90.04
# Batch accuracy: 90.82
# Batch accuracy: 92.97
# Batch accuracy: 90.04
# Batch accuracy: 90.43
# Batch accuracy: 89.06
# Batch accuracy: 89.06
# Batch accuracy: 91.60
# Batch accuracy: 91.02
# Batch accuracy: 91.02
# Batch accuracy: 88.67
# Batch accuracy: 91.02
# Batch accuracy: 92.38
# Batch accuracy: 89.84
# Batch accuracy: 91.99
# Batch accuracy: 86.72
# Batch accuracy: 90.62
# Batch accuracy: 89.65
# Batch accuracy: 91.02
# Batch accuracy: 90.23
# Batch accuracy: 89.45
# Batch accuracy: 91.41
# Batch accuracy: 90.23
# Batch accuracy: 91.02
# Batch accuracy: 91.99
# Batch accuracy: 90.43
# Batch accuracy: 89.45
# Batch accuracy: 87.50
# Batch accuracy: 90.62
# Batch accuracy: 90.43
# Batch accuracy: 88.87
# Batch accuracy: 90.04
# Batch accuracy: 91.41
# Batch accuracy: 92.38
# Batch accuracy: 91.60
# Batch accuracy: 89.45
# Batch accuracy: 89.65
# Batch accuracy: 91.21
# Batch accuracy: 91.21
# Batch accuracy: 89.65
# Batch accuracy: 90.23
# Batch accuracy: 90.62
# Batch accuracy: 88.09
# Batch accuracy: 90.43
# Batch accuracy: 91.02
# Batch accuracy: 93.55
# Batch accuracy: 93.36
# Batch accuracy: 88.71
#   Accuracy: 90.43
# New best model, saving it!
#
# ======== Epoch 4 / 30 ========
# Training...
#   Batch    40  of    975.    .
#   step loss: 0.36
#   Batch    80  of    975.    .
#   step loss: 0.38
#   Batch   120  of    975.    .
#   step loss: 0.29
#   Batch   160  of    975.    .
#   step loss: 0.39
#   Batch   200  of    975.    .
#   step loss: 0.38
#   Batch   240  of    975.    .
#   step loss: 0.40
#   Batch   280  of    975.    .
#   step loss: 0.34
#   Batch   320  of    975.    .
#   step loss: 0.33
#   Batch   360  of    975.    .
#   step loss: 0.30
#   Batch   400  of    975.    .
#   step loss: 0.34
#   Batch   440  of    975.    .
#   step loss: 0.45
#   Batch   480  of    975.    .
#   step loss: 0.40
#   Batch   520  of    975.    .
#   step loss: 0.32
#   Batch   560  of    975.    .
#   step loss: 0.37
#   Batch   600  of    975.    .
#   step loss: 0.42
#   Batch   640  of    975.    .
#   step loss: 0.38
#   Batch   680  of    975.    .
#   step loss: 0.40
#   Batch   720  of    975.    .
#   step loss: 0.30
#   Batch   760  of    975.    .
#   step loss: 0.35
#   Batch   800  of    975.    .
#   step loss: 0.41
#   Batch   840  of    975.    .
#   step loss: 0.28
#   Batch   880  of    975.    .
#   step loss: 0.34
#   Batch   920  of    975.    .
#   step loss: 0.37
#   Batch   960  of    975.    .
#   step loss: 0.40
#
#   Average training loss: 0.36
#
# Running Validation...
# Batch accuracy: 90.62
# Batch accuracy: 90.43
# Batch accuracy: 93.95
# Batch accuracy: 92.77
# Batch accuracy: 90.43
# Batch accuracy: 89.26
# Batch accuracy: 91.02
# Batch accuracy: 89.65
# Batch accuracy: 89.84
# Batch accuracy: 91.99
# Batch accuracy: 90.82
# Batch accuracy: 90.82
# Batch accuracy: 91.02
# Batch accuracy: 90.62
# Batch accuracy: 90.43
# Batch accuracy: 90.04
# Batch accuracy: 90.82
# Batch accuracy: 92.77
# Batch accuracy: 91.99
# Batch accuracy: 91.21
# Batch accuracy: 91.60
# Batch accuracy: 88.87
# Batch accuracy: 91.80
# Batch accuracy: 91.99
# Batch accuracy: 90.43
# Batch accuracy: 91.41
# Batch accuracy: 93.36
# Batch accuracy: 91.80
# Batch accuracy: 89.84
# Batch accuracy: 91.02
# Batch accuracy: 90.82
# Batch accuracy: 91.21
# Batch accuracy: 89.65
# Batch accuracy: 89.06
# Batch accuracy: 91.02
# Batch accuracy: 91.60
# Batch accuracy: 93.16
# Batch accuracy: 91.21
# Batch accuracy: 92.58
# Batch accuracy: 91.02
# Batch accuracy: 90.82
# Batch accuracy: 90.62
# Batch accuracy: 91.02
# Batch accuracy: 90.62
# Batch accuracy: 91.41
# Batch accuracy: 87.50
# Batch accuracy: 90.62
# Batch accuracy: 91.21
# Batch accuracy: 88.48
# Batch accuracy: 91.21
# Batch accuracy: 90.82
# Batch accuracy: 91.21
# Batch accuracy: 91.80
# Batch accuracy: 92.19
# Batch accuracy: 90.04
# Batch accuracy: 90.04
# Batch accuracy: 91.99
# Batch accuracy: 88.87
# Batch accuracy: 91.99
# Batch accuracy: 89.26
# Batch accuracy: 91.60
# Batch accuracy: 89.84
# Batch accuracy: 92.19
# Batch accuracy: 93.36
# Batch accuracy: 88.67
# Batch accuracy: 91.80
# Batch accuracy: 91.02
# Batch accuracy: 91.80
# Batch accuracy: 92.19
# Batch accuracy: 92.19
# Batch accuracy: 90.62
# Batch accuracy: 89.06
# Batch accuracy: 93.36
# Batch accuracy: 91.60
# Batch accuracy: 92.38
# Batch accuracy: 91.60
# Batch accuracy: 93.36
# Batch accuracy: 91.41
# Batch accuracy: 90.04
# Batch accuracy: 88.87
# Batch accuracy: 91.41
# Batch accuracy: 90.43
# Batch accuracy: 90.62
# Batch accuracy: 91.80
# Batch accuracy: 91.41
# Batch accuracy: 88.87
# Batch accuracy: 91.41
# Batch accuracy: 90.23
# Batch accuracy: 90.82
# Batch accuracy: 91.02
# Batch accuracy: 89.45
# Batch accuracy: 90.04
# Batch accuracy: 91.02
# Batch accuracy: 92.77
# Batch accuracy: 89.84
# Batch accuracy: 90.04
# Batch accuracy: 90.62
# Batch accuracy: 90.82
# Batch accuracy: 93.75
# Batch accuracy: 90.43
# Batch accuracy: 91.21
# Batch accuracy: 91.21
# Batch accuracy: 90.04
# Batch accuracy: 88.09
# Batch accuracy: 91.80
# Batch accuracy: 91.60
# Batch accuracy: 92.58
# Batch accuracy: 92.19
# Batch accuracy: 92.74
#   Accuracy: 91.02
# New best model, saving it!
#
# ======== Epoch 5 / 30 ========
# Training...
#   Batch    40  of    975.    .
#   step loss: 0.41
#   Batch    80  of    975.    .
#   step loss: 0.26
#   Batch   120  of    975.    .
#   step loss: 0.33
#   Batch   160  of    975.    .
#   step loss: 0.37
#   Batch   200  of    975.    .
#   step loss: 0.20
#   Batch   240  of    975.    .
#   step loss: 0.27
#   Batch   280  of    975.    .
#   step loss: 0.27
#   Batch   320  of    975.    .
#   step loss: 0.24
#   Batch   360  of    975.    .
#   step loss: 0.27
#   Batch   400  of    975.    .
#   step loss: 0.33
#   Batch   440  of    975.    .
#   step loss: 0.35
#   Batch   480  of    975.    .
#   step loss: 0.32
#   Batch   520  of    975.    .
#   step loss: 0.39
#   Batch   560  of    975.    .
#   step loss: 0.26
#   Batch   600  of    975.    .
#   step loss: 0.29
#   Batch   640  of    975.    .
#   step loss: 0.37
#   Batch   680  of    975.    .
#   step loss: 0.44
#   Batch   720  of    975.    .
#   step loss: 0.26
#   Batch   760  of    975.    .
#   step loss: 0.34
#   Batch   800  of    975.    .
#   step loss: 0.23
#   Batch   840  of    975.    .
#   step loss: 0.29
#   Batch   880  of    975.    .
#   step loss: 0.28
#   Batch   920  of    975.    .
#   step loss: 0.29
#   Batch   960  of    975.    .
#   step loss: 0.35
#
#   Average training loss: 0.31
#
# Running Validation...
# Batch accuracy: 90.82
# Batch accuracy: 92.38
# Batch accuracy: 88.67
# Batch accuracy: 91.60
# Batch accuracy: 91.99
# Batch accuracy: 90.82
# Batch accuracy: 89.45
# Batch accuracy: 90.82
# Batch accuracy: 89.65
# Batch accuracy: 90.04
# Batch accuracy: 90.62
# Batch accuracy: 91.02
# Batch accuracy: 90.43
# Batch accuracy: 91.21
# Batch accuracy: 91.41
# Batch accuracy: 92.19
# Batch accuracy: 92.58
# Batch accuracy: 92.19
# Batch accuracy: 91.80
# Batch accuracy: 89.45
# Batch accuracy: 91.21
# Batch accuracy: 90.82
# Batch accuracy: 91.41
# Batch accuracy: 88.28
# Batch accuracy: 89.84
# Batch accuracy: 92.77
# Batch accuracy: 88.87
# Batch accuracy: 92.77
# Batch accuracy: 90.04
# Batch accuracy: 93.75
# Batch accuracy: 92.19
# Batch accuracy: 91.60
# Batch accuracy: 90.23
# Batch accuracy: 92.58
# Batch accuracy: 91.80
# Batch accuracy: 91.02
# Batch accuracy: 89.84
# Batch accuracy: 89.84
# Batch accuracy: 92.77
# Batch accuracy: 92.19
# Batch accuracy: 90.43
# Batch accuracy: 89.65
# Batch accuracy: 89.65
# Batch accuracy: 93.36
# Batch accuracy: 94.14
# Batch accuracy: 91.60
# Batch accuracy: 90.23
# Batch accuracy: 90.23
# Batch accuracy: 92.77
# Batch accuracy: 91.41
# Batch accuracy: 92.58
# Batch accuracy: 92.77
# Batch accuracy: 89.45
# Batch accuracy: 91.99
# Batch accuracy: 92.77
# Batch accuracy: 91.60
# Batch accuracy: 89.06
# Batch accuracy: 91.99
# Batch accuracy: 89.84
# Batch accuracy: 92.58
# Batch accuracy: 90.82
# Batch accuracy: 92.19
# Batch accuracy: 90.82
# Batch accuracy: 91.80
# Batch accuracy: 91.21
# Batch accuracy: 91.99
# Batch accuracy: 90.62
# Batch accuracy: 91.60
# Batch accuracy: 90.23
# Batch accuracy: 91.41
# Batch accuracy: 90.82
# Batch accuracy: 91.80
# Batch accuracy: 89.45
# Batch accuracy: 88.48
# Batch accuracy: 89.84
# Batch accuracy: 92.58
# Batch accuracy: 90.82
# Batch accuracy: 92.19
# Batch accuracy: 93.36
# Batch accuracy: 91.99
# Batch accuracy: 89.65
# Batch accuracy: 90.43
# Batch accuracy: 89.84
# Batch accuracy: 91.60
# Batch accuracy: 90.04
# Batch accuracy: 90.43
# Batch accuracy: 90.43
# Batch accuracy: 91.21
# Batch accuracy: 93.75
# Batch accuracy: 90.82
# Batch accuracy: 92.19
# Batch accuracy: 92.19
# Batch accuracy: 91.41
# Batch accuracy: 91.60
# Batch accuracy: 90.62
# Batch accuracy: 91.41
# Batch accuracy: 89.84
# Batch accuracy: 92.97
# Batch accuracy: 92.19
# Batch accuracy: 89.84
# Batch accuracy: 91.80
# Batch accuracy: 90.62
# Batch accuracy: 91.21
# Batch accuracy: 91.21
# Batch accuracy: 91.02
# Batch accuracy: 92.38
# Batch accuracy: 91.60
# Batch accuracy: 92.19
# Batch accuracy: 95.97
#   Accuracy: 91.24
# New best model, saving it!
#
# ======== Epoch 6 / 30 ========
# Training...
#   Batch    40  of    975.    .
#   step loss: 0.18
#   Batch    80  of    975.    .
#   step loss: 0.33
#   Batch   120  of    975.    .
#   step loss: 0.31
#   Batch   160  of    975.    .
#   step loss: 0.26
#   Batch   200  of    975.    .
#   step loss: 0.24
#   Batch   240  of    975.    .
#   step loss: 0.33
#   Batch   280  of    975.    .
#   step loss: 0.30
#   Batch   320  of    975.    .
#   step loss: 0.22
#   Batch   360  of    975.    .
#   step loss: 0.28
#   Batch   400  of    975.    .
#   step loss: 0.28
#   Batch   440  of    975.    .
#   step loss: 0.25
#   Batch   480  of    975.    .
#   step loss: 0.29
#   Batch   520  of    975.    .
#   step loss: 0.30
#   Batch   560  of    975.    .
#   step loss: 0.23
#   Batch   600  of    975.    .
#   step loss: 0.22
#   Batch   640  of    975.    .
#   step loss: 0.24
#   Batch   680  of    975.    .
#   step loss: 0.36
#   Batch   720  of    975.    .
#   step loss: 0.25
#   Batch   760  of    975.    .
#   step loss: 0.26
#   Batch   800  of    975.    .
#   step loss: 0.28
#   Batch   840  of    975.    .
#   step loss: 0.35
#   Batch   880  of    975.    .
#   step loss: 0.30
#   Batch   920  of    975.    .
#   step loss: 0.26
#   Batch   960  of    975.    .
#   step loss: 0.28
#
#   Average training loss: 0.28
#
# Running Validation...
# Batch accuracy: 92.58
# Batch accuracy: 90.04
# Batch accuracy: 90.23
# Batch accuracy: 92.58
# Batch accuracy: 91.21
# Batch accuracy: 93.55
# Batch accuracy: 91.02
# Batch accuracy: 92.38
# Batch accuracy: 89.84
# Batch accuracy: 90.04
# Batch accuracy: 89.45
# Batch accuracy: 93.95
# Batch accuracy: 93.95
# Batch accuracy: 93.75
# Batch accuracy: 93.36
# Batch accuracy: 91.41
# Batch accuracy: 90.23
# Batch accuracy: 91.41
# Batch accuracy: 91.99
# Batch accuracy: 91.02
# Batch accuracy: 89.65
# Batch accuracy: 92.97
# Batch accuracy: 92.38
# Batch accuracy: 91.99
# Batch accuracy: 88.67
# Batch accuracy: 91.02
# Batch accuracy: 90.62
# Batch accuracy: 90.43
# Batch accuracy: 91.41
# Batch accuracy: 94.34
# Batch accuracy: 93.16
# Batch accuracy: 91.41
# Batch accuracy: 90.62
# Batch accuracy: 91.41
# Batch accuracy: 92.97
# Batch accuracy: 91.02
# Batch accuracy: 90.23
# Batch accuracy: 92.38
# Batch accuracy: 91.02
# Batch accuracy: 91.60
# Batch accuracy: 92.77
# Batch accuracy: 92.38
# Batch accuracy: 91.80
# Batch accuracy: 91.99
# Batch accuracy: 91.99
# Batch accuracy: 91.99
# Batch accuracy: 89.45
# Batch accuracy: 88.67
# Batch accuracy: 93.16
# Batch accuracy: 90.62
# Batch accuracy: 91.80
# Batch accuracy: 90.04
# Batch accuracy: 91.21
# Batch accuracy: 90.04
# Batch accuracy: 91.60
# Batch accuracy: 91.21
# Batch accuracy: 88.48
# Batch accuracy: 90.62
# Batch accuracy: 91.41
# Batch accuracy: 91.02
# Batch accuracy: 91.80
# Batch accuracy: 91.41
# Batch accuracy: 91.80
# Batch accuracy: 90.82
# Batch accuracy: 92.38
# Batch accuracy: 91.02
# Batch accuracy: 91.60
# Batch accuracy: 93.55
# Batch accuracy: 91.60
# Batch accuracy: 92.58
# Batch accuracy: 91.99
# Batch accuracy: 91.02
# Batch accuracy: 93.95
# Batch accuracy: 90.82
# Batch accuracy: 91.41
# Batch accuracy: 90.23
# Batch accuracy: 90.62
# Batch accuracy: 94.92
# Batch accuracy: 90.43
# Batch accuracy: 93.16
# Batch accuracy: 91.41
# Batch accuracy: 92.38
# Batch accuracy: 93.16
# Batch accuracy: 91.41
# Batch accuracy: 92.38
# Batch accuracy: 89.65
# Batch accuracy: 91.99
# Batch accuracy: 90.43
# Batch accuracy: 92.38
# Batch accuracy: 90.43
# Batch accuracy: 91.99
# Batch accuracy: 93.55
# Batch accuracy: 92.58
# Batch accuracy: 90.23
# Batch accuracy: 92.77
# Batch accuracy: 92.38
# Batch accuracy: 93.16
# Batch accuracy: 90.82
# Batch accuracy: 90.62
# Batch accuracy: 90.82
# Batch accuracy: 92.58
# Batch accuracy: 92.38
# Batch accuracy: 91.41
# Batch accuracy: 91.02
# Batch accuracy: 90.62
# Batch accuracy: 91.80
# Batch accuracy: 90.43
# Batch accuracy: 92.38
# Batch accuracy: 91.13
#   Accuracy: 91.57
# New best model, saving it!
#
# ======== Epoch 7 / 30 ========
# Training...
#   Batch    40  of    975.    .
#   step loss: 0.22
#   Batch    80  of    975.    .
#   step loss: 0.16
#   Batch   120  of    975.    .
#   step loss: 0.23
#   Batch   160  of    975.    .
#   step loss: 0.28
#   Batch   200  of    975.    .
#   step loss: 0.23
#   Batch   240  of    975.    .
#   step loss: 0.20
#   Batch   280  of    975.    .
#   step loss: 0.23
#   Batch   320  of    975.    .
#   step loss: 0.30
#   Batch   360  of    975.    .
#   step loss: 0.22
#   Batch   400  of    975.    .
#   step loss: 0.25
#   Batch   440  of    975.    .
#   step loss: 0.29
#   Batch   480  of    975.    .
#   step loss: 0.35
#   Batch   520  of    975.    .
#   step loss: 0.26
#   Batch   560  of    975.    .
#   step loss: 0.22
#   Batch   600  of    975.    .
#   step loss: 0.32
#   Batch   640  of    975.    .
#   step loss: 0.19
#   Batch   680  of    975.    .
#   step loss: 0.22
#   Batch   720  of    975.    .
#   step loss: 0.19
#   Batch   760  of    975.    .
#   step loss: 0.32
#   Batch   800  of    975.    .
#   step loss: 0.23
#   Batch   840  of    975.    .
#   step loss: 0.27
#   Batch   880  of    975.    .
#   step loss: 0.25
#   Batch   920  of    975.    .
#   step loss: 0.24
#   Batch   960  of    975.    .
#   step loss: 0.19
#
#   Average training loss: 0.25
#
# Running Validation...
# Batch accuracy: 91.99
# Batch accuracy: 92.19
# Batch accuracy: 91.21
# Batch accuracy: 92.97
# Batch accuracy: 92.38
# Batch accuracy: 90.23
# Batch accuracy: 91.99
# Batch accuracy: 89.26
# Batch accuracy: 93.95
# Batch accuracy: 91.02
# Batch accuracy: 91.21
# Batch accuracy: 90.82
# Batch accuracy: 94.53
# Batch accuracy: 90.23
# Batch accuracy: 90.04
# Batch accuracy: 93.55
# Batch accuracy: 91.02
# Batch accuracy: 91.02
# Batch accuracy: 91.60
# Batch accuracy: 90.82
# Batch accuracy: 91.21
# Batch accuracy: 90.82
# Batch accuracy: 90.43
# Batch accuracy: 90.43
# Batch accuracy: 90.04
# Batch accuracy: 92.77
# Batch accuracy: 92.58
# Batch accuracy: 90.23
# Batch accuracy: 92.19
# Batch accuracy: 93.36
# Batch accuracy: 94.14
# Batch accuracy: 93.16
# Batch accuracy: 90.62
# Batch accuracy: 92.38
# Batch accuracy: 92.38
# Batch accuracy: 91.60
# Batch accuracy: 91.21
# Batch accuracy: 91.21
# Batch accuracy: 94.34
# Batch accuracy: 92.38
# Batch accuracy: 92.97
# Batch accuracy: 90.23
# Batch accuracy: 91.02
# Batch accuracy: 90.43
# Batch accuracy: 89.45
# Batch accuracy: 89.84
# Batch accuracy: 92.38
# Batch accuracy: 93.75
# Batch accuracy: 91.41
# Batch accuracy: 91.80
# Batch accuracy: 93.55
# Batch accuracy: 93.55
# Batch accuracy: 93.16
# Batch accuracy: 90.43
# Batch accuracy: 91.41
# Batch accuracy: 91.41
# Batch accuracy: 89.06
# Batch accuracy: 91.60
# Batch accuracy: 92.19
# Batch accuracy: 92.97
# Batch accuracy: 91.80
# Batch accuracy: 91.99
# Batch accuracy: 90.04
# Batch accuracy: 91.80
# Batch accuracy: 91.21
# Batch accuracy: 91.99
# Batch accuracy: 91.21
# Batch accuracy: 90.62
# Batch accuracy: 90.62
# Batch accuracy: 89.84
# Batch accuracy: 89.45
# Batch accuracy: 92.58
# Batch accuracy: 90.04
# Batch accuracy: 94.14
# Batch accuracy: 92.38
# Batch accuracy: 92.19
# Batch accuracy: 93.16
# Batch accuracy: 91.41
# Batch accuracy: 93.95
# Batch accuracy: 89.84
# Batch accuracy: 91.21
# Batch accuracy: 91.99
# Batch accuracy: 92.77
# Batch accuracy: 93.55
# Batch accuracy: 91.60
# Batch accuracy: 93.75
# Batch accuracy: 92.19
# Batch accuracy: 93.36
# Batch accuracy: 87.70
# Batch accuracy: 90.23
# Batch accuracy: 91.99
# Batch accuracy: 91.41
# Batch accuracy: 91.02
# Batch accuracy: 92.19
# Batch accuracy: 93.16
# Batch accuracy: 91.60
# Batch accuracy: 91.80
# Batch accuracy: 92.97
# Batch accuracy: 90.43
# Batch accuracy: 89.84
# Batch accuracy: 93.36
# Batch accuracy: 91.99
# Batch accuracy: 91.60
# Batch accuracy: 91.80
# Batch accuracy: 88.87
# Batch accuracy: 92.77
# Batch accuracy: 91.02
# Batch accuracy: 92.58
# Batch accuracy: 93.55
#   Accuracy: 91.69
# New best model, saving it!
#
# ======== Epoch 8 / 30 ========
# Training...
#   Batch    40  of    975.    .
#   step loss: 0.18
#   Batch    80  of    975.    .
#   step loss: 0.21
#   Batch   120  of    975.    .
#   step loss: 0.23
#   Batch   160  of    975.    .
#   step loss: 0.17
#   Batch   200  of    975.    .
#   step loss: 0.25
#   Batch   240  of    975.    .
#   step loss: 0.18
#   Batch   280  of    975.    .
#   step loss: 0.13
#   Batch   320  of    975.    .
#   step loss: 0.23
#   Batch   360  of    975.    .
#   step loss: 0.25
#   Batch   400  of    975.    .
#   step loss: 0.26
#   Batch   440  of    975.    .
#   step loss: 0.26
#   Batch   480  of    975.    .
#   step loss: 0.26
#   Batch   520  of    975.    .
#   step loss: 0.26
#   Batch   560  of    975.    .
#   step loss: 0.25
#   Batch   600  of    975.    .
#   step loss: 0.23
#   Batch   640  of    975.    .
#   step loss: 0.21
#   Batch   680  of    975.    .
#   step loss: 0.30
#   Batch   720  of    975.    .
#   step loss: 0.25
#   Batch   760  of    975.    .
#   step loss: 0.23
#   Batch   800  of    975.    .
#   step loss: 0.33
#   Batch   840  of    975.    .
#   step loss: 0.27
#   Batch   880  of    975.    .
#   step loss: 0.28
#   Batch   920  of    975.    .
#   step loss: 0.19
#   Batch   960  of    975.    .
#   step loss: 0.27
#
#   Average training loss: 0.23
#
# Running Validation...
# Batch accuracy: 93.75
# Batch accuracy: 93.75
# Batch accuracy: 91.80
# Batch accuracy: 92.97
# Batch accuracy: 93.16
# Batch accuracy: 92.38
# Batch accuracy: 90.04
# Batch accuracy: 90.43
# Batch accuracy: 90.43
# Batch accuracy: 89.84
# Batch accuracy: 93.16
# Batch accuracy: 91.02
# Batch accuracy: 91.21
# Batch accuracy: 89.84
# Batch accuracy: 90.82
# Batch accuracy: 92.38
# Batch accuracy: 91.60
# Batch accuracy: 91.80
# Batch accuracy: 92.77
# Batch accuracy: 91.80
# Batch accuracy: 88.48
# Batch accuracy: 92.58
# Batch accuracy: 91.41
# Batch accuracy: 89.26
# Batch accuracy: 91.60
# Batch accuracy: 90.62
# Batch accuracy: 92.19
# Batch accuracy: 91.60
# Batch accuracy: 91.21
# Batch accuracy: 91.80
# Batch accuracy: 91.60
# Batch accuracy: 90.82
# Batch accuracy: 92.97
# Batch accuracy: 89.45
# Batch accuracy: 93.36
# Batch accuracy: 91.99
# Batch accuracy: 91.80
# Batch accuracy: 94.53
# Batch accuracy: 91.99
# Batch accuracy: 91.21
# Batch accuracy: 91.21
# Batch accuracy: 91.60
# Batch accuracy: 91.21
# Batch accuracy: 91.80
# Batch accuracy: 90.43
# Batch accuracy: 92.19
# Batch accuracy: 91.80
# Batch accuracy: 89.84
# Batch accuracy: 91.60
# Batch accuracy: 90.82
# Batch accuracy: 93.36
# Batch accuracy: 92.38
# Batch accuracy: 92.97
# Batch accuracy: 93.36
# Batch accuracy: 90.23
# Batch accuracy: 93.55
# Batch accuracy: 91.99
# Batch accuracy: 91.60
# Batch accuracy: 92.38
# Batch accuracy: 91.99
# Batch accuracy: 91.80
# Batch accuracy: 91.99
# Batch accuracy: 92.19
# Batch accuracy: 92.97
# Batch accuracy: 92.19
# Batch accuracy: 90.04
# Batch accuracy: 89.84
# Batch accuracy: 91.80
# Batch accuracy: 92.38
# Batch accuracy: 91.99
# Batch accuracy: 88.48
# Batch accuracy: 92.58
# Batch accuracy: 91.21
# Batch accuracy: 90.82
# Batch accuracy: 91.99
# Batch accuracy: 90.23
# Batch accuracy: 91.21
# Batch accuracy: 90.04
# Batch accuracy: 92.38
# Batch accuracy: 91.99
# Batch accuracy: 91.21
# Batch accuracy: 93.75
# Batch accuracy: 91.02
# Batch accuracy: 89.45
# Batch accuracy: 90.62
# Batch accuracy: 93.16
# Batch accuracy: 89.65
# Batch accuracy: 91.02
# Batch accuracy: 91.41
# Batch accuracy: 93.16
# Batch accuracy: 91.80
# Batch accuracy: 91.41
# Batch accuracy: 92.19
# Batch accuracy: 91.21
# Batch accuracy: 93.55
# Batch accuracy: 91.41
# Batch accuracy: 91.41
# Batch accuracy: 90.43
# Batch accuracy: 92.38
# Batch accuracy: 92.19
# Batch accuracy: 90.82
# Batch accuracy: 91.99
# Batch accuracy: 93.36
# Batch accuracy: 92.38
# Batch accuracy: 90.82
# Batch accuracy: 91.80
# Batch accuracy: 92.19
# Batch accuracy: 91.60
# Batch accuracy: 91.94
#   Accuracy: 91.64
# The model does not improve for 1 epochs!
#
# ======== Epoch 9 / 30 ========
# Training...
#   Batch    40  of    975.    .
#   step loss: 0.25
#   Batch    80  of    975.    .
#   step loss: 0.19
#   Batch   120  of    975.    .
#   step loss: 0.23
#   Batch   160  of    975.    .
#   step loss: 0.28
#   Batch   200  of    975.    .
#   step loss: 0.19
#   Batch   240  of    975.    .
#   step loss: 0.19
#   Batch   280  of    975.    .
#   step loss: 0.18
#   Batch   320  of    975.    .
#   step loss: 0.17
#   Batch   360  of    975.    .
#   step loss: 0.21
#   Batch   400  of    975.    .
#   step loss: 0.23
#   Batch   440  of    975.    .
#   step loss: 0.26
#   Batch   480  of    975.    .
#   step loss: 0.25
#   Batch   520  of    975.    .
#   step loss: 0.20
#   Batch   560  of    975.    .
#   step loss: 0.25
#   Batch   600  of    975.    .
#   step loss: 0.23
#   Batch   640  of    975.    .
#   step loss: 0.23
#   Batch   680  of    975.    .
#   step loss: 0.16
#   Batch   720  of    975.    .
#   step loss: 0.20
#   Batch   760  of    975.    .
#   step loss: 0.24
#   Batch   800  of    975.    .
#   step loss: 0.19
#   Batch   840  of    975.    .
#   step loss: 0.16
#   Batch   880  of    975.    .
#   step loss: 0.19
#   Batch   920  of    975.    .
#   step loss: 0.27
#   Batch   960  of    975.    .
#   step loss: 0.19
#
#   Average training loss: 0.21
#
# Running Validation...
# Batch accuracy: 91.99
# Batch accuracy: 91.21
# Batch accuracy: 91.21
# Batch accuracy: 92.58
# Batch accuracy: 92.77
# Batch accuracy: 91.41
# Batch accuracy: 89.26
# Batch accuracy: 93.16
# Batch accuracy: 91.02
# Batch accuracy: 91.60
# Batch accuracy: 91.80
# Batch accuracy: 93.36
# Batch accuracy: 92.97
# Batch accuracy: 92.97
# Batch accuracy: 92.38
# Batch accuracy: 89.45
# Batch accuracy: 90.62
# Batch accuracy: 92.97
# Batch accuracy: 94.34
# Batch accuracy: 91.99
# Batch accuracy: 92.77
# Batch accuracy: 91.60
# Batch accuracy: 91.99
# Batch accuracy: 86.91
# Batch accuracy: 90.43
# Batch accuracy: 92.58
# Batch accuracy: 92.19
# Batch accuracy: 89.84
# Batch accuracy: 92.19
# Batch accuracy: 92.58
# Batch accuracy: 91.60
# Batch accuracy: 90.23
# Batch accuracy: 92.19
# Batch accuracy: 90.82
# Batch accuracy: 90.43
# Batch accuracy: 90.62
# Batch accuracy: 91.80
# Batch accuracy: 93.16
# Batch accuracy: 91.41
# Batch accuracy: 92.58
# Batch accuracy: 92.97
# Batch accuracy: 91.99
# Batch accuracy: 91.02
# Batch accuracy: 90.23
# Batch accuracy: 89.45
# Batch accuracy: 91.99
# Batch accuracy: 90.23
# Batch accuracy: 91.60
# Batch accuracy: 92.38
# Batch accuracy: 91.99
# Batch accuracy: 91.02
# Batch accuracy: 92.58
# Batch accuracy: 91.99
# Batch accuracy: 89.65
# Batch accuracy: 91.02
# Batch accuracy: 91.02
# Batch accuracy: 93.36
# Batch accuracy: 91.60
# Batch accuracy: 91.02
# Batch accuracy: 92.58
# Batch accuracy: 92.58
# Batch accuracy: 94.14
# Batch accuracy: 92.77
# Batch accuracy: 92.97
# Batch accuracy: 90.43
# Batch accuracy: 90.23
# Batch accuracy: 91.41
# Batch accuracy: 91.21
# Batch accuracy: 91.80
# Batch accuracy: 91.60
# Batch accuracy: 88.87
# Batch accuracy: 92.19
# Batch accuracy: 90.43
# Batch accuracy: 95.12
# Batch accuracy: 89.06
# Batch accuracy: 93.95
# Batch accuracy: 92.38
# Batch accuracy: 91.60
# Batch accuracy: 90.62
# Batch accuracy: 93.55
# Batch accuracy: 92.58
# Batch accuracy: 92.19
# Batch accuracy: 93.36
# Batch accuracy: 94.14
# Batch accuracy: 92.97
# Batch accuracy: 93.75
# Batch accuracy: 91.41
# Batch accuracy: 89.84
# Batch accuracy: 91.41
# Batch accuracy: 90.04
# Batch accuracy: 92.58
# Batch accuracy: 90.62
# Batch accuracy: 92.58
# Batch accuracy: 91.02
# Batch accuracy: 91.02
# Batch accuracy: 92.19
# Batch accuracy: 92.77
# Batch accuracy: 91.21
# Batch accuracy: 91.80
# Batch accuracy: 92.58
# Batch accuracy: 92.19
# Batch accuracy: 94.53
# Batch accuracy: 92.58
# Batch accuracy: 91.02
# Batch accuracy: 92.19
# Batch accuracy: 92.97
# Batch accuracy: 91.41
# Batch accuracy: 91.21
# Batch accuracy: 89.52
#   Accuracy: 91.75
# New best model, saving it!
#
# ======== Epoch 10 / 30 ========
# Training...
#   Batch    40  of    975.    .
#   step loss: 0.14
#   Batch    80  of    975.    .
#   step loss: 0.13
#   Batch   120  of    975.    .
#   step loss: 0.12
#   Batch   160  of    975.    .
#   step loss: 0.19
#   Batch   200  of    975.    .
#   step loss: 0.19
#   Batch   240  of    975.    .
#   step loss: 0.21
#   Batch   280  of    975.    .
#   step loss: 0.11
#   Batch   320  of    975.    .
#   step loss: 0.21
#   Batch   360  of    975.    .
#   step loss: 0.19
#   Batch   400  of    975.    .
#   step loss: 0.21
#   Batch   440  of    975.    .
#   step loss: 0.23
#   Batch   480  of    975.    .
#   step loss: 0.21
#   Batch   520  of    975.    .
#   step loss: 0.19
#   Batch   560  of    975.    .
#   step loss: 0.28
#   Batch   600  of    975.    .
#   step loss: 0.15
#   Batch   640  of    975.    .
#   step loss: 0.16
#   Batch   680  of    975.    .
#   step loss: 0.22
#   Batch   720  of    975.    .
#   step loss: 0.18
#   Batch   760  of    975.    .
#   step loss: 0.19
#   Batch   800  of    975.    .
#   step loss: 0.21
#   Batch   840  of    975.    .
#   step loss: 0.16
#   Batch   880  of    975.    .
#   step loss: 0.27
#   Batch   920  of    975.    .
#   step loss: 0.21
#   Batch   960  of    975.    .
#   step loss: 0.24
#
#   Average training loss: 0.19
#
# Running Validation...
# Batch accuracy: 92.58
# Batch accuracy: 91.41
# Batch accuracy: 91.21
# Batch accuracy: 92.77
# Batch accuracy: 92.19
# Batch accuracy: 91.99
# Batch accuracy: 93.36
# Batch accuracy: 91.21
# Batch accuracy: 91.80
# Batch accuracy: 91.80
# Batch accuracy: 92.38
# Batch accuracy: 92.97
# Batch accuracy: 94.53
# Batch accuracy: 92.19
# Batch accuracy: 91.99
# Batch accuracy: 92.38
# Batch accuracy: 91.41
# Batch accuracy: 91.80
# Batch accuracy: 92.77
# Batch accuracy: 92.38
# Batch accuracy: 91.60
# Batch accuracy: 92.58
# Batch accuracy: 93.36
# Batch accuracy: 90.62
# Batch accuracy: 90.43
# Batch accuracy: 91.41
# Batch accuracy: 91.60
# Batch accuracy: 91.02
# Batch accuracy: 91.02
# Batch accuracy: 91.80
# Batch accuracy: 90.82
# Batch accuracy: 92.19
# Batch accuracy: 91.99
# Batch accuracy: 93.36
# Batch accuracy: 91.60
# Batch accuracy: 91.80
# Batch accuracy: 91.21
# Batch accuracy: 90.04
# Batch accuracy: 92.19
# Batch accuracy: 92.97
# Batch accuracy: 91.80
# Batch accuracy: 92.38
# Batch accuracy: 91.60
# Batch accuracy: 90.04
# Batch accuracy: 93.16
# Batch accuracy: 91.02
# Batch accuracy: 91.99
# Batch accuracy: 90.43
# Batch accuracy: 90.62
# Batch accuracy: 92.77
# Batch accuracy: 91.99
# Batch accuracy: 91.41
# Batch accuracy: 91.60
# Batch accuracy: 91.41
# Batch accuracy: 91.80
# Batch accuracy: 91.41
# Batch accuracy: 91.02
# Batch accuracy: 93.36
# Batch accuracy: 91.80
# Batch accuracy: 90.23
# Batch accuracy: 91.80
# Batch accuracy: 91.41
# Batch accuracy: 93.95
# Batch accuracy: 92.58
# Batch accuracy: 91.21
# Batch accuracy: 93.75
# Batch accuracy: 90.82
# Batch accuracy: 92.38
# Batch accuracy: 92.19
# Batch accuracy: 90.82
# Batch accuracy: 91.41
# Batch accuracy: 90.04
# Batch accuracy: 91.99
# Batch accuracy: 90.62
# Batch accuracy: 91.02
# Batch accuracy: 91.99
# Batch accuracy: 92.97
# Batch accuracy: 91.60
# Batch accuracy: 91.80
# Batch accuracy: 93.55
# Batch accuracy: 90.04
# Batch accuracy: 92.38
# Batch accuracy: 91.60
# Batch accuracy: 93.16
# Batch accuracy: 90.62
# Batch accuracy: 89.65
# Batch accuracy: 91.99
# Batch accuracy: 91.21
# Batch accuracy: 93.16
# Batch accuracy: 91.41
# Batch accuracy: 89.65
# Batch accuracy: 92.19
# Batch accuracy: 92.97
# Batch accuracy: 93.95
# Batch accuracy: 90.43
# Batch accuracy: 91.21
# Batch accuracy: 92.58
# Batch accuracy: 92.97
# Batch accuracy: 92.19
# Batch accuracy: 94.34
# Batch accuracy: 91.02
# Batch accuracy: 90.62
# Batch accuracy: 91.02
# Batch accuracy: 91.21
# Batch accuracy: 92.19
# Batch accuracy: 92.58
# Batch accuracy: 91.41
# Batch accuracy: 93.36
# Batch accuracy: 94.35
#   Accuracy: 91.87
# New best model, saving it!
#
# ======== Epoch 11 / 30 ========
# Training...
#   Batch    40  of    975.    .
#   step loss: 0.14
#   Batch    80  of    975.    .
#   step loss: 0.21
#   Batch   120  of    975.    .
#   step loss: 0.21
#   Batch   160  of    975.    .
#   step loss: 0.17
#   Batch   200  of    975.    .
#   step loss: 0.24
#   Batch   240  of    975.    .
#   step loss: 0.14
#   Batch   280  of    975.    .
#   step loss: 0.17
#   Batch   320  of    975.    .
#   step loss: 0.14
#   Batch   360  of    975.    .
#   step loss: 0.20
#   Batch   400  of    975.    .
#   step loss: 0.15
#   Batch   440  of    975.    .
#   step loss: 0.17
#   Batch   480  of    975.    .
#   step loss: 0.17
#   Batch   520  of    975.    .
#   step loss: 0.20
#   Batch   560  of    975.    .
#   step loss: 0.16
#   Batch   600  of    975.    .
#   step loss: 0.15
#   Batch   640  of    975.    .
#   step loss: 0.17
#   Batch   680  of    975.    .
#   step loss: 0.14
#   Batch   720  of    975.    .
#   step loss: 0.19
#   Batch   760  of    975.    .
#   step loss: 0.18
#   Batch   800  of    975.    .
#   step loss: 0.16
#   Batch   840  of    975.    .
#   step loss: 0.15
#   Batch   880  of    975.    .
#   step loss: 0.14
#   Batch   920  of    975.    .
#   step loss: 0.16
#   Batch   960  of    975.    .
#   step loss: 0.20
#
#   Average training loss: 0.18
#
# Running Validation...
# Batch accuracy: 91.60
# Batch accuracy: 92.19
# Batch accuracy: 93.36
# Batch accuracy: 90.62
# Batch accuracy: 90.23
# Batch accuracy: 92.58
# Batch accuracy: 91.02
# Batch accuracy: 92.19
# Batch accuracy: 92.38
# Batch accuracy: 92.38
# Batch accuracy: 91.21
# Batch accuracy: 91.99
# Batch accuracy: 92.19
# Batch accuracy: 92.19
# Batch accuracy: 93.75
# Batch accuracy: 89.84
# Batch accuracy: 93.95
# Batch accuracy: 92.58
# Batch accuracy: 91.80
# Batch accuracy: 91.99
# Batch accuracy: 91.41
# Batch accuracy: 91.60
# Batch accuracy: 91.99
# Batch accuracy: 90.43
# Batch accuracy: 92.77
# Batch accuracy: 91.02
# Batch accuracy: 92.38
# Batch accuracy: 92.19
# Batch accuracy: 89.45
# Batch accuracy: 92.77
# Batch accuracy: 93.75
# Batch accuracy: 91.21
# Batch accuracy: 90.43
# Batch accuracy: 92.77
# Batch accuracy: 93.55
# Batch accuracy: 92.77
# Batch accuracy: 91.41
# Batch accuracy: 92.97
# Batch accuracy: 92.58
# Batch accuracy: 92.97
# Batch accuracy: 93.55
# Batch accuracy: 93.55
# Batch accuracy: 91.60
# Batch accuracy: 91.99
# Batch accuracy: 91.21
# Batch accuracy: 91.41
# Batch accuracy: 92.19
# Batch accuracy: 94.53
# Batch accuracy: 90.43
# Batch accuracy: 92.38
# Batch accuracy: 90.82
# Batch accuracy: 93.55
# Batch accuracy: 89.84
# Batch accuracy: 91.99
# Batch accuracy: 94.92
# Batch accuracy: 93.16
# Batch accuracy: 91.99
# Batch accuracy: 91.41
# Batch accuracy: 90.04
# Batch accuracy: 92.19
# Batch accuracy: 91.02
# Batch accuracy: 91.02
# Batch accuracy: 91.80
# Batch accuracy: 93.36
# Batch accuracy: 91.60
# Batch accuracy: 92.77
# Batch accuracy: 90.04
# Batch accuracy: 92.77
# Batch accuracy: 89.65
# Batch accuracy: 92.97
# Batch accuracy: 90.43
# Batch accuracy: 91.99
# Batch accuracy: 91.60
# Batch accuracy: 92.38
# Batch accuracy: 89.45
# Batch accuracy: 91.41
# Batch accuracy: 90.23
# Batch accuracy: 92.19
# Batch accuracy: 91.41
# Batch accuracy: 89.26
# Batch accuracy: 91.21
# Batch accuracy: 91.41
# Batch accuracy: 89.84
# Batch accuracy: 91.41
# Batch accuracy: 90.23
# Batch accuracy: 91.60
# Batch accuracy: 91.99
# Batch accuracy: 90.43
# Batch accuracy: 92.77
# Batch accuracy: 90.62
# Batch accuracy: 92.77
# Batch accuracy: 92.19
# Batch accuracy: 92.19
# Batch accuracy: 92.58
# Batch accuracy: 92.58
# Batch accuracy: 90.62
# Batch accuracy: 93.16
# Batch accuracy: 91.21
# Batch accuracy: 91.60
# Batch accuracy: 94.53
# Batch accuracy: 90.43
# Batch accuracy: 91.99
# Batch accuracy: 91.99
# Batch accuracy: 91.80
# Batch accuracy: 91.02
# Batch accuracy: 91.02
# Batch accuracy: 90.43
# Batch accuracy: 93.75
# Batch accuracy: 91.13
#   Accuracy: 91.83
# The model does not improve for 1 epochs!
# Epoch    11: reducing learning rate of group 0 to 1.0000e-04.
#
# ======== Epoch 12 / 30 ========
# Training...
#   Batch    40  of    975.    .
#   step loss: 0.10
#   Batch    80  of    975.    .
#   step loss: 0.12
#   Batch   120  of    975.    .
#   step loss: 0.14
#   Batch   160  of    975.    .
#   step loss: 0.14
#   Batch   200  of    975.    .
#   step loss: 0.21
#   Batch   240  of    975.    .
#   step loss: 0.10
#   Batch   280  of    975.    .
#   step loss: 0.14
#   Batch   320  of    975.    .
#   step loss: 0.18
#   Batch   360  of    975.    .
#   step loss: 0.10
#   Batch   400  of    975.    .
#   step loss: 0.14
#   Batch   440  of    975.    .
#   step loss: 0.11
#   Batch   480  of    975.    .
#   step loss: 0.14
#   Batch   520  of    975.    .
#   step loss: 0.10
#   Batch   560  of    975.    .
#   step loss: 0.12
#   Batch   600  of    975.    .
#   step loss: 0.11
#   Batch   640  of    975.    .
#   step loss: 0.09
#   Batch   680  of    975.    .
#   step loss: 0.15
#   Batch   720  of    975.    .
#   step loss: 0.14
#   Batch   760  of    975.    .
#   step loss: 0.16
#   Batch   800  of    975.    .
#   step loss: 0.12
#   Batch   840  of    975.    .
#   step loss: 0.16
#   Batch   880  of    975.    .
#   step loss: 0.12
#   Batch   920  of    975.    .
#   step loss: 0.12
#   Batch   960  of    975.    .
#   step loss: 0.06
#
#   Average training loss: 0.13
#
# Running Validation...
# Batch accuracy: 93.36
# Batch accuracy: 91.99
# Batch accuracy: 91.99
# Batch accuracy: 91.99
# Batch accuracy: 91.02
# Batch accuracy: 91.60
# Batch accuracy: 92.58
# Batch accuracy: 91.60
# Batch accuracy: 90.43
# Batch accuracy: 91.60
# Batch accuracy: 92.19
# Batch accuracy: 91.99
# Batch accuracy: 92.97
# Batch accuracy: 91.60
# Batch accuracy: 92.77
# Batch accuracy: 91.21
# Batch accuracy: 91.41
# Batch accuracy: 92.19
# Batch accuracy: 93.36
# Batch accuracy: 92.97
# Batch accuracy: 92.58
# Batch accuracy: 94.53
# Batch accuracy: 91.80
# Batch accuracy: 92.97
# Batch accuracy: 93.95
# Batch accuracy: 91.41
# Batch accuracy: 92.97
# Batch accuracy: 93.36
# Batch accuracy: 91.99
# Batch accuracy: 91.80
# Batch accuracy: 91.41
# Batch accuracy: 92.58
# Batch accuracy: 91.99
# Batch accuracy: 92.38
# Batch accuracy: 92.38
# Batch accuracy: 90.82
# Batch accuracy: 91.60
# Batch accuracy: 93.36
# Batch accuracy: 92.77
# Batch accuracy: 93.75
# Batch accuracy: 93.36
# Batch accuracy: 91.41
# Batch accuracy: 90.43
# Batch accuracy: 93.55
# Batch accuracy: 91.99
# Batch accuracy: 90.82
# Batch accuracy: 92.19
# Batch accuracy: 92.38
# Batch accuracy: 91.80
# Batch accuracy: 91.80
# Batch accuracy: 94.53
# Batch accuracy: 92.58
# Batch accuracy: 92.58
# Batch accuracy: 91.99
# Batch accuracy: 94.14
# Batch accuracy: 93.75
# Batch accuracy: 94.14
# Batch accuracy: 92.77
# Batch accuracy: 91.41
# Batch accuracy: 91.41
# Batch accuracy: 92.58
# Batch accuracy: 92.97
# Batch accuracy: 93.16
# Batch accuracy: 91.99
# Batch accuracy: 91.99
# Batch accuracy: 91.02
# Batch accuracy: 92.38
# Batch accuracy: 90.23
# Batch accuracy: 91.60
# Batch accuracy: 90.43
# Batch accuracy: 91.60
# Batch accuracy: 90.62
# Batch accuracy: 91.60
# Batch accuracy: 92.38
# Batch accuracy: 92.58
# Batch accuracy: 91.60
# Batch accuracy: 92.19
# Batch accuracy: 91.21
# Batch accuracy: 93.36
# Batch accuracy: 92.19
# Batch accuracy: 92.77
# Batch accuracy: 92.77
# Batch accuracy: 93.75
# Batch accuracy: 92.19
# Batch accuracy: 91.99
# Batch accuracy: 94.14
# Batch accuracy: 94.34
# Batch accuracy: 93.16
# Batch accuracy: 92.38
# Batch accuracy: 92.77
# Batch accuracy: 92.77
# Batch accuracy: 92.97
# Batch accuracy: 93.75
# Batch accuracy: 92.19
# Batch accuracy: 91.99
# Batch accuracy: 91.80
# Batch accuracy: 92.97
# Batch accuracy: 91.41
# Batch accuracy: 90.43
# Batch accuracy: 93.16
# Batch accuracy: 91.41
# Batch accuracy: 91.99
# Batch accuracy: 93.95
# Batch accuracy: 91.60
# Batch accuracy: 92.97
# Batch accuracy: 91.21
# Batch accuracy: 92.58
# Batch accuracy: 91.80
# Batch accuracy: 97.58
#   Accuracy: 92.36
# New best model, saving it!
#
# ======== Epoch 13 / 30 ========
# Training...
#   Batch    40  of    975.    .
#   step loss: 0.12
#   Batch    80  of    975.    .
#   step loss: 0.11
#   Batch   120  of    975.    .
#   step loss: 0.12
#   Batch   160  of    975.    .
#   step loss: 0.09
#   Batch   200  of    975.    .
#   step loss: 0.10
#   Batch   240  of    975.    .
#   step loss: 0.16
#   Batch   280  of    975.    .
#   step loss: 0.12
#   Batch   320  of    975.    .
#   step loss: 0.12
#   Batch   360  of    975.    .
#   step loss: 0.09
#   Batch   400  of    975.    .
#   step loss: 0.13
#   Batch   440  of    975.    .
#   step loss: 0.13
#   Batch   480  of    975.    .
#   step loss: 0.13
#   Batch   520  of    975.    .
#   step loss: 0.08
#   Batch   560  of    975.    .
#   step loss: 0.15
#   Batch   600  of    975.    .
#   step loss: 0.10
#   Batch   640  of    975.    .
#   step loss: 0.13
#   Batch   680  of    975.    .
#   step loss: 0.18
#   Batch   720  of    975.    .
#   step loss: 0.13
#   Batch   760  of    975.    .
#   step loss: 0.13
#   Batch   800  of    975.    .
#   step loss: 0.11
#   Batch   840  of    975.    .
#   step loss: 0.12
#   Batch   880  of    975.    .
#   step loss: 0.10
#   Batch   920  of    975.    .
#   step loss: 0.15
#   Batch   960  of    975.    .
#   step loss: 0.12
#
#   Average training loss: 0.13
#
# Running Validation...
# Batch accuracy: 91.21
# Batch accuracy: 93.36
# Batch accuracy: 91.99
# Batch accuracy: 92.97
# Batch accuracy: 91.41
# Batch accuracy: 91.21
# Batch accuracy: 92.58
# Batch accuracy: 91.02
# Batch accuracy: 90.43
# Batch accuracy: 93.36
# Batch accuracy: 91.60
# Batch accuracy: 92.97
# Batch accuracy: 91.80
# Batch accuracy: 91.21
# Batch accuracy: 92.19
# Batch accuracy: 93.55
# Batch accuracy: 91.99
# Batch accuracy: 93.55
# Batch accuracy: 92.38
# Batch accuracy: 93.36
# Batch accuracy: 92.19
# Batch accuracy: 94.92
# Batch accuracy: 90.23
# Batch accuracy: 90.43
# Batch accuracy: 91.41
# Batch accuracy: 92.38
# Batch accuracy: 91.21
# Batch accuracy: 92.38
# Batch accuracy: 92.19
# Batch accuracy: 93.16
# Batch accuracy: 93.16
# Batch accuracy: 92.77
# Batch accuracy: 92.97
# Batch accuracy: 92.19
# Batch accuracy: 89.65
# Batch accuracy: 91.41
# Batch accuracy: 93.16
# Batch accuracy: 91.21
# Batch accuracy: 91.80
# Batch accuracy: 93.16
# Batch accuracy: 91.02
# Batch accuracy: 92.58
# Batch accuracy: 95.51
# Batch accuracy: 93.55
# Batch accuracy: 90.04
# Batch accuracy: 91.60
# Batch accuracy: 89.65
# Batch accuracy: 93.55
# Batch accuracy: 91.80
# Batch accuracy: 93.16
# Batch accuracy: 91.21
# Batch accuracy: 95.12
# Batch accuracy: 92.38
# Batch accuracy: 93.16
# Batch accuracy: 92.38
# Batch accuracy: 90.23
# Batch accuracy: 93.55
# Batch accuracy: 91.21
# Batch accuracy: 92.58
# Batch accuracy: 90.82
# Batch accuracy: 92.97
# Batch accuracy: 92.58
# Batch accuracy: 91.02
# Batch accuracy: 93.55
# Batch accuracy: 92.19
# Batch accuracy: 91.80
# Batch accuracy: 91.21
# Batch accuracy: 92.19
# ...
# Batch accuracy: 91.60
# Batch accuracy: 93.36
# Batch accuracy: 93.55
# Batch accuracy: 91.80
# Batch accuracy: 92.19
# Batch accuracy: 91.80
# Batch accuracy: 93.16
# Batch accuracy: 92.38
# Batch accuracy: 92.58
# Batch accuracy: 91.80
# Batch accuracy: 92.58
# Batch accuracy: 92.58
# Batch accuracy: 94.92
# Batch accuracy: 93.36
# Batch accuracy: 92.19
# Batch accuracy: 92.77
# Batch accuracy: 91.99
# Batch accuracy: 91.99
# Batch accuracy: 92.97
# Batch accuracy: 92.58
# Batch accuracy: 92.97
# Batch accuracy: 93.75
# Batch accuracy: 91.41
# Batch accuracy: 93.16
# Batch accuracy: 90.62
# Batch accuracy: 91.80
# Batch accuracy: 91.60
# Batch accuracy: 92.19
# Batch accuracy: 91.60
# Batch accuracy: 91.41
# Batch accuracy: 93.36
# Batch accuracy: 92.38
# Batch accuracy: 93.16
# Batch accuracy: 91.99
# Batch accuracy: 90.62
# Batch accuracy: 92.97
# Batch accuracy: 91.99
# Batch accuracy: 92.74
#   Accuracy: 92.27
# The model does not improve for 2 epochs!
#
# ======== Epoch 15 / 30 ========
# Training...
#   Batch    40  of    975.    .
#   step loss: 0.14
#   Batch    80  of    975.    .
#   step loss: 0.09
#   Batch   120  of    975.    .
#   step loss: 0.10
#   Batch   160  of    975.    .
#   step loss: 0.08
#   Batch   200  of    975.    .
#   step loss: 0.14
#   Batch   240  of    975.    .
#   step loss: 0.10
#   Batch   280  of    975.    .
#   step loss: 0.16
#   Batch   320  of    975.    .
#   step loss: 0.13
#   Batch   360  of    975.    .
#   step loss: 0.10
#   Batch   400  of    975.    .
#   step loss: 0.11
#   Batch   440  of    975.    .
#   step loss: 0.08
#   Batch   480  of    975.    .
#   step loss: 0.15
#   Batch   520  of    975.    .
#   step loss: 0.09
#   Batch   560  of    975.    .
#   step loss: 0.10
#   Batch   600  of    975.    .
#   step loss: 0.14
#   Batch   640  of    975.    .
#   step loss: 0.13
#   Batch   680  of    975.    .
#   step loss: 0.09
#   Batch   720  of    975.    .
#   step loss: 0.15
#   Batch   760  of    975.    .
#   step loss: 0.12
#   Batch   800  of    975.    .
#   step loss: 0.14
#   Batch   840  of    975.    .
#   step loss: 0.12
#   Batch   880  of    975.    .
#   step loss: 0.12
#   Batch   920  of    975.    .
#   step loss: 0.11
#   Batch   960  of    975.    .
#   step loss: 0.13
#
#   Average training loss: 0.12
#
# Running Validation...
# Batch accuracy: 92.97
# Batch accuracy: 92.77
# Batch accuracy: 93.75
# Batch accuracy: 93.16
# Batch accuracy: 92.19
# Batch accuracy: 93.95
# Batch accuracy: 92.58
# Batch accuracy: 92.97
# Batch accuracy: 92.58
# Batch accuracy: 91.21
# Batch accuracy: 93.75
# Batch accuracy: 91.02
# Batch accuracy: 91.60
# Batch accuracy: 91.02
# Batch accuracy: 91.21
# Batch accuracy: 94.53
# Batch accuracy: 90.62
# Batch accuracy: 92.77
# Batch accuracy: 93.95
# Batch accuracy: 90.43
# Batch accuracy: 93.55
# Batch accuracy: 93.75
# Batch accuracy: 91.02
# Batch accuracy: 91.80
# Batch accuracy: 88.67
# Batch accuracy: 92.58
# Batch accuracy: 94.14
# Batch accuracy: 93.16
# Batch accuracy: 93.36
# Batch accuracy: 89.45
# Batch accuracy: 91.60
# Batch accuracy: 93.75
# Batch accuracy: 93.75
# Batch accuracy: 93.16
# Batch accuracy: 90.82
# Batch accuracy: 88.67
# Batch accuracy: 92.58
# Batch accuracy: 91.41
# Batch accuracy: 90.62
# Batch accuracy: 91.02
# Batch accuracy: 91.02
# Batch accuracy: 93.75
# Batch accuracy: 94.34
# Batch accuracy: 92.97
# Batch accuracy: 91.80
# Batch accuracy: 92.97
# Batch accuracy: 91.99
# Batch accuracy: 90.62
# Batch accuracy: 92.58
# Batch accuracy: 93.95
# Batch accuracy: 92.58
# Batch accuracy: 91.02
# Batch accuracy: 93.16
# Batch accuracy: 90.43
# Batch accuracy: 92.38
# Batch accuracy: 89.65
# Batch accuracy: 93.55
# Batch accuracy: 90.62
# Batch accuracy: 90.82
# Batch accuracy: 91.80
# Batch accuracy: 91.60
# Batch accuracy: 92.97
# Batch accuracy: 92.38
# Batch accuracy: 94.53
# Batch accuracy: 93.16
# Batch accuracy: 92.38
# Batch accuracy: 93.75
# Batch accuracy: 94.34
# Batch accuracy: 91.60
# Batch accuracy: 91.99
# Batch accuracy: 93.36
# Batch accuracy: 93.36
# Batch accuracy: 92.19
# Batch accuracy: 92.77
# Batch accuracy: 93.55
# Batch accuracy: 91.99
# Batch accuracy: 92.77
# Batch accuracy: 92.19
# Batch accuracy: 93.95
# Batch accuracy: 91.99
# Batch accuracy: 92.97
# Batch accuracy: 92.97
# Batch accuracy: 91.80
# Batch accuracy: 93.16
# Batch accuracy: 91.21
# Batch accuracy: 90.82
# Batch accuracy: 92.58
# Batch accuracy: 92.38
# Batch accuracy: 92.77
# Batch accuracy: 93.16
# Batch accuracy: 92.19
# Batch accuracy: 92.38
# Batch accuracy: 91.99
# Batch accuracy: 93.55
# Batch accuracy: 91.41
# Batch accuracy: 92.19
# Batch accuracy: 92.58
# Batch accuracy: 92.58
# Batch accuracy: 89.65
# Batch accuracy: 91.99
# Batch accuracy: 92.58
# Batch accuracy: 91.41
# Batch accuracy: 93.55
# Batch accuracy: 91.60
# Batch accuracy: 92.58
# Batch accuracy: 90.62
# Batch accuracy: 93.75
# Batch accuracy: 92.77
# Batch accuracy: 94.35
#   Accuracy: 92.33
# The model does not improve for 3 epochs!
#
# ======== Epoch 16 / 30 ========
# Training...
#   Batch    40  of    975.    .
#   step loss: 0.14
#   Batch    80  of    975.    .
#   step loss: 0.10
#   Batch   120  of    975.    .
#   step loss: 0.13
#   Batch   160  of    975.    .
#   step loss: 0.14
#   Batch   200  of    975.    .
#   step loss: 0.11
#   Batch   240  of    975.    .
#   step loss: 0.18
#   Batch   280  of    975.    .
#   step loss: 0.16
#   Batch   320  of    975.    .
#   step loss: 0.17
#   Batch   360  of    975.    .
#   step loss: 0.10
#   Batch   400  of    975.    .
#   step loss: 0.09
#   Batch   440  of    975.    .
#   step loss: 0.15
#   Batch   480  of    975.    .
#   step loss: 0.10
#   Batch   520  of    975.    .
#   step loss: 0.18
#   Batch   560  of    975.    .
#   step loss: 0.13
#   Batch   600  of    975.    .
#   step loss: 0.11
#   Batch   640  of    975.    .
#   step loss: 0.12
#   Batch   680  of    975.    .
#   step loss: 0.09
#   Batch   720  of    975.    .
#   step loss: 0.13
#   Batch   760  of    975.    .
#   step loss: 0.12
#   Batch   800  of    975.    .
#   step loss: 0.12
#   Batch   840  of    975.    .
#   step loss: 0.12
#   Batch   880  of    975.    .
#   step loss: 0.12
#   Batch   920  of    975.    .
#   step loss: 0.18
#   Batch   960  of    975.    .
#   step loss: 0.16
#
#   Average training loss: 0.12
#
# Running Validation...
# Batch accuracy: 91.80
# Batch accuracy: 92.58
# Batch accuracy: 92.19
# Batch accuracy: 90.62
# Batch accuracy: 93.95
# Batch accuracy: 91.80
# Batch accuracy: 91.80
# Batch accuracy: 91.80
# Batch accuracy: 94.53
# Batch accuracy: 91.41
# Batch accuracy: 90.62
# Batch accuracy: 94.92
# Batch accuracy: 91.41
# Batch accuracy: 93.16
# Batch accuracy: 91.60
# Batch accuracy: 92.58
# Batch accuracy: 95.51
# Batch accuracy: 92.97
# Batch accuracy: 92.19
# Batch accuracy: 92.19
# Batch accuracy: 92.97
# Batch accuracy: 92.58
# Batch accuracy: 93.16
# Batch accuracy: 91.99
# Batch accuracy: 91.41
# Batch accuracy: 93.36
# Batch accuracy: 93.55
# Batch accuracy: 92.77
# Batch accuracy: 92.58
# Batch accuracy: 93.95
# Batch accuracy: 93.16
# Batch accuracy: 92.97
# Batch accuracy: 94.34
# Batch accuracy: 93.36
# Batch accuracy: 91.41
# Batch accuracy: 92.19
# Batch accuracy: 91.99
# Batch accuracy: 91.60
# Batch accuracy: 91.41
# Batch accuracy: 92.38
# Batch accuracy: 93.36
# Batch accuracy: 94.53
# Batch accuracy: 91.60
# Batch accuracy: 91.80
# Batch accuracy: 95.12
# Batch accuracy: 91.21
# Batch accuracy: 92.77
# Batch accuracy: 91.80
# Batch accuracy: 92.58
# Batch accuracy: 93.36
# Batch accuracy: 92.97
# Batch accuracy: 91.21
# Batch accuracy: 91.02
# Batch accuracy: 91.80
# Batch accuracy: 90.23
# Batch accuracy: 91.80
# Batch accuracy: 93.16
# Batch accuracy: 91.60
# Batch accuracy: 92.77
# Batch accuracy: 92.38
# Batch accuracy: 92.58
# Batch accuracy: 92.19
# Batch accuracy: 91.41
# Batch accuracy: 92.58
# Batch accuracy: 92.19
# Batch accuracy: 93.16
# Batch accuracy: 91.41
# Batch accuracy: 91.60
# Batch accuracy: 91.99
# Batch accuracy: 91.60
# Batch accuracy: 93.36
# Batch accuracy: 91.99
# Batch accuracy: 91.60
# Batch accuracy: 91.02
# Batch accuracy: 93.55
# Batch accuracy: 91.21
# Batch accuracy: 91.21
# Batch accuracy: 92.19
# Batch accuracy: 92.58
# Batch accuracy: 92.38
# Batch accuracy: 92.58
# Batch accuracy: 92.38
# Batch accuracy: 92.77
# Batch accuracy: 93.16
# Batch accuracy: 92.19
# Batch accuracy: 91.60
# Batch accuracy: 91.60
# Batch accuracy: 92.97
# Batch accuracy: 90.04
# Batch accuracy: 93.16
# Batch accuracy: 91.99
# Batch accuracy: 92.38
# Batch accuracy: 90.43
# Batch accuracy: 91.41
# Batch accuracy: 94.34
# Batch accuracy: 92.38
# Batch accuracy: 91.80
# Batch accuracy: 92.38
# Batch accuracy: 91.80
# Batch accuracy: 91.41
# Batch accuracy: 92.77
# Batch accuracy: 93.36
# Batch accuracy: 91.41
# Batch accuracy: 91.60
# Batch accuracy: 91.99
# Batch accuracy: 91.80
# Batch accuracy: 91.02
# Batch accuracy: 91.21
# Batch accuracy: 90.32
#   Accuracy: 92.29
# The model does not improve for 4 epochs!
# Epoch    16: reducing learning rate of group 0 to 1.0000e-05.
#
# ======== Epoch 17 / 30 ========
# Training...
#   Batch    40  of    975.    .
#   step loss: 0.09
#   Batch    80  of    975.    .
#   step loss: 0.09
#   Batch   120  of    975.    .
#   step loss: 0.13
#   Batch   160  of    975.    .
#   step loss: 0.10
#   Batch   200  of    975.    .
#   step loss: 0.07
#   Batch   240  of    975.    .
#   step loss: 0.10
#   Batch   280  of    975.    .
#   step loss: 0.11
#   Batch   320  of    975.    .
#   step loss: 0.10
#   Batch   360  of    975.    .
#   step loss: 0.11
#   Batch   400  of    975.    .
#   step loss: 0.04
#   Batch   440  of    975.    .
#   step loss: 0.13
#   Batch   480  of    975.    .
#   step loss: 0.10
#   Batch   520  of    975.    .
#   step loss: 0.13
#   Batch   560  of    975.    .
#   step loss: 0.13
#   Batch   600  of    975.    .
#   step loss: 0.10
#   Batch   640  of    975.    .
#   step loss: 0.14
#   Batch   680  of    975.    .
#   step loss: 0.10
#   Batch   720  of    975.    .
#   step loss: 0.13
#   Batch   760  of    975.    .
#   step loss: 0.07
#   Batch   800  of    975.    .
#   step loss: 0.15
#   Batch   840  of    975.    .
#   step loss: 0.08
#   Batch   880  of    975.    .
#   step loss: 0.10
#   Batch   920  of    975.    .
#   step loss: 0.15
#   Batch   960  of    975.    .
#   step loss: 0.13
#
#   Average training loss: 0.12
#
# Running Validation...
# Batch accuracy: 93.36
# Batch accuracy: 91.99
# Batch accuracy: 90.43
# Batch accuracy: 91.21
# Batch accuracy: 92.58
# Batch accuracy: 90.62
# Batch accuracy: 93.95
# Batch accuracy: 91.60
# Batch accuracy: 91.02
# Batch accuracy: 92.19
# Batch accuracy: 90.23
# Batch accuracy: 91.60
# Batch accuracy: 92.38
# Batch accuracy: 91.21
# Batch accuracy: 93.95
# Batch accuracy: 90.43
# Batch accuracy: 91.99
# Batch accuracy: 90.04
# Batch accuracy: 91.41
# Batch accuracy: 94.14
# Batch accuracy: 92.77
# Batch accuracy: 93.75
# Batch accuracy: 91.02
# Batch accuracy: 92.77
# Batch accuracy: 91.80
# Batch accuracy: 92.77
# Batch accuracy: 92.97
# Batch accuracy: 91.60
# Batch accuracy: 92.77
# Batch accuracy: 94.14
# Batch accuracy: 91.80
# Batch accuracy: 92.58
# Batch accuracy: 91.99
# Batch accuracy: 95.51
# Batch accuracy: 92.38
# Batch accuracy: 91.99
# Batch accuracy: 93.95
# Batch accuracy: 92.77
# Batch accuracy: 91.80
# Batch accuracy: 90.82
# Batch accuracy: 92.97
# Batch accuracy: 93.36
# Batch accuracy: 94.14
# Batch accuracy: 92.77
# Batch accuracy: 94.14
# Batch accuracy: 91.02
# Batch accuracy: 92.97
# Batch accuracy: 90.23
# Batch accuracy: 93.36
# Batch accuracy: 92.38
# Batch accuracy: 94.53
# Batch accuracy: 91.41
# Batch accuracy: 93.75
# Batch accuracy: 92.77
# Batch accuracy: 92.58
# Batch accuracy: 92.58
# Batch accuracy: 95.12
# Batch accuracy: 92.38
# Batch accuracy: 92.77
# Batch accuracy: 94.34
# Batch accuracy: 92.97
# Batch accuracy: 90.23
# Batch accuracy: 89.45
# Batch accuracy: 91.41
# Batch accuracy: 91.21
# Batch accuracy: 92.58
# Batch accuracy: 90.82
# Batch accuracy: 91.80
# Batch accuracy: 91.99
# Batch accuracy: 92.38
# Batch accuracy: 89.26
# Batch accuracy: 93.95
# Batch accuracy: 93.95
# Batch accuracy: 90.62
# Batch accuracy: 93.95
# Batch accuracy: 92.97
# Batch accuracy: 94.34
# Batch accuracy: 92.19
# Batch accuracy: 90.23
# Batch accuracy: 93.55
# Batch accuracy: 91.60
# Batch accuracy: 91.60
# Batch accuracy: 93.55
# Batch accuracy: 93.95
# Batch accuracy: 92.58
# Batch accuracy: 91.41
# Batch accuracy: 91.80
# Batch accuracy: 92.19
# Batch accuracy: 91.41
# Batch accuracy: 93.16
# Batch accuracy: 91.99
# Batch accuracy: 92.97
# Batch accuracy: 94.14
# Batch accuracy: 89.26
# Batch accuracy: 91.41
# Batch accuracy: 92.19
# Batch accuracy: 91.21
# Batch accuracy: 93.16
# Batch accuracy: 92.38
# Batch accuracy: 93.55
# Batch accuracy: 91.99
# Batch accuracy: 93.16
# Batch accuracy: 92.77
# Batch accuracy: 91.21
# Batch accuracy: 92.77
# Batch accuracy: 93.55
# Batch accuracy: 92.58
# Batch accuracy: 91.80
# Batch accuracy: 92.74
#   Accuracy: 92.35
# The model does not improve for 5 epochs!
#
# ======== Epoch 18 / 30 ========
# Training...
#   Batch    40  of    975.    .
#   step loss: 0.11
#   Batch    80  of    975.    .
#   step loss: 0.11
#   Batch   120  of    975.    .
#   step loss: 0.13
#   Batch   160  of    975.    .
#   step loss: 0.12
#   Batch   200  of    975.    .
#   step loss: 0.10
#   Batch   240  of    975.    .
#   step loss: 0.11
#   Batch   280  of    975.    .
#   step loss: 0.13
#   Batch   320  of    975.    .
#   step loss: 0.11
#   Batch   360  of    975.    .
#   step loss: 0.11
#   Batch   400  of    975.    .
#   step loss: 0.15
#   Batch   440  of    975.    .
#   step loss: 0.12
#   Batch   480  of    975.    .
#   step loss: 0.11
#   Batch   520  of    975.    .
#   step loss: 0.10
#   Batch   560  of    975.    .
#   step loss: 0.09
#   Batch   600  of    975.    .
#   step loss: 0.07
#   Batch   640  of    975.    .
#   step loss: 0.15
#   Batch   680  of    975.    .
#   step loss: 0.18
#   Batch   720  of    975.    .
#   step loss: 0.13
#   Batch   760  of    975.    .
#   step loss: 0.11
#   Batch   800  of    975.    .
#   step loss: 0.07
#   Batch   840  of    975.    .
#   step loss: 0.14
#   Batch   880  of    975.    .
#   step loss: 0.13
#   Batch   920  of    975.    .
#   step loss: 0.09
#   Batch   960  of    975.    .
#   step loss: 0.13
#
#   Average training loss: 0.11
#
# Running Validation...
# Batch accuracy: 91.80
# Batch accuracy: 91.80
# Batch accuracy: 91.80
# Batch accuracy: 92.77
# Batch accuracy: 94.14
# Batch accuracy: 92.58
# Batch accuracy: 94.53
# Batch accuracy: 92.58
# Batch accuracy: 91.41
# Batch accuracy: 92.19
# Batch accuracy: 89.45
# Batch accuracy: 91.02
# Batch accuracy: 92.19
# Batch accuracy: 92.58
# Batch accuracy: 94.92
# Batch accuracy: 92.19
# Batch accuracy: 92.97
# Batch accuracy: 92.58
# Batch accuracy: 89.45
# Batch accuracy: 93.75
# Batch accuracy: 92.97
# Batch accuracy: 94.53
# Batch accuracy: 92.97
# Batch accuracy: 93.16
# Batch accuracy: 91.99
# Batch accuracy: 91.02
# Batch accuracy: 90.62
# Batch accuracy: 91.99
# Batch accuracy: 91.02
# Batch accuracy: 91.60
# Batch accuracy: 93.36
# Batch accuracy: 91.41
# Batch accuracy: 93.95
# Batch accuracy: 93.16
# Batch accuracy: 92.19
# Batch accuracy: 93.75
# Batch accuracy: 92.19
# Batch accuracy: 94.34
# Batch accuracy: 92.58
# Batch accuracy: 92.38
# Batch accuracy: 91.60
# Batch accuracy: 91.60
# Batch accuracy: 89.45
# Batch accuracy: 93.36
# Batch accuracy: 91.60
# Batch accuracy: 92.19
# Batch accuracy: 93.75
# Batch accuracy: 91.99
# Batch accuracy: 92.58
# Batch accuracy: 92.77
# Batch accuracy: 90.82
# Batch accuracy: 92.58
# Batch accuracy: 92.97
# Batch accuracy: 92.97
# Batch accuracy: 91.41
# Batch accuracy: 91.02
# Batch accuracy: 92.19
# Batch accuracy: 90.82
# Batch accuracy: 93.55
# Batch accuracy: 91.99
# Batch accuracy: 91.99
# Batch accuracy: 91.80
# Batch accuracy: 91.99
# Batch accuracy: 91.80
# Batch accuracy: 92.77
# Batch accuracy: 92.19
# Batch accuracy: 91.60
# Batch accuracy: 91.99
# Batch accuracy: 90.82
# Batch accuracy: 92.97
# Batch accuracy: 91.99
# Batch accuracy: 91.99
# Batch accuracy: 92.97
# Batch accuracy: 92.58
# Batch accuracy: 92.77
# Batch accuracy: 90.23
# Batch accuracy: 94.34
# Batch accuracy: 94.14
# Batch accuracy: 93.75
# Batch accuracy: 92.77
# Batch accuracy: 91.02
# Batch accuracy: 93.75
# Batch accuracy: 94.53
# Batch accuracy: 92.58
# Batch accuracy: 91.21
# Batch accuracy: 91.99
# Batch accuracy: 92.77
# Batch accuracy: 92.97
# Batch accuracy: 92.58
# Batch accuracy: 90.04
# Batch accuracy: 91.41
# Batch accuracy: 92.38
# Batch accuracy: 91.41
# Batch accuracy: 94.34
# Batch accuracy: 92.38
# Batch accuracy: 91.60
# Batch accuracy: 91.41
# Batch accuracy: 91.60
# Batch accuracy: 91.21
# Batch accuracy: 91.60
# Batch accuracy: 91.02
# Batch accuracy: 91.02
# Batch accuracy: 93.36
# Batch accuracy: 94.53
# Batch accuracy: 92.97
# Batch accuracy: 93.95
# Batch accuracy: 92.38
# Batch accuracy: 92.38
# Batch accuracy: 94.35
#   Accuracy: 92.34
# The model does not improve for 6 epochs!
# ====>Stopping training, the model did not improve for 6
# ====>Best epoch: 12.
#
# Training complete!

# %%
def predict(
    model_path: Path,
    dataset: str,
    batch_size: int,
    labels_dict,
    device: torch.device
):

    print(f"====Loading dataset for testing")
    test_corpus = NLPDataset(dataset, "test", sentence_max_len, labels_dict = labels_dict, vocab= voc)

    test_dataloader = DataLoader(
        test_corpus,
        batch_size=batch_size,
        #sampler = RandomSampler(test_corpus),
        pin_memory=True,
        num_workers=0,
        drop_last=False
    )

    print(f"====Loading model for testing")
    model = torch.load(join(model_path, "best-model.pth"))
    model.to(device)
    model.eval()
    pred_labels = []
    test_labels = []
    logits_list = []

    def _list_from_tensor(tensor):
        if tensor.numel() == 1:
            return [tensor.item()]
        return list(tensor.cpu().detach().numpy())

    print("====Testing model...")
    for batch in test_dataloader:
        #h = model.init_hidden(len(batch[0]), device)
        #h = tuple([each.data for each in val_h])
        b_input_ids = batch[0]
        b_input_ids = torch.tensor(b_input_ids).to(device).long()
        b_labels = batch[1].to(device)
        with torch.no_grad():
            #h = tuple([each.data for each in h])
            loss, logits = model(b_input_ids, b_labels)
            preds = np.argmax(logits.cpu(), axis=1) # Convert one-hot to index
            b_labels = b_labels.int()
            pred_labels.extend(_list_from_tensor(preds))
            test_labels.extend(_list_from_tensor(b_labels))
        logits_list.extend(_list_from_tensor(logits))

    print(classification_report(test_labels, pred_labels, labels=list(labels_dict.values()), target_names=np.array(list(labels_dict.keys())), digits=3, output_dict=False))
    logits_list = expit(logits_list)
    del model
    torch.cuda.empty_cache()

# %%
del train_dataloader
del validation_dataloader
del train_corpus
del val_corpus
del model
torch.cuda.empty_cache()

# %%
predict(last_saved_model, dataset, batch_size, labels_dict, device)
# Out:
# ====Loading dataset for testing
# ====Loading model for testing
# ====Testing model...
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:39: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#                                              precision    recall  f1-score   support
#
#                               FISHING_LINES      0.835     0.815     0.825       584
#                      MOBILE_DEVICE_CHARGERS      0.939     0.970     0.954       804
#                                  SUNGLASSES      0.960     0.970     0.965       875
#                                    FREEZERS      0.861     0.919     0.889       444
#                                  CAR_WHEELS      0.965     0.990     0.977       720
#                            BATHROOM_FAUCETS      0.900     0.885     0.893       521
#                              ACTION_FIGURES      0.686     0.680     0.683       800
#                                       IRONS      0.975     0.977     0.976       433
#                                  MATTRESSES      0.952     0.976     0.964       534
#                       SWIMMING_POOL_HEATERS      0.950     0.905     0.927        21
#                              KITCHEN_KNIVES      0.932     0.950     0.941       202
#                                 TELEVISIONS      0.943     0.952     0.947       728
#                    SPORT_AND_BAZAAR_BOTTLES      0.861     0.891     0.876       229
#                                    STARTERS      0.969     0.963     0.966       354
#                                  FACE_MASKS      0.847     0.801     0.824       166
#                             KITCHEN_FAUCETS      0.881     0.907     0.894       431
#     TACTICAL_AND_SPORTING_KNIVES_AND_BLADES      0.975     0.933     0.953       164
#                                   NOTEBOOKS      0.916     0.967     0.941       543
#                                 DEEP_FRYERS      0.955     0.938     0.947       455
#                                TORSION_BARS      0.984     1.000     0.992       123
#                            AUDIO_AMPLIFIERS      0.772     0.839     0.804       311
#                              CEILING_LIGHTS      0.910     0.945     0.927       472
#                                       BELTS      0.885     0.939     0.911        49
#                    AUTOMOTIVE_WEATHERSTRIPS      0.955     0.971     0.963       788
#                                  HEADBOARDS      0.987     0.987     0.987       228
#                                       YARNS      0.852     0.894     0.873       142
#                                SMARTWATCHES      0.943     0.935     0.939       724
#                             FOOTBALL_SHIRTS      0.961     0.967     0.964       921
#                      AUTOMOTIVE_CLUTCH_KITS      0.975     0.986     0.981       719
#                                WRISTWATCHES      0.950     0.958     0.954       876
#                                  WALLPAPERS      0.957     0.932     0.944       885
#         AUTOMOTIVE_SIDE_VIEW_MIRROR_GLASSES      0.967     0.983     0.975       536
#                            AUDIO_INTERFACES      0.914     0.883     0.898       300
#                            KITCHEN_PLAYSETS      0.882     0.900     0.891       100
#                                 LIGHT_BULBS      0.951     0.938     0.945       829
#                              CELL_BATTERIES      0.955     0.948     0.951       670
#                        SURVEILLANCE_CAMERAS      0.940     0.884     0.912       909
#                                   THERMOSES      0.812     0.780     0.796       100
#                  HUMIDIFIERS_AND_VAPORIZERS      0.925     0.925     0.925       173
#                              KITCHEN_APRONS      0.909     0.741     0.816        27
#                         PORTABLE_GENERATORS      0.978     0.992     0.985       132
#                                  CELLPHONES      0.882     0.884     0.883       329
#                            HANDICRAFT_BOXES      0.700     0.750     0.724       112
#                         EMBROIDERY_MACHINES      0.878     0.843     0.860        51
#                                     CAMERAS      0.758     0.750     0.754        92
#             DESKTOP_COMPUTER_POWER_SUPPLIES      0.961     0.981     0.971       679
#                              BABIES_FORMULA      0.879     0.909     0.894        88
#                     MOTORCYCLE_SPEEDOMETERS      1.000     0.500     0.667         4
#                                     CARPETS      0.924     0.964     0.943       857
#                       CARDS_AND_INVITATIONS      0.923     0.766     0.837        47
#                            ELECTRIC_GUITARS      0.970     0.961     0.966       778
#                           COMPUTER_MONITORS      0.969     0.969     0.969       701
#                          MULTIGAME_MACHINES      0.816     0.805     0.810        77
#                                 TABLECLOTHS      0.967     0.972     0.970       544
#                                   VIBRATORS      0.870     0.803     0.836       117
#                                      PLANTS      0.938     0.965     0.951       313
#                                AM_FM_RADIOS      0.893     0.911     0.902       383
#                      ENGINE_CONTROL_MODULES      0.981     0.993     0.987       415
#             LATEX_ENAMEL_AND_ACRYLIC_PAINTS      1.000     0.985     0.992        67
#             MUSICAL_KEYBOARD_CASES_AND_BAGS      0.978     0.978     0.978       760
#                                 VIDEO_GAMES      0.974     0.990     0.982       908
#                          ARTIFICIAL_FLOWERS      0.921     0.942     0.931       497
#                          OUTER_TIE_ROD_ENDS      0.978     0.976     0.977       496
#                           EXHAUST_MANIFOLDS      0.875     0.875     0.875         8
#                     DIGITAL_VOICE_RECORDERS      0.903     0.943     0.923       774
#                               REFRIGERATORS      0.943     0.939     0.941       524
#                             DISPOSABLE_CUPS      0.833     0.771     0.801       188
#                                  EYESHADOWS      0.960     0.954     0.957       738
#                                      RANGES      0.937     0.964     0.951       450
#          AUTOMOTIVE_POWER_WINDOW_REGULATORS      0.941     0.928     0.934       138
#                                     HOOKAHS      0.958     0.952     0.955       168
#                       AUTOMOTIVE_AMPLIFIERS      0.940     0.929     0.935       662
#                           PROJECTOR_SCREENS      0.875     0.925     0.899        53
#                          AUTOMOTIVE_EMBLEMS      0.945     0.924     0.934       524
#                           PAINTBALL_MARKERS      0.870     0.897     0.883        97
#               AUTOMOTIVE_SPRING_SUSPENSIONS      0.945     0.992     0.968       121
#                                 ENGINE_OILS      0.956     0.969     0.963       770
#                            BATTERY_CHARGERS      0.727     0.800     0.762        30
#                     SWEATSHIRTS_AND_HOODIES      0.870     0.907     0.888       118
#                      CONTINUOUS_INK_SYSTEMS      0.944     0.971     0.958       140
#                              BATHROOM_SINKS      0.908     0.953     0.930       427
#                                MEMORY_CARDS      0.973     0.970     0.972       669
#                                    HANDBAGS      0.932     0.952     0.942       850
#                               KITCHEN_SINKS      0.896     0.881     0.888       253
#                            CAMERA_BATTERIES      0.951     0.946     0.948       554
#                             WATER_RADIATORS      0.955     0.965     0.960       399
#                           CYCLING_COMPUTERS      0.925     0.925     0.925       161
#                                EROTIC_BOOKS      0.971     0.985     0.978        67
#                            MOTORCYCLE_CASES      0.986     0.986     0.986       222
#                                    COSTUMES      0.953     0.960     0.957       276
#                           BODYWEIGHT_SCALES      0.898     0.901     0.899       293
#                      GAMEPADS_AND_JOYSTICKS      0.967     0.954     0.961       612
#                                       PANTS      0.904     0.942     0.923       799
#                                      STOOLS      0.948     0.976     0.962       594
#                               FISHING_REELS      0.981     0.970     0.976       740
#                                     WALLETS      0.974     0.962     0.968       665
#                           MUSICAL_KEYBOARDS      0.952     0.975     0.963       511
#                                  ULTRABOOKS      0.922     0.871     0.896       232
#                             ENGINE_BEARINGS      0.988     0.982     0.985       327
#                    CAR_POWER_STEERING_PUMPS      0.984     0.989     0.987       370
#                                     TABLETS      0.974     0.957     0.965       624
#                              MAKEUP_BRUSHES      0.977     0.976     0.977       534
#                               HORSE_SADDLES      1.000     0.990     0.995       102
#                          CD_AND_DVD_PLAYERS      0.845     0.883     0.864       291
#                    VIDEO_GAME_PREPAID_CARDS      0.828     0.706     0.762        68
#                             SCREEN_PRINTERS      0.896     0.942     0.919       156
#                                  ROOF_RACKS      0.977     0.981     0.979       428
#                                  HEADPHONES      0.946     0.931     0.939       189
#                       ELECTRIC_SCREWDRIVERS      0.858     0.746     0.798       122
#                             VACUUM_CLEANERS      0.929     0.812     0.867        16
#                                 FLASHLIGHTS      0.975     0.967     0.971       606
#                                HOME_SHELVES      0.869     0.847     0.858       157
#                               BRUSH_CUTTERS      0.954     0.936     0.945       110
#                         COMPUTER_PROCESSORS      0.966     0.962     0.964       794
#                                    NECKTIES      0.985     0.985     0.985       134
#                          MOTORCYCLE_JACKETS      0.951     0.942     0.946       551
#                                    WRENCHES      0.955     0.976     0.965       371
#                                 WHEELCHAIRS      0.957     0.989     0.973        90
#                          RAM_MEMORY_MODULES      0.979     0.972     0.976       822
#                                PENCIL_CASES      0.909     0.929     0.919       183
#                AUTOMOTIVE_SHIFT_LEVER_KNOBS      1.000     1.000     1.000       938
#                                        MUGS      0.927     0.933     0.930       329
#                              WALKIE_TALKIES      0.946     0.929     0.938       283
#                                       DOLLS      0.886     0.932     0.909       843
#                                  TREADMILLS      1.000     0.985     0.992        65
#                                 SPARK_PLUGS      0.966     0.950     0.958       726
#                               HAIR_CLIPPERS      0.855     0.868     0.862       714
#                                   SUITCASES      0.962     0.957     0.960       582
#                                 BLANK_DISCS      0.914     0.899     0.907       178
#                                    SPEAKERS      0.938     0.950     0.944       525
#                               DVD_RECORDERS      0.949     0.942     0.945       450
#                     KEYBOARD_AND_MOUSE_KITS      0.952     0.945     0.949       275
#                             CAR_SEAT_COVERS      0.989     0.997     0.993       942
#          AUTOMOTIVE_SUSPENSION_CONTROL_ARMS      0.968     0.965     0.966       254
#                           BAR_CODE_SCANNERS      0.988     0.969     0.978       254
#                         AUTOMOTIVE_MOLDINGS      0.958     0.981     0.969       720
#                               BABY_SWIMWEAR      0.815     0.835     0.824       121
#                        TABLE_AND_DESK_LAMPS      0.890     0.900     0.895       260
#                           JACKETS_AND_COATS      0.913     0.929     0.921       815
#                                  CHAMPAGNES      0.828     0.774     0.800        31
#                              FOOTBALL_SHOES      0.992     0.997     0.995       734
#                           CHARMS_AND_MEDALS      0.878     0.837     0.857        86
#                                 MICROPHONES      0.952     0.989     0.970       465
#                         PERMANENT_EPILATORS      0.853     0.862     0.857        94
#                              WOMEN_SWIMWEAR      0.927     0.940     0.933       500
#                  PARTY_DECORATIVE_BACKDROPS      0.971     0.971     0.971       105
#                               ROLLER_SKATES      0.986     0.988     0.987       586
#                                      COMICS      0.789     0.807     0.798       534
#                                       BOOKS      0.664     0.800     0.726       834
#                              CUPCAKE_STANDS      1.000     0.625     0.769         8
#                               UPS_BATTERIES      0.828     0.750     0.787        64
#                                 CAKE_STANDS      0.822     0.822     0.822        45
#            REAR_WHEEL_HUBS_BEARING_ASSEMBLY      0.980     0.993     0.986       401
#                            DIECAST_VEHICLES      0.912     0.909     0.911       606
#                                 CALCULATORS      0.972     0.981     0.977       536
#                                 TV_ANTENNAS      0.969     0.997     0.983       310
#                                 PAPER_CLIPS      0.958     0.902     0.929        51
#                              MALE_UNDERWEAR      0.969     0.974     0.972       422
#                                  ALL_IN_ONE      0.951     0.915     0.933       189
#                            DRINKING_GLASSES      0.796     0.866     0.830       382
#                                       DRUMS      0.891     0.925     0.907       212
#                               WELDING_MASKS      0.965     0.873     0.917        63
#                                    WHISKEYS      0.945     0.963     0.954       267
#                               VIDEO_CAMERAS      0.842     0.865     0.853        37
#                               COFFEE_MAKERS      0.980     0.974     0.977       567
#                        KNEE_BRACES_SUPPORTS      0.959     0.915     0.937       129
#                                 WALL_CLOCKS      0.975     0.956     0.965       480
#                                 WALL_LIGHTS      0.938     0.884     0.910       172
#                              GARDEN_BENCHES      0.900     0.643     0.750        14
#                                  SCULPTURES      0.911     0.890     0.900       437
#                                        FANS      0.971     0.958     0.965       597
#                                 FOUNDATIONS      0.932     0.936     0.934       706
#                                   EYELINERS      0.902     0.740     0.813        50
#                                  DRILL_BITS      0.937     0.930     0.933       143
#                                PC_KEYBOARDS      0.750     0.692     0.720        26
#                               EROTIC_CREAMS      0.844     0.892     0.868       279
#                           DESKTOP_COMPUTERS      0.966     0.778     0.862        36
#                           DECORATIVE_VINYLS      0.900     0.962     0.930       709
#                                 BOARD_GAMES      0.850     0.919     0.883       654
#                         KITCHEN_RANGE_HOODS      0.984     0.984     0.984       309
#                                     DRAWERS      0.974     0.960     0.967       198
#                             FURNITURE_KNOBS      0.986     0.966     0.976       147
#        HOME_APPLIANCE_CONTACTORS_AND_RELAYS      0.942     0.961     0.951       408
#                            SHAVING_MACHINES      0.823     0.768     0.795       449
#                                TOOTHBRUSHES      0.955     0.966     0.961       265
#                     STREAMING_MEDIA_DEVICES      0.939     0.928     0.933       415
#                      CAR_AC_HOSE_ASSEMBLIES      0.667     0.471     0.552        17
#                              SWAY_BAR_LINKS      0.882     0.843     0.862        89
#                               PREAMPLIFIERS      0.429     0.261     0.324        23
#                                  FISH_TANKS      0.977     0.876     0.924       145
#                                      DRONES      0.971     0.963     0.967       653
#                            EMERGENCY_LIGHTS      0.925     0.941     0.933       288
#                                    BLENDERS      0.896     0.931     0.913       452
#                              LASER_MEASURES      0.914     0.964     0.938        55
#                                CASH_DRAWERS      1.000     0.921     0.959        38
#                             CAMERA_CHARGERS      0.910     0.926     0.918       285
#                            CAR_AV_RECEIVERS      0.918     0.907     0.912       589
#                            STEERING_COLUMNS      0.959     0.986     0.972       143
#                                      SKIRTS      0.949     0.974     0.962       154
#                             SANDER_MACHINES      0.959     0.955     0.957       292
#                                RICE_COOKERS      0.980     0.942     0.961        52
#                              BRAKE_BOOSTERS      0.964     0.964     0.964       139
#                                    NETBOOKS      0.942     0.890     0.915       145
#                               FISHING_LURES      0.773     0.866     0.817        67
#                            AUTOMOTIVE_TIRES      0.847     0.762     0.803        80
#                                     STATUES      0.381     0.348     0.364        23
#                                    T_SHIRTS      0.955     0.953     0.954       742
#                             OFFICE_SOFTWARE      0.786     0.671     0.724        82
#                              BABY_CAR_SEATS      0.962     0.975     0.968       550
#                                 WATCH_BANDS      0.914     0.917     0.915       265
#                                        PENS      0.677     0.778     0.724        27
#                   BATHROOM_ACCESSORIES_SETS      0.696     0.821     0.753        78
#                                 CAR_STEREOS      0.812     0.852     0.831       243
#  CELLPHONE_TABLET_AND_GPS_SCREEN_PROTECTORS      0.879     0.935     0.906       155
#                              GLASSES_FRAMES      0.952     0.929     0.940       296
#                                AIRSOFT_GUNS      0.948     0.967     0.958       245
#                                   HAND_FANS      0.800     0.875     0.836        32
#                                  SIDEBOARDS      0.970     0.960     0.965       201
#                            VEHICLE_STICKERS      0.957     0.968     0.962       530
#                              BABY_STROLLERS      0.934     0.972     0.953       468
#                                      MOVIES      0.803     0.690     0.742        71
#                          MICRO_ROTARY_TOOLS      0.955     0.928     0.941        69
#                                   SOUVENIRS      0.957     0.881     0.917       151
#                                      VODKAS      0.925     0.915     0.920        94
#                               PUREBRED_DOGS      0.938     0.966     0.952       705
#                                     VIOLINS      0.968     0.987     0.977       151
#                                 HOVERBOARDS      0.979     0.977     0.978       480
#                      SUSPENSION_BALL_JOINTS      0.986     0.972     0.979       579
#                                   BACKPACKS      0.946     0.974     0.960       699
#                              ADHESIVE_TAPES      0.934     0.949     0.941       253
#                           ELECTRICAL_CABLES      0.965     0.980     0.972       250
#                               COFFEE_TABLES      0.917     0.846     0.880        26
#                  INTERACTIVE_GAMING_FIGURES      0.968     0.984     0.976       246
#                   AUTOMOTIVE_AC_COMPRESSORS      0.878     0.837     0.857        43
#                       HAIRDRESSING_SCISSORS      0.975     0.969     0.972       160
#                                    CUSHIONS      0.904     0.925     0.914       213
#                   THERMAL_CUPS_AND_TUMBLERS      0.793     0.821     0.807        56
#         TV_REPLACEMENT_BACKLIGHT_LED_STRIPS      0.982     0.939     0.960       115
#                         ENGINE_INTAKE_HOSES      0.913     0.928     0.920       373
#                    AUTOMOBILE_FENDER_LINERS      1.000     0.944     0.971        18
#                              DJ_CONTROLLERS      0.886     0.846     0.865       175
#                                STUFFED_TOYS      0.812     0.839     0.825       679
#              MARTIAL_ARTS_AND_BOXING_GLOVES      0.947     0.976     0.961       254
#                               CAMERA_LENSES      0.919     0.936     0.928       219
#                                EROTIC_PUMPS      0.965     0.933     0.949        89
#                               PAINT_ROLLERS      1.000     0.909     0.952        11
#                                MEN_SWIMWEAR      0.833     0.556     0.667        18
#                 PORTABLE_CELLPHONE_CHARGERS      0.971     0.934     0.952       500
#                              ANALOG_CAMERAS      0.867     0.899     0.883       457
#                             HAIR_TREATMENTS      0.821     0.719     0.766        89
#                       DJ_EFFECTS_PROCESSORS      0.737     0.708     0.722       202
#                     BUMPER_IMPACT_ABSORBERS      0.964     0.971     0.967       245
#                  NOTEBOOKS_AND_WRITING_PADS      0.873     0.948     0.909       153
#                         FINGERPRINT_READERS      0.957     0.917     0.936        24
#                                    BLANKETS      0.842     0.893     0.867       131
#                                 SUPPLEMENTS      0.753     0.779     0.766       430
#                                    HAMMOCKS      0.976     0.976     0.976        82
#                AUTOMOTIVE_SIDE_VIEW_MIRRORS      0.963     0.965     0.964       737
#                   FACIAL_SKIN_CARE_PRODUCTS      0.762     0.806     0.783       341
#                             PACKAGING_ROLLS      1.000     1.000     1.000        26
#                       TV_AND_MONITOR_MOUNTS      0.977     0.993     0.985       546
#                                CAR_ANTENNAS      0.999     0.994     0.996       934
#                                    CACHACAS      0.974     0.936     0.955       157
#                                     TV_SMPS      0.886     0.864     0.875       279
#                              KITCHEN_TOWELS      0.968     0.986     0.977       277
#                                    CALIPERS      1.000     0.955     0.977        22
#                             PARKING_SENSORS      0.987     0.983     0.985       539
#                   ELECTRIC_PRESSURE_WASHERS      0.985     0.962     0.973       343
#              HAIR_SHAMPOOS_AND_CONDITIONERS      0.833     0.682     0.750        44
#                                STETHOSCOPES      0.939     0.861     0.899        36
#                                    PRINTERS      0.901     0.935     0.918       400
#                             ELECTRIC_DRILLS      0.935     0.966     0.950       414
#                                KITCHEN_POTS      0.939     0.948     0.944       485
#                              FUEL_INJECTORS      0.848     0.922     0.884       103
#                            VEHICLE_SPEAKERS      0.935     0.950     0.942       421
#                           HOME_OFFICE_DESKS      0.917     0.960     0.938       149
#                              GUITAR_STRINGS      0.885     0.943     0.913       106
#                             DISC_PACKAGINGS      0.865     0.865     0.865        74
#                                 LIP_GLOSSES      0.923     0.889     0.906       190
#                                     DRESSES      0.971     0.974     0.973       692
#                                BASS_GUITARS      0.938     0.946     0.942       467
#                                  TURNTABLES      0.846     0.852     0.849       270
#                           TOY_BUILDING_SETS      0.879     0.819     0.848       249
#                                  BED_SHEETS      0.882     0.893     0.887        75
#                               CAR_GEARBOXES      0.963     0.981     0.972       267
#                                FLOOD_LIGHTS      0.941     0.961     0.951       462
#                          SOLDERING_MACHINES      0.984     0.971     0.978       383
#                            ELECTRONIC_DRUMS      0.899     0.838     0.867       117
#                    DATA_CABLES_AND_ADAPTERS      0.933     0.875     0.903        80
#                      AUTOMOTIVE_WATER_PUMPS      0.893     0.898     0.895       391
#                              FOOTBALL_BALLS      0.950     0.981     0.965       156
#                                LENS_FILTERS      0.946     0.933     0.940        75
#                       INSTRUMENT_AMPLIFIERS      0.910     0.902     0.906       449
#                                MUSIC_STANDS      1.000     0.844     0.915        32
#                        CAR_DISTRIBUTOR_CAPS      0.954     0.917     0.935       205
#                                  MOUSE_PADS      0.975     0.975     0.975       201
#                                     FABRICS      0.881     0.897     0.889       379
#                               CABIN_FILTERS      0.976     1.000     0.988       244
#                             SEWING_MACHINES      0.907     0.938     0.923       292
#                                      MIXERS      0.968     0.946     0.957       350
#                         MOTORCYCLE_FAIRINGS      0.930     0.907     0.918       353
#                                   CV_JOINTS      0.975     0.959     0.967       443
#                  HAIR_STRAIGHTENING_BRUSHES      0.867     1.000     0.929        26
#                             WHEELS_BEARINGS      0.980     0.991     0.985       547
#                                AV_RECEIVERS      0.852     0.824     0.838       188
#                              NETWORK_CABLES      0.900     0.953     0.926       190
#                                       CRIBS      0.827     0.868     0.847       242
#                                HOME_HEATERS      0.933     0.893     0.913       234
#                  BRACELETS_AND_ANKLE_BRACES      0.889     0.925     0.907       346
#                                    SNEAKERS      0.941     0.889     0.914        72
#                  AUTOMOTIVE_THROTTLE_BODIES      0.979     0.920     0.948        50
#                              COOKING_SCALES      0.912     0.934     0.923       412
#                               PEDAL_EFFECTS      0.925     0.945     0.935       695
#                              ENGINE_PISTONS      0.908     0.902     0.905       132
#                               FLATWARE_SETS      0.903     0.903     0.903        31
#                                     PANTIES      0.857     0.857     0.857        49
#                          ELECTRICAL_OUTLETS      0.926     0.926     0.926       122
#                          BABY_CLOTHING_SETS      0.776     0.684     0.727        76
#                              STEAM_CLEANERS      0.789     0.789     0.789        19
#                            DECORATIVE_VASES      0.866     0.923     0.894       274
#                             FOOD_PROCESSORS      0.919     0.844     0.880       135
#                             TRAILER_HITCHES      0.989     0.995     0.992       184
#                       SOFA_AND_FUTON_COVERS      0.990     0.990     0.990        99
#                                      SHIRTS      0.888     0.873     0.880       118
#                       VEHICLE_CLUTCH_CABLES      0.900     0.900     0.900        10
#                                 GATE_MOTORS      0.966     0.953     0.959       298
#                                  FOG_LIGHTS      0.986     0.962     0.974       292
#                                   SIM_CARDS      0.955     0.875     0.913        24
#                               BABY_MONITORS      0.960     0.982     0.971       220
#                            VEHICLE_CV_AXLES      0.970     0.928     0.948        69
#                                   LIPSTICKS      0.948     0.964     0.956       562
#                      SERVING_AND_HOME_TRAYS      0.946     0.938     0.942       354
#                                    COOKTOPS      0.667     0.364     0.471        11
#                              GRAPHICS_CARDS      1.000     1.000     1.000        32
#                          FIRE_EXTINGUISHERS      1.000     0.967     0.983        30
#                  KITCHEN_CABINET_ORGANIZERS      0.500     0.143     0.222         7
#                                       SOFAS      0.867     0.910     0.888       100
#                            GRAPHICS_TABLETS      0.958     0.963     0.961       190
#                                      SHORTS      0.923     0.960     0.941       274
#                            SWIMMING_GOGGLES      0.940     0.818     0.875        77
#                            POOL_INFLATABLES      0.895     0.919     0.907        37
#                                       DOORS      0.867     0.876     0.872        97
#                               SPORT_WATCHES      0.908     0.929     0.918       478
#            PORTABLE_EVAPORATIVE_AIR_COOLERS      0.917     0.877     0.896       138
#              DOG_CARRIERS_AND_CARRYING_BAGS      0.981     0.930     0.955        57
#                     ENGINE_INTAKE_MANIFOLDS      0.962     0.980     0.971        51
#                          MOTORCYCLE_HELMETS      0.988     0.997     0.992       715
#                        COMBUSTION_CHAINSAWS      0.988     0.964     0.976        84
#               ELECTRONIC_ENTRANCE_INTERCOMS      0.952     0.938     0.945       211
#                                     CRAYONS      0.971     0.980     0.975       101
#                                THERMOMETERS      0.969     0.984     0.976        63
#                              CAMERA_TRIPODS      0.954     0.970     0.962       427
#                           ARTIFICIAL_PLANTS      0.700     0.519     0.596        27
#                            PROJECTOR_MOUNTS      0.750     0.600     0.667         5
#                 PORTABLE_ELECTRIC_MASSAGERS      0.926     0.904     0.915        83
#               NON_CORRECTIVE_CONTACT_LENSES      0.875     0.875     0.875        24
#                                     PUZZLES      0.909     0.946     0.927        74
#            WASHING_AND_DRYER_MACHINE_COVERS      0.925     0.980     0.951        50
#                        PUSH_AND_RIDING_TOYS      0.621     0.562     0.590        32
#                                SHOWER_HEADS      0.906     0.898     0.902       235
#                            ANTI_THEFT_STUDS      0.958     0.941     0.950       220
#                               HATS_AND_CAPS      0.859     0.846     0.853        65
#                                   MAGAZINES      0.692     0.580     0.631       143
#                  ENGINE_COOLING_FAN_SHROUDS      0.920     0.976     0.947        83
#                      AUTOMOTIVE_OIL_FILTERS      0.829     0.791     0.810        43
#                            MOTORCYCLE_TIRES      0.863     0.946     0.903       147
#               MOTORCYCLE_TURN_SIGNAL_LIGHTS      0.960     0.986     0.973       221
#                                     PILLOWS      0.933     0.903     0.918        31
#                                    TEQUILAS      0.941     0.970     0.955        33
#                                 TOILET_RUGS      0.887     0.847     0.867       249
#                                      FLUTES      0.898     0.898     0.898       128
#                                    UKULELES      0.945     1.000     0.972        52
#                                 TOOTHPASTES      0.871     0.871     0.871        62
#                       MOTORCYCLE_CRASH_BARS      0.833     0.714     0.769        21
#                             PIPES_AND_TUBES      0.545     0.462     0.500        13
#                                FOOD_SLICERS      0.944     0.773     0.850        22
#           DESKTOP_COMPUTER_COOLERS_AND_FANS      0.942     0.945     0.944       345
#                                   SWAY_BARS      0.968     0.929     0.948        98
#                            AQUARIUM_FILTERS      0.927     0.953     0.940       214
#               CELLPHONE_REPLACEMENT_CAMERAS      0.942     0.961     0.951        51
#                                     MIRRORS      0.884     0.884     0.884        86
#                             BLU_RAY_PLAYERS      0.946     0.909     0.927       175
#                          AUTOMOTIVE_FENDERS      0.948     0.887     0.917       124
#                             SPARKLING_WINES      0.500     0.250     0.333        12
#              ENGINE_VALVES_SPRING_RETAINERS      0.970     0.956     0.963        68
#                                BABY_WALKERS      1.000     0.923     0.960        13
#             ANTIVIRUS_AND_INTERNET_SECURITY      0.833     0.938     0.882        16
#                       COTTON_CANDY_MACHINES      1.000     1.000     1.000         7
#                             ORAL_IRRIGATORS      1.000     0.750     0.857         8
#                    MOTORCYCLE_CLUTCH_COVERS      0.883     0.946     0.913       239
#                               GAME_CONSOLES      0.926     0.862     0.893       347
#                               TABLE_RUNNERS      0.943     0.985     0.964        67
#                           PLAYGROUND_SLIDES      0.909     0.769     0.833        13
#                                 3D_PRINTERS      0.978     0.936     0.957        47
#                                 DIAPER_BAGS      0.912     0.903     0.907       103
#                               ELECTRIC_SAWS      0.973     0.978     0.975       363
#                           KITCHEN_FURNITURE      0.800     0.947     0.867        38
#                            BABY_HIGH_CHAIRS      0.766     0.557     0.645        88
#                                    MINI_PCS      0.800     0.571     0.667        14
#                                    MASCARAS      0.894     0.913     0.903        92
#                     AUTOMOTIVE_WHEEL_COVERS      0.924     0.946     0.935       129
#                           WINDSHIELD_WIPERS      0.964     0.974     0.969       190
#                                     LIQUORS      0.940     0.940     0.940       100
#                            CLOTHING_PATCHES      0.962     0.862     0.909        58
#                       WOOD_BURNING_MACHINES      1.000     1.000     1.000         7
#                                  BINOCULARS      0.955     0.919     0.937       186
#                      COMMERCIAL_LIGHT_SIGNS      0.970     1.000     0.985        32
#                            WATER_DISPENSERS      0.972     0.938     0.955       225
#                       GLOW_PLUG_CONTROLLERS      0.946     0.946     0.946        56
#                                  TELEPHONES      0.789     0.714     0.750        21
#                             AIR_COMPRESSORS      0.921     0.960     0.940       353
#                           OPERATING_SYSTEMS      0.873     0.889     0.881       270
#                        CAR_ENGINE_CAMSHAFTS      0.833     1.000     0.909        15
#                             CLOTHES_HANGERS      0.989     0.946     0.967        92
#                                    WETSUITS      1.000     0.842     0.914        19
#                                TOILET_SEATS      0.989     0.984     0.987       191
#                            AUTOMOTIVE_DOORS      0.962     0.982     0.972       332
#             SUSPENSION_CONTROL_ARM_BUSHINGS      0.878     0.833     0.855       138
#                          VEHICLE_BRAKE_PADS      0.956     0.986     0.970       350
#                 REMOTE_CONTROL_TOY_VEHICLES      0.823     0.890     0.855       209
#                        AUTOMOTIVE_NERF_BARS      0.974     1.000     0.987        38
#                              ESSENTIAL_OILS      0.815     0.815     0.815        65
#                             SLATWALL_PANELS      1.000     1.000     1.000        80
#                                  TOOL_BOXES      0.954     0.954     0.954       109
#                                BABY_DIAPERS      0.984     0.971     0.977       375
#                          ALARMS_AND_SENSORS      0.919     0.925     0.922       295
#                            MOTORCYCLE_SUITS      0.944     0.919     0.932        37
#                               KITCHEN_BOWLS      0.727     0.727     0.727        22
#                              CAT_SCRATCHERS      0.857     0.800     0.828        15
#                              INK_CARTRIDGES      0.826     0.633     0.717        30
#                    MARKERS_AND_HIGHLIGHTERS      0.887     0.873     0.880       126
#                      JUMPSUITS_AND_OVERALLS      0.896     0.811     0.851       106
#                                 NAIL_DRYERS      0.954     0.947     0.950       131
#                             CAMERA_MONOPODS      0.840     0.857     0.848        49
#                                    BICYCLES      0.972     0.957     0.964       184
#                                        SALT      1.000     1.000     1.000        10
#                    SCREEN_PRINTING_MACHINES      0.857     0.429     0.571        14
#                                        BEDS      0.907     0.907     0.907        43
#                     BODY_SKIN_CARE_PRODUCTS      0.749     0.776     0.762       380
# AUTOMOTIVE_MANUAL_TRANSMISSION_SHIFT_LEVERS      0.767     0.920     0.836        25
#                            TV_STORAGE_UNITS      0.917     0.846     0.880        52
#                       AUTOMOTIVE_HEADLIGHTS      0.928     0.985     0.956       131
#                                  PAINTBALLS      0.908     0.929     0.919        85
#                                      SCREWS      0.833     0.877     0.855        57
#                                  TOY_ROBOTS      0.667     0.533     0.593        15
#                                     POSTERS      0.922     0.971     0.946       206
#                            MOTORCYCLE_PANTS      0.900     0.839     0.868       118
#                         INTEGRATED_CIRCUITS      0.627     0.722     0.671        72
#                                GARDEN_HOSES      0.963     0.929     0.945        56
#                                 ALTERNATORS      0.896     0.896     0.896        48
#                          MAGNIFYING_GLASSES      0.942     0.934     0.938       122
#                                    PERFUMES      0.941     0.923     0.932        52
#                                       FLOUR      0.882     1.000     0.938        15
#                                FISHING_RODS      0.531     0.895     0.667        19
#                  CELLPHONE_AND_TABLET_CASES      0.884     0.923     0.903        91
#                                     PAJAMAS      0.964     0.946     0.955        56
#                                  BUTT_PLUGS      0.737     0.824     0.778        34
#                 LUMBAR_AND_ABDOMINAL_BRACES      0.959     0.966     0.963       147
#                              AIR_MATTRESSES      0.931     0.961     0.946       154
#                               WATER_HEATERS      0.975     0.947     0.961       247
#                                 DISHWASHERS      0.952     0.932     0.942       148
#                        ELECTRIC_LAWN_MOWERS      1.000     0.500     0.667         4
#                               HOME_THEATERS      0.800     0.444     0.571         9
#                            LED_STAGE_LIGHTS      0.869     0.801     0.834       216
#           CHALKBOARD_AND_WHITEBOARD_ERASERS      1.000     0.783     0.878        23
#                               BABY_BOUNCERS      0.773     0.944     0.850        18
#                                       RINGS      0.886     0.907     0.897        43
#                      AUTOMOTIVE_AIR_FILTERS      0.907     0.891     0.899        55
#                                LUGGAGE_TAGS      0.894     0.894     0.894        47
#                                HEATER_CORES      1.000     0.714     0.833        21
#                             CLEANING_CLOTHS      0.955     0.903     0.928        93
#                              AIR_FRESHENERS      0.634     0.605     0.619        43
#                                     BLOUSES      0.806     0.658     0.725        38
#                             SAFETY_FOOTWEAR      1.000     0.985     0.992        66
#                                FREEZER_BAGS      0.875     0.875     0.875         8
#                      SHOCK_MOUNT_INSOLATORS      0.759     0.822     0.789        73
#                                  BAR_CLAMPS      1.000     0.812     0.897        16
#                             CHRISTMAS_TREES      0.944     0.919     0.932        37
#                          CAR_AIR_FRESHENERS      0.838     0.838     0.838        99
#                          BASKETBALL_JERSEYS      1.000     0.800     0.889        15
#                                  ACCORDIONS      0.984     0.974     0.979       311
#                                  FOOD_CARTS      0.935     0.935     0.935        31
#                                   HEAT_GUNS      0.989     0.989     0.989        94
#                   ENGINE_CRANKSHAFT_PULLEYS      0.943     0.925     0.934       107
#                                  PARTY_HATS      0.833     0.625     0.714         8
#                             RECEPTION_DESKS      1.000     1.000     1.000         4
#                              PICTURE_FRAMES      0.874     0.921     0.897       151
#                               OSCILLOSCOPES      0.900     0.900     0.900        10
#                   HABERDASHERY_LACE_EDGINGS      0.880     0.872     0.876       109
#                                       BEERS      0.965     0.965     0.965       170
#                                HOLE_PUNCHES      1.000     0.571     0.727         7
#                               DJ_TURNTABLES      0.742     0.575     0.648        80
#                                 VR_HEADSETS      0.966     0.980     0.973       352
#                             KITCHEN_MORTARS      1.000     0.750     0.857         4
#                                       OVENS      0.948     0.965     0.957       171
#                                DISHES_RACKS      0.604     0.653     0.627        49
#                                    EARRINGS      0.891     0.932     0.911        44
#                                   WARDROBES      0.939     0.861     0.899        36
#                           RACKS_AND_PINIONS      0.955     0.947     0.951       113
#                                   BOOKCASES      0.829     0.829     0.829        35
#                                  TOY_TRAINS      0.868     0.702     0.776        94
#                      CARD_PAYMENT_TERMINALS      0.842     0.941     0.889        17
#                           SUBMERSIBLE_PUMPS      0.980     0.970     0.975       100
#             GARDENING_AND_AGRICULTURE_SEEDS      0.897     0.972     0.933        36
#                                      MODEMS      0.792     0.805     0.798       123
#                               OFFICE_CHAIRS      0.883     0.929     0.905        98
#                                   PENDRIVES      0.919     0.899     0.909       139
#                                   NECKLACES      0.872     0.824     0.847        91
#                          ENGINE_GASKET_SETS      0.600     0.353     0.444        17
#                  AUTOMOTIVE_SHOCK_ABSORBERS      0.738     0.939     0.827        66
#                                 VINYL_ROLLS      0.656     0.600     0.627        70
#               TROLLEY_AND_FURNITURE_CASTERS      1.000     0.250     0.400         4
#                   TV_RECEIVERS_AND_DECODERS      0.765     0.722     0.743        18
#                                LIFE_JACKETS      0.889     0.727     0.800        22
#                        SELF_ADHESIVE_LABELS      0.905     0.776     0.835        49
#                   IGNITION_SWITCH_ACTUATORS      1.000     1.000     1.000        14
#                            BABY_STERILIZERS      0.750     0.682     0.714        22
#                       PARKING_BRAKE_HANDLES      0.984     0.984     0.984        61
#                      CLUTCH_SLAVE_CYLINDERS      0.700     0.700     0.700        30
#                                      FISHES      1.000     0.333     0.500         9
#                             COOKIES_CUTTERS      0.920     0.896     0.908        77
#                                  NEBULIZERS      0.957     0.918     0.938        49
#                                  COMFORTERS      0.696     0.800     0.744        20
#                         ELLIPTICAL_MACHINES      0.884     0.891     0.887       128
#                               ENGINE_VALVES      0.891     0.932     0.911        44
#                                  SANDPAPERS      0.889     0.762     0.821        21
#        AUTOMOTIVE_SHOCK_ABSORBER_BUMP_STOPS      1.000     0.892     0.943        37
#                                     GAZEBOS      0.966     0.923     0.944        91
#                                  XENON_KITS      0.905     0.950     0.927        20
#                      AUTOMOTIVE_DOOR_PANELS      0.955     0.993     0.974       150
#                  INDOOR_CURTAINS_AND_BLINDS      0.962     0.938     0.950       161
#                         CAR_WINDOW_SWITCHES      0.821     0.742     0.780        31
#                                   EPILATORS      0.837     0.819     0.828        94
#                           MALE_MASTURBATORS      0.867     0.867     0.867        15
#                         DRILLS_SCREWDRIVERS      0.524     0.458     0.489        24
#                                  CONCEALERS      0.886     0.886     0.886        88
#                     SCHOOL_AND_OFFICE_GLUES      0.545     0.600     0.571        10
#                      SANDALS_AND_FLIP_FLOPS      0.913     0.933     0.923        45
#                                   BAR_SOAPS      0.789     0.750     0.769        60
#                   ELECTRIC_BATHROOM_FAUCETS      0.870     0.800     0.833        25
#                           VOLTAGE_DETECTORS      1.000     0.966     0.982        29
#                     ORTHOPEDIC_ANKLE_BRACES      1.000     0.733     0.846        15
#                              HEDGE_TRIMMERS      0.933     1.000     0.966        14
#                         STABILIZERS_AND_UPS      1.000     1.000     1.000         2
#                               BABY_PLAYARDS      0.839     0.855     0.847       110
#                            RESISTANCE_BANDS      0.910     0.956     0.932       180
#                             LAPTOP_CHARGERS      0.917     0.809     0.859        68
#                       COMPUTER_MOTHERBOARDS      0.739     0.829     0.782        41
# ...
#                            LIVING_ROOM_SETS      0.778     0.500     0.609        14
#                              BABY_PACIFIERS      1.000     0.800     0.889        15
#                              HAND_POLISHERS      0.846     0.786     0.815        14
#                                SHADE_CLOTHS      0.923     1.000     0.960        12
#                               HAMMER_DRILLS      0.714     0.625     0.667         8
#                              POWER_GRINDERS      0.900     0.692     0.783        13
#                               CAMERA_STRAPS      1.000     0.333     0.500         3
#                           LAWN_MOWER_BLADES      0.800     0.444     0.571         9
#                          PNEUMATIC_STAPLERS      0.929     1.000     0.963        13
#              THERMAL_REFRIGERATORS_AND_BAGS      0.783     0.643     0.706        28
#                                LIGHT_STANDS      1.000     0.571     0.727         7
#                                      STRAWS      0.857     0.750     0.800         8
#                                       SUITS      0.786     0.667     0.721        33
#                           BATHROOM_VANITIES      0.833     0.625     0.714         8
#                         VIBRATION_PLATFORMS      1.000     0.833     0.909        18
#                               DINING_TABLES      0.846     0.688     0.759        16
#                           TURNTABLE_NEEDLES      1.000     0.667     0.800         3
#                                HEARING_AIDS      1.000     0.800     0.889        10
#                     ORTHOPEDIC_WALKER_BOOTS      0.667     0.571     0.615        14
#                                         TEA      0.857     0.600     0.706        10
#                             TORQUE_WRENCHES      1.000     0.625     0.769         8
#                                 CATS_LITTER      0.846     0.917     0.880        12
#                                 MATE_GOURDS      0.889     0.727     0.800        11
#                                  MEAT_HOOKS      1.000     1.000     1.000         2
#                       AUTOMOTIVE_DEFLECTORS      1.000     1.000     1.000         5
#                   VARIABLE_FREQUENCY_DRIVES      1.000     0.857     0.923         7
#                                  SWEETENERS      1.000     1.000     1.000         8
#         AUTOMOTIVE_CELLPHONE_AND_GPS_MOUNTS      1.000     0.667     0.800         6
#                         RADIO_BASE_STATIONS      0.333     0.167     0.222         6
#                                    CRUTCHES      1.000     0.250     0.400         4
#                                POWER_STRIPS      0.714     0.500     0.588        10
#                               KATANA_SWORDS      0.846     0.846     0.846        13
#                        CATS_AND_DOGS_TREATS      1.000     0.429     0.600        14
#                         MEMORY_CARD_READERS      0.667     0.667     0.667         3
#                            TELEPHONE_CABLES      1.000     0.929     0.963        14
#                          SOLID_SWEET_PASTES      1.000     0.700     0.824        10
#                           DISPOSABLE_GLOVES      0.000     0.000     0.000         3
#                        MOTORCYCLE_GRAB_BARS      1.000     1.000     1.000         3
#                              PLUNGE_ROUTERS      1.000     0.625     0.769         8
#                         GROOVE_JOINT_PLIERS      0.800     1.000     0.889         4
#                          BICYCLE_HANDLEBARS      0.000     0.000     0.000         5
#                          SOLDERING_STATIONS      0.960     0.923     0.941        26
#                               TANDEM_CHAIRS      0.500     0.429     0.462         7
#                                GARAGE_DOORS      0.800     0.667     0.727        12
#                         SPARK_PLUG_WIRESETS      0.929     0.812     0.867        32
#                       ELECTRIC_SHOWER_HEADS      1.000     0.400     0.571         5
#                        PORTABLE_DVD_PLAYERS      0.600     0.667     0.632         9
#                                      DILDOS      0.429     0.375     0.400         8
#                   INDUSTRIAL_DOUGH_KNEADERS      0.800     0.615     0.696        13
#                   UNIVERSAL_REMOTE_CONTROLS      0.333     0.333     0.333         3
#                                 WHEEL_STUDS      0.250     0.333     0.286         6
#                            FABRIC_SOFTENERS      0.864     1.000     0.927        19
#              MOTORCYCLE_DISTRIBUTION_CHAINS      0.941     0.842     0.889        19
#                       DOOR_AND_WINDOW_LOCKS      0.500     0.333     0.400         3
#                                        GINS      1.000     0.250     0.400         4
#                                 HAND_TRUCKS      1.000     0.500     0.667         4
#                                    STAPLERS      1.000     0.833     0.909         6
#                                   APERITIFS      1.000     0.800     0.889         5
#                             SHOWER_CURTAINS      1.000     0.750     0.857         4
#                              ANTIQUE_CHAIRS      1.000     0.143     0.250         7
#                               YOGURT_MAKERS      1.000     0.600     0.750         5
#                                 SHIN_GUARDS      0.000     0.000     0.000         2
#                             GOLF_CLUBS_SETS      1.000     0.778     0.875         9
#                  FOOTBALL_GOALKEEPER_GLOVES      1.000     0.875     0.933        16
#                                LASER_LEVELS      0.714     0.625     0.667         8
#                        KEYBOARD_CONTROLLERS      0.250     0.400     0.308         5
#                          ALTERNATOR_PULLEYS      0.944     1.000     0.971        17
#            CAMERA_AND_CELLPHONE_STABILIZERS      1.000     0.667     0.800         3
#                                BABY_JUMPERS      1.000     0.667     0.800         6
#                 CAMERA_REPLACEMENT_DISPLAYS      1.000     0.857     0.923         7
#                                 CRANKSHAFTS      0.714     0.714     0.714        21
#                                BREAD_MAKERS      0.750     1.000     0.857         3
#                    SCHOOL_AND_OFFICE_PAPERS      0.750     0.375     0.500         8
#                    STOVETOP_POPCORN_POPPERS      1.000     0.625     0.769         8
#                      BREAST_FEEDING_PILLOWS      1.000     0.818     0.900        11
#                               POOL_CLEANERS      1.000     0.600     0.750         5
#                              LINEMAN_PLIERS      0.750     1.000     0.857         3
#                                  COAT_RACKS      0.429     0.500     0.462         6
#                                  POOL_PUMPS      1.000     0.917     0.957        12
#                     WATER_PURIFIERS_FILTERS      0.667     0.500     0.571        20
#                               SAFETY_GLOVES      0.750     0.500     0.600         6
#                          ISOPROPYL_ALCOHOLS      1.000     0.667     0.800         9
#               VEHICLE_BRAKE_HYDRAULIC_HOSES      1.000     0.556     0.714         9
#                              MEDICINE_BALLS      0.500     0.250     0.333         4
#                             KITCHEN_GRATERS      0.667     0.400     0.500         5
#                              NAPKIN_HOLDERS      1.000     0.444     0.615         9
#                               PUNCHING_BAGS      1.000     0.333     0.500         3
#                                 ESPADRILLES      0.800     0.500     0.615         8
#                         CAR_CENTER_CONSOLES      0.500     0.167     0.250         6
#                             VIDEO_CASSETTES      0.714     0.833     0.769         6
#                              POTENTIOMETERS      1.000     0.400     0.571         5
#                    READY_TO_DRINK_COCKTAILS      0.333     0.500     0.400         2
#                                 FLOOR_LAMPS      0.538     0.636     0.583        11
#                            DRONE_PROPELLERS      0.800     0.667     0.727         6
#                                       TENTS      0.800     0.727     0.762        11
#                            SAFETY_HARNESSES      1.000     0.500     0.667         4
#                                    SYRINGES      0.667     0.500     0.571         4
#                                   BEDLINERS      0.857     0.750     0.800        16
#                     ELECTROLYTIC_CAPACITORS      1.000     0.714     0.833         7
#                                BASKET_BALLS      1.000     1.000     1.000         2
#                                   OTOSCOPES      0.667     0.500     0.571         4
#                               WAFFLE_MAKERS      0.875     0.875     0.875         8
#                                 PENIS_RINGS      0.667     0.500     0.571         4
#                          ELECTRIC_AIR_PUMPS      0.800     0.500     0.615         8
#                             COFFEE_CAPSULES      1.000     0.600     0.750         5
#                         BABY_PACIFIER_CLIPS      0.625     1.000     0.769         5
#                                   KEY_RACKS      0.000     0.000     0.000         4
#                                  DEODORANTS      1.000     0.800     0.889         5
#                          INDUSTRIAL_PULLEYS      1.000     1.000     1.000         5
#                               BILL_COUNTERS      0.800     0.800     0.800         5
#                  AUDIO_AND_VIDEO_CONNECTORS      0.000     0.000     0.000         4
#                            WASHING_MACHINES      0.889     0.667     0.762        12
#                 ENGINE_COOLING_FAN_SWITCHES      1.000     0.667     0.800         6
#                        AUTOMOTIVE_BATTERIES      0.250     0.200     0.222         5
#                        CHIP_AND_DIP_SERVERS      0.000     0.000     0.000         4
#                                ARCHERY_BOWS      0.750     1.000     0.857         6
#                             VINYL_FLOORINGS      0.714     0.714     0.714         7
#                              MENSTRUAL_CUPS      1.000     1.000     1.000         5
#                               SLEEPING_BAGS      0.400     0.500     0.444         4
#                               RUBBER_STAMPS      1.000     0.600     0.750         5
#                              DRYER_MACHINES      0.875     0.875     0.875         8
#                            ENERGETIC_STONES      0.750     0.857     0.800         7
#                              BICYCLE_PEDALS      1.000     0.778     0.875         9
#                      MOTORCYCLE_CARBURETORS      0.667     0.400     0.500         5
#                           SCREWDRIVERS_SETS      1.000     0.333     0.500         3
#                                EDIBLE_SEEDS      1.000     0.333     0.500         3
#                        STORE_SHOPPING_CARTS      1.000     0.750     0.857         4
#                         SWIMMING_NOSE_CLIPS      1.000     0.500     0.667         2
#                                 AFTERSHAVES      0.000     0.000     0.000         3
#                              AIRBAG_MODULES      1.000     1.000     1.000         3
#                                   HAND_SAWS      0.857     1.000     0.923         6
#           NECK_GAITERS_MASKS_AND_BALACLAVAS      0.000     0.000     0.000         2
#                          MAGNETIC_COMPASSES      1.000     1.000     1.000         6
#                          MAKEUP_TRAIN_CASES      1.000     0.500     0.667         4
#                            POPCORN_MACHINES      1.000     0.889     0.941         9
#                                LAMP_HOLDERS      0.400     0.500     0.444         4
#                    IGNITION_CONTROL_MODULES      1.000     0.286     0.444         7
#                             CAR_FRONT_MASKS      1.000     0.500     0.667         2
#                               HAND_BLENDERS      0.000     0.000     0.000         3
#                              KIDS_TRICYCLES      0.000     0.000     0.000         4
#                              AIRGUN_PELLETS      0.500     0.250     0.333         4
#                            AUTOMOTIVE_SEATS      0.400     0.333     0.364         6
#              MOTORCYCLE_TRANSMISSION_CROWNS      1.000     0.250     0.400         4
#                                  LAMINATORS      1.000     0.571     0.727         7
#                                 CEREAL_BARS      1.000     0.667     0.800         3
#                                MUSIC_ALBUMS      0.000     0.000     0.000         4
#                   AUTOMOTIVE_CV_JOINT_BOOTS      0.667     0.857     0.750         7
#                           MICROWAVE_KEYPADS      1.000     1.000     1.000         3
#                           WALL_ANCHOR_PLUGS      0.750     0.750     0.750         4
#                                 DRUM_STANDS      0.750     0.429     0.545         7
#                                 PET_COLLARS      0.846     0.786     0.815        14
#                             GATE_GEAR_RACKS      1.000     0.500     0.667         4
#                                   CAR_HOODS      0.667     0.667     0.667         3
#                        SCREEN_PRINTING_KITS      0.500     0.250     0.333         4
#                                  LED_STRIPS      0.600     0.750     0.667         4
#                             SANDWICH_MAKERS      0.000     0.000     0.000         2
#                              DENTAL_FLOSSES      1.000     1.000     1.000         2
#                              CAMERA_FLASHES      1.000     0.600     0.750         5
#                           DOG_NAIL_CLIPPERS      1.000     1.000     1.000         2
#                                    PINBALLS      0.800     0.667     0.727         6
#                                      GAUZES      1.000     0.667     0.800         6
#                                        SODS      0.667     0.667     0.667         3
#                          ELECTRICITY_METERS      0.000     0.000     0.000         4
#                             METAL_DETECTORS      1.000     0.667     0.800         3
#                          ELECTRIC_CHAINSAWS      1.000     0.333     0.500         3
#                            KNITTING_NEEDLES      0.455     0.833     0.588         6
#                           SWIMMING_EARPLUGS      0.000     0.000     0.000         2
#                                 SOUND_CARDS      0.667     0.800     0.727         5
#                                    STEPPERS      0.250     0.250     0.250         4
#                                 FANNY_PACKS      0.000     0.000     0.000         4
#                          TOOTHBRUSH_HOLDERS      0.000     0.000     0.000         2
#                          TABLE_TENNIS_BALLS      1.000     0.500     0.667         2
#                 ENGINE_OIL_PRESSURE_SENSORS      0.500     0.333     0.400         3
#                                 ICE_BUCKETS      1.000     0.429     0.600         7
#                               MASSAGE_SOFAS      1.000     0.750     0.857         4
#                              STYLING_CHAIRS      1.000     0.500     0.667         2
#                               BICYCLE_SEATS      1.000     0.333     0.500         3
#                            VOLLEYBALL_BALLS      0.000     0.000     0.000         3
#                           SPHYGMOMANOMETERS      0.333     0.500     0.400         4
#                              BINDING_SPINES      0.000     0.000     0.000         2
#                    DIGITAL_WEATHER_STATIONS      1.000     1.000     1.000         2
#                          HOME_BOTTLE_STANDS      1.000     0.667     0.800         3
#                                   DOORBELLS      1.000     0.500     0.667         2
#                                DRIED_FRUITS      1.000     1.000     1.000         2
#                            BOXING_HEADGEARS      0.000     0.000     0.000         2
#
#                                    accuracy                          0.924    138550
#                                   macro avg      0.859     0.792     0.814    138550
#                                weighted avg      0.924     0.924     0.923    138550
