# %% [markdown]
# #### Based on https://medium.com/swlh/painless-fine-tuning-of-bert-in-pytorch-b91c14912caa
# https://github.com/aniruddhachoudhury/BERT-Tutorials/blob/master/Blog%202/BERT_Fine_Tuning_Sentence_Classification.ipynb

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import matplotlib.pyplot as plt
import torch.nn as nn
from os.path import join
import torch
from nlpClassifiers.data.dataset  import NLPDataset
from nlpClassifiers.models.models import BertSentenceFeaturesModel
#from torch.optim import AdamW, SGD
from torch.utils.data import DataLoader, SequentialSampler, RandomSampler
from transformers import BertForSequenceClassification, AdamW, BertConfig
from transformers import get_linear_schedule_with_warmup
from torch.nn import LayerNorm as BertLayerNorm
import numpy as np
import time
import logging
import datetime
import random
import pandas as pd
import argparse
import pickle as pk
import itertools
import os
import shutil
from pathlib import Path
import copy
import wandb
import re
from nlpClassifiers import settings
from scipy.special import expit
from sklearn.metrics import classification_report
# Out:
# wandb: WARNING W&B installed but not logged in.  Run `wandb login` or set the WANDB_API_KEY env variable.

# %%
def predict(
    model_path: Path,
    dataset: str,
    batch_size: int,
    labels_dict,
    device: torch.device
):

    print(f"====Loading dataset for testing")
    test_corpus = NLPDataset(dataset, "test", sentence_max_len, bert_path, labels_dict)
    test_dataloader = DataLoader(
        test_corpus,
        batch_size=batch_size,
        sampler = RandomSampler(test_corpus),
        pin_memory=True,
        num_workers=0,
        drop_last=True
    )

    print(f"====Loading model for testing")
    model = torch.load(join(model_path, "best-model.pth"))
    model.to(device)
    model.eval()
    pred_labels = []
    test_labels = []
    logits_list = []

    def _list_from_tensor(tensor):
        if tensor.numel() == 1:
            return [tensor.item()]
        return list(tensor.cpu().detach().numpy())

    print("====Testing model...")
    for batch in test_dataloader:
        batch = tuple(t.to(device) for t in batch)
        b_input_ids, b_segment_ids, b_input_mask, b_labels = batch
        with torch.no_grad():
            loss, logits= model(b_input_ids,  b_segment_ids, b_labels)
            preds = np.argmax(logits.cpu(), axis=1) # Convert one-hot to index
            b_labels = b_labels.int()
            pred_labels.extend(_list_from_tensor(preds))
            test_labels.extend(_list_from_tensor(b_labels))
        logits_list.extend(_list_from_tensor(logits))

    print(classification_report(test_labels, pred_labels, labels=list(labels_dict.values()), target_names=np.array(list(labels_dict.keys())), digits=3))
    logits_list = expit(logits_list)

    del model
    torch.cuda.empty_cache()

# %%
def get_accuracy_from_logits(logits, labels):
    acc = (labels.cpu() == logits.cpu().argmax(-1)).float().detach().numpy()
    return float(100 * acc.sum() / len(acc))

# %%
DATA_PATH = '../../data/virtual-operator'
MODELS_PATH = '../../models/virtual-operator/bert-base-portuguese-tapt-classifier/'
PATH_TO_BERT = '../../models/virtual-operator/bertimbau-adaptive-base-finetuned/'
TRAIN_DATASET = os.path.join(DATA_PATH, 'train.csv')
VAL_DATASET = os.path.join(DATA_PATH, 'val.csv')
TEST_DATASET  = os.path.join(DATA_PATH, 'test.csv')
PATH_TO_VIRTUAL_OPERATOR_MODELS =  "../../models/virtual-operator"
PATH_TO_AGENT_BENCHMARK_MODELS = "../../models/agent-benchmark"
PATH_TO_ML_PT_MODELS = "../../models/mercado-livre-pt-only"

# %%
gpu = 7
dataset = 'mercado-livre-pt'
save_name = 'bert-features-classifier-cls-mercado-livre-pt'
bert_path = 'neuralmind/bert-base-portuguese-cased'
batch_size = 16
sentence_max_len = 30

# %%
BASE_PATH_TO_MODELS = {"virtual-operator": PATH_TO_VIRTUAL_OPERATOR_MODELS, "agent-benchmark": PATH_TO_AGENT_BENCHMARK_MODELS, "mercado-livre-pt": PATH_TO_ML_PT_MODELS}
FULL_PATH_TO_MODELS = join(BASE_PATH_TO_MODELS[dataset], "bert-base-portuguese-tapt-classifier")

# %%
device = torch.device(f"cuda:{gpu}")

# %%
model_path = Path(
    FULL_PATH_TO_MODELS, 
    f"base-dataset-{dataset}-{save_name}"
)
last_saved_model = model_path

# %%
train_corpus = NLPDataset(dataset, "train", sentence_max_len, bert_path)
labels_dict = train_corpus.labels_dict

# %%
predict(last_saved_model, dataset, batch_size, labels_dict, device)
# Out:
# ====Loading dataset for testing
# ====Loading model for testing
# ====Testing model...
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/_classification.py:1221: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#                                              precision    recall  f1-score   support
#
#                               FISHING_LINES      0.861     0.913     0.886       583
#                      MOBILE_DEVICE_CHARGERS      0.976     0.973     0.974       804
#                                  SUNGLASSES      0.977     0.984     0.981       875
#                                    FREEZERS      0.919     0.944     0.931       444
#                                  CAR_WHEELS      0.986     0.996     0.991       720
#                            BATHROOM_FAUCETS      0.871     0.910     0.890       521
#                              ACTION_FIGURES      0.752     0.731     0.741       800
#                                       IRONS      0.979     0.977     0.978       433
#                                  MATTRESSES      0.976     0.989     0.982       534
#                       SWIMMING_POOL_HEATERS      0.909     0.952     0.930        21
#                              KITCHEN_KNIVES      0.937     0.955     0.946       202
#                                 TELEVISIONS      0.956     0.962     0.959       728
#                    SPORT_AND_BAZAAR_BOTTLES      0.971     0.882     0.924       229
#                                    STARTERS      0.980     0.975     0.977       354
#                                  FACE_MASKS      0.849     0.916     0.881       166
#                             KITCHEN_FAUCETS      0.904     0.893     0.898       431
#     TACTICAL_AND_SPORTING_KNIVES_AND_BLADES      0.969     0.939     0.954       164
#                                   NOTEBOOKS      0.944     0.954     0.949       543
#                                 DEEP_FRYERS      0.991     0.958     0.974       455
#                                TORSION_BARS      1.000     1.000     1.000       123
#                            AUDIO_AMPLIFIERS      0.833     0.849     0.841       311
#                              CEILING_LIGHTS      0.946     0.968     0.957       472
#                                       BELTS      0.941     0.980     0.960        49
#                    AUTOMOTIVE_WEATHERSTRIPS      0.962     0.970     0.966       788
#                                  HEADBOARDS      0.987     0.987     0.987       228
#                                       YARNS      0.849     0.951     0.897       142
#                                SMARTWATCHES      0.895     0.964     0.928       724
#                             FOOTBALL_SHIRTS      0.964     0.973     0.969       921
#                      AUTOMOTIVE_CLUTCH_KITS      0.992     0.996     0.994       719
#                                WRISTWATCHES      0.957     0.968     0.963       876
#                                  WALLPAPERS      0.984     0.928     0.955       885
#         AUTOMOTIVE_SIDE_VIEW_MIRROR_GLASSES      0.989     0.989     0.989       536
#                            AUDIO_INTERFACES      0.945     0.920     0.932       300
#                            KITCHEN_PLAYSETS      0.921     0.930     0.925       100
#                                 LIGHT_BULBS      0.926     0.961     0.943       829
#                              CELL_BATTERIES      0.974     0.964     0.969       670
#                        SURVEILLANCE_CAMERAS      0.945     0.888     0.915       909
#                                   THERMOSES      0.814     0.920     0.864       100
#                  HUMIDIFIERS_AND_VAPORIZERS      0.949     0.971     0.960       173
#                              KITCHEN_APRONS      0.864     0.704     0.776        27
#                         PORTABLE_GENERATORS      0.992     0.992     0.992       132
#                                  CELLPHONES      0.926     0.915     0.920       329
#                            HANDICRAFT_BOXES      0.854     0.786     0.819       112
#                         EMBROIDERY_MACHINES      0.920     0.902     0.911        51
#                                     CAMERAS      0.871     0.880     0.876        92
#             DESKTOP_COMPUTER_POWER_SUPPLIES      0.980     0.987     0.983       679
#                              BABIES_FORMULA      0.966     0.977     0.972        88
#                     MOTORCYCLE_SPEEDOMETERS      1.000     0.500     0.667         4
#                                     CARPETS      0.954     0.974     0.964       857
#                       CARDS_AND_INVITATIONS      0.870     0.851     0.860        47
#                            ELECTRIC_GUITARS      0.971     0.978     0.974       778
#                           COMPUTER_MONITORS      0.977     0.977     0.977       701
#                          MULTIGAME_MACHINES      0.831     0.896     0.862        77
#                                 TABLECLOTHS      0.982     0.982     0.982       544
#                                   VIBRATORS      0.820     0.897     0.857       117
#                                      PLANTS      0.978     0.981     0.979       313
#                                AM_FM_RADIOS      0.939     0.927     0.933       383
#                      ENGINE_CONTROL_MODULES      0.995     0.993     0.994       415
#             LATEX_ENAMEL_AND_ACRYLIC_PAINTS      1.000     1.000     1.000        67
#             MUSICAL_KEYBOARD_CASES_AND_BAGS      0.991     0.986     0.988       760
#                                 VIDEO_GAMES      0.977     0.987     0.982       908
#                          ARTIFICIAL_FLOWERS      0.945     0.976     0.960       497
#                          OUTER_TIE_ROD_ENDS      0.988     0.976     0.982       496
#                           EXHAUST_MANIFOLDS      0.889     1.000     0.941         8
#                     DIGITAL_VOICE_RECORDERS      0.893     0.948     0.920       774
#                               REFRIGERATORS      0.946     0.966     0.956       524
#                             DISPOSABLE_CUPS      0.881     0.867     0.874       188
#                                  EYESHADOWS      0.982     0.974     0.978       738
#                                      RANGES      0.962     0.964     0.963       450
#          AUTOMOTIVE_POWER_WINDOW_REGULATORS      0.977     0.920     0.948       138
#                                     HOOKAHS      0.994     0.964     0.979       168
#                       AUTOMOTIVE_AMPLIFIERS      0.970     0.940     0.955       662
#                           PROJECTOR_SCREENS      1.000     1.000     1.000        53
#                          AUTOMOTIVE_EMBLEMS      0.955     0.941     0.948       524
#                           PAINTBALL_MARKERS      0.930     0.959     0.944        97
#               AUTOMOTIVE_SPRING_SUSPENSIONS      0.952     0.983     0.967       121
#                                 ENGINE_OILS      0.989     0.978     0.984       770
#                            BATTERY_CHARGERS      0.667     0.800     0.727        30
#                     SWEATSHIRTS_AND_HOODIES      0.933     0.949     0.941       118
#                      CONTINUOUS_INK_SYSTEMS      0.993     0.971     0.982       140
#                              BATHROOM_SINKS      0.944     0.981     0.962       427
#                                MEMORY_CARDS      0.986     0.981     0.984       669
#                                    HANDBAGS      0.951     0.965     0.958       850
#                               KITCHEN_SINKS      0.938     0.889     0.913       253
#                            CAMERA_BATTERIES      0.960     0.984     0.971       554
#                             WATER_RADIATORS      0.963     0.965     0.964       399
#                           CYCLING_COMPUTERS      0.974     0.925     0.949       161
#                                EROTIC_BOOKS      1.000     0.985     0.992        67
#                            MOTORCYCLE_CASES      0.991     1.000     0.996       222
#                                    COSTUMES      0.960     0.960     0.960       276
#                           BODYWEIGHT_SCALES      0.936     0.942     0.939       293
#                      GAMEPADS_AND_JOYSTICKS      0.972     0.971     0.971       612
#                                       PANTS      0.936     0.939     0.938       799
#                                      STOOLS      0.995     0.973     0.984       594
#                               FISHING_REELS      0.982     0.978     0.980       740
#                                     WALLETS      0.982     0.971     0.977       665
#                           MUSICAL_KEYBOARDS      0.960     0.982     0.971       511
#                                  ULTRABOOKS      0.921     0.905     0.913       232
#                             ENGINE_BEARINGS      0.970     0.982     0.976       327
#                    CAR_POWER_STEERING_PUMPS      0.987     0.989     0.988       370
#                                     TABLETS      0.984     0.960     0.972       624
#                              MAKEUP_BRUSHES      0.979     0.983     0.981       534
#                               HORSE_SADDLES      0.990     1.000     0.995       102
#                          CD_AND_DVD_PLAYERS      0.895     0.942     0.918       291
#                    VIDEO_GAME_PREPAID_CARDS      0.828     0.779     0.803        68
#                             SCREEN_PRINTERS      0.949     0.962     0.955       156
#                                  ROOF_RACKS      0.981     0.981     0.981       428
#                                  HEADPHONES      0.957     0.942     0.949       189
#                       ELECTRIC_SCREWDRIVERS      0.815     0.902     0.856       122
#                             VACUUM_CLEANERS      0.737     0.875     0.800        16
#                                 FLASHLIGHTS      0.987     0.979     0.983       606
#                                HOME_SHELVES      0.837     0.885     0.861       157
#                               BRUSH_CUTTERS      0.972     0.955     0.963       110
#                         COMPUTER_PROCESSORS      0.990     0.981     0.985       794
#                                    NECKTIES      0.992     0.985     0.989       134
#                          MOTORCYCLE_JACKETS      0.971     0.964     0.967       551
#                                    WRENCHES      0.966     0.984     0.975       371
#                                 WHEELCHAIRS      0.989     0.989     0.989        90
#                          RAM_MEMORY_MODULES      0.995     0.990     0.993       822
#                                PENCIL_CASES      0.976     0.902     0.938       183
#                AUTOMOTIVE_SHIFT_LEVER_KNOBS      1.000     1.000     1.000       938
#                                        MUGS      0.943     0.954     0.949       329
#                              WALKIE_TALKIES      0.954     0.947     0.950       283
#                                       DOLLS      0.943     0.938     0.941       843
#                                  TREADMILLS      0.984     0.969     0.977        65
#                                 SPARK_PLUGS      0.982     0.953     0.967       726
#                               HAIR_CLIPPERS      0.877     0.811     0.843       714
#                                   SUITCASES      0.974     0.973     0.973       582
#                                 BLANK_DISCS      0.955     0.949     0.952       178
#                                    SPEAKERS      0.937     0.962     0.949       525
#                               DVD_RECORDERS      0.973     0.978     0.976       450
#                     KEYBOARD_AND_MOUSE_KITS      0.967     0.956     0.962       275
#                             CAR_SEAT_COVERS      0.995     0.995     0.995       942
#          AUTOMOTIVE_SUSPENSION_CONTROL_ARMS      0.973     0.988     0.980       254
#                           BAR_CODE_SCANNERS      0.980     0.976     0.978       254
#                         AUTOMOTIVE_MOLDINGS      0.973     0.983     0.978       720
#                               BABY_SWIMWEAR      0.860     0.860     0.860       121
#                        TABLE_AND_DESK_LAMPS      0.949     0.935     0.942       260
#                           JACKETS_AND_COATS      0.944     0.948     0.946       815
#                                  CHAMPAGNES      0.707     0.935     0.806        31
#                              FOOTBALL_SHOES      0.996     0.993     0.995       734
#                           CHARMS_AND_MEDALS      0.976     0.953     0.965        86
#                                 MICROPHONES      0.973     0.991     0.982       465
#                         PERMANENT_EPILATORS      0.876     0.904     0.890        94
#                              WOMEN_SWIMWEAR      0.968     0.954     0.961       500
#                  PARTY_DECORATIVE_BACKDROPS      0.963     0.990     0.976       104
#                               ROLLER_SKATES      0.991     0.993     0.992       586
#                                      COMICS      0.779     0.880     0.827       534
#                                       BOOKS      0.854     0.831     0.842       833
#                              CUPCAKE_STANDS      0.714     0.625     0.667         8
#                               UPS_BATTERIES      0.699     0.906     0.789        64
#                                 CAKE_STANDS      0.872     0.911     0.891        45
#            REAR_WHEEL_HUBS_BEARING_ASSEMBLY      0.976     0.998     0.986       401
#                            DIECAST_VEHICLES      0.955     0.936     0.945       606
#                                 CALCULATORS      0.996     0.991     0.993       536
#                                 TV_ANTENNAS      0.978     0.990     0.984       310
#                                 PAPER_CLIPS      1.000     0.941     0.970        51
#                              MALE_UNDERWEAR      0.981     0.983     0.982       422
#                                  ALL_IN_ONE      0.978     0.937     0.957       189
#                            DRINKING_GLASSES      0.883     0.893     0.888       382
#                                       DRUMS      0.948     0.943     0.946       212
#                               WELDING_MASKS      0.982     0.889     0.933        63
#                                    WHISKEYS      0.960     0.981     0.970       267
#                               VIDEO_CAMERAS      0.946     0.946     0.946        37
#                               COFFEE_MAKERS      0.986     0.981     0.983       567
#                        KNEE_BRACES_SUPPORTS      0.969     0.969     0.969       129
#                                 WALL_CLOCKS      0.988     0.990     0.989       479
#                                 WALL_LIGHTS      0.977     0.977     0.977       172
#                              GARDEN_BENCHES      0.588     0.714     0.645        14
#                                  SCULPTURES      0.944     0.931     0.938       437
#                                        FANS      0.980     0.975     0.977       597
#                                 FOUNDATIONS      0.964     0.959     0.962       706
#                                   EYELINERS      0.977     0.840     0.903        50
#                                  DRILL_BITS      0.979     0.979     0.979       143
#                                PC_KEYBOARDS      0.750     0.692     0.720        26
#                               EROTIC_CREAMS      0.924     0.918     0.921       279
#                           DESKTOP_COMPUTERS      0.895     0.944     0.919        36
#                           DECORATIVE_VINYLS      0.922     0.961     0.941       709
#                                 BOARD_GAMES      0.916     0.931     0.923       654
#                         KITCHEN_RANGE_HOODS      1.000     0.981     0.990       309
#                                     DRAWERS      0.980     0.990     0.985       198
#                             FURNITURE_KNOBS      0.948     0.993     0.970       147
#        HOME_APPLIANCE_CONTACTORS_AND_RELAYS      0.988     0.983     0.985       408
#                            SHAVING_MACHINES      0.729     0.846     0.784       449
#                                TOOTHBRUSHES      0.985     0.974     0.979       265
#                     STREAMING_MEDIA_DEVICES      0.955     0.964     0.959       415
#                      CAR_AC_HOSE_ASSEMBLIES      0.875     0.412     0.560        17
#                              SWAY_BAR_LINKS      0.929     0.888     0.908        89
#                               PREAMPLIFIERS      0.600     0.391     0.474        23
#                                  FISH_TANKS      0.986     0.938     0.961       145
#                                      DRONES      0.991     0.974     0.982       653
#                            EMERGENCY_LIGHTS      0.928     0.941     0.934       288
#                                    BLENDERS      0.882     0.973     0.925       452
#                              LASER_MEASURES      0.963     0.945     0.954        55
#                                CASH_DRAWERS      0.973     0.947     0.960        38
#                             CAMERA_CHARGERS      0.905     0.937     0.921       285
#                            CAR_AV_RECEIVERS      0.941     0.942     0.941       589
#                            STEERING_COLUMNS      0.986     0.986     0.986       143
#                                      SKIRTS      0.961     0.968     0.964       154
#                             SANDER_MACHINES      0.979     0.955     0.967       292
#                                RICE_COOKERS      0.981     1.000     0.990        52
#                              BRAKE_BOOSTERS      0.993     0.993     0.993       139
#                                    NETBOOKS      0.943     0.917     0.930       145
#                               FISHING_LURES      0.862     0.836     0.848        67
#                            AUTOMOTIVE_TIRES      0.918     0.838     0.876        80
#                                     STATUES      0.500     0.652     0.566        23
#                                    T_SHIRTS      0.951     0.974     0.963       742
#                             OFFICE_SOFTWARE      0.787     0.768     0.778        82
#                              BABY_CAR_SEATS      0.969     0.984     0.976       549
#                                 WATCH_BANDS      0.917     0.921     0.919       265
#                                        PENS      0.590     0.852     0.697        27
#                   BATHROOM_ACCESSORIES_SETS      0.868     0.846     0.857        78
#                                 CAR_STEREOS      0.848     0.872     0.860       243
#  CELLPHONE_TABLET_AND_GPS_SCREEN_PROTECTORS      0.873     0.935     0.903       155
#                              GLASSES_FRAMES      0.960     0.966     0.963       296
#                                AIRSOFT_GUNS      0.975     0.971     0.973       245
#                                   HAND_FANS      0.816     0.969     0.886        32
#                                  SIDEBOARDS      0.985     0.990     0.988       201
#                            VEHICLE_STICKERS      0.970     0.975     0.973       530
#                              BABY_STROLLERS      0.962     0.976     0.969       468
#                                      MOVIES      0.914     0.746     0.822        71
#                          MICRO_ROTARY_TOOLS      0.971     0.971     0.971        69
#                                   SOUVENIRS      0.897     0.927     0.912       151
#                                      VODKAS      0.937     0.947     0.942        94
#                               PUREBRED_DOGS      0.986     0.986     0.986       705
#                                     VIOLINS      0.962     0.993     0.977       151
#                                 HOVERBOARDS      0.992     0.990     0.991       480
#                      SUSPENSION_BALL_JOINTS      0.981     0.978     0.979       579
#                                   BACKPACKS      0.972     0.989     0.980       699
#                              ADHESIVE_TAPES      0.935     0.968     0.951       253
#                           ELECTRICAL_CABLES      0.977     1.000     0.988       250
#                               COFFEE_TABLES      1.000     0.923     0.960        26
#                  INTERACTIVE_GAMING_FIGURES      0.984     1.000     0.992       246
#                   AUTOMOTIVE_AC_COMPRESSORS      0.975     0.907     0.940        43
#                       HAIRDRESSING_SCISSORS      0.975     0.981     0.978       160
#                                    CUSHIONS      0.967     0.967     0.967       213
#                   THERMAL_CUPS_AND_TUMBLERS      0.909     0.893     0.901        56
#         TV_REPLACEMENT_BACKLIGHT_LED_STRIPS      0.966     0.991     0.979       115
#                         ENGINE_INTAKE_HOSES      0.912     0.944     0.928       373
#                    AUTOMOBILE_FENDER_LINERS      0.889     0.889     0.889        18
#                              DJ_CONTROLLERS      0.891     0.891     0.891       175
#                                STUFFED_TOYS      0.874     0.903     0.888       679
#              MARTIAL_ARTS_AND_BOXING_GLOVES      0.976     0.976     0.976       254
#                               CAMERA_LENSES      0.977     0.963     0.970       219
#                                EROTIC_PUMPS      0.988     0.899     0.941        89
#                               PAINT_ROLLERS      1.000     0.909     0.952        11
#                                MEN_SWIMWEAR      0.824     0.778     0.800        18
#                 PORTABLE_CELLPHONE_CHARGERS      0.974     0.958     0.966       500
#                              ANALOG_CAMERAS      0.955     0.967     0.961       457
#                             HAIR_TREATMENTS      0.804     0.831     0.818        89
#                       DJ_EFFECTS_PROCESSORS      0.819     0.807     0.813       202
#                     BUMPER_IMPACT_ABSORBERS      0.976     0.976     0.976       245
#                  NOTEBOOKS_AND_WRITING_PADS      0.993     0.987     0.990       153
#                         FINGERPRINT_READERS      1.000     0.917     0.957        24
#                                    BLANKETS      0.888     0.908     0.898       131
#                                 SUPPLEMENTS      0.894     0.881     0.888       430
#                                    HAMMOCKS      1.000     0.988     0.994        82
#                AUTOMOTIVE_SIDE_VIEW_MIRRORS      0.974     0.984     0.979       737
#                   FACIAL_SKIN_CARE_PRODUCTS      0.816     0.883     0.848       341
#                             PACKAGING_ROLLS      1.000     1.000     1.000        26
#                       TV_AND_MONITOR_MOUNTS      0.987     0.993     0.990       546
#                                CAR_ANTENNAS      0.999     0.996     0.997       934
#                                    CACHACAS      0.981     0.968     0.974       157
#                                     TV_SMPS      0.896     0.892     0.894       279
#                              KITCHEN_TOWELS      0.989     0.971     0.980       277
#                                    CALIPERS      0.917     1.000     0.957        22
#                             PARKING_SENSORS      0.991     0.996     0.994       539
#                   ELECTRIC_PRESSURE_WASHERS      0.994     0.980     0.987       343
#              HAIR_SHAMPOOS_AND_CONDITIONERS      0.900     0.818     0.857        44
#                                STETHOSCOPES      1.000     0.917     0.957        36
#                                    PRINTERS      0.953     0.958     0.955       400
#                             ELECTRIC_DRILLS      0.964     0.981     0.972       414
#                                KITCHEN_POTS      0.963     0.965     0.964       485
#                              FUEL_INJECTORS      0.867     0.951     0.907       103
#                            VEHICLE_SPEAKERS      0.974     0.967     0.970       421
#                           HOME_OFFICE_DESKS      0.980     0.973     0.976       149
#                              GUITAR_STRINGS      0.963     0.981     0.972       106
#                             DISC_PACKAGINGS      0.917     0.892     0.904        74
#                                 LIP_GLOSSES      0.907     0.921     0.914       190
#                                     DRESSES      0.978     0.970     0.974       692
#                                BASS_GUITARS      0.968     0.959     0.963       467
#                                  TURNTABLES      0.905     0.915     0.910       270
#                           TOY_BUILDING_SETS      0.964     0.855     0.906       249
#                                  BED_SHEETS      0.871     0.987     0.925        75
#                               CAR_GEARBOXES      0.992     0.989     0.991       267
#                                FLOOD_LIGHTS      0.980     0.942     0.960       462
#                          SOLDERING_MACHINES      0.987     0.982     0.984       383
#                            ELECTRONIC_DRUMS      0.946     0.906     0.926       117
#                    DATA_CABLES_AND_ADAPTERS      0.877     0.887     0.882        80
#                      AUTOMOTIVE_WATER_PUMPS      0.933     0.890     0.911       391
#                              FOOTBALL_BALLS      0.987     0.987     0.987       156
#                                LENS_FILTERS      0.986     0.960     0.973        75
#                       INSTRUMENT_AMPLIFIERS      0.902     0.960     0.930       449
#                                MUSIC_STANDS      1.000     0.875     0.933        32
#                        CAR_DISTRIBUTOR_CAPS      0.969     0.922     0.945       205
#                                  MOUSE_PADS      0.990     0.975     0.982       201
#                                     FABRICS      0.939     0.942     0.941       379
#                               CABIN_FILTERS      0.996     0.996     0.996       244
#                             SEWING_MACHINES      0.959     0.973     0.966       292
#                                      MIXERS      0.980     0.971     0.976       350
#                         MOTORCYCLE_FAIRINGS      0.962     0.932     0.947       353
#                                   CV_JOINTS      0.977     0.968     0.973       443
#                  HAIR_STRAIGHTENING_BRUSHES      0.963     1.000     0.981        26
#                             WHEELS_BEARINGS      0.996     0.993     0.995       547
#                                AV_RECEIVERS      0.849     0.867     0.858       188
#                              NETWORK_CABLES      0.954     0.974     0.964       190
#                                       CRIBS      0.943     0.955     0.949       242
#                                HOME_HEATERS      0.960     0.919     0.939       234
#                  BRACELETS_AND_ANKLE_BRACES      0.939     0.939     0.939       346
#                                    SNEAKERS      0.821     0.958     0.885        72
#                  AUTOMOTIVE_THROTTLE_BODIES      0.979     0.940     0.959        50
#                              COOKING_SCALES      0.952     0.905     0.928       412
#                               PEDAL_EFFECTS      0.954     0.950     0.952       695
#                              ENGINE_PISTONS      0.969     0.947     0.958       132
#                               FLATWARE_SETS      0.964     0.871     0.915        31
#                                     PANTIES      0.868     0.939     0.902        49
#                          ELECTRICAL_OUTLETS      0.859     0.951     0.903       122
#                          BABY_CLOTHING_SETS      0.811     0.789     0.800        76
#                              STEAM_CLEANERS      1.000     0.789     0.882        19
#                            DECORATIVE_VASES      0.885     0.927     0.906       274
#                             FOOD_PROCESSORS      0.975     0.867     0.918       135
#                             TRAILER_HITCHES      1.000     1.000     1.000       184
#                       SOFA_AND_FUTON_COVERS      0.990     1.000     0.995        99
#                                      SHIRTS      0.946     0.890     0.917       118
#                       VEHICLE_CLUTCH_CABLES      1.000     1.000     1.000        10
#                                 GATE_MOTORS      0.970     0.987     0.978       298
#                                  FOG_LIGHTS      0.966     0.976     0.971       292
#                                   SIM_CARDS      0.957     0.917     0.936        24
#                               BABY_MONITORS      0.964     0.986     0.975       220
#                            VEHICLE_CV_AXLES      1.000     0.971     0.985        69
#                                   LIPSTICKS      0.973     0.972     0.972       562
#                      SERVING_AND_HOME_TRAYS      0.963     0.958     0.960       354
#                                    COOKTOPS      0.429     0.273     0.333        11
#                              GRAPHICS_CARDS      0.941     1.000     0.970        32
#                          FIRE_EXTINGUISHERS      1.000     0.967     0.983        30
#                  KITCHEN_CABINET_ORGANIZERS      0.000     0.000     0.000         7
#                                       SOFAS      0.889     0.960     0.923       100
#                            GRAPHICS_TABLETS      0.969     0.984     0.977       190
#                                      SHORTS      0.926     0.964     0.945       274
#                            SWIMMING_GOGGLES      0.972     0.896     0.932        77
#                            POOL_INFLATABLES      0.897     0.946     0.921        37
#                                       DOORS      0.897     0.897     0.897        97
#                               SPORT_WATCHES      0.942     0.845     0.891       478
#            PORTABLE_EVAPORATIVE_AIR_COOLERS      0.947     0.913     0.930       138
#              DOG_CARRIERS_AND_CARRYING_BAGS      0.944     0.895     0.919        57
#                     ENGINE_INTAKE_MANIFOLDS      0.877     0.980     0.926        51
#                          MOTORCYCLE_HELMETS      0.994     0.999     0.997       715
#                        COMBUSTION_CHAINSAWS      0.988     1.000     0.994        84
#               ELECTRONIC_ENTRANCE_INTERCOMS      0.972     0.972     0.972       211
#                                     CRAYONS      1.000     0.960     0.980       101
#                                THERMOMETERS      0.940     1.000     0.969        63
#                              CAMERA_TRIPODS      0.988     0.977     0.982       427
#                           ARTIFICIAL_PLANTS      0.760     0.704     0.731        27
#                            PROJECTOR_MOUNTS      0.800     0.800     0.800         5
#                 PORTABLE_ELECTRIC_MASSAGERS      0.939     0.928     0.933        83
#               NON_CORRECTIVE_CONTACT_LENSES      0.952     0.833     0.889        24
#                                     PUZZLES      0.922     0.959     0.940        74
#            WASHING_AND_DRYER_MACHINE_COVERS      1.000     0.960     0.980        50
#                        PUSH_AND_RIDING_TOYS      0.760     0.594     0.667        32
#                                SHOWER_HEADS      0.875     0.923     0.899       235
#                            ANTI_THEFT_STUDS      0.977     0.950     0.963       220
#                               HATS_AND_CAPS      0.785     0.954     0.861        65
#                                   MAGAZINES      0.797     0.685     0.737       143
#                  ENGINE_COOLING_FAN_SHROUDS      0.988     1.000     0.994        83
#                      AUTOMOTIVE_OIL_FILTERS      0.860     0.860     0.860        43
#                            MOTORCYCLE_TIRES      0.916     0.966     0.940       147
#               MOTORCYCLE_TURN_SIGNAL_LIGHTS      0.995     1.000     0.998       221
#                                     PILLOWS      0.968     0.968     0.968        31
#                                    TEQUILAS      0.941     0.970     0.955        33
#                                 TOILET_RUGS      0.918     0.896     0.907       249
#                                      FLUTES      0.960     0.930     0.944       128
#                                    UKULELES      0.945     1.000     0.972        52
#                                 TOOTHPASTES      0.906     0.935     0.921        62
#                       MOTORCYCLE_CRASH_BARS      0.905     0.905     0.905        21
#                             PIPES_AND_TUBES      0.467     0.538     0.500        13
#                                FOOD_SLICERS      0.905     0.864     0.884        22
#           DESKTOP_COMPUTER_COOLERS_AND_FANS      0.952     0.974     0.963       345
#                                   SWAY_BARS      0.930     0.949     0.939        98
#                            AQUARIUM_FILTERS      0.968     0.991     0.979       214
#               CELLPHONE_REPLACEMENT_CAMERAS      1.000     0.961     0.980        51
#                                     MIRRORS      0.951     0.907     0.929        86
#                             BLU_RAY_PLAYERS      0.949     0.966     0.958       175
#                          AUTOMOTIVE_FENDERS      0.952     0.968     0.960       124
#                             SPARKLING_WINES      0.000     0.000     0.000        12
#              ENGINE_VALVES_SPRING_RETAINERS      0.957     0.985     0.971        68
#                                BABY_WALKERS      0.591     1.000     0.743        13
#             ANTIVIRUS_AND_INTERNET_SECURITY      0.938     0.938     0.938        16
#                       COTTON_CANDY_MACHINES      1.000     1.000     1.000         7
#                             ORAL_IRRIGATORS      1.000     1.000     1.000         8
#                    MOTORCYCLE_CLUTCH_COVERS      0.926     0.941     0.934       239
#                               GAME_CONSOLES      0.946     0.911     0.928       347
#                               TABLE_RUNNERS      0.904     0.985     0.943        67
#                           PLAYGROUND_SLIDES      1.000     1.000     1.000        13
#                                 3D_PRINTERS      0.920     0.979     0.948        47
#                                 DIAPER_BAGS      0.933     0.942     0.937       103
#                               ELECTRIC_SAWS      0.981     0.989     0.985       363
#                           KITCHEN_FURNITURE      0.923     0.947     0.935        38
#                            BABY_HIGH_CHAIRS      0.861     0.773     0.814        88
#                                    MINI_PCS      0.625     0.714     0.667        14
#                                    MASCARAS      0.935     0.935     0.935        92
#                     AUTOMOTIVE_WHEEL_COVERS      0.955     0.984     0.969       129
#                           WINDSHIELD_WIPERS      0.964     0.984     0.974       190
#                                     LIQUORS      1.000     0.950     0.974       100
#                            CLOTHING_PATCHES      0.981     0.879     0.927        58
#                       WOOD_BURNING_MACHINES      1.000     1.000     1.000         7
#                                  BINOCULARS      0.978     0.962     0.970       186
#                      COMMERCIAL_LIGHT_SIGNS      1.000     1.000     1.000        32
#                            WATER_DISPENSERS      0.918     0.951     0.934       225
#                       GLOW_PLUG_CONTROLLERS      1.000     0.946     0.972        56
#                                  TELEPHONES      0.923     0.571     0.706        21
#                             AIR_COMPRESSORS      0.953     0.969     0.961       353
#                           OPERATING_SYSTEMS      0.951     0.941     0.946       270
#                        CAR_ENGINE_CAMSHAFTS      0.750     1.000     0.857        15
#                             CLOTHES_HANGERS      0.989     0.957     0.972        92
#                                    WETSUITS      0.941     0.842     0.889        19
#                                TOILET_SEATS      0.989     0.984     0.987       191
#                            AUTOMOTIVE_DOORS      0.994     0.982     0.988       332
#             SUSPENSION_CONTROL_ARM_BUSHINGS      0.877     0.826     0.851       138
#                          VEHICLE_BRAKE_PADS      0.980     0.991     0.986       350
#                 REMOTE_CONTROL_TOY_VEHICLES      0.873     0.923     0.898       209
#                        AUTOMOTIVE_NERF_BARS      1.000     1.000     1.000        38
#                              ESSENTIAL_OILS      0.873     0.846     0.859        65
#                             SLATWALL_PANELS      1.000     0.988     0.994        80
#                                  TOOL_BOXES      1.000     0.936     0.967       109
#                                BABY_DIAPERS      0.997     0.976     0.987       375
#                          ALARMS_AND_SENSORS      0.937     0.963     0.950       295
#                            MOTORCYCLE_SUITS      0.971     0.919     0.944        37
#                               KITCHEN_BOWLS      0.800     0.909     0.851        22
#                              CAT_SCRATCHERS      0.875     0.933     0.903        15
#                              INK_CARTRIDGES      0.839     0.867     0.852        30
#                    MARKERS_AND_HIGHLIGHTERS      0.941     0.881     0.910       126
#                      JUMPSUITS_AND_OVERALLS      0.907     0.925     0.916       106
#                                 NAIL_DRYERS      0.977     0.954     0.965       131
#                             CAMERA_MONOPODS      0.849     0.918     0.882        49
#                                    BICYCLES      0.983     0.957     0.970       184
#                                        SALT      1.000     1.000     1.000        10
#                    SCREEN_PRINTING_MACHINES      0.700     1.000     0.824        14
#                                        BEDS      0.894     0.977     0.933        43
#                     BODY_SKIN_CARE_PRODUCTS      0.847     0.842     0.844       380
# AUTOMOTIVE_MANUAL_TRANSMISSION_SHIFT_LEVERS      0.885     0.920     0.902        25
#                            TV_STORAGE_UNITS      0.980     0.942     0.961        52
#                       AUTOMOTIVE_HEADLIGHTS      0.934     0.977     0.955       131
#                                  PAINTBALLS      0.888     0.929     0.908        85
#                                      SCREWS      0.869     0.930     0.898        57
#                                  TOY_ROBOTS      0.909     0.667     0.769        15
#                                     POSTERS      0.952     0.971     0.962       206
#                            MOTORCYCLE_PANTS      0.947     0.915     0.931       118
#                         INTEGRATED_CIRCUITS      0.778     0.875     0.824        72
#                                GARDEN_HOSES      0.963     0.929     0.945        56
#                                 ALTERNATORS      0.933     0.875     0.903        48
#                          MAGNIFYING_GLASSES      0.991     0.926     0.958       122
#                                    PERFUMES      0.907     0.942     0.925        52
#                                       FLOUR      0.882     1.000     0.938        15
#                                FISHING_RODS      0.905     1.000     0.950        19
#                  CELLPHONE_AND_TABLET_CASES      0.879     0.956     0.916        91
#                                     PAJAMAS      0.948     0.982     0.965        56
#                                  BUTT_PLUGS      0.771     0.794     0.783        34
#                 LUMBAR_AND_ABDOMINAL_BRACES      0.979     0.973     0.976       147
#                              AIR_MATTRESSES      0.966     0.935     0.950       154
#                               WATER_HEATERS      0.988     0.960     0.973       247
#                                 DISHWASHERS      1.000     0.959     0.979       148
#                        ELECTRIC_LAWN_MOWERS      1.000     0.750     0.857         4
#                               HOME_THEATERS      0.750     0.667     0.706         9
#                            LED_STAGE_LIGHTS      0.922     0.875     0.898       216
#           CHALKBOARD_AND_WHITEBOARD_ERASERS      1.000     0.913     0.955        23
#                               BABY_BOUNCERS      0.810     0.944     0.872        18
#                                       RINGS      0.953     0.953     0.953        43
#                      AUTOMOTIVE_AIR_FILTERS      0.932     1.000     0.965        55
#                                LUGGAGE_TAGS      0.913     0.894     0.903        47
#                                HEATER_CORES      0.938     0.714     0.811        21
#                             CLEANING_CLOTHS      0.864     0.957     0.908        93
#                              AIR_FRESHENERS      0.781     0.581     0.667        43
#                                     BLOUSES      0.730     0.711     0.720        38
#                             SAFETY_FOOTWEAR      0.957     1.000     0.978        66
#                                FREEZER_BAGS      0.778     0.875     0.824         8
#                      SHOCK_MOUNT_INSOLATORS      0.833     0.890     0.861        73
#                                  BAR_CLAMPS      0.929     0.812     0.867        16
#                             CHRISTMAS_TREES      1.000     0.919     0.958        37
#                          CAR_AIR_FRESHENERS      0.826     0.909     0.865        99
#                          BASKETBALL_JERSEYS      1.000     0.800     0.889        15
#                                  ACCORDIONS      0.974     0.981     0.978       311
#                                  FOOD_CARTS      1.000     0.935     0.967        31
#                                   HEAT_GUNS      0.989     0.989     0.989        94
#                   ENGINE_CRANKSHAFT_PULLEYS      0.927     0.944     0.935       107
#                                  PARTY_HATS      1.000     0.250     0.400         8
#                             RECEPTION_DESKS      0.800     1.000     0.889         4
#                              PICTURE_FRAMES      0.967     0.974     0.970       151
#                               OSCILLOSCOPES      0.900     0.900     0.900        10
#                   HABERDASHERY_LACE_EDGINGS      0.928     0.945     0.936       109
#                                       BEERS      0.988     0.971     0.979       170
#                                HOLE_PUNCHES      1.000     0.571     0.727         7
#                               DJ_TURNTABLES      0.763     0.725     0.744        80
#                                 VR_HEADSETS      0.983     0.980     0.982       352
#                             KITCHEN_MORTARS      1.000     0.750     0.857         4
#                                       OVENS      0.971     0.982     0.977       171
#                                DISHES_RACKS      0.692     0.735     0.713        49
#                                    EARRINGS      0.955     0.955     0.955        44
#                                   WARDROBES      0.943     0.917     0.930        36
#                           RACKS_AND_PINIONS      0.982     0.965     0.973       113
#                                   BOOKCASES      0.795     1.000     0.886        35
#                                  TOY_TRAINS      0.860     0.851     0.856        94
#                      CARD_PAYMENT_TERMINALS      0.933     0.824     0.875        17
#                           SUBMERSIBLE_PUMPS      0.970     0.980     0.975       100
#             GARDENING_AND_AGRICULTURE_SEEDS      0.854     0.972     0.909        36
#                                      MODEMS      0.889     0.911     0.900       123
#                               OFFICE_CHAIRS      0.909     0.918     0.914        98
#                                   PENDRIVES      0.937     0.964     0.950       139
#                                   NECKLACES      0.906     0.956     0.930        91
#                          ENGINE_GASKET_SETS      0.467     0.412     0.437        17
#                  AUTOMOTIVE_SHOCK_ABSORBERS      0.756     0.894     0.819        66
#                                 VINYL_ROLLS      0.631     0.757     0.688        70
#               TROLLEY_AND_FURNITURE_CASTERS      1.000     1.000     1.000         4
#                   TV_RECEIVERS_AND_DECODERS      0.762     0.889     0.821        18
#                                LIFE_JACKETS      0.512     0.955     0.667        22
#                        SELF_ADHESIVE_LABELS      0.824     0.857     0.840        49
#                   IGNITION_SWITCH_ACTUATORS      1.000     1.000     1.000        14
#                            BABY_STERILIZERS      0.909     0.909     0.909        22
#                       PARKING_BRAKE_HANDLES      0.938     0.984     0.960        61
#                      CLUTCH_SLAVE_CYLINDERS      0.711     0.900     0.794        30
#                                      FISHES      0.857     0.667     0.750         9
#                             COOKIES_CUTTERS      0.914     0.961     0.937        77
#                                  NEBULIZERS      0.961     1.000     0.980        49
#                                  COMFORTERS      0.682     0.750     0.714        20
#                         ELLIPTICAL_MACHINES      0.952     0.930     0.941       128
#                               ENGINE_VALVES      0.930     0.909     0.920        44
#                                  SANDPAPERS      0.905     0.905     0.905        21
#        AUTOMOTIVE_SHOCK_ABSORBER_BUMP_STOPS      0.944     0.919     0.932        37
#                                     GAZEBOS      0.989     0.967     0.978        91
#                                  XENON_KITS      0.952     1.000     0.976        20
#                      AUTOMOTIVE_DOOR_PANELS      0.974     1.000     0.987       150
#                  INDOOR_CURTAINS_AND_BLINDS      0.957     0.975     0.966       161
#                         CAR_WINDOW_SWITCHES      0.931     0.871     0.900        31
#                                   EPILATORS      0.885     0.904     0.895        94
#                           MALE_MASTURBATORS      0.857     0.800     0.828        15
#                         DRILLS_SCREWDRIVERS      1.000     0.125     0.222        24
#                                  CONCEALERS      0.920     0.909     0.914        88
#                     SCHOOL_AND_OFFICE_GLUES      0.667     0.800     0.727        10
#                      SANDALS_AND_FLIP_FLOPS      0.957     0.978     0.967        45
#                                   BAR_SOAPS      0.895     0.850     0.872        60
#                   ELECTRIC_BATHROOM_FAUCETS      0.818     0.720     0.766        25
#                           VOLTAGE_DETECTORS      0.933     0.966     0.949        29
#                     ORTHOPEDIC_ANKLE_BRACES      1.000     0.867     0.929        15
#                              HEDGE_TRIMMERS      1.000     1.000     1.000        14
#                         STABILIZERS_AND_UPS      0.000     0.000     0.000         2
#                               BABY_PLAYARDS      0.961     0.891     0.925       110
#                            RESISTANCE_BANDS      0.967     0.972     0.970       180
#                             LAPTOP_CHARGERS      0.955     0.941     0.948        68
#                       COMPUTER_MOTHERBOARDS      0.660     0.805     0.725        41
#                                 COIN_PURSES      0.821     0.885     0.852        26
#                                       VESTS      0.979     0.969     0.974        97
#                           HAIRDRESSING_CAPS      1.000     0.875     0.933         8
#                                CAMERA_CASES      0.333     0.143     0.200         7
#                           MOTORCYCLE_GLOVES      0.948     0.967     0.957       151
#                 COMPUTER_AND_TV_FLEX_CABLES      0.937     0.983     0.959       120
#                                       MANGA      0.769     0.769     0.769        39
#                                SELF_TANNERS      1.000     0.667     0.800         3
#                          HEARING_PROTECTORS      0.907     1.000     0.951        39
#                               DIFFERENTIALS      0.941     0.914     0.928        35
#                    FLEA_AND_TICK_TREATMENTS      0.992     0.977     0.984       129
# ...
#                            LIVING_ROOM_SETS      0.900     0.643     0.750        14
#                              BABY_PACIFIERS      1.000     1.000     1.000        15
#                              HAND_POLISHERS      0.750     0.857     0.800        14
#                                SHADE_CLOTHS      1.000     1.000     1.000        12
#                               HAMMER_DRILLS      0.000     0.000     0.000         8
#                              POWER_GRINDERS      0.846     0.846     0.846        13
#                               CAMERA_STRAPS      1.000     0.333     0.500         3
#                           LAWN_MOWER_BLADES      0.600     0.667     0.632         9
#                          PNEUMATIC_STAPLERS      1.000     1.000     1.000        13
#              THERMAL_REFRIGERATORS_AND_BAGS      1.000     0.679     0.809        28
#                                LIGHT_STANDS      1.000     1.000     1.000         7
#                                      STRAWS      0.750     0.750     0.750         8
#                                       SUITS      0.750     0.636     0.689        33
#                           BATHROOM_VANITIES      0.778     0.875     0.824         8
#                         VIBRATION_PLATFORMS      0.800     0.889     0.842        18
#                               DINING_TABLES      0.722     0.812     0.765        16
#                           TURNTABLE_NEEDLES      1.000     0.333     0.500         3
#                                HEARING_AIDS      0.900     0.900     0.900        10
#                     ORTHOPEDIC_WALKER_BOOTS      0.917     0.786     0.846        14
#                                         TEA      0.857     0.600     0.706        10
#                             TORQUE_WRENCHES      1.000     1.000     1.000         8
#                                 CATS_LITTER      0.917     0.917     0.917        12
#                                 MATE_GOURDS      0.909     0.909     0.909        11
#                                  MEAT_HOOKS      0.667     1.000     0.800         2
#                       AUTOMOTIVE_DEFLECTORS      1.000     1.000     1.000         5
#                   VARIABLE_FREQUENCY_DRIVES      1.000     0.857     0.923         7
#                                  SWEETENERS      1.000     1.000     1.000         8
#         AUTOMOTIVE_CELLPHONE_AND_GPS_MOUNTS      1.000     0.833     0.909         6
#                         RADIO_BASE_STATIONS      0.400     0.333     0.364         6
#                                    CRUTCHES      1.000     1.000     1.000         4
#                                POWER_STRIPS      0.750     0.900     0.818        10
#                               KATANA_SWORDS      0.846     0.846     0.846        13
#                        CATS_AND_DOGS_TREATS      0.727     0.571     0.640        14
#                         MEMORY_CARD_READERS      0.500     0.333     0.400         3
#                            TELEPHONE_CABLES      1.000     0.929     0.963        14
#                          SOLID_SWEET_PASTES      1.000     0.800     0.889        10
#                           DISPOSABLE_GLOVES      0.000     0.000     0.000         3
#                        MOTORCYCLE_GRAB_BARS      0.600     1.000     0.750         3
#                              PLUNGE_ROUTERS      0.875     0.875     0.875         8
#                         GROOVE_JOINT_PLIERS      0.800     1.000     0.889         4
#                          BICYCLE_HANDLEBARS      0.600     0.600     0.600         5
#                          SOLDERING_STATIONS      0.957     0.880     0.917        25
#                               TANDEM_CHAIRS      1.000     0.571     0.727         7
#                                GARAGE_DOORS      1.000     0.667     0.800        12
#                         SPARK_PLUG_WIRESETS      0.897     0.812     0.852        32
#                       ELECTRIC_SHOWER_HEADS      0.500     0.200     0.286         5
#                        PORTABLE_DVD_PLAYERS      0.714     0.556     0.625         9
#                                      DILDOS      0.750     0.375     0.500         8
#                   INDUSTRIAL_DOUGH_KNEADERS      0.917     0.846     0.880        13
#                   UNIVERSAL_REMOTE_CONTROLS      0.000     0.000     0.000         3
#                                 WHEEL_STUDS      0.500     0.333     0.400         6
#                            FABRIC_SOFTENERS      0.905     1.000     0.950        19
#              MOTORCYCLE_DISTRIBUTION_CHAINS      1.000     0.158     0.273        19
#                       DOOR_AND_WINDOW_LOCKS      0.500     0.333     0.400         3
#                                        GINS      0.667     1.000     0.800         4
#                                 HAND_TRUCKS      1.000     0.500     0.667         4
#                                    STAPLERS      1.000     1.000     1.000         6
#                                   APERITIFS      0.714     1.000     0.833         5
#                             SHOWER_CURTAINS      1.000     0.750     0.857         4
#                              ANTIQUE_CHAIRS      0.000     0.000     0.000         7
#                               YOGURT_MAKERS      0.571     0.800     0.667         5
#                                 SHIN_GUARDS      1.000     0.500     0.667         2
#                             GOLF_CLUBS_SETS      0.615     0.889     0.727         9
#                  FOOTBALL_GOALKEEPER_GLOVES      0.923     0.750     0.828        16
#                                LASER_LEVELS      0.727     1.000     0.842         8
#                        KEYBOARD_CONTROLLERS      0.167     0.200     0.182         5
#                          ALTERNATOR_PULLEYS      0.941     0.941     0.941        17
#            CAMERA_AND_CELLPHONE_STABILIZERS      0.400     0.667     0.500         3
#                                BABY_JUMPERS      1.000     0.667     0.800         6
#                 CAMERA_REPLACEMENT_DISPLAYS      0.857     0.857     0.857         7
#                                 CRANKSHAFTS      0.950     0.905     0.927        21
#                                BREAD_MAKERS      0.750     1.000     0.857         3
#                    SCHOOL_AND_OFFICE_PAPERS      0.714     0.625     0.667         8
#                    STOVETOP_POPCORN_POPPERS      0.583     0.875     0.700         8
#                      BREAST_FEEDING_PILLOWS      0.818     0.818     0.818        11
#                               POOL_CLEANERS      0.000     0.000     0.000         5
#                              LINEMAN_PLIERS      1.000     1.000     1.000         3
#                                  COAT_RACKS      0.444     0.667     0.533         6
#                                  POOL_PUMPS      0.688     0.917     0.786        12
#                     WATER_PURIFIERS_FILTERS      0.833     0.500     0.625        20
#                               SAFETY_GLOVES      0.300     0.500     0.375         6
#                          ISOPROPYL_ALCOHOLS      0.900     1.000     0.947         9
#               VEHICLE_BRAKE_HYDRAULIC_HOSES      1.000     0.667     0.800         9
#                              MEDICINE_BALLS      1.000     0.500     0.667         4
#                             KITCHEN_GRATERS      0.571     0.800     0.667         5
#                              NAPKIN_HOLDERS      1.000     0.889     0.941         9
#                               PUNCHING_BAGS      0.500     0.333     0.400         3
#                                 ESPADRILLES      1.000     0.875     0.933         8
#                         CAR_CENTER_CONSOLES      0.571     0.667     0.615         6
#                             VIDEO_CASSETTES      0.444     0.667     0.533         6
#                              POTENTIOMETERS      1.000     0.800     0.889         5
#                    READY_TO_DRINK_COCKTAILS      0.000     0.000     0.000         2
#                                 FLOOR_LAMPS      0.769     0.909     0.833        11
#                            DRONE_PROPELLERS      0.625     0.833     0.714         6
#                                       TENTS      0.846     1.000     0.917        11
#                            SAFETY_HARNESSES      1.000     0.500     0.667         4
#                                    SYRINGES      0.800     1.000     0.889         4
#                                   BEDLINERS      0.550     0.688     0.611        16
#                     ELECTROLYTIC_CAPACITORS      1.000     1.000     1.000         7
#                                BASKET_BALLS      0.000     0.000     0.000         2
#                                   OTOSCOPES      1.000     1.000     1.000         4
#                               WAFFLE_MAKERS      1.000     1.000     1.000         8
#                                 PENIS_RINGS      0.667     0.500     0.571         4
#                          ELECTRIC_AIR_PUMPS      0.750     0.750     0.750         8
#                             COFFEE_CAPSULES      0.800     0.800     0.800         5
#                         BABY_PACIFIER_CLIPS      0.714     1.000     0.833         5
#                                   KEY_RACKS      0.429     0.750     0.545         4
#                                  DEODORANTS      0.800     0.800     0.800         5
#                          INDUSTRIAL_PULLEYS      0.833     1.000     0.909         5
#                               BILL_COUNTERS      1.000     1.000     1.000         5
#                  AUDIO_AND_VIDEO_CONNECTORS      0.000     0.000     0.000         4
#                            WASHING_MACHINES      0.857     1.000     0.923        12
#                 ENGINE_COOLING_FAN_SWITCHES      0.600     1.000     0.750         6
#                        AUTOMOTIVE_BATTERIES      0.000     0.000     0.000         5
#                        CHIP_AND_DIP_SERVERS      0.333     0.250     0.286         4
#                                ARCHERY_BOWS      0.667     1.000     0.800         6
#                             VINYL_FLOORINGS      0.000     0.000     0.000         7
#                              MENSTRUAL_CUPS      1.000     1.000     1.000         5
#                               SLEEPING_BAGS      0.500     0.750     0.600         4
#                               RUBBER_STAMPS      0.556     1.000     0.714         5
#                              DRYER_MACHINES      0.778     0.875     0.824         8
#                            ENERGETIC_STONES      0.714     0.714     0.714         7
#                              BICYCLE_PEDALS      0.000     0.000     0.000         9
#                      MOTORCYCLE_CARBURETORS      0.750     0.600     0.667         5
#                           SCREWDRIVERS_SETS      1.000     0.667     0.800         3
#                                EDIBLE_SEEDS      1.000     0.333     0.500         3
#                        STORE_SHOPPING_CARTS      0.600     0.750     0.667         4
#                         SWIMMING_NOSE_CLIPS      0.000     0.000     0.000         2
#                                 AFTERSHAVES      0.333     0.333     0.333         3
#                              AIRBAG_MODULES      0.000     0.000     0.000         3
#                                   HAND_SAWS      0.857     1.000     0.923         6
#           NECK_GAITERS_MASKS_AND_BALACLAVAS      1.000     0.500     0.667         2
#                          MAGNETIC_COMPASSES      1.000     1.000     1.000         6
#                          MAKEUP_TRAIN_CASES      0.000     0.000     0.000         4
#                            POPCORN_MACHINES      1.000     0.556     0.714         9
#                                LAMP_HOLDERS      0.600     0.750     0.667         4
#                    IGNITION_CONTROL_MODULES      0.600     0.429     0.500         7
#                             CAR_FRONT_MASKS      0.000     0.000     0.000         2
#                               HAND_BLENDERS      1.000     0.333     0.500         3
#                              KIDS_TRICYCLES      1.000     1.000     1.000         4
#                              AIRGUN_PELLETS      1.000     0.250     0.400         4
#                            AUTOMOTIVE_SEATS      0.444     0.667     0.533         6
#              MOTORCYCLE_TRANSMISSION_CROWNS      1.000     1.000     1.000         4
#                                  LAMINATORS      1.000     0.714     0.833         7
#                                 CEREAL_BARS      1.000     0.667     0.800         3
#                                MUSIC_ALBUMS      1.000     0.500     0.667         4
#                   AUTOMOTIVE_CV_JOINT_BOOTS      0.667     0.857     0.750         7
#                           MICROWAVE_KEYPADS      1.000     1.000     1.000         3
#                           WALL_ANCHOR_PLUGS      0.400     0.500     0.444         4
#                                 DRUM_STANDS      0.800     0.571     0.667         7
#                                 PET_COLLARS      0.929     0.929     0.929        14
#                             GATE_GEAR_RACKS      1.000     0.750     0.857         4
#                                   CAR_HOODS      1.000     1.000     1.000         3
#                        SCREEN_PRINTING_KITS      0.000     0.000     0.000         4
#                                  LED_STRIPS      0.800     1.000     0.889         4
#                             SANDWICH_MAKERS      0.000     0.000     0.000         2
#                              DENTAL_FLOSSES      0.000     0.000     0.000         2
#                              CAMERA_FLASHES      0.800     0.800     0.800         5
#                           DOG_NAIL_CLIPPERS      1.000     0.500     0.667         2
#                                    PINBALLS      1.000     0.500     0.667         6
#                                      GAUZES      1.000     0.667     0.800         6
#                                        SODS      0.000     0.000     0.000         3
#                          ELECTRICITY_METERS      0.000     0.000     0.000         4
#                             METAL_DETECTORS      1.000     0.333     0.500         3
#                          ELECTRIC_CHAINSAWS      1.000     0.333     0.500         3
#                            KNITTING_NEEDLES      0.500     0.833     0.625         6
#                           SWIMMING_EARPLUGS      0.000     0.000     0.000         2
#                                 SOUND_CARDS      0.667     0.800     0.727         5
#                                    STEPPERS      0.667     0.500     0.571         4
#                                 FANNY_PACKS      0.667     0.500     0.571         4
#                          TOOTHBRUSH_HOLDERS      0.000     0.000     0.000         2
#                          TABLE_TENNIS_BALLS      0.000     0.000     0.000         2
#                 ENGINE_OIL_PRESSURE_SENSORS      0.000     0.000     0.000         3
#                                 ICE_BUCKETS      0.833     0.714     0.769         7
#                               MASSAGE_SOFAS      1.000     0.750     0.857         4
#                              STYLING_CHAIRS      0.000     0.000     0.000         2
#                               BICYCLE_SEATS      1.000     1.000     1.000         3
#                            VOLLEYBALL_BALLS      1.000     0.333     0.500         3
#                           SPHYGMOMANOMETERS      0.000     0.000     0.000         4
#                              BINDING_SPINES      0.000     0.000     0.000         2
#                    DIGITAL_WEATHER_STATIONS      1.000     1.000     1.000         2
#                          HOME_BOTTLE_STANDS      1.000     0.667     0.800         3
#                                   DOORBELLS      0.333     0.500     0.400         2
#                                DRIED_FRUITS      1.000     1.000     1.000         2
#                            BOXING_HEADGEARS      1.000     0.500     0.667         2
#
#                                    accuracy                          0.945    138544
#                                   macro avg      0.853     0.832     0.833    138544
#                                weighted avg      0.944     0.945     0.944    138544
