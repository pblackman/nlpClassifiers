# %%
# %load_ext autoreload
# %autoreload 2

from os.path import join
import os
import pandas as pd
import torch
import numpy as np
import torch.nn as nn
import torch.nn.functional as F
from torch.optim.lr_scheduler import ReduceLROnPlateau
from torch.nn.init import kaiming_uniform_
from torch.optim import SGD
from torch.utils.data import DataLoader, SequentialSampler, RandomSampler
from torch.optim import Adam
from torch.autograd import Variable
from nlpClassifiers.data.dataset  import NLPDataset, Vocabulary
from sklearn.metrics import roc_curve, auc, classification_report
from scipy.special import expit
import gensim
import shutil
from pathlib import Path
import random

# %%
ROOT = '../../'
PATH_TO_VIRTUAL_OPERATOR_DATA = join(ROOT, "data/virtual-operator")
PATH_TO_AGENT_BENCHMARK_DATA = join(ROOT, "data/agent-benchmark")
PATH_TO_ML_PT_DATA = join(ROOT, "data/mercado-livre-pt-only")

PATH_TO_VIRTUAL_OPERATOR_MODELS = join(ROOT, "models/virtual-operator")
PATH_TO_AGENT_BENCHMARK_MODELS = join(ROOT, "models/agent-benchmark")
PATH_TO_ML_PT_MODELS = join(ROOT, "models/mercado-livre-pt-only")
#EMBEDDINGS_FILE = '../../data/agent-benchmark/vocab/word2vec-model-agent-benchmark.bin'
EMBEDDING_DIM = 300
MAX_WORDS = 30000
dataset = 'mercado-livre-pt'

sentence_max_len = 82
batch_size = 512
biLSTM = True
epochs=30
stopwords_lang = None
gpu=1
lr=1e-3
clipping_value=0.25
save_name='bilstm-pytorch-jointly-trained-embeddings'
patience=5

# %%
BASE_PATH_TO_MODELS = {"virtual-operator": PATH_TO_VIRTUAL_OPERATOR_MODELS, "agent-benchmark": PATH_TO_AGENT_BENCHMARK_MODELS, "mercado-livre-pt": PATH_TO_ML_PT_MODELS}
FULL_PATH_TO_MODELS = join(BASE_PATH_TO_MODELS[dataset], "bilstm-classifier")

# %%
def _init_fn(worker_id):
    np.random.seed(seed)

# %%
def read_data(dataset, subset):
    BASE_PATH_TO_DATASET = {"virtual-operator": PATH_TO_VIRTUAL_OPERATOR_DATA, "agent-benchmark": PATH_TO_AGENT_BENCHMARK_DATA, "mercado-livre-pt": PATH_TO_ML_PT_DATA}
    BASE_PATH_TO_DATASET = {"train": join(BASE_PATH_TO_DATASET[dataset], "train.csv"), "val": join(BASE_PATH_TO_DATASET[dataset], "val.csv"), "test": join(BASE_PATH_TO_DATASET[dataset], "test.csv")}
    FULL_PATH_TO_DATASET = BASE_PATH_TO_DATASET[subset]
    
    if dataset == "mercado-livre-pt":
        sep=","
    else:
        sep=";"
    data = pd.read_csv(FULL_PATH_TO_DATASET, sep=sep, names =['utterance','label'], header=None, dtype={'utterance':str, 'label': str} )
    return data

# %%
train_df = read_data(dataset, "train")
val_df = read_data(dataset, "val")

# %%
voc = Vocabulary('CNN', stopwords_lang)
voc.build_vocab(train_df['utterance'].tolist() +  val_df['utterance'].tolist(), MAX_WORDS)
#embedding_weights = voc.load_embeddings(EMBEDDINGS_FILE, EMBEDDING_DIM)
if voc.num_words < MAX_WORDS or MAX_WORDS == 0:
    MAX_WORDS = voc.num_words

# %%
train_corpus = NLPDataset(dataset, "train", sentence_max_len, vocab= voc)
labels_dict = train_corpus.labels_dict
val_corpus = NLPDataset(dataset, "val", sentence_max_len, labels_dict = labels_dict, vocab= voc)

# %%
train_dataloader = DataLoader(
            train_corpus,
            sampler = RandomSampler(train_corpus),
            batch_size = batch_size,
            pin_memory=True,
            #shuffle=True,
            worker_init_fn=_init_fn,
            num_workers=0
)

validation_dataloader = DataLoader(
            val_corpus,
            sampler = RandomSampler(val_corpus),
            batch_size = batch_size,
            pin_memory=True,
            #shuffle=True,
            worker_init_fn=_init_fn,
            num_workers=0
)

# %%
#del model
torch.cuda.empty_cache()

# %%
def seed_everything(seed=10):
    random.seed(seed)
    os.environ['PYTHONHASHSEED'] = str(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    torch.backends.cudnn.deterministic = True

# %%
seed_everything()

# %%
device = torch.device(f"cuda:{gpu}")

# %%
class LSTMNet(nn.Module):
    def __init__(self, device, num_classes, num_features, criterion, embedding_dim, bidirectional, embedding_weights=None):
        super(LSTMNet, self).__init__()
        self.criterion = criterion
        self.embedding_dim = embedding_dim
        self.lstm_units = embedding_dim
        self.lstm_act = nn.Tanh()
        self.num_directions = 2 if bidirectional else 1
        self.device = device
        self.n_layers = 1
        self.embedding = nn.Embedding(num_features, embedding_dim, padding_idx = 0)
        
        if(embedding_weights is not None):
            print("Embedding layer Weights won't be updated.")
            #self.embedding.from_pretrained(embedding_weights, freeze=True)
            self.embedding.load_state_dict({'weight': embedding_weights})
            self.embedding.weight.requires_grad = False
        else:
            self.embedding.weight.data = torch.zeros(self.embedding.weight.data.size())
            self.embedding.weight.requires_grad = True
        
        self.lstm = nn.LSTM(embedding_dim, self.lstm_units, num_layers=self.n_layers, bidirectional=bidirectional, batch_first=True)

        self.dropout = nn.Dropout(0.2)       
        self.linear = nn.Linear(self.num_directions * self.lstm_units, num_classes)   
        self.init_weights()
        
    def forward(self, x, y):

        # lstm step => then ONLY take the sequence's final timetep to pass into the linear/dense layer
        # Note: lstm_out contains outputs for every step of the sequence we are looping over (for BPTT)
        # but we just need the output of the last step of the sequence, aka lstm_out[-1]
        #print("x input:", x.size())
        #set_trace()
        x = self.embedding(x)
        #print("embeddings:", x.size())
        x_, (h_n, c_n) = self.lstm(x)
        h = x_[:,-0,:]
        #h = self.lstm_act(h)
        '''        
        if self.num_directions == 2:
            h = torch.cat((h_n[-2, :, :], h_n[-1, :, :]), dim=1)
        else:
            h = h_n[-1, :, :]
        '''
        #print("h before activation:", h.size())
        #print("h after activation:", h.size())
        output = self.dropout(h)
        output = self.linear(output)
        #print("output after linear:", output.size())
        loss = self.criterion(output.squeeze(), y)
        #print("loss:", loss.size())
        return loss,output
    
    def init_weights(self):  
        nn.init.xavier_normal_(self.lstm.weight_hh_l0)
        nn.init.xavier_normal_(self.lstm.weight_ih_l0)
        nn.init.xavier_normal_(self.linear.weight.data)
       
        for name, param in self.lstm.named_parameters():
            if 'bias' in name:
                nn.init.constant_(param, 0.0)
            elif 'weight_ih' in name:
                nn.init.kaiming_normal_(param)
            elif 'weight_hh' in name:
                nn.init.orthogonal_(param)

# %%
criterion = torch.nn.CrossEntropyLoss()
model = LSTMNet(device, train_corpus.num_labels, MAX_WORDS, criterion, EMBEDDING_DIM, biLSTM)

# %%
model = model.to(device)
optimizer = Adam(model.parameters(),lr, betas=(0.7, 0.999))

# %%
def get_accuracy_from_logits(logits, labels):
    acc = (labels.cpu() == logits.cpu().argmax(-1)).float().detach().numpy()
    return float(100 * acc.sum() / len(acc))

# %%
scheduler = ReduceLROnPlateau(optimizer, mode='min', patience=3,verbose=True, factor=0.1)

best_epoch = -1
last_saved_model = ""
training_stats = []
global_step = 0
best_val_acc = float("-inf")
best_model_wts = None
best_curr_val = 0

for epoch_i in range(0, epochs):
    print("")
    print('======== Epoch {:} / {:} ========'.format(epoch_i + 1, epochs))
    print('Training...')
    total_train_loss = 0
    model.train()
    for step, batch in enumerate(train_dataloader):
         # Progress update every 40 batches.
        if step % 40 == 0 and not step == 0:
            print('  Batch {:>5,}  of  {:>5,}.    .'.format(step, len(train_dataloader)))
        b_input_ids = batch[0]
        b_labels = batch[1].clone().detach().to(device)
        b_input_ids = b_input_ids.clone().detach().to(device).long()
        loss, logits= model(b_input_ids, b_labels)
        step_loss = loss.item()
        model.zero_grad()
        loss.backward()
        torch.nn.utils.clip_grad_norm_(model.parameters(), clipping_value)
        optimizer.step()
        

        if step % 40 == 0 and not step == 0:
            print("  step loss: {0:.2f}".format(step_loss))
        total_train_loss += step_loss
        global_step += 1
    avg_train_loss = total_train_loss / len(train_dataloader)
    # Measure how long this epoch took.
    print("")
    print("  Average training loss: {0:.2f}".format(avg_train_loss))

    print("")
    print("Running Validation...")
    model.eval()

    # Tracking variables
    total_eval_accuracy = 0.0
    total_eval_loss = 0
    nb_eval_steps = 0
    for step, batch in enumerate(validation_dataloader):
        b_input_ids = batch[0]
        b_input_ids = b_input_ids.clone().detach().to(device).long()
        b_labels = batch[1].to(device)
        with torch.no_grad():
            # Forward pass, calculate logit predictions.
            loss, logits = model(b_input_ids, b_labels)
        total_eval_loss += loss
        batch_acc = get_accuracy_from_logits(logits, b_labels)
        print("Batch accuracy: {0:.2f}".format(batch_acc))
        total_eval_accuracy += batch_acc
    
    # Calculate the average loss over all of the batches.
    avg_val_accuracy = total_eval_accuracy / len(validation_dataloader)
    print("  Accuracy: {0:.2f}".format(avg_val_accuracy))
    
    if avg_val_accuracy > best_val_acc:
        print(f"New best model, saving it!")
        if avg_val_accuracy > best_curr_val:
            best_curr_val = avg_val_accuracy
        if last_saved_model:
            shutil.rmtree(last_saved_model)
        model_path = Path(
            FULL_PATH_TO_MODELS,
            f"base-dataset-{dataset}-{save_name}"
        )
        last_saved_model = model_path
        model_path.mkdir(parents=True, exist_ok=True)
        best_val_acc = avg_val_accuracy
        torch.save(model, join(model_path, "best-model.pth"))
        best_epoch = epoch_i
        n_epochs_no_improvement = 0
    elif avg_val_accuracy > best_curr_val:
        best_curr_val = avg_val_accuracy
        n_epochs_no_improvement = 0
    else:
        n_epochs_no_improvement += 1
        print(f"The model does not improve for {n_epochs_no_improvement} epochs!")

    if n_epochs_no_improvement > patience:
        print(f"====>Stopping training, the model did not improve for {n_epochs_no_improvement}\n====>Best epoch: {best_epoch + 1}.")
        break
    scheduler.step(total_eval_loss)
print("")
print("Training complete!")
# Out:
# ======== Epoch 1 / 30 ========
# Training...
#   Batch    40  of    975.    .
#   step loss: 5.73
#   Batch    80  of    975.    .
#   step loss: 4.16
#   Batch   120  of    975.    .
#   step loss: 2.62
#   Batch   160  of    975.    .
#   step loss: 1.68
#   Batch   200  of    975.    .
#   step loss: 1.25
#   Batch   240  of    975.    .
#   step loss: 1.14
#   Batch   280  of    975.    .
#   step loss: 0.82
#   Batch   320  of    975.    .
#   step loss: 0.83
#   Batch   360  of    975.    .
#   step loss: 0.81
#   Batch   400  of    975.    .
#   step loss: 0.65
#   Batch   440  of    975.    .
#   step loss: 0.64
#   Batch   480  of    975.    .
#   step loss: 0.62
#   Batch   520  of    975.    .
#   step loss: 0.47
#   Batch   560  of    975.    .
#   step loss: 0.55
#   Batch   600  of    975.    .
#   step loss: 0.48
#   Batch   640  of    975.    .
#   step loss: 0.58
#   Batch   680  of    975.    .
#   step loss: 0.43
#   Batch   720  of    975.    .
#   step loss: 0.38
#   Batch   760  of    975.    .
#   step loss: 0.31
#   Batch   800  of    975.    .
#   step loss: 0.36
#   Batch   840  of    975.    .
#   step loss: 0.32
#   Batch   880  of    975.    .
#   step loss: 0.40
#   Batch   920  of    975.    .
#   step loss: 0.37
#   Batch   960  of    975.    .
#   step loss: 0.29
#
#   Average training loss: 1.20
#
# Running Validation...
# Batch accuracy: 91.99
# Batch accuracy: 91.41
# Batch accuracy: 94.14
# Batch accuracy: 93.16
# Batch accuracy: 92.58
# Batch accuracy: 92.38
# Batch accuracy: 91.80
# Batch accuracy: 92.58
# Batch accuracy: 94.53
# Batch accuracy: 90.82
# Batch accuracy: 94.73
# Batch accuracy: 92.38
# Batch accuracy: 94.34
# Batch accuracy: 95.70
# Batch accuracy: 93.36
# Batch accuracy: 90.62
# Batch accuracy: 92.97
# Batch accuracy: 92.77
# Batch accuracy: 90.23
# Batch accuracy: 90.04
# Batch accuracy: 90.62
# Batch accuracy: 93.75
# Batch accuracy: 93.95
# Batch accuracy: 92.97
# Batch accuracy: 92.19
# Batch accuracy: 91.80
# Batch accuracy: 93.55
# Batch accuracy: 92.77
# Batch accuracy: 93.36
# Batch accuracy: 90.82
# Batch accuracy: 93.16
# Batch accuracy: 92.97
# Batch accuracy: 92.58
# Batch accuracy: 94.34
# Batch accuracy: 93.95
# Batch accuracy: 93.55
# Batch accuracy: 91.60
# Batch accuracy: 91.60
# Batch accuracy: 91.60
# Batch accuracy: 92.19
# Batch accuracy: 94.34
# Batch accuracy: 93.75
# Batch accuracy: 93.55
# Batch accuracy: 91.80
# Batch accuracy: 91.99
# Batch accuracy: 92.97
# Batch accuracy: 91.41
# Batch accuracy: 92.58
# Batch accuracy: 92.58
# Batch accuracy: 92.58
# Batch accuracy: 92.58
# Batch accuracy: 91.21
# Batch accuracy: 90.62
# Batch accuracy: 93.16
# Batch accuracy: 93.36
# Batch accuracy: 93.36
# Batch accuracy: 92.38
# Batch accuracy: 91.41
# Batch accuracy: 92.97
# Batch accuracy: 92.19
# Batch accuracy: 93.36
# Batch accuracy: 91.80
# Batch accuracy: 90.23
# Batch accuracy: 93.16
# Batch accuracy: 92.38
# Batch accuracy: 91.99
# Batch accuracy: 94.73
# Batch accuracy: 92.38
# Batch accuracy: 93.16
# Batch accuracy: 91.21
# Batch accuracy: 94.53
# Batch accuracy: 91.60
# Batch accuracy: 94.73
# Batch accuracy: 94.92
# Batch accuracy: 93.55
# Batch accuracy: 92.97
# Batch accuracy: 90.82
# Batch accuracy: 94.34
# Batch accuracy: 94.53
# Batch accuracy: 92.77
# Batch accuracy: 91.21
# Batch accuracy: 91.21
# Batch accuracy: 92.38
# Batch accuracy: 92.58
# Batch accuracy: 89.84
# Batch accuracy: 91.80
# Batch accuracy: 93.16
# Batch accuracy: 92.97
# Batch accuracy: 91.99
# Batch accuracy: 93.16
# Batch accuracy: 94.14
# Batch accuracy: 93.55
# Batch accuracy: 93.55
# Batch accuracy: 93.95
# Batch accuracy: 93.36
# Batch accuracy: 92.97
# Batch accuracy: 91.60
# Batch accuracy: 91.99
# Batch accuracy: 92.58
# Batch accuracy: 93.16
# Batch accuracy: 93.75
# Batch accuracy: 92.97
# Batch accuracy: 93.16
# Batch accuracy: 93.16
# Batch accuracy: 92.38
# Batch accuracy: 91.60
# Batch accuracy: 93.36
# Batch accuracy: 92.97
# Batch accuracy: 93.55
#   Accuracy: 92.70
# New best model, saving it!
#
# ======== Epoch 2 / 30 ========
# Training...
#   Batch    40  of    975.    .
#   step loss: 0.23
#   Batch    80  of    975.    .
#   step loss: 0.25
#   Batch   120  of    975.    .
#   step loss: 0.22
#   Batch   160  of    975.    .
#   step loss: 0.21
#   Batch   200  of    975.    .
#   step loss: 0.16
#   Batch   240  of    975.    .
#   step loss: 0.20
#   Batch   280  of    975.    .
#   step loss: 0.23
#   Batch   320  of    975.    .
#   step loss: 0.23
#   Batch   360  of    975.    .
#   step loss: 0.34
#   Batch   400  of    975.    .
#   step loss: 0.32
#   Batch   440  of    975.    .
#   step loss: 0.28
#   Batch   480  of    975.    .
#   step loss: 0.25
#   Batch   520  of    975.    .
#   step loss: 0.19
#   Batch   560  of    975.    .
#   step loss: 0.35
#   Batch   600  of    975.    .
#   step loss: 0.25
#   Batch   640  of    975.    .
#   step loss: 0.28
#   Batch   680  of    975.    .
#   step loss: 0.22
#   Batch   720  of    975.    .
#   step loss: 0.17
#   Batch   760  of    975.    .
#   step loss: 0.29
#   Batch   800  of    975.    .
#   step loss: 0.14
#   Batch   840  of    975.    .
#   step loss: 0.23
#   Batch   880  of    975.    .
#   step loss: 0.20
#   Batch   920  of    975.    .
#   step loss: 0.20
#   Batch   960  of    975.    .
#   step loss: 0.21
#
#   Average training loss: 0.24
#
# Running Validation...
# Batch accuracy: 92.97
# Batch accuracy: 93.75
# Batch accuracy: 92.58
# Batch accuracy: 92.19
# Batch accuracy: 92.77
# Batch accuracy: 94.14
# Batch accuracy: 92.97
# Batch accuracy: 95.12
# Batch accuracy: 91.60
# Batch accuracy: 92.97
# Batch accuracy: 93.55
# Batch accuracy: 93.36
# Batch accuracy: 93.16
# Batch accuracy: 92.38
# Batch accuracy: 95.12
# Batch accuracy: 93.95
# Batch accuracy: 94.53
# Batch accuracy: 94.73
# Batch accuracy: 94.34
# Batch accuracy: 91.60
# Batch accuracy: 95.12
# Batch accuracy: 93.55
# Batch accuracy: 93.16
# Batch accuracy: 95.51
# Batch accuracy: 92.38
# Batch accuracy: 92.97
# Batch accuracy: 93.95
# Batch accuracy: 94.14
# Batch accuracy: 91.99
# Batch accuracy: 94.92
# Batch accuracy: 91.99
# Batch accuracy: 94.34
# Batch accuracy: 92.19
# Batch accuracy: 94.92
# Batch accuracy: 91.60
# Batch accuracy: 94.14
# Batch accuracy: 91.99
# Batch accuracy: 92.77
# Batch accuracy: 94.53
# Batch accuracy: 92.58
# Batch accuracy: 92.38
# Batch accuracy: 95.70
# Batch accuracy: 93.95
# Batch accuracy: 93.75
# Batch accuracy: 93.75
# Batch accuracy: 94.34
# Batch accuracy: 93.95
# Batch accuracy: 92.19
# Batch accuracy: 93.55
# Batch accuracy: 92.19
# Batch accuracy: 93.36
# Batch accuracy: 94.14
# Batch accuracy: 92.97
# Batch accuracy: 93.55
# Batch accuracy: 94.53
# Batch accuracy: 91.99
# Batch accuracy: 94.53
# Batch accuracy: 92.58
# Batch accuracy: 91.99
# Batch accuracy: 93.36
# Batch accuracy: 91.99
# Batch accuracy: 91.21
# Batch accuracy: 92.77
# Batch accuracy: 92.97
# Batch accuracy: 94.14
# Batch accuracy: 93.36
# Batch accuracy: 93.95
# Batch accuracy: 95.12
# Batch accuracy: 94.14
# Batch accuracy: 94.73
# Batch accuracy: 92.19
# Batch accuracy: 94.53
# Batch accuracy: 94.92
# Batch accuracy: 93.16
# Batch accuracy: 91.80
# Batch accuracy: 95.12
# Batch accuracy: 93.36
# Batch accuracy: 93.75
# Batch accuracy: 94.14
# Batch accuracy: 94.14
# Batch accuracy: 91.80
# Batch accuracy: 94.92
# Batch accuracy: 94.34
# Batch accuracy: 94.53
# Batch accuracy: 94.34
# Batch accuracy: 93.36
# Batch accuracy: 94.53
# Batch accuracy: 93.55
# Batch accuracy: 91.99
# Batch accuracy: 92.58
# Batch accuracy: 94.73
# Batch accuracy: 94.53
# Batch accuracy: 92.19
# Batch accuracy: 93.75
# Batch accuracy: 92.77
# Batch accuracy: 95.12
# Batch accuracy: 93.95
# Batch accuracy: 93.95
# Batch accuracy: 93.55
# Batch accuracy: 90.82
# Batch accuracy: 94.92
# Batch accuracy: 93.36
# Batch accuracy: 93.36
# Batch accuracy: 94.53
# Batch accuracy: 93.36
# Batch accuracy: 92.58
# Batch accuracy: 93.16
# Batch accuracy: 91.99
# Batch accuracy: 95.97
#   Accuracy: 93.50
# New best model, saving it!
#
# ======== Epoch 3 / 30 ========
# Training...
#   Batch    40  of    975.    .
#   step loss: 0.09
#   Batch    80  of    975.    .
#   step loss: 0.09
#   Batch   120  of    975.    .
#   step loss: 0.15
#   Batch   160  of    975.    .
#   step loss: 0.11
#   Batch   200  of    975.    .
#   step loss: 0.15
#   Batch   240  of    975.    .
#   step loss: 0.11
#   Batch   280  of    975.    .
#   step loss: 0.14
#   Batch   320  of    975.    .
#   step loss: 0.15
#   Batch   360  of    975.    .
#   step loss: 0.12
#   Batch   400  of    975.    .
#   step loss: 0.14
#   Batch   440  of    975.    .
#   step loss: 0.20
#   Batch   480  of    975.    .
#   step loss: 0.15
#   Batch   520  of    975.    .
#   step loss: 0.14
#   Batch   560  of    975.    .
#   step loss: 0.13
#   Batch   600  of    975.    .
#   step loss: 0.17
#   Batch   640  of    975.    .
#   step loss: 0.17
#   Batch   680  of    975.    .
#   step loss: 0.19
#   Batch   720  of    975.    .
#   step loss: 0.19
#   Batch   760  of    975.    .
#   step loss: 0.22
#   Batch   800  of    975.    .
#   step loss: 0.14
#   Batch   840  of    975.    .
#   step loss: 0.13
#   Batch   880  of    975.    .
#   step loss: 0.22
#   Batch   920  of    975.    .
#   step loss: 0.15
#   Batch   960  of    975.    .
#   step loss: 0.23
#
#   Average training loss: 0.16
#
# Running Validation...
# Batch accuracy: 92.19
# Batch accuracy: 92.19
# Batch accuracy: 93.75
# Batch accuracy: 92.77
# Batch accuracy: 91.41
# Batch accuracy: 92.97
# Batch accuracy: 92.19
# Batch accuracy: 90.82
# Batch accuracy: 93.55
# Batch accuracy: 92.97
# Batch accuracy: 93.75
# Batch accuracy: 94.92
# Batch accuracy: 94.53
# Batch accuracy: 93.95
# Batch accuracy: 92.38
# Batch accuracy: 94.14
# Batch accuracy: 93.36
# Batch accuracy: 93.36
# Batch accuracy: 94.53
# Batch accuracy: 93.16
# Batch accuracy: 92.97
# Batch accuracy: 92.58
# Batch accuracy: 92.58
# Batch accuracy: 94.14
# Batch accuracy: 93.36
# Batch accuracy: 93.36
# Batch accuracy: 91.80
# Batch accuracy: 92.77
# Batch accuracy: 95.31
# Batch accuracy: 92.19
# Batch accuracy: 93.95
# Batch accuracy: 94.14
# Batch accuracy: 94.14
# Batch accuracy: 90.62
# Batch accuracy: 93.95
# Batch accuracy: 94.14
# Batch accuracy: 92.77
# Batch accuracy: 93.55
# Batch accuracy: 94.34
# Batch accuracy: 95.31
# Batch accuracy: 92.97
# Batch accuracy: 95.31
# Batch accuracy: 95.12
# Batch accuracy: 93.95
# Batch accuracy: 93.36
# Batch accuracy: 92.97
# Batch accuracy: 93.75
# Batch accuracy: 94.53
# Batch accuracy: 93.75
# Batch accuracy: 95.31
# Batch accuracy: 92.77
# Batch accuracy: 92.58
# Batch accuracy: 92.58
# Batch accuracy: 93.16
# Batch accuracy: 93.95
# Batch accuracy: 95.12
# Batch accuracy: 91.60
# Batch accuracy: 94.34
# Batch accuracy: 91.99
# Batch accuracy: 93.36
# Batch accuracy: 93.75
# Batch accuracy: 94.53
# Batch accuracy: 93.16
# Batch accuracy: 93.75
# Batch accuracy: 93.75
# Batch accuracy: 94.53
# Batch accuracy: 93.95
# Batch accuracy: 94.34
# Batch accuracy: 92.77
# Batch accuracy: 94.53
# Batch accuracy: 95.12
# Batch accuracy: 92.77
# Batch accuracy: 92.77
# Batch accuracy: 92.97
# Batch accuracy: 94.34
# Batch accuracy: 92.58
# Batch accuracy: 92.38
# Batch accuracy: 93.95
# Batch accuracy: 93.36
# Batch accuracy: 92.77
# Batch accuracy: 94.92
# Batch accuracy: 94.92
# Batch accuracy: 93.95
# Batch accuracy: 94.92
# Batch accuracy: 93.95
# Batch accuracy: 94.53
# Batch accuracy: 95.31
# Batch accuracy: 93.55
# Batch accuracy: 92.38
# Batch accuracy: 93.36
# Batch accuracy: 95.12
# Batch accuracy: 94.34
# Batch accuracy: 93.95
# Batch accuracy: 94.14
# Batch accuracy: 93.36
# Batch accuracy: 93.95
# Batch accuracy: 92.97
# Batch accuracy: 94.53
# Batch accuracy: 93.95
# Batch accuracy: 93.55
# Batch accuracy: 92.38
# Batch accuracy: 93.16
# Batch accuracy: 94.34
# Batch accuracy: 92.58
# Batch accuracy: 93.75
# Batch accuracy: 94.92
# Batch accuracy: 93.36
# Batch accuracy: 93.36
# Batch accuracy: 96.77
#   Accuracy: 93.59
# New best model, saving it!
#
# ======== Epoch 4 / 30 ========
# Training...
#   Batch    40  of    975.    .
#   step loss: 0.07
#   Batch    80  of    975.    .
#   step loss: 0.12
#   Batch   120  of    975.    .
#   step loss: 0.13
#   Batch   160  of    975.    .
#   step loss: 0.10
#   Batch   200  of    975.    .
#   step loss: 0.10
#   Batch   240  of    975.    .
#   step loss: 0.09
#   Batch   280  of    975.    .
#   step loss: 0.11
#   Batch   320  of    975.    .
#   step loss: 0.12
#   Batch   360  of    975.    .
#   step loss: 0.11
#   Batch   400  of    975.    .
#   step loss: 0.10
#   Batch   440  of    975.    .
#   step loss: 0.18
#   Batch   480  of    975.    .
#   step loss: 0.09
#   Batch   520  of    975.    .
#   step loss: 0.09
#   Batch   560  of    975.    .
#   step loss: 0.11
#   Batch   600  of    975.    .
#   step loss: 0.16
#   Batch   640  of    975.    .
#   step loss: 0.16
#   Batch   680  of    975.    .
#   step loss: 0.14
#   Batch   720  of    975.    .
#   step loss: 0.13
#   Batch   760  of    975.    .
#   step loss: 0.11
#   Batch   800  of    975.    .
#   step loss: 0.10
#   Batch   840  of    975.    .
#   step loss: 0.16
#   Batch   880  of    975.    .
#   step loss: 0.11
#   Batch   920  of    975.    .
#   step loss: 0.17
#   Batch   960  of    975.    .
#   step loss: 0.15
#
#   Average training loss: 0.11
#
# Running Validation...
# Batch accuracy: 91.80
# Batch accuracy: 91.80
# Batch accuracy: 92.19
# Batch accuracy: 93.36
# Batch accuracy: 93.75
# Batch accuracy: 94.34
# Batch accuracy: 92.77
# Batch accuracy: 92.58
# Batch accuracy: 94.14
# Batch accuracy: 93.36
# Batch accuracy: 91.41
# Batch accuracy: 93.55
# Batch accuracy: 92.97
# Batch accuracy: 92.38
# Batch accuracy: 92.58
# Batch accuracy: 93.75
# Batch accuracy: 94.34
# Batch accuracy: 93.16
# Batch accuracy: 94.14
# Batch accuracy: 94.34
# Batch accuracy: 93.95
# Batch accuracy: 93.55
# Batch accuracy: 92.97
# Batch accuracy: 93.55
# Batch accuracy: 93.16
# Batch accuracy: 93.95
# Batch accuracy: 95.51
# Batch accuracy: 93.95
# Batch accuracy: 95.12
# Batch accuracy: 93.36
# Batch accuracy: 92.58
# Batch accuracy: 92.77
# Batch accuracy: 93.95
# Batch accuracy: 94.14
# Batch accuracy: 93.75
# Batch accuracy: 95.31
# Batch accuracy: 93.16
# Batch accuracy: 92.58
# Batch accuracy: 92.97
# Batch accuracy: 92.19
# Batch accuracy: 92.77
# Batch accuracy: 94.73
# Batch accuracy: 94.92
# Batch accuracy: 91.99
# Batch accuracy: 92.77
# Batch accuracy: 91.99
# Batch accuracy: 93.95
# Batch accuracy: 92.97
# Batch accuracy: 92.38
# Batch accuracy: 94.73
# Batch accuracy: 92.38
# Batch accuracy: 93.36
# Batch accuracy: 93.55
# Batch accuracy: 92.77
# Batch accuracy: 93.36
# Batch accuracy: 94.53
# Batch accuracy: 95.70
# Batch accuracy: 94.53
# Batch accuracy: 92.19
# Batch accuracy: 93.16
# Batch accuracy: 93.16
# Batch accuracy: 94.92
# Batch accuracy: 94.73
# Batch accuracy: 93.36
# Batch accuracy: 95.90
# Batch accuracy: 94.34
# Batch accuracy: 93.36
# Batch accuracy: 91.60
# Batch accuracy: 92.38
# Batch accuracy: 94.14
# Batch accuracy: 92.77
# Batch accuracy: 92.19
# Batch accuracy: 95.51
# Batch accuracy: 94.34
# Batch accuracy: 93.95
# Batch accuracy: 93.95
# Batch accuracy: 94.92
# Batch accuracy: 93.95
# Batch accuracy: 91.21
# Batch accuracy: 93.16
# Batch accuracy: 94.14
# Batch accuracy: 92.58
# Batch accuracy: 92.77
# Batch accuracy: 92.77
# Batch accuracy: 93.16
# Batch accuracy: 94.53
# Batch accuracy: 92.97
# Batch accuracy: 93.16
# Batch accuracy: 93.55
# Batch accuracy: 94.92
# Batch accuracy: 93.75
# Batch accuracy: 92.97
# Batch accuracy: 92.97
# Batch accuracy: 92.77
# Batch accuracy: 94.92
# Batch accuracy: 94.92
# Batch accuracy: 92.58
# Batch accuracy: 90.82
# Batch accuracy: 94.73
# Batch accuracy: 91.80
# Batch accuracy: 94.34
# Batch accuracy: 93.55
# Batch accuracy: 93.95
# Batch accuracy: 94.14
# Batch accuracy: 95.51
# Batch accuracy: 91.99
# Batch accuracy: 93.95
# Batch accuracy: 95.12
# Batch accuracy: 93.55
#   Accuracy: 93.49
# The model does not improve for 1 epochs!
#
# ======== Epoch 5 / 30 ========
# Training...
#   Batch    40  of    975.    .
#   step loss: 0.09
#   Batch    80  of    975.    .
#   step loss: 0.05
#   Batch   120  of    975.    .
#   step loss: 0.07
#   Batch   160  of    975.    .
#   step loss: 0.07
#   Batch   200  of    975.    .
#   step loss: 0.07
#   Batch   240  of    975.    .
#   step loss: 0.07
#   Batch   280  of    975.    .
#   step loss: 0.11
#   Batch   320  of    975.    .
#   step loss: 0.08
#   Batch   360  of    975.    .
#   step loss: 0.12
#   Batch   400  of    975.    .
#   step loss: 0.09
#   Batch   440  of    975.    .
#   step loss: 0.10
#   Batch   480  of    975.    .
#   step loss: 0.11
#   Batch   520  of    975.    .
#   step loss: 0.08
#   Batch   560  of    975.    .
#   step loss: 0.06
#   Batch   600  of    975.    .
#   step loss: 0.08
#   Batch   640  of    975.    .
#   step loss: 0.07
#   Batch   680  of    975.    .
#   step loss: 0.11
#   Batch   720  of    975.    .
#   step loss: 0.05
#   Batch   760  of    975.    .
#   step loss: 0.07
#   Batch   800  of    975.    .
#   step loss: 0.08
#   Batch   840  of    975.    .
#   step loss: 0.10
#   Batch   880  of    975.    .
#   step loss: 0.05
#   Batch   920  of    975.    .
#   step loss: 0.05
#   Batch   960  of    975.    .
#   step loss: 0.09
#
#   Average training loss: 0.08
#
# Running Validation...
# Batch accuracy: 94.73
# Batch accuracy: 93.55
# Batch accuracy: 94.14
# Batch accuracy: 93.55
# Batch accuracy: 93.55
# Batch accuracy: 92.58
# Batch accuracy: 92.58
# Batch accuracy: 94.34
# Batch accuracy: 91.60
# Batch accuracy: 92.97
# Batch accuracy: 91.60
# Batch accuracy: 93.55
# Batch accuracy: 93.55
# Batch accuracy: 94.73
# Batch accuracy: 94.73
# Batch accuracy: 92.77
# Batch accuracy: 91.60
# Batch accuracy: 94.92
# Batch accuracy: 95.31
# Batch accuracy: 93.36
# Batch accuracy: 95.31
# Batch accuracy: 91.60
# Batch accuracy: 93.36
# Batch accuracy: 91.80
# Batch accuracy: 92.38
# Batch accuracy: 93.55
# Batch accuracy: 95.70
# Batch accuracy: 92.97
# Batch accuracy: 92.19
# Batch accuracy: 94.14
# Batch accuracy: 94.73
# Batch accuracy: 92.58
# Batch accuracy: 92.58
# Batch accuracy: 95.12
# Batch accuracy: 92.97
# Batch accuracy: 93.16
# Batch accuracy: 94.14
# Batch accuracy: 93.16
# Batch accuracy: 93.16
# Batch accuracy: 94.14
# Batch accuracy: 94.34
# Batch accuracy: 94.53
# Batch accuracy: 92.58
# Batch accuracy: 94.53
# Batch accuracy: 92.38
# Batch accuracy: 95.90
# Batch accuracy: 92.77
# Batch accuracy: 92.97
# Batch accuracy: 92.38
# Batch accuracy: 94.14
# Batch accuracy: 93.75
# Batch accuracy: 94.34
# Batch accuracy: 94.34
# Batch accuracy: 91.60
# Batch accuracy: 94.14
# Batch accuracy: 92.19
# Batch accuracy: 95.12
# Batch accuracy: 93.95
# Batch accuracy: 91.21
# Batch accuracy: 93.16
# Batch accuracy: 93.55
# Batch accuracy: 93.55
# Batch accuracy: 93.95
# Batch accuracy: 94.73
# Batch accuracy: 93.55
# Batch accuracy: 94.53
# Batch accuracy: 93.36
# Batch accuracy: 92.77
# Batch accuracy: 92.58
# Batch accuracy: 92.58
# Batch accuracy: 94.92
# Batch accuracy: 93.75
# Batch accuracy: 94.92
# Batch accuracy: 93.75
# Batch accuracy: 94.14
# Batch accuracy: 92.97
# Batch accuracy: 93.36
# Batch accuracy: 93.95
# Batch accuracy: 94.34
# Batch accuracy: 92.77
# Batch accuracy: 94.14
# Batch accuracy: 93.55
# Batch accuracy: 92.19
# Batch accuracy: 94.92
# Batch accuracy: 94.14
# Batch accuracy: 95.51
# Batch accuracy: 94.92
# Batch accuracy: 94.73
# Batch accuracy: 93.75
# Batch accuracy: 93.95
# Batch accuracy: 94.34
# Batch accuracy: 94.34
# Batch accuracy: 93.16
# Batch accuracy: 93.75
# Batch accuracy: 94.14
# Batch accuracy: 92.97
# Batch accuracy: 93.36
# Batch accuracy: 92.97
# Batch accuracy: 94.34
# Batch accuracy: 92.97
# Batch accuracy: 94.34
# Batch accuracy: 94.14
# Batch accuracy: 90.62
# Batch accuracy: 92.77
# Batch accuracy: 93.36
# Batch accuracy: 91.80
# Batch accuracy: 92.58
# Batch accuracy: 91.99
# Batch accuracy: 96.77
#   Accuracy: 93.57
# The model does not improve for 2 epochs!
#
# ======== Epoch 6 / 30 ========
# Training...
#   Batch    40  of    975.    .
#   step loss: 0.05
#   Batch    80  of    975.    .
#   step loss: 0.07
#   Batch   120  of    975.    .
#   step loss: 0.07
#   Batch   160  of    975.    .
#   step loss: 0.07
#   Batch   200  of    975.    .
#   step loss: 0.05
#   Batch   240  of    975.    .
#   step loss: 0.04
#   Batch   280  of    975.    .
#   step loss: 0.04
#   Batch   320  of    975.    .
#   step loss: 0.08
#   Batch   360  of    975.    .
#   step loss: 0.06
#   Batch   400  of    975.    .
#   step loss: 0.05
#   Batch   440  of    975.    .
#   step loss: 0.08
#   Batch   480  of    975.    .
#   step loss: 0.04
#   Batch   520  of    975.    .
#   step loss: 0.04
#   Batch   560  of    975.    .
#   step loss: 0.04
#   Batch   600  of    975.    .
#   step loss: 0.07
#   Batch   640  of    975.    .
#   step loss: 0.06
#   Batch   680  of    975.    .
#   step loss: 0.07
#   Batch   720  of    975.    .
#   step loss: 0.06
#   Batch   760  of    975.    .
#   step loss: 0.08
#   Batch   800  of    975.    .
#   step loss: 0.07
#   Batch   840  of    975.    .
#   step loss: 0.06
#   Batch   880  of    975.    .
#   step loss: 0.06
#   Batch   920  of    975.    .
#   step loss: 0.08
#   Batch   960  of    975.    .
#   step loss: 0.09
#
#   Average training loss: 0.06
#
# Running Validation...
# Batch accuracy: 93.95
# Batch accuracy: 93.55
# Batch accuracy: 93.55
# Batch accuracy: 92.77
# Batch accuracy: 93.55
# Batch accuracy: 91.80
# Batch accuracy: 95.31
# Batch accuracy: 93.75
# Batch accuracy: 91.60
# Batch accuracy: 92.77
# Batch accuracy: 91.99
# Batch accuracy: 93.16
# Batch accuracy: 93.16
# Batch accuracy: 91.21
# Batch accuracy: 91.99
# Batch accuracy: 92.77
# Batch accuracy: 92.38
# Batch accuracy: 93.95
# Batch accuracy: 92.77
# Batch accuracy: 93.16
# Batch accuracy: 95.12
# Batch accuracy: 94.92
# Batch accuracy: 93.95
# Batch accuracy: 91.02
# Batch accuracy: 93.16
# Batch accuracy: 91.60
# Batch accuracy: 94.92
# Batch accuracy: 94.14
# Batch accuracy: 92.77
# Batch accuracy: 93.95
# Batch accuracy: 94.92
# Batch accuracy: 93.95
# Batch accuracy: 91.80
# Batch accuracy: 93.36
# Batch accuracy: 93.36
# Batch accuracy: 92.97
# Batch accuracy: 92.58
# Batch accuracy: 93.36
# Batch accuracy: 93.55
# Batch accuracy: 92.19
# Batch accuracy: 91.80
# Batch accuracy: 92.58
# Batch accuracy: 93.95
# Batch accuracy: 91.41
# Batch accuracy: 94.92
# Batch accuracy: 92.58
# Batch accuracy: 93.16
# Batch accuracy: 94.92
# Batch accuracy: 93.75
# Batch accuracy: 92.58
# Batch accuracy: 92.38
# Batch accuracy: 91.21
# Batch accuracy: 94.14
# Batch accuracy: 93.36
# Batch accuracy: 95.31
# Batch accuracy: 93.55
# Batch accuracy: 93.16
# Batch accuracy: 91.60
# Batch accuracy: 93.55
# Batch accuracy: 93.55
# Batch accuracy: 91.02
# Batch accuracy: 91.99
# Batch accuracy: 91.41
# Batch accuracy: 94.53
# Batch accuracy: 94.53
# Batch accuracy: 94.73
# Batch accuracy: 91.80
# Batch accuracy: 95.51
# Batch accuracy: 93.16
# Batch accuracy: 94.14
# Batch accuracy: 91.99
# Batch accuracy: 92.38
# Batch accuracy: 93.16
# Batch accuracy: 93.16
# Batch accuracy: 94.53
# Batch accuracy: 93.55
# Batch accuracy: 94.73
# Batch accuracy: 92.58
# Batch accuracy: 91.80
# Batch accuracy: 94.53
# Batch accuracy: 93.36
# Batch accuracy: 92.77
# Batch accuracy: 93.75
# Batch accuracy: 93.75
# Batch accuracy: 92.38
# Batch accuracy: 92.19
# Batch accuracy: 94.14
# Batch accuracy: 92.97
# Batch accuracy: 95.51
# Batch accuracy: 93.55
# Batch accuracy: 94.14
# Batch accuracy: 93.36
# Batch accuracy: 94.34
# Batch accuracy: 94.53
# Batch accuracy: 93.55
# Batch accuracy: 92.77
# Batch accuracy: 94.53
# Batch accuracy: 95.12
# Batch accuracy: 93.16
# Batch accuracy: 94.92
# Batch accuracy: 94.73
# Batch accuracy: 92.97
# Batch accuracy: 92.97
# Batch accuracy: 92.38
# Batch accuracy: 93.36
# Batch accuracy: 93.95
# Batch accuracy: 93.95
# Batch accuracy: 93.95
# Batch accuracy: 96.77
#   Accuracy: 93.35
# The model does not improve for 3 epochs!
# Epoch     6: reducing learning rate of group 0 to 1.0000e-04.
#
# ======== Epoch 7 / 30 ========
# Training...
#   Batch    40  of    975.    .
#   step loss: 0.05
#   Batch    80  of    975.    .
#   step loss: 0.06
#   Batch   120  of    975.    .
#   step loss: 0.02
#   Batch   160  of    975.    .
#   step loss: 0.05
#   Batch   200  of    975.    .
#   step loss: 0.03
#   Batch   240  of    975.    .
#   step loss: 0.05
#   Batch   280  of    975.    .
#   step loss: 0.03
#   Batch   320  of    975.    .
#   step loss: 0.06
#   Batch   360  of    975.    .
#   step loss: 0.04
#   Batch   400  of    975.    .
#   step loss: 0.05
#   Batch   440  of    975.    .
#   step loss: 0.03
#   Batch   480  of    975.    .
#   step loss: 0.03
#   Batch   520  of    975.    .
#   step loss: 0.06
#   Batch   560  of    975.    .
#   step loss: 0.04
#   Batch   600  of    975.    .
#   step loss: 0.05
#   Batch   640  of    975.    .
#   step loss: 0.05
#   Batch   680  of    975.    .
#   step loss: 0.04
#   Batch   720  of    975.    .
#   step loss: 0.03
#   Batch   760  of    975.    .
#   step loss: 0.01
#   Batch   800  of    975.    .
#   step loss: 0.06
#   Batch   840  of    975.    .
#   step loss: 0.05
#   Batch   880  of    975.    .
#   step loss: 0.03
#   Batch   920  of    975.    .
#   step loss: 0.06
#   Batch   960  of    975.    .
#   step loss: 0.01
#
#   Average training loss: 0.04
#
# Running Validation...
# Batch accuracy: 93.36
# Batch accuracy: 92.97
# Batch accuracy: 92.97
# Batch accuracy: 93.95
# Batch accuracy: 93.36
# Batch accuracy: 91.60
# Batch accuracy: 94.92
# Batch accuracy: 95.31
# Batch accuracy: 93.55
# Batch accuracy: 92.97
# Batch accuracy: 94.92
# Batch accuracy: 92.38
# Batch accuracy: 91.41
# Batch accuracy: 92.97
# Batch accuracy: 94.34
# Batch accuracy: 94.14
# Batch accuracy: 93.16
# Batch accuracy: 94.14
# Batch accuracy: 93.16
# Batch accuracy: 93.36
# Batch accuracy: 91.60
# Batch accuracy: 94.53
# Batch accuracy: 94.92
# Batch accuracy: 94.14
# Batch accuracy: 92.58
# Batch accuracy: 94.53
# Batch accuracy: 92.58
# Batch accuracy: 93.55
# Batch accuracy: 94.92
# Batch accuracy: 94.34
# Batch accuracy: 93.16
# Batch accuracy: 94.73
# Batch accuracy: 93.16
# Batch accuracy: 93.55
# Batch accuracy: 94.92
# Batch accuracy: 93.75
# Batch accuracy: 93.75
# Batch accuracy: 94.73
# Batch accuracy: 94.73
# Batch accuracy: 93.75
# Batch accuracy: 93.95
# Batch accuracy: 94.53
# Batch accuracy: 94.34
# Batch accuracy: 91.99
# Batch accuracy: 94.92
# Batch accuracy: 95.12
# Batch accuracy: 92.97
# Batch accuracy: 95.12
# Batch accuracy: 93.55
# Batch accuracy: 92.58
# Batch accuracy: 93.55
# Batch accuracy: 94.53
# Batch accuracy: 93.95
# Batch accuracy: 94.14
# Batch accuracy: 93.75
# Batch accuracy: 95.12
# Batch accuracy: 94.34
# Batch accuracy: 94.73
# Batch accuracy: 92.97
# Batch accuracy: 93.16
# Batch accuracy: 91.60
# Batch accuracy: 92.38
# Batch accuracy: 92.19
# Batch accuracy: 93.16
# Batch accuracy: 93.55
# Batch accuracy: 92.38
# Batch accuracy: 93.16
# Batch accuracy: 94.53
# Batch accuracy: 94.53
# Batch accuracy: 92.58
# Batch accuracy: 91.60
# Batch accuracy: 94.14
# Batch accuracy: 92.38
# Batch accuracy: 93.75
# Batch accuracy: 92.97
# Batch accuracy: 94.73
# Batch accuracy: 93.75
# Batch accuracy: 94.73
# Batch accuracy: 96.29
# Batch accuracy: 92.77
# Batch accuracy: 94.14
# Batch accuracy: 93.16
# Batch accuracy: 92.58
# Batch accuracy: 92.58
# Batch accuracy: 91.80
# Batch accuracy: 94.73
# Batch accuracy: 94.73
# Batch accuracy: 95.31
# Batch accuracy: 92.58
# Batch accuracy: 94.53
# Batch accuracy: 94.14
# Batch accuracy: 92.97
# Batch accuracy: 94.53
# Batch accuracy: 92.97
# Batch accuracy: 93.95
# Batch accuracy: 94.34
# Batch accuracy: 93.95
# Batch accuracy: 94.53
# Batch accuracy: 93.75
# Batch accuracy: 92.97
# Batch accuracy: 94.73
# Batch accuracy: 94.34
# Batch accuracy: 94.73
# Batch accuracy: 94.34
# Batch accuracy: 93.36
# Batch accuracy: 93.75
# Batch accuracy: 94.34
# Batch accuracy: 95.51
# Batch accuracy: 95.16
#   Accuracy: 93.74
# New best model, saving it!
#
# ======== Epoch 8 / 30 ========
# Training...
#   Batch    40  of    975.    .
#   step loss: 0.03
#   Batch    80  of    975.    .
#   step loss: 0.03
#   Batch   120  of    975.    .
#   step loss: 0.06
#   Batch   160  of    975.    .
#   step loss: 0.04
#   Batch   200  of    975.    .
#   step loss: 0.03
#   Batch   240  of    975.    .
#   step loss: 0.04
#   Batch   280  of    975.    .
#   step loss: 0.04
#   Batch   320  of    975.    .
#   step loss: 0.03
#   Batch   360  of    975.    .
#   step loss: 0.02
#   Batch   400  of    975.    .
#   step loss: 0.02
#   Batch   440  of    975.    .
#   step loss: 0.06
#   Batch   480  of    975.    .
#   step loss: 0.02
#   Batch   520  of    975.    .
#   step loss: 0.05
#   Batch   560  of    975.    .
#   step loss: 0.06
#   Batch   600  of    975.    .
#   step loss: 0.02
#   Batch   640  of    975.    .
#   step loss: 0.04
#   Batch   680  of    975.    .
#   step loss: 0.05
#   Batch   720  of    975.    .
#   step loss: 0.05
#   Batch   760  of    975.    .
#   step loss: 0.04
#   Batch   800  of    975.    .
#   step loss: 0.02
#   Batch   840  of    975.    .
#   step loss: 0.03
#   Batch   880  of    975.    .
#   step loss: 0.03
#   Batch   920  of    975.    .
#   step loss: 0.03
#   Batch   960  of    975.    .
#   step loss: 0.03
#
#   Average training loss: 0.03
#
# Running Validation...
# Batch accuracy: 93.75
# Batch accuracy: 93.16
# Batch accuracy: 93.36
# Batch accuracy: 91.99
# Batch accuracy: 92.58
# Batch accuracy: 91.99
# Batch accuracy: 93.95
# Batch accuracy: 93.16
# Batch accuracy: 93.95
# Batch accuracy: 94.53
# Batch accuracy: 94.73
# Batch accuracy: 94.14
# Batch accuracy: 91.60
# Batch accuracy: 94.34
# Batch accuracy: 92.19
# Batch accuracy: 95.12
# Batch accuracy: 94.53
# Batch accuracy: 94.73
# Batch accuracy: 93.95
# Batch accuracy: 92.77
# Batch accuracy: 92.58
# Batch accuracy: 92.19
# Batch accuracy: 93.95
# Batch accuracy: 92.19
# Batch accuracy: 94.53
# Batch accuracy: 92.77
# Batch accuracy: 91.99
# Batch accuracy: 94.34
# Batch accuracy: 93.16
# Batch accuracy: 93.16
# Batch accuracy: 94.34
# Batch accuracy: 92.58
# Batch accuracy: 94.92
# Batch accuracy: 92.97
# Batch accuracy: 93.36
# Batch accuracy: 94.73
# Batch accuracy: 94.34
# Batch accuracy: 91.41
# Batch accuracy: 93.75
# Batch accuracy: 93.75
# Batch accuracy: 92.38
# Batch accuracy: 92.97
# Batch accuracy: 93.55
# Batch accuracy: 91.80
# Batch accuracy: 95.12
# Batch accuracy: 93.95
# Batch accuracy: 93.95
# Batch accuracy: 92.38
# Batch accuracy: 94.34
# Batch accuracy: 93.55
# Batch accuracy: 92.58
# Batch accuracy: 95.51
# Batch accuracy: 93.75
# Batch accuracy: 94.73
# Batch accuracy: 92.97
# Batch accuracy: 93.16
# Batch accuracy: 94.53
# Batch accuracy: 93.16
# Batch accuracy: 92.58
# Batch accuracy: 94.14
# Batch accuracy: 94.34
# Batch accuracy: 92.97
# Batch accuracy: 93.55
# Batch accuracy: 93.55
# Batch accuracy: 95.70
# Batch accuracy: 96.48
# Batch accuracy: 95.12
# Batch accuracy: 91.99
# Batch accuracy: 95.31
# Batch accuracy: 95.51
# Batch accuracy: 93.95
# Batch accuracy: 95.51
# Batch accuracy: 93.55
# Batch accuracy: 93.55
# Batch accuracy: 93.36
# Batch accuracy: 92.77
# Batch accuracy: 94.34
# Batch accuracy: 93.55
# Batch accuracy: 95.70
# Batch accuracy: 93.75
# Batch accuracy: 95.31
# Batch accuracy: 94.34
# Batch accuracy: 96.09
# Batch accuracy: 93.95
# Batch accuracy: 94.73
# Batch accuracy: 95.12
# Batch accuracy: 93.16
# Batch accuracy: 92.97
# Batch accuracy: 94.34
# Batch accuracy: 92.38
# Batch accuracy: 94.34
# Batch accuracy: 93.55
# Batch accuracy: 94.14
# Batch accuracy: 94.34
# Batch accuracy: 94.14
# Batch accuracy: 92.97
# Batch accuracy: 93.95
# Batch accuracy: 93.75
# Batch accuracy: 92.58
# Batch accuracy: 95.70
# Batch accuracy: 93.95
# Batch accuracy: 93.95
# Batch accuracy: 93.55
# Batch accuracy: 94.34
# Batch accuracy: 92.97
# Batch accuracy: 94.34
# Batch accuracy: 94.73
# Batch accuracy: 94.53
# Batch accuracy: 95.16
#   Accuracy: 93.78
# New best model, saving it!
#
# ======== Epoch 9 / 30 ========
# Training...
#   Batch    40  of    975.    .
#   step loss: 0.03
#   Batch    80  of    975.    .
#   step loss: 0.02
#   Batch   120  of    975.    .
#   step loss: 0.02
#   Batch   160  of    975.    .
#   step loss: 0.02
#   Batch   200  of    975.    .
#   step loss: 0.01
#   Batch   240  of    975.    .
#   step loss: 0.02
#   Batch   280  of    975.    .
#   step loss: 0.02
#   Batch   320  of    975.    .
#   step loss: 0.02
#   Batch   360  of    975.    .
#   step loss: 0.02
#   Batch   400  of    975.    .
#   step loss: 0.03
#   Batch   440  of    975.    .
#   step loss: 0.05
#   Batch   480  of    975.    .
#   step loss: 0.01
#   Batch   520  of    975.    .
#   step loss: 0.05
#   Batch   560  of    975.    .
#   step loss: 0.02
#   Batch   600  of    975.    .
#   step loss: 0.03
#   Batch   640  of    975.    .
#   step loss: 0.01
#   Batch   680  of    975.    .
#   step loss: 0.02
#   Batch   720  of    975.    .
#   step loss: 0.03
#   Batch   760  of    975.    .
#   step loss: 0.02
#   Batch   800  of    975.    .
#   step loss: 0.02
#   Batch   840  of    975.    .
#   step loss: 0.02
#   Batch   880  of    975.    .
#   step loss: 0.04
#   Batch   920  of    975.    .
#   step loss: 0.02
#   Batch   960  of    975.    .
#   step loss: 0.04
#
#   Average training loss: 0.03
#
# Running Validation...
# Batch accuracy: 95.70
# Batch accuracy: 93.95
# Batch accuracy: 93.16
# Batch accuracy: 93.55
# Batch accuracy: 92.97
# Batch accuracy: 92.38
# Batch accuracy: 94.73
# Batch accuracy: 94.53
# Batch accuracy: 95.31
# Batch accuracy: 93.95
# Batch accuracy: 91.41
# Batch accuracy: 93.36
# Batch accuracy: 94.34
# Batch accuracy: 92.38
# Batch accuracy: 93.75
# Batch accuracy: 92.77
# Batch accuracy: 93.95
# Batch accuracy: 94.14
# Batch accuracy: 92.58
# Batch accuracy: 92.97
# Batch accuracy: 93.55
# Batch accuracy: 93.55
# Batch accuracy: 95.70
# Batch accuracy: 95.51
# Batch accuracy: 93.55
# Batch accuracy: 94.34
# Batch accuracy: 94.34
# Batch accuracy: 91.60
# Batch accuracy: 94.34
# Batch accuracy: 93.75
# Batch accuracy: 96.29
# Batch accuracy: 92.19
# Batch accuracy: 93.75
# Batch accuracy: 93.75
# Batch accuracy: 94.53
# Batch accuracy: 94.73
# Batch accuracy: 94.53
# Batch accuracy: 92.38
# Batch accuracy: 94.53
# Batch accuracy: 93.75
# Batch accuracy: 94.14
# Batch accuracy: 94.73
# Batch accuracy: 94.14
# Batch accuracy: 93.95
# Batch accuracy: 92.77
# Batch accuracy: 92.38
# Batch accuracy: 93.75
# Batch accuracy: 94.14
# Batch accuracy: 93.95
# Batch accuracy: 93.55
# Batch accuracy: 93.16
# Batch accuracy: 93.75
# Batch accuracy: 94.92
# Batch accuracy: 91.99
# Batch accuracy: 94.73
# Batch accuracy: 91.60
# Batch accuracy: 92.38
# Batch accuracy: 93.36
# Batch accuracy: 95.12
# Batch accuracy: 93.16
# Batch accuracy: 94.92
# Batch accuracy: 93.36
# Batch accuracy: 94.73
# Batch accuracy: 95.12
# Batch accuracy: 93.95
# Batch accuracy: 94.14
# Batch accuracy: 94.53
# Batch accuracy: 93.55
# Batch accuracy: 92.38
# Batch accuracy: 93.55
# Batch accuracy: 92.77
# Batch accuracy: 92.58
# Batch accuracy: 96.09
# Batch accuracy: 95.31
# Batch accuracy: 92.97
# Batch accuracy: 94.14
# Batch accuracy: 94.14
# Batch accuracy: 93.36
# Batch accuracy: 92.77
# Batch accuracy: 93.75
# Batch accuracy: 93.95
# Batch accuracy: 93.16
# Batch accuracy: 94.53
# Batch accuracy: 92.77
# Batch accuracy: 94.73
# Batch accuracy: 93.95
# Batch accuracy: 93.95
# Batch accuracy: 93.75
# Batch accuracy: 93.55
# Batch accuracy: 92.58
# Batch accuracy: 94.53
# Batch accuracy: 95.90
# Batch accuracy: 93.55
# Batch accuracy: 93.95
# Batch accuracy: 94.73
# Batch accuracy: 93.16
# Batch accuracy: 93.95
# Batch accuracy: 93.95
# Batch accuracy: 93.16
# Batch accuracy: 92.97
# Batch accuracy: 94.14
# Batch accuracy: 93.75
# Batch accuracy: 94.92
# Batch accuracy: 92.97
# Batch accuracy: 94.73
# Batch accuracy: 93.95
# Batch accuracy: 93.55
# Batch accuracy: 93.36
# Batch accuracy: 95.16
#   Accuracy: 93.81
# New best model, saving it!
#
# ======== Epoch 10 / 30 ========
# Training...
#   Batch    40  of    975.    .
#   step loss: 0.01
#   Batch    80  of    975.    .
#   step loss: 0.02
#   Batch   120  of    975.    .
#   step loss: 0.01
#   Batch   160  of    975.    .
#   step loss: 0.01
#   Batch   200  of    975.    .
#   step loss: 0.02
#   Batch   240  of    975.    .
#   step loss: 0.03
#   Batch   280  of    975.    .
#   step loss: 0.03
#   Batch   320  of    975.    .
#   step loss: 0.04
#   Batch   360  of    975.    .
#   step loss: 0.01
#   Batch   400  of    975.    .
#   step loss: 0.03
#   Batch   440  of    975.    .
#   step loss: 0.03
#   Batch   480  of    975.    .
#   step loss: 0.01
#   Batch   520  of    975.    .
#   step loss: 0.01
#   Batch   560  of    975.    .
#   step loss: 0.01
#   Batch   600  of    975.    .
#   step loss: 0.03
#   Batch   640  of    975.    .
#   step loss: 0.04
#   Batch   680  of    975.    .
#   step loss: 0.01
#   Batch   720  of    975.    .
#   step loss: 0.04
#   Batch   760  of    975.    .
#   step loss: 0.03
#   Batch   800  of    975.    .
#   step loss: 0.02
#   Batch   840  of    975.    .
#   step loss: 0.02
#   Batch   880  of    975.    .
#   step loss: 0.02
#   Batch   920  of    975.    .
#   step loss: 0.02
#   Batch   960  of    975.    .
#   step loss: 0.03
#
#   Average training loss: 0.02
#
# Running Validation...
# Batch accuracy: 93.75
# Batch accuracy: 93.95
# Batch accuracy: 93.55
# Batch accuracy: 92.97
# Batch accuracy: 94.73
# Batch accuracy: 93.55
# Batch accuracy: 94.53
# Batch accuracy: 95.70
# Batch accuracy: 91.21
# Batch accuracy: 92.97
# Batch accuracy: 93.55
# Batch accuracy: 92.77
# Batch accuracy: 93.75
# Batch accuracy: 92.19
# Batch accuracy: 93.75
# Batch accuracy: 95.70
# Batch accuracy: 94.92
# Batch accuracy: 94.14
# Batch accuracy: 92.77
# Batch accuracy: 93.75
# Batch accuracy: 91.60
# Batch accuracy: 94.34
# Batch accuracy: 94.53
# Batch accuracy: 92.19
# Batch accuracy: 92.58
# Batch accuracy: 94.34
# Batch accuracy: 92.58
# Batch accuracy: 95.70
# Batch accuracy: 94.73
# Batch accuracy: 93.75
# Batch accuracy: 94.34
# Batch accuracy: 93.36
# Batch accuracy: 93.95
# Batch accuracy: 93.16
# Batch accuracy: 94.34
# Batch accuracy: 93.16
# Batch accuracy: 94.14
# Batch accuracy: 94.73
# Batch accuracy: 94.53
# Batch accuracy: 94.73
# Batch accuracy: 92.58
# Batch accuracy: 95.12
# Batch accuracy: 94.73
# Batch accuracy: 93.75
# Batch accuracy: 93.16
# Batch accuracy: 92.97
# Batch accuracy: 94.92
# Batch accuracy: 95.51
# Batch accuracy: 95.90
# Batch accuracy: 92.19
# Batch accuracy: 90.23
# Batch accuracy: 93.95
# Batch accuracy: 92.77
# Batch accuracy: 94.34
# Batch accuracy: 94.73
# Batch accuracy: 93.16
# Batch accuracy: 94.73
# Batch accuracy: 92.97
# Batch accuracy: 93.16
# Batch accuracy: 94.14
# Batch accuracy: 93.36
# Batch accuracy: 93.36
# Batch accuracy: 92.38
# Batch accuracy: 95.31
# Batch accuracy: 94.34
# Batch accuracy: 94.14
# Batch accuracy: 94.34
# Batch accuracy: 94.53
# Batch accuracy: 93.16
# Batch accuracy: 93.55
# Batch accuracy: 94.14
# Batch accuracy: 92.77
# Batch accuracy: 95.31
# Batch accuracy: 94.73
# Batch accuracy: 94.14
# Batch accuracy: 94.14
# Batch accuracy: 94.73
# Batch accuracy: 92.19
# Batch accuracy: 94.14
# Batch accuracy: 95.12
# Batch accuracy: 92.77
# Batch accuracy: 93.36
# Batch accuracy: 93.95
# Batch accuracy: 93.75
# Batch accuracy: 92.19
# Batch accuracy: 93.75
# Batch accuracy: 94.53
# Batch accuracy: 95.70
# Batch accuracy: 92.97
# Batch accuracy: 93.95
# Batch accuracy: 94.92
# Batch accuracy: 92.38
# Batch accuracy: 93.16
# Batch accuracy: 94.53
# Batch accuracy: 93.75
# Batch accuracy: 92.38
# Batch accuracy: 94.34
# Batch accuracy: 94.73
# Batch accuracy: 92.77
# Batch accuracy: 93.36
# Batch accuracy: 93.75
# Batch accuracy: 94.34
# Batch accuracy: 94.73
# Batch accuracy: 94.14
# Batch accuracy: 94.53
# Batch accuracy: 94.34
# Batch accuracy: 94.73
# Batch accuracy: 93.55
# Batch accuracy: 96.77
#   Accuracy: 93.85
# New best model, saving it!
# Epoch    10: reducing learning rate of group 0 to 1.0000e-05.
#
# ======== Epoch 11 / 30 ========
# Training...
#   Batch    40  of    975.    .
#   step loss: 0.02
#   Batch    80  of    975.    .
#   step loss: 0.02
#   Batch   120  of    975.    .
#   step loss: 0.04
#   Batch   160  of    975.    .
#   step loss: 0.03
#   Batch   200  of    975.    .
#   step loss: 0.02
#   Batch   240  of    975.    .
#   step loss: 0.02
#   Batch   280  of    975.    .
#   step loss: 0.01
#   Batch   320  of    975.    .
#   step loss: 0.02
#   Batch   360  of    975.    .
#   step loss: 0.04
#   Batch   400  of    975.    .
#   step loss: 0.03
#   Batch   440  of    975.    .
#   step loss: 0.02
#   Batch   480  of    975.    .
#   step loss: 0.01
#   Batch   520  of    975.    .
#   step loss: 0.02
#   Batch   560  of    975.    .
#   step loss: 0.02
#   Batch   600  of    975.    .
#   step loss: 0.01
#   Batch   640  of    975.    .
#   step loss: 0.01
#   Batch   680  of    975.    .
#   step loss: 0.01
#   Batch   720  of    975.    .
#   step loss: 0.01
#   Batch   760  of    975.    .
#   step loss: 0.05
#   Batch   800  of    975.    .
#   step loss: 0.02
#   Batch   840  of    975.    .
#   step loss: 0.02
#   Batch   880  of    975.    .
#   step loss: 0.02
#   Batch   920  of    975.    .
#   step loss: 0.01
#   Batch   960  of    975.    .
#   step loss: 0.03
#
#   Average training loss: 0.02
#
# Running Validation...
# Batch accuracy: 93.55
# Batch accuracy: 95.12
# Batch accuracy: 94.73
# Batch accuracy: 94.14
# Batch accuracy: 92.77
# Batch accuracy: 94.53
# Batch accuracy: 94.53
# Batch accuracy: 93.55
# Batch accuracy: 93.95
# Batch accuracy: 92.58
# Batch accuracy: 94.34
# Batch accuracy: 93.95
# Batch accuracy: 92.58
# Batch accuracy: 93.16
# Batch accuracy: 95.90
# Batch accuracy: 94.53
# Batch accuracy: 94.53
# Batch accuracy: 94.73
# Batch accuracy: 93.95
# Batch accuracy: 94.73
# Batch accuracy: 91.80
# Batch accuracy: 94.92
# Batch accuracy: 92.58
# Batch accuracy: 93.16
# Batch accuracy: 92.58
# Batch accuracy: 91.99
# Batch accuracy: 94.73
# Batch accuracy: 93.95
# Batch accuracy: 93.36
# Batch accuracy: 93.95
# Batch accuracy: 94.73
# Batch accuracy: 93.95
# Batch accuracy: 94.53
# Batch accuracy: 91.21
# Batch accuracy: 93.55
# Batch accuracy: 94.14
# Batch accuracy: 94.53
# Batch accuracy: 93.55
# Batch accuracy: 94.92
# Batch accuracy: 93.55
# Batch accuracy: 94.34
# Batch accuracy: 94.34
# Batch accuracy: 93.36
# Batch accuracy: 94.92
# Batch accuracy: 94.73
# Batch accuracy: 91.60
# Batch accuracy: 93.16
# Batch accuracy: 94.14
# Batch accuracy: 93.36
# Batch accuracy: 95.31
# Batch accuracy: 92.97
# Batch accuracy: 93.95
# Batch accuracy: 93.95
# Batch accuracy: 92.97
# Batch accuracy: 92.77
# Batch accuracy: 92.77
# Batch accuracy: 94.92
# Batch accuracy: 94.92
# Batch accuracy: 94.14
# Batch accuracy: 94.53
# Batch accuracy: 95.31
# Batch accuracy: 94.92
# Batch accuracy: 91.60
# Batch accuracy: 94.73
# Batch accuracy: 95.31
# Batch accuracy: 91.21
# Batch accuracy: 92.19
# Batch accuracy: 94.53
# Batch accuracy: 95.70
# Batch accuracy: 92.58
# Batch accuracy: 93.95
# Batch accuracy: 92.77
# Batch accuracy: 94.53
# Batch accuracy: 93.36
# Batch accuracy: 94.34
# Batch accuracy: 91.60
# Batch accuracy: 94.53
# Batch accuracy: 96.09
# Batch accuracy: 93.95
# Batch accuracy: 92.38
# Batch accuracy: 93.16
# Batch accuracy: 93.75
# Batch accuracy: 93.16
# Batch accuracy: 94.34
# Batch accuracy: 92.58
# Batch accuracy: 93.75
# Batch accuracy: 94.53
# Batch accuracy: 92.58
# Batch accuracy: 96.68
# Batch accuracy: 93.55
# Batch accuracy: 94.92
# Batch accuracy: 92.97
# Batch accuracy: 93.95
# Batch accuracy: 93.36
# Batch accuracy: 95.51
# Batch accuracy: 92.58
# Batch accuracy: 92.58
# Batch accuracy: 93.36
# Batch accuracy: 93.95
# Batch accuracy: 93.75
# Batch accuracy: 95.31
# Batch accuracy: 93.36
# Batch accuracy: 93.36
# Batch accuracy: 94.34
# Batch accuracy: 95.12
# Batch accuracy: 93.36
# Batch accuracy: 92.97
# Batch accuracy: 93.75
# Batch accuracy: 90.32
#   Accuracy: 93.79
# The model does not improve for 1 epochs!
#
# ======== Epoch 12 / 30 ========
# Training...
#   Batch    40  of    975.    .
#   step loss: 0.01
#   Batch    80  of    975.    .
#   step loss: 0.03
#   Batch   120  of    975.    .
#   step loss: 0.03
#   Batch   160  of    975.    .
#   step loss: 0.03
#   Batch   200  of    975.    .
#   step loss: 0.02
#   Batch   240  of    975.    .
#   step loss: 0.02
#   Batch   280  of    975.    .
#   step loss: 0.04
#   Batch   320  of    975.    .
#   step loss: 0.01
#   Batch   360  of    975.    .
#   step loss: 0.04
#   Batch   400  of    975.    .
#   step loss: 0.03
#   Batch   440  of    975.    .
#   step loss: 0.01
#   Batch   480  of    975.    .
#   step loss: 0.03
#   Batch   520  of    975.    .
#   step loss: 0.02
#   Batch   560  of    975.    .
#   step loss: 0.00
#   Batch   600  of    975.    .
#   step loss: 0.02
#   Batch   640  of    975.    .
#   step loss: 0.03
#   Batch   680  of    975.    .
#   step loss: 0.02
#   Batch   720  of    975.    .
#   step loss: 0.01
#   Batch   760  of    975.    .
#   step loss: 0.01
#   Batch   800  of    975.    .
#   step loss: 0.02
#   Batch   840  of    975.    .
#   step loss: 0.01
#   Batch   880  of    975.    .
#   step loss: 0.02
#   Batch   920  of    975.    .
#   step loss: 0.02
#   Batch   960  of    975.    .
#   step loss: 0.02
#
#   Average training loss: 0.02
#
# Running Validation...
# Batch accuracy: 93.95
# Batch accuracy: 93.55
# Batch accuracy: 95.31
# Batch accuracy: 93.55
# Batch accuracy: 95.90
# Batch accuracy: 92.38
# Batch accuracy: 92.97
# Batch accuracy: 94.53
# Batch accuracy: 94.34
# Batch accuracy: 95.31
# Batch accuracy: 92.77
# Batch accuracy: 92.97
# Batch accuracy: 92.38
# Batch accuracy: 93.16
# Batch accuracy: 93.55
# Batch accuracy: 93.95
# Batch accuracy: 92.38
# Batch accuracy: 92.38
# Batch accuracy: 93.75
# Batch accuracy: 93.16
# Batch accuracy: 92.97
# Batch accuracy: 92.19
# Batch accuracy: 92.97
# Batch accuracy: 92.58
# Batch accuracy: 92.38
# Batch accuracy: 92.77
# Batch accuracy: 92.77
# Batch accuracy: 92.97
# Batch accuracy: 94.14
# Batch accuracy: 93.95
# Batch accuracy: 92.58
# Batch accuracy: 93.16
# Batch accuracy: 94.14
# Batch accuracy: 93.75
# Batch accuracy: 93.55
# Batch accuracy: 93.55
# Batch accuracy: 94.34
# Batch accuracy: 92.58
# Batch accuracy: 95.12
# Batch accuracy: 92.97
# Batch accuracy: 94.14
# Batch accuracy: 93.55
# Batch accuracy: 96.29
# Batch accuracy: 92.38
# Batch accuracy: 94.14
# Batch accuracy: 93.75
# Batch accuracy: 94.34
# Batch accuracy: 91.80
# Batch accuracy: 93.55
# Batch accuracy: 93.75
# Batch accuracy: 95.90
# Batch accuracy: 93.16
# Batch accuracy: 94.92
# Batch accuracy: 94.92
# Batch accuracy: 94.14
# Batch accuracy: 94.14
# Batch accuracy: 91.99
# Batch accuracy: 95.31
# Batch accuracy: 94.73
# Batch accuracy: 92.97
# Batch accuracy: 94.14
# Batch accuracy: 92.77
# Batch accuracy: 94.34
# Batch accuracy: 93.95
# Batch accuracy: 93.75
# Batch accuracy: 95.51
# Batch accuracy: 94.14
# Batch accuracy: 92.97
# Batch accuracy: 92.38
# Batch accuracy: 93.36
# Batch accuracy: 95.31
# Batch accuracy: 95.31
# Batch accuracy: 92.97
# Batch accuracy: 94.92
# Batch accuracy: 94.34
# Batch accuracy: 94.14
# Batch accuracy: 94.92
# Batch accuracy: 93.95
# Batch accuracy: 92.38
# Batch accuracy: 94.92
# Batch accuracy: 95.31
# Batch accuracy: 94.14
# Batch accuracy: 94.73
# Batch accuracy: 94.53
# Batch accuracy: 94.34
# Batch accuracy: 94.73
# Batch accuracy: 93.75
# Batch accuracy: 92.77
# Batch accuracy: 92.19
# Batch accuracy: 94.34
# Batch accuracy: 94.14
# Batch accuracy: 92.97
# Batch accuracy: 92.97
# Batch accuracy: 93.75
# Batch accuracy: 95.31
# Batch accuracy: 94.14
# Batch accuracy: 93.55
# Batch accuracy: 92.58
# Batch accuracy: 92.97
# Batch accuracy: 93.36
# Batch accuracy: 95.12
# Batch accuracy: 94.53
# Batch accuracy: 93.36
# Batch accuracy: 94.53
# Batch accuracy: 94.53
# Batch accuracy: 93.75
# Batch accuracy: 95.70
# Batch accuracy: 92.77
# Batch accuracy: 93.55
#   Accuracy: 93.78
# The model does not improve for 2 epochs!
#
# ======== Epoch 13 / 30 ========
# Training...
#   Batch    40  of    975.    .
#   step loss: 0.01
#   Batch    80  of    975.    .
#   step loss: 0.02
#   Batch   120  of    975.    .
#   step loss: 0.05
#   Batch   160  of    975.    .
#   step loss: 0.02
#   Batch   200  of    975.    .
#   step loss: 0.01
#   Batch   240  of    975.    .
#   step loss: 0.03
#   Batch   280  of    975.    .
#   step loss: 0.02
#   Batch   320  of    975.    .
#   step loss: 0.02
#   Batch   360  of    975.    .
#   step loss: 0.01
#   Batch   400  of    975.    .
#   step loss: 0.02
#   Batch   440  of    975.    .
#   step loss: 0.03
#   Batch   480  of    975.    .
#   step loss: 0.01
#   Batch   520  of    975.    .
#   step loss: 0.01
#   Batch   560  of    975.    .
#   step loss: 0.01
#   Batch   600  of    975.    .
#   step loss: 0.02
#   Batch   640  of    975.    .
#   step loss: 0.01
#   Batch   680  of    975.    .
#   step loss: 0.02
#   Batch   720  of    975.    .
#   step loss: 0.01
#   Batch   760  of    975.    .
#   step loss: 0.02
#   Batch   800  of    975.    .
#   step loss: 0.01
#   Batch   840  of    975.    .
#   step loss: 0.02
#   Batch   880  of    975.    .
#   step loss: 0.01
#   Batch   920  of    975.    .
#   step loss: 0.01
#   Batch   960  of    975.    .
#   step loss: 0.01
#
#   Average training loss: 0.02
#
# Running Validation...
# Batch accuracy: 92.19
# Batch accuracy: 93.95
# Batch accuracy: 93.36
# Batch accuracy: 94.34
# Batch accuracy: 94.34
# Batch accuracy: 93.75
# Batch accuracy: 92.58
# Batch accuracy: 93.95
# Batch accuracy: 93.95
# Batch accuracy: 94.53
# Batch accuracy: 93.36
# Batch accuracy: 94.53
# Batch accuracy: 92.38
# Batch accuracy: 94.92
# Batch accuracy: 94.73
# Batch accuracy: 94.34
# Batch accuracy: 94.73
# Batch accuracy: 94.53
# Batch accuracy: 95.70
# Batch accuracy: 92.58
# Batch accuracy: 92.58
# Batch accuracy: 93.75
# Batch accuracy: 93.36
# Batch accuracy: 93.36
# Batch accuracy: 92.97
# Batch accuracy: 93.75
# Batch accuracy: 93.55
# Batch accuracy: 93.36
# Batch accuracy: 91.21
# Batch accuracy: 92.97
# Batch accuracy: 94.92
# Batch accuracy: 94.73
# Batch accuracy: 93.16
# Batch accuracy: 93.16
# Batch accuracy: 93.75
# Batch accuracy: 92.19
# Batch accuracy: 92.97
# Batch accuracy: 94.14
# Batch accuracy: 94.34
# Batch accuracy: 94.53
# Batch accuracy: 94.73
# Batch accuracy: 92.77
# Batch accuracy: 91.99
# Batch accuracy: 94.53
# Batch accuracy: 93.36
# Batch accuracy: 91.99
# Batch accuracy: 93.55
# Batch accuracy: 94.53
# Batch accuracy: 93.36
# Batch accuracy: 92.77
# Batch accuracy: 94.92
# Batch accuracy: 94.53
# Batch accuracy: 94.14
# Batch accuracy: 93.95
# Batch accuracy: 96.29
# Batch accuracy: 94.34
# Batch accuracy: 95.12
# Batch accuracy: 94.14
# Batch accuracy: 95.51
# Batch accuracy: 93.75
# Batch accuracy: 91.60
# Batch accuracy: 94.34
# Batch accuracy: 92.19
# Batch accuracy: 92.97
# Batch accuracy: 93.95
# Batch accuracy: 94.34
# Batch accuracy: 93.36
# Batch accuracy: 93.36
# Batch accuracy: 94.53
# Batch accuracy: 95.70
# Batch accuracy: 94.53
# Batch accuracy: 93.36
# Batch accuracy: 93.75
# Batch accuracy: 93.95
# Batch accuracy: 93.75
# Batch accuracy: 92.77
# Batch accuracy: 94.53
# Batch accuracy: 94.53
# Batch accuracy: 93.75
# Batch accuracy: 93.75
# Batch accuracy: 94.14
# Batch accuracy: 94.14
# Batch accuracy: 91.99
# Batch accuracy: 94.34
# Batch accuracy: 93.75
# Batch accuracy: 93.75
# Batch accuracy: 95.12
# Batch accuracy: 93.75
# Batch accuracy: 93.55
# Batch accuracy: 93.75
# Batch accuracy: 93.36
# Batch accuracy: 92.97
# Batch accuracy: 95.12
# Batch accuracy: 94.34
# Batch accuracy: 94.14
# Batch accuracy: 94.14
# Batch accuracy: 94.53
# Batch accuracy: 92.97
# Batch accuracy: 93.36
# Batch accuracy: 92.97
# Batch accuracy: 92.38
# Batch accuracy: 93.95
# Batch accuracy: 93.36
# Batch accuracy: 93.55
# Batch accuracy: 93.75
# Batch accuracy: 94.73
# Batch accuracy: 93.95
# Batch accuracy: 94.34
# Batch accuracy: 93.55
#   Accuracy: 93.78
# The model does not improve for 3 epochs!
#
# ======== Epoch 14 / 30 ========
# Training...
#   Batch    40  of    975.    .
#   step loss: 0.03
#   Batch    80  of    975.    .
#   step loss: 0.02
#   Batch   120  of    975.    .
#   step loss: 0.01
#   Batch   160  of    975.    .
#   step loss: 0.02
#   Batch   200  of    975.    .
#   step loss: 0.01
#   Batch   240  of    975.    .
#   step loss: 0.03
#   Batch   280  of    975.    .
#   step loss: 0.01
#   Batch   320  of    975.    .
#   step loss: 0.02
#   Batch   360  of    975.    .
#   step loss: 0.02
#   Batch   400  of    975.    .
#   step loss: 0.01
#   Batch   440  of    975.    .
#   step loss: 0.01
#   Batch   480  of    975.    .
#   step loss: 0.03
#   Batch   520  of    975.    .
#   step loss: 0.02
#   Batch   560  of    975.    .
#   step loss: 0.01
#   Batch   600  of    975.    .
#   step loss: 0.01
#   Batch   640  of    975.    .
#   step loss: 0.03
#   Batch   680  of    975.    .
#   step loss: 0.02
#   Batch   720  of    975.    .
#   step loss: 0.02
#   Batch   760  of    975.    .
#   step loss: 0.01
#   Batch   800  of    975.    .
#   step loss: 0.02
#   Batch   840  of    975.    .
#   step loss: 0.02
#   Batch   880  of    975.    .
#   step loss: 0.01
#   Batch   920  of    975.    .
#   step loss: 0.01
#   Batch   960  of    975.    .
#   step loss: 0.01
#
#   Average training loss: 0.02
#
# Running Validation...
# Batch accuracy: 93.16
# Batch accuracy: 93.95
# Batch accuracy: 94.34
# Batch accuracy: 94.34
# Batch accuracy: 94.73
# Batch accuracy: 93.36
# Batch accuracy: 92.77
# Batch accuracy: 95.90
# Batch accuracy: 94.92
# Batch accuracy: 93.55
# Batch accuracy: 93.55
# Batch accuracy: 92.19
# Batch accuracy: 93.55
# Batch accuracy: 93.75
# Batch accuracy: 93.36
# Batch accuracy: 94.14
# Batch accuracy: 95.70
# Batch accuracy: 92.38
# Batch accuracy: 93.95
# Batch accuracy: 93.16
# Batch accuracy: 93.16
# Batch accuracy: 93.36
# Batch accuracy: 94.73
# Batch accuracy: 93.36
# Batch accuracy: 91.41
# Batch accuracy: 95.12
# Batch accuracy: 94.14
# Batch accuracy: 93.95
# Batch accuracy: 92.77
# Batch accuracy: 94.53
# Batch accuracy: 91.60
# Batch accuracy: 94.73
# Batch accuracy: 93.55
# Batch accuracy: 92.38
# Batch accuracy: 95.70
# Batch accuracy: 93.95
# Batch accuracy: 96.48
# Batch accuracy: 92.58
# Batch accuracy: 92.97
# Batch accuracy: 92.97
# Batch accuracy: 95.90
# Batch accuracy: 92.77
# Batch accuracy: 92.77
# Batch accuracy: 91.21
# Batch accuracy: 94.14
# Batch accuracy: 93.95
# Batch accuracy: 93.16
# Batch accuracy: 95.12
# Batch accuracy: 92.97
# Batch accuracy: 92.38
# Batch accuracy: 94.92
# Batch accuracy: 93.55
# Batch accuracy: 92.38
# Batch accuracy: 93.95
# Batch accuracy: 93.95
# Batch accuracy: 93.55
# Batch accuracy: 94.14
# Batch accuracy: 93.95
# Batch accuracy: 93.95
# Batch accuracy: 92.38
# Batch accuracy: 93.75
# Batch accuracy: 93.75
# Batch accuracy: 95.31
# Batch accuracy: 93.95
# Batch accuracy: 92.77
# Batch accuracy: 93.36
# Batch accuracy: 92.58
# Batch accuracy: 93.55
# Batch accuracy: 93.36
# Batch accuracy: 92.77
# Batch accuracy: 94.34
# Batch accuracy: 94.34
# Batch accuracy: 94.73
# Batch accuracy: 95.31
# Batch accuracy: 94.73
# Batch accuracy: 94.92
# Batch accuracy: 96.29
# Batch accuracy: 93.95
# Batch accuracy: 94.92
# Batch accuracy: 92.77
# Batch accuracy: 94.34
# Batch accuracy: 92.97
# Batch accuracy: 93.95
# Batch accuracy: 95.70
# Batch accuracy: 95.51
# Batch accuracy: 92.19
# Batch accuracy: 94.53
# Batch accuracy: 92.97
# Batch accuracy: 92.97
# Batch accuracy: 94.14
# Batch accuracy: 93.95
# Batch accuracy: 95.12
# Batch accuracy: 93.55
# Batch accuracy: 93.95
# Batch accuracy: 93.75
# Batch accuracy: 94.34
# Batch accuracy: 93.95
# Batch accuracy: 94.34
# Batch accuracy: 92.77
# Batch accuracy: 94.53
# Batch accuracy: 93.95
# Batch accuracy: 94.73
# Batch accuracy: 94.34
# Batch accuracy: 91.60
# Batch accuracy: 93.95
# Batch accuracy: 92.97
# Batch accuracy: 94.14
# Batch accuracy: 92.77
# Batch accuracy: 94.35
#   Accuracy: 93.81
# The model does not improve for 4 epochs!
# Epoch    14: reducing learning rate of group 0 to 1.0000e-06.
#
# ======== Epoch 15 / 30 ========
# Training...
#   Batch    40  of    975.    .
#   step loss: 0.01
#   Batch    80  of    975.    .
#   step loss: 0.01
#   Batch   120  of    975.    .
#   step loss: 0.02
#   Batch   160  of    975.    .
#   step loss: 0.02
#   Batch   200  of    975.    .
#   step loss: 0.02
#   Batch   240  of    975.    .
#   step loss: 0.01
#   Batch   280  of    975.    .
#   step loss: 0.01
#   Batch   320  of    975.    .
#   step loss: 0.01
#   Batch   360  of    975.    .
#   step loss: 0.04
#   Batch   400  of    975.    .
#   step loss: 0.01
#   Batch   440  of    975.    .
#   step loss: 0.02
#   Batch   480  of    975.    .
#   step loss: 0.02
#   Batch   520  of    975.    .
#   step loss: 0.04
#   Batch   560  of    975.    .
#   step loss: 0.02
#   Batch   600  of    975.    .
#   step loss: 0.02
#   Batch   640  of    975.    .
#   step loss: 0.01
#   Batch   680  of    975.    .
#   step loss: 0.05
#   Batch   720  of    975.    .
#   step loss: 0.03
#   Batch   760  of    975.    .
#   step loss: 0.02
#   Batch   800  of    975.    .
#   step loss: 0.02
#   Batch   840  of    975.    .
#   step loss: 0.02
#   Batch   880  of    975.    .
#   step loss: 0.01
#   Batch   920  of    975.    .
#   step loss: 0.01
#   Batch   960  of    975.    .
#   step loss: 0.02
#
#   Average training loss: 0.02
#
# Running Validation...
# Batch accuracy: 94.14
# Batch accuracy: 93.55
# Batch accuracy: 92.58
# Batch accuracy: 94.53
# Batch accuracy: 93.36
# Batch accuracy: 92.77
# Batch accuracy: 94.14
# Batch accuracy: 90.43
# Batch accuracy: 93.36
# Batch accuracy: 94.34
# Batch accuracy: 95.31
# Batch accuracy: 93.16
# Batch accuracy: 94.53
# Batch accuracy: 92.97
# Batch accuracy: 94.14
# Batch accuracy: 94.92
# Batch accuracy: 93.36
# Batch accuracy: 92.77
# Batch accuracy: 93.75
# Batch accuracy: 91.60
# Batch accuracy: 94.34
# Batch accuracy: 93.36
# Batch accuracy: 93.75
# Batch accuracy: 93.95
# Batch accuracy: 94.14
# Batch accuracy: 95.51
# Batch accuracy: 92.77
# Batch accuracy: 94.14
# Batch accuracy: 93.95
# Batch accuracy: 94.14
# Batch accuracy: 92.77
# Batch accuracy: 93.75
# Batch accuracy: 94.73
# Batch accuracy: 92.97
# Batch accuracy: 93.16
# Batch accuracy: 94.92
# Batch accuracy: 93.36
# Batch accuracy: 94.14
# Batch accuracy: 93.55
# Batch accuracy: 93.75
# Batch accuracy: 94.14
# Batch accuracy: 94.53
# Batch accuracy: 93.95
# Batch accuracy: 94.14
# Batch accuracy: 94.34
# Batch accuracy: 93.36
# Batch accuracy: 93.55
# Batch accuracy: 94.14
# Batch accuracy: 96.09
# Batch accuracy: 93.16
# Batch accuracy: 94.53
# Batch accuracy: 92.19
# Batch accuracy: 95.12
# Batch accuracy: 93.75
# Batch accuracy: 92.58
# Batch accuracy: 95.12
# Batch accuracy: 93.95
# Batch accuracy: 94.34
# Batch accuracy: 94.73
# Batch accuracy: 93.95
# Batch accuracy: 92.58
# Batch accuracy: 94.34
# Batch accuracy: 92.77
# Batch accuracy: 93.75
# Batch accuracy: 92.58
# Batch accuracy: 93.75
# Batch accuracy: 94.73
# Batch accuracy: 93.95
# Batch accuracy: 91.99
# Batch accuracy: 95.12
# Batch accuracy: 92.77
# Batch accuracy: 92.77
# Batch accuracy: 95.31
# Batch accuracy: 93.55
# Batch accuracy: 93.55
# Batch accuracy: 91.21
# Batch accuracy: 93.16
# Batch accuracy: 94.73
# Batch accuracy: 91.60
# Batch accuracy: 94.53
# Batch accuracy: 95.12
# Batch accuracy: 94.14
# Batch accuracy: 93.75
# Batch accuracy: 93.55
# Batch accuracy: 94.53
# Batch accuracy: 92.97
# Batch accuracy: 93.16
# Batch accuracy: 95.12
# Batch accuracy: 92.97
# Batch accuracy: 94.73
# Batch accuracy: 94.14
# Batch accuracy: 94.73
# Batch accuracy: 91.99
# Batch accuracy: 93.16
# Batch accuracy: 94.53
# Batch accuracy: 94.92
# Batch accuracy: 94.14
# Batch accuracy: 94.14
# Batch accuracy: 93.95
# Batch accuracy: 94.14
# Batch accuracy: 93.95
# Batch accuracy: 93.55
# Batch accuracy: 92.77
# Batch accuracy: 94.14
# Batch accuracy: 94.53
# Batch accuracy: 94.14
# Batch accuracy: 94.53
# Batch accuracy: 94.92
# Batch accuracy: 96.77
#   Accuracy: 93.82
# The model does not improve for 5 epochs!
#
# ======== Epoch 16 / 30 ========
# Training...
#   Batch    40  of    975.    .
#   step loss: 0.01
#   Batch    80  of    975.    .
#   step loss: 0.01
#   Batch   120  of    975.    .
#   step loss: 0.01
#   Batch   160  of    975.    .
#   step loss: 0.02
#   Batch   200  of    975.    .
#   step loss: 0.01
#   Batch   240  of    975.    .
#   step loss: 0.03
#   Batch   280  of    975.    .
#   step loss: 0.05
#   Batch   320  of    975.    .
#   step loss: 0.02
#   Batch   360  of    975.    .
#   step loss: 0.03
#   Batch   400  of    975.    .
#   step loss: 0.02
#   Batch   440  of    975.    .
#   step loss: 0.02
#   Batch   480  of    975.    .
#   step loss: 0.02
#   Batch   520  of    975.    .
#   step loss: 0.02
#   Batch   560  of    975.    .
#   step loss: 0.02
#   Batch   600  of    975.    .
#   step loss: 0.03
#   Batch   640  of    975.    .
#   step loss: 0.02
#   Batch   680  of    975.    .
#   step loss: 0.02
#   Batch   720  of    975.    .
#   step loss: 0.02
#   Batch   760  of    975.    .
#   step loss: 0.02
#   Batch   800  of    975.    .
#   step loss: 0.01
#   Batch   840  of    975.    .
#   step loss: 0.01
#   Batch   880  of    975.    .
#   step loss: 0.01
#   Batch   920  of    975.    .
#   step loss: 0.02
#   Batch   960  of    975.    .
#   step loss: 0.02
#
#   Average training loss: 0.02
#
# Running Validation...
# Batch accuracy: 93.55
# Batch accuracy: 93.75
# Batch accuracy: 93.36
# Batch accuracy: 94.53
# Batch accuracy: 93.16
# Batch accuracy: 94.34
# Batch accuracy: 96.09
# Batch accuracy: 94.34
# Batch accuracy: 93.95
# Batch accuracy: 93.36
# Batch accuracy: 93.55
# Batch accuracy: 94.34
# Batch accuracy: 93.16
# Batch accuracy: 92.38
# Batch accuracy: 94.53
# Batch accuracy: 94.34
# Batch accuracy: 93.75
# Batch accuracy: 92.38
# Batch accuracy: 93.36
# Batch accuracy: 93.36
# Batch accuracy: 94.53
# Batch accuracy: 93.55
# Batch accuracy: 94.34
# Batch accuracy: 92.38
# Batch accuracy: 93.55
# Batch accuracy: 94.34
# Batch accuracy: 94.53
# Batch accuracy: 95.12
# Batch accuracy: 95.31
# Batch accuracy: 93.16
# Batch accuracy: 91.99
# Batch accuracy: 93.16
# Batch accuracy: 94.34
# Batch accuracy: 92.58
# Batch accuracy: 93.16
# Batch accuracy: 91.99
# Batch accuracy: 95.31
# Batch accuracy: 94.53
# Batch accuracy: 94.53
# Batch accuracy: 94.53
# Batch accuracy: 94.53
# Batch accuracy: 93.75
# Batch accuracy: 93.36
# Batch accuracy: 93.36
# Batch accuracy: 92.77
# Batch accuracy: 92.19
# Batch accuracy: 93.16
# Batch accuracy: 94.14
# Batch accuracy: 93.55
# Batch accuracy: 94.73
# Batch accuracy: 93.75
# Batch accuracy: 92.77
# Batch accuracy: 94.34
# Batch accuracy: 93.16
# Batch accuracy: 95.31
# Batch accuracy: 93.55
# Batch accuracy: 94.14
# Batch accuracy: 94.53
# Batch accuracy: 94.14
# Batch accuracy: 94.73
# Batch accuracy: 93.55
# Batch accuracy: 92.38
# Batch accuracy: 94.34
# Batch accuracy: 96.09
# Batch accuracy: 92.97
# Batch accuracy: 94.34
# Batch accuracy: 94.73
# Batch accuracy: 94.73
# Batch accuracy: 91.41
# Batch accuracy: 93.36
# Batch accuracy: 92.77
# Batch accuracy: 93.55
# Batch accuracy: 95.12
# Batch accuracy: 93.55
# Batch accuracy: 93.36
# Batch accuracy: 93.75
# Batch accuracy: 93.55
# Batch accuracy: 93.36
# Batch accuracy: 94.14
# Batch accuracy: 93.55
# Batch accuracy: 92.38
# Batch accuracy: 92.38
# Batch accuracy: 92.19
# Batch accuracy: 94.92
# Batch accuracy: 94.14
# Batch accuracy: 93.16
# Batch accuracy: 92.19
# Batch accuracy: 92.58
# Batch accuracy: 92.77
# Batch accuracy: 94.53
# Batch accuracy: 92.58
# Batch accuracy: 95.51
# Batch accuracy: 93.55
# Batch accuracy: 94.53
# Batch accuracy: 94.73
# Batch accuracy: 95.51
# Batch accuracy: 94.53
# Batch accuracy: 94.14
# Batch accuracy: 95.90
# Batch accuracy: 93.16
# Batch accuracy: 93.16
# Batch accuracy: 93.95
# Batch accuracy: 93.55
# Batch accuracy: 94.34
# Batch accuracy: 93.55
# Batch accuracy: 93.75
# Batch accuracy: 95.70
# Batch accuracy: 92.77
# Batch accuracy: 97.58
#   Accuracy: 93.82
# The model does not improve for 6 epochs!
# ====>Stopping training, the model did not improve for 6
# ====>Best epoch: 10.
#
# Training complete!

# %%
def predict(
    model_path: Path,
    dataset: str,
    batch_size: int,
    labels_dict,
    device: torch.device
):

    print(f"====Loading dataset for testing")
    test_corpus = NLPDataset(dataset, "test", sentence_max_len, labels_dict = labels_dict, vocab= voc)

    test_dataloader = DataLoader(
        test_corpus,
        batch_size=batch_size,
        #sampler = RandomSampler(test_corpus),
        pin_memory=True,
        num_workers=0,
        drop_last=False
    )

    print(f"====Loading model for testing")
    model = torch.load(join(model_path, "best-model.pth"))
    model.to(device)
    model.eval()
    pred_labels = []
    test_labels = []
    logits_list = []

    def _list_from_tensor(tensor):
        if tensor.numel() == 1:
            return [tensor.item()]
        return list(tensor.cpu().detach().numpy())

    print("====Testing model...")
    for batch in test_dataloader:
        b_input_ids = batch[0]
        b_input_ids = torch.tensor(b_input_ids).to(device).long()
        b_labels = batch[1].to(device)
        with torch.no_grad():
            loss, logits = model(b_input_ids, b_labels)
            preds = np.argmax(logits.cpu(), axis=1) # Convert one-hot to index
            b_labels = b_labels.int()
            pred_labels.extend(_list_from_tensor(preds))
            test_labels.extend(_list_from_tensor(b_labels))
        logits_list.extend(_list_from_tensor(logits))

    print(classification_report(test_labels, pred_labels, labels=list(labels_dict.values()), target_names=np.array(list(labels_dict.keys())), digits=3, output_dict=False))
    logits_list = expit(logits_list)
    del model
    torch.cuda.empty_cache()

# %%
del train_dataloader
del validation_dataloader
del train_corpus
del val_corpus
del model
torch.cuda.empty_cache()

# %%
predict(last_saved_model, dataset, batch_size, labels_dict, device)
# Out:
# ====Loading dataset for testing
# ====Loading model for testing
# ====Testing model...
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:37: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#                                              precision    recall  f1-score   support
#
#                               FISHING_LINES      0.910     0.918     0.914       584
#                      MOBILE_DEVICE_CHARGERS      0.969     0.969     0.969       804
#                                  SUNGLASSES      0.964     0.970     0.967       875
#                                    FREEZERS      0.880     0.921     0.900       444
#                                  CAR_WHEELS      0.985     0.997     0.991       720
#                            BATHROOM_FAUCETS      0.904     0.889     0.896       521
#                              ACTION_FIGURES      0.721     0.725     0.723       800
#                                       IRONS      0.977     0.982     0.979       433
#                                  MATTRESSES      0.981     0.983     0.982       534
#                       SWIMMING_POOL_HEATERS      0.950     0.905     0.927        21
#                              KITCHEN_KNIVES      0.932     0.955     0.944       202
#                                 TELEVISIONS      0.937     0.953     0.945       728
#                    SPORT_AND_BAZAAR_BOTTLES      0.949     0.900     0.924       229
#                                    STARTERS      0.983     0.980     0.982       354
#                                  FACE_MASKS      0.802     0.880     0.839       166
#                             KITCHEN_FAUCETS      0.900     0.900     0.900       431
#     TACTICAL_AND_SPORTING_KNIVES_AND_BLADES      0.963     0.945     0.954       164
#                                   NOTEBOOKS      0.924     0.947     0.935       543
#                                 DEEP_FRYERS      0.986     0.954     0.970       455
#                                TORSION_BARS      1.000     1.000     1.000       123
#                            AUDIO_AMPLIFIERS      0.846     0.830     0.838       311
#                              CEILING_LIGHTS      0.956     0.966     0.961       472
#                                       BELTS      0.939     0.939     0.939        49
#                    AUTOMOTIVE_WEATHERSTRIPS      0.953     0.972     0.962       788
#                                  HEADBOARDS      1.000     0.982     0.991       228
#                                       YARNS      0.903     0.923     0.913       142
#                                SMARTWATCHES      0.949     0.953     0.951       724
#                             FOOTBALL_SHIRTS      0.962     0.970     0.966       921
#                      AUTOMOTIVE_CLUTCH_KITS      0.979     0.987     0.983       719
#                                WRISTWATCHES      0.958     0.965     0.961       876
#                                  WALLPAPERS      0.963     0.941     0.952       885
#         AUTOMOTIVE_SIDE_VIEW_MIRROR_GLASSES      0.983     0.983     0.983       536
#                            AUDIO_INTERFACES      0.948     0.913     0.930       300
#                            KITCHEN_PLAYSETS      0.941     0.950     0.945       100
#                                 LIGHT_BULBS      0.946     0.958     0.952       829
#                              CELL_BATTERIES      0.979     0.960     0.969       670
#                        SURVEILLANCE_CAMERAS      0.930     0.900     0.914       909
#                                   THERMOSES      0.782     0.930     0.849       100
#                  HUMIDIFIERS_AND_VAPORIZERS      0.941     0.919     0.930       173
#                              KITCHEN_APRONS      0.739     0.630     0.680        27
#                         PORTABLE_GENERATORS      0.992     0.992     0.992       132
#                                  CELLPHONES      0.926     0.948     0.937       329
#                            HANDICRAFT_BOXES      0.792     0.750     0.771       112
#                         EMBROIDERY_MACHINES      0.896     0.843     0.869        51
#                                     CAMERAS      0.831     0.750     0.789        92
#             DESKTOP_COMPUTER_POWER_SUPPLIES      0.977     0.985     0.981       679
#                              BABIES_FORMULA      0.978     0.989     0.983        88
#                     MOTORCYCLE_SPEEDOMETERS      1.000     0.500     0.667         4
#                                     CARPETS      0.964     0.968     0.966       857
#                       CARDS_AND_INVITATIONS      0.905     0.809     0.854        47
#                            ELECTRIC_GUITARS      0.974     0.978     0.976       778
#                           COMPUTER_MONITORS      0.965     0.970     0.967       701
#                          MULTIGAME_MACHINES      0.831     0.831     0.831        77
#                                 TABLECLOTHS      0.967     0.965     0.966       544
#                                   VIBRATORS      0.851     0.880     0.866       117
#                                      PLANTS      0.959     0.965     0.962       313
#                                AM_FM_RADIOS      0.897     0.935     0.916       383
#                      ENGINE_CONTROL_MODULES      0.995     0.995     0.995       415
#             LATEX_ENAMEL_AND_ACRYLIC_PAINTS      1.000     1.000     1.000        67
#             MUSICAL_KEYBOARD_CASES_AND_BAGS      0.989     0.983     0.986       760
#                                 VIDEO_GAMES      0.980     0.988     0.984       908
#                          ARTIFICIAL_FLOWERS      0.916     0.962     0.938       497
#                          OUTER_TIE_ROD_ENDS      0.990     0.982     0.986       496
#                           EXHAUST_MANIFOLDS      0.889     1.000     0.941         8
#                     DIGITAL_VOICE_RECORDERS      0.915     0.935     0.925       774
#                               REFRIGERATORS      0.959     0.941     0.950       524
#                             DISPOSABLE_CUPS      0.856     0.851     0.853       188
#                                  EYESHADOWS      0.976     0.977     0.976       738
#                                      RANGES      0.960     0.969     0.965       450
#          AUTOMOTIVE_POWER_WINDOW_REGULATORS      0.962     0.920     0.941       138
#                                     HOOKAHS      0.982     0.964     0.973       168
#                       AUTOMOTIVE_AMPLIFIERS      0.948     0.946     0.947       662
#                           PROJECTOR_SCREENS      0.962     0.962     0.962        53
#                          AUTOMOTIVE_EMBLEMS      0.937     0.931     0.934       524
#                           PAINTBALL_MARKERS      0.989     0.918     0.952        97
#               AUTOMOTIVE_SPRING_SUSPENSIONS      0.937     0.983     0.960       121
#                                 ENGINE_OILS      0.981     0.981     0.981       770
#                            BATTERY_CHARGERS      0.735     0.833     0.781        30
#                     SWEATSHIRTS_AND_HOODIES      0.933     0.949     0.941       118
#                      CONTINUOUS_INK_SYSTEMS      0.993     0.979     0.986       140
#                              BATHROOM_SINKS      0.943     0.967     0.955       427
#                                MEMORY_CARDS      0.979     0.976     0.978       669
#                                    HANDBAGS      0.957     0.952     0.955       850
#                               KITCHEN_SINKS      0.908     0.901     0.905       253
#                            CAMERA_BATTERIES      0.958     0.957     0.958       554
#                             WATER_RADIATORS      0.957     0.957     0.957       399
#                           CYCLING_COMPUTERS      0.944     0.950     0.947       161
#                                EROTIC_BOOKS      1.000     0.985     0.992        67
#                            MOTORCYCLE_CASES      0.986     0.982     0.984       222
#                                    COSTUMES      0.943     0.964     0.953       276
#                           BODYWEIGHT_SCALES      0.922     0.922     0.922       293
#                      GAMEPADS_AND_JOYSTICKS      0.969     0.974     0.971       612
#                                       PANTS      0.929     0.954     0.941       799
#                                      STOOLS      0.973     0.975     0.974       594
#                               FISHING_REELS      0.988     0.977     0.982       740
#                                     WALLETS      0.977     0.967     0.972       665
#                           MUSICAL_KEYBOARDS      0.971     0.977     0.974       511
#                                  ULTRABOOKS      0.924     0.888     0.905       232
#                             ENGINE_BEARINGS      0.970     0.982     0.976       327
#                    CAR_POWER_STEERING_PUMPS      0.987     0.992     0.989       370
#                                     TABLETS      0.960     0.966     0.963       624
#                              MAKEUP_BRUSHES      0.983     0.970     0.976       534
#                               HORSE_SADDLES      0.990     1.000     0.995       102
#                          CD_AND_DVD_PLAYERS      0.892     0.907     0.899       291
#                    VIDEO_GAME_PREPAID_CARDS      0.891     0.838     0.864        68
#                             SCREEN_PRINTERS      0.931     0.949     0.940       156
#                                  ROOF_RACKS      0.993     0.986     0.989       428
#                                  HEADPHONES      0.983     0.942     0.962       189
#                       ELECTRIC_SCREWDRIVERS      0.838     0.803     0.820       122
#                             VACUUM_CLEANERS      0.933     0.875     0.903        16
#                                 FLASHLIGHTS      0.979     0.980     0.979       606
#                                HOME_SHELVES      0.849     0.860     0.854       157
#                               BRUSH_CUTTERS      0.972     0.936     0.954       110
#                         COMPUTER_PROCESSORS      0.977     0.982     0.980       794
#                                    NECKTIES      0.985     0.985     0.985       134
#                          MOTORCYCLE_JACKETS      0.968     0.942     0.955       551
#                                    WRENCHES      0.966     0.992     0.979       371
#                                 WHEELCHAIRS      0.978     1.000     0.989        90
#                          RAM_MEMORY_MODULES      0.995     0.988     0.991       822
#                                PENCIL_CASES      0.934     0.923     0.929       183
#                AUTOMOTIVE_SHIFT_LEVER_KNOBS      1.000     1.000     1.000       938
#                                        MUGS      0.924     0.930     0.927       329
#                              WALKIE_TALKIES      0.944     0.961     0.953       283
#                                       DOLLS      0.920     0.932     0.926       843
#                                  TREADMILLS      0.954     0.954     0.954        65
#                                 SPARK_PLUGS      0.962     0.952     0.957       726
#                               HAIR_CLIPPERS      0.861     0.892     0.876       714
#                                   SUITCASES      0.961     0.971     0.966       582
#                                 BLANK_DISCS      0.922     0.927     0.924       178
#                                    SPEAKERS      0.951     0.958     0.954       525
#                               DVD_RECORDERS      0.960     0.960     0.960       450
#                     KEYBOARD_AND_MOUSE_KITS      0.970     0.949     0.960       275
#                             CAR_SEAT_COVERS      0.990     0.996     0.993       942
#          AUTOMOTIVE_SUSPENSION_CONTROL_ARMS      0.969     0.972     0.971       254
#                           BAR_CODE_SCANNERS      1.000     0.972     0.986       254
#                         AUTOMOTIVE_MOLDINGS      0.956     0.975     0.966       720
#                               BABY_SWIMWEAR      0.849     0.884     0.866       121
#                        TABLE_AND_DESK_LAMPS      0.927     0.927     0.927       260
#                           JACKETS_AND_COATS      0.921     0.946     0.933       815
#                                  CHAMPAGNES      0.964     0.871     0.915        31
#                              FOOTBALL_SHOES      0.995     0.997     0.996       734
#                           CHARMS_AND_MEDALS      0.952     0.930     0.941        86
#                                 MICROPHONES      0.966     0.991     0.979       465
#                         PERMANENT_EPILATORS      0.899     0.851     0.874        94
#                              WOMEN_SWIMWEAR      0.958     0.954     0.956       500
#                  PARTY_DECORATIVE_BACKDROPS      0.963     0.990     0.977       105
#                               ROLLER_SKATES      0.983     0.990     0.986       586
#                                      COMICS      0.788     0.815     0.801       534
#                                       BOOKS      0.708     0.843     0.770       834
#                              CUPCAKE_STANDS      0.667     0.750     0.706         8
#                               UPS_BATTERIES      0.852     0.719     0.780        64
#                                 CAKE_STANDS      0.867     0.867     0.867        45
#            REAR_WHEEL_HUBS_BEARING_ASSEMBLY      0.988     0.993     0.990       401
#                            DIECAST_VEHICLES      0.935     0.942     0.938       606
#                                 CALCULATORS      0.985     0.985     0.985       536
#                                 TV_ANTENNAS      0.984     0.987     0.986       310
#                                 PAPER_CLIPS      0.980     0.961     0.970        51
#                              MALE_UNDERWEAR      0.965     0.979     0.972       422
#                                  ALL_IN_ONE      0.962     0.942     0.952       189
#                            DRINKING_GLASSES      0.850     0.887     0.868       382
#                                       DRUMS      0.939     0.943     0.941       212
#                               WELDING_MASKS      0.966     0.905     0.934        63
#                                    WHISKEYS      0.956     0.981     0.969       267
#                               VIDEO_CAMERAS      0.897     0.946     0.921        37
#                               COFFEE_MAKERS      0.977     0.975     0.976       567
#                        KNEE_BRACES_SUPPORTS      0.946     0.946     0.946       129
#                                 WALL_CLOCKS      0.970     0.958     0.964       480
#                                 WALL_LIGHTS      0.982     0.971     0.977       172
#                              GARDEN_BENCHES      0.625     0.714     0.667        14
#                                  SCULPTURES      0.911     0.934     0.922       437
#                                        FANS      0.980     0.972     0.976       597
#                                 FOUNDATIONS      0.945     0.958     0.951       706
#                                   EYELINERS      0.889     0.800     0.842        50
#                                  DRILL_BITS      0.979     0.972     0.975       143
#                                PC_KEYBOARDS      0.857     0.692     0.766        26
#                               EROTIC_CREAMS      0.908     0.925     0.917       279
#                           DESKTOP_COMPUTERS      0.842     0.889     0.865        36
#                           DECORATIVE_VINYLS      0.928     0.949     0.939       709
#                                 BOARD_GAMES      0.921     0.928     0.925       654
#                         KITCHEN_RANGE_HOODS      0.987     0.984     0.985       309
#                                     DRAWERS      0.975     0.975     0.975       198
#                             FURNITURE_KNOBS      0.954     0.993     0.973       147
#        HOME_APPLIANCE_CONTACTORS_AND_RELAYS      0.973     0.975     0.974       408
#                            SHAVING_MACHINES      0.836     0.797     0.816       449
#                                TOOTHBRUSHES      0.970     0.970     0.970       265
#                     STREAMING_MEDIA_DEVICES      0.924     0.964     0.943       415
#                      CAR_AC_HOSE_ASSEMBLIES      1.000     0.647     0.786        17
#                              SWAY_BAR_LINKS      0.951     0.865     0.906        89
#                               PREAMPLIFIERS      0.444     0.348     0.390        23
#                                  FISH_TANKS      0.978     0.931     0.954       145
#                                      DRONES      0.985     0.982     0.983       653
#                            EMERGENCY_LIGHTS      0.930     0.917     0.923       288
#                                    BLENDERS      0.925     0.949     0.937       452
#                              LASER_MEASURES      0.869     0.964     0.914        55
#                                CASH_DRAWERS      0.971     0.895     0.932        38
#                             CAMERA_CHARGERS      0.927     0.930     0.928       285
#                            CAR_AV_RECEIVERS      0.921     0.951     0.936       589
#                            STEERING_COLUMNS      0.986     0.993     0.990       143
#                                      SKIRTS      0.968     0.974     0.971       154
#                             SANDER_MACHINES      0.982     0.955     0.969       292
#                                RICE_COOKERS      0.943     0.962     0.952        52
#                              BRAKE_BOOSTERS      0.986     0.986     0.986       139
#                                    NETBOOKS      0.899     0.924     0.912       145
#                               FISHING_LURES      0.829     0.866     0.847        67
#                            AUTOMOTIVE_TIRES      0.867     0.812     0.839        80
#                                     STATUES      0.417     0.435     0.426        23
#                                    T_SHIRTS      0.945     0.970     0.957       742
#                             OFFICE_SOFTWARE      0.698     0.732     0.714        82
#                              BABY_CAR_SEATS      0.973     0.984     0.978       550
#                                 WATCH_BANDS      0.914     0.921     0.917       265
#                                        PENS      0.719     0.852     0.780        27
#                   BATHROOM_ACCESSORIES_SETS      0.747     0.756     0.752        78
#                                 CAR_STEREOS      0.863     0.831     0.847       243
#  CELLPHONE_TABLET_AND_GPS_SCREEN_PROTECTORS      0.894     0.923     0.908       155
#                              GLASSES_FRAMES      0.952     0.946     0.949       296
#                                AIRSOFT_GUNS      0.971     0.951     0.961       245
#                                   HAND_FANS      0.857     0.938     0.896        32
#                                  SIDEBOARDS      0.961     0.980     0.970       201
#                            VEHICLE_STICKERS      0.979     0.962     0.971       530
#                              BABY_STROLLERS      0.964     0.981     0.972       468
#                                      MOVIES      0.895     0.718     0.797        71
#                          MICRO_ROTARY_TOOLS      0.931     0.971     0.950        69
#                                   SOUVENIRS      0.921     0.921     0.921       151
#                                      VODKAS      0.900     0.957     0.928        94
#                               PUREBRED_DOGS      0.990     0.987     0.989       705
#                                     VIOLINS      0.968     0.993     0.980       151
#                                 HOVERBOARDS      0.971     0.988     0.979       480
#                      SUSPENSION_BALL_JOINTS      0.979     0.972     0.976       579
#                                   BACKPACKS      0.965     0.981     0.973       699
#                              ADHESIVE_TAPES      0.946     0.964     0.955       253
#                           ELECTRICAL_CABLES      0.984     0.992     0.988       250
#                               COFFEE_TABLES      0.905     0.731     0.809        26
#                  INTERACTIVE_GAMING_FIGURES      0.968     0.996     0.982       246
#                   AUTOMOTIVE_AC_COMPRESSORS      0.933     0.977     0.955        43
#                       HAIRDRESSING_SCISSORS      0.981     0.981     0.981       160
#                                    CUSHIONS      0.943     0.925     0.934       213
#                   THERMAL_CUPS_AND_TUMBLERS      0.961     0.875     0.916        56
#         TV_REPLACEMENT_BACKLIGHT_LED_STRIPS      0.973     0.948     0.960       115
#                         ENGINE_INTAKE_HOSES      0.925     0.954     0.939       373
#                    AUTOMOBILE_FENDER_LINERS      0.941     0.889     0.914        18
#                              DJ_CONTROLLERS      0.874     0.914     0.894       175
#                                STUFFED_TOYS      0.877     0.891     0.884       679
#              MARTIAL_ARTS_AND_BOXING_GLOVES      0.973     0.980     0.976       254
#                               CAMERA_LENSES      0.967     0.941     0.954       219
#                                EROTIC_PUMPS      0.953     0.921     0.937        89
#                               PAINT_ROLLERS      1.000     0.909     0.952        11
#                                MEN_SWIMWEAR      0.846     0.611     0.710        18
#                 PORTABLE_CELLPHONE_CHARGERS      0.977     0.950     0.963       500
#                              ANALOG_CAMERAS      0.913     0.963     0.937       457
#                             HAIR_TREATMENTS      0.828     0.865     0.846        89
#                       DJ_EFFECTS_PROCESSORS      0.777     0.792     0.784       202
#                     BUMPER_IMPACT_ABSORBERS      0.956     0.971     0.964       245
#                  NOTEBOOKS_AND_WRITING_PADS      0.942     0.948     0.945       153
#                         FINGERPRINT_READERS      0.958     0.958     0.958        24
#                                    BLANKETS      0.856     0.908     0.881       131
#                                 SUPPLEMENTS      0.870     0.870     0.870       430
#                                    HAMMOCKS      0.976     0.976     0.976        82
#                AUTOMOTIVE_SIDE_VIEW_MIRRORS      0.955     0.982     0.969       737
#                   FACIAL_SKIN_CARE_PRODUCTS      0.812     0.839     0.825       341
#                             PACKAGING_ROLLS      1.000     1.000     1.000        26
#                       TV_AND_MONITOR_MOUNTS      0.984     0.987     0.985       546
#                                CAR_ANTENNAS      0.995     0.997     0.996       934
#                                    CACHACAS      0.980     0.955     0.968       157
#                                     TV_SMPS      0.895     0.921     0.908       279
#                              KITCHEN_TOWELS      0.968     0.982     0.975       277
#                                    CALIPERS      0.952     0.909     0.930        22
#                             PARKING_SENSORS      0.985     0.993     0.989       539
#                   ELECTRIC_PRESSURE_WASHERS      0.991     0.980     0.985       343
#              HAIR_SHAMPOOS_AND_CONDITIONERS      0.947     0.818     0.878        44
#                                STETHOSCOPES      0.969     0.861     0.912        36
#                                    PRINTERS      0.963     0.963     0.963       400
#                             ELECTRIC_DRILLS      0.946     0.966     0.956       414
#                                KITCHEN_POTS      0.961     0.965     0.963       485
#                              FUEL_INJECTORS      0.875     0.951     0.912       103
#                            VEHICLE_SPEAKERS      0.960     0.976     0.968       421
#                           HOME_OFFICE_DESKS      0.954     0.973     0.963       149
#                              GUITAR_STRINGS      0.971     0.953     0.962       106
#                             DISC_PACKAGINGS      0.865     0.865     0.865        74
#                                 LIP_GLOSSES      0.916     0.921     0.919       190
#                                     DRESSES      0.971     0.970     0.970       692
#                                BASS_GUITARS      0.960     0.972     0.966       467
#                                  TURNTABLES      0.866     0.885     0.875       270
#                           TOY_BUILDING_SETS      0.915     0.859     0.886       249
#                                  BED_SHEETS      0.877     0.947     0.910        75
#                               CAR_GEARBOXES      0.971     0.989     0.980       267
#                                FLOOD_LIGHTS      0.949     0.965     0.957       462
#                          SOLDERING_MACHINES      0.984     0.982     0.983       383
#                            ELECTRONIC_DRUMS      0.890     0.897     0.894       117
#                    DATA_CABLES_AND_ADAPTERS      0.893     0.938     0.915        80
#                      AUTOMOTIVE_WATER_PUMPS      0.882     0.895     0.888       391
#                              FOOTBALL_BALLS      0.938     0.974     0.956       156
#                                LENS_FILTERS      0.973     0.960     0.966        75
#                       INSTRUMENT_AMPLIFIERS      0.944     0.935     0.940       449
#                                MUSIC_STANDS      0.966     0.875     0.918        32
#                        CAR_DISTRIBUTOR_CAPS      0.913     0.917     0.915       205
#                                  MOUSE_PADS      0.985     0.980     0.983       201
#                                     FABRICS      0.901     0.939     0.920       379
#                               CABIN_FILTERS      0.968     1.000     0.984       244
#                             SEWING_MACHINES      0.946     0.966     0.956       292
#                                      MIXERS      0.972     0.974     0.973       350
#                         MOTORCYCLE_FAIRINGS      0.902     0.943     0.922       353
#                                   CV_JOINTS      0.964     0.968     0.966       443
#                  HAIR_STRAIGHTENING_BRUSHES      0.929     1.000     0.963        26
#                             WHEELS_BEARINGS      0.991     0.989     0.990       547
#                                AV_RECEIVERS      0.815     0.867     0.840       188
#                              NETWORK_CABLES      0.973     0.958     0.966       190
#                                       CRIBS      0.901     0.901     0.901       242
#                                HOME_HEATERS      0.938     0.910     0.924       234
#                  BRACELETS_AND_ANKLE_BRACES      0.924     0.910     0.917       346
#                                    SNEAKERS      0.917     0.917     0.917        72
#                  AUTOMOTIVE_THROTTLE_BODIES      0.959     0.940     0.949        50
#                              COOKING_SCALES      0.915     0.939     0.927       412
#                               PEDAL_EFFECTS      0.958     0.958     0.958       695
#                              ENGINE_PISTONS      0.924     0.924     0.924       132
#                               FLATWARE_SETS      0.929     0.839     0.881        31
#                                     PANTIES      0.863     0.898     0.880        49
#                          ELECTRICAL_OUTLETS      0.944     0.959     0.951       122
#                          BABY_CLOTHING_SETS      0.829     0.829     0.829        76
#                              STEAM_CLEANERS      0.923     0.632     0.750        19
#                            DECORATIVE_VASES      0.882     0.931     0.906       274
#                             FOOD_PROCESSORS      0.903     0.896     0.900       135
#                             TRAILER_HITCHES      1.000     0.984     0.992       184
#                       SOFA_AND_FUTON_COVERS      0.990     1.000     0.995        99
#                                      SHIRTS      0.914     0.898     0.906       118
#                       VEHICLE_CLUTCH_CABLES      0.833     1.000     0.909        10
#                                 GATE_MOTORS      0.990     0.983     0.987       298
#                                  FOG_LIGHTS      0.973     0.973     0.973       292
#                                   SIM_CARDS      0.957     0.917     0.936        24
#                               BABY_MONITORS      0.969     0.991     0.980       220
#                            VEHICLE_CV_AXLES      0.943     0.957     0.950        69
#                                   LIPSTICKS      0.960     0.979     0.969       562
#                      SERVING_AND_HOME_TRAYS      0.965     0.938     0.951       354
#                                    COOKTOPS      0.700     0.636     0.667        11
#                              GRAPHICS_CARDS      1.000     0.938     0.968        32
#                          FIRE_EXTINGUISHERS      0.967     0.967     0.967        30
#                  KITCHEN_CABINET_ORGANIZERS      0.000     0.000     0.000         7
#                                       SOFAS      0.891     0.900     0.896       100
#                            GRAPHICS_TABLETS      0.979     0.984     0.982       190
#                                      SHORTS      0.909     0.945     0.927       274
#                            SWIMMING_GOGGLES      0.943     0.857     0.898        77
#                            POOL_INFLATABLES      0.902     1.000     0.949        37
#                                       DOORS      0.916     0.897     0.906        97
#                               SPORT_WATCHES      0.928     0.950     0.939       478
#            PORTABLE_EVAPORATIVE_AIR_COOLERS      0.911     0.891     0.901       138
#              DOG_CARRIERS_AND_CARRYING_BAGS      0.931     0.947     0.939        57
#                     ENGINE_INTAKE_MANIFOLDS      0.962     1.000     0.981        51
#                          MOTORCYCLE_HELMETS      0.989     1.000     0.994       715
#                        COMBUSTION_CHAINSAWS      1.000     0.964     0.982        84
#               ELECTRONIC_ENTRANCE_INTERCOMS      0.986     0.967     0.976       211
#                                     CRAYONS      0.980     0.970     0.975       101
#                                THERMOMETERS      0.969     0.984     0.976        63
#                              CAMERA_TRIPODS      0.972     0.967     0.969       427
#                           ARTIFICIAL_PLANTS      0.739     0.630     0.680        27
#                            PROJECTOR_MOUNTS      0.600     0.600     0.600         5
#                 PORTABLE_ELECTRIC_MASSAGERS      0.962     0.904     0.932        83
#               NON_CORRECTIVE_CONTACT_LENSES      1.000     0.958     0.979        24
#                                     PUZZLES      0.920     0.932     0.926        74
#            WASHING_AND_DRYER_MACHINE_COVERS      1.000     0.960     0.980        50
#                        PUSH_AND_RIDING_TOYS      0.792     0.594     0.679        32
#                                SHOWER_HEADS      0.846     0.911     0.877       235
#                            ANTI_THEFT_STUDS      0.963     0.945     0.954       220
#                               HATS_AND_CAPS      0.866     0.892     0.879        65
#                                   MAGAZINES      0.679     0.664     0.671       143
#                  ENGINE_COOLING_FAN_SHROUDS      0.976     0.976     0.976        83
#                      AUTOMOTIVE_OIL_FILTERS      0.941     0.744     0.831        43
#                            MOTORCYCLE_TIRES      0.903     0.946     0.924       147
#               MOTORCYCLE_TURN_SIGNAL_LIGHTS      0.969     0.995     0.982       221
#                                     PILLOWS      0.966     0.903     0.933        31
#                                    TEQUILAS      0.943     1.000     0.971        33
#                                 TOILET_RUGS      0.898     0.920     0.909       249
#                                      FLUTES      0.967     0.922     0.944       128
#                                    UKULELES      0.945     1.000     0.972        52
#                                 TOOTHPASTES      0.950     0.919     0.934        62
#                       MOTORCYCLE_CRASH_BARS      0.895     0.810     0.850        21
#                             PIPES_AND_TUBES      0.667     0.615     0.640        13
#                                FOOD_SLICERS      0.818     0.818     0.818        22
#           DESKTOP_COMPUTER_COOLERS_AND_FANS      0.949     0.971     0.960       345
#                                   SWAY_BARS      0.958     0.939     0.948        98
#                            AQUARIUM_FILTERS      0.968     0.977     0.972       214
#               CELLPHONE_REPLACEMENT_CAMERAS      1.000     0.941     0.970        51
#                                     MIRRORS      0.874     0.884     0.879        86
#                             BLU_RAY_PLAYERS      0.977     0.954     0.965       175
#                          AUTOMOTIVE_FENDERS      0.915     0.952     0.933       124
#                             SPARKLING_WINES      0.600     0.500     0.545        12
#              ENGINE_VALVES_SPRING_RETAINERS      0.970     0.941     0.955        68
#                                BABY_WALKERS      0.923     0.923     0.923        13
#             ANTIVIRUS_AND_INTERNET_SECURITY      0.833     0.938     0.882        16
#                       COTTON_CANDY_MACHINES      1.000     1.000     1.000         7
#                             ORAL_IRRIGATORS      1.000     0.875     0.933         8
#                    MOTORCYCLE_CLUTCH_COVERS      0.910     0.929     0.919       239
#                               GAME_CONSOLES      0.945     0.888     0.915       347
#                               TABLE_RUNNERS      0.914     0.955     0.934        67
#                           PLAYGROUND_SLIDES      1.000     0.846     0.917        13
#                                 3D_PRINTERS      0.959     1.000     0.979        47
#                                 DIAPER_BAGS      0.933     0.942     0.937       103
#                               ELECTRIC_SAWS      0.965     0.989     0.977       363
#                           KITCHEN_FURNITURE      0.878     0.947     0.911        38
#                            BABY_HIGH_CHAIRS      0.733     0.716     0.724        88
#                                    MINI_PCS      0.643     0.643     0.643        14
#                                    MASCARAS      0.944     0.924     0.934        92
#                     AUTOMOTIVE_WHEEL_COVERS      0.939     0.961     0.950       129
#                           WINDSHIELD_WIPERS      0.963     0.968     0.966       190
#                                     LIQUORS      0.979     0.940     0.959       100
#                            CLOTHING_PATCHES      0.944     0.879     0.911        58
#                       WOOD_BURNING_MACHINES      1.000     0.857     0.923         7
#                                  BINOCULARS      0.978     0.957     0.967       186
#                      COMMERCIAL_LIGHT_SIGNS      0.970     1.000     0.985        32
#                            WATER_DISPENSERS      0.952     0.960     0.956       225
#                       GLOW_PLUG_CONTROLLERS      0.945     0.929     0.937        56
#                                  TELEPHONES      0.895     0.810     0.850        21
#                             AIR_COMPRESSORS      0.949     0.955     0.952       353
#                           OPERATING_SYSTEMS      0.924     0.896     0.910       270
#                        CAR_ENGINE_CAMSHAFTS      0.833     1.000     0.909        15
#                             CLOTHES_HANGERS      1.000     0.957     0.978        92
#                                    WETSUITS      1.000     0.895     0.944        19
#                                TOILET_SEATS      1.000     0.984     0.992       191
#                            AUTOMOTIVE_DOORS      0.976     0.973     0.974       332
#             SUSPENSION_CONTROL_ARM_BUSHINGS      0.837     0.819     0.828       138
#                          VEHICLE_BRAKE_PADS      0.972     0.983     0.977       350
#                 REMOTE_CONTROL_TOY_VEHICLES      0.900     0.904     0.902       209
#                        AUTOMOTIVE_NERF_BARS      1.000     1.000     1.000        38
#                              ESSENTIAL_OILS      0.833     0.846     0.840        65
#                             SLATWALL_PANELS      0.988     1.000     0.994        80
#                                  TOOL_BOXES      0.912     0.954     0.933       109
#                                BABY_DIAPERS      0.995     0.979     0.987       375
#                          ALARMS_AND_SENSORS      0.942     0.929     0.935       295
#                            MOTORCYCLE_SUITS      0.917     0.892     0.904        37
#                               KITCHEN_BOWLS      0.762     0.727     0.744        22
#                              CAT_SCRATCHERS      1.000     0.867     0.929        15
#                              INK_CARTRIDGES      0.926     0.833     0.877        30
#                    MARKERS_AND_HIGHLIGHTERS      0.917     0.881     0.899       126
#                      JUMPSUITS_AND_OVERALLS      0.904     0.887     0.895       106
#                                 NAIL_DRYERS      0.947     0.962     0.955       131
#                             CAMERA_MONOPODS      0.887     0.959     0.922        49
#                                    BICYCLES      0.978     0.962     0.970       184
#                                        SALT      0.833     1.000     0.909        10
#                    SCREEN_PRINTING_MACHINES      0.889     0.571     0.696        14
#                                        BEDS      0.952     0.930     0.941        43
#                     BODY_SKIN_CARE_PRODUCTS      0.796     0.821     0.808       380
# AUTOMOTIVE_MANUAL_TRANSMISSION_SHIFT_LEVERS      0.909     0.800     0.851        25
#                            TV_STORAGE_UNITS      0.906     0.923     0.914        52
#                       AUTOMOTIVE_HEADLIGHTS      0.926     0.962     0.944       131
#                                  PAINTBALLS      0.849     0.929     0.888        85
#                                      SCREWS      0.898     0.930     0.914        57
#                                  TOY_ROBOTS      0.917     0.733     0.815        15
#                                     POSTERS      0.966     0.956     0.961       206
#                            MOTORCYCLE_PANTS      0.944     0.864     0.903       118
#                         INTEGRATED_CIRCUITS      0.812     0.722     0.765        72
#                                GARDEN_HOSES      0.912     0.929     0.920        56
#                                 ALTERNATORS      0.917     0.917     0.917        48
#                          MAGNIFYING_GLASSES      0.966     0.918     0.941       122
#                                    PERFUMES      0.904     0.904     0.904        52
#                                       FLOUR      0.938     1.000     0.968        15
#                                FISHING_RODS      0.762     0.842     0.800        19
#                  CELLPHONE_AND_TABLET_CASES      0.913     0.923     0.918        91
#                                     PAJAMAS      0.932     0.982     0.957        56
#                                  BUTT_PLUGS      0.818     0.794     0.806        34
#                 LUMBAR_AND_ABDOMINAL_BRACES      0.979     0.966     0.973       147
#                              AIR_MATTRESSES      0.974     0.968     0.971       154
#                               WATER_HEATERS      0.979     0.943     0.961       247
#                                 DISHWASHERS      0.986     0.953     0.969       148
#                        ELECTRIC_LAWN_MOWERS      0.750     0.750     0.750         4
#                               HOME_THEATERS      0.667     0.222     0.333         9
#                            LED_STAGE_LIGHTS      0.868     0.852     0.860       216
#           CHALKBOARD_AND_WHITEBOARD_ERASERS      1.000     0.870     0.930        23
#                               BABY_BOUNCERS      0.762     0.889     0.821        18
#                                       RINGS      0.923     0.837     0.878        43
#                      AUTOMOTIVE_AIR_FILTERS      0.981     0.945     0.963        55
#                                LUGGAGE_TAGS      0.891     0.872     0.882        47
#                                HEATER_CORES      1.000     0.667     0.800        21
#                             CLEANING_CLOTHS      0.913     0.903     0.908        93
#                              AIR_FRESHENERS      0.561     0.535     0.548        43
#                                     BLOUSES      0.684     0.684     0.684        38
#                             SAFETY_FOOTWEAR      1.000     0.985     0.992        66
#                                FREEZER_BAGS      0.875     0.875     0.875         8
#                      SHOCK_MOUNT_INSOLATORS      0.818     0.863     0.840        73
#                                  BAR_CLAMPS      0.857     0.750     0.800        16
#                             CHRISTMAS_TREES      0.971     0.919     0.944        37
#                          CAR_AIR_FRESHENERS      0.861     0.879     0.870        99
#                          BASKETBALL_JERSEYS      1.000     0.733     0.846        15
#                                  ACCORDIONS      0.984     0.981     0.982       311
#                                  FOOD_CARTS      0.966     0.903     0.933        31
#                                   HEAT_GUNS      0.979     0.989     0.984        94
#                   ENGINE_CRANKSHAFT_PULLEYS      0.971     0.925     0.947       107
#                                  PARTY_HATS      0.625     0.625     0.625         8
#                             RECEPTION_DESKS      0.800     1.000     0.889         4
#                              PICTURE_FRAMES      0.928     0.934     0.931       151
#                               OSCILLOSCOPES      0.818     0.900     0.857        10
#                   HABERDASHERY_LACE_EDGINGS      0.925     0.899     0.912       109
#                                       BEERS      0.988     0.971     0.979       170
#                                HOLE_PUNCHES      0.833     0.714     0.769         7
#                               DJ_TURNTABLES      0.754     0.613     0.676        80
#                                 VR_HEADSETS      0.983     0.983     0.983       352
#                             KITCHEN_MORTARS      1.000     0.750     0.857         4
#                                       OVENS      0.965     0.971     0.968       171
#                                DISHES_RACKS      0.688     0.673     0.680        49
#                                    EARRINGS      0.913     0.955     0.933        44
#                                   WARDROBES      0.875     0.972     0.921        36
#                           RACKS_AND_PINIONS      0.973     0.965     0.969       113
#                                   BOOKCASES      0.842     0.914     0.877        35
#                                  TOY_TRAINS      0.867     0.830     0.848        94
#                      CARD_PAYMENT_TERMINALS      0.941     0.941     0.941        17
#                           SUBMERSIBLE_PUMPS      0.990     0.970     0.980       100
#             GARDENING_AND_AGRICULTURE_SEEDS      0.886     0.861     0.873        36
#                                      MODEMS      0.838     0.886     0.862       123
#                               OFFICE_CHAIRS      0.935     0.888     0.911        98
#                                   PENDRIVES      0.924     0.964     0.944       139
#                                   NECKLACES      0.865     0.912     0.888        91
#                          ENGINE_GASKET_SETS      0.500     0.353     0.414        17
#                  AUTOMOTIVE_SHOCK_ABSORBERS      0.787     0.894     0.837        66
#                                 VINYL_ROLLS      0.676     0.686     0.681        70
#               TROLLEY_AND_FURNITURE_CASTERS      1.000     0.750     0.857         4
#                   TV_RECEIVERS_AND_DECODERS      0.750     0.833     0.789        18
#                                LIFE_JACKETS      1.000     0.591     0.743        22
#                        SELF_ADHESIVE_LABELS      0.808     0.857     0.832        49
#                   IGNITION_SWITCH_ACTUATORS      1.000     1.000     1.000        14
#                            BABY_STERILIZERS      0.875     0.636     0.737        22
#                       PARKING_BRAKE_HANDLES      0.952     0.984     0.968        61
#                      CLUTCH_SLAVE_CYLINDERS      0.781     0.833     0.806        30
#                                      FISHES      0.583     0.778     0.667         9
#                             COOKIES_CUTTERS      0.933     0.909     0.921        77
#                                  NEBULIZERS      0.939     0.939     0.939        49
#                                  COMFORTERS      0.652     0.750     0.698        20
#                         ELLIPTICAL_MACHINES      0.927     0.898     0.913       128
#                               ENGINE_VALVES      0.925     0.841     0.881        44
#                                  SANDPAPERS      0.895     0.810     0.850        21
#        AUTOMOTIVE_SHOCK_ABSORBER_BUMP_STOPS      1.000     0.919     0.958        37
#                                     GAZEBOS      0.989     0.967     0.978        91
#                                  XENON_KITS      0.950     0.950     0.950        20
#                      AUTOMOTIVE_DOOR_PANELS      0.987     0.993     0.990       150
#                  INDOOR_CURTAINS_AND_BLINDS      0.968     0.938     0.953       161
#                         CAR_WINDOW_SWITCHES      0.786     0.710     0.746        31
#                                   EPILATORS      0.901     0.872     0.886        94
#                           MALE_MASTURBATORS      0.833     0.667     0.741        15
#                         DRILLS_SCREWDRIVERS      0.474     0.375     0.419        24
#                                  CONCEALERS      0.952     0.898     0.924        88
#                     SCHOOL_AND_OFFICE_GLUES      0.700     0.700     0.700        10
#                      SANDALS_AND_FLIP_FLOPS      0.957     0.978     0.967        45
#                                   BAR_SOAPS      0.810     0.850     0.829        60
#                   ELECTRIC_BATHROOM_FAUCETS      0.720     0.720     0.720        25
#                           VOLTAGE_DETECTORS      0.875     0.966     0.918        29
#                     ORTHOPEDIC_ANKLE_BRACES      0.923     0.800     0.857        15
#                              HEDGE_TRIMMERS      1.000     1.000     1.000        14
#                         STABILIZERS_AND_UPS      1.000     1.000     1.000         2
#                               BABY_PLAYARDS      0.910     0.827     0.867       110
#                            RESISTANCE_BANDS      0.955     0.950     0.953       180
#                             LAPTOP_CHARGERS      0.939     0.912     0.925        68
#                       COMPUTER_MOTHERBOARDS      0.917     0.805     0.857        41
# ...
#                            LIVING_ROOM_SETS      0.800     0.571     0.667        14
#                              BABY_PACIFIERS      1.000     1.000     1.000        15
#                              HAND_POLISHERS      0.786     0.786     0.786        14
#                                SHADE_CLOTHS      1.000     1.000     1.000        12
#                               HAMMER_DRILLS      0.625     0.625     0.625         8
#                              POWER_GRINDERS      0.833     0.769     0.800        13
#                               CAMERA_STRAPS      1.000     0.667     0.800         3
#                           LAWN_MOWER_BLADES      0.857     0.667     0.750         9
#                          PNEUMATIC_STAPLERS      1.000     1.000     1.000        13
#              THERMAL_REFRIGERATORS_AND_BAGS      0.905     0.679     0.776        28
#                                LIGHT_STANDS      1.000     0.714     0.833         7
#                                      STRAWS      0.800     0.500     0.615         8
#                                       SUITS      0.774     0.727     0.750        33
#                           BATHROOM_VANITIES      0.833     0.625     0.714         8
#                         VIBRATION_PLATFORMS      0.833     0.833     0.833        18
#                               DINING_TABLES      1.000     0.875     0.933        16
#                           TURNTABLE_NEEDLES      1.000     0.333     0.500         3
#                                HEARING_AIDS      1.000     0.900     0.947        10
#                     ORTHOPEDIC_WALKER_BOOTS      0.818     0.643     0.720        14
#                                         TEA      0.778     0.700     0.737        10
#                             TORQUE_WRENCHES      1.000     1.000     1.000         8
#                                 CATS_LITTER      1.000     0.917     0.957        12
#                                 MATE_GOURDS      0.900     0.818     0.857        11
#                                  MEAT_HOOKS      0.667     1.000     0.800         2
#                       AUTOMOTIVE_DEFLECTORS      1.000     1.000     1.000         5
#                   VARIABLE_FREQUENCY_DRIVES      1.000     0.857     0.923         7
#                                  SWEETENERS      1.000     0.875     0.933         8
#         AUTOMOTIVE_CELLPHONE_AND_GPS_MOUNTS      1.000     0.667     0.800         6
#                         RADIO_BASE_STATIONS      0.667     0.333     0.444         6
#                                    CRUTCHES      1.000     1.000     1.000         4
#                                POWER_STRIPS      0.875     0.700     0.778        10
#                               KATANA_SWORDS      0.833     0.769     0.800        13
#                        CATS_AND_DOGS_TREATS      1.000     0.643     0.783        14
#                         MEMORY_CARD_READERS      0.500     0.667     0.571         3
#                            TELEPHONE_CABLES      1.000     0.929     0.963        14
#                          SOLID_SWEET_PASTES      1.000     0.700     0.824        10
#                           DISPOSABLE_GLOVES      1.000     0.333     0.500         3
#                        MOTORCYCLE_GRAB_BARS      1.000     1.000     1.000         3
#                              PLUNGE_ROUTERS      1.000     0.750     0.857         8
#                         GROOVE_JOINT_PLIERS      0.800     1.000     0.889         4
#                          BICYCLE_HANDLEBARS      1.000     0.400     0.571         5
#                          SOLDERING_STATIONS      0.962     0.962     0.962        26
#                               TANDEM_CHAIRS      0.571     0.571     0.571         7
#                                GARAGE_DOORS      0.818     0.750     0.783        12
#                         SPARK_PLUG_WIRESETS      0.903     0.875     0.889        32
#                       ELECTRIC_SHOWER_HEADS      0.500     0.200     0.286         5
#                        PORTABLE_DVD_PLAYERS      1.000     0.667     0.800         9
#                                      DILDOS      0.250     0.125     0.167         8
#                   INDUSTRIAL_DOUGH_KNEADERS      0.917     0.846     0.880        13
#                   UNIVERSAL_REMOTE_CONTROLS      1.000     0.333     0.500         3
#                                 WHEEL_STUDS      0.333     0.167     0.222         6
#                            FABRIC_SOFTENERS      0.900     0.947     0.923        19
#              MOTORCYCLE_DISTRIBUTION_CHAINS      0.941     0.842     0.889        19
#                       DOOR_AND_WINDOW_LOCKS      1.000     0.333     0.500         3
#                                        GINS      1.000     0.500     0.667         4
#                                 HAND_TRUCKS      1.000     0.500     0.667         4
#                                    STAPLERS      1.000     0.667     0.800         6
#                                   APERITIFS      0.800     0.800     0.800         5
#                             SHOWER_CURTAINS      1.000     1.000     1.000         4
#                              ANTIQUE_CHAIRS      0.500     0.143     0.222         7
#                               YOGURT_MAKERS      0.250     0.200     0.222         5
#                                 SHIN_GUARDS      1.000     0.500     0.667         2
#                             GOLF_CLUBS_SETS      1.000     0.778     0.875         9
#                  FOOTBALL_GOALKEEPER_GLOVES      0.882     0.938     0.909        16
#                                LASER_LEVELS      0.778     0.875     0.824         8
#                        KEYBOARD_CONTROLLERS      0.286     0.400     0.333         5
#                          ALTERNATOR_PULLEYS      0.941     0.941     0.941        17
#            CAMERA_AND_CELLPHONE_STABILIZERS      0.750     1.000     0.857         3
#                                BABY_JUMPERS      0.667     0.667     0.667         6
#                 CAMERA_REPLACEMENT_DISPLAYS      1.000     1.000     1.000         7
#                                 CRANKSHAFTS      0.905     0.905     0.905        21
#                                BREAD_MAKERS      0.600     1.000     0.750         3
#                    SCHOOL_AND_OFFICE_PAPERS      0.750     0.375     0.500         8
#                    STOVETOP_POPCORN_POPPERS      0.857     0.750     0.800         8
#                      BREAST_FEEDING_PILLOWS      0.818     0.818     0.818        11
#                               POOL_CLEANERS      1.000     0.600     0.750         5
#                              LINEMAN_PLIERS      0.500     0.667     0.571         3
#                                  COAT_RACKS      0.444     0.667     0.533         6
#                                  POOL_PUMPS      0.917     0.917     0.917        12
#                     WATER_PURIFIERS_FILTERS      0.929     0.650     0.765        20
#                               SAFETY_GLOVES      0.800     0.667     0.727         6
#                          ISOPROPYL_ALCOHOLS      1.000     0.889     0.941         9
#               VEHICLE_BRAKE_HYDRAULIC_HOSES      1.000     0.889     0.941         9
#                              MEDICINE_BALLS      1.000     0.750     0.857         4
#                             KITCHEN_GRATERS      0.500     0.600     0.545         5
#                              NAPKIN_HOLDERS      0.857     0.667     0.750         9
#                               PUNCHING_BAGS      0.500     0.333     0.400         3
#                                 ESPADRILLES      0.800     0.500     0.615         8
#                         CAR_CENTER_CONSOLES      1.000     0.667     0.800         6
#                             VIDEO_CASSETTES      1.000     1.000     1.000         6
#                              POTENTIOMETERS      1.000     0.400     0.571         5
#                    READY_TO_DRINK_COCKTAILS      0.333     0.500     0.400         2
#                                 FLOOR_LAMPS      0.750     0.818     0.783        11
#                            DRONE_PROPELLERS      1.000     1.000     1.000         6
#                                       TENTS      0.846     1.000     0.917        11
#                            SAFETY_HARNESSES      1.000     0.500     0.667         4
#                                    SYRINGES      0.571     1.000     0.727         4
#                                   BEDLINERS      0.812     0.812     0.812        16
#                     ELECTROLYTIC_CAPACITORS      1.000     0.857     0.923         7
#                                BASKET_BALLS      1.000     1.000     1.000         2
#                                   OTOSCOPES      1.000     1.000     1.000         4
#                               WAFFLE_MAKERS      1.000     0.750     0.857         8
#                                 PENIS_RINGS      0.667     0.500     0.571         4
#                          ELECTRIC_AIR_PUMPS      0.778     0.875     0.824         8
#                             COFFEE_CAPSULES      0.750     0.600     0.667         5
#                         BABY_PACIFIER_CLIPS      0.556     1.000     0.714         5
#                                   KEY_RACKS      0.250     0.250     0.250         4
#                                  DEODORANTS      0.800     0.800     0.800         5
#                          INDUSTRIAL_PULLEYS      0.625     1.000     0.769         5
#                               BILL_COUNTERS      1.000     1.000     1.000         5
#                  AUDIO_AND_VIDEO_CONNECTORS      0.000     0.000     0.000         4
#                            WASHING_MACHINES      0.909     0.833     0.870        12
#                 ENGINE_COOLING_FAN_SWITCHES      0.667     0.667     0.667         6
#                        AUTOMOTIVE_BATTERIES      0.000     0.000     0.000         5
#                        CHIP_AND_DIP_SERVERS      0.000     0.000     0.000         4
#                                ARCHERY_BOWS      0.857     1.000     0.923         6
#                             VINYL_FLOORINGS      0.750     0.857     0.800         7
#                              MENSTRUAL_CUPS      1.000     1.000     1.000         5
#                               SLEEPING_BAGS      0.600     0.750     0.667         4
#                               RUBBER_STAMPS      0.667     0.800     0.727         5
#                              DRYER_MACHINES      1.000     0.750     0.857         8
#                            ENERGETIC_STONES      0.500     0.429     0.462         7
#                              BICYCLE_PEDALS      1.000     1.000     1.000         9
#                      MOTORCYCLE_CARBURETORS      1.000     1.000     1.000         5
#                           SCREWDRIVERS_SETS      1.000     0.667     0.800         3
#                                EDIBLE_SEEDS      1.000     0.333     0.500         3
#                        STORE_SHOPPING_CARTS      1.000     0.750     0.857         4
#                         SWIMMING_NOSE_CLIPS      1.000     0.500     0.667         2
#                                 AFTERSHAVES      1.000     0.333     0.500         3
#                              AIRBAG_MODULES      1.000     1.000     1.000         3
#                                   HAND_SAWS      1.000     1.000     1.000         6
#           NECK_GAITERS_MASKS_AND_BALACLAVAS      0.500     0.500     0.500         2
#                          MAGNETIC_COMPASSES      1.000     0.833     0.909         6
#                          MAKEUP_TRAIN_CASES      1.000     0.500     0.667         4
#                            POPCORN_MACHINES      1.000     1.000     1.000         9
#                                LAMP_HOLDERS      0.571     1.000     0.727         4
#                    IGNITION_CONTROL_MODULES      0.250     0.143     0.182         7
#                             CAR_FRONT_MASKS      1.000     1.000     1.000         2
#                               HAND_BLENDERS      0.000     0.000     0.000         3
#                              KIDS_TRICYCLES      1.000     1.000     1.000         4
#                              AIRGUN_PELLETS      0.333     0.250     0.286         4
#                            AUTOMOTIVE_SEATS      0.600     0.500     0.545         6
#              MOTORCYCLE_TRANSMISSION_CROWNS      1.000     0.500     0.667         4
#                                  LAMINATORS      1.000     0.714     0.833         7
#                                 CEREAL_BARS      1.000     0.667     0.800         3
#                                MUSIC_ALBUMS      0.667     0.500     0.571         4
#                   AUTOMOTIVE_CV_JOINT_BOOTS      0.714     0.714     0.714         7
#                           MICROWAVE_KEYPADS      1.000     0.667     0.800         3
#                           WALL_ANCHOR_PLUGS      1.000     0.750     0.857         4
#                                 DRUM_STANDS      0.750     0.429     0.545         7
#                                 PET_COLLARS      0.800     0.857     0.828        14
#                             GATE_GEAR_RACKS      1.000     0.500     0.667         4
#                                   CAR_HOODS      1.000     1.000     1.000         3
#                        SCREEN_PRINTING_KITS      1.000     0.750     0.857         4
#                                  LED_STRIPS      0.750     0.750     0.750         4
#                             SANDWICH_MAKERS      0.500     0.500     0.500         2
#                              DENTAL_FLOSSES      1.000     0.500     0.667         2
#                              CAMERA_FLASHES      1.000     1.000     1.000         5
#                           DOG_NAIL_CLIPPERS      1.000     0.500     0.667         2
#                                    PINBALLS      0.500     0.333     0.400         6
#                                      GAUZES      1.000     0.667     0.800         6
#                                        SODS      0.500     0.667     0.571         3
#                          ELECTRICITY_METERS      0.000     0.000     0.000         4
#                             METAL_DETECTORS      1.000     0.667     0.800         3
#                          ELECTRIC_CHAINSAWS      0.500     0.333     0.400         3
#                            KNITTING_NEEDLES      0.500     0.500     0.500         6
#                           SWIMMING_EARPLUGS      0.000     0.000     0.000         2
#                                 SOUND_CARDS      1.000     0.600     0.750         5
#                                    STEPPERS      0.500     0.750     0.600         4
#                                 FANNY_PACKS      0.000     0.000     0.000         4
#                          TOOTHBRUSH_HOLDERS      0.000     0.000     0.000         2
#                          TABLE_TENNIS_BALLS      1.000     0.500     0.667         2
#                 ENGINE_OIL_PRESSURE_SENSORS      0.500     0.333     0.400         3
#                                 ICE_BUCKETS      1.000     0.714     0.833         7
#                               MASSAGE_SOFAS      0.500     0.250     0.333         4
#                              STYLING_CHAIRS      0.500     0.500     0.500         2
#                               BICYCLE_SEATS      1.000     1.000     1.000         3
#                            VOLLEYBALL_BALLS      1.000     0.333     0.500         3
#                           SPHYGMOMANOMETERS      0.667     0.500     0.571         4
#                              BINDING_SPINES      1.000     0.500     0.667         2
#                    DIGITAL_WEATHER_STATIONS      1.000     1.000     1.000         2
#                          HOME_BOTTLE_STANDS      1.000     0.667     0.800         3
#                                   DOORBELLS      0.500     0.500     0.500         2
#                                DRIED_FRUITS      1.000     1.000     1.000         2
#                            BOXING_HEADGEARS      1.000     0.500     0.667         2
#
#                                    accuracy                          0.939    138550
#                                   macro avg      0.878     0.830     0.846    138550
#                                weighted avg      0.939     0.939     0.938    138550
