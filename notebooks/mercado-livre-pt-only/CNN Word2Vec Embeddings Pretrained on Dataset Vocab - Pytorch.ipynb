# %%
from os.path import join
import os
import pandas as pd
import torch
import numpy as np
import torch.nn as nn
import torch.nn.functional as F
from torch.optim.lr_scheduler import ReduceLROnPlateau
from torch.nn.init import kaiming_uniform_
from torch.optim import SGD
from torch.utils.data import DataLoader, SequentialSampler, RandomSampler
from torch.optim import Adam
from nlpClassifiers.data.dataset  import NLPDataset, Vocabulary
from sklearn.metrics import roc_curve, auc, classification_report
from scipy.special import expit
import gensim
import shutil
from pathlib import Path
import random

# %%
ROOT = '../../'
PATH_TO_VIRTUAL_OPERATOR_DATA = join(ROOT, "data/virtual-operator")
PATH_TO_AGENT_BENCHMARK_DATA = join(ROOT, "data/agent-benchmark")
PATH_TO_ML_PT_DATA = join(ROOT, "data/mercado-livre-pt-only")

PATH_TO_VIRTUAL_OPERATOR_MODELS = join(ROOT, "models/virtual-operator")
PATH_TO_AGENT_BENCHMARK_MODELS = join(ROOT, "models/agent-benchmark")
PATH_TO_ML_PT_MODELS = join(ROOT, "models/mercado-livre-pt-only")

EMBEDDING_DIM = 300
EMBEDDINGS_FILE = '../../data/mercado-livre-pt-only/word2vec-model-mercado-livre-pt.bin'
MAX_WORDS = 30000
dataset = 'mercado-livre-pt'
sentence_max_len = 82
batch_size = 512

epochs=30
stopwords_lang = None
gpu=1
lr=0.001
clipping_value=0.25
save_name='cnn-pytorch-word2vec-dataset-embeddings'
patience=5

# %%
BASE_PATH_TO_MODELS = {"virtual-operator": PATH_TO_VIRTUAL_OPERATOR_MODELS, "agent-benchmark": PATH_TO_AGENT_BENCHMARK_MODELS, "mercado-livre-pt": PATH_TO_ML_PT_MODELS}
FULL_PATH_TO_MODELS = join(BASE_PATH_TO_MODELS[dataset], "bow-classifier")

# %%
def _init_fn(worker_id):
    np.random.seed(seed)

# %%
def read_data(dataset, subset):
    BASE_PATH_TO_DATASET = {"virtual-operator": PATH_TO_VIRTUAL_OPERATOR_DATA, "agent-benchmark": PATH_TO_AGENT_BENCHMARK_DATA, "mercado-livre-pt": PATH_TO_ML_PT_DATA}
    BASE_PATH_TO_DATASET = {"train": join(BASE_PATH_TO_DATASET[dataset], "train.csv"), "val": join(BASE_PATH_TO_DATASET[dataset], "val.csv"), "test": join(BASE_PATH_TO_DATASET[dataset], "test.csv")}
    FULL_PATH_TO_DATASET = BASE_PATH_TO_DATASET[subset]
    
    if dataset == "mercado-livre-pt":
        sep=","
    else:
        sep=";"
    data = pd.read_csv(FULL_PATH_TO_DATASET, sep=sep, names =['utterance','label'], header=None, dtype={'utterance':str, 'label': str} )
    return data

# %%
train_df = read_data(dataset, "train")
val_df = read_data(dataset, "val")

# %%
voc = Vocabulary('CNN', stopwords_lang)
voc.build_vocab(train_df['utterance'].tolist() +  val_df['utterance'].tolist(), MAX_WORDS)
embedding_weights = voc.load_embeddings(EMBEDDINGS_FILE, EMBEDDING_DIM)
if voc.num_words < MAX_WORDS or MAX_WORDS == 0:
    MAX_WORDS = voc.num_words
# Out:
# 1 tokens not found in vocabulary.

# %%
train_corpus = NLPDataset(dataset, "train", sentence_max_len, vocab= voc)
labels_dict = train_corpus.labels_dict
val_corpus = NLPDataset(dataset, "val", sentence_max_len, labels_dict = labels_dict, vocab= voc)

# %%
train_dataloader = DataLoader(
            train_corpus,
            sampler = RandomSampler(train_corpus),
            batch_size = batch_size,
            pin_memory=True,
            worker_init_fn=_init_fn,
            num_workers=0
)

validation_dataloader = DataLoader(
            val_corpus,
            sampler = RandomSampler(val_corpus),
            batch_size = batch_size,
            pin_memory=True,
            worker_init_fn=_init_fn,
            num_workers=0
)

# %%
def initialize_weights(model):
    if type(model) in [nn.Linear]:
        nn.init.xavier_normal_(model.weight.data)
    elif type(model) in [nn.LSTM, nn.RNN, nn.GRU]:
        nn.init.xavier_normal_(model.weight_hh_l0)
        nn.init.xavier_normal_(model.weight_ih_l0)

# %%
#del model
torch.cuda.empty_cache()

# %%
def seed_everything(seed=10):
    random.seed(seed)
    os.environ['PYTHONHASHSEED'] = str(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    torch.backends.cudnn.deterministic = True

# %%
seed_everything()

# %%
class CNNNet(nn.Module):
    def __init__(self, num_classes, num_features, criterion, embedding_dim, embedding_weights=None):
        super(CNNNet, self).__init__()
        self.criterion = criterion
        self.embedding_dim = embedding_dim
        self.n_layers = 1
        self.embedding = nn.Embedding(num_features, embedding_dim, padding_idx = 0)
        if(embedding_weights is not None):
            print("Embedding layer Weights won't be updated.")
            self.embedding.load_state_dict({'weight': embedding_weights})
            self.embedding.weight.requires_grad = False
            #self.embedding.from_pretrained(embedding_weights, freeze=True)
        else:
            self.embedding.weight.data = torch.zeros(self.embedding.weight.data.size())
            self.embedding.weight.requires_grad = True
        
        self.cnn = nn.Conv1d(embedding_dim, 256, 4)
        
        for name, param in self.cnn.named_parameters():
            if 'bias' in name:
                nn.init.constant_(param, 0.0)
            elif 'weight_ih' in name:
                nn.init.kaiming_normal_(param)
            elif 'weight_hh' in name:
                nn.init.orthogonal_(param)
             
        self.dropout = nn.Dropout(0.2)       
        self.out = nn.Linear(256, num_classes)
        self.init_weights()
    def forward(self, x, y):
        # Conv1d takes in (batch, channels, seq_len), but raw embedded is (batch, seq_len, channels)
        h_embedding = self.embedding(x)
        h_embedding = h_embedding.permute(0, 2, 1)
        h_cnn = self.cnn(h_embedding)
        h_cnn = h_cnn.permute(0, 2, 1)
        h_cnn = self.dropout(h_cnn)
        h_max_pool = self.global_max_pool(h_cnn)
        x = self.out(h_max_pool)
        loss = self.criterion(x, y)
        # return the final output
        return loss,x 
    
    @staticmethod
    def global_max_pool(x):
        """Convolution and global max pooling layer"""
        return x.max(1)[0]
    
    def init_weights(self):
        """
        Here we reproduce Keras default initialization weights to initialize Embeddings/LSTM weights
        """
        ih = (param.data for name, param in self.named_parameters() if 'weight_ih' in name)
        hh = (param.data for name, param in self.named_parameters() if 'weight_hh' in name)
        b = (param.data for name, param in self.named_parameters() if 'bias' in name)
        for t in ih:
            nn.init.xavier_uniform(t)
        for t in hh:
            nn.init.orthogonal(t)
        for t in b:
            nn.init.constant(t, 0)
    
    def init_hidden(self, batch_size, device):
        weight = next(self.parameters()).data
        hidden = (weight.new(self.n_layers, batch_size, self.embedding_dim).zero_().to(device),
                      weight.new(self.n_layers, batch_size, self.embedding_dim).zero_().to(device))
        return hidden

# %%
criterion = torch.nn.CrossEntropyLoss()
model = CNNNet(train_corpus.num_labels, MAX_WORDS, criterion, EMBEDDING_DIM, embedding_weights)
# Out:
# Embedding layer Weights won't be updated.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:60: UserWarning: nn.init.constant is now deprecated in favor of nn.init.constant_.

# %%
model.apply(initialize_weights)
# Out:
# CNNNet(
#   (criterion): CrossEntropyLoss()
#   (embedding): Embedding(30000, 300, padding_idx=0)
#   (cnn): Conv1d(300, 256, kernel_size=(4,), stride=(1,))
#   (dropout): Dropout(p=0.2, inplace=False)
#   (out): Linear(in_features=256, out_features=1048, bias=True)
# )

# %%
device = torch.device(f"cuda:{gpu}")

# %%
model = model.to(device)
optimizer = Adam(model.parameters(),lr, betas=(0.7, 0.999))

# %%
def multi_acc(y_pred, y_test):
    y_pred_softmax = torch.log_softmax(y_pred, dim = 1)
    _, y_pred_tags = torch.max(y_pred_softmax, dim = 1)    
    
    correct_pred = (y_pred_tags == y_test).float()
    acc = correct_pred.sum() / len(correct_pred)
    acc = acc * 100.0

    return acc

# %%
def get_accuracy_from_logits(logits, labels):
    acc = (labels.cpu() == logits.cpu().argmax(-1)).float().detach().numpy()
    return float(100 * acc.sum() / len(acc))

# %%
scheduler = ReduceLROnPlateau(optimizer, mode='min', patience=3,verbose=True, factor=0.1)

best_epoch = -1
last_saved_model = ""
training_stats = []
global_step = 0
best_val_acc = float("-inf")
best_model_wts = None
best_curr_val = 0

for epoch_i in range(0, epochs):
    print("")
    print('======== Epoch {:} / {:} ========'.format(epoch_i + 1, epochs))
    print('Training...')
    total_train_loss = 0
    model.train()
    for step, batch in enumerate(train_dataloader):
        #val_h = model.init_hidden(len(batch[0]), device)
        #val_h = tuple([each.data for each in val_h])
         # Progress update every 40 batches.
        if step % 40 == 0 and not step == 0:
            print('  Batch {:>5,}  of  {:>5,}.    .'.format(step, len(train_dataloader)))
        b_input_ids = batch[0]
        b_labels = batch[1].to(device)
        b_input_ids = torch.tensor(b_input_ids).to(device).long()
        model.zero_grad()
        loss, logits = model(b_input_ids, b_labels)
        loss.backward()
        torch.nn.utils.clip_grad_norm_(model.parameters(), clipping_value)
        optimizer.step()
        step_loss = loss.item()
        if step % 40 == 0 and not step == 0:
            print("  step loss: {0:.2f}".format(step_loss))
        total_train_loss += step_loss
        global_step += 1
    avg_train_loss = total_train_loss / len(train_dataloader)
    # Measure how long this epoch took.
    print("")
    print("  Average training loss: {0:.2f}".format(avg_train_loss))

    print("")
    print("Running Validation...")
    model.eval()

    # Tracking variables
    total_eval_accuracy = 0.0
    total_eval_loss = 0
    nb_eval_steps = 0
    for step, batch in enumerate(validation_dataloader):
        #val_h = model.init_hidden(len(batch[0]), device)
        #val_h = tuple([each.data for each in val_h])
        b_input_ids = batch[0]
        b_input_ids = torch.tensor(b_input_ids).to(device).long()
        b_labels = batch[1].to(device)
        with torch.no_grad():
            # Forward pass, calculate logit predictions.
            loss, logits = model(b_input_ids, b_labels)
        total_eval_loss += loss
        batch_acc = get_accuracy_from_logits(logits, b_labels)
        batch_acc2 = multi_acc(logits, b_labels)
        print("Batch accuracy: {0:.2f}".format(batch_acc))
        total_eval_accuracy += batch_acc
    
    # Calculate the average loss over all of the batches.
    avg_val_accuracy = total_eval_accuracy / len(validation_dataloader)
    print("  Accuracy: {0:.2f}".format(avg_val_accuracy))
    
    if avg_val_accuracy > best_val_acc:
        print(f"New best model, saving it!")
        if avg_val_accuracy > best_curr_val:
            best_curr_val = avg_val_accuracy
        if last_saved_model:
            shutil.rmtree(last_saved_model)
        model_path = Path(
            FULL_PATH_TO_MODELS,
            f"base-dataset-{dataset}-{save_name}"
        )
        last_saved_model = model_path
        model_path.mkdir(parents=True, exist_ok=True)
        best_val_acc = avg_val_accuracy
        torch.save(model, join(model_path, "best-model.pth"))
        best_epoch = epoch_i
        n_epochs_no_improvement = 0
    elif avg_val_accuracy > best_curr_val:
        best_curr_val = avg_val_accuracy
        n_epochs_no_improvement = 0
    else:
        n_epochs_no_improvement += 1
        print(f"The model does not improve for {n_epochs_no_improvement} epochs!")

    if n_epochs_no_improvement > patience:
        print(f"====>Stopping training, the model did not improve for {n_epochs_no_improvement}\n====>Best epoch: {best_epoch + 1}.")
        break
    scheduler.step(total_eval_loss)
print("")
print("Training complete!")
# Out:
# ======== Epoch 1 / 30 ========
# Training...
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:25: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   Batch    40  of    975.    .
#   step loss: 2.28
#   Batch    80  of    975.    .
#   step loss: 1.40
#   Batch   120  of    975.    .
#   step loss: 1.01
#   Batch   160  of    975.    .
#   step loss: 0.92
#   Batch   200  of    975.    .
#   step loss: 0.86
#   Batch   240  of    975.    .
#   step loss: 0.75
#   Batch   280  of    975.    .
#   step loss: 0.84
#   Batch   320  of    975.    .
#   step loss: 0.76
#   Batch   360  of    975.    .
#   step loss: 0.67
#   Batch   400  of    975.    .
#   step loss: 0.54
#   Batch   440  of    975.    .
#   step loss: 0.67
#   Batch   480  of    975.    .
#   step loss: 0.65
#   Batch   520  of    975.    .
#   step loss: 0.58
#   Batch   560  of    975.    .
#   step loss: 0.71
#   Batch   600  of    975.    .
#   step loss: 0.49
#   Batch   640  of    975.    .
#   step loss: 0.57
#   Batch   680  of    975.    .
#   step loss: 0.54
#   Batch   720  of    975.    .
#   step loss: 0.51
#   Batch   760  of    975.    .
#   step loss: 0.50
#   Batch   800  of    975.    .
#   step loss: 0.53
#   Batch   840  of    975.    .
#   step loss: 0.58
#   Batch   880  of    975.    .
#   step loss: 0.50
#   Batch   920  of    975.    .
#   step loss: 0.53
#   Batch   960  of    975.    .
#   step loss: 0.49
#
#   Average training loss: 0.88
#
# Running Validation...
# Batch accuracy: 89.26
# Batch accuracy: 89.26
# Batch accuracy: 86.91
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:53: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
# Batch accuracy: 89.45
# Batch accuracy: 86.72
# Batch accuracy: 89.84
# Batch accuracy: 87.70
# Batch accuracy: 87.30
# Batch accuracy: 88.09
# Batch accuracy: 90.62
# Batch accuracy: 91.02
# Batch accuracy: 85.35
# Batch accuracy: 85.55
# Batch accuracy: 87.89
# Batch accuracy: 87.70
# Batch accuracy: 87.50
# Batch accuracy: 88.67
# Batch accuracy: 88.67
# Batch accuracy: 87.30
# Batch accuracy: 88.67
# Batch accuracy: 90.04
# Batch accuracy: 87.50
# Batch accuracy: 90.23
# Batch accuracy: 85.16
# Batch accuracy: 89.26
# Batch accuracy: 90.04
# Batch accuracy: 91.21
# Batch accuracy: 88.09
# Batch accuracy: 87.50
# Batch accuracy: 88.67
# Batch accuracy: 87.50
# Batch accuracy: 89.06
# Batch accuracy: 89.84
# Batch accuracy: 89.06
# Batch accuracy: 88.28
# Batch accuracy: 82.62
# Batch accuracy: 87.89
# Batch accuracy: 86.72
# Batch accuracy: 86.33
# Batch accuracy: 88.87
# Batch accuracy: 86.72
# Batch accuracy: 86.72
# Batch accuracy: 88.28
# Batch accuracy: 89.26
# Batch accuracy: 87.11
# Batch accuracy: 89.65
# Batch accuracy: 89.65
# Batch accuracy: 88.67
# Batch accuracy: 90.62
# Batch accuracy: 90.04
# Batch accuracy: 89.45
# Batch accuracy: 87.89
# Batch accuracy: 88.09
# Batch accuracy: 91.21
# Batch accuracy: 86.91
# Batch accuracy: 91.60
# Batch accuracy: 86.91
# Batch accuracy: 90.04
# Batch accuracy: 87.70
# Batch accuracy: 87.70
# Batch accuracy: 84.96
# Batch accuracy: 88.48
# Batch accuracy: 89.06
# Batch accuracy: 89.65
# Batch accuracy: 88.09
# Batch accuracy: 87.11
# Batch accuracy: 89.26
# Batch accuracy: 89.45
# Batch accuracy: 87.11
# Batch accuracy: 88.09
# Batch accuracy: 90.62
# Batch accuracy: 88.48
# Batch accuracy: 87.30
# Batch accuracy: 89.65
# Batch accuracy: 87.70
# Batch accuracy: 86.91
# Batch accuracy: 88.48
# Batch accuracy: 89.26
# Batch accuracy: 88.67
# Batch accuracy: 87.89
# Batch accuracy: 87.89
# Batch accuracy: 89.84
# Batch accuracy: 90.04
# Batch accuracy: 90.23
# Batch accuracy: 90.23
# Batch accuracy: 87.11
# Batch accuracy: 90.82
# Batch accuracy: 91.41
# Batch accuracy: 88.67
# Batch accuracy: 88.87
# Batch accuracy: 88.87
# Batch accuracy: 87.11
# Batch accuracy: 88.28
# Batch accuracy: 86.33
# Batch accuracy: 88.48
# Batch accuracy: 88.09
# Batch accuracy: 90.04
# Batch accuracy: 87.50
# Batch accuracy: 87.50
# Batch accuracy: 88.48
# Batch accuracy: 87.11
# Batch accuracy: 89.45
# Batch accuracy: 88.67
# Batch accuracy: 88.67
# Batch accuracy: 86.91
# Batch accuracy: 89.26
# Batch accuracy: 86.72
# Batch accuracy: 90.23
# Batch accuracy: 88.71
#   Accuracy: 88.43
# New best model, saving it!
#
# ======== Epoch 2 / 30 ========
# Training...
#   Batch    40  of    975.    .
#   step loss: 0.40
#   Batch    80  of    975.    .
#   step loss: 0.49
#   Batch   120  of    975.    .
#   step loss: 0.47
#   Batch   160  of    975.    .
#   step loss: 0.42
#   Batch   200  of    975.    .
#   step loss: 0.50
#   Batch   240  of    975.    .
#   step loss: 0.40
#   Batch   280  of    975.    .
#   step loss: 0.43
#   Batch   320  of    975.    .
#   step loss: 0.46
#   Batch   360  of    975.    .
#   step loss: 0.37
#   Batch   400  of    975.    .
#   step loss: 0.45
#   Batch   440  of    975.    .
#   step loss: 0.45
#   Batch   480  of    975.    .
#   step loss: 0.40
#   Batch   520  of    975.    .
#   step loss: 0.49
#   Batch   560  of    975.    .
#   step loss: 0.48
#   Batch   600  of    975.    .
#   step loss: 0.47
#   Batch   640  of    975.    .
#   step loss: 0.44
#   Batch   680  of    975.    .
#   step loss: 0.43
#   Batch   720  of    975.    .
#   step loss: 0.59
#   Batch   760  of    975.    .
#   step loss: 0.32
#   Batch   800  of    975.    .
#   step loss: 0.38
#   Batch   840  of    975.    .
#   step loss: 0.51
#   Batch   880  of    975.    .
#   step loss: 0.44
#   Batch   920  of    975.    .
#   step loss: 0.45
#   Batch   960  of    975.    .
#   step loss: 0.38
#
#   Average training loss: 0.44
#
# Running Validation...
# Batch accuracy: 92.19
# Batch accuracy: 89.06
# Batch accuracy: 87.50
# Batch accuracy: 90.82
# Batch accuracy: 92.19
# Batch accuracy: 89.06
# Batch accuracy: 91.41
# Batch accuracy: 89.65
# Batch accuracy: 87.30
# Batch accuracy: 87.70
# Batch accuracy: 88.87
# Batch accuracy: 92.19
# Batch accuracy: 89.65
# Batch accuracy: 91.02
# Batch accuracy: 90.82
# Batch accuracy: 89.45
# Batch accuracy: 90.04
# Batch accuracy: 91.41
# Batch accuracy: 90.62
# Batch accuracy: 88.87
# Batch accuracy: 87.70
# Batch accuracy: 90.62
# Batch accuracy: 90.43
# Batch accuracy: 88.28
# Batch accuracy: 88.28
# Batch accuracy: 91.02
# Batch accuracy: 89.65
# Batch accuracy: 94.34
# Batch accuracy: 90.04
# Batch accuracy: 91.02
# Batch accuracy: 89.84
# Batch accuracy: 89.45
# Batch accuracy: 88.48
# Batch accuracy: 90.43
# Batch accuracy: 87.50
# Batch accuracy: 90.62
# Batch accuracy: 91.60
# Batch accuracy: 89.06
# Batch accuracy: 88.09
# Batch accuracy: 87.89
# Batch accuracy: 88.67
# Batch accuracy: 90.04
# Batch accuracy: 91.41
# Batch accuracy: 88.87
# Batch accuracy: 91.41
# Batch accuracy: 89.84
# Batch accuracy: 90.62
# Batch accuracy: 91.60
# Batch accuracy: 91.02
# Batch accuracy: 87.89
# Batch accuracy: 89.45
# Batch accuracy: 88.48
# Batch accuracy: 87.89
# Batch accuracy: 90.82
# Batch accuracy: 89.06
# Batch accuracy: 90.43
# Batch accuracy: 90.04
# Batch accuracy: 89.26
# Batch accuracy: 90.23
# Batch accuracy: 91.21
# Batch accuracy: 89.26
# Batch accuracy: 86.52
# Batch accuracy: 88.67
# Batch accuracy: 87.70
# Batch accuracy: 91.02
# Batch accuracy: 91.41
# Batch accuracy: 90.23
# Batch accuracy: 89.45
# Batch accuracy: 87.70
# Batch accuracy: 91.60
# Batch accuracy: 90.82
# Batch accuracy: 87.30
# Batch accuracy: 91.21
# Batch accuracy: 89.26
# Batch accuracy: 89.45
# Batch accuracy: 90.23
# Batch accuracy: 89.06
# Batch accuracy: 91.41
# Batch accuracy: 88.28
# Batch accuracy: 88.28
# Batch accuracy: 88.87
# Batch accuracy: 91.41
# Batch accuracy: 92.19
# Batch accuracy: 90.04
# Batch accuracy: 90.43
# Batch accuracy: 88.87
# Batch accuracy: 87.89
# Batch accuracy: 88.48
# Batch accuracy: 91.99
# Batch accuracy: 89.84
# Batch accuracy: 89.84
# Batch accuracy: 92.58
# Batch accuracy: 88.48
# Batch accuracy: 90.62
# Batch accuracy: 90.82
# Batch accuracy: 86.52
# Batch accuracy: 91.02
# Batch accuracy: 90.62
# Batch accuracy: 88.48
# Batch accuracy: 88.09
# Batch accuracy: 89.45
# Batch accuracy: 91.99
# Batch accuracy: 92.19
# Batch accuracy: 90.82
# Batch accuracy: 91.99
# Batch accuracy: 91.02
# Batch accuracy: 91.41
# Batch accuracy: 89.84
# Batch accuracy: 88.71
#   Accuracy: 89.87
# New best model, saving it!
#
# ======== Epoch 3 / 30 ========
# Training...
#   Batch    40  of    975.    .
#   step loss: 0.34
#   Batch    80  of    975.    .
#   step loss: 0.42
#   Batch   120  of    975.    .
#   step loss: 0.35
#   Batch   160  of    975.    .
#   step loss: 0.39
#   Batch   200  of    975.    .
#   step loss: 0.29
#   Batch   240  of    975.    .
#   step loss: 0.44
#   Batch   280  of    975.    .
#   step loss: 0.43
#   Batch   320  of    975.    .
#   step loss: 0.46
#   Batch   360  of    975.    .
#   step loss: 0.31
#   Batch   400  of    975.    .
#   step loss: 0.30
#   Batch   440  of    975.    .
#   step loss: 0.37
#   Batch   480  of    975.    .
#   step loss: 0.33
#   Batch   520  of    975.    .
#   step loss: 0.47
#   Batch   560  of    975.    .
#   step loss: 0.35
#   Batch   600  of    975.    .
#   step loss: 0.32
#   Batch   640  of    975.    .
#   step loss: 0.45
#   Batch   680  of    975.    .
#   step loss: 0.37
#   Batch   720  of    975.    .
#   step loss: 0.33
#   Batch   760  of    975.    .
#   step loss: 0.37
#   Batch   800  of    975.    .
#   step loss: 0.50
#   Batch   840  of    975.    .
#   step loss: 0.39
#   Batch   880  of    975.    .
#   step loss: 0.50
#   Batch   920  of    975.    .
#   step loss: 0.36
#   Batch   960  of    975.    .
#   step loss: 0.37
#
#   Average training loss: 0.37
#
# Running Validation...
# Batch accuracy: 90.23
# Batch accuracy: 91.02
# Batch accuracy: 90.43
# Batch accuracy: 91.60
# Batch accuracy: 90.43
# Batch accuracy: 91.41
# Batch accuracy: 90.62
# Batch accuracy: 89.65
# Batch accuracy: 90.04
# Batch accuracy: 89.26
# Batch accuracy: 87.70
# Batch accuracy: 91.60
# Batch accuracy: 92.58
# Batch accuracy: 89.26
# Batch accuracy: 89.06
# Batch accuracy: 89.06
# Batch accuracy: 89.65
# Batch accuracy: 91.80
# Batch accuracy: 91.60
# Batch accuracy: 91.02
# Batch accuracy: 89.26
# Batch accuracy: 90.23
# Batch accuracy: 90.43
# Batch accuracy: 90.23
# Batch accuracy: 90.23
# Batch accuracy: 90.82
# Batch accuracy: 88.67
# Batch accuracy: 90.04
# Batch accuracy: 88.48
# Batch accuracy: 91.02
# Batch accuracy: 90.23
# Batch accuracy: 89.06
# Batch accuracy: 92.19
# Batch accuracy: 90.04
# Batch accuracy: 88.28
# Batch accuracy: 89.26
# Batch accuracy: 87.89
# Batch accuracy: 89.26
# Batch accuracy: 91.02
# Batch accuracy: 92.77
# Batch accuracy: 91.02
# Batch accuracy: 92.19
# Batch accuracy: 90.62
# Batch accuracy: 91.80
# Batch accuracy: 90.04
# Batch accuracy: 87.30
# Batch accuracy: 89.84
# Batch accuracy: 89.84
# Batch accuracy: 91.41
# Batch accuracy: 88.28
# Batch accuracy: 91.99
# Batch accuracy: 90.04
# Batch accuracy: 89.06
# Batch accuracy: 89.84
# Batch accuracy: 91.41
# Batch accuracy: 91.02
# Batch accuracy: 91.41
# Batch accuracy: 90.43
# Batch accuracy: 91.21
# Batch accuracy: 91.99
# Batch accuracy: 91.41
# Batch accuracy: 90.04
# Batch accuracy: 91.02
# Batch accuracy: 93.36
# Batch accuracy: 90.82
# Batch accuracy: 91.60
# Batch accuracy: 90.04
# Batch accuracy: 89.06
# Batch accuracy: 92.58
# Batch accuracy: 91.21
# Batch accuracy: 89.65
# Batch accuracy: 89.06
# Batch accuracy: 91.02
# Batch accuracy: 92.19
# Batch accuracy: 89.65
# Batch accuracy: 92.58
# Batch accuracy: 88.09
# Batch accuracy: 90.82
# Batch accuracy: 90.43
# Batch accuracy: 90.43
# Batch accuracy: 91.99
# Batch accuracy: 90.62
# Batch accuracy: 90.82
# Batch accuracy: 90.23
# Batch accuracy: 90.82
# Batch accuracy: 91.80
# Batch accuracy: 89.65
# Batch accuracy: 91.21
# Batch accuracy: 89.26
# Batch accuracy: 88.87
# Batch accuracy: 91.02
# Batch accuracy: 90.62
# Batch accuracy: 91.02
# Batch accuracy: 90.82
# Batch accuracy: 92.77
# Batch accuracy: 92.38
# Batch accuracy: 89.26
# Batch accuracy: 90.43
# Batch accuracy: 90.43
# Batch accuracy: 91.60
# Batch accuracy: 91.02
# Batch accuracy: 90.23
# Batch accuracy: 91.21
# Batch accuracy: 88.87
# Batch accuracy: 89.65
# Batch accuracy: 90.82
# Batch accuracy: 92.77
# Batch accuracy: 92.58
# Batch accuracy: 89.52
#   Accuracy: 90.51
# New best model, saving it!
#
# ======== Epoch 4 / 30 ========
# Training...
#   Batch    40  of    975.    .
#   step loss: 0.34
#   Batch    80  of    975.    .
#   step loss: 0.32
#   Batch   120  of    975.    .
#   step loss: 0.25
#   Batch   160  of    975.    .
#   step loss: 0.33
#   Batch   200  of    975.    .
#   step loss: 0.36
#   Batch   240  of    975.    .
#   step loss: 0.43
#   Batch   280  of    975.    .
#   step loss: 0.30
#   Batch   320  of    975.    .
#   step loss: 0.29
#   Batch   360  of    975.    .
#   step loss: 0.25
#   Batch   400  of    975.    .
#   step loss: 0.28
#   Batch   440  of    975.    .
#   step loss: 0.34
#   Batch   480  of    975.    .
#   step loss: 0.32
#   Batch   520  of    975.    .
#   step loss: 0.35
#   Batch   560  of    975.    .
#   step loss: 0.31
#   Batch   600  of    975.    .
#   step loss: 0.38
#   Batch   640  of    975.    .
#   step loss: 0.40
#   Batch   680  of    975.    .
#   step loss: 0.37
#   Batch   720  of    975.    .
#   step loss: 0.35
#   Batch   760  of    975.    .
#   step loss: 0.30
#   Batch   800  of    975.    .
#   step loss: 0.41
#   Batch   840  of    975.    .
#   step loss: 0.27
#   Batch   880  of    975.    .
#   step loss: 0.36
#   Batch   920  of    975.    .
#   step loss: 0.39
#   Batch   960  of    975.    .
#   step loss: 0.31
#
#   Average training loss: 0.33
#
# Running Validation...
# Batch accuracy: 89.65
# Batch accuracy: 89.84
# Batch accuracy: 91.21
# Batch accuracy: 91.41
# Batch accuracy: 89.65
# Batch accuracy: 91.02
# Batch accuracy: 91.02
# Batch accuracy: 90.82
# Batch accuracy: 91.21
# Batch accuracy: 91.21
# Batch accuracy: 90.82
# Batch accuracy: 90.23
# Batch accuracy: 91.80
# Batch accuracy: 88.48
# Batch accuracy: 90.43
# Batch accuracy: 89.84
# Batch accuracy: 91.60
# Batch accuracy: 91.60
# Batch accuracy: 91.80
# Batch accuracy: 91.41
# Batch accuracy: 92.77
# Batch accuracy: 91.60
# Batch accuracy: 92.58
# Batch accuracy: 91.80
# Batch accuracy: 91.21
# Batch accuracy: 89.45
# Batch accuracy: 92.19
# Batch accuracy: 91.41
# Batch accuracy: 88.09
# Batch accuracy: 91.02
# Batch accuracy: 91.80
# Batch accuracy: 90.04
# Batch accuracy: 90.62
# Batch accuracy: 89.65
# Batch accuracy: 90.04
# Batch accuracy: 90.82
# Batch accuracy: 91.99
# Batch accuracy: 87.89
# Batch accuracy: 91.21
# Batch accuracy: 90.43
# Batch accuracy: 89.65
# Batch accuracy: 90.04
# Batch accuracy: 90.62
# Batch accuracy: 90.43
# Batch accuracy: 89.26
# Batch accuracy: 88.67
# Batch accuracy: 90.82
# Batch accuracy: 91.21
# Batch accuracy: 87.89
# Batch accuracy: 89.84
# Batch accuracy: 92.38
# Batch accuracy: 90.82
# Batch accuracy: 91.41
# Batch accuracy: 91.80
# Batch accuracy: 90.62
# Batch accuracy: 88.87
# Batch accuracy: 91.80
# Batch accuracy: 90.23
# Batch accuracy: 91.60
# Batch accuracy: 90.23
# Batch accuracy: 91.41
# Batch accuracy: 91.99
# Batch accuracy: 92.97
# Batch accuracy: 91.80
# Batch accuracy: 87.70
# Batch accuracy: 90.82
# Batch accuracy: 91.02
# Batch accuracy: 89.84
# Batch accuracy: 92.38
# Batch accuracy: 91.21
# Batch accuracy: 91.21
# Batch accuracy: 89.06
# Batch accuracy: 92.19
# Batch accuracy: 90.82
# Batch accuracy: 91.80
# Batch accuracy: 90.04
# Batch accuracy: 92.38
# Batch accuracy: 90.62
# Batch accuracy: 88.87
# Batch accuracy: 90.04
# Batch accuracy: 90.82
# Batch accuracy: 91.02
# Batch accuracy: 91.02
# Batch accuracy: 90.62
# Batch accuracy: 89.65
# Batch accuracy: 90.04
# Batch accuracy: 90.82
# Batch accuracy: 90.23
# Batch accuracy: 88.48
# Batch accuracy: 90.82
# Batch accuracy: 88.48
# Batch accuracy: 89.45
# Batch accuracy: 89.06
# Batch accuracy: 93.16
# Batch accuracy: 91.21
# Batch accuracy: 89.26
# Batch accuracy: 91.60
# Batch accuracy: 91.21
# Batch accuracy: 91.41
# Batch accuracy: 90.23
# Batch accuracy: 91.99
# Batch accuracy: 90.43
# Batch accuracy: 90.23
# Batch accuracy: 89.45
# Batch accuracy: 92.97
# Batch accuracy: 90.43
# Batch accuracy: 91.60
# Batch accuracy: 90.43
# Batch accuracy: 93.55
#   Accuracy: 90.71
# New best model, saving it!
#
# ======== Epoch 5 / 30 ========
# Training...
#   Batch    40  of    975.    .
#   step loss: 0.28
#   Batch    80  of    975.    .
#   step loss: 0.29
#   Batch   120  of    975.    .
#   step loss: 0.32
#   Batch   160  of    975.    .
#   step loss: 0.30
#   Batch   200  of    975.    .
#   step loss: 0.25
#   Batch   240  of    975.    .
#   step loss: 0.30
#   Batch   280  of    975.    .
#   step loss: 0.26
#   Batch   320  of    975.    .
#   step loss: 0.25
#   Batch   360  of    975.    .
#   step loss: 0.25
#   Batch   400  of    975.    .
#   step loss: 0.29
#   Batch   440  of    975.    .
#   step loss: 0.29
#   Batch   480  of    975.    .
#   step loss: 0.24
#   Batch   520  of    975.    .
#   step loss: 0.31
#   Batch   560  of    975.    .
#   step loss: 0.24
#   Batch   600  of    975.    .
#   step loss: 0.30
#   Batch   640  of    975.    .
#   step loss: 0.35
#   Batch   680  of    975.    .
#   step loss: 0.44
#   Batch   720  of    975.    .
#   step loss: 0.29
#   Batch   760  of    975.    .
#   step loss: 0.31
#   Batch   800  of    975.    .
#   step loss: 0.28
#   Batch   840  of    975.    .
#   step loss: 0.23
#   Batch   880  of    975.    .
#   step loss: 0.29
#   Batch   920  of    975.    .
#   step loss: 0.32
#   Batch   960  of    975.    .
#   step loss: 0.35
#
#   Average training loss: 0.30
#
# Running Validation...
# Batch accuracy: 91.41
# Batch accuracy: 89.45
# Batch accuracy: 88.48
# Batch accuracy: 89.65
# Batch accuracy: 89.65
# Batch accuracy: 90.82
# Batch accuracy: 89.84
# Batch accuracy: 89.45
# Batch accuracy: 89.84
# Batch accuracy: 91.80
# Batch accuracy: 90.23
# Batch accuracy: 91.21
# Batch accuracy: 90.04
# Batch accuracy: 91.41
# Batch accuracy: 90.43
# Batch accuracy: 92.19
# Batch accuracy: 89.26
# Batch accuracy: 92.38
# Batch accuracy: 90.62
# Batch accuracy: 87.89
# Batch accuracy: 90.04
# Batch accuracy: 88.67
# Batch accuracy: 89.45
# Batch accuracy: 88.28
# Batch accuracy: 90.23
# Batch accuracy: 92.19
# Batch accuracy: 88.87
# Batch accuracy: 92.77
# Batch accuracy: 91.02
# Batch accuracy: 91.99
# Batch accuracy: 92.97
# Batch accuracy: 91.60
# Batch accuracy: 90.43
# Batch accuracy: 91.99
# Batch accuracy: 90.04
# Batch accuracy: 91.99
# Batch accuracy: 90.04
# Batch accuracy: 90.62
# Batch accuracy: 91.99
# Batch accuracy: 91.41
# Batch accuracy: 88.28
# Batch accuracy: 88.87
# Batch accuracy: 90.23
# Batch accuracy: 90.82
# Batch accuracy: 93.55
# Batch accuracy: 91.21
# Batch accuracy: 89.06
# Batch accuracy: 89.26
# Batch accuracy: 92.97
# Batch accuracy: 90.23
# Batch accuracy: 92.38
# Batch accuracy: 93.16
# Batch accuracy: 90.23
# Batch accuracy: 90.82
# Batch accuracy: 92.38
# Batch accuracy: 89.06
# Batch accuracy: 86.91
# Batch accuracy: 92.19
# Batch accuracy: 90.23
# Batch accuracy: 91.21
# Batch accuracy: 91.02
# Batch accuracy: 91.60
# Batch accuracy: 90.82
# Batch accuracy: 91.02
# Batch accuracy: 89.65
# Batch accuracy: 91.02
# Batch accuracy: 88.09
# Batch accuracy: 93.16
# Batch accuracy: 89.84
# Batch accuracy: 91.80
# Batch accuracy: 89.65
# Batch accuracy: 92.77
# Batch accuracy: 89.65
# Batch accuracy: 89.26
# Batch accuracy: 90.43
# Batch accuracy: 89.45
# Batch accuracy: 89.84
# Batch accuracy: 90.82
# Batch accuracy: 93.55
# Batch accuracy: 90.62
# Batch accuracy: 90.43
# Batch accuracy: 90.04
# Batch accuracy: 90.23
# Batch accuracy: 91.80
# Batch accuracy: 89.26
# Batch accuracy: 89.65
# Batch accuracy: 89.65
# Batch accuracy: 90.43
# Batch accuracy: 92.58
# Batch accuracy: 91.99
# Batch accuracy: 92.58
# Batch accuracy: 90.82
# Batch accuracy: 90.62
# Batch accuracy: 90.82
# Batch accuracy: 91.21
# Batch accuracy: 89.65
# Batch accuracy: 90.82
# Batch accuracy: 93.36
# Batch accuracy: 90.04
# Batch accuracy: 88.87
# Batch accuracy: 92.58
# Batch accuracy: 90.23
# Batch accuracy: 90.23
# Batch accuracy: 90.62
# Batch accuracy: 91.80
# Batch accuracy: 92.77
# Batch accuracy: 91.21
# Batch accuracy: 92.97
# Batch accuracy: 95.97
#   Accuracy: 90.76
# New best model, saving it!
#
# ======== Epoch 6 / 30 ========
# Training...
#   Batch    40  of    975.    .
#   step loss: 0.16
#   Batch    80  of    975.    .
#   step loss: 0.31
#   Batch   120  of    975.    .
#   step loss: 0.28
#   Batch   160  of    975.    .
#   step loss: 0.25
#   Batch   200  of    975.    .
#   step loss: 0.27
#   Batch   240  of    975.    .
#   step loss: 0.33
#   Batch   280  of    975.    .
#   step loss: 0.28
#   Batch   320  of    975.    .
#   step loss: 0.25
#   Batch   360  of    975.    .
#   step loss: 0.27
#   Batch   400  of    975.    .
#   step loss: 0.25
#   Batch   440  of    975.    .
#   step loss: 0.26
#   Batch   480  of    975.    .
#   step loss: 0.28
#   Batch   520  of    975.    .
#   step loss: 0.26
#   Batch   560  of    975.    .
#   step loss: 0.24
#   Batch   600  of    975.    .
#   step loss: 0.30
#   Batch   640  of    975.    .
#   step loss: 0.27
#   Batch   680  of    975.    .
#   step loss: 0.42
#   Batch   720  of    975.    .
#   step loss: 0.22
#   Batch   760  of    975.    .
#   step loss: 0.27
#   Batch   800  of    975.    .
#   step loss: 0.26
#   Batch   840  of    975.    .
#   step loss: 0.32
#   Batch   880  of    975.    .
#   step loss: 0.28
#   Batch   920  of    975.    .
#   step loss: 0.19
#   Batch   960  of    975.    .
#   step loss: 0.30
#
#   Average training loss: 0.28
#
# Running Validation...
# Batch accuracy: 93.16
# Batch accuracy: 92.19
# Batch accuracy: 88.28
# Batch accuracy: 92.38
# Batch accuracy: 90.04
# Batch accuracy: 92.58
# Batch accuracy: 90.23
# Batch accuracy: 92.97
# Batch accuracy: 87.89
# Batch accuracy: 90.23
# Batch accuracy: 89.26
# Batch accuracy: 91.21
# Batch accuracy: 92.58
# Batch accuracy: 91.60
# Batch accuracy: 91.99
# Batch accuracy: 90.62
# Batch accuracy: 92.77
# Batch accuracy: 90.04
# Batch accuracy: 91.60
# Batch accuracy: 90.82
# Batch accuracy: 89.26
# Batch accuracy: 91.41
# Batch accuracy: 90.82
# Batch accuracy: 93.75
# Batch accuracy: 88.67
# Batch accuracy: 90.62
# Batch accuracy: 90.23
# Batch accuracy: 90.04
# Batch accuracy: 90.43
# Batch accuracy: 92.58
# Batch accuracy: 91.80
# Batch accuracy: 89.45
# Batch accuracy: 90.62
# Batch accuracy: 89.84
# Batch accuracy: 89.84
# Batch accuracy: 91.02
# Batch accuracy: 90.82
# Batch accuracy: 91.80
# Batch accuracy: 89.65
# Batch accuracy: 89.65
# Batch accuracy: 91.99
# Batch accuracy: 91.99
# Batch accuracy: 92.77
# Batch accuracy: 91.21
# Batch accuracy: 92.19
# Batch accuracy: 91.41
# Batch accuracy: 87.70
# Batch accuracy: 86.91
# Batch accuracy: 93.55
# Batch accuracy: 90.82
# Batch accuracy: 89.06
# Batch accuracy: 89.06
# Batch accuracy: 89.65
# Batch accuracy: 88.09
# Batch accuracy: 91.60
# Batch accuracy: 90.82
# Batch accuracy: 89.65
# Batch accuracy: 90.62
# Batch accuracy: 90.82
# Batch accuracy: 89.26
# Batch accuracy: 93.36
# Batch accuracy: 91.21
# Batch accuracy: 89.84
# Batch accuracy: 90.62
# Batch accuracy: 91.99
# Batch accuracy: 89.26
# Batch accuracy: 90.23
# Batch accuracy: 92.38
# Batch accuracy: 91.21
# Batch accuracy: 91.41
# Batch accuracy: 92.38
# Batch accuracy: 89.26
# Batch accuracy: 92.19
# Batch accuracy: 90.23
# Batch accuracy: 91.02
# Batch accuracy: 90.82
# Batch accuracy: 89.84
# Batch accuracy: 92.77
# Batch accuracy: 89.26
# Batch accuracy: 91.21
# Batch accuracy: 91.41
# Batch accuracy: 93.95
# Batch accuracy: 92.19
# Batch accuracy: 90.82
# Batch accuracy: 90.62
# Batch accuracy: 90.82
# Batch accuracy: 93.75
# Batch accuracy: 91.02
# Batch accuracy: 92.38
# Batch accuracy: 90.04
# Batch accuracy: 92.38
# Batch accuracy: 93.55
# Batch accuracy: 93.36
# Batch accuracy: 90.23
# Batch accuracy: 90.82
# Batch accuracy: 91.02
# Batch accuracy: 91.21
# Batch accuracy: 90.04
# Batch accuracy: 89.65
# Batch accuracy: 92.19
# Batch accuracy: 91.99
# Batch accuracy: 90.04
# Batch accuracy: 91.02
# Batch accuracy: 91.80
# Batch accuracy: 89.26
# Batch accuracy: 92.97
# Batch accuracy: 89.65
# Batch accuracy: 90.43
# Batch accuracy: 90.32
#   Accuracy: 90.95
# New best model, saving it!
#
# ======== Epoch 7 / 30 ========
# Training...
#   Batch    40  of    975.    .
#   step loss: 0.27
#   Batch    80  of    975.    .
#   step loss: 0.16
#   Batch   120  of    975.    .
#   step loss: 0.20
#   Batch   160  of    975.    .
#   step loss: 0.29
#   Batch   200  of    975.    .
#   step loss: 0.27
#   Batch   240  of    975.    .
#   step loss: 0.20
#   Batch   280  of    975.    .
#   step loss: 0.29
#   Batch   320  of    975.    .
#   step loss: 0.31
#   Batch   360  of    975.    .
#   step loss: 0.21
#   Batch   400  of    975.    .
#   step loss: 0.31
#   Batch   440  of    975.    .
#   step loss: 0.29
#   Batch   480  of    975.    .
#   step loss: 0.36
#   Batch   520  of    975.    .
#   step loss: 0.28
#   Batch   560  of    975.    .
#   step loss: 0.22
#   Batch   600  of    975.    .
#   step loss: 0.33
#   Batch   640  of    975.    .
#   step loss: 0.24
#   Batch   680  of    975.    .
#   step loss: 0.21
#   Batch   720  of    975.    .
#   step loss: 0.26
#   Batch   760  of    975.    .
#   step loss: 0.27
#   Batch   800  of    975.    .
#   step loss: 0.26
#   Batch   840  of    975.    .
#   step loss: 0.27
#   Batch   880  of    975.    .
#   step loss: 0.36
#   Batch   920  of    975.    .
#   step loss: 0.36
#   Batch   960  of    975.    .
#   step loss: 0.20
#
#   Average training loss: 0.26
#
# Running Validation...
# Batch accuracy: 92.38
# Batch accuracy: 91.80
# Batch accuracy: 90.62
# Batch accuracy: 91.60
# Batch accuracy: 91.41
# Batch accuracy: 90.62
# Batch accuracy: 91.41
# Batch accuracy: 90.82
# Batch accuracy: 92.77
# Batch accuracy: 89.06
# Batch accuracy: 92.19
# Batch accuracy: 90.82
# Batch accuracy: 91.41
# Batch accuracy: 90.43
# Batch accuracy: 91.60
# Batch accuracy: 91.02
# Batch accuracy: 90.23
# Batch accuracy: 89.45
# Batch accuracy: 90.62
# Batch accuracy: 89.45
# Batch accuracy: 91.60
# Batch accuracy: 91.02
# Batch accuracy: 89.65
# Batch accuracy: 90.04
# Batch accuracy: 90.04
# Batch accuracy: 91.99
# Batch accuracy: 91.41
# Batch accuracy: 89.84
# Batch accuracy: 92.19
# Batch accuracy: 91.41
# Batch accuracy: 91.41
# Batch accuracy: 90.04
# Batch accuracy: 89.45
# Batch accuracy: 91.02
# Batch accuracy: 91.80
# Batch accuracy: 91.02
# Batch accuracy: 91.21
# Batch accuracy: 88.48
# Batch accuracy: 93.36
# Batch accuracy: 92.19
# Batch accuracy: 91.60
# Batch accuracy: 90.43
# Batch accuracy: 91.80
# Batch accuracy: 90.62
# Batch accuracy: 90.04
# Batch accuracy: 90.23
# Batch accuracy: 90.43
# Batch accuracy: 92.19
# Batch accuracy: 90.04
# Batch accuracy: 91.60
# Batch accuracy: 93.36
# Batch accuracy: 93.36
# Batch accuracy: 91.41
# Batch accuracy: 90.43
# Batch accuracy: 90.43
# Batch accuracy: 91.02
# Batch accuracy: 88.48
# Batch accuracy: 90.23
# Batch accuracy: 90.62
# Batch accuracy: 91.80
# Batch accuracy: 91.41
# Batch accuracy: 91.99
# Batch accuracy: 88.87
# Batch accuracy: 90.04
# Batch accuracy: 91.80
# Batch accuracy: 91.80
# Batch accuracy: 90.82
# Batch accuracy: 89.26
# Batch accuracy: 89.45
# Batch accuracy: 89.45
# Batch accuracy: 88.67
# Batch accuracy: 90.43
# Batch accuracy: 93.16
# Batch accuracy: 93.95
# Batch accuracy: 91.99
# Batch accuracy: 91.99
# Batch accuracy: 93.75
# Batch accuracy: 90.23
# Batch accuracy: 91.99
# Batch accuracy: 90.04
# Batch accuracy: 92.38
# Batch accuracy: 91.02
# Batch accuracy: 92.38
# Batch accuracy: 93.16
# Batch accuracy: 92.58
# Batch accuracy: 92.77
# Batch accuracy: 92.19
# Batch accuracy: 91.41
# Batch accuracy: 87.30
# Batch accuracy: 89.84
# Batch accuracy: 90.62
# Batch accuracy: 90.43
# Batch accuracy: 91.02
# Batch accuracy: 90.82
# Batch accuracy: 92.97
# Batch accuracy: 88.28
# Batch accuracy: 92.77
# Batch accuracy: 90.82
# Batch accuracy: 89.65
# Batch accuracy: 89.84
# Batch accuracy: 93.36
# Batch accuracy: 91.60
# Batch accuracy: 91.80
# Batch accuracy: 91.21
# Batch accuracy: 90.62
# Batch accuracy: 91.41
# Batch accuracy: 89.84
# Batch accuracy: 92.19
# Batch accuracy: 95.16
#   Accuracy: 91.10
# New best model, saving it!
#
# ======== Epoch 8 / 30 ========
# Training...
#   Batch    40  of    975.    .
#   step loss: 0.19
#   Batch    80  of    975.    .
#   step loss: 0.23
#   Batch   120  of    975.    .
#   step loss: 0.19
#   Batch   160  of    975.    .
#   step loss: 0.22
#   Batch   200  of    975.    .
#   step loss: 0.27
#   Batch   240  of    975.    .
#   step loss: 0.17
#   Batch   280  of    975.    .
#   step loss: 0.15
#   Batch   320  of    975.    .
#   step loss: 0.24
#   Batch   360  of    975.    .
#   step loss: 0.20
#   Batch   400  of    975.    .
#   step loss: 0.26
#   Batch   440  of    975.    .
#   step loss: 0.27
#   Batch   480  of    975.    .
#   step loss: 0.27
#   Batch   520  of    975.    .
#   step loss: 0.24
#   Batch   560  of    975.    .
#   step loss: 0.29
#   Batch   600  of    975.    .
#   step loss: 0.25
#   Batch   640  of    975.    .
#   step loss: 0.25
#   Batch   680  of    975.    .
#   step loss: 0.26
#   Batch   720  of    975.    .
#   step loss: 0.22
#   Batch   760  of    975.    .
#   step loss: 0.20
#   Batch   800  of    975.    .
#   step loss: 0.39
#   Batch   840  of    975.    .
#   step loss: 0.28
#   Batch   880  of    975.    .
#   step loss: 0.34
#   Batch   920  of    975.    .
#   step loss: 0.25
#   Batch   960  of    975.    .
#   step loss: 0.27
#
#   Average training loss: 0.24
#
# Running Validation...
# Batch accuracy: 91.41
# Batch accuracy: 93.55
# Batch accuracy: 91.21
# Batch accuracy: 92.38
# Batch accuracy: 90.62
# Batch accuracy: 91.60
# Batch accuracy: 90.43
# Batch accuracy: 89.65
# Batch accuracy: 88.67
# Batch accuracy: 89.65
# Batch accuracy: 91.80
# Batch accuracy: 88.67
# Batch accuracy: 92.19
# Batch accuracy: 89.84
# Batch accuracy: 88.09
# Batch accuracy: 92.38
# Batch accuracy: 89.65
# Batch accuracy: 91.02
# Batch accuracy: 93.16
# Batch accuracy: 91.80
# Batch accuracy: 90.62
# Batch accuracy: 91.21
# Batch accuracy: 91.41
# Batch accuracy: 91.99
# Batch accuracy: 91.02
# Batch accuracy: 88.87
# Batch accuracy: 91.21
# Batch accuracy: 91.99
# Batch accuracy: 90.82
# Batch accuracy: 90.62
# Batch accuracy: 88.87
# Batch accuracy: 90.43
# Batch accuracy: 91.99
# Batch accuracy: 91.80
# Batch accuracy: 92.19
# Batch accuracy: 90.23
# Batch accuracy: 90.62
# Batch accuracy: 93.36
# Batch accuracy: 92.97
# Batch accuracy: 90.43
# Batch accuracy: 88.48
# Batch accuracy: 91.41
# Batch accuracy: 90.23
# Batch accuracy: 91.02
# Batch accuracy: 91.60
# Batch accuracy: 90.82
# Batch accuracy: 91.21
# Batch accuracy: 91.60
# Batch accuracy: 91.21
# Batch accuracy: 89.26
# Batch accuracy: 91.41
# Batch accuracy: 91.41
# Batch accuracy: 91.80
# Batch accuracy: 91.60
# Batch accuracy: 90.82
# Batch accuracy: 91.99
# Batch accuracy: 91.60
# Batch accuracy: 90.23
# Batch accuracy: 92.77
# Batch accuracy: 91.02
# Batch accuracy: 88.67
# Batch accuracy: 91.99
# Batch accuracy: 91.21
# Batch accuracy: 92.77
# Batch accuracy: 93.36
# Batch accuracy: 89.26
# Batch accuracy: 90.82
# Batch accuracy: 91.21
# Batch accuracy: 91.02
# Batch accuracy: 92.38
# Batch accuracy: 89.84
# Batch accuracy: 93.16
# Batch accuracy: 91.41
# Batch accuracy: 89.45
# Batch accuracy: 91.99
# Batch accuracy: 90.04
# Batch accuracy: 91.41
# Batch accuracy: 88.67
# Batch accuracy: 91.60
# Batch accuracy: 90.04
# Batch accuracy: 91.99
# Batch accuracy: 92.97
# Batch accuracy: 92.77
# Batch accuracy: 91.21
# Batch accuracy: 90.43
# Batch accuracy: 91.99
# Batch accuracy: 91.02
# Batch accuracy: 91.99
# Batch accuracy: 92.19
# Batch accuracy: 92.38
# Batch accuracy: 90.62
# Batch accuracy: 92.58
# Batch accuracy: 92.38
# Batch accuracy: 93.16
# Batch accuracy: 91.02
# Batch accuracy: 90.62
# Batch accuracy: 91.02
# Batch accuracy: 90.23
# Batch accuracy: 91.60
# Batch accuracy: 91.21
# Batch accuracy: 91.02
# Batch accuracy: 92.77
# Batch accuracy: 91.80
# Batch accuracy: 91.60
# Batch accuracy: 91.41
# Batch accuracy: 90.23
# Batch accuracy: 91.99
# Batch accuracy: 90.04
# Batch accuracy: 90.32
#   Accuracy: 91.16
# New best model, saving it!
#
# ======== Epoch 9 / 30 ========
# Training...
#   Batch    40  of    975.    .
#   step loss: 0.23
#   Batch    80  of    975.    .
#   step loss: 0.17
#   Batch   120  of    975.    .
#   step loss: 0.25
#   Batch   160  of    975.    .
#   step loss: 0.28
#   Batch   200  of    975.    .
#   step loss: 0.19
#   Batch   240  of    975.    .
#   step loss: 0.29
#   Batch   280  of    975.    .
#   step loss: 0.23
#   Batch   320  of    975.    .
#   step loss: 0.19
#   Batch   360  of    975.    .
#   step loss: 0.24
#   Batch   400  of    975.    .
#   step loss: 0.26
#   Batch   440  of    975.    .
#   step loss: 0.21
#   Batch   480  of    975.    .
#   step loss: 0.24
#   Batch   520  of    975.    .
#   step loss: 0.22
#   Batch   560  of    975.    .
#   step loss: 0.31
#   Batch   600  of    975.    .
#   step loss: 0.23
#   Batch   640  of    975.    .
#   step loss: 0.25
#   Batch   680  of    975.    .
#   step loss: 0.18
#   Batch   720  of    975.    .
#   step loss: 0.15
#   Batch   760  of    975.    .
#   step loss: 0.25
#   Batch   800  of    975.    .
#   step loss: 0.30
#   Batch   840  of    975.    .
#   step loss: 0.17
#   Batch   880  of    975.    .
#   step loss: 0.17
#   Batch   920  of    975.    .
#   step loss: 0.24
#   Batch   960  of    975.    .
#   step loss: 0.28
#
#   Average training loss: 0.23
#
# Running Validation...
# Batch accuracy: 90.62
# Batch accuracy: 89.06
# Batch accuracy: 91.21
# Batch accuracy: 90.82
# Batch accuracy: 91.80
# Batch accuracy: 90.43
# Batch accuracy: 88.67
# Batch accuracy: 92.77
# Batch accuracy: 91.21
# Batch accuracy: 91.41
# Batch accuracy: 91.41
# Batch accuracy: 91.80
# Batch accuracy: 91.80
# Batch accuracy: 90.82
# Batch accuracy: 92.19
# Batch accuracy: 88.67
# Batch accuracy: 90.82
# Batch accuracy: 90.43
# Batch accuracy: 91.21
# Batch accuracy: 90.23
# Batch accuracy: 92.19
# Batch accuracy: 90.43
# Batch accuracy: 91.60
# Batch accuracy: 89.65
# Batch accuracy: 90.04
# Batch accuracy: 91.80
# Batch accuracy: 92.38
# Batch accuracy: 87.89
# Batch accuracy: 91.99
# Batch accuracy: 92.19
# Batch accuracy: 90.23
# Batch accuracy: 90.23
# Batch accuracy: 90.04
# Batch accuracy: 91.41
# Batch accuracy: 89.06
# Batch accuracy: 89.65
# Batch accuracy: 90.43
# Batch accuracy: 92.38
# Batch accuracy: 90.43
# Batch accuracy: 92.19
# Batch accuracy: 90.82
# Batch accuracy: 92.58
# Batch accuracy: 90.43
# Batch accuracy: 88.87
# Batch accuracy: 89.26
# Batch accuracy: 90.23
# Batch accuracy: 91.60
# Batch accuracy: 89.06
# Batch accuracy: 91.60
# Batch accuracy: 91.41
# Batch accuracy: 90.62
# Batch accuracy: 91.99
# Batch accuracy: 88.87
# Batch accuracy: 88.67
# Batch accuracy: 89.45
# Batch accuracy: 89.26
# Batch accuracy: 91.21
# Batch accuracy: 90.43
# Batch accuracy: 92.77
# Batch accuracy: 92.97
# Batch accuracy: 92.58
# Batch accuracy: 91.60
# Batch accuracy: 92.19
# Batch accuracy: 91.80
# Batch accuracy: 91.60
# Batch accuracy: 89.45
# Batch accuracy: 91.41
# Batch accuracy: 90.23
# Batch accuracy: 91.99
# Batch accuracy: 92.38
# Batch accuracy: 90.43
# Batch accuracy: 92.38
# Batch accuracy: 91.21
# Batch accuracy: 94.53
# Batch accuracy: 88.67
# Batch accuracy: 91.60
# Batch accuracy: 92.38
# Batch accuracy: 90.04
# Batch accuracy: 90.23
# Batch accuracy: 91.80
# Batch accuracy: 91.99
# Batch accuracy: 90.62
# Batch accuracy: 91.21
# Batch accuracy: 93.16
# Batch accuracy: 89.06
# Batch accuracy: 93.55
# Batch accuracy: 90.43
# Batch accuracy: 91.80
# Batch accuracy: 91.41
# Batch accuracy: 89.65
# Batch accuracy: 91.99
# Batch accuracy: 89.06
# Batch accuracy: 91.80
# Batch accuracy: 91.41
# Batch accuracy: 90.82
# Batch accuracy: 91.80
# Batch accuracy: 91.41
# Batch accuracy: 90.23
# Batch accuracy: 91.99
# Batch accuracy: 92.38
# Batch accuracy: 90.04
# Batch accuracy: 91.80
# Batch accuracy: 91.60
# Batch accuracy: 89.65
# Batch accuracy: 90.04
# Batch accuracy: 91.41
# Batch accuracy: 89.84
# Batch accuracy: 91.02
# Batch accuracy: 93.55
#   Accuracy: 91.00
# The model does not improve for 1 epochs!
#
# ======== Epoch 10 / 30 ========
# Training...
#   Batch    40  of    975.    .
#   step loss: 0.14
#   Batch    80  of    975.    .
#   step loss: 0.18
#   Batch   120  of    975.    .
#   step loss: 0.18
#   Batch   160  of    975.    .
#   step loss: 0.26
#   Batch   200  of    975.    .
#   step loss: 0.20
#   Batch   240  of    975.    .
#   step loss: 0.22
#   Batch   280  of    975.    .
#   step loss: 0.17
#   Batch   320  of    975.    .
#   step loss: 0.21
#   Batch   360  of    975.    .
#   step loss: 0.22
#   Batch   400  of    975.    .
#   step loss: 0.24
#   Batch   440  of    975.    .
#   step loss: 0.24
#   Batch   480  of    975.    .
#   step loss: 0.16
#   Batch   520  of    975.    .
#   step loss: 0.27
#   Batch   560  of    975.    .
#   step loss: 0.26
#   Batch   600  of    975.    .
#   step loss: 0.23
#   Batch   640  of    975.    .
#   step loss: 0.17
#   Batch   680  of    975.    .
#   step loss: 0.30
#   Batch   720  of    975.    .
#   step loss: 0.17
#   Batch   760  of    975.    .
#   step loss: 0.23
#   Batch   800  of    975.    .
#   step loss: 0.18
#   Batch   840  of    975.    .
#   step loss: 0.25
#   Batch   880  of    975.    .
#   step loss: 0.36
#   Batch   920  of    975.    .
#   step loss: 0.20
#   Batch   960  of    975.    .
#   step loss: 0.27
#
#   Average training loss: 0.22
#
# Running Validation...
# Batch accuracy: 93.36
# Batch accuracy: 91.21
# Batch accuracy: 92.19
# Batch accuracy: 91.41
# Batch accuracy: 91.99
# Batch accuracy: 91.41
# Batch accuracy: 91.60
# Batch accuracy: 93.95
# Batch accuracy: 91.02
# Batch accuracy: 91.80
# Batch accuracy: 91.21
# Batch accuracy: 92.38
# Batch accuracy: 91.60
# Batch accuracy: 90.04
# Batch accuracy: 90.23
# Batch accuracy: 91.41
# Batch accuracy: 91.60
# Batch accuracy: 92.58
# Batch accuracy: 90.82
# Batch accuracy: 89.84
# Batch accuracy: 89.84
# Batch accuracy: 92.38
# Batch accuracy: 90.62
# Batch accuracy: 91.21
# Batch accuracy: 90.23
# Batch accuracy: 91.02
# Batch accuracy: 92.58
# Batch accuracy: 90.04
# Batch accuracy: 90.23
# Batch accuracy: 92.77
# Batch accuracy: 90.62
# Batch accuracy: 90.04
# Batch accuracy: 90.62
# Batch accuracy: 90.62
# Batch accuracy: 92.19
# Batch accuracy: 90.62
# Batch accuracy: 91.80
# Batch accuracy: 91.02
# Batch accuracy: 91.80
# Batch accuracy: 94.14
# Batch accuracy: 90.62
# Batch accuracy: 92.58
# Batch accuracy: 90.43
# Batch accuracy: 90.43
# Batch accuracy: 91.60
# Batch accuracy: 88.87
# Batch accuracy: 90.62
# Batch accuracy: 89.06
# Batch accuracy: 89.65
# Batch accuracy: 93.16
# Batch accuracy: 90.62
# Batch accuracy: 91.80
# Batch accuracy: 91.02
# Batch accuracy: 88.67
# Batch accuracy: 90.04
# Batch accuracy: 92.19
# Batch accuracy: 88.48
# Batch accuracy: 91.99
# Batch accuracy: 90.23
# Batch accuracy: 87.30
# Batch accuracy: 91.02
# Batch accuracy: 90.04
# Batch accuracy: 92.38
# Batch accuracy: 90.82
# Batch accuracy: 89.45
# Batch accuracy: 90.43
# Batch accuracy: 91.99
# Batch accuracy: 91.80
# Batch accuracy: 90.43
# Batch accuracy: 90.04
# Batch accuracy: 90.82
# Batch accuracy: 90.62
# Batch accuracy: 90.04
# Batch accuracy: 91.41
# Batch accuracy: 91.80
# Batch accuracy: 90.82
# Batch accuracy: 92.38
# Batch accuracy: 91.80
# Batch accuracy: 90.82
# Batch accuracy: 91.99
# Batch accuracy: 88.28
# Batch accuracy: 92.19
# Batch accuracy: 89.65
# Batch accuracy: 91.21
# Batch accuracy: 90.62
# Batch accuracy: 90.43
# Batch accuracy: 92.19
# Batch accuracy: 89.84
# Batch accuracy: 91.02
# Batch accuracy: 91.21
# Batch accuracy: 91.02
# Batch accuracy: 91.60
# Batch accuracy: 90.43
# Batch accuracy: 91.41
# Batch accuracy: 90.82
# Batch accuracy: 90.62
# Batch accuracy: 90.43
# Batch accuracy: 91.02
# Batch accuracy: 92.38
# Batch accuracy: 93.75
# Batch accuracy: 90.62
# Batch accuracy: 89.06
# Batch accuracy: 89.45
# Batch accuracy: 92.19
# Batch accuracy: 90.62
# Batch accuracy: 91.41
# Batch accuracy: 90.23
# Batch accuracy: 92.77
# Batch accuracy: 94.35
#   Accuracy: 91.07
# The model does not improve for 2 epochs!
# Epoch    10: reducing learning rate of group 0 to 1.0000e-04.
#
# ======== Epoch 11 / 30 ========
# Training...
#   Batch    40  of    975.    .
#   step loss: 0.18
#   Batch    80  of    975.    .
#   step loss: 0.21
#   Batch   120  of    975.    .
#   step loss: 0.16
#   Batch   160  of    975.    .
#   step loss: 0.20
#   Batch   200  of    975.    .
#   step loss: 0.19
#   Batch   240  of    975.    .
#   step loss: 0.13
#   Batch   280  of    975.    .
#   step loss: 0.14
#   Batch   320  of    975.    .
#   step loss: 0.17
#   Batch   360  of    975.    .
#   step loss: 0.13
#   Batch   400  of    975.    .
#   step loss: 0.16
#   Batch   440  of    975.    .
#   step loss: 0.15
#   Batch   480  of    975.    .
#   step loss: 0.14
#   Batch   520  of    975.    .
#   step loss: 0.22
#   Batch   560  of    975.    .
#   step loss: 0.13
#   Batch   600  of    975.    .
#   step loss: 0.14
#   Batch   640  of    975.    .
#   step loss: 0.16
#   Batch   680  of    975.    .
#   step loss: 0.11
#   Batch   720  of    975.    .
#   step loss: 0.19
#   Batch   760  of    975.    .
#   step loss: 0.12
#   Batch   800  of    975.    .
#   step loss: 0.14
#   Batch   840  of    975.    .
#   step loss: 0.11
#   Batch   880  of    975.    .
#   step loss: 0.12
#   Batch   920  of    975.    .
#   step loss: 0.13
#   Batch   960  of    975.    .
#   step loss: 0.14
#
#   Average training loss: 0.15
#
# Running Validation...
# Batch accuracy: 92.19
# Batch accuracy: 91.41
# Batch accuracy: 92.97
# Batch accuracy: 90.04
# Batch accuracy: 90.43
# Batch accuracy: 91.60
# Batch accuracy: 92.58
# Batch accuracy: 90.43
# Batch accuracy: 92.58
# Batch accuracy: 91.21
# Batch accuracy: 93.95
# Batch accuracy: 91.21
# Batch accuracy: 91.41
# Batch accuracy: 93.16
# Batch accuracy: 92.77
# Batch accuracy: 89.65
# Batch accuracy: 95.12
# Batch accuracy: 93.36
# Batch accuracy: 92.38
# Batch accuracy: 93.16
# Batch accuracy: 91.99
# Batch accuracy: 94.73
# Batch accuracy: 90.43
# Batch accuracy: 90.04
# Batch accuracy: 92.38
# Batch accuracy: 92.19
# Batch accuracy: 93.95
# Batch accuracy: 91.02
# Batch accuracy: 91.60
# Batch accuracy: 92.77
# Batch accuracy: 93.16
# Batch accuracy: 92.58
# Batch accuracy: 90.82
# Batch accuracy: 91.80
# Batch accuracy: 91.80
# Batch accuracy: 92.19
# Batch accuracy: 92.77
# Batch accuracy: 93.16
# Batch accuracy: 91.99
# Batch accuracy: 91.41
# Batch accuracy: 93.55
# Batch accuracy: 91.99
# Batch accuracy: 90.04
# Batch accuracy: 90.23
# Batch accuracy: 91.60
# Batch accuracy: 91.41
# Batch accuracy: 92.58
# Batch accuracy: 94.34
# Batch accuracy: 92.19
# Batch accuracy: 91.80
# Batch accuracy: 90.82
# Batch accuracy: 93.16
# Batch accuracy: 91.21
# Batch accuracy: 91.80
# Batch accuracy: 94.73
# Batch accuracy: 92.38
# Batch accuracy: 92.38
# Batch accuracy: 91.21
# Batch accuracy: 91.60
# Batch accuracy: 92.19
# Batch accuracy: 91.80
# Batch accuracy: 92.38
# Batch accuracy: 93.16
# Batch accuracy: 93.75
# Batch accuracy: 93.16
# Batch accuracy: 91.41
# Batch accuracy: 89.65
# Batch accuracy: 92.77
# Batch accuracy: 90.82
# Batch accuracy: 92.77
# Batch accuracy: 91.02
# Batch accuracy: 91.21
# Batch accuracy: 91.60
# Batch accuracy: 91.60
# Batch accuracy: 89.45
# Batch accuracy: 91.21
# Batch accuracy: 90.82
# Batch accuracy: 91.21
# Batch accuracy: 91.02
# Batch accuracy: 89.26
# Batch accuracy: 92.77
# Batch accuracy: 90.62
# Batch accuracy: 91.41
# Batch accuracy: 90.82
# Batch accuracy: 92.19
# Batch accuracy: 91.99
# Batch accuracy: 90.82
# Batch accuracy: 91.60
# Batch accuracy: 92.58
# Batch accuracy: 91.80
# Batch accuracy: 91.02
# Batch accuracy: 92.58
# Batch accuracy: 92.19
# Batch accuracy: 92.38
# Batch accuracy: 92.38
# Batch accuracy: 89.65
# Batch accuracy: 91.99
# Batch accuracy: 91.60
# Batch accuracy: 90.04
# Batch accuracy: 93.75
# Batch accuracy: 90.04
# Batch accuracy: 92.77
# Batch accuracy: 91.99
# Batch accuracy: 92.58
# Batch accuracy: 90.82
# Batch accuracy: 91.41
# Batch accuracy: 91.60
# Batch accuracy: 92.38
# Batch accuracy: 93.55
#   Accuracy: 91.90
# New best model, saving it!
#
# ======== Epoch 12 / 30 ========
# Training...
#   Batch    40  of    975.    .
#   step loss: 0.12
#   Batch    80  of    975.    .
#   step loss: 0.11
#   Batch   120  of    975.    .
#   step loss: 0.11
#   Batch   160  of    975.    .
#   step loss: 0.10
#   Batch   200  of    975.    .
#   step loss: 0.18
#   Batch   240  of    975.    .
#   step loss: 0.10
#   Batch   280  of    975.    .
#   step loss: 0.14
#   Batch   320  of    975.    .
#   step loss: 0.17
#   Batch   360  of    975.    .
#   step loss: 0.12
#   Batch   400  of    975.    .
#   step loss: 0.12
#   Batch   440  of    975.    .
#   step loss: 0.13
#   Batch   480  of    975.    .
#   step loss: 0.14
#   Batch   520  of    975.    .
#   step loss: 0.09
#   Batch   560  of    975.    .
#   step loss: 0.13
#   Batch   600  of    975.    .
#   step loss: 0.12
#   Batch   640  of    975.    .
#   step loss: 0.09
#   Batch   680  of    975.    .
#   step loss: 0.12
#   Batch   720  of    975.    .
#   step loss: 0.14
#   Batch   760  of    975.    .
#   step loss: 0.09
#   Batch   800  of    975.    .
#   step loss: 0.13
#   Batch   840  of    975.    .
#   step loss: 0.17
#   Batch   880  of    975.    .
#   step loss: 0.12
#   Batch   920  of    975.    .
#   step loss: 0.11
#   Batch   960  of    975.    .
#   step loss: 0.09
#
#   Average training loss: 0.14
#
# Running Validation...
# Batch accuracy: 93.95
# Batch accuracy: 88.67
# Batch accuracy: 90.23
# Batch accuracy: 92.19
# Batch accuracy: 91.60
# Batch accuracy: 90.62
# Batch accuracy: 91.60
# Batch accuracy: 91.99
# Batch accuracy: 90.23
# Batch accuracy: 90.82
# Batch accuracy: 91.99
# Batch accuracy: 92.97
# Batch accuracy: 93.55
# Batch accuracy: 91.21
# Batch accuracy: 92.58
# Batch accuracy: 91.80
# Batch accuracy: 90.82
# Batch accuracy: 91.80
# Batch accuracy: 91.99
# Batch accuracy: 93.95
# Batch accuracy: 93.55
# Batch accuracy: 93.55
# Batch accuracy: 92.97
# Batch accuracy: 92.38
# Batch accuracy: 93.16
# Batch accuracy: 90.82
# Batch accuracy: 93.16
# Batch accuracy: 94.53
# Batch accuracy: 91.21
# Batch accuracy: 89.06
# Batch accuracy: 91.99
# Batch accuracy: 91.99
# Batch accuracy: 91.21
# Batch accuracy: 91.21
# Batch accuracy: 92.58
# Batch accuracy: 89.84
# Batch accuracy: 91.99
# Batch accuracy: 93.36
# Batch accuracy: 93.95
# Batch accuracy: 92.38
# Batch accuracy: 94.53
# Batch accuracy: 92.19
# Batch accuracy: 91.99
# Batch accuracy: 92.97
# Batch accuracy: 91.21
# Batch accuracy: 91.41
# Batch accuracy: 90.23
# Batch accuracy: 90.62
# Batch accuracy: 91.21
# Batch accuracy: 91.99
# Batch accuracy: 93.36
# Batch accuracy: 91.60
# Batch accuracy: 91.41
# Batch accuracy: 92.77
# Batch accuracy: 92.77
# Batch accuracy: 92.77
# Batch accuracy: 93.16
# Batch accuracy: 92.38
# Batch accuracy: 91.99
# Batch accuracy: 90.82
# Batch accuracy: 91.41
# Batch accuracy: 91.60
# Batch accuracy: 91.21
# Batch accuracy: 92.38
# Batch accuracy: 92.19
# Batch accuracy: 91.41
# Batch accuracy: 91.21
# Batch accuracy: 91.02
# Batch accuracy: 91.21
# Batch accuracy: 90.23
# Batch accuracy: 92.19
# Batch accuracy: 90.62
# Batch accuracy: 91.80
# Batch accuracy: 92.38
# Batch accuracy: 92.97
# Batch accuracy: 92.58
# Batch accuracy: 91.21
# Batch accuracy: 91.41
# Batch accuracy: 92.77
# Batch accuracy: 90.43
# Batch accuracy: 93.55
# Batch accuracy: 90.04
# Batch accuracy: 91.02
# Batch accuracy: 91.80
# Batch accuracy: 90.82
# Batch accuracy: 92.58
# Batch accuracy: 93.36
# Batch accuracy: 91.41
# Batch accuracy: 92.58
# Batch accuracy: 92.77
# Batch accuracy: 90.82
# Batch accuracy: 93.36
# Batch accuracy: 92.19
# Batch accuracy: 89.65
# Batch accuracy: 91.02
# Batch accuracy: 92.19
# Batch accuracy: 91.99
# Batch accuracy: 92.19
# Batch accuracy: 90.23
# Batch accuracy: 94.53
# Batch accuracy: 90.43
# Batch accuracy: 90.62
# Batch accuracy: 93.55
# Batch accuracy: 90.62
# Batch accuracy: 92.19
# Batch accuracy: 91.99
# Batch accuracy: 92.58
# Batch accuracy: 92.19
# Batch accuracy: 92.74
#   Accuracy: 91.91
# New best model, saving it!
#
# ======== Epoch 13 / 30 ========
# Training...
#   Batch    40  of    975.    .
#   step loss: 0.13
#   Batch    80  of    975.    .
#   step loss: 0.14
#   Batch   120  of    975.    .
#   step loss: 0.10
#   Batch   160  of    975.    .
#   step loss: 0.12
#   Batch   200  of    975.    .
#   step loss: 0.11
#   Batch   240  of    975.    .
#   step loss: 0.13
#   Batch   280  of    975.    .
#   step loss: 0.12
#   Batch   320  of    975.    .
#   step loss: 0.10
#   Batch   360  of    975.    .
#   step loss: 0.08
#   Batch   400  of    975.    .
#   step loss: 0.14
#   Batch   440  of    975.    .
#   step loss: 0.12
#   Batch   480  of    975.    .
#   step loss: 0.16
#   Batch   520  of    975.    .
#   step loss: 0.09
#   Batch   560  of    975.    .
#   step loss: 0.14
#   Batch   600  of    975.    .
#   step loss: 0.10
#   Batch   640  of    975.    .
#   step loss: 0.15
#   Batch   680  of    975.    .
#   step loss: 0.20
#   Batch   720  of    975.    .
#   step loss: 0.11
#   Batch   760  of    975.    .
#   step loss: 0.13
#   Batch   800  of    975.    .
#   step loss: 0.11
#   Batch   840  of    975.    .
#   step loss: 0.13
#   Batch   880  of    975.    .
#   step loss: 0.11
#   Batch   920  of    975.    .
#   step loss: 0.16
#   Batch   960  of    975.    .
#   step loss: 0.13
#
#   Average training loss: 0.13
#
# Running Validation...
# Batch accuracy: 89.84
# Batch accuracy: 92.97
# Batch accuracy: 91.80
# Batch accuracy: 91.21
# Batch accuracy: 91.21
# Batch accuracy: 89.65
# Batch accuracy: 92.19
# Batch accuracy: 90.43
# Batch accuracy: 92.58
# Batch accuracy: 93.75
# Batch accuracy: 91.80
# Batch accuracy: 93.75
# Batch accuracy: 90.82
# Batch accuracy: 89.45
# Batch accuracy: 92.19
# Batch accuracy: 92.97
# Batch accuracy: 90.62
# Batch accuracy: 93.36
# Batch accuracy: 91.41
# Batch accuracy: 92.38
# Batch accuracy: 94.53
# Batch accuracy: 93.75
# Batch accuracy: 89.26
# Batch accuracy: 92.38
# Batch accuracy: 92.38
# Batch accuracy: 92.58
# Batch accuracy: 89.65
# Batch accuracy: 93.55
# Batch accuracy: 92.77
# Batch accuracy: 93.75
# Batch accuracy: 93.16
# Batch accuracy: 91.80
# Batch accuracy: 92.77
# Batch accuracy: 91.80
# Batch accuracy: 90.43
# Batch accuracy: 91.21
# Batch accuracy: 92.19
# Batch accuracy: 91.41
# Batch accuracy: 90.23
# Batch accuracy: 93.36
# Batch accuracy: 90.04
# Batch accuracy: 92.19
# Batch accuracy: 95.31
# Batch accuracy: 92.97
# Batch accuracy: 91.60
# Batch accuracy: 91.60
# Batch accuracy: 90.43
# Batch accuracy: 93.75
# Batch accuracy: 92.77
# Batch accuracy: 92.38
# Batch accuracy: 91.02
# Batch accuracy: 93.55
# Batch accuracy: 91.80
# Batch accuracy: 93.95
# Batch accuracy: 92.97
# Batch accuracy: 91.21
# Batch accuracy: 94.14
# Batch accuracy: 93.16
# Batch accuracy: 93.95
# Batch accuracy: 91.21
# Batch accuracy: 93.75
# Batch accuracy: 91.60
# Batch accuracy: 91.41
# Batch accuracy: 92.19
# Batch accuracy: 91.80
# Batch accuracy: 92.19
# Batch accuracy: 91.21
# Batch accuracy: 90.43
# ...
# Batch accuracy: 91.99
# Batch accuracy: 88.48
# Batch accuracy: 92.19
# Batch accuracy: 92.38
# Batch accuracy: 92.77
# Batch accuracy: 92.58
# Batch accuracy: 92.38
# Batch accuracy: 90.43
# Batch accuracy: 91.02
# Batch accuracy: 91.60
# Batch accuracy: 93.36
# Batch accuracy: 91.99
# Batch accuracy: 92.19
# Batch accuracy: 92.77
# Batch accuracy: 91.02
# Batch accuracy: 92.58
# Batch accuracy: 91.99
# Batch accuracy: 91.80
# Batch accuracy: 93.16
# Batch accuracy: 91.60
# Batch accuracy: 92.58
# Batch accuracy: 93.16
# Batch accuracy: 90.82
# Batch accuracy: 91.60
# Batch accuracy: 92.77
# Batch accuracy: 91.60
# Batch accuracy: 92.77
# Batch accuracy: 91.60
# Batch accuracy: 91.60
# Batch accuracy: 92.97
# Batch accuracy: 90.43
# Batch accuracy: 91.02
# Batch accuracy: 91.60
# Batch accuracy: 91.60
# Batch accuracy: 93.95
# Batch accuracy: 91.41
# Batch accuracy: 91.80
# Batch accuracy: 90.23
# Batch accuracy: 92.77
# Batch accuracy: 92.97
# Batch accuracy: 96.77
#   Accuracy: 92.06
# The model does not improve for 2 epochs!
#
# ======== Epoch 16 / 30 ========
# Training...
#   Batch    40  of    975.    .
#   step loss: 0.11
#   Batch    80  of    975.    .
#   step loss: 0.08
#   Batch   120  of    975.    .
#   step loss: 0.16
#   Batch   160  of    975.    .
#   step loss: 0.14
#   Batch   200  of    975.    .
#   step loss: 0.13
#   Batch   240  of    975.    .
#   step loss: 0.18
#   Batch   280  of    975.    .
#   step loss: 0.12
#   Batch   320  of    975.    .
#   step loss: 0.17
#   Batch   360  of    975.    .
#   step loss: 0.09
#   Batch   400  of    975.    .
#   step loss: 0.11
#   Batch   440  of    975.    .
#   step loss: 0.14
#   Batch   480  of    975.    .
#   step loss: 0.10
#   Batch   520  of    975.    .
#   step loss: 0.16
#   Batch   560  of    975.    .
#   step loss: 0.12
#   Batch   600  of    975.    .
#   step loss: 0.12
#   Batch   640  of    975.    .
#   step loss: 0.13
#   Batch   680  of    975.    .
#   step loss: 0.09
#   Batch   720  of    975.    .
#   step loss: 0.11
#   Batch   760  of    975.    .
#   step loss: 0.07
#   Batch   800  of    975.    .
#   step loss: 0.14
#   Batch   840  of    975.    .
#   step loss: 0.11
#   Batch   880  of    975.    .
#   step loss: 0.12
#   Batch   920  of    975.    .
#   step loss: 0.17
#   Batch   960  of    975.    .
#   step loss: 0.16
#
#   Average training loss: 0.12
#
# Running Validation...
# Batch accuracy: 90.62
# Batch accuracy: 93.16
# Batch accuracy: 90.82
# Batch accuracy: 91.41
# Batch accuracy: 92.77
# Batch accuracy: 91.60
# Batch accuracy: 92.38
# Batch accuracy: 93.16
# Batch accuracy: 91.99
# Batch accuracy: 91.21
# Batch accuracy: 90.62
# Batch accuracy: 95.12
# Batch accuracy: 91.21
# Batch accuracy: 91.21
# Batch accuracy: 90.62
# Batch accuracy: 92.38
# Batch accuracy: 95.51
# Batch accuracy: 93.75
# Batch accuracy: 91.80
# Batch accuracy: 90.04
# Batch accuracy: 92.19
# Batch accuracy: 90.82
# Batch accuracy: 91.60
# Batch accuracy: 92.58
# Batch accuracy: 91.60
# Batch accuracy: 93.75
# Batch accuracy: 92.97
# Batch accuracy: 92.38
# Batch accuracy: 89.65
# Batch accuracy: 93.36
# Batch accuracy: 93.16
# Batch accuracy: 90.82
# Batch accuracy: 92.38
# Batch accuracy: 93.36
# Batch accuracy: 90.04
# Batch accuracy: 92.77
# Batch accuracy: 91.60
# Batch accuracy: 92.58
# Batch accuracy: 93.75
# Batch accuracy: 91.21
# Batch accuracy: 93.55
# Batch accuracy: 94.92
# Batch accuracy: 92.19
# Batch accuracy: 91.41
# Batch accuracy: 93.55
# Batch accuracy: 89.65
# Batch accuracy: 92.38
# Batch accuracy: 90.23
# Batch accuracy: 93.36
# Batch accuracy: 91.80
# Batch accuracy: 91.21
# Batch accuracy: 89.65
# Batch accuracy: 91.80
# Batch accuracy: 93.95
# Batch accuracy: 89.45
# Batch accuracy: 91.41
# Batch accuracy: 93.75
# Batch accuracy: 92.58
# Batch accuracy: 92.38
# Batch accuracy: 91.60
# Batch accuracy: 90.62
# Batch accuracy: 92.58
# Batch accuracy: 92.58
# Batch accuracy: 91.21
# Batch accuracy: 91.99
# Batch accuracy: 92.38
# Batch accuracy: 91.60
# Batch accuracy: 90.82
# Batch accuracy: 92.58
# Batch accuracy: 91.21
# Batch accuracy: 93.16
# Batch accuracy: 91.99
# Batch accuracy: 92.77
# Batch accuracy: 91.41
# Batch accuracy: 94.14
# Batch accuracy: 91.60
# Batch accuracy: 93.16
# Batch accuracy: 93.16
# Batch accuracy: 92.19
# Batch accuracy: 91.60
# Batch accuracy: 92.19
# Batch accuracy: 92.77
# Batch accuracy: 94.14
# Batch accuracy: 90.62
# Batch accuracy: 91.80
# Batch accuracy: 91.99
# Batch accuracy: 91.80
# Batch accuracy: 92.97
# Batch accuracy: 91.21
# Batch accuracy: 91.60
# Batch accuracy: 91.21
# Batch accuracy: 90.43
# Batch accuracy: 90.82
# Batch accuracy: 92.19
# Batch accuracy: 91.02
# Batch accuracy: 92.38
# Batch accuracy: 91.99
# Batch accuracy: 90.62
# Batch accuracy: 90.82
# Batch accuracy: 89.65
# Batch accuracy: 91.99
# Batch accuracy: 90.62
# Batch accuracy: 89.65
# Batch accuracy: 91.60
# Batch accuracy: 92.19
# Batch accuracy: 91.80
# Batch accuracy: 92.19
# Batch accuracy: 92.97
# Batch accuracy: 90.32
#   Accuracy: 91.96
# The model does not improve for 3 epochs!
#
# ======== Epoch 17 / 30 ========
# Training...
#   Batch    40  of    975.    .
#   step loss: 0.07
#   Batch    80  of    975.    .
#   step loss: 0.08
#   Batch   120  of    975.    .
#   step loss: 0.15
#   Batch   160  of    975.    .
#   step loss: 0.09
#   Batch   200  of    975.    .
#   step loss: 0.07
#   Batch   240  of    975.    .
#   step loss: 0.09
#   Batch   280  of    975.    .
#   step loss: 0.12
#   Batch   320  of    975.    .
#   step loss: 0.07
#   Batch   360  of    975.    .
#   step loss: 0.13
#   Batch   400  of    975.    .
#   step loss: 0.08
#   Batch   440  of    975.    .
#   step loss: 0.14
#   Batch   480  of    975.    .
#   step loss: 0.08
#   Batch   520  of    975.    .
#   step loss: 0.12
#   Batch   560  of    975.    .
#   step loss: 0.10
#   Batch   600  of    975.    .
#   step loss: 0.13
#   Batch   640  of    975.    .
#   step loss: 0.18
#   Batch   680  of    975.    .
#   step loss: 0.11
#   Batch   720  of    975.    .
#   step loss: 0.12
#   Batch   760  of    975.    .
#   step loss: 0.11
#   Batch   800  of    975.    .
#   step loss: 0.11
#   Batch   840  of    975.    .
#   step loss: 0.07
#   Batch   880  of    975.    .
#   step loss: 0.11
#   Batch   920  of    975.    .
#   step loss: 0.10
#   Batch   960  of    975.    .
#   step loss: 0.14
#
#   Average training loss: 0.11
#
# Running Validation...
# Batch accuracy: 92.97
# Batch accuracy: 92.19
# Batch accuracy: 89.45
# Batch accuracy: 91.99
# Batch accuracy: 94.34
# Batch accuracy: 91.02
# Batch accuracy: 89.84
# Batch accuracy: 92.77
# Batch accuracy: 90.43
# Batch accuracy: 91.80
# Batch accuracy: 89.06
# Batch accuracy: 91.02
# Batch accuracy: 91.99
# Batch accuracy: 90.62
# Batch accuracy: 94.34
# Batch accuracy: 91.60
# Batch accuracy: 92.97
# Batch accuracy: 91.80
# Batch accuracy: 92.77
# Batch accuracy: 91.99
# Batch accuracy: 92.38
# Batch accuracy: 92.58
# Batch accuracy: 92.38
# Batch accuracy: 90.82
# Batch accuracy: 93.36
# Batch accuracy: 92.19
# Batch accuracy: 89.06
# Batch accuracy: 91.80
# Batch accuracy: 90.62
# Batch accuracy: 91.60
# Batch accuracy: 93.36
# Batch accuracy: 93.55
# Batch accuracy: 91.80
# Batch accuracy: 94.73
# Batch accuracy: 91.60
# Batch accuracy: 92.77
# Batch accuracy: 93.16
# Batch accuracy: 91.41
# Batch accuracy: 92.58
# Batch accuracy: 91.41
# Batch accuracy: 91.99
# Batch accuracy: 93.55
# Batch accuracy: 93.16
# Batch accuracy: 91.80
# Batch accuracy: 94.34
# Batch accuracy: 90.23
# Batch accuracy: 92.58
# Batch accuracy: 91.21
# Batch accuracy: 91.41
# Batch accuracy: 92.38
# Batch accuracy: 92.19
# Batch accuracy: 92.58
# Batch accuracy: 92.97
# Batch accuracy: 92.58
# Batch accuracy: 91.21
# Batch accuracy: 91.21
# Batch accuracy: 92.58
# Batch accuracy: 93.16
# Batch accuracy: 93.75
# Batch accuracy: 93.36
# Batch accuracy: 91.41
# Batch accuracy: 91.02
# Batch accuracy: 88.28
# Batch accuracy: 91.99
# Batch accuracy: 91.60
# Batch accuracy: 91.60
# Batch accuracy: 92.38
# Batch accuracy: 92.77
# Batch accuracy: 91.60
# Batch accuracy: 93.75
# Batch accuracy: 90.04
# Batch accuracy: 93.16
# Batch accuracy: 94.53
# Batch accuracy: 90.62
# Batch accuracy: 93.36
# Batch accuracy: 93.55
# Batch accuracy: 92.77
# Batch accuracy: 92.77
# Batch accuracy: 90.82
# Batch accuracy: 91.21
# Batch accuracy: 92.77
# Batch accuracy: 91.80
# Batch accuracy: 91.41
# Batch accuracy: 93.95
# Batch accuracy: 90.62
# Batch accuracy: 91.80
# Batch accuracy: 92.38
# Batch accuracy: 92.58
# Batch accuracy: 92.19
# Batch accuracy: 93.55
# Batch accuracy: 90.04
# Batch accuracy: 90.82
# Batch accuracy: 93.16
# Batch accuracy: 90.23
# Batch accuracy: 90.82
# Batch accuracy: 91.60
# Batch accuracy: 92.97
# Batch accuracy: 93.55
# Batch accuracy: 92.77
# Batch accuracy: 92.97
# Batch accuracy: 91.21
# Batch accuracy: 92.58
# Batch accuracy: 91.02
# Batch accuracy: 89.65
# Batch accuracy: 91.21
# Batch accuracy: 92.77
# Batch accuracy: 91.99
# Batch accuracy: 92.97
# Batch accuracy: 91.94
#   Accuracy: 92.05
# The model does not improve for 4 epochs!
#
# ======== Epoch 18 / 30 ========
# Training...
#   Batch    40  of    975.    .
#   step loss: 0.13
#   Batch    80  of    975.    .
#   step loss: 0.11
#   Batch   120  of    975.    .
#   step loss: 0.11
#   Batch   160  of    975.    .
#   step loss: 0.09
#   Batch   200  of    975.    .
#   step loss: 0.10
#   Batch   240  of    975.    .
#   step loss: 0.18
#   Batch   280  of    975.    .
#   step loss: 0.12
#   Batch   320  of    975.    .
#   step loss: 0.10
#   Batch   360  of    975.    .
#   step loss: 0.12
#   Batch   400  of    975.    .
#   step loss: 0.14
#   Batch   440  of    975.    .
#   step loss: 0.10
#   Batch   480  of    975.    .
#   step loss: 0.15
#   Batch   520  of    975.    .
#   step loss: 0.09
#   Batch   560  of    975.    .
#   step loss: 0.07
#   Batch   600  of    975.    .
#   step loss: 0.09
#   Batch   640  of    975.    .
#   step loss: 0.13
#   Batch   680  of    975.    .
#   step loss: 0.16
#   Batch   720  of    975.    .
#   step loss: 0.10
#   Batch   760  of    975.    .
#   step loss: 0.11
#   Batch   800  of    975.    .
#   step loss: 0.14
#   Batch   840  of    975.    .
#   step loss: 0.14
#   Batch   880  of    975.    .
#   step loss: 0.14
#   Batch   920  of    975.    .
#   step loss: 0.11
#   Batch   960  of    975.    .
#   step loss: 0.14
#
#   Average training loss: 0.11
#
# Running Validation...
# Batch accuracy: 92.38
# Batch accuracy: 91.60
# Batch accuracy: 90.43
# Batch accuracy: 92.19
# Batch accuracy: 92.77
# Batch accuracy: 93.75
# Batch accuracy: 94.14
# Batch accuracy: 91.60
# Batch accuracy: 92.38
# Batch accuracy: 91.60
# Batch accuracy: 91.60
# Batch accuracy: 90.82
# Batch accuracy: 90.43
# Batch accuracy: 92.77
# Batch accuracy: 95.31
# Batch accuracy: 91.80
# Batch accuracy: 91.21
# Batch accuracy: 92.58
# Batch accuracy: 91.60
# Batch accuracy: 93.75
# Batch accuracy: 91.41
# Batch accuracy: 92.19
# Batch accuracy: 92.19
# Batch accuracy: 94.14
# Batch accuracy: 91.21
# Batch accuracy: 91.41
# Batch accuracy: 91.21
# Batch accuracy: 92.38
# Batch accuracy: 90.04
# Batch accuracy: 91.02
# Batch accuracy: 91.41
# Batch accuracy: 91.41
# Batch accuracy: 92.19
# Batch accuracy: 93.95
# Batch accuracy: 92.38
# Batch accuracy: 92.97
# Batch accuracy: 91.21
# Batch accuracy: 92.58
# Batch accuracy: 93.75
# Batch accuracy: 90.82
# Batch accuracy: 91.99
# Batch accuracy: 91.02
# Batch accuracy: 89.84
# Batch accuracy: 91.41
# Batch accuracy: 89.65
# Batch accuracy: 91.99
# Batch accuracy: 94.53
# Batch accuracy: 91.80
# Batch accuracy: 92.38
# Batch accuracy: 92.97
# Batch accuracy: 91.60
# Batch accuracy: 91.60
# Batch accuracy: 91.80
# Batch accuracy: 91.60
# Batch accuracy: 90.43
# Batch accuracy: 90.82
# Batch accuracy: 90.82
# Batch accuracy: 90.62
# Batch accuracy: 91.60
# Batch accuracy: 91.60
# Batch accuracy: 92.58
# Batch accuracy: 92.58
# Batch accuracy: 91.41
# Batch accuracy: 91.02
# Batch accuracy: 92.58
# Batch accuracy: 92.77
# Batch accuracy: 93.36
# Batch accuracy: 90.23
# Batch accuracy: 90.04
# Batch accuracy: 90.82
# Batch accuracy: 92.77
# Batch accuracy: 93.16
# Batch accuracy: 92.97
# Batch accuracy: 92.38
# Batch accuracy: 91.41
# Batch accuracy: 90.23
# Batch accuracy: 92.38
# Batch accuracy: 93.55
# Batch accuracy: 94.34
# Batch accuracy: 92.97
# Batch accuracy: 92.38
# Batch accuracy: 93.36
# Batch accuracy: 94.34
# Batch accuracy: 92.38
# Batch accuracy: 91.99
# Batch accuracy: 91.60
# Batch accuracy: 92.58
# Batch accuracy: 90.23
# Batch accuracy: 92.38
# Batch accuracy: 89.84
# Batch accuracy: 90.62
# Batch accuracy: 91.99
# Batch accuracy: 92.19
# Batch accuracy: 93.75
# Batch accuracy: 90.43
# Batch accuracy: 90.04
# Batch accuracy: 92.58
# Batch accuracy: 92.19
# Batch accuracy: 90.62
# Batch accuracy: 92.38
# Batch accuracy: 92.97
# Batch accuracy: 91.80
# Batch accuracy: 91.99
# Batch accuracy: 94.34
# Batch accuracy: 93.75
# Batch accuracy: 93.55
# Batch accuracy: 92.38
# Batch accuracy: 91.02
# Batch accuracy: 95.16
#   Accuracy: 92.05
# The model does not improve for 5 epochs!
#
# ======== Epoch 19 / 30 ========
# Training...
#   Batch    40  of    975.    .
#   step loss: 0.12
#   Batch    80  of    975.    .
#   step loss: 0.09
#   Batch   120  of    975.    .
#   step loss: 0.09
#   Batch   160  of    975.    .
#   step loss: 0.16
#   Batch   200  of    975.    .
#   step loss: 0.12
#   Batch   240  of    975.    .
#   step loss: 0.08
#   Batch   280  of    975.    .
#   step loss: 0.14
#   Batch   320  of    975.    .
#   step loss: 0.17
#   Batch   360  of    975.    .
#   step loss: 0.09
#   Batch   400  of    975.    .
#   step loss: 0.09
#   Batch   440  of    975.    .
#   step loss: 0.12
#   Batch   480  of    975.    .
#   step loss: 0.14
#   Batch   520  of    975.    .
#   step loss: 0.11
#   Batch   560  of    975.    .
#   step loss: 0.13
#   Batch   600  of    975.    .
#   step loss: 0.11
#   Batch   640  of    975.    .
#   step loss: 0.11
#   Batch   680  of    975.    .
#   step loss: 0.11
#   Batch   720  of    975.    .
#   step loss: 0.09
#   Batch   760  of    975.    .
#   step loss: 0.11
#   Batch   800  of    975.    .
#   step loss: 0.11
#   Batch   840  of    975.    .
#   step loss: 0.14
#   Batch   880  of    975.    .
#   step loss: 0.11
#   Batch   920  of    975.    .
#   step loss: 0.10
#   Batch   960  of    975.    .
#   step loss: 0.10
#
#   Average training loss: 0.11
#
# Running Validation...
# Batch accuracy: 90.82
# Batch accuracy: 91.60
# Batch accuracy: 91.41
# Batch accuracy: 95.12
# Batch accuracy: 91.80
# Batch accuracy: 92.97
# Batch accuracy: 92.38
# Batch accuracy: 92.38
# Batch accuracy: 93.55
# Batch accuracy: 94.14
# Batch accuracy: 93.16
# Batch accuracy: 90.82
# Batch accuracy: 90.23
# Batch accuracy: 92.77
# Batch accuracy: 93.16
# Batch accuracy: 91.80
# Batch accuracy: 92.19
# Batch accuracy: 92.77
# Batch accuracy: 92.19
# Batch accuracy: 89.65
# Batch accuracy: 93.36
# Batch accuracy: 91.60
# Batch accuracy: 92.58
# Batch accuracy: 92.97
# Batch accuracy: 92.19
# Batch accuracy: 92.97
# Batch accuracy: 90.82
# Batch accuracy: 92.38
# Batch accuracy: 90.23
# Batch accuracy: 92.38
# Batch accuracy: 91.41
# Batch accuracy: 92.38
# Batch accuracy: 91.80
# Batch accuracy: 91.80
# Batch accuracy: 92.97
# Batch accuracy: 91.21
# Batch accuracy: 93.16
# Batch accuracy: 91.60
# Batch accuracy: 90.82
# Batch accuracy: 92.19
# Batch accuracy: 92.58
# Batch accuracy: 91.21
# Batch accuracy: 90.62
# Batch accuracy: 93.36
# Batch accuracy: 89.84
# Batch accuracy: 91.99
# Batch accuracy: 90.04
# Batch accuracy: 91.41
# Batch accuracy: 93.95
# Batch accuracy: 89.84
# Batch accuracy: 89.84
# Batch accuracy: 91.99
# Batch accuracy: 92.38
# Batch accuracy: 89.65
# Batch accuracy: 91.02
# Batch accuracy: 89.65
# Batch accuracy: 91.99
# Batch accuracy: 91.21
# Batch accuracy: 93.16
# Batch accuracy: 95.31
# Batch accuracy: 91.99
# Batch accuracy: 92.19
# Batch accuracy: 92.38
# Batch accuracy: 93.16
# Batch accuracy: 91.99
# Batch accuracy: 92.58
# Batch accuracy: 92.58
# Batch accuracy: 91.60
# Batch accuracy: 92.58
# Batch accuracy: 91.41
# Batch accuracy: 91.41
# Batch accuracy: 93.95
# Batch accuracy: 93.16
# Batch accuracy: 91.80
# Batch accuracy: 92.19
# Batch accuracy: 93.36
# Batch accuracy: 90.82
# Batch accuracy: 90.62
# Batch accuracy: 90.43
# Batch accuracy: 92.38
# Batch accuracy: 91.80
# Batch accuracy: 91.02
# Batch accuracy: 91.21
# Batch accuracy: 93.95
# Batch accuracy: 92.97
# Batch accuracy: 89.65
# Batch accuracy: 91.60
# Batch accuracy: 91.21
# Batch accuracy: 92.77
# Batch accuracy: 92.19
# Batch accuracy: 91.60
# Batch accuracy: 91.80
# Batch accuracy: 91.21
# Batch accuracy: 93.16
# Batch accuracy: 92.38
# Batch accuracy: 93.75
# Batch accuracy: 92.38
# Batch accuracy: 92.19
# Batch accuracy: 93.55
# Batch accuracy: 92.58
# Batch accuracy: 91.80
# Batch accuracy: 91.41
# Batch accuracy: 90.04
# Batch accuracy: 91.21
# Batch accuracy: 92.38
# Batch accuracy: 93.16
# Batch accuracy: 90.62
# Batch accuracy: 91.21
# Batch accuracy: 92.74
#   Accuracy: 91.99
# The model does not improve for 6 epochs!
# ====>Stopping training, the model did not improve for 6
# ====>Best epoch: 13.
#
# Training complete!

# %%
def predict(
    model_path: Path,
    dataset: str,
    batch_size: int,
    labels_dict,
    device: torch.device
):

    print(f"====Loading dataset for testing")
    test_corpus = NLPDataset(dataset, "test", sentence_max_len, labels_dict = labels_dict, vocab= voc)

    test_dataloader = DataLoader(
        test_corpus,
        batch_size=batch_size,
        #sampler = RandomSampler(test_corpus),
        pin_memory=True,
        num_workers=0,
        drop_last=False
    )

    print(f"====Loading model for testing")
    model = torch.load(join(model_path, "best-model.pth"))
    model.to(device)
    model.eval()
    pred_labels = []
    test_labels = []
    logits_list = []

    def _list_from_tensor(tensor):
        if tensor.numel() == 1:
            return [tensor.item()]
        return list(tensor.cpu().detach().numpy())

    print("====Testing model...")
    for batch in test_dataloader:
        #h = model.init_hidden(len(batch[0]), device)
        #h = tuple([each.data for each in val_h])
        b_input_ids = batch[0]
        b_input_ids = torch.tensor(b_input_ids).to(device).long()
        b_labels = batch[1].to(device)
        with torch.no_grad():
            #h = tuple([each.data for each in h])
            loss, logits = model(b_input_ids, b_labels)
            preds = np.argmax(logits.cpu(), axis=1) # Convert one-hot to index
            b_labels = b_labels.int()
            pred_labels.extend(_list_from_tensor(preds))
            test_labels.extend(_list_from_tensor(b_labels))
        logits_list.extend(_list_from_tensor(logits))

    print(classification_report(test_labels, pred_labels, labels=list(labels_dict.values()), target_names=np.array(list(labels_dict.keys())), digits=3, output_dict=False))
    logits_list = expit(logits_list)
    del model
    torch.cuda.empty_cache()

# %%
del train_dataloader
del validation_dataloader
del train_corpus
del val_corpus
del model
torch.cuda.empty_cache()

# %%
predict(last_saved_model, dataset, batch_size, labels_dict, device)
# Out:
# ====Loading dataset for testing
# ====Loading model for testing
# ====Testing model...
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:39: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#                                              precision    recall  f1-score   support
#
#                               FISHING_LINES      0.825     0.856     0.840       584
#                      MOBILE_DEVICE_CHARGERS      0.961     0.959     0.960       804
#                                  SUNGLASSES      0.954     0.973     0.963       875
#                                    FREEZERS      0.861     0.908     0.884       444
#                                  CAR_WHEELS      0.980     0.999     0.989       720
#                            BATHROOM_FAUCETS      0.870     0.900     0.885       521
#                              ACTION_FIGURES      0.664     0.675     0.670       800
#                                       IRONS      0.979     0.972     0.976       433
#                                  MATTRESSES      0.981     0.976     0.978       534
#                       SWIMMING_POOL_HEATERS      0.720     0.857     0.783        21
#                              KITCHEN_KNIVES      0.904     0.931     0.917       202
#                                 TELEVISIONS      0.958     0.934     0.946       728
#                    SPORT_AND_BAZAAR_BOTTLES      0.889     0.878     0.884       229
#                                    STARTERS      0.948     0.972     0.960       354
#                                  FACE_MASKS      0.866     0.819     0.842       166
#                             KITCHEN_FAUCETS      0.913     0.882     0.897       431
#     TACTICAL_AND_SPORTING_KNIVES_AND_BLADES      0.956     0.927     0.941       164
#                                   NOTEBOOKS      0.907     0.956     0.931       543
#                                 DEEP_FRYERS      0.962     0.958     0.960       455
#                                TORSION_BARS      0.992     1.000     0.996       123
#                            AUDIO_AMPLIFIERS      0.802     0.833     0.817       311
#                              CEILING_LIGHTS      0.938     0.953     0.945       472
#                                       BELTS      0.902     0.939     0.920        49
#                    AUTOMOTIVE_WEATHERSTRIPS      0.932     0.970     0.950       788
#                                  HEADBOARDS      1.000     0.982     0.991       228
#                                       YARNS      0.800     0.901     0.848       142
#                                SMARTWATCHES      0.939     0.942     0.941       724
#                             FOOTBALL_SHIRTS      0.958     0.954     0.956       921
#                      AUTOMOTIVE_CLUTCH_KITS      0.978     0.990     0.984       719
#                                WRISTWATCHES      0.950     0.962     0.956       876
#                                  WALLPAPERS      0.953     0.941     0.947       885
#         AUTOMOTIVE_SIDE_VIEW_MIRROR_GLASSES      0.981     0.983     0.982       536
#                            AUDIO_INTERFACES      0.932     0.870     0.900       300
#                            KITCHEN_PLAYSETS      0.922     0.950     0.936       100
#                                 LIGHT_BULBS      0.940     0.948     0.944       829
#                              CELL_BATTERIES      0.968     0.945     0.956       670
#                        SURVEILLANCE_CAMERAS      0.963     0.826     0.889       909
#                                   THERMOSES      0.808     0.840     0.824       100
#                  HUMIDIFIERS_AND_VAPORIZERS      0.931     0.931     0.931       173
#                              KITCHEN_APRONS      0.783     0.667     0.720        27
#                         PORTABLE_GENERATORS      0.978     1.000     0.989       132
#                                  CELLPHONES      0.891     0.942     0.916       329
#                            HANDICRAFT_BOXES      0.699     0.768     0.732       112
#                         EMBROIDERY_MACHINES      0.822     0.725     0.771        51
#                                     CAMERAS      0.745     0.761     0.753        92
#             DESKTOP_COMPUTER_POWER_SUPPLIES      0.980     0.990     0.985       679
#                              BABIES_FORMULA      0.773     0.966     0.859        88
#                     MOTORCYCLE_SPEEDOMETERS      1.000     0.500     0.667         4
#                                     CARPETS      0.950     0.961     0.956       857
#                       CARDS_AND_INVITATIONS      0.692     0.766     0.727        47
#                            ELECTRIC_GUITARS      0.962     0.977     0.969       778
#                           COMPUTER_MONITORS      0.952     0.966     0.959       701
#                          MULTIGAME_MACHINES      0.759     0.857     0.805        77
#                                 TABLECLOTHS      0.956     0.969     0.963       544
#                                   VIBRATORS      0.811     0.769     0.789       117
#                                      PLANTS      0.931     0.949     0.940       313
#                                AM_FM_RADIOS      0.911     0.914     0.913       383
#                      ENGINE_CONTROL_MODULES      0.998     1.000     0.999       415
#             LATEX_ENAMEL_AND_ACRYLIC_PAINTS      1.000     1.000     1.000        67
#             MUSICAL_KEYBOARD_CASES_AND_BAGS      0.976     0.979     0.978       760
#                                 VIDEO_GAMES      0.978     0.981     0.980       908
#                          ARTIFICIAL_FLOWERS      0.921     0.944     0.932       497
#                          OUTER_TIE_ROD_ENDS      0.988     0.976     0.982       496
#                           EXHAUST_MANIFOLDS      0.800     1.000     0.889         8
#                     DIGITAL_VOICE_RECORDERS      0.853     0.986     0.915       774
#                               REFRIGERATORS      0.928     0.931     0.930       524
#                             DISPOSABLE_CUPS      0.814     0.814     0.814       188
#                                  EYESHADOWS      0.954     0.959     0.957       738
#                                      RANGES      0.962     0.962     0.962       450
#          AUTOMOTIVE_POWER_WINDOW_REGULATORS      0.940     0.913     0.926       138
#                                     HOOKAHS      0.982     0.958     0.970       168
#                       AUTOMOTIVE_AMPLIFIERS      0.948     0.940     0.944       662
#                           PROJECTOR_SCREENS      0.961     0.925     0.942        53
#                          AUTOMOTIVE_EMBLEMS      0.952     0.912     0.932       524
#                           PAINTBALL_MARKERS      0.854     0.907     0.880        97
#               AUTOMOTIVE_SPRING_SUSPENSIONS      0.929     0.967     0.947       121
#                                 ENGINE_OILS      0.977     0.974     0.975       770
#                            BATTERY_CHARGERS      0.706     0.800     0.750        30
#                     SWEATSHIRTS_AND_HOODIES      0.922     0.907     0.915       118
#                      CONTINUOUS_INK_SYSTEMS      0.978     0.971     0.975       140
#                              BATHROOM_SINKS      0.918     0.972     0.944       427
#                                MEMORY_CARDS      0.972     0.973     0.972       669
#                                    HANDBAGS      0.959     0.946     0.953       850
#                               KITCHEN_SINKS      0.936     0.870     0.902       253
#                            CAMERA_BATTERIES      0.936     0.969     0.952       554
#                             WATER_RADIATORS      0.943     0.952     0.948       399
#                           CYCLING_COMPUTERS      0.944     0.944     0.944       161
#                                EROTIC_BOOKS      1.000     0.970     0.985        67
#                            MOTORCYCLE_CASES      0.991     0.986     0.989       222
#                                    COSTUMES      0.929     0.942     0.935       276
#                           BODYWEIGHT_SCALES      0.885     0.891     0.888       293
#                      GAMEPADS_AND_JOYSTICKS      0.975     0.954     0.964       612
#                                       PANTS      0.924     0.946     0.935       799
#                                      STOOLS      0.978     0.966     0.972       594
#                               FISHING_REELS      0.985     0.973     0.979       740
#                                     WALLETS      0.968     0.962     0.965       665
#                           MUSICAL_KEYBOARDS      0.943     0.973     0.958       511
#                                  ULTRABOOKS      0.935     0.871     0.902       232
#                             ENGINE_BEARINGS      0.964     0.979     0.971       327
#                    CAR_POWER_STEERING_PUMPS      0.971     0.992     0.981       370
#                                     TABLETS      0.975     0.939     0.957       624
#                              MAKEUP_BRUSHES      0.983     0.974     0.978       534
#                               HORSE_SADDLES      0.990     0.971     0.980       102
#                          CD_AND_DVD_PLAYERS      0.880     0.859     0.870       291
#                    VIDEO_GAME_PREPAID_CARDS      0.725     0.735     0.730        68
#                             SCREEN_PRINTERS      0.913     0.942     0.927       156
#                                  ROOF_RACKS      0.986     0.984     0.985       428
#                                  HEADPHONES      0.931     0.926     0.928       189
#                       ELECTRIC_SCREWDRIVERS      0.817     0.770     0.793       122
#                             VACUUM_CLEANERS      1.000     0.812     0.897        16
#                                 FLASHLIGHTS      0.964     0.970     0.967       606
#                                HOME_SHELVES      0.796     0.822     0.809       157
#                               BRUSH_CUTTERS      0.955     0.955     0.955       110
#                         COMPUTER_PROCESSORS      0.983     0.969     0.976       794
#                                    NECKTIES      0.985     0.993     0.989       134
#                          MOTORCYCLE_JACKETS      0.943     0.936     0.940       551
#                                    WRENCHES      0.963     0.989     0.976       371
#                                 WHEELCHAIRS      0.957     0.989     0.973        90
#                          RAM_MEMORY_MODULES      0.989     0.985     0.987       822
#                                PENCIL_CASES      0.960     0.907     0.933       183
#                AUTOMOTIVE_SHIFT_LEVER_KNOBS      1.000     1.000     1.000       938
#                                        MUGS      0.910     0.924     0.917       329
#                              WALKIE_TALKIES      0.941     0.951     0.946       283
#                                       DOLLS      0.894     0.925     0.910       843
#                                  TREADMILLS      0.984     0.954     0.969        65
#                                 SPARK_PLUGS      0.958     0.949     0.954       726
#                               HAIR_CLIPPERS      0.839     0.878     0.858       714
#                                   SUITCASES      0.954     0.973     0.963       582
#                                 BLANK_DISCS      0.920     0.910     0.915       178
#                                    SPEAKERS      0.936     0.952     0.944       525
#                               DVD_RECORDERS      0.949     0.958     0.954       450
#                     KEYBOARD_AND_MOUSE_KITS      0.956     0.949     0.953       275
#                             CAR_SEAT_COVERS      0.991     1.000     0.995       942
#          AUTOMOTIVE_SUSPENSION_CONTROL_ARMS      0.977     0.992     0.984       254
#                           BAR_CODE_SCANNERS      0.976     0.972     0.974       254
#                         AUTOMOTIVE_MOLDINGS      0.973     0.968     0.971       720
#                               BABY_SWIMWEAR      0.906     0.876     0.891       121
#                        TABLE_AND_DESK_LAMPS      0.936     0.900     0.918       260
#                           JACKETS_AND_COATS      0.899     0.917     0.908       815
#                                  CHAMPAGNES      0.774     0.774     0.774        31
#                              FOOTBALL_SHOES      0.992     0.995     0.993       734
#                           CHARMS_AND_MEDALS      0.821     0.907     0.862        86
#                                 MICROPHONES      0.966     0.970     0.968       465
#                         PERMANENT_EPILATORS      0.860     0.851     0.856        94
#                              WOMEN_SWIMWEAR      0.926     0.956     0.941       500
#                  PARTY_DECORATIVE_BACKDROPS      0.954     0.981     0.967       105
#                               ROLLER_SKATES      0.983     0.993     0.988       586
#                                      COMICS      0.782     0.801     0.792       534
#                                       BOOKS      0.611     0.788     0.688       834
#                              CUPCAKE_STANDS      0.500     0.500     0.500         8
#                               UPS_BATTERIES      0.763     0.703     0.732        64
#                                 CAKE_STANDS      0.846     0.733     0.786        45
#            REAR_WHEEL_HUBS_BEARING_ASSEMBLY      0.980     0.983     0.981       401
#                            DIECAST_VEHICLES      0.934     0.914     0.924       606
#                                 CALCULATORS      0.962     0.981     0.971       536
#                                 TV_ANTENNAS      0.966     0.994     0.979       310
#                                 PAPER_CLIPS      0.904     0.922     0.913        51
#                              MALE_UNDERWEAR      0.976     0.964     0.970       422
#                                  ALL_IN_ONE      0.896     0.910     0.903       189
#                            DRINKING_GLASSES      0.837     0.846     0.841       382
#                                       DRUMS      0.934     0.939     0.936       212
#                               WELDING_MASKS      0.932     0.873     0.902        63
#                                    WHISKEYS      0.924     0.963     0.943       267
#                               VIDEO_CAMERAS      0.906     0.784     0.841        37
#                               COFFEE_MAKERS      0.975     0.968     0.972       567
#                        KNEE_BRACES_SUPPORTS      0.953     0.953     0.953       129
#                                 WALL_CLOCKS      0.963     0.967     0.965       480
#                                 WALL_LIGHTS      0.988     0.959     0.973       172
#                              GARDEN_BENCHES      0.750     0.429     0.545        14
#                                  SCULPTURES      0.865     0.906     0.885       437
#                                        FANS      0.973     0.966     0.970       597
#                                 FOUNDATIONS      0.939     0.936     0.938       706
#                                   EYELINERS      0.818     0.720     0.766        50
#                                  DRILL_BITS      0.926     0.965     0.945       143
#                                PC_KEYBOARDS      0.727     0.615     0.667        26
#                               EROTIC_CREAMS      0.860     0.882     0.871       279
#                           DESKTOP_COMPUTERS      0.931     0.750     0.831        36
#                           DECORATIVE_VINYLS      0.907     0.951     0.928       709
#                                 BOARD_GAMES      0.875     0.896     0.885       654
#                         KITCHEN_RANGE_HOODS      0.987     0.981     0.984       309
#                                     DRAWERS      0.975     0.990     0.982       198
#                             FURNITURE_KNOBS      0.935     0.973     0.953       147
#        HOME_APPLIANCE_CONTACTORS_AND_RELAYS      0.975     0.961     0.968       408
#                            SHAVING_MACHINES      0.811     0.753     0.781       449
#                                TOOTHBRUSHES      0.934     0.962     0.948       265
#                     STREAMING_MEDIA_DEVICES      0.937     0.933     0.935       415
#                      CAR_AC_HOSE_ASSEMBLIES      0.733     0.647     0.688        17
#                              SWAY_BAR_LINKS      0.927     0.854     0.889        89
#                               PREAMPLIFIERS      0.357     0.217     0.270        23
#                                  FISH_TANKS      0.942     0.903     0.923       145
#                                      DRONES      0.972     0.972     0.972       653
#                            EMERGENCY_LIGHTS      0.924     0.931     0.927       288
#                                    BLENDERS      0.924     0.916     0.920       452
#                              LASER_MEASURES      0.981     0.945     0.963        55
#                                CASH_DRAWERS      1.000     0.921     0.959        38
#                             CAMERA_CHARGERS      0.917     0.933     0.925       285
#                            CAR_AV_RECEIVERS      0.924     0.924     0.924       589
#                            STEERING_COLUMNS      0.986     0.986     0.986       143
#                                      SKIRTS      0.932     0.974     0.952       154
#                             SANDER_MACHINES      0.956     0.969     0.963       292
#                                RICE_COOKERS      0.980     0.962     0.971        52
#                              BRAKE_BOOSTERS      0.957     0.971     0.964       139
#                                    NETBOOKS      0.872     0.897     0.884       145
#                               FISHING_LURES      0.828     0.791     0.809        67
#                            AUTOMOTIVE_TIRES      0.767     0.825     0.795        80
#                                     STATUES      0.588     0.435     0.500        23
#                                    T_SHIRTS      0.934     0.951     0.943       742
#                             OFFICE_SOFTWARE      0.615     0.585     0.600        82
#                              BABY_CAR_SEATS      0.968     0.976     0.972       550
#                                 WATCH_BANDS      0.900     0.883     0.891       265
#                                        PENS      0.846     0.815     0.830        27
#                   BATHROOM_ACCESSORIES_SETS      0.845     0.769     0.805        78
#                                 CAR_STEREOS      0.814     0.848     0.831       243
#  CELLPHONE_TABLET_AND_GPS_SCREEN_PROTECTORS      0.874     0.897     0.885       155
#                              GLASSES_FRAMES      0.948     0.932     0.940       296
#                                AIRSOFT_GUNS      0.960     0.971     0.966       245
#                                   HAND_FANS      0.923     0.750     0.828        32
#                                  SIDEBOARDS      0.960     0.960     0.960       201
#                            VEHICLE_STICKERS      0.986     0.964     0.975       530
#                              BABY_STROLLERS      0.954     0.972     0.963       468
#                                      MOVIES      0.863     0.620     0.721        71
#                          MICRO_ROTARY_TOOLS      0.871     0.884     0.878        69
#                                   SOUVENIRS      0.882     0.887     0.884       151
#                                      VODKAS      0.846     0.936     0.889        94
#                               PUREBRED_DOGS      0.952     0.977     0.964       705
#                                     VIOLINS      0.974     0.987     0.980       151
#                                 HOVERBOARDS      0.985     0.981     0.983       480
#                      SUSPENSION_BALL_JOINTS      0.979     0.971     0.975       579
#                                   BACKPACKS      0.947     0.974     0.961       699
#                              ADHESIVE_TAPES      0.949     0.957     0.953       253
#                           ELECTRICAL_CABLES      0.976     0.984     0.980       250
#                               COFFEE_TABLES      0.905     0.731     0.809        26
#                  INTERACTIVE_GAMING_FIGURES      0.972     0.984     0.978       246
#                   AUTOMOTIVE_AC_COMPRESSORS      0.974     0.860     0.914        43
#                       HAIRDRESSING_SCISSORS      0.981     0.975     0.978       160
#                                    CUSHIONS      0.948     0.934     0.941       213
#                   THERMAL_CUPS_AND_TUMBLERS      0.940     0.839     0.887        56
#         TV_REPLACEMENT_BACKLIGHT_LED_STRIPS      0.991     0.965     0.978       115
#                         ENGINE_INTAKE_HOSES      0.917     0.949     0.933       373
#                    AUTOMOBILE_FENDER_LINERS      0.850     0.944     0.895        18
#                              DJ_CONTROLLERS      0.898     0.851     0.874       175
#                                STUFFED_TOYS      0.799     0.838     0.818       679
#              MARTIAL_ARTS_AND_BOXING_GLOVES      0.950     0.969     0.959       254
#                               CAMERA_LENSES      0.972     0.941     0.956       219
#                                EROTIC_PUMPS      0.952     0.899     0.925        89
#                               PAINT_ROLLERS      1.000     0.909     0.952        11
#                                MEN_SWIMWEAR      0.786     0.611     0.688        18
#                 PORTABLE_CELLPHONE_CHARGERS      0.961     0.940     0.950       500
#                              ANALOG_CAMERAS      0.912     0.928     0.920       457
#                             HAIR_TREATMENTS      0.775     0.775     0.775        89
#                       DJ_EFFECTS_PROCESSORS      0.757     0.708     0.731       202
#                     BUMPER_IMPACT_ABSORBERS      0.939     0.947     0.943       245
#                  NOTEBOOKS_AND_WRITING_PADS      0.896     0.954     0.924       153
#                         FINGERPRINT_READERS      0.870     0.833     0.851        24
#                                    BLANKETS      0.816     0.878     0.846       131
#                                 SUPPLEMENTS      0.812     0.786     0.799       430
#                                    HAMMOCKS      0.964     0.976     0.970        82
#                AUTOMOTIVE_SIDE_VIEW_MIRRORS      0.968     0.974     0.971       737
#                   FACIAL_SKIN_CARE_PRODUCTS      0.751     0.786     0.768       341
#                             PACKAGING_ROLLS      0.962     0.962     0.962        26
#                       TV_AND_MONITOR_MOUNTS      0.975     0.991     0.983       546
#                                CAR_ANTENNAS      1.000     0.993     0.996       934
#                                    CACHACAS      0.973     0.911     0.941       157
#                                     TV_SMPS      0.875     0.875     0.875       279
#                              KITCHEN_TOWELS      0.971     0.975     0.973       277
#                                    CALIPERS      1.000     1.000     1.000        22
#                             PARKING_SENSORS      0.983     0.987     0.985       539
#                   ELECTRIC_PRESSURE_WASHERS      0.977     0.977     0.977       343
#              HAIR_SHAMPOOS_AND_CONDITIONERS      0.795     0.705     0.747        44
#                                STETHOSCOPES      0.970     0.889     0.928        36
#                                    PRINTERS      0.912     0.927     0.919       400
#                             ELECTRIC_DRILLS      0.948     0.964     0.956       414
#                                KITCHEN_POTS      0.953     0.957     0.955       485
#                              FUEL_INJECTORS      0.911     0.893     0.902       103
#                            VEHICLE_SPEAKERS      0.967     0.967     0.967       421
#                           HOME_OFFICE_DESKS      0.871     0.953     0.910       149
#                              GUITAR_STRINGS      0.887     0.962     0.923       106
#                             DISC_PACKAGINGS      0.808     0.851     0.829        74
#                                 LIP_GLOSSES      0.919     0.900     0.910       190
#                                     DRESSES      0.958     0.961     0.960       692
#                                BASS_GUITARS      0.965     0.946     0.956       467
#                                  TURNTABLES      0.842     0.870     0.856       270
#                           TOY_BUILDING_SETS      0.867     0.839     0.853       249
#                                  BED_SHEETS      0.779     0.893     0.832        75
#                               CAR_GEARBOXES      0.971     0.989     0.980       267
#                                FLOOD_LIGHTS      0.944     0.946     0.945       462
#                          SOLDERING_MACHINES      0.982     0.974     0.978       383
#                            ELECTRONIC_DRUMS      0.918     0.863     0.890       117
#                    DATA_CABLES_AND_ADAPTERS      0.802     0.912     0.854        80
#                      AUTOMOTIVE_WATER_PUMPS      0.870     0.890     0.880       391
#                              FOOTBALL_BALLS      0.962     0.968     0.965       156
#                                LENS_FILTERS      0.946     0.933     0.940        75
#                       INSTRUMENT_AMPLIFIERS      0.915     0.909     0.912       449
#                                MUSIC_STANDS      1.000     0.875     0.933        32
#                        CAR_DISTRIBUTOR_CAPS      0.969     0.912     0.940       205
#                                  MOUSE_PADS      0.950     0.955     0.953       201
#                                     FABRICS      0.873     0.873     0.873       379
#                               CABIN_FILTERS      0.984     1.000     0.992       244
#                             SEWING_MACHINES      0.922     0.932     0.927       292
#                                      MIXERS      0.977     0.969     0.973       350
#                         MOTORCYCLE_FAIRINGS      0.910     0.941     0.925       353
#                                   CV_JOINTS      0.968     0.964     0.966       443
#                  HAIR_STRAIGHTENING_BRUSHES      0.889     0.923     0.906        26
#                             WHEELS_BEARINGS      0.989     0.991     0.990       547
#                                AV_RECEIVERS      0.854     0.840     0.847       188
#                              NETWORK_CABLES      0.957     0.947     0.952       190
#                                       CRIBS      0.881     0.884     0.882       242
#                                HOME_HEATERS      0.921     0.893     0.907       234
#                  BRACELETS_AND_ANKLE_BRACES      0.889     0.902     0.895       346
#                                    SNEAKERS      0.838     0.861     0.849        72
#                  AUTOMOTIVE_THROTTLE_BODIES      0.959     0.940     0.949        50
#                              COOKING_SCALES      0.914     0.905     0.910       412
#                               PEDAL_EFFECTS      0.952     0.944     0.948       695
#                              ENGINE_PISTONS      0.930     0.902     0.915       132
#                               FLATWARE_SETS      1.000     0.774     0.873        31
#                                     PANTIES      0.840     0.857     0.848        49
#                          ELECTRICAL_OUTLETS      0.919     0.934     0.927       122
#                          BABY_CLOTHING_SETS      0.768     0.829     0.797        76
#                              STEAM_CLEANERS      0.571     0.421     0.485        19
#                            DECORATIVE_VASES      0.865     0.891     0.878       274
#                             FOOD_PROCESSORS      0.817     0.859     0.838       135
#                             TRAILER_HITCHES      0.995     0.989     0.992       184
#                       SOFA_AND_FUTON_COVERS      0.990     0.970     0.980        99
#                                      SHIRTS      0.891     0.831     0.860       118
#                       VEHICLE_CLUTCH_CABLES      0.818     0.900     0.857        10
#                                 GATE_MOTORS      0.980     0.980     0.980       298
#                                  FOG_LIGHTS      0.973     0.969     0.971       292
#                                   SIM_CARDS      0.905     0.792     0.844        24
#                               BABY_MONITORS      0.952     0.986     0.969       220
#                            VEHICLE_CV_AXLES      0.939     0.899     0.919        69
#                                   LIPSTICKS      0.951     0.961     0.956       562
#                      SERVING_AND_HOME_TRAYS      0.938     0.946     0.942       354
#                                    COOKTOPS      0.455     0.455     0.455        11
#                              GRAPHICS_CARDS      0.882     0.938     0.909        32
#                          FIRE_EXTINGUISHERS      0.897     0.867     0.881        30
#                  KITCHEN_CABINET_ORGANIZERS      0.000     0.000     0.000         7
#                                       SOFAS      0.833     0.900     0.865       100
#                            GRAPHICS_TABLETS      0.984     0.979     0.982       190
#                                      SHORTS      0.917     0.927     0.922       274
#                            SWIMMING_GOGGLES      0.897     0.792     0.841        77
#                            POOL_INFLATABLES      0.829     0.919     0.872        37
#                                       DOORS      0.810     0.876     0.842        97
#                               SPORT_WATCHES      0.929     0.927     0.928       478
#            PORTABLE_EVAPORATIVE_AIR_COOLERS      0.953     0.884     0.917       138
#              DOG_CARRIERS_AND_CARRYING_BAGS      0.912     0.912     0.912        57
#                     ENGINE_INTAKE_MANIFOLDS      0.927     1.000     0.962        51
#                          MOTORCYCLE_HELMETS      0.988     0.999     0.993       715
#                        COMBUSTION_CHAINSAWS      0.952     0.952     0.952        84
#               ELECTRONIC_ENTRANCE_INTERCOMS      0.957     0.953     0.955       211
#                                     CRAYONS      0.980     0.980     0.980       101
#                                THERMOMETERS      0.984     0.984     0.984        63
#                              CAMERA_TRIPODS      0.956     0.977     0.966       427
#                           ARTIFICIAL_PLANTS      0.560     0.519     0.538        27
#                            PROJECTOR_MOUNTS      0.750     0.600     0.667         5
#                 PORTABLE_ELECTRIC_MASSAGERS      0.924     0.880     0.901        83
#               NON_CORRECTIVE_CONTACT_LENSES      0.800     0.833     0.816        24
#                                     PUZZLES      0.870     0.905     0.887        74
#            WASHING_AND_DRYER_MACHINE_COVERS      0.980     1.000     0.990        50
#                        PUSH_AND_RIDING_TOYS      0.536     0.469     0.500        32
#                                SHOWER_HEADS      0.842     0.838     0.840       235
#                            ANTI_THEFT_STUDS      0.953     0.932     0.943       220
#                               HATS_AND_CAPS      0.809     0.846     0.827        65
#                                   MAGAZINES      0.693     0.552     0.615       143
#                  ENGINE_COOLING_FAN_SHROUDS      0.988     0.952     0.969        83
#                      AUTOMOTIVE_OIL_FILTERS      0.914     0.744     0.821        43
#                            MOTORCYCLE_TIRES      0.897     0.884     0.890       147
#               MOTORCYCLE_TURN_SIGNAL_LIGHTS      0.986     0.986     0.986       221
#                                     PILLOWS      0.867     0.839     0.852        31
#                                    TEQUILAS      0.912     0.939     0.925        33
#                                 TOILET_RUGS      0.893     0.904     0.898       249
#                                      FLUTES      0.950     0.891     0.919       128
#                                    UKULELES      0.963     1.000     0.981        52
#                                 TOOTHPASTES      0.897     0.839     0.867        62
#                       MOTORCYCLE_CRASH_BARS      0.842     0.762     0.800        21
#                             PIPES_AND_TUBES      0.312     0.385     0.345        13
#                                FOOD_SLICERS      0.810     0.773     0.791        22
#           DESKTOP_COMPUTER_COOLERS_AND_FANS      0.939     0.945     0.942       345
#                                   SWAY_BARS      0.938     0.918     0.928        98
#                            AQUARIUM_FILTERS      0.945     0.972     0.959       214
#               CELLPHONE_REPLACEMENT_CAMERAS      1.000     0.961     0.980        51
#                                     MIRRORS      0.922     0.826     0.871        86
#                             BLU_RAY_PLAYERS      0.911     0.931     0.921       175
#                          AUTOMOTIVE_FENDERS      0.890     0.911     0.900       124
#                             SPARKLING_WINES      0.500     0.333     0.400        12
#              ENGINE_VALVES_SPRING_RETAINERS      0.970     0.956     0.963        68
#                                BABY_WALKERS      0.833     0.769     0.800        13
#             ANTIVIRUS_AND_INTERNET_SECURITY      0.682     0.938     0.789        16
#                       COTTON_CANDY_MACHINES      1.000     0.857     0.923         7
#                             ORAL_IRRIGATORS      0.667     0.500     0.571         8
#                    MOTORCYCLE_CLUTCH_COVERS      0.911     0.946     0.928       239
#                               GAME_CONSOLES      0.924     0.873     0.898       347
#                               TABLE_RUNNERS      0.912     0.925     0.919        67
#                           PLAYGROUND_SLIDES      0.909     0.769     0.833        13
#                                 3D_PRINTERS      0.917     0.936     0.926        47
#                                 DIAPER_BAGS      0.969     0.922     0.945       103
#                               ELECTRIC_SAWS      0.975     0.986     0.981       363
#                           KITCHEN_FURNITURE      0.868     0.868     0.868        38
#                            BABY_HIGH_CHAIRS      0.773     0.580     0.662        88
#                                    MINI_PCS      0.727     0.571     0.640        14
#                                    MASCARAS      0.944     0.913     0.928        92
#                     AUTOMOTIVE_WHEEL_COVERS      0.937     0.922     0.930       129
#                           WINDSHIELD_WIPERS      0.974     0.974     0.974       190
#                                     LIQUORS      0.979     0.930     0.954       100
#                            CLOTHING_PATCHES      0.870     0.810     0.839        58
#                       WOOD_BURNING_MACHINES      0.857     0.857     0.857         7
#                                  BINOCULARS      0.957     0.952     0.954       186
#                      COMMERCIAL_LIGHT_SIGNS      1.000     1.000     1.000        32
#                            WATER_DISPENSERS      0.943     0.951     0.947       225
#                       GLOW_PLUG_CONTROLLERS      0.897     0.929     0.912        56
#                                  TELEPHONES      0.867     0.619     0.722        21
#                             AIR_COMPRESSORS      0.932     0.966     0.949       353
#                           OPERATING_SYSTEMS      0.828     0.889     0.857       270
#                        CAR_ENGINE_CAMSHAFTS      0.824     0.933     0.875        15
#                             CLOTHES_HANGERS      1.000     0.957     0.978        92
#                                    WETSUITS      1.000     0.842     0.914        19
#                                TOILET_SEATS      0.984     0.995     0.990       191
#                            AUTOMOTIVE_DOORS      0.965     0.991     0.978       332
#             SUSPENSION_CONTROL_ARM_BUSHINGS      0.758     0.819     0.787       138
#                          VEHICLE_BRAKE_PADS      0.977     0.983     0.980       350
#                 REMOTE_CONTROL_TOY_VEHICLES      0.876     0.876     0.876       209
#                        AUTOMOTIVE_NERF_BARS      1.000     0.974     0.987        38
#                              ESSENTIAL_OILS      0.855     0.723     0.783        65
#                             SLATWALL_PANELS      1.000     1.000     1.000        80
#                                  TOOL_BOXES      0.936     0.945     0.941       109
#                                BABY_DIAPERS      0.984     0.979     0.981       375
#                          ALARMS_AND_SENSORS      0.894     0.919     0.906       295
#                            MOTORCYCLE_SUITS      0.917     0.892     0.904        37
#                               KITCHEN_BOWLS      0.500     0.500     0.500        22
#                              CAT_SCRATCHERS      0.929     0.867     0.897        15
#                              INK_CARTRIDGES      0.889     0.800     0.842        30
#                    MARKERS_AND_HIGHLIGHTERS      0.879     0.921     0.899       126
#                      JUMPSUITS_AND_OVERALLS      0.800     0.792     0.796       106
#                                 NAIL_DRYERS      0.977     0.954     0.965       131
#                             CAMERA_MONOPODS      0.837     0.735     0.783        49
#                                    BICYCLES      0.978     0.951     0.964       184
#                                        SALT      1.000     0.900     0.947        10
#                    SCREEN_PRINTING_MACHINES      0.800     0.571     0.667        14
#                                        BEDS      0.787     0.860     0.822        43
#                     BODY_SKIN_CARE_PRODUCTS      0.722     0.792     0.755       380
# AUTOMOTIVE_MANUAL_TRANSMISSION_SHIFT_LEVERS      0.821     0.920     0.868        25
#                            TV_STORAGE_UNITS      0.889     0.923     0.906        52
#                       AUTOMOTIVE_HEADLIGHTS      0.926     0.962     0.944       131
#                                  PAINTBALLS      0.886     0.918     0.902        85
#                                      SCREWS      0.776     0.912     0.839        57
#                                  TOY_ROBOTS      0.571     0.267     0.364        15
#                                     POSTERS      0.907     0.942     0.924       206
#                            MOTORCYCLE_PANTS      0.907     0.907     0.907       118
#                         INTEGRATED_CIRCUITS      0.265     0.736     0.390        72
#                                GARDEN_HOSES      0.947     0.964     0.956        56
#                                 ALTERNATORS      0.857     0.875     0.866        48
#                          MAGNIFYING_GLASSES      0.958     0.926     0.942       122
#                                    PERFUMES      0.873     0.923     0.897        52
#                                       FLOUR      0.917     0.733     0.815        15
#                                FISHING_RODS      0.938     0.789     0.857        19
#                  CELLPHONE_AND_TABLET_CASES      0.835     0.945     0.887        91
#                                     PAJAMAS      0.961     0.875     0.916        56
#                                  BUTT_PLUGS      0.651     0.824     0.727        34
#                 LUMBAR_AND_ABDOMINAL_BRACES      0.979     0.966     0.973       147
#                              AIR_MATTRESSES      0.948     0.948     0.948       154
#                               WATER_HEATERS      0.954     0.931     0.943       247
#                                 DISHWASHERS      0.952     0.932     0.942       148
#                        ELECTRIC_LAWN_MOWERS      1.000     0.750     0.857         4
#                               HOME_THEATERS      0.714     0.556     0.625         9
#                            LED_STAGE_LIGHTS      0.864     0.852     0.858       216
#           CHALKBOARD_AND_WHITEBOARD_ERASERS      0.955     0.913     0.933        23
#                               BABY_BOUNCERS      0.789     0.833     0.811        18
#                                       RINGS      0.907     0.907     0.907        43
#                      AUTOMOTIVE_AIR_FILTERS      0.911     0.927     0.919        55
#                                LUGGAGE_TAGS      0.884     0.809     0.844        47
#                                HEATER_CORES      1.000     0.762     0.865        21
#                             CLEANING_CLOTHS      0.882     0.882     0.882        93
#                              AIR_FRESHENERS      0.952     0.465     0.625        43
#                                     BLOUSES      0.657     0.605     0.630        38
#                             SAFETY_FOOTWEAR      0.970     0.985     0.977        66
#                                FREEZER_BAGS      0.857     0.750     0.800         8
#                      SHOCK_MOUNT_INSOLATORS      0.822     0.822     0.822        73
#                                  BAR_CLAMPS      0.733     0.688     0.710        16
#                             CHRISTMAS_TREES      0.949     1.000     0.974        37
#                          CAR_AIR_FRESHENERS      0.821     0.879     0.849        99
#                          BASKETBALL_JERSEYS      1.000     0.600     0.750        15
#                                  ACCORDIONS      0.959     0.971     0.965       311
#                                  FOOD_CARTS      0.931     0.871     0.900        31
#                                   HEAT_GUNS      0.989     0.979     0.984        94
#                   ENGINE_CRANKSHAFT_PULLEYS      0.919     0.953     0.936       107
#                                  PARTY_HATS      0.800     0.500     0.615         8
#                             RECEPTION_DESKS      1.000     1.000     1.000         4
#                              PICTURE_FRAMES      0.944     0.894     0.918       151
#                               OSCILLOSCOPES      0.316     0.600     0.414        10
#                   HABERDASHERY_LACE_EDGINGS      0.865     0.881     0.873       109
#                                       BEERS      0.953     0.959     0.956       170
#                                HOLE_PUNCHES      1.000     0.571     0.727         7
#                               DJ_TURNTABLES      0.701     0.588     0.639        80
#                                 VR_HEADSETS      0.980     0.980     0.980       352
#                             KITCHEN_MORTARS      0.500     0.250     0.333         4
#                                       OVENS      0.959     0.965     0.962       171
#                                DISHES_RACKS      0.702     0.673     0.688        49
#                                    EARRINGS      0.872     0.932     0.901        44
#                                   WARDROBES      0.721     0.861     0.785        36
#                           RACKS_AND_PINIONS      0.972     0.938     0.955       113
#                                   BOOKCASES      0.769     0.857     0.811        35
#                                  TOY_TRAINS      0.767     0.702     0.733        94
#                      CARD_PAYMENT_TERMINALS      0.762     0.941     0.842        17
#                           SUBMERSIBLE_PUMPS      0.960     0.960     0.960       100
#             GARDENING_AND_AGRICULTURE_SEEDS      0.868     0.917     0.892        36
#                                      MODEMS      0.772     0.772     0.772       123
#                               OFFICE_CHAIRS      0.817     0.908     0.860        98
#                                   PENDRIVES      0.935     0.928     0.931       139
#                                   NECKLACES      0.779     0.736     0.757        91
#                          ENGINE_GASKET_SETS      0.625     0.294     0.400        17
#                  AUTOMOTIVE_SHOCK_ABSORBERS      0.781     0.864     0.820        66
#                                 VINYL_ROLLS      0.623     0.543     0.580        70
#               TROLLEY_AND_FURNITURE_CASTERS      1.000     0.250     0.400         4
#                   TV_RECEIVERS_AND_DECODERS      0.786     0.611     0.688        18
#                                LIFE_JACKETS      1.000     0.727     0.842        22
#                        SELF_ADHESIVE_LABELS      0.771     0.755     0.763        49
#                   IGNITION_SWITCH_ACTUATORS      0.800     0.857     0.828        14
#                            BABY_STERILIZERS      0.842     0.727     0.780        22
#                       PARKING_BRAKE_HANDLES      0.984     0.984     0.984        61
#                      CLUTCH_SLAVE_CYLINDERS      0.750     0.800     0.774        30
#                                      FISHES      0.400     0.222     0.286         9
#                             COOKIES_CUTTERS      0.868     0.857     0.863        77
#                                  NEBULIZERS      0.955     0.857     0.903        49
#                                  COMFORTERS      0.583     0.350     0.438        20
#                         ELLIPTICAL_MACHINES      0.908     0.922     0.915       128
#                               ENGINE_VALVES      0.932     0.932     0.932        44
#                                  SANDPAPERS      0.938     0.714     0.811        21
#        AUTOMOTIVE_SHOCK_ABSORBER_BUMP_STOPS      1.000     0.838     0.912        37
#                                     GAZEBOS      0.988     0.934     0.960        91
#                                  XENON_KITS      0.895     0.850     0.872        20
#                      AUTOMOTIVE_DOOR_PANELS      0.973     0.973     0.973       150
#                  INDOOR_CURTAINS_AND_BLINDS      0.960     0.901     0.929       161
#                         CAR_WINDOW_SWITCHES      0.852     0.742     0.793        31
#                                   EPILATORS      0.862     0.798     0.829        94
#                           MALE_MASTURBATORS      0.846     0.733     0.786        15
#                         DRILLS_SCREWDRIVERS      0.389     0.292     0.333        24
#                                  CONCEALERS      0.808     0.716     0.759        88
#                     SCHOOL_AND_OFFICE_GLUES      0.429     0.600     0.500        10
#                      SANDALS_AND_FLIP_FLOPS      0.851     0.889     0.870        45
#                                   BAR_SOAPS      0.776     0.750     0.763        60
#                   ELECTRIC_BATHROOM_FAUCETS      0.724     0.840     0.778        25
#                           VOLTAGE_DETECTORS      0.871     0.931     0.900        29
#                     ORTHOPEDIC_ANKLE_BRACES      0.857     0.800     0.828        15
#                              HEDGE_TRIMMERS      0.933     1.000     0.966        14
#                         STABILIZERS_AND_UPS      1.000     0.500     0.667         2
#                               BABY_PLAYARDS      0.803     0.855     0.828       110
#                            RESISTANCE_BANDS      0.944     0.939     0.942       180
#                             LAPTOP_CHARGERS      0.857     0.882     0.870        68
#                       COMPUTER_MOTHERBOARDS      0.814     0.854     0.833        41
# ...
#                            LIVING_ROOM_SETS      0.727     0.571     0.640        14
#                              BABY_PACIFIERS      0.786     0.733     0.759        15
#                              HAND_POLISHERS      0.778     0.500     0.609        14
#                                SHADE_CLOTHS      0.800     1.000     0.889        12
#                               HAMMER_DRILLS      1.000     0.250     0.400         8
#                              POWER_GRINDERS      0.692     0.692     0.692        13
#                               CAMERA_STRAPS      1.000     0.667     0.800         3
#                           LAWN_MOWER_BLADES      1.000     0.778     0.875         9
#                          PNEUMATIC_STAPLERS      1.000     0.923     0.960        13
#              THERMAL_REFRIGERATORS_AND_BAGS      0.857     0.643     0.735        28
#                                LIGHT_STANDS      1.000     0.714     0.833         7
#                                      STRAWS      0.625     0.625     0.625         8
#                                       SUITS      0.722     0.394     0.510        33
#                           BATHROOM_VANITIES      1.000     0.625     0.769         8
#                         VIBRATION_PLATFORMS      0.938     0.833     0.882        18
#                               DINING_TABLES      1.000     0.750     0.857        16
#                           TURNTABLE_NEEDLES      1.000     0.667     0.800         3
#                                HEARING_AIDS      0.800     0.800     0.800        10
#                     ORTHOPEDIC_WALKER_BOOTS      0.750     0.643     0.692        14
#                                         TEA      0.889     0.800     0.842        10
#                             TORQUE_WRENCHES      1.000     0.625     0.769         8
#                                 CATS_LITTER      0.857     1.000     0.923        12
#                                 MATE_GOURDS      0.857     0.545     0.667        11
#                                  MEAT_HOOKS      1.000     1.000     1.000         2
#                       AUTOMOTIVE_DEFLECTORS      1.000     1.000     1.000         5
#                   VARIABLE_FREQUENCY_DRIVES      1.000     0.857     0.923         7
#                                  SWEETENERS      0.500     0.500     0.500         8
#         AUTOMOTIVE_CELLPHONE_AND_GPS_MOUNTS      0.833     0.833     0.833         6
#                         RADIO_BASE_STATIONS      0.000     0.000     0.000         6
#                                    CRUTCHES      1.000     0.250     0.400         4
#                                POWER_STRIPS      0.667     0.400     0.500        10
#                               KATANA_SWORDS      0.900     0.692     0.783        13
#                        CATS_AND_DOGS_TREATS      0.545     0.429     0.480        14
#                         MEMORY_CARD_READERS      0.000     0.000     0.000         3
#                            TELEPHONE_CABLES      1.000     0.929     0.963        14
#                          SOLID_SWEET_PASTES      0.333     0.500     0.400        10
#                           DISPOSABLE_GLOVES      0.000     0.000     0.000         3
#                        MOTORCYCLE_GRAB_BARS      1.000     0.667     0.800         3
#                              PLUNGE_ROUTERS      0.800     0.500     0.615         8
#                         GROOVE_JOINT_PLIERS      0.800     1.000     0.889         4
#                          BICYCLE_HANDLEBARS      1.000     0.400     0.571         5
#                          SOLDERING_STATIONS      0.923     0.923     0.923        26
#                               TANDEM_CHAIRS      0.600     0.429     0.500         7
#                                GARAGE_DOORS      1.000     0.833     0.909        12
#                         SPARK_PLUG_WIRESETS      0.897     0.812     0.852        32
#                       ELECTRIC_SHOWER_HEADS      0.250     0.200     0.222         5
#                        PORTABLE_DVD_PLAYERS      0.714     0.556     0.625         9
#                                      DILDOS      0.286     0.250     0.267         8
#                   INDUSTRIAL_DOUGH_KNEADERS      0.600     0.692     0.643        13
#                   UNIVERSAL_REMOTE_CONTROLS      0.000     0.000     0.000         3
#                                 WHEEL_STUDS      0.250     0.167     0.200         6
#                            FABRIC_SOFTENERS      0.900     0.947     0.923        19
#              MOTORCYCLE_DISTRIBUTION_CHAINS      0.882     0.789     0.833        19
#                       DOOR_AND_WINDOW_LOCKS      0.500     0.333     0.400         3
#                                        GINS      0.000     0.000     0.000         4
#                                 HAND_TRUCKS      1.000     0.500     0.667         4
#                                    STAPLERS      0.750     0.500     0.600         6
#                                   APERITIFS      0.000     0.000     0.000         5
#                             SHOWER_CURTAINS      1.000     1.000     1.000         4
#                              ANTIQUE_CHAIRS      0.500     0.143     0.222         7
#                               YOGURT_MAKERS      0.000     0.000     0.000         5
#                                 SHIN_GUARDS      0.000     0.000     0.000         2
#                             GOLF_CLUBS_SETS      0.667     0.667     0.667         9
#                  FOOTBALL_GOALKEEPER_GLOVES      0.857     0.750     0.800        16
#                                LASER_LEVELS      0.714     0.625     0.667         8
#                        KEYBOARD_CONTROLLERS      0.333     0.400     0.364         5
#                          ALTERNATOR_PULLEYS      0.882     0.882     0.882        17
#            CAMERA_AND_CELLPHONE_STABILIZERS      1.000     0.667     0.800         3
#                                BABY_JUMPERS      1.000     0.500     0.667         6
#                 CAMERA_REPLACEMENT_DISPLAYS      1.000     0.857     0.923         7
#                                 CRANKSHAFTS      0.850     0.810     0.829        21
#                                BREAD_MAKERS      0.125     0.333     0.182         3
#                    SCHOOL_AND_OFFICE_PAPERS      1.000     0.375     0.545         8
#                    STOVETOP_POPCORN_POPPERS      1.000     0.625     0.769         8
#                      BREAST_FEEDING_PILLOWS      0.727     0.727     0.727        11
#                               POOL_CLEANERS      1.000     0.400     0.571         5
#                              LINEMAN_PLIERS      1.000     0.667     0.800         3
#                                  COAT_RACKS      0.250     0.167     0.200         6
#                                  POOL_PUMPS      0.900     0.750     0.818        12
#                     WATER_PURIFIERS_FILTERS      0.875     0.350     0.500        20
#                               SAFETY_GLOVES      0.750     0.500     0.600         6
#                          ISOPROPYL_ALCOHOLS      0.875     0.778     0.824         9
#               VEHICLE_BRAKE_HYDRAULIC_HOSES      0.833     0.556     0.667         9
#                              MEDICINE_BALLS      0.500     0.500     0.500         4
#                             KITCHEN_GRATERS      0.500     0.200     0.286         5
#                              NAPKIN_HOLDERS      0.667     0.222     0.333         9
#                               PUNCHING_BAGS      1.000     0.333     0.500         3
#                                 ESPADRILLES      0.000     0.000     0.000         8
#                         CAR_CENTER_CONSOLES      1.000     0.667     0.800         6
#                             VIDEO_CASSETTES      0.455     0.833     0.588         6
#                              POTENTIOMETERS      1.000     0.400     0.571         5
#                    READY_TO_DRINK_COCKTAILS      0.000     0.000     0.000         2
#                                 FLOOR_LAMPS      0.727     0.727     0.727        11
#                            DRONE_PROPELLERS      0.250     0.167     0.200         6
#                                       TENTS      0.733     1.000     0.846        11
#                            SAFETY_HARNESSES      0.000     0.000     0.000         4
#                                    SYRINGES      1.000     0.250     0.400         4
#                                   BEDLINERS      0.917     0.688     0.786        16
#                     ELECTROLYTIC_CAPACITORS      1.000     0.714     0.833         7
#                                BASKET_BALLS      0.667     1.000     0.800         2
#                                   OTOSCOPES      1.000     0.250     0.400         4
#                               WAFFLE_MAKERS      0.778     0.875     0.824         8
#                                 PENIS_RINGS      0.500     0.250     0.333         4
#                          ELECTRIC_AIR_PUMPS      0.714     0.625     0.667         8
#                             COFFEE_CAPSULES      0.833     1.000     0.909         5
#                         BABY_PACIFIER_CLIPS      0.625     1.000     0.769         5
#                                   KEY_RACKS      0.000     0.000     0.000         4
#                                  DEODORANTS      0.750     0.600     0.667         5
#                          INDUSTRIAL_PULLEYS      1.000     0.600     0.750         5
#                               BILL_COUNTERS      0.800     0.800     0.800         5
#                  AUDIO_AND_VIDEO_CONNECTORS      0.000     0.000     0.000         4
#                            WASHING_MACHINES      1.000     0.583     0.737        12
#                 ENGINE_COOLING_FAN_SWITCHES      0.800     0.667     0.727         6
#                        AUTOMOTIVE_BATTERIES      1.000     0.400     0.571         5
#                        CHIP_AND_DIP_SERVERS      0.333     0.250     0.286         4
#                                ARCHERY_BOWS      0.833     0.833     0.833         6
#                             VINYL_FLOORINGS      0.750     0.857     0.800         7
#                              MENSTRUAL_CUPS      1.000     1.000     1.000         5
#                               SLEEPING_BAGS      1.000     0.250     0.400         4
#                               RUBBER_STAMPS      0.750     0.600     0.667         5
#                              DRYER_MACHINES      0.545     0.750     0.632         8
#                            ENERGETIC_STONES      0.667     0.571     0.615         7
#                              BICYCLE_PEDALS      1.000     0.889     0.941         9
#                      MOTORCYCLE_CARBURETORS      0.750     0.600     0.667         5
#                           SCREWDRIVERS_SETS      0.000     0.000     0.000         3
#                                EDIBLE_SEEDS      0.667     0.667     0.667         3
#                        STORE_SHOPPING_CARTS      1.000     1.000     1.000         4
#                         SWIMMING_NOSE_CLIPS      1.000     0.500     0.667         2
#                                 AFTERSHAVES      0.000     0.000     0.000         3
#                              AIRBAG_MODULES      1.000     0.667     0.800         3
#                                   HAND_SAWS      0.800     0.667     0.727         6
#           NECK_GAITERS_MASKS_AND_BALACLAVAS      0.000     0.000     0.000         2
#                          MAGNETIC_COMPASSES      0.800     0.667     0.727         6
#                          MAKEUP_TRAIN_CASES      1.000     0.500     0.667         4
#                            POPCORN_MACHINES      0.750     1.000     0.857         9
#                                LAMP_HOLDERS      0.333     0.500     0.400         4
#                    IGNITION_CONTROL_MODULES      0.333     0.143     0.200         7
#                             CAR_FRONT_MASKS      0.667     1.000     0.800         2
#                               HAND_BLENDERS      0.000     0.000     0.000         3
#                              KIDS_TRICYCLES      0.333     0.250     0.286         4
#                              AIRGUN_PELLETS      0.500     0.250     0.333         4
#                            AUTOMOTIVE_SEATS      0.333     0.167     0.222         6
#              MOTORCYCLE_TRANSMISSION_CROWNS      1.000     0.500     0.667         4
#                                  LAMINATORS      0.375     0.429     0.400         7
#                                 CEREAL_BARS      1.000     0.333     0.500         3
#                                MUSIC_ALBUMS      0.333     0.250     0.286         4
#                   AUTOMOTIVE_CV_JOINT_BOOTS      0.667     0.857     0.750         7
#                           MICROWAVE_KEYPADS      1.000     1.000     1.000         3
#                           WALL_ANCHOR_PLUGS      1.000     0.500     0.667         4
#                                 DRUM_STANDS      0.800     0.571     0.667         7
#                                 PET_COLLARS      0.900     0.643     0.750        14
#                             GATE_GEAR_RACKS      1.000     0.250     0.400         4
#                                   CAR_HOODS      1.000     1.000     1.000         3
#                        SCREEN_PRINTING_KITS      1.000     0.500     0.667         4
#                                  LED_STRIPS      0.750     0.750     0.750         4
#                             SANDWICH_MAKERS      0.500     0.500     0.500         2
#                              DENTAL_FLOSSES      0.500     1.000     0.667         2
#                              CAMERA_FLASHES      1.000     0.800     0.889         5
#                           DOG_NAIL_CLIPPERS      1.000     0.500     0.667         2
#                                    PINBALLS      1.000     0.333     0.500         6
#                                      GAUZES      0.800     0.667     0.727         6
#                                        SODS      0.500     0.333     0.400         3
#                          ELECTRICITY_METERS      0.000     0.000     0.000         4
#                             METAL_DETECTORS      0.667     0.667     0.667         3
#                          ELECTRIC_CHAINSAWS      1.000     0.333     0.500         3
#                            KNITTING_NEEDLES      0.625     0.833     0.714         6
#                           SWIMMING_EARPLUGS      0.000     0.000     0.000         2
#                                 SOUND_CARDS      1.000     0.400     0.571         5
#                                    STEPPERS      0.500     0.250     0.333         4
#                                 FANNY_PACKS      0.000     0.000     0.000         4
#                          TOOTHBRUSH_HOLDERS      1.000     0.500     0.667         2
#                          TABLE_TENNIS_BALLS      1.000     0.500     0.667         2
#                 ENGINE_OIL_PRESSURE_SENSORS      0.500     0.333     0.400         3
#                                 ICE_BUCKETS      0.500     0.429     0.462         7
#                               MASSAGE_SOFAS      1.000     0.250     0.400         4
#                              STYLING_CHAIRS      1.000     0.500     0.667         2
#                               BICYCLE_SEATS      0.500     0.333     0.400         3
#                            VOLLEYBALL_BALLS      0.000     0.000     0.000         3
#                           SPHYGMOMANOMETERS      0.500     0.250     0.333         4
#                              BINDING_SPINES      0.000     0.000     0.000         2
#                    DIGITAL_WEATHER_STATIONS      0.000     0.000     0.000         2
#                          HOME_BOTTLE_STANDS      1.000     0.667     0.800         3
#                                   DOORBELLS      0.000     0.000     0.000         2
#                                DRIED_FRUITS      0.500     0.500     0.500         2
#                            BOXING_HEADGEARS      0.000     0.000     0.000         2
#
#                                    accuracy                          0.921    138550
#                                   macro avg      0.826     0.762     0.782    138550
#                                weighted avg      0.922     0.921     0.921    138550
